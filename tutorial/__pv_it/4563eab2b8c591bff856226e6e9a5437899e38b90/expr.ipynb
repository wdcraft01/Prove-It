# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, Q, y
from proveit.logic import And, Forall

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [y]
expr = Forall(subExpr2, And(Function(P, y), Forall(subExpr2, Function(Q, y), conditions = subExpr1)), conditions = subExpr1)
# Out:
# expr: forall_{y} (P(y) and [forall_{y} Q(y)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y} (P(y) and [forall_{y} Q(y)])
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. y -> (P(y) and [forall_{y} Q(y)])
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. P(y) and [forall_{y} Q(y)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (P(y) , forall_{y} Q(y))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. P(y)
#    core type: Operation
#    operator: 7
#    operand: 12
# 6. forall_{y} Q(y)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. y -> Q(y)
#    core type: Lambda
#    parameter: 12
#    body: 10
# 10. Q(y)
#     core type: Operation
#     operator: 11
#     operand: 12
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. y
#     core type: Variable
#     sub-expressions:
