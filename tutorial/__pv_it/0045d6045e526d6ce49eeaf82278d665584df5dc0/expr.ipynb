# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
import sys
sys.path.insert(1, "../..")
from demo_operations import Factorial, Multiply
from proveit import ExprTuple, Literal, Variable
from proveit._common_ import x, y

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("omega", latexFormat = r"\omega")
subExpr2 = Factorial(Multiply(x, Literal("5"), subExpr1))
expr = ExprTuple(subExpr2, y, Factorial(Multiply(subExpr2, Literal("5"), subExpr1)))
# Out:
# expr: ((x * 5 * omega)! , y , ((x * 5 * omega)! * 5 * omega)!)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((x * 5 * omega)! , y , ((x * 5 * omega)! * 5 * omega)!)
#    core type: ExprTuple
#    sub-expressions: 5, 1, 2
# 1. y
#    core type: Variable
#    sub-expressions:
# 2. ((x * 5 * omega)! * 5 * omega)!
#    core type: Operation
#    operator: 6
#    operand: 3
# 3. (x * 5 * omega)! * 5 * omega
#    core type: Operation
#    operator: 8
#    operands: 4
# 4. ((x * 5 * omega)! , 5 , omega)
#    core type: ExprTuple
#    sub-expressions: 5, 11, 12
# 5. (x * 5 * omega)!
#    core type: Operation
#    operator: 6
#    operand: 7
# 6. !
#    core type: Literal
#    sub-expressions:
# 7. x * 5 * omega
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. *
#    core type: Literal
#    sub-expressions:
# 9. (x , 5 , omega)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. 5
#     core type: Literal
#     sub-expressions:
# 12. omega
#     core type: Variable
#     sub-expressions:
