# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.number.Sum.html">Sum</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import m, x
from proveit.number import Exp, Interval, Sum, infinity, zero

# %%
# build up the expression from sub-expressions
expr = Sum([m], Exp(x, m), domain = Interval(zero, infinity), conditions = [])
# Out:
# expr: Sum_{m=0}^{infinity} x^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. Sum_{m=0}^{infinity} x^{m}
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. m -> x^{m} | m in {0...infinity}
#    core type: Lambda
#    parameter: 11
#    body: 3
#    conditions: 4\n3. x^{m}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (m in {0...infinity})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. Exp
#    core type: Literal
#    sub-expressions:
# 6. (x , m)
#    core type: ExprTuple
#    sub-expressions: 8, 11
# 7. m in {0...infinity}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (m , {0...infinity})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. {0...infinity}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (0 , infinity)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. infinity
#     core type: Literal
#     sub-expressions:
