# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Pxy, Qx, Ry, S, x, y
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
expr = Forall([x, y], Pxy, domain = S, conditions = [Qx, Ry])
# Out:
# expr: forall_{x, y in S | Q(x) , R(y)} P(x , y)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, y in S | Q(x) , R(y)} P(x , y)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. x -> [forall_{y in S | R(y)} P(x , y)] | x in S , Q(x)
#    core type: Lambda
#    parameter: 16
#    body: 2
#    conditions: 3\n2. forall_{y in S | R(y)} P(x , y)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x in S , Q(x))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. y -> P(x , y) | y in S , R(y)
#    core type: Lambda
#    parameter: 20
#    body: 8
#    conditions: 9\n6. x in S
#    core type: Operation
#    operator: 17
#    operands: 10
# 7. Q(x)
#    core type: Operation
#    operator: 11
#    operand: 16
# 8. P(x , y)
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (y in S , R(y))
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. (x , S)
#     core type: ExprTuple
#     sub-expressions: 16, 21
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. P
#     core type: Variable
#     sub-expressions:
# 13. (x , y)
#     core type: ExprTuple
#     sub-expressions: 16, 20
# 14. y in S
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. R(y)
#     core type: Operation
#     operator: 19
#     operand: 20
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (y , S)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. R
#     core type: Variable
#     sub-expressions:
# 20. y
#     core type: Variable
#     sub-expressions:
# 21. S
#     core type: Variable
#     sub-expressions:
