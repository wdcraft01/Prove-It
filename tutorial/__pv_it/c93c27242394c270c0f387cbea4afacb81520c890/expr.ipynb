# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import Qx, S, a, x, y
from proveit.logic import Equals, InSet
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Equals(Add(x, a), Add(y, a)), conditions = [InSet(y, S), Equals(x, y), Qx])
# Out:
# expr: y -> ((x + a) = (y + a)) | y in S , x = y , Q(x)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> ((x + a) = (y + a)) | y in S , x = y , Q(x)
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. (x + a) = (y + a)
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. (y in S , x = y , Q(x))
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 3. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 4. y in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. x = y
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. Q(x)
#    core type: Operation
#    operator: 13
#    operand: 18
# 7. x + a
#    core type: Operation
#    operator: 15
#    operands: 14
# 8. y + a
#    core type: Operation
#    operator: 15
#    operands: 16
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (y , S)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 13. Q
#     core type: Variable
#     sub-expressions:
# 14. (x , a)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (y , a)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. S
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
