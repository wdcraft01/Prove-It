# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Lambda
from proveit._common_ import P, Q, Qx, R, S, a, x, y
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([x, y], Equals(Add(x, a), Add(y, a)), domains = [R, S], conditions = [Equals(x, y), Qx]), conditions = [InSet(a, P), Function(Q, a)])
# Out:
# expr: a -> [forall_{(x, y) in R * S | x = y , Q(x)} ((x + a) = (y + a))] | a in P , Q(a)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{(x, y) in R * S | x = y , Q(x)} ((x + a) = (y + a))] | a in P , Q(a)
#    core type: Lambda
#    parameter: 34
#    body: 1
#    conditions: 2\n1. forall_{(x, y) in R * S | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 9
#    operand: 3
# 2. (a in P , Q(a))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. x -> [forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))] | x in R
#    core type: Lambda
#    parameter: 32
#    body: 6
#    conditions: 7\n4. a in P
#    core type: Operation
#    operator: 23
#    operands: 8
# 5. Q(a)
#    core type: Operation
#    operator: 27
#    operand: 34
# 6. forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (x in R)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , P)
#    core type: ExprTuple
#    sub-expressions: 34, 12
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. y -> ((x + a) = (y + a)) | y in S , x = y , Q(x)
#     core type: Lambda
#     parameter: 33
#     body: 13
#     conditions: 14\n11. x in R
#     core type: Operation
#     operator: 23
#     operands: 15
# 12. P
#     core type: Variable
#     sub-expressions:
# 13. (x + a) = (y + a)
#     core type: Operation
#     operator: 25
#     operands: 16
# 14. (y in S , x = y , Q(x))
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 15. (x , R)
#     core type: ExprTuple
#     sub-expressions: 32, 20
# 16. (x + a , y + a)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. y in S
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. x = y
#     core type: Operation
#     operator: 25
#     operands: 26
# 19. Q(x)
#     core type: Operation
#     operator: 27
#     operand: 32
# 20. R
#     core type: Variable
#     sub-expressions:
# 21. x + a
#     core type: Operation
#     operator: 29
#     operands: 28
# 22. y + a
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (y , S)
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (x , y)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. Q
#     core type: Variable
#     sub-expressions:
# 28. (x , a)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (y , a)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. S
#     core type: Variable
#     sub-expressions:
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. y
#     core type: Variable
#     sub-expressions:
# 34. a
#     core type: Variable
#     sub-expressions:
