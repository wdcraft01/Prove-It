# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Forall([a, x, y], Equals(Add(x, a), Add(y, a)), domain = S, conditions = [Equals(x, y)])
# Out:
# expr: forall_{a, x, y in S | x = y} ((x + a) = (y + a))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, x, y in S | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{x, y in S | x = y} ((x + a) = (y + a))] | a in S
#    core type: Lambda
#    parameter: 30
#    body: 2
#    conditions: 3\n2. forall_{x, y in S | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{y in S | x = y} ((x + a) = (y + a))] | x in S
#    core type: Lambda
#    parameter: 28
#    body: 6
#    conditions: 7\n5. a in S
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall_{y in S | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (x in S)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , S)
#    core type: ExprTuple
#    sub-expressions: 30, 27
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. y -> ((x + a) = (y + a)) | y in S , x = y
#     core type: Lambda
#     parameter: 29
#     body: 12
#     conditions: 13\n11. x in S
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. (x + a) = (y + a)
#     core type: Operation
#     operator: 22
#     operands: 15
# 13. (y in S , x = y)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. (x , S)
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 15. (x + a , y + a)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. y in S
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. x = y
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. x + a
#     core type: Operation
#     operator: 25
#     operands: 24
# 19. y + a
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (y , S)
#     core type: ExprTuple
#     sub-expressions: 29, 27
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (x , y)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. (x , a)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (y , a)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. S
#     core type: Variable
#     sub-expressions:
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. y
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
