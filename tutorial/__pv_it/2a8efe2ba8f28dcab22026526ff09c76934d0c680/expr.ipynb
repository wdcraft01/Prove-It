# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import Pxy, R, S, x, y
from proveit.logic import Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Pxy, domain = R, conditions = []), conditions = [InSet(x, S)])
# Out:
# expr: x -> [forall_{y in R} P(x , y)] | x in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y in R} P(x , y)] | x in S
#    core type: Lambda
#    parameter: 13
#    body: 1
#    conditions: 2\n1. forall_{y in R} P(x , y)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> P(x , y) | y in R
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n5. x in S
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. P(x , y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (y in R)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (x , S)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. P
#    core type: Variable
#    sub-expressions:
# 10. (x , y)
#     core type: ExprTuple
#     sub-expressions: 13, 16
# 11. y in R
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. S
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y , R)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. R
#     core type: Variable
#     sub-expressions:
