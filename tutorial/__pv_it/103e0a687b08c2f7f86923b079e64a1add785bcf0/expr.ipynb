# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, x, y
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(Add(x, a), Add(y, a)), domain = S, conditions = [Equals(x, y)]), conditions = [InSet(x, S)])
# Out:
# expr: x -> [forall_{y in S | x = y} ((x + a) = (y + a))] | x in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y in S | x = y} ((x + a) = (y + a))] | x in S
#    core type: Lambda
#    parameter: 22
#    body: 1
#    conditions: 2\n1. forall_{y in S | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((x + a) = (y + a)) | y in S , x = y
#    core type: Lambda
#    parameter: 23
#    body: 6
#    conditions: 7\n5. x in S
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. (x + a) = (y + a)
#    core type: Operation
#    operator: 16
#    operands: 9
# 7. (y in S , x = y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (x , S)
#    core type: ExprTuple
#    sub-expressions: 22, 21
# 9. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. y in S
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. x = y
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. x + a
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. y + a
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y , S)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (x , y)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. (x , a)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (y , a)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. S
#     core type: Variable
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. y
#     core type: Variable
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
