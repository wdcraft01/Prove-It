# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import Qx, S, a, x, y
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([x, y], Equals(Add(x, a), Add(y, a)), domain = S, conditions = [Equals(x, y), Qx]), conditions = [InSet(a, S)])
# Out:
# expr: a -> [forall_{x, y in S | x = y , Q(x)} ((x + a) = (y + a))] | a in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{x, y in S | x = y , Q(x)} ((x + a) = (y + a))] | a in S
#    core type: Lambda
#    parameter: 31
#    body: 1
#    conditions: 2\n1. forall_{x, y in S | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. x -> [forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))] | x in S
#    core type: Lambda
#    parameter: 29
#    body: 5
#    conditions: 6\n4. a in S
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (x in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (a , S)
#    core type: ExprTuple
#    sub-expressions: 31, 28
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. y -> ((x + a) = (y + a)) | y in S , x = y , Q(x)
#    core type: Lambda
#    parameter: 30
#    body: 11
#    conditions: 12\n10. x in S
#     core type: Operation
#     operator: 20
#     operands: 13
# 11. (x + a) = (y + a)
#     core type: Operation
#     operator: 22
#     operands: 14
# 12. (y in S , x = y , Q(x))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17
# 13. (x , S)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 14. (x + a , y + a)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. y in S
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. x = y
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. Q(x)
#     core type: Operation
#     operator: 24
#     operand: 29
# 18. x + a
#     core type: Operation
#     operator: 26
#     operands: 25
# 19. y + a
#     core type: Operation
#     operator: 26
#     operands: 27
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (y , S)
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (x , y)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 24. Q
#     core type: Variable
#     sub-expressions:
# 25. (x , a)
#     core type: ExprTuple
#     sub-expressions: 29, 31
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (y , a)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. S
#     core type: Variable
#     sub-expressions:
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. y
#     core type: Variable
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
