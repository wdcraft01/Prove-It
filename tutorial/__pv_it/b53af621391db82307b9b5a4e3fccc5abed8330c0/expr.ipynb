# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import Pxy, R, S, x, y
from proveit.logic import Forall, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x, y], Pxy, domains = [S, R], conditions = []), InSet(x, S), InSet(y, R))
# Out:
# expr: (forall_{(x, y) in S * R} P(x , y) , x in S , y in R)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{(x, y) in S * R} P(x , y) , x in S , y in R)
#    core type: ExprTuple
#    sub-expressions: 1, 7, 13
# 1. forall_{(x, y) in S * R} P(x , y)
#    core type: Operation
#    operator: 5
#    operand: 2
# 2. x -> [forall_{y in R} P(x , y)] | x in S
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. forall_{y in R} P(x , y)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (x in S)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. y -> P(x , y) | y in R
#    core type: Lambda
#    parameter: 18
#    body: 8
#    conditions: 9\n7. x in S
#    core type: Operation
#    operator: 16
#    operands: 10
# 8. P(x , y)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (y in R)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. (x , S)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 15, 18
# 13. y in R
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. S
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (y , R)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. R
#     core type: Variable
#     sub-expressions:
