# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, a, x, y
from proveit.logic import Forall
from proveit.number import Add, Less

# %%
# build up the expression from sub-expressions
expr = Forall([y], Forall([a], Function(P, [x, y, a]), conditions = [Less(a, Add(x, y))]), conditions = [])
# Out:
# expr: forall_{y} [forall_{a | a < (x + y)} P(x , y , a)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y} [forall_{a | a < (x + y)} P(x , y , a)]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. y -> [forall_{a | a < (x + y)} P(x , y , a)]
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. forall_{a | a < (x + y)} P(x , y , a)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. a -> P(x , y , a) | a < (x + y)
#    core type: Lambda
#    parameter: 12
#    body: 5
#    conditions: 6\n5. P(x , y , a)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a < (x + y))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. (x , y , a)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 12
# 9. a < (x + y)
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. <
#     core type: Literal
#     sub-expressions:
# 11. (a , x + y)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. x + y
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (x , y)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. y
#     core type: Variable
#     sub-expressions:
