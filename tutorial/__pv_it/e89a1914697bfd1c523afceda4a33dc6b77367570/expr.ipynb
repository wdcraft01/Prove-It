# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Pxy, R, S, x, y
from proveit.logic import Forall, Set

# %%
# build up the expression from sub-expressions
expr = Set(Forall([x, y], Pxy, domains = [S, R], conditions = []))
# Out:
# expr: {forall_{(x, y) in S * R} P(x , y)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{(x, y) in S * R} P(x , y)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (forall_{(x, y) in S * R} P(x , y))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. forall_{(x, y) in S * R} P(x , y)
#    core type: Operation
#    operator: 7
#    operand: 4
# 4. x -> [forall_{y in R} P(x , y)] | x in S
#    core type: Lambda
#    parameter: 17
#    body: 5
#    conditions: 6\n5. forall_{y in R} P(x , y)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (x in S)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. y -> P(x , y) | y in R
#    core type: Lambda
#    parameter: 20
#    body: 10
#    conditions: 11\n9. x in S
#    core type: Operation
#    operator: 18
#    operands: 12
# 10. P(x , y)
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (y in R)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (x , S)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 13. P
#     core type: Variable
#     sub-expressions:
# 14. (x , y)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 15. y in R
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. S
#     core type: Variable
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (y , R)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. y
#     core type: Variable
#     sub-expressions:
# 21. R
#     core type: Variable
#     sub-expressions:
