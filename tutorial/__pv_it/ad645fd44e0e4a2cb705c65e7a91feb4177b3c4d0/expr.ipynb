# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Qx, R, a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Forall([y], Equals(Add(x, a), Add(y, a)), domain = R, conditions = [Equals(x, y), Qx])
# Out:
# expr: forall_{y in R | x = y , Q(x)} ((x + a) = (y + a))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in R | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> ((x + a) = (y + a)) | y in R , x = y , Q(x)
#    core type: Lambda
#    parameter: 21
#    body: 3
#    conditions: 4\n3. (x + a) = (y + a)
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (y in R , x = y , Q(x))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 6. y in R
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. x = y
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. Q(x)
#    core type: Operation
#    operator: 15
#    operand: 20
# 9. x + a
#    core type: Operation
#    operator: 17
#    operands: 16
# 10. y + a
#     core type: Operation
#     operator: 17
#     operands: 18
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (y , R)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (x , y)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 15. Q
#     core type: Variable
#     sub-expressions:
# 16. (x , a)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (y , a)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. R
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. y
#     core type: Variable
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
