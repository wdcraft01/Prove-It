# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, Q, Qx, R, a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Forall([a], Forall([x, y], Equals(Add(x, a), Add(y, a)), domain = R, conditions = [Equals(x, y), Qx]), domain = P, conditions = [Function(Q, a)])
# Out:
# expr: forall_{a in P | Q(a)} [forall_{x, y in R | x = y , Q(x)} ((x + a) = (y + a))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a in P | Q(a)} [forall_{x, y in R | x = y , Q(x)} ((x + a) = (y + a))]
#    core type: Operation
#    operator: 10
#    operand: 1
# 1. a -> [forall_{x, y in R | x = y , Q(x)} ((x + a) = (y + a))] | a in P , Q(a)
#    core type: Lambda
#    parameter: 34
#    body: 2
#    conditions: 3\n2. forall_{x, y in R | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 10
#    operand: 4
# 3. (a in P , Q(a))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. x -> [forall_{y in R | x = y , Q(x)} ((x + a) = (y + a))] | x in R
#    core type: Lambda
#    parameter: 32
#    body: 7
#    conditions: 8\n5. a in P
#    core type: Operation
#    operator: 23
#    operands: 9
# 6. Q(a)
#    core type: Operation
#    operator: 27
#    operand: 34
# 7. forall_{y in R | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. (x in R)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (a , P)
#    core type: ExprTuple
#    sub-expressions: 34, 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. y -> ((x + a) = (y + a)) | y in R , x = y , Q(x)
#     core type: Lambda
#     parameter: 33
#     body: 14
#     conditions: 15\n12. x in R
#     core type: Operation
#     operator: 23
#     operands: 16
# 13. P
#     core type: Variable
#     sub-expressions:
# 14. (x + a) = (y + a)
#     core type: Operation
#     operator: 25
#     operands: 17
# 15. (y in R , x = y , Q(x))
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 16. (x , R)
#     core type: ExprTuple
#     sub-expressions: 32, 31
# 17. (x + a , y + a)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. y in R
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. x = y
#     core type: Operation
#     operator: 25
#     operands: 26
# 20. Q(x)
#     core type: Operation
#     operator: 27
#     operand: 32
# 21. x + a
#     core type: Operation
#     operator: 29
#     operands: 28
# 22. y + a
#     core type: Operation
#     operator: 29
#     operands: 30
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (y , R)
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 25. =
#     core type: Literal
#     sub-expressions:
# 26. (x , y)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. Q
#     core type: Variable
#     sub-expressions:
# 28. (x , a)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (y , a)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. R
#     core type: Variable
#     sub-expressions:
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. y
#     core type: Variable
#     sub-expressions:
# 34. a
#     core type: Variable
#     sub-expressions:
