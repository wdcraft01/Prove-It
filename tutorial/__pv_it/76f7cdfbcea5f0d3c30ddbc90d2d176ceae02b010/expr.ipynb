# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import Pxyz, x, y, z
from proveit.logic import Forall
from proveit.number import Add, Less

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y, z], Pxyz, conditions = [Less(z, Add(x, y))]))
# Out:
# expr: x -> [forall_{y, z | z < (x + y)} P(x , y , z)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y, z | z < (x + y)} P(x , y , z)]
#    core type: Lambda
#    parameter: 17
#    body: 1
# 1. forall_{y, z | z < (x + y)} P(x , y , z)
#    core type: Operation
#    operator: 4
#    operand: 2
# 2. y -> [forall_{z | z < (x + y)} P(x , y , z)]
#    core type: Lambda
#    parameter: 18
#    body: 3
# 3. forall_{z | z < (x + y)} P(x , y , z)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. z -> P(x , y , z) | z < (x + y)
#    core type: Lambda
#    parameter: 13
#    body: 6
#    conditions: 7\n6. P(x , y , z)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (z < (x + y))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. (x , y , z)
#    core type: ExprTuple
#    sub-expressions: 17, 18, 13
# 10. z < (x + y)
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. <
#     core type: Literal
#     sub-expressions:
# 12. (z , x + y)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. z
#     core type: Variable
#     sub-expressions:
# 14. x + y
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (x , y)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. y
#     core type: Variable
#     sub-expressions:
