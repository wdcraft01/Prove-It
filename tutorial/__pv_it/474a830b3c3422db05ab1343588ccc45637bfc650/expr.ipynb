# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Forall([y], Equals(Add(x, a), Add(y, a)), domain = S, conditions = [Equals(x, y)])
# Out:
# expr: forall_{y in S | x = y} ((x + a) = (y + a))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in S | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> ((x + a) = (y + a)) | y in S , x = y
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. (x + a) = (y + a)
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (y in S , x = y)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. y in S
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. x = y
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. x + a
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. y + a
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y , S)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x , y)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. (x , a)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (y , a)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. S
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
