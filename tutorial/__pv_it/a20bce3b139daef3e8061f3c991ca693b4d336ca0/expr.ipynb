# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import Qx, R, S, a, x, y
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(Add(x, a), Add(y, a)), domain = S, conditions = [Equals(x, y), Qx]), conditions = [InSet(x, R)])
# Out:
# expr: x -> [forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))] | x in R

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))] | x in R
#    core type: Lambda
#    parameter: 25
#    body: 1
#    conditions: 2\n1. forall_{y in S | x = y , Q(x)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x in R)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((x + a) = (y + a)) | y in S , x = y , Q(x)
#    core type: Lambda
#    parameter: 26
#    body: 6
#    conditions: 7\n5. x in R
#    core type: Operation
#    operator: 16
#    operands: 8
# 6. (x + a) = (y + a)
#    core type: Operation
#    operator: 18
#    operands: 9
# 7. (y in S , x = y , Q(x))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. (x , R)
#    core type: ExprTuple
#    sub-expressions: 25, 13
# 9. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. y in S
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. x = y
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. Q(x)
#     core type: Operation
#     operator: 20
#     operand: 25
# 13. R
#     core type: Variable
#     sub-expressions:
# 14. x + a
#     core type: Operation
#     operator: 22
#     operands: 21
# 15. y + a
#     core type: Operation
#     operator: 22
#     operands: 23
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (y , S)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (x , y)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 20. Q
#     core type: Variable
#     sub-expressions:
# 21. (x , a)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (y , a)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. S
#     core type: Variable
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
