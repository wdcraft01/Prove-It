# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Pxyz, x, y, z
from proveit.logic import Forall, Set
from proveit.number import Add, Less

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = Less(z, Add(x, y))
expr = Set(subExpr2, Forall([x], Forall([y], Forall([z], Pxyz, conditions = [subExpr2]), conditions = subExpr1), conditions = subExpr1))
# Out:
# expr: {z < (x + y) , forall_{x} [forall_{y} [forall_{z | z < (x + y)} P(x , y , z)]]}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {z < (x + y) , forall_{x} [forall_{y} [forall_{z | z < (x + y)} P(x , y , z)]]}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (z < (x + y) , forall_{x} [forall_{y} [forall_{z | z < (x + y)} P(x , y , z)]])
#    core type: ExprTuple
#    sub-expressions: 14, 3
# 3. forall_{x} [forall_{y} [forall_{z | z < (x + y)} P(x , y , z)]]
#    core type: Operation
#    operator: 8
#    operand: 4
# 4. x -> [forall_{y} [forall_{z | z < (x + y)} P(x , y , z)]]
#    core type: Lambda
#    parameter: 21
#    body: 5
# 5. forall_{y} [forall_{z | z < (x + y)} P(x , y , z)]
#    core type: Operation
#    operator: 8
#    operand: 6
# 6. y -> [forall_{z | z < (x + y)} P(x , y , z)]
#    core type: Lambda
#    parameter: 22
#    body: 7
# 7. forall_{z | z < (x + y)} P(x , y , z)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. forall
#    core type: Literal
#    sub-expressions:
# ...
