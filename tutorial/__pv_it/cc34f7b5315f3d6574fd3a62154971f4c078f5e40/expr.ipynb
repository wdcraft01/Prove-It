# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Px, Qx, Rx, S, x
from proveit.logic import Forall, Set

# %%
# build up the expression from sub-expressions
expr = Set(Forall([x], Px, domain = S, conditions = [Qx, Rx]))
# Out:
# expr: {forall_{x in S | Q(x) , R(x)} P(x)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x in S | Q(x) , R(x)} P(x)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x in S | Q(x) , R(x)} P(x))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. forall_{x in S | Q(x) , R(x)} P(x)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> P(x) | x in S , Q(x) , R(x)
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n6. P(x)
#    core type: Operation
#    operator: 8
#    operand: 16
# 7. (x in S , Q(x) , R(x))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. x in S
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Q(x)
#     core type: Operation
#     operator: 14
#     operand: 16
# 11. R(x)
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x , S)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. R
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. S
#     core type: Variable
#     sub-expressions:
