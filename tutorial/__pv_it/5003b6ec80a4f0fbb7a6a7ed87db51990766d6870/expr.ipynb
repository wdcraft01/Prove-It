# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([B, C], Implies(A, C), conditions = [Implies(A, B), Implies(B, C)])
# Out:
# expr: forall_{B, C | A => B , B => C} (A => C)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B, C | A => B , B => C} (A => C)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. B -> [forall_{C | B => C} (A => C)] | A => B
#    core type: Lambda
#    parameter: 15
#    body: 2
#    conditions: 3\n2. forall_{C | B => C} (A => C)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A => B)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. C -> (A => C) | B => C
#    core type: Lambda
#    parameter: 16
#    body: 7
#    conditions: 8\n6. A => B
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. A => C
#    core type: Operation
#    operator: 13
#    operands: 10
# 8. (B => C)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 12, 15
# 10. (A , C)
#     core type: ExprTuple
#     sub-expressions: 12, 16
# 11. B => C
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (B , C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
