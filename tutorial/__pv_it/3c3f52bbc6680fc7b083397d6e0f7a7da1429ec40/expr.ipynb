# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([A, B, C], Implies(A, C), conditions = [Implies(A, B), Implies(B, C)])
# Out:
# expr: forall_{A, B, C | A => B , B => C} (A => C)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B, C | A => B , B => C} (A => C)
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. A -> [forall_{B, C | A => B , B => C} (A => C)]
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. forall_{B, C | A => B , B => C} (A => C)
#    core type: Operation
#    operator: 6
#    operand: 3
# 3. B -> [forall_{C | B => C} (A => C)] | A => B
#    core type: Lambda
#    parameter: 17
#    body: 4
#    conditions: 5\n4. forall_{C | B => C} (A => C)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (A => B)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. C -> (A => C) | B => C
#    core type: Lambda
#    parameter: 18
#    body: 9
#    conditions: 10\n8. A => B
#    core type: Operation
#    operator: 15
#    operands: 11
# 9. A => C
#    core type: Operation
#    operator: 15
#    operands: 12
# 10. (B => C)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 14, 17
# 12. (A , C)
#     core type: ExprTuple
#     sub-expressions: 14, 18
# 13. B => C
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (B , C)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
