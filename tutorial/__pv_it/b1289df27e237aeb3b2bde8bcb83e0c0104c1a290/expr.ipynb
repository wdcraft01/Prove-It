# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import m, x
from proveit.logic import Equals
from proveit.number import Add, Div, Exp, Interval, Neg, Sum, infinity, one, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Sum([x], Exp(m, x), domain = Interval(zero, infinity), conditions = []), Div(one, Add(one, Neg(m))))
# Out:
# expr: (Sum_{x=0}^{infinity} m^{x}) = (1 / (1 - m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Sum_{x=0}^{infinity} m^{x}) = (1 / (1 - m))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{x=0}^{infinity} m^{x} , 1 / (1 - m))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{x=0}^{infinity} m^{x}
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. 1 / (1 - m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. x -> m^{x} | x in {0...infinity}
#    core type: Lambda
#    parameter: 21
#    body: 9
#    conditions: 10\n7. /
#    core type: Literal
#    sub-expressions:
# 8. (1 , 1 - m)
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 9. m^{x}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (x in {0...infinity})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. 1 - m
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (m , x)
#     core type: ExprTuple
#     sub-expressions: 24, 21
# 14. x in {0...infinity}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (1 , -m)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x , {0...infinity})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. -m
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. {0...infinity}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. -
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (0 , infinity)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 0
#     core type: Literal
#     sub-expressions:
# 28. infinity
#     core type: Literal
#     sub-expressions:
