# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Pxy, Ry, S, y
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
expr = Forall([y], Pxy, domain = S, conditions = [Ry])
# Out:
# expr: forall_{y in S | R(y)} P(x , y)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in S | R(y)} P(x , y)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> P(x , y) | y in S , R(y)
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. P(x , y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (y in S , R(y))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. (x , y)
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 7. y in S
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. R(y)
#    core type: Operation
#    operator: 12
#    operand: 13
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y , S)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. R
#     core type: Variable
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
# 14. S
#     core type: Variable
#     sub-expressions:
