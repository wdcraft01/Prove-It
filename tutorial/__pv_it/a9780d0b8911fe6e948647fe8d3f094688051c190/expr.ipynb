# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(Add(x, a), Add(y, a)), conditions = [Equals(x, y)]))
# Out:
# expr: x -> [forall_{y | x = y} ((x + a) = (y + a))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y | x = y} ((x + a) = (y + a))]
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. forall_{y | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. y -> ((x + a) = (y + a)) | x = y
#    core type: Lambda
#    parameter: 16
#    body: 4
#    conditions: 5\n4. (x + a) = (y + a)
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (x = y)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. x = y
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x + a
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. y + a
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x , y)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (x , a)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (y , a)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
