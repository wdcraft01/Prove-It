# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Forall([a, x, y], Equals(Add(x, a), Add(y, a)), conditions = [Equals(x, y)])
# Out:
# expr: forall_{a, x, y | x = y} ((x + a) = (y + a))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, x, y | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. a -> [forall_{x, y | x = y} ((x + a) = (y + a))]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{x, y | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. x -> [forall_{y | x = y} ((x + a) = (y + a))]
#    core type: Lambda
#    parameter: 18
#    body: 4
# 4. forall_{y | x = y} ((x + a) = (y + a))
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. y -> ((x + a) = (y + a)) | x = y
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n7. (x + a) = (y + a)
#    core type: Operation
#    operator: 13
#    operands: 9
# 8. (x = y)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. x = y
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. x + a
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. y + a
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (x , y)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. (x , a)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (y , a)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
