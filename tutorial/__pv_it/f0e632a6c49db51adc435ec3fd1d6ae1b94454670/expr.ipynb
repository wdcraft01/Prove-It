# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Px, Qx, x
from proveit.logic import And, Forall, Set

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [x]
expr = Set(Forall(subExpr2, And(Px, Forall(subExpr2, Qx, conditions = subExpr1)), conditions = subExpr1))
# Out:
# expr: {forall_{x} (P(x) and [forall_{x} Q(x)])}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x} (P(x) and [forall_{x} Q(x)])}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x} (P(x) and [forall_{x} Q(x)]))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. forall_{x} (P(x) and [forall_{x} Q(x)])
#    core type: Operation
#    operator: 11
#    operand: 4
# 4. x -> (P(x) and [forall_{x} Q(x)])
#    core type: Lambda
#    parameter: 15
#    body: 5
# 5. P(x) and [forall_{x} Q(x)]
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(x) , forall_{x} Q(x))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. P(x)
#    core type: Operation
#    operator: 10
#    operand: 15
# 9. forall_{x} Q(x)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. x -> Q(x)
#     core type: Lambda
#     parameter: 15
#     body: 13
# 13. Q(x)
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
