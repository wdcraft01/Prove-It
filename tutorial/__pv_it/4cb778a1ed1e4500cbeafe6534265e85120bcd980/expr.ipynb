# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import Pxyz, x, y, z
from proveit.logic import Forall
from proveit.number import Add, Less

# %%
# build up the expression from sub-expressions
subExpr1 = Less(z, Add(x, y))
expr = ExprTuple(Forall([x, y, z], Pxyz, conditions = [subExpr1]), subExpr1)
# Out:
# expr: (forall_{x, y, z | z < (x + y)} P(x , y , z) , z < (x + y))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{x, y, z | z < (x + y)} P(x , y , z) , z < (x + y))
#    core type: ExprTuple
#    sub-expressions: 1, 12
# 1. forall_{x, y, z | z < (x + y)} P(x , y , z)
#    core type: Operation
#    operator: 6
#    operand: 2
# 2. x -> [forall_{y, z | z < (x + y)} P(x , y , z)]
#    core type: Lambda
#    parameter: 19
#    body: 3
# 3. forall_{y, z | z < (x + y)} P(x , y , z)
#    core type: Operation
#    operator: 6
#    operand: 4
# 4. y -> [forall_{z | z < (x + y)} P(x , y , z)]
#    core type: Lambda
#    parameter: 20
#    body: 5
# 5. forall_{z | z < (x + y)} P(x , y , z)
#    core type: Operation
#    operator: 6
#    operand: 7
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. z -> P(x , y , z) | z < (x + y)
#    core type: Lambda
#    parameter: 15
#    body: 8
#    conditions: 9\n8. P(x , y , z)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (z < (x + y))
#    core type: ExprTuple
#    sub-expressions: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. (x , y , z)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 15
# 12. z < (x + y)
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. <
#     core type: Literal
#     sub-expressions:
# 14. (z , x + y)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. z
#     core type: Variable
#     sub-expressions:
# 16. x + y
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (x , y)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. y
#     core type: Variable
#     sub-expressions:
