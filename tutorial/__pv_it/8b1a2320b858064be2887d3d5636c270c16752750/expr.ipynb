# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import Px, Q, Qx, fy, x
from proveit.logic import Forall, Set

# %%
# build up the expression from sub-expressions
expr = Set(Forall([x], Px, conditions = [Qx]), Function(Q, fy))
# Out:
# expr: {forall_{x | Q(x)} P(x) , Q(f(y))}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x | Q(x)} P(x) , Q(f(y))}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x | Q(x)} P(x) , Q(f(y)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x | Q(x)} P(x)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. Q(f(y))
#    core type: Operation
#    operator: 14
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> P(x) | Q(x)
#    core type: Lambda
#    parameter: 15
#    body: 8
#    conditions: 9\n7. f(y)
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. P(x)
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. (Q(x))
#    core type: ExprTuple
#    sub-expressions: 13
# 10. f
#     core type: Variable
#     sub-expressions:
# 11. y
#     core type: Variable
#     sub-expressions:
# 12. P
#     core type: Variable
#     sub-expressions:
# 13. Q(x)
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
