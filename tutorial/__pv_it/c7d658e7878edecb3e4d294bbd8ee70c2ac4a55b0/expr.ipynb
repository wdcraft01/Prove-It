# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import Q, a, x, y
from proveit.logic import Equals, Forall
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Forall([a], Equals(Add(x, a), Add(y, a)), conditions = [Function(Q, a)])
# Out:
# expr: forall_{a | Q(a)} ((x + a) = (y + a))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a | Q(a)} ((x + a) = (y + a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> ((x + a) = (y + a)) | Q(a)
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. (x + a) = (y + a)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (Q(a))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x + a , y + a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Q(a)
#    core type: Operation
#    operator: 10
#    operand: 16
# 8. x + a
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. y + a
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Q
#     core type: Variable
#     sub-expressions:
# 11. (x , a)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (y , a)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
