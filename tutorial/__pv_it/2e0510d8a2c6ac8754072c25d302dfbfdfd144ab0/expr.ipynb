# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import Px, Qx, Rx, S, x
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
expr = Forall([x], Px, domain = S, conditions = [Qx, Rx])
# Out:
# expr: forall_{x in S | Q(x) , R(x)} P(x)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x in S | Q(x) , R(x)} P(x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> P(x) | x in S , Q(x) , R(x)
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. P(x)
#    core type: Operation
#    operator: 5
#    operand: 13
# 4. (x in S , Q(x) , R(x))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. x in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. Q(x)
#    core type: Operation
#    operator: 11
#    operand: 13
# 8. R(x)
#    core type: Operation
#    operator: 12
#    operand: 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , S)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. R
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. S
#     core type: Variable
#     sub-expressions:
