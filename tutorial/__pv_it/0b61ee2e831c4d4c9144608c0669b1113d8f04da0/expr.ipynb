# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, b, x, z
from proveit.logic import Forall
from proveit.number import Add, Less

# %%
# build up the expression from sub-expressions
expr = Forall([z], Function(P, [x, b, z]), conditions = [Less(z, Add(x, b))])
# Out:
# expr: forall_{z | z < (x + b)} P(x , b , z)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{z | z < (x + b)} P(x , b , z)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. z -> P(x , b , z) | z < (x + b)
#    core type: Lambda
#    parameter: 10
#    body: 3
#    conditions: 4\n3. P(x , b , z)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (z < (x + b))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. (x , b , z)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 10
# 7. z < (x + b)
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. <
#    core type: Literal
#    sub-expressions:
# 9. (z , x + b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. z
#     core type: Variable
#     sub-expressions:
# 11. x + b
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (x , b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
