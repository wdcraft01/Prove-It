# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, n
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes, Div, Exp, Interval, Neg, Sum, infinity, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Equals(Sum([n], Exp(a, n), domain = Interval(zero, infinity), conditions = []), Div(one, Add(one, Neg(a)))), conditions = [InSet(a, Complexes)])
# Out:
# expr: a -> ((Sum_{n=0}^{infinity} a^{n}) = (1 / (1 - a))) | a in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> ((Sum_{n=0}^{infinity} a^{n}) = (1 / (1 - a))) | a in Complexes
#    core type: Lambda
#    parameter: 29
#    body: 1
#    conditions: 2\n1. (Sum_{n=0}^{infinity} a^{n}) = (1 / (1 - a))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{n=0}^{infinity} a^{n} , 1 / (1 - a))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. a in Complexes
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. Sum_{n=0}^{infinity} a^{n}
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. 1 / (1 - a)
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 29, 13
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. n -> a^{n} | n in {0...infinity}
#     core type: Lambda
#     parameter: 26
#     body: 14
#     conditions: 15\n11. /
# ...
