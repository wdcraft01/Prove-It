# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">tutorial</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function
from proveit._common_ import Px, Q, Qx, R, Rx, S, fy, x
from proveit.logic import Forall, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x], Px, domain = S, conditions = [Qx, Rx]), InSet(fy, S), Function(Q, fy), Function(R, fy))
# Out:
# expr: (forall_{x in S | Q(x) , R(x)} P(x) , f(y) in S , Q(f(y)) , R(f(y)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{x in S | Q(x) , R(x)} P(x) , f(y) in S , Q(f(y)) , R(f(y)))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. forall_{x in S | Q(x) , R(x)} P(x)
#    core type: Operation
#    operator: 5
#    operand: 6
# 2. f(y) in S
#    core type: Operation
#    operator: 17
#    operands: 7
# 3. Q(f(y))
#    core type: Operation
#    operator: 19
#    operand: 10
# 4. R(f(y))
#    core type: Operation
#    operator: 20
#    operand: 10
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> P(x) | x in S , Q(x) , R(x)
#    core type: Lambda
#    parameter: 21
#    body: 8
#    conditions: 9\n7. (f(y) , S)
#    core type: ExprTuple
#    sub-expressions: 10, 22
# 8. P(x)
#    core type: Operation
#    operator: 11
#    operand: 21
# 9. (x in S , Q(x) , R(x))
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. f(y)
#     core type: Operation
#     operator: 15
#     operand: 16
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. x in S
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. Q(x)
#     core type: Operation
#     operator: 19
#     operand: 21
# 14. R(x)
#     core type: Operation
#     operator: 20
#     operand: 21
# 15. f
#     core type: Variable
#     sub-expressions:
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x , S)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. Q
#     core type: Variable
#     sub-expressions:
# 20. R
#     core type: Variable
#     sub-expressions:
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. S
#     core type: Variable
#     sub-expressions:
