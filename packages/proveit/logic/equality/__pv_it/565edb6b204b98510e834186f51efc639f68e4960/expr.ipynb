# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#substituteInFalse">substituteInFalse</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.equality._theorems_ import substituteInFalse

# %%
# check that the built expression is the same as the stored expression
# %check_expr substituteInFalse
# Out:
# Passed sanity check: built 'substituteInFalse' is the same as the stored Expression.

# %%
# display the expression information
substituteInFalse.exprInfo()
# Out:
# 0. forall_{P, x | P(x) , [not](x)} P(FALSE)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. P -> [forall_{x | P(x) , [not](x)} P(FALSE)]
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. forall_{x | P(x) , [not](x)} P(FALSE)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> P(FALSE) | P(x) , [not](x)
#    core type: Lambda
#    parameter: 12
#    body: 5
#    conditions: 6\n5. P(FALSE)
#    core type: Operation
#    operator: 10
#    operand: 7
# 6. (P(x) , [not](x))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. FALSE
#    core type: Literal
#    sub-expressions:
# 8. P(x)
#    core type: Operation
#    operator: 10
#    operand: 12
# 9. [not](x)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. x
#     core type: Variable
# ...
