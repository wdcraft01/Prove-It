# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Booleans, Implies, InSet, Not, NotEquals, Set

# %%
# build up the expression from sub-expressions
expr = Set(Implies(Not(b), NotEquals(a, a)), InSet(b, Booleans))
# Out:
# expr: {[not](b) => (a != a) , b in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not](b) => (a != a) , b in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ([not](b) => (a != a) , b in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [not](b) => (a != a)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. b in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. ([not](b) , a != a)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. [not](b)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. a != a
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. !=
#     core type: Literal
#     sub-expressions:
# 15. (a , a)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 16. a
#     core type: Variable
#     sub-expressions:
