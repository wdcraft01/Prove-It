# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import f, g, l
from proveit.logic import Equals, Forall, Implies
from proveit.logic._common_ import f_xIter1l, f_yIter1l, g_xIter1l, g_zIter1l, iterQ1k, iterQ1k_xIter1l, iterQ1k_yIter1l, iterQ1k_zIter1l, xIter1l, yIter1l, zIter1l
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([l], Forall([f, g, iterQ1k], Implies(Forall([xIter1l], Equals(f_xIter1l, g_xIter1l), conditions = [iterQ1k_xIter1l]), Equals(Lambda(yIter1l, f_yIter1l, conditions = [iterQ1k_yIter1l]), Lambda(zIter1l, g_zIter1l, conditions = [iterQ1k_zIter1l])).withWrappingAt(2)).withWrappingAt(2), conditions = subExpr1), domain = NaturalsPos, conditions = subExpr1)
# Out:
# expr: forall_{l in NaturalsPos} [forall_{f, g, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} (f(x_1,...,x_l) = g(x_1,...,x_l))] =>  \\ ([(y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)] =  \\ [(z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)]))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{l in NaturalsPos} [forall_{f, g, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} (f(x_1,...,x_l) = g(x_1,...,x_l))] =>  \\ ([(y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)] =  \\ [(z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)]))]
#    core type: Operation
#    operator: 22
#    operand: 1
# 1. l -> [forall_{f, g, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} (f(x_1,...,x_l) = g(x_1,...,x_l))] =>  \\ ([(y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)] =  \\ [(z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)]))] | l in NaturalsPos
#    core type: Lambda
#    parameter: 79
#    body: 2
# ...
