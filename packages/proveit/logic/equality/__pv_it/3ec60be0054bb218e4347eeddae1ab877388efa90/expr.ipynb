# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#subLeftSideInto">subLeftSideInto</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.equality._theorems_ import subLeftSideInto

# %%
# check that the built expression is the same as the stored expression
# %check_expr subLeftSideInto
# Out:
# Passed sanity check: built 'subLeftSideInto' is the same as the stored Expression.

# %%
# display the expression information
subLeftSideInto.exprInfo()
# Out:
# 0. forall_{P, x, y | P(y) , x = y} P(x)
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. P -> [forall_{x, y | P(y) , x = y} P(x)]
#    core type: Lambda
#    parameter: 11
#    body: 2
# 2. forall_{x, y | P(y) , x = y} P(x)
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. x -> [forall_{y | P(y) , x = y} P(x)]
#    core type: Lambda
#    parameter: 14
#    body: 4
# 4. forall_{y | P(y) , x = y} P(x)
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. y -> P(x) | P(y) , x = y
#    core type: Lambda
#    parameter: 15
#    body: 7
#    conditions: 8\n7. P(x)
#    core type: Operation
#    operator: 11
#    operand: 14
# 8. (P(y) , x = y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. P(y)
#    core type: Operation
#    operator: 11
#    operand: 15
# 10. x = y
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x , y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
