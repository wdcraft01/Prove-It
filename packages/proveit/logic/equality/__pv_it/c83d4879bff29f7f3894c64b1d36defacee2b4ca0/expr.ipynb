# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic._common_ import f_xIter1l, g_xIter1l

# %%
# build up the expression from sub-expressions
expr = ExprTuple(f_xIter1l, g_xIter1l)
# Out:
# expr: (f(x_1,...,x_l) , g(x_1,...,x_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f(x_1,...,x_l) , g(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. f(x_1,...,x_l)
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. g(x_1,...,x_l)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. f
#    core type: Variable
#    sub-expressions:
# 4. g
#    core type: Variable
#    sub-expressions:
# 5. x_1,...,x_l
#    core type: Iter
#    lambda_map: 6
#    start_index: 17
#    end_index: 18
# 6. _x_ -> x__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 13
#    body: 7
#    conditions: 8\n7. x__x_
#    core type: Indexed
#    var: 9
#    index: 13
#    base: "1"
# 8. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. _x_ in {1...l}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. _x_
#     core type: Variable
#     sub-expressions:
# 14. {1...l}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. l
#     core type: Variable
#     sub-expressions:
