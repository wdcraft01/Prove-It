# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.NamedExprs.html">NamedExprs</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda, NamedExprs, Variable
from proveit._common_ import a, b, c, d
from proveit.logic import Equals
from proveit.number import Add, Exp, frac

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = NamedExprs([("lambda",Lambda(subExpr1, Equals(a, Add(b, frac(c, subExpr1), Exp(c, d))))), ("_x_",d)])
# Out:
# expr: {lambda:[_x_ -> (a = (b + (c / _x_) + c^{d}))], _x_:d}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {lambda:[_x_ -> (a = (b + (c / _x_) + c^{d}))], _x_:d}
#    core type: NamedExprs
#    lambda: 1
#    _x_: 18
# 1. _x_ -> (a = (b + (c / _x_) + c^{d}))
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. a = (b + (c / _x_) + c^{d})
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a , b + (c / _x_) + c^{d})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. a
#    core type: Variable
#    sub-expressions:
# 6. b + (c / _x_) + c^{d}
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (b , c / _x_ , c^{d})
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. c / _x_
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. c^{d}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (c , _x_)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (c , d)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. _x_
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. d
#     core type: Variable
#     sub-expressions:
