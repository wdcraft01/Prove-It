# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, fab, fxy, x, y
from proveit.logic import And, Equals, Implies

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Implies(And(Equals(x, a), Equals(y, b)), Equals(fxy, fab)))
# Out:
# expr: b -> (((x = a) and (y = b)) => (f(x , y) = f(a , b)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> (((x = a) and (y = b)) => (f(x , y) = f(a , b)))
#    core type: Lambda
#    parameter: 22
#    body: 1
# 1. ((x = a) and (y = b)) => (f(x , y) = f(a , b))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. ((x = a) and (y = b) , f(x , y) = f(a , b))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (x = a) and (y = b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. f(x , y) = f(a , b)
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x = a , y = b)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (f(x , y) , f(a , b))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. x = a
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. y = b
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. f(x , y)
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. f(a , b)
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (x , a)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (y , b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 16. (x , y)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. f
#     core type: Variable
#     sub-expressions:
# 18. (a , b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. y
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
