# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, c, fa, fx, x
from proveit.logic import Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([x, a, c], Implies(Equals(x, a), Implies(Equals(fa, c), Equals(fx, c))), conditions = [])
# Out:
# expr: forall_{x, a, c} ((x = a) => ((f(a) = c) => (f(x) = c)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, a, c} ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> [forall_{a, c} ((x = a) => ((f(a) = c) => (f(x) = c)))]
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. forall_{a, c} ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. a -> [forall_{c} ((x = a) => ((f(a) = c) => (f(x) = c)))]
#    core type: Lambda
#    parameter: 22
#    body: 4
# 4. forall_{c} ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. c -> ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Lambda
#    parameter: 21
#    body: 7
# 7. (x = a) => ((f(a) = c) => (f(x) = c))
#    core type: Operation
#    operator: 12
#    operands: 8
# 8. (x = a , (f(a) = c) => (f(x) = c))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x = a
#    core type: Operation
#    operator: 17
#    operands: 11
# 10. (f(a) = c) => (f(x) = c)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x , a)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (f(a) = c , f(x) = c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. f(a) = c
#     core type: Operation
#     operator: 17
#     operands: 16
# 15. f(x) = c
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (f(a) , c)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (f(x) , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. f(a)
#     core type: Operation
#     operator: 23
#     operand: 22
# 20. f(x)
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. f
#     core type: Variable
#     sub-expressions:
# 24. x
#     core type: Variable
#     sub-expressions:
