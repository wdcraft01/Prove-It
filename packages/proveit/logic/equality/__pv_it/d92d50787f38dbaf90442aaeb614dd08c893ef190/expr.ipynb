# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import fx, fy, x, y
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([x, y], Equals(fx, fy), conditions = [Equals(x, y)])
# Out:
# expr: forall_{x, y | x = y} (f(x) = f(y))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, y | x = y} (f(x) = f(y))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{y | x = y} (f(x) = f(y))]
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. forall_{y | x = y} (f(x) = f(y))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> (f(x) = f(y)) | x = y
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. f(x) = f(y)
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. (x = y)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (f(x) , f(y))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. x = y
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. f(x)
#    core type: Operation
#    operator: 13
#    operand: 14
# 10. f(y)
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. f
#     core type: Variable
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
