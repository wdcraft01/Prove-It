# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.logic._common_ import f_yIter1l, iterQ1k_yIter1l, yIter1l

# %%
# build up the expression from sub-expressions
expr = Lambda(yIter1l, f_yIter1l, conditions = [iterQ1k_yIter1l])
# Out:
# expr: (y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 9
#    body: 1
#    conditions: 2\n1. f(y_1,...,y_l)
#    core type: Operation
#    operator: 3
#    operand: 9
# 2. (Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. f
#    core type: Variable
#    sub-expressions:
# 4. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#    core type: Iter
#    lambda_map: 5
#    start_index: 28
#    end_index: 23
# 5. i -> Q_i(y_1,...,y_l) | i in {1...k}
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n6. Q_i(y_1,...,y_l)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Q_i
#    core type: Indexed
#    var: 11
#    index: 16
#    base: "1"
# 9. y_1,...,y_l
#    core type: Iter
#    lambda_map: 12
#    start_index: 28
#    end_index: 29
# 10. i in {1...k}
#     core type: Operation
#     operator: 21
#     operands: 13
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 24
#     body: 14
#     conditions: 15\n13. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. y__x_
#     core type: Indexed
#     var: 18
#     index: 24
#     base: "1"
# 15. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. {1...k}
#     core type: Operation
#     operator: 26
#     operands: 20
# 18. y
#     core type: Variable
#     sub-expressions:
# 19. _x_ in {1...l}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 28, 23
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. k
#     core type: Variable
#     sub-expressions:
# 24. _x_
#     core type: Variable
#     sub-expressions:
# 25. {1...l}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. l
#     core type: Variable
#     sub-expressions:
