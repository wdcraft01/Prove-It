# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda
from proveit.logic._common_ import f_yIter1l, g_zIter1l, iterQ1k_yIter1l, iterQ1k_zIter1l, yIter1l, zIter1l

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(yIter1l, f_yIter1l, conditions = [iterQ1k_yIter1l]), Lambda(zIter1l, g_zIter1l, conditions = [iterQ1k_zIter1l]))
# Out:
# expr: ((y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l) , (z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l) , (z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n2. (z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)
#    core type: Lambda
#    parameter: 18
#    body: 5
#    conditions: 6\n3. f(y_1,...,y_l)
#    core type: Operation
#    operator: 7
#    operand: 16
# 4. (Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 8
# 5. g(z_1,...,z_l)
#    core type: Operation
#    operator: 9
#    operand: 18
# 6. (Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l))
#    core type: ExprTuple
#    sub-expressions: 10
# 7. f
#    core type: Variable
#    sub-expressions:
# 8. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
# ...
