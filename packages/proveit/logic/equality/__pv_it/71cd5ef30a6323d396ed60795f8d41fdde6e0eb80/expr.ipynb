# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda, Variable
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Div, Exp

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Lambda(subExpr1, Equals(a, Add(b, Div(c, subExpr1), Exp(c, subExpr1))))
# Out:
# expr: _x_ -> (a = (b + (c / _x_) + c^{_x_}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. _x_ -> (a = (b + (c / _x_) + c^{_x_}))
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. a = (b + (c / _x_) + c^{_x_})
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (a , b + (c / _x_) + c^{_x_})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. a
#    core type: Variable
#    sub-expressions:
# 5. b + (c / _x_) + c^{_x_}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (b , c / _x_ , c^{_x_})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c / _x_
#    core type: Operation
#    operator: 11
#    operands: 13
# 10. c^{_x_}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (c , _x_)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. _x_
#     core type: Variable
#     sub-expressions:
