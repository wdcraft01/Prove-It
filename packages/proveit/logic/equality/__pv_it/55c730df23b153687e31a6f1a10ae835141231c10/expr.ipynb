# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c, d, y
from proveit.logic import Equals
from proveit.number import Add, Div, Exp

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Equals(y, d), Equals(a, Add(b, Div(c, d), Exp(c, d))))
# Out:
# expr: (y = d , a = (b + (c / d) + c^{d}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (y = d , a = (b + (c / d) + c^{d}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. y = d
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a = (b + (c / d) + c^{d})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (y , d)
#    core type: ExprTuple
#    sub-expressions: 6, 18
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a , b + (c / d) + c^{d})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. y
#    core type: Variable
#    sub-expressions:
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b + (c / d) + c^{d}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (b , c / d , c^{d})
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. c / d
#     core type: Operation
#     operator: 14
#     operands: 16
# 13. c^{d}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (c , d)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. d
#     core type: Variable
#     sub-expressions:
