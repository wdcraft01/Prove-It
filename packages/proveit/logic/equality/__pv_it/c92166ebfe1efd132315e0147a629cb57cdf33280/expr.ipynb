# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.logic import Equals
from proveit.logic._common_ import f_xIter1l, g_xIter1l, iterQ1k_xIter1l, xIter1l

# %%
# build up the expression from sub-expressions
expr = Lambda(xIter1l, Equals(f_xIter1l, g_xIter1l), conditions = [iterQ1k_xIter1l])
# Out:
# expr: (x_1,...,x_l) -> (f(x_1,...,x_l) = g(x_1,...,x_l)) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1,...,x_l) -> (f(x_1,...,x_l) = g(x_1,...,x_l)) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. f(x_1,...,x_l) = g(x_1,...,x_l)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (f(x_1,...,x_l) , g(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 8
#    start_index: 33
#    end_index: 28
# 6. f(x_1,...,x_l)
#    core type: Operation
#    operator: 9
#    operand: 14
# 7. g(x_1,...,x_l)
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. i -> Q_i(x_1,...,x_l) | i in {1...k}
#    core type: Lambda
#    parameter: 21
#    body: 11
#    conditions: 12\n9. f
#    core type: Variable
#    sub-expressions:
# 10. g
#     core type: Variable
#     sub-expressions:
# 11. Q_i(x_1,...,x_l)
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. Q_i
#     core type: Indexed
#     var: 16
#     index: 21
#     base: "1"
# 14. x_1,...,x_l
#     core type: Iter
#     lambda_map: 17
#     start_index: 33
#     end_index: 34
# 15. i in {1...k}
#     core type: Operation
#     operator: 26
#     operands: 18
# 16. Q
#     core type: Variable
#     sub-expressions:
# 17. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 29
#     body: 19
#     conditions: 20\n18. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. x__x_
#     core type: Indexed
#     var: 23
#     index: 29
#     base: "1"
# 20. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. {1...k}
#     core type: Operation
#     operator: 31
#     operands: 25
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...l}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 33, 28
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. k
#     core type: Variable
#     sub-expressions:
# 29. _x_
#     core type: Variable
#     sub-expressions:
# 30. {1...l}
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. Interval
#     core type: Literal
#     sub-expressions:
# 32. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. l
#     core type: Variable
#     sub-expressions:
