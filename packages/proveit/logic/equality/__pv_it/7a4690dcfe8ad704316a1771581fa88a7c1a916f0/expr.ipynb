# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, fab, fxy, x, y
from proveit.logic import And, Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([b, c], Implies(And(Equals(x, a), Equals(y, b)), Implies(Equals(fab, c), Equals(fxy, c))), conditions = [])
# Out:
# expr: forall_{b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. b -> [forall_{c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))]
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. forall_{c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Lambda
#    parameter: 24
#    body: 5
# 5. ((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c))
#    core type: Operation
#    operator: 11
#    operands: 6
# 6. ((x = a) and (y = b) , (f(a , b) = c) => (f(x , y) = c))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. (x = a) and (y = b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (f(a , b) = c) => (f(x , y) = c)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (x = a , y = b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (f(a , b) = c , f(x , y) = c)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. x = a
#     core type: Operation
#     operator: 20
#     operands: 17
# 14. y = b
#     core type: Operation
#     operator: 20
#     operands: 18
# 15. f(a , b) = c
#     core type: Operation
#     operator: 20
#     operands: 19
# 16. f(x , y) = c
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (x , a)
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 18. (y , b)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 19. (f(a , b) , c)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (f(x , y) , c)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. f(a , b)
#     core type: Operation
#     operator: 26
#     operands: 25
# 23. f(x , y)
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. (a , b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. f
#     core type: Variable
#     sub-expressions:
# 27. (x , y)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. y
#     core type: Variable
#     sub-expressions:
