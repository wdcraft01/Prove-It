# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#mappingSubstitution">mappingSubstitution</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.equality._axioms_ import mappingSubstitution

# %%
# check that the built expression is the same as the stored expression
# %check_expr mappingSubstitution
# Out:
# Passed sanity check: built 'mappingSubstitution' is the same as the stored Expression.

# %%
# display the expression information
mappingSubstitution.exprInfo()
# Out:
# 0. forall_{(k, l) in Naturals * NaturalsPos} [forall_{f, g, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} (f(x_1,...,x_l) = g(x_1,...,x_l))] =>  \\ ([(y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)] =  \\ [(z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)]))]
#    core type: Operation
#    operator: 28
#    operand: 1
# 1. k -> [forall_{l in NaturalsPos} [forall_{f, g, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} (f(x_1,...,x_l) = g(x_1,...,x_l))] =>  \\ ([(y_1,...,y_l) -> f(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)] =  \\ [(z_1,...,z_l) -> g(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)]))]] | k in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 2
# ...
