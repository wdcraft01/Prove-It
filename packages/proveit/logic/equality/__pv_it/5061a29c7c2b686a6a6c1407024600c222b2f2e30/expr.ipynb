# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, fab, fxy, x, y
from proveit.logic import And, Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([y, a, b], Implies(And(Equals(x, a), Equals(y, b)), Equals(fxy, fab)), conditions = [])
# Out:
# expr: forall_{y, a, b} (((x = a) and (y = b)) => (f(x , y) = f(a , b)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y, a, b} (((x = a) and (y = b)) => (f(x , y) = f(a , b)))
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. y -> [forall_{a, b} (((x = a) and (y = b)) => (f(x , y) = f(a , b)))]
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. forall_{a, b} (((x = a) and (y = b)) => (f(x , y) = f(a , b)))
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. a -> [forall_{b} (((x = a) and (y = b)) => (f(x , y) = f(a , b)))]
#    core type: Lambda
#    parameter: 27
#    body: 4
# 4. forall_{b} (((x = a) and (y = b)) => (f(x , y) = f(a , b)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. b -> (((x = a) and (y = b)) => (f(x , y) = f(a , b)))
#    core type: Lambda
#    parameter: 28
#    body: 7
# 7. ((x = a) and (y = b)) => (f(x , y) = f(a , b))
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. ((x = a) and (y = b) , f(x , y) = f(a , b))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. (x = a) and (y = b)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. f(x , y) = f(a , b)
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (x = a , y = b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. (f(x , y) , f(a , b))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. x = a
#     core type: Operation
#     operator: 20
#     operands: 19
# 16. y = b
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. f(x , y)
#     core type: Operation
#     operator: 23
#     operands: 22
# 18. f(a , b)
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (x , a)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (y , b)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 22. (x , y)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. f
#     core type: Variable
#     sub-expressions:
# 24. (a , b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. y
#     core type: Variable
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
