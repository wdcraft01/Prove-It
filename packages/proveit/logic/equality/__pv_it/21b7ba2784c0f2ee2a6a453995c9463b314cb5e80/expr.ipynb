# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, fab, fxy, x, y
from proveit.logic import And, Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([x, y, a, b, c], Implies(And(Equals(x, a), Equals(y, b)), Implies(Equals(fab, c), Equals(fxy, c))), conditions = [])
# Out:
# expr: forall_{x, y, a, b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, y, a, b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. x -> [forall_{y, a, b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))]
#    core type: Lambda
#    parameter: 36
#    body: 2
# 2. forall_{y, a, b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 9
#    operand: 3
# 3. y -> [forall_{a, b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))]
#    core type: Lambda
#    parameter: 37
#    body: 4
# 4. forall_{a, b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 9
#    operand: 5
# 5. a -> [forall_{b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))]
#    core type: Lambda
#    parameter: 34
#    body: 6
# 6. forall_{b, c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 9
#    operand: 7
# 7. b -> [forall_{c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))]
#    core type: Lambda
#    parameter: 35
#    body: 8
# 8. forall_{c} (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. c -> (((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c)))
#     core type: Lambda
#     parameter: 30
#     body: 11
# 11. ((x = a) and (y = b)) => ((f(a , b) = c) => (f(x , y) = c))
#     core type: Operation
#     operator: 17
#     operands: 12
# 12. ((x = a) and (y = b) , (f(a , b) = c) => (f(x , y) = c))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. (x = a) and (y = b)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (f(a , b) = c) => (f(x , y) = c)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (x = a , y = b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. =>
#     core type: Literal
#     sub-expressions:
# 18. (f(a , b) = c , f(x , y) = c)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. x = a
#     core type: Operation
#     operator: 26
#     operands: 23
# 20. y = b
#     core type: Operation
#     operator: 26
#     operands: 24
# 21. f(a , b) = c
#     core type: Operation
#     operator: 26
#     operands: 25
# 22. f(x , y) = c
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. (x , a)
#     core type: ExprTuple
#     sub-expressions: 36, 34
# 24. (y , b)
#     core type: ExprTuple
#     sub-expressions: 37, 35
# 25. (f(a , b) , c)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (f(x , y) , c)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. f(a , b)
#     core type: Operation
#     operator: 32
#     operands: 31
# 29. f(x , y)
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. c
#     core type: Variable
#     sub-expressions:
# 31. (a , b)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. f
#     core type: Variable
#     sub-expressions:
# 33. (x , y)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. a
#     core type: Variable
#     sub-expressions:
# 35. b
#     core type: Variable
#     sub-expressions:
# 36. x
#     core type: Variable
#     sub-expressions:
# 37. y
#     core type: Variable
#     sub-expressions:
