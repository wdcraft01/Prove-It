# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.equality</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, c, fa, fx, x
from proveit.logic import Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([a, c], Implies(Equals(x, a), Implies(Equals(fa, c), Equals(fx, c))), conditions = [])
# Out:
# expr: forall_{a, c} ((x = a) => ((f(a) = c) => (f(x) = c)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, c} ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. a -> [forall_{c} ((x = a) => ((f(a) = c) => (f(x) = c)))]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{c} ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> ((x = a) => ((f(a) = c) => (f(x) = c)))
#    core type: Lambda
#    parameter: 19
#    body: 5
# 5. (x = a) => ((f(a) = c) => (f(x) = c))
#    core type: Operation
#    operator: 10
#    operands: 6
# 6. (x = a , (f(a) = c) => (f(x) = c))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x = a
#    core type: Operation
#    operator: 15
#    operands: 9
# 8. (f(a) = c) => (f(x) = c)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (x , a)
#    core type: ExprTuple
#    sub-expressions: 22, 20
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (f(a) = c , f(x) = c)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. f(a) = c
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. f(x) = c
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (f(a) , c)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (f(x) , c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. f(a)
#     core type: Operation
#     operator: 21
#     operand: 20
# 18. f(x)
#     core type: Operation
#     operator: 21
#     operand: 22
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. f
#     core type: Variable
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
