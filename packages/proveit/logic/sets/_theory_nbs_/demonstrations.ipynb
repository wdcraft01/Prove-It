# %% [markdown]
# Demonstrations for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.logic.sets</a>
# ========

# %%
import proveit
# %begin demonstrations

# %% [markdown]
# #### Relating Simple Existential Claims to Minimal Cardinality Claims

# %%
from proveit import x, Q, X, S, Function
from proveit.logic import Exists, InSet
exists_x_in_S = Exists(x, InSet(x, S))
exists_x_in_S

# %%
exists_x_with_condition = Exists(x, Function(Q, x), domain=S)

# %%
exists_x_in_S.deduce_set_cardinality()

# %%
exists_x_with_condition.deduce_set_cardinality()

# %%
# %end demonstrations
