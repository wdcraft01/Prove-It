# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.logic.sets.disjointness</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
from proveit import A, B
from proveit.logic import Forall
from proveit.logic.sets import Difference, Disjoint, Intersect
# %begin theorems

# %%
set_diff_commuted_disjoint = Forall((A, B), Disjoint(Difference(A, B), Difference(B, A)))

# %%
diff_and_intersect_disjoint = Forall((A, B), Disjoint(Difference(A, B), Intersect(A, B)))

# %%
# %end theorems
