# %% [markdown]
# Axioms for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.logic.sets.symmetric_difference</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the axioms of a theory:
# %axioms_notebook # Keep this at the top following 'import proveit'.

from proveit import x, A, B, X
from proveit.logic import Equals, Forall, InSet, XOr
from proveit.logic.sets import SymmetricDifference

# %%
# %begin axioms

# %%
sym_diff_def = Forall((x, A, B), Equals(InSet(x, SymmetricDifference(A, B)), XOr(InSet(x, A), InSet(x, B))))

# %%
# %end axioms
