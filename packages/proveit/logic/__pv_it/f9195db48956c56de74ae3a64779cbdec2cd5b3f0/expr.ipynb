# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Variable
from proveit._common_ import QQ, j, l, xx
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Function(Indexed(QQ, j, base = 1), Iter(subExpr1, Indexed(xx, subExpr1, base = 1), one, l))
# Out:
# expr: Q_j(x_1,...,x_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. Q_j(x_1,...,x_l)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Q_j
#    core type: Indexed
#    var: 3
#    index: 4
#    base: "1"
# 2. x_1,...,x_l
#    core type: Iter
#    lambda_map: 5
#    start_index: 16
#    end_index: 17
# 3. Q
#    core type: Variable
#    sub-expressions:
# 4. j
#    core type: Variable
#    sub-expressions:
# 5. _x_ -> x__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 12
#    body: 6
#    conditions: 7\n6. x__x_
#    core type: Indexed
#    var: 8
#    index: 12
#    base: "1"
# 7. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. _x_ in {1...l}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. _x_
#     core type: Variable
#     sub-expressions:
# 13. {1...l}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. l
#     core type: Variable
#     sub-expressions:
