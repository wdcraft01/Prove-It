# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iterB1m">iterB1m</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import the special expression
from proveit.logic._common_ import iterB1m

# %%
# check that the built expression is the same as the stored expression
# %check_expr iterB1m
# Out:
# Passed sanity check: built 'iterB1m' is the same as the stored Expression.

# %%
# display the expression information
iterB1m.exprInfo()
# Out:
# 0. B_1,...,B_m
#    core type: Iter
#    lambda_map: 1
#    start_index: 12
#    end_index: 13
# 1. _x_ -> B__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 8
#    body: 2
#    conditions: 3\n2. B__x_
#    core type: Indexed
#    var: 4
#    index: 8
#    base: "1"
# 3. (_x_ in {1...m})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. B
#    core type: Variable
#    sub-expressions:
# 5. _x_ in {1...m}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (_x_ , {1...m})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. _x_
#    core type: Variable
#    sub-expressions:
# 9. {1...m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. m
#     core type: Variable
#     sub-expressions:
