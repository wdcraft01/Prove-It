# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Lambda
from proveit._common_ import QQ, i, k, x
from proveit.logic import InSet
from proveit.number import Interval, one

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Function(Indexed(QQ, i, base = 1), x), conditions = [InSet(i, Interval(one, k))])
# Out:
# expr: i -> Q_i(x) | i in {1...k}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> Q_i(x) | i in {1...k}
#    core type: Lambda
#    parameter: 9
#    body: 1
#    conditions: 2\n1. Q_i(x)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. Q_i
#    core type: Indexed
#    var: 6
#    index: 9
#    base: "1"
# 4. x
#    core type: Variable
#    sub-expressions:
# 5. i in {1...k}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. Q
#    core type: Variable
#    sub-expressions:
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i , {1...k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. {1...k}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. k
#     core type: Variable
# ...
