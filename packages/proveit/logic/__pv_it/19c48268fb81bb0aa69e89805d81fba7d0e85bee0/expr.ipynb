# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iterQ1k_xIter1l_y">iterQ1k_xIter1l_y</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import the special expression
from proveit.logic._common_ import iterQ1k_xIter1l_y

# %%
# check that the built expression is the same as the stored expression
# %check_expr iterQ1k_xIter1l_y
# Out:
# Passed sanity check: built 'iterQ1k_xIter1l_y' is the same as the stored Expression.

# %%
# display the expression information
iterQ1k_xIter1l_y.exprInfo()
# Out:
# 0. Q_1(x_1 ,  ...  , x_l , y),...,Q_k(x_1 ,  ...  , x_l , y)
#    core type: Iter
#    lambda_map: 1
#    start_index: 26
#    end_index: 19
# 1. i -> Q_i(x_1 ,  ...  , x_l , y) | i in {1...k}
#    core type: Lambda
#    parameter: 12
#    body: 2
#    conditions: 3\n2. Q_i(x_1 ,  ...  , x_l , y)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Q_i
#    core type: Indexed
#    var: 7
#    index: 12
#    base: "1"
# 5. (x_1 ,  ...  , x_l , y)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. i in {1...k}
#    core type: Operation
#    operator: 20
#    operands: 10
# 7. Q
#    core type: Variable
#    sub-expressions:
# 8. x_1,...,x_l
#    core type: Iter
#    lambda_map: 11
#    start_index: 26
#    end_index: 27
# 9. y
#    core type: Variable
#    sub-expressions:
# 10. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. _x_ -> x__x_ | _x_ in {1...l}
# ...
