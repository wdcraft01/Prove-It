# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iterQ1k_y">iterQ1k_y</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import the special expression
from proveit.logic._common_ import iterQ1k_y

# %%
# check that the built expression is the same as the stored expression
# %check_expr iterQ1k_y
# Out:
# Passed sanity check: built 'iterQ1k_y' is the same as the stored Expression.

# %%
# display the expression information
iterQ1k_y.exprInfo()
# Out:
# 0. Q_1(y),...,Q_k(y)
#    core type: Iter
#    lambda_map: 1
#    start_index: 14
#    end_index: 15
# 1. i -> Q_i(y) | i in {1...k}
#    core type: Lambda
#    parameter: 10
#    body: 2
#    conditions: 3\n2. Q_i(y)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Q_i
#    core type: Indexed
#    var: 7
#    index: 10
#    base: "1"
# 5. y
#    core type: Variable
#    sub-expressions:
# 6. i in {1...k}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. Q
#    core type: Variable
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i , {1...k})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. {1...k}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (1 , k)
#     core type: ExprTuple
# ...
