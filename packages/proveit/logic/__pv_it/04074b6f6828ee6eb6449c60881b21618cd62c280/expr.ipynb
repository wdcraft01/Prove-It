# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Lambda, Variable
from proveit._common_ import RR, i, l, m, n, xx, yy
from proveit.logic import InSet
from proveit.number import Interval, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Lambda(i, Function(Indexed(RR, i, base = 1), [Iter(subExpr1, Indexed(xx, subExpr1, base = 1), one, l), Iter(subExpr1, Indexed(yy, subExpr1, base = 1), one, n)]), conditions = [InSet(i, Interval(one, m))])
# Out:
# expr: i -> R_i(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) | i in {1...m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> R_i(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) | i in {1...m}
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. R_i(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. R_i
#    core type: Indexed
#    var: 6
#    index: 12
#    base: "1"
# 4. (x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. i in {1...m}
#    core type: Operation
#    operator: 25
#    operands: 9
# 6. R
#    core type: Variable
#    sub-expressions:
# 7. x_1,...,x_l
#    core type: Iter
#    lambda_map: 10
#    start_index: 34
#    end_index: 33
# 8. y_1,...,y_n
#    core type: Iter
#    lambda_map: 11
#    start_index: 34
#    end_index: 35
# 9. (i , {1...m})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 28
#     body: 14
# ...
