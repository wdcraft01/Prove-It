# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iterQ1k">iterQ1k</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import the special expression
from proveit.logic._common_ import iterQ1k

# %%
# check that the built expression is the same as the stored expression
# %check_expr iterQ1k
# Out:
# Passed sanity check: built 'iterQ1k' is the same as the stored Expression.

# %%
# display the expression information
iterQ1k.exprInfo()
# Out:
# 0. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 1
#    start_index: 12
#    end_index: 13
# 1. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 8
#    body: 2
#    conditions: 3\n2. Q__x_
#    core type: Indexed
#    var: 4
#    index: 8
#    base: "1"
# 3. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. Q
#    core type: Variable
#    sub-expressions:
# 5. _x_ in {1...k}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (_x_ , {1...k})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. _x_
#    core type: Variable
#    sub-expressions:
# 9. {1...k}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
