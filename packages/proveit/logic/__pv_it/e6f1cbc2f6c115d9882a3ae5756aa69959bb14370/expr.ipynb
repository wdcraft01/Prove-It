# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#g_zIter1l">g_zIter1l</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Function.html">Function</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import the special expression
from proveit.logic._common_ import g_zIter1l

# %%
# check that the built expression is the same as the stored expression
# %check_expr g_zIter1l
# Out:
# Passed sanity check: built 'g_zIter1l' is the same as the stored Expression.

# %%
# display the expression information
g_zIter1l.exprInfo()
# Out:
# 0. g(z_1,...,z_l)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. g
#    core type: Variable
#    sub-expressions:
# 2. z_1,...,z_l
#    core type: Iter
#    lambda_map: 3
#    start_index: 14
#    end_index: 15
# 3. _x_ -> z__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 10
#    body: 4
#    conditions: 5\n4. z__x_
#    core type: Indexed
#    var: 6
#    index: 10
#    base: "1"
# 5. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. z
#    core type: Variable
#    sub-expressions:
# 7. _x_ in {1...l}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (_x_ , {1...l})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. _x_
#     core type: Variable
#     sub-expressions:
# 11. {1...l}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (1 , l)
#     core type: ExprTuple
# ...
