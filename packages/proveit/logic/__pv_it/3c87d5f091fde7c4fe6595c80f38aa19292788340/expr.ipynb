# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iterQ1i_xIter1l">iterQ1i_xIter1l</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic</a>

# %%
# import the special expression
from proveit.logic._common_ import iterQ1i_xIter1l

# %%
# check that the built expression is the same as the stored expression
# %check_expr iterQ1i_xIter1l
# Out:
# Passed sanity check: built 'iterQ1i_xIter1l' is the same as the stored Expression.

# %%
# display the expression information
iterQ1i_xIter1l.exprInfo()
# Out:
# 0. Q_1(x_1,...,x_l),...,Q_i(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 1
#    start_index: 24
#    end_index: 19
# 1. j -> Q_j(x_1,...,x_l) | j in {1...i}
#    core type: Lambda
#    parameter: 12
#    body: 2
#    conditions: 3\n2. Q_j(x_1,...,x_l)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (j in {1...i})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Q_j
#    core type: Indexed
#    var: 7
#    index: 12
#    base: "1"
# 5. x_1,...,x_l
#    core type: Iter
#    lambda_map: 8
#    start_index: 24
#    end_index: 25
# 6. j in {1...i}
#    core type: Operation
#    operator: 17
#    operands: 9
# 7. Q
#    core type: Variable
#    sub-expressions:
# 8. _x_ -> x__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 20
#    body: 10
#    conditions: 11\n9. (j , {1...i})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. x__x_
#     core type: Indexed
#     var: 14
#     index: 20
#     base: "1"
# 11. (_x_ in {1...l})
# ...
