# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, FALSE, InSet, NotEquals, Set

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Equals(InSet(x, Set(y)), FALSE), conditions = [NotEquals(x, y)])
# Out:
# expr: y -> ((x in {y}) = FALSE) | x != y

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> ((x in {y}) = FALSE) | x != y
#    core type: Lambda
#    parameter: 16
#    body: 1
#    conditions: 2\n1. (x in {y}) = FALSE
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x != y)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x in {y} , FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. x != y
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. x in {y}
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. FALSE
#    core type: Literal
#    sub-expressions:
# 8. !=
#    core type: Literal
#    sub-expressions:
# 9. (x , y)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x , {y})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. {y}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. Set
#     core type: Literal
#     sub-expressions:
# 15. (y)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. y
#     core type: Variable
#     sub-expressions:
