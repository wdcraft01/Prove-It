# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import i, l, x, yy
from proveit.logic import And, Equals, NotEquals, NotInSet, Set
from proveit.logic._common_ import yIter1l
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Equals(NotInSet(x, Set(yIter1l)), And(Iter(i, NotEquals(x, Indexed(yy, i, base = 1)), one, l)))
# Out:
# expr: (x not-in {y_1 ,  ...  , y_l}) = ((x != y_1) and  ...  and (x != y_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x not-in {y_1 ,  ...  , y_l}) = ((x != y_1) and  ...  and (x != y_l))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (x not-in {y_1 ,  ...  , y_l} , (x != y_1) and  ...  and (x != y_l))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x not-in {y_1 ,  ...  , y_l}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x != y_1) and  ...  and (x != y_l)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. not-in
#    core type: Literal
#    sub-expressions:
# 6. (x , {y_1 ,  ...  , y_l})
#    core type: ExprTuple
#    sub-expressions: 23, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x != y_1 ,  ...  , x != y_l)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. {y_1 ,  ...  , y_l}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x != y_1),...,(x != y_l)
#     core type: Iter
#     lambda_map: 13
#     start_index: 35
#     end_index: 36
# ...
