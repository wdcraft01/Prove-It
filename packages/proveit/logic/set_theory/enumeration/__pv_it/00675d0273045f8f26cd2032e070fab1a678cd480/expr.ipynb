# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], InSet(x, Set(y)), conditions = [Equals(x, y)]))
# Out:
# expr: x -> [forall_{y | x = y} (x in {y})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y | x = y} (x in {y})]
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. forall_{y | x = y} (x in {y})
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. y -> (x in {y}) | x = y
#    core type: Lambda
#    parameter: 15
#    body: 4
#    conditions: 5\n4. x in {y}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x = y)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x , {y})
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 8. x = y
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. {y}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x , y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (y)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
