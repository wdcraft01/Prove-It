# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#unfoldSingleton">unfoldSingleton</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.enumeration._theorems_ import unfoldSingleton

# %%
# check that the built expression is the same as the stored expression
# %check_expr unfoldSingleton
# Out:
# Passed sanity check: built 'unfoldSingleton' is the same as the stored Expression.

# %%
# display the expression information
unfoldSingleton.exprInfo()
# Out:
# 0. forall_{x, y | x in {y}} (x = y)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{y | x in {y}} (x = y)]
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. forall_{y | x in {y}} (x = y)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> (x = y) | x in {y}
#    core type: Lambda
#    parameter: 16
#    body: 5
#    conditions: 6\n5. x = y
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in {y})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x , y)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 9. x in {y}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x , {y})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. {y}
# ...
