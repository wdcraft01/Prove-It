# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, FALSE, Forall, InSet, NotEquals, Set

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(InSet(x, Set(y)), FALSE), conditions = [NotEquals(x, y)]))
# Out:
# expr: x -> [forall_{y | x != y} ((x in {y}) = FALSE)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y | x != y} ((x in {y}) = FALSE)]
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. forall_{y | x != y} ((x in {y}) = FALSE)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. y -> ((x in {y}) = FALSE) | x != y
#    core type: Lambda
#    parameter: 19
#    body: 4
#    conditions: 5\n4. (x in {y}) = FALSE
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x != y)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x in {y} , FALSE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. x != y
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. x in {y}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. FALSE
#     core type: Literal
#     sub-expressions:
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 15, 19
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x , {y})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. {y}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Set
#     core type: Literal
#     sub-expressions:
# 18. (y)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. y
#     core type: Variable
#     sub-expressions:
