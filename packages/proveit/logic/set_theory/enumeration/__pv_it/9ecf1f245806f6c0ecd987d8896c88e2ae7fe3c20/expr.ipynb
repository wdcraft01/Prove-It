# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import i, l, x, yy
from proveit.logic import Equals, InSet, Or, Set
from proveit.logic._common_ import yIter1l
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(yIter1l, InSet(x, Set(yIter1l)), conditions = [Or(Iter(i, Equals(x, Indexed(yy, i, base = 1)), one, l))])
# Out:
# expr: (y_1,...,y_l) -> (x in {y_1 ,  ...  , y_l}) | (x = y_1) or  ...  or (x = y_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (y_1,...,y_l) -> (x in {y_1 ,  ...  , y_l}) | (x = y_1) or  ...  or (x = y_l)
#    core type: Lambda
#    parameter: 11
#    body: 1
#    conditions: 2\n1. x in {y_1 ,  ...  , y_l}
#    core type: Operation
#    operator: 25
#    operands: 3
# 2. ((x = y_1) or  ...  or (x = y_l))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (x , {y_1 ,  ...  , y_l})
#    core type: ExprTuple
#    sub-expressions: 22, 5
# 4. (x = y_1) or  ...  or (x = y_l)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. {y_1 ,  ...  , y_l}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (x = y_1 ,  ...  , x = y_l)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Set
#    core type: Literal
#    sub-expressions:
# 9. (y_1 ,  ...  , y_l)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (x = y_1),...,(x = y_l)
#     core type: Iter
#     lambda_map: 12
#     start_index: 33
#     end_index: 34
# ...
