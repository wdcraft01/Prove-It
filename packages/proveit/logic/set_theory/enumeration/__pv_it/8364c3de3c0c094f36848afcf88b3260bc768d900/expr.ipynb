# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import Equals, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(Equals(A, B), Equals(A, C), Equals(A, D)))
# Out:
# expr: {(A = B) or (A = C) or (A = D)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(A = B) or (A = C) or (A = D)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ((A = B) or (A = C) or (A = D))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A = B) or (A = C) or (A = D)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A = B , A = C , A = D)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. A = B
#    core type: Operation
#    operator: 11
#    operands: 9
# 7. A = C
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. A = D
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 10. (A , C)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (A , D)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. C
#     core type: Variable
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. D
#     core type: Variable
#     sub-expressions:
