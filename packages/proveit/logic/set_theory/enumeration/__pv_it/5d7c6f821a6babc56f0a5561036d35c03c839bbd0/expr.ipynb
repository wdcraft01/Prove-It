# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, NotEquals, NotInSet, Set

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(NotInSet(x, Set(y)), NotEquals(x, y)), conditions = []))
# Out:
# expr: x -> [forall_{y} ((x not-in {y}) = (x != y))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y} ((x not-in {y}) = (x != y))]
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. forall_{y} ((x not-in {y}) = (x != y))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. y -> ((x not-in {y}) = (x != y))
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. (x not-in {y}) = (x != y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x not-in {y} , x != y)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x not-in {y}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. x != y
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. not-in
#    core type: Literal
#    sub-expressions:
# 10. (x , {y})
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 14, 17
# 13. {y}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. Set
#     core type: Literal
#     sub-expressions:
# 16. (y)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. y
#     core type: Variable
#     sub-expressions:
