# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, Not, NotEquals

# %%
# build up the expression from sub-expressions
expr = Forall([x, y], Equals(NotEquals(x, y), Not(Equals(x, y))), conditions = [])
# Out:
# expr: forall_{x, y} ((x != y) = [not](x = y))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, y} ((x != y) = [not](x = y))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{y} ((x != y) = [not](x = y))]
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. forall_{y} ((x != y) = [not](x = y))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((x != y) = [not](x = y))
#    core type: Lambda
#    parameter: 15
#    body: 5
# 5. (x != y) = [not](x = y)
#    core type: Operation
#    operator: 12
#    operands: 6
# 6. (x != y , [not](x = y))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x != y
#    core type: Operation
#    operator: 9
#    operands: 13
# 8. [not](x = y)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. !=
#    core type: Literal
#    sub-expressions:
# 10. not
#     core type: Literal
#     sub-expressions:
# 11. x = y
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x , y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
