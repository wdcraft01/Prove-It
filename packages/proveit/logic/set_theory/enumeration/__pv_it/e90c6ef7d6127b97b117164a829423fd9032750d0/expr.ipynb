# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#inSingletonIsBool">inSingletonIsBool</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.enumeration._theorems_ import inSingletonIsBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr inSingletonIsBool
# Out:
# Passed sanity check: built 'inSingletonIsBool' is the same as the stored Expression.

# %%
# display the expression information
inSingletonIsBool.exprInfo()
# Out:
# 0. forall_{x, y} ((x in {y}) in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{y} ((x in {y}) in BOOLEANS)]
#    core type: Lambda
#    parameter: 11
#    body: 2
# 2. forall_{y} ((x in {y}) in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((x in {y}) in BOOLEANS)
#    core type: Lambda
#    parameter: 15
#    body: 5
# 5. (x in {y}) in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 6
# 6. (x in {y} , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x in {y}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , {y})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. {y}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (y)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. y
#     core type: Variable
#     sub-expressions:
