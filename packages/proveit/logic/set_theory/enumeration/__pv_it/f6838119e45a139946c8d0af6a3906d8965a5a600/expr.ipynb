# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, InSet, Set, TRUE

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Equals(InSet(x, Set(y)), TRUE), conditions = [Equals(x, y)])
# Out:
# expr: y -> ((x in {y}) = TRUE) | x = y

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> ((x in {y}) = TRUE) | x = y
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. (x in {y}) = TRUE
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (x = y)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (x in {y} , TRUE)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. x = y
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. x in {y}
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. TRUE
#    core type: Literal
#    sub-expressions:
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x , y)
#    core type: ExprTuple
#    sub-expressions: 11, 15
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , {y})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. {y}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (y)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. y
#     core type: Variable
#     sub-expressions:
