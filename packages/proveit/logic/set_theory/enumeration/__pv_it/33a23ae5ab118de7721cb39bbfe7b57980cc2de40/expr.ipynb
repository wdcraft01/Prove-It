# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#enumSetDef">enumSetDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.enumeration</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.enumeration._axioms_ import enumSetDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr enumSetDef
# Out:
# Passed sanity check: built 'enumSetDef' is the same as the stored Expression.

# %%
# display the expression information
enumSetDef.exprInfo()
# Out:
# 0. forall_{l in Naturals} [forall_{x, y_1,...,y_l} ((x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l)))]
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. l -> [forall_{x, y_1,...,y_l} ((x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l)))] | l in Naturals
#    core type: Lambda
#    parameter: 45
#    body: 2
#    conditions: 3\n2. forall_{x, y_1,...,y_l} ((x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l)))
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{y_1,...,y_l} ((x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l)))]
#    core type: Lambda
#    parameter: 32
#    body: 6
# 5. l in Naturals
#    core type: Operation
#    operator: 38
#    operands: 7
# 6. forall_{y_1,...,y_l} ((x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l)))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (l , Naturals)
#    core type: ExprTuple
#    sub-expressions: 45, 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (y_1,...,y_l) -> ((x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l)))
#    core type: Lambda
#    parameter: 23
#    body: 11
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. (x in {y_1 ,  ...  , y_l}) = ((x = y_1) or  ...  or (x = y_l))
#     core type: Operation
#     operator: 27
#     operands: 12
# 12. (x in {y_1 ,  ...  , y_l} , (x = y_1) or  ...  or (x = y_l))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. x in {y_1 ,  ...  , y_l}
#     core type: Operation
#     operator: 38
#     operands: 15
# 14. (x = y_1) or  ...  or (x = y_l)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (x , {y_1 ,  ...  , y_l})
#     core type: ExprTuple
#     sub-expressions: 32, 18
# 16. or
#     core type: Literal
#     sub-expressions:
# 17. (x = y_1 ,  ...  , x = y_l)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. {y_1 ,  ...  , y_l}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (x = y_1),...,(x = y_l)
#     core type: Iter
#     lambda_map: 22
#     start_index: 44
#     end_index: 45
# 20. Set
#     core type: Literal
#     sub-expressions:
# 21. (y_1 ,  ...  , y_l)
#     core type: ExprTuple
#     sub-expressions: 23
# 22. i -> (x = y_i) | i in {1...l}
#     core type: Lambda
#     parameter: 37
#     body: 24
#     conditions: 25\n23. y_1,...,y_l
#     core type: Iter
#     lambda_map: 26
#     start_index: 44
#     end_index: 45
# 24. x = y_i
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (i in {1...l})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 40
#     body: 30
#     conditions: 31\n27. =
#     core type: Literal
#     sub-expressions:
# 28. (x , y_i)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. i in {1...l}
#     core type: Operation
#     operator: 38
#     operands: 34
# 30. y__x_
#     core type: Indexed
#     var: 36
#     index: 40
#     base: "1"
# 31. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. y_i
#     core type: Indexed
#     var: 36
#     index: 37
#     base: "1"
# 34. (i , {1...l})
#     core type: ExprTuple
#     sub-expressions: 37, 41
# 35. _x_ in {1...l}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. y
#     core type: Variable
#     sub-expressions:
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. _x_
#     core type: Variable
#     sub-expressions:
# 41. {1...l}
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. Interval
#     core type: Literal
#     sub-expressions:
# 43. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. l
#     core type: Variable
#     sub-expressions:
