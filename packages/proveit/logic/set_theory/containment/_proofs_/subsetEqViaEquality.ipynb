# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_context_.ipynb">logic</a>.<a class="ProveItLink" href="../../_context_.ipynb">set_theory</a>.<a class="ProveItLink" href="../_context_.ipynb">containment</a>.<a href="../_theorems_.ipynb#subsetEqViaEquality" class="ProveItLink">subsetEqViaEquality</a> theorem
# ========
# *** see <a href="../__pv_it/25e91905b7f122ed31887b2ec5caefd3bc7bd0470/dependencies.ipynb" class="ProveItLink">dependencies</a> ***

# %%
import proveit
from proveit._common_ import A, B, C
from proveit.logic import Equals
from proveit.logic.set_theory.containment._axioms_ import subsetEqDef
from proveit.logic.set_theory.containment._theorems_ import subsetEqReflexive, foldSubsetEq, unfoldSubsetEq
# %proving subsetEqViaEquality presuming [proveit.logic]
# Out:
# Beginning proof of subsetEqViaEquality
# Recorded 'presuming' information
# Presuming theorems in proveit.logic (except any that presume this theorem).
# Presuming previous theorems (applied transitively).
# subsetEqViaEquality: forall_{A, B | A = B} (A subseteq B)

# %%
subsetEqDef
# Out:
# |- forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])

# %%
subsetEqDefSpecAB = subsetEqDef.specialize()
# Out:
# subsetEqDefSpecAB: |- (A subseteq B) = [forall_{x in A} (x in B)]

# %%
subsetEqViaEquality.specialize({A:A, B:A}, assumptions=[Equals(A, B)])
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove forall_{A, B | A = B} (A subseteq B) assuming {A = B}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove A subseteq B assuming {A = B}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove forall_{_x_ in A} (_x_ in B) assuming {A = B}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      51         try:
# ---> 52             proven_inst_expr = self.explicitInstanceExpr().prove(assumptions=extra_assumptions+defaults.checkedAssumptions(assumptions))
#      53             instanceVarLists = [list(self.explicitInstanceVars())]
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     437             if concludedTruth is None:
# --> 438                 raise ProofFailure(self, assumptions, "Failure to automatically 'conclude'")
#     439             if not isinstance(concludedTruth, KnownTruth):
#
# ProofFailure: Unable to prove _x_ in B assuming {_x_ in A, A = B}: Failure to automatically 'conclude'
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/proof.py in __init__(self, implicationExpr, assumptions)
#     654                 # (if WILDCARD_ASSUMPTIONS is included, it will be proven by assumption if there isn't an existing proof otherwise)
# --> 655                 antecedentTruth = implicationExpr.operands[0].prove(assumptions)
#     656                 _appendExtraAssumptions(assumptions, antecedentTruth)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      64             else:
# ---> 65                 raise ProofFailure(self, assumptions, "Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.")
#      66
#
# ProofFailure: Unable to prove forall_{_x_ in A} (_x_ in B) assuming {A = B}: Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.
#
# During handling of the above exception, another exception occurred:
#
# ModusPonensFailure                        Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      51         try:
# ---> 52             proven_inst_expr = self.explicitInstanceExpr().prove(assumptions=extra_assumptions+defaults.checkedAssumptions(assumptions))
#      53             instanceVarLists = [list(self.explicitInstanceVars())]
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#
# ~/Desktop/Prove-It/packages/proveit/logic/set_theory/containment/subset.py in conclude(self, assumptions)
#     149         # We need to automate this better, right now it is only practical to do concludeAsFolded manually.
# --> 150         return self.concludeAsFolded(elemInstanceVar=safeDummyVar(self), assumptions=assumptions)
#     151
#
# ~/Desktop/Prove-It/packages/proveit/logic/set_theory/containment/subset.py in concludeAsFolded(self, elemInstanceVar, assumptions)
#     172         from ._theorems_ import foldSubsetEq
# --> 173         return foldSubsetEq.specialize({A:self.subset, B:self.superset}, relabelMap={x:elemInstanceVar}, assumptions=assumptions).deriveConsequent(assumptions)
#     174
#
# ~/Desktop/Prove-It/packages/proveit/_core_/known_truth.py in call_method_with_known_truth_assumptions(*args, **kwargs)
#     608                     kwargs['assumptions'] = defaults.checkedAssumptions(assumptions)
# --> 609                 return attr.__call__(*args, **kwargs)
#     610             return call_method_with_known_truth_assumptions
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in deriveConsequent(self, assumptions)
#     135         from proveit._core_.proof import ModusPonens
# --> 136         return ModusPonens(self, assumptions).provenTruth
#     137
#
# ~/Desktop/Prove-It/packages/proveit/_core_/proof.py in __init__(self, implicationExpr, assumptions)
#     657             except ProofFailure:
# --> 658                 raise ModusPonensFailure(implicationExpr.operands[1], assumptions, 'Antecedent of %s is not proven'%str(implicationExpr))
#     659             # remove any unnecessary assumptions (but keep the order that was provided)
#
# ModusPonensFailure: Unable to prove A subseteq B assuming {A = B}: Antecedent of [forall_{_x_ in A} (_x_ in B)] => (A subseteq B) is not proven
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-17-44e936698542> in <module>
# ----> 1 subsetEqViaEquality.specialize({A:A, B:A}, assumptions=[Equals(A, B)])
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in specialize(self, specializeMap, relabelMap, assumptions)
#     113         and then call specialize on the KnownTruth.
#     114         '''
# --> 115         return self.prove(assumptions).specialize(specializeMap, relabelMap, assumptions=assumptions)
#     116
#     117     def _specializeUnravelingTheorem(self, theorem, *instanceVarLists):
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     434                 except ProofFailure:
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#     438                 raise ProofFailure(self, assumptions, "Failure to automatically 'conclude'")
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      63                 raise ProofFailure(self, assumptions, "Unable to conclude automatically; both the 'foldAsForall' method on the domain and automated generalization failed.")
#      64             else:
# ---> 65                 raise ProofFailure(self, assumptions, "Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.")
#      66
#      67     def unfold(self, assumptions=USE_DEFAULTS):
#
# ProofFailure: Unable to prove forall_{A, B | A = B} (A subseteq B) assuming {A = B}: Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.

# %%
subsetEqDefSpecAB.subRightSideInto(subsetEqViaEquality)
# Out:
# ---------------------------------------------------------------------------
# ScopingViolation                          Traceback (most recent call last)
# <ipython-input-12-d566620267ca> in <module>
# ----> 1 subsetEqDefSpecAB.subRightSideInto(subsetEqViaEquality)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/known_truth.py in call_method_with_known_truth_assumptions(*args, **kwargs)
#     607                     assumptions = tuple(assumptions) + self.assumptions
#     608                     kwargs['assumptions'] = defaults.checkedAssumptions(assumptions)
# --> 609                 return attr.__call__(*args, **kwargs)
#     610             return call_method_with_known_truth_assumptions
#     611
#
# ~/Desktop/Prove-It/packages/proveit/logic/equality/equals.py in subRightSideInto(self, lambdaMap, assumptions)
#     372         except:
#     373             pass
# --> 374         return subRightSideInto.specialize({x:self.lhs, y:self.rhs, P:Plambda}, assumptions=assumptions)
#     375
#     376     def deriveRightViaEquivalence(self, assumptions=USE_DEFAULTS):
#
# ~/Desktop/Prove-It/packages/proveit/_core_/known_truth.py in specialize(self, specializeMap, relabelMap, assumptions)
#     760                     processedSubMap[iVar] = iVar
#     761
# --> 762         return self._checkedTruth(Specialization(self, numForallEliminations=numForallEliminations, specializeMap=processedSubMap, relabelMap=relabelMap, assumptions=assumptions))
#     763
#     764     def generalize(self, forallVarLists, domainLists=None, domain=None, conditions=tuple()):
#
# ~/Desktop/Prove-It/packages/proveit/_core_/proof.py in __init__(self, generalTruth, numForallEliminations, specializeMap, relabelMap, assumptions)
#     724             generalExpr = generalTruth.expr
#     725             # perform the appropriate substitution/relabeling
# --> 726             specializedExpr, requirements, mappedVarLists, mappings = Specialization._specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     727             # obtain the KnownTruths for the substituted conditions
#     728             requirementTruths = []
#
# ~/Desktop/Prove-It/packages/proveit/_core_/proof.py in _specialized_expr(generalExpr, numForallEliminations, specializeMap, relabelMap, assumptions)
#     857                 raise SpecializationFailure(None, assumptions, 'Must specialize all of the instance variables of the Forall operations to be eliminated')
#     858             # make substitutions in the condition
# --> 859             subbedConditions += conditions.substituted(partialMap, relabelMap)
#     860
#     861         # sort the relabeling vars in order of their appearance in the original expression
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/composite/expr_list.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     333         subbed_exprs = []
#     334         for expr in self:
# --> 335             subbed_expr = expr.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     336             if isinstance(expr, Iter) and isinstance(subbed_expr, ExprList):
#     337                 # The iterated expression is being expanded
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     368                     lambdaExprReservedVars = {k:v for k, v in reservedVars.items() if k not in subbedOperator.parameterVarSet}
#     369                 else: lambdaExprReservedVars = None
# --> 370                 return subbedOperator.body._restrictionChecked(lambdaExprReservedVars).substituted(operandSubMap, assumptions=assumptions, requirements=requirements)
#     371         # remake the Expression with substituted operator and/or operands
#     372         if len(subbed_operators)==1:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349         if len(exprMap)>0 and (self in exprMap):
#     350             return exprMap[self]._restrictionChecked(reservedVars)
# --> 351         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     352         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     353         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/lambda_expr/lambda_expr.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     284         body_requirements = []
#     285         body_assumptions = list(inner_assumptions)+list(subbedConditions)
# --> 286         subbedBody = self.body.substituted(inner_expr_map, relabelMap, inner_reservations, body_assumptions, body_requirements)
#     287
#     288         for requirements, requirements_assumptions in zip((condition_requirements, body_requirements), ([], subbedConditions)):
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/operation/operation.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     349         if len(exprMap)>0 and (self in exprMap):
#     350             return exprMap[self]._restrictionChecked(reservedVars)
# --> 351         subbed_operand_or_operands = self.operand_or_operands.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#     352         subbed_operands = compositeExpression(subbed_operand_or_operands)
#     353         subbed_operator_or_operators = self.operator_or_operators.substituted(exprMap, relabelMap, reservedVars, assumptions, requirements)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/lambda_expr/lambda_expr.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#     284         body_requirements = []
#     285         body_assumptions = list(inner_assumptions)+list(subbedConditions)
# --> 286         subbedBody = self.body.substituted(inner_expr_map, relabelMap, inner_reservations, body_assumptions, body_requirements)
#     287
#     288         for requirements, requirements_assumptions in zip((condition_requirements, body_requirements), ([], subbedConditions)):
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/label/var.py in substituted(self, exprMap, relabelMap, reservedVars, assumptions, requirements)
#      26             if not isinstance(subbed, Expression):
#      27                 raise TypeError('Must substitute a Variable with an Expression (not %s)'%subbed.__class__)
# ---> 28             return subbed._restrictionChecked(reservedVars)
#      29         elif relabelMap is not None:
#      30             subbed = relabelMap.get(self, self)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in _restrictionChecked(self, reservedVars)
#     637         '''
#     638         if not reservedVars is None and not self.freeVars().isdisjoint(list(reservedVars.keys())):
# --> 639             raise ScopingViolation("Must not make substitution with reserved variables  (i.e., parameters of a Lambda function)")
#     640         return self
#     641
#
# ScopingViolation: Must not make substitution with reserved variables  (i.e., parameters of a Lambda function)

# %%
subsetEqDefSpecABDerived = subsetEqDefSpecAB.deriveLeftViaEquivalence([subsetEqDefSpecAB.rhs])
# Out:
# subsetEqDefSpecABDerived: {forall_{x in A} (x in B)} |- A subseteq B

# %%
subsetEqDefSpecAA = subsetEqDef.specialize({A:A, B:A})
# Out:
# subsetEqDefSpecAA: |- (A subseteq A) = [forall_{x in A} (x in A)]

# %%
subsetEqDefSpecAA.deriveLeftViaEquivalence([subsetEqDefSpecAA.rhs])
# Out:
# {forall_{x in A} (x in A)} |- A subseteq A

# %%
subsetEqReflexive
# Out:
# |- forall_{A} (A subseteq A)

# %%
subsetEqReflexive.specialize()
# Out:
# |- A subseteq A

# %%
unfoldSubsetEq
# Out:
# |- forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]

# %%
# %qed
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove forall_{A, B | A = B} (A subseteq B): Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove A subseteq B assuming {A = B}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     432                     # first attempt to prove via implication
# --> 433                     concludedTruth = self.concludeViaImplication(assumptions)
#     434                 except ProofFailure:
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in concludeViaImplication(self, assumptions)
#     481         from proveit.logic import concludeViaImplication
# --> 482         return concludeViaImplication(self, assumptions)
#     483
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in concludeViaImplication(consequent, assumptions)
#     301                         queue.append(local_antecedent)
# --> 302     raise ProofFailure(consequent, assumptions, 'Unable to conclude via implications')
#     303
#
# ProofFailure: Unable to prove forall_{_x_ in A} (_x_ in B) assuming {A = B}: Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      51         try:
# ---> 52             proven_inst_expr = self.explicitInstanceExpr().prove(assumptions=extra_assumptions+defaults.checkedAssumptions(assumptions))
#      53             instanceVarLists = [list(self.explicitInstanceVars())]
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     437             if concludedTruth is None:
# --> 438                 raise ProofFailure(self, assumptions, "Failure to automatically 'conclude'")
#     439             if not isinstance(concludedTruth, KnownTruth):
#
# ProofFailure: Unable to prove _x_ in B assuming {_x_ in A, A = B}: Failure to automatically 'conclude'
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/_core_/proof.py in __init__(self, implicationExpr, assumptions)
#     654                 # (if WILDCARD_ASSUMPTIONS is included, it will be proven by assumption if there isn't an existing proof otherwise)
# --> 655                 antecedentTruth = implicationExpr.operands[0].prove(assumptions)
#     656                 _appendExtraAssumptions(assumptions, antecedentTruth)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      64             else:
# ---> 65                 raise ProofFailure(self, assumptions, "Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.")
#      66
#
# ProofFailure: Unable to prove forall_{_x_ in A} (_x_ in B) assuming {A = B}: Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.
#
# During handling of the above exception, another exception occurred:
#
# ModusPonensFailure                        Traceback (most recent call last)
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      51         try:
# ---> 52             proven_inst_expr = self.explicitInstanceExpr().prove(assumptions=extra_assumptions+defaults.checkedAssumptions(assumptions))
#      53             instanceVarLists = [list(self.explicitInstanceVars())]
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#
# ~/Desktop/Prove-It/packages/proveit/logic/set_theory/containment/subset.py in conclude(self, assumptions)
#     149         # We need to automate this better, right now it is only practical to do concludeAsFolded manually.
# --> 150         return self.concludeAsFolded(elemInstanceVar=safeDummyVar(self), assumptions=assumptions)
#     151
#
# ~/Desktop/Prove-It/packages/proveit/logic/set_theory/containment/subset.py in concludeAsFolded(self, elemInstanceVar, assumptions)
#     172         from ._theorems_ import foldSubsetEq
# --> 173         return foldSubsetEq.specialize({A:self.subset, B:self.superset}, relabelMap={x:elemInstanceVar}, assumptions=assumptions).deriveConsequent(assumptions)
#     174
#
# ~/Desktop/Prove-It/packages/proveit/_core_/known_truth.py in call_method_with_known_truth_assumptions(*args, **kwargs)
#     608                     kwargs['assumptions'] = defaults.checkedAssumptions(assumptions)
# --> 609                 return attr.__call__(*args, **kwargs)
#     610             return call_method_with_known_truth_assumptions
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/implication/implies.py in deriveConsequent(self, assumptions)
#     135         from proveit._core_.proof import ModusPonens
# --> 136         return ModusPonens(self, assumptions).provenTruth
#     137
#
# ~/Desktop/Prove-It/packages/proveit/_core_/proof.py in __init__(self, implicationExpr, assumptions)
#     657             except ProofFailure:
# --> 658                 raise ModusPonensFailure(implicationExpr.operands[1], assumptions, 'Antecedent of %s is not proven'%str(implicationExpr))
#     659             # remove any unnecessary assumptions (but keep the order that was provided)
#
# ModusPonensFailure: Unable to prove A subseteq B assuming {A = B}: Antecedent of [forall_{_x_ in A} (_x_ in B)] => (A subseteq B) is not proven
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# <ipython-input-10-b046f9677097> in <module>
# ----> 1 get_ipython().run_line_magic('qed', '')
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-133> in qed(self, line)
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/Desktop/Prove-It/packages/proveit/magics.py in qed(self, line)
#     622     @line_magic
#     623     def qed(self, line):
# --> 624         return ProveItMagicCommands.qed(self)
#     625
#     626     @line_magic
#
# ~/Desktop/Prove-It/packages/proveit/magics.py in qed(self)
#     410
#     411     def qed(self):
# --> 412         proof = KnownTruth.theoremBeingProven.provenTruth._qed()
#     413         proof._repr_html_() # generate expressions that should be referenced
#     414         self.context.referenceDisplayedExpressions('_proof_' + KnownTruth.theoremBeingProven.name)
#
# ~/Desktop/Prove-It/packages/proveit/_core_/known_truth.py in _qed(self)
#     319         KnownTruth.qedInProgress = True
#     320         try:
# --> 321             proof = self.expr.prove().proof()
#     322             if not proof.isUsable():
#     323                 proof.provenTruth.raiseUnusableProof()
#
# ~/Desktop/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, assumptions, automation)
#     434                 except ProofFailure:
#     435                     # try the 'conclude' method of the specific Expression class
# --> 436                     concludedTruth = self.conclude(assumptions)
#     437             if concludedTruth is None:
#     438                 raise ProofFailure(self, assumptions, "Failure to automatically 'conclude'")
#
# ~/Desktop/Prove-It/packages/proveit/logic/boolean/quantification/universal/forall.py in conclude(self, assumptions)
#      63                 raise ProofFailure(self, assumptions, "Unable to conclude automatically; both the 'foldAsForall' method on the domain and automated generalization failed.")
#      64             else:
# ---> 65                 raise ProofFailure(self, assumptions, "Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.")
#      66
#      67     def unfold(self, assumptions=USE_DEFAULTS):
#
# ProofFailure: Unable to prove forall_{A, B | A = B} (A subseteq B): Unable to conclude automatically; the domain has no 'foldAsForall' method and automated generalization failed.
