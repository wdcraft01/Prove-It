# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C
from proveit.logic import Forall, Superset, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B, C], Superset(A, C), conditions = [Superset(A, B), SupersetEq(B, C)]))
# Out:
# expr: A -> [forall_{B, C | A supset B , B supseteq C} (A supset C)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B, C | A supset B , B supseteq C} (A supset C)]
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. forall_{B, C | A supset B , B supseteq C} (A supset C)
#    core type: Operation
#    operator: 5
#    operand: 2
# 2. B -> [forall_{C | B supseteq C} (A supset C)] | A supset B
#    core type: Lambda
#    parameter: 17
#    body: 3
#    conditions: 4\n3. forall_{C | B supseteq C} (A supset C)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (A supset B)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. C -> (A supset C) | B supseteq C
#    core type: Lambda
#    parameter: 18
#    body: 8
#    conditions: 9\n7. A supset B
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. A supset C
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (B supseteq C)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 14, 17
# 11. supset
#     core type: Literal
#     sub-expressions:
# 12. (A , C)
#     core type: ExprTuple
#     sub-expressions: 14, 18
# 13. B supseteq C
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. supseteq
#     core type: Literal
#     sub-expressions:
# 16. (B , C)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
