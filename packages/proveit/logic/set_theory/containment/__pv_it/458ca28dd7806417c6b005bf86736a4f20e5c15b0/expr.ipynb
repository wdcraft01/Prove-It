# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, x
from proveit.logic import Equals, Forall, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Equals(SubsetEq(A, B), Forall([x], InSet(x, B), domain = A, conditions = []))
# Out:
# expr: (A subseteq B) = [forall_{x in A} (x in B)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A subseteq B) = [forall_{x in A} (x in B)]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A subseteq B , forall_{x in A} (x in B))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A subseteq B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 7
#    operand: 8
# 5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. (A , B)
#    core type: ExprTuple
#    sub-expressions: 17, 13
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> (x in B) | x in A
#    core type: Lambda
#    parameter: 16
#    body: 9
#    conditions: 10\n9. x in B
#    core type: Operation
#    operator: 14
#    operands: 11
# 10. (x in A)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (x , B)
#     core type: ExprTuple
#     sub-expressions: 16, 13
# 12. x in A
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x , A)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
