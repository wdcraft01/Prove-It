# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#foldSubsetEq">foldSubsetEq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import foldSubsetEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr foldSubsetEq
# Out:
# Passed sanity check: built 'foldSubsetEq' is the same as the stored Expression.

# %%
# display the expression information
foldSubsetEq.exprInfo()
# Out:
# 0. forall_{A, B} ([forall_{x in A} (x in B)] => (A subseteq B))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. A -> [forall_{B} ([forall_{x in A} (x in B)] => (A subseteq B))]
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. forall_{B} ([forall_{x in A} (x in B)] => (A subseteq B))
#    core type: Operation
#    operator: 9
#    operand: 3
# 3. B -> ([forall_{x in A} (x in B)] => (A subseteq B))
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. [forall_{x in A} (x in B)] => (A subseteq B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x in A} (x in B) , A subseteq B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. A subseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. forall
#    core type: Literal
#    sub-expressions:
# ...
