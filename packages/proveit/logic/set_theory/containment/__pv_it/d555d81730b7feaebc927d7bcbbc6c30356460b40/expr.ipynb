# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#transitivitySupsetEqSupset">transitivitySupsetEqSupset</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import transitivitySupsetEqSupset

# %%
# check that the built expression is the same as the stored expression
# %check_expr transitivitySupsetEqSupset
# Out:
# Passed sanity check: built 'transitivitySupsetEqSupset' is the same as the stored Expression.

# %%
# display the expression information
transitivitySupsetEqSupset.exprInfo()
# Out:
# 0. forall_{A, B, C | A supseteq B , B supset C} (A supset C)
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. A -> [forall_{B, C | A supseteq B , B supset C} (A supset C)]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{B, C | A supseteq B , B supset C} (A supset C)
#    core type: Operation
#    operator: 6
#    operand: 3
# 3. B -> [forall_{C | B supset C} (A supset C)] | A supseteq B
#    core type: Lambda
#    parameter: 18
#    body: 4
#    conditions: 5\n4. forall_{C | B supset C} (A supset C)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (A supseteq B)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. C -> (A supset C) | B supset C
#    core type: Lambda
#    parameter: 19
#    body: 9
#    conditions: 10\n8. A supseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. A supset C
#    core type: Operation
#    operator: 16
#    operands: 13
# ...
