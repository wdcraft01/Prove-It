# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#transitivitySubsetEqSubset">transitivitySubsetEqSubset</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import transitivitySubsetEqSubset

# %%
# check that the built expression is the same as the stored expression
# %check_expr transitivitySubsetEqSubset
# Out:
# Passed sanity check: built 'transitivitySubsetEqSubset' is the same as the stored Expression.

# %%
# display the expression information
transitivitySubsetEqSubset.exprInfo()
# Out:
# 0. forall_{A, B, C | A subseteq B , B subset C} (A subset C)
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. A -> [forall_{B, C | A subseteq B , B subset C} (A subset C)]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{B, C | A subseteq B , B subset C} (A subset C)
#    core type: Operation
#    operator: 6
#    operand: 3
# 3. B -> [forall_{C | B subset C} (A subset C)] | A subseteq B
#    core type: Lambda
#    parameter: 18
#    body: 4
#    conditions: 5\n4. forall_{C | B subset C} (A subset C)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (A subseteq B)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. C -> (A subset C) | B subset C
#    core type: Lambda
#    parameter: 19
#    body: 9
#    conditions: 10\n8. A subseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. A subset C
#    core type: Operation
#    operator: 16
#    operands: 13
# 10. (B subset C)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. subseteq
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
#     core type: ExprTuple
#     sub-expressions: 15, 18
# 13. (A , C)
#     core type: ExprTuple
#     sub-expressions: 15, 19
# 14. B subset C
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. subset
#     core type: Literal
#     sub-expressions:
# 17. (B , C)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. C
#     core type: Variable
#     sub-expressions:
