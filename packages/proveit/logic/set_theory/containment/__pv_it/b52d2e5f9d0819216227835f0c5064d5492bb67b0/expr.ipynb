# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import A, B
from proveit.logic import Forall, Implies, InSet, SupersetEq

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Implies(Forall([subExpr1], InSet(subExpr1, A), domain = B, conditions = []), SupersetEq(A, B))
# Out:
# expr: [forall_{_x_ in B} (_x_ in A)] => (A supseteq B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [forall_{_x_ in B} (_x_ in A)] => (A supseteq B)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{_x_ in B} (_x_ in A) , A supseteq B)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{_x_ in B} (_x_ in A)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. A supseteq B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. _x_ -> (_x_ in A) | _x_ in B
#    core type: Lambda
#    parameter: 16
#    body: 9
#    conditions: 10\n7. supseteq
#    core type: Literal
#    sub-expressions:
# 8. (A , B)
#    core type: ExprTuple
#    sub-expressions: 13, 17
# 9. _x_ in A
#    core type: Operation
#    operator: 14
#    operands: 11
# 10. (_x_ in B)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (_x_ , A)
#     core type: ExprTuple
#     sub-expressions: 16, 13
# 12. _x_ in B
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (_x_ , B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. _x_
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
