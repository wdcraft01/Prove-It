# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, x
from proveit.logic import Equals, Forall, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([B], Equals(SubsetEq(A, B), Forall([x], InSet(x, B), domain = A, conditions = subExpr1)), conditions = subExpr1)
# Out:
# expr: forall_{B} ((A subseteq B) = [forall_{x in A} (x in B)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B} ((A subseteq B) = [forall_{x in A} (x in B)])
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. B -> ((A subseteq B) = [forall_{x in A} (x in B)])
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. (A subseteq B) = [forall_{x in A} (x in B)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A subseteq B , forall_{x in A} (x in B))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A subseteq B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. subseteq
#    core type: Literal
#    sub-expressions:
# 8. (A , B)
#    core type: ExprTuple
#    sub-expressions: 19, 15
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. x -> (x in B) | x in A
#     core type: Lambda
#     parameter: 18
#     body: 11
#     conditions: 12\n11. x in B
#     core type: Operation
#     operator: 16
#     operands: 13
# 12. (x in A)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (x , B)
#     core type: ExprTuple
#     sub-expressions: 18, 15
# 14. x in A
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x , A)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
