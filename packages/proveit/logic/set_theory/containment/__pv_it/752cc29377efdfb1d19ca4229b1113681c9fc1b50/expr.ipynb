# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable
from proveit._common_ import A, B
from proveit.logic import Forall, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = ExprTuple(Forall([subExpr1], InSet(subExpr1, B), domain = A, conditions = []), SubsetEq(A, B))
# Out:
# expr: (forall_{_x_ in A} (_x_ in B) , A subseteq B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{_x_ in A} (_x_ in B) , A subseteq B)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{_x_ in A} (_x_ in B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. A subseteq B
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. _x_ -> (_x_ in B) | _x_ in A
#    core type: Lambda
#    parameter: 14
#    body: 7
#    conditions: 8\n5. subseteq
#    core type: Literal
#    sub-expressions:
# 6. (A , B)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 7. _x_ in B
#    core type: Operation
#    operator: 12
#    operands: 9
# 8. (_x_ in A)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (_x_ , B)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 10. _x_ in A
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (_x_ , A)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. _x_
#     core type: Variable
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
