# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#subsetEqViaEquality">subsetEqViaEquality</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import subsetEqViaEquality

# %%
# check that the built expression is the same as the stored expression
# %check_expr subsetEqViaEquality
# Out:
# Passed sanity check: built 'subsetEqViaEquality' is the same as the stored Expression.

# %%
# display the expression information
subsetEqViaEquality.exprInfo()
# Out:
# 0. forall_{A, B | A = B} (A subseteq B)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | A = B} (A subseteq B)]
#    core type: Lambda
#    parameter: 11
#    body: 2
# 2. forall_{B | A = B} (A subseteq B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (A subseteq B) | A = B
#    core type: Lambda
#    parameter: 12
#    body: 5
#    conditions: 6\n5. A subseteq B
#    core type: Operation
#    operator: 7
#    operands: 10
# 6. (A = B)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. subseteq
#    core type: Literal
#    sub-expressions:
# 8. A = B
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
