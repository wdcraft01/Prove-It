# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#subsetEqDef">subsetEqDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._axioms_ import subsetEqDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr subsetEqDef
# Out:
# Passed sanity check: built 'subsetEqDef' is the same as the stored Expression.

# %%
# display the expression information
subsetEqDef.exprInfo()
# Out:
# 0. forall_{A, B} ((A subseteq B) = [forall_{x in A} (x in B)])
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. A -> [forall_{B} ((A subseteq B) = [forall_{x in A} (x in B)])]
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. forall_{B} ((A subseteq B) = [forall_{x in A} (x in B)])
#    core type: Operation
#    operator: 11
#    operand: 3
# 3. B -> ((A subseteq B) = [forall_{x in A} (x in B)])
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. (A subseteq B) = [forall_{x in A} (x in B)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (A subseteq B , forall_{x in A} (x in B))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A subseteq B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. subseteq
#    core type: Literal
#    sub-expressions:
# 10. (A , B)
# ...
