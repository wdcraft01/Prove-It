# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#supersetDef">supersetDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._axioms_ import supersetDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr supersetDef
# Out:
# Passed sanity check: built 'supersetDef' is the same as the stored Expression.

# %%
# display the expression information
supersetDef.exprInfo()
# Out:
# 0. forall_{A, B} ((A supset B) = ((A supseteq B) and (A nsubseteq B)))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B} ((A supset B) = ((A supseteq B) and (A nsubseteq B)))]
#    core type: Lambda
#    parameter: 18
#    body: 2
# 2. forall_{B} ((A supset B) = ((A supseteq B) and (A nsubseteq B)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((A supset B) = ((A supseteq B) and (A nsubseteq B)))
#    core type: Lambda
#    parameter: 19
#    body: 5
# 5. (A supset B) = ((A supseteq B) and (A nsubseteq B))
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (A supset B , (A supseteq B) and (A nsubseteq B))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A supset B
#    core type: Operation
#    operator: 10
#    operands: 17
# 9. (A supseteq B) and (A nsubseteq B)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. supset
#     core type: Literal
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A supseteq B , A nsubseteq B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A supseteq B
#     core type: Operation
#     operator: 15
#     operands: 17
# 14. A nsubseteq B
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. supseteq
#     core type: Literal
#     sub-expressions:
# 16. nsubseteq
#     core type: Literal
#     sub-expressions:
# 17. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
