# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#foldSupsetEq">foldSupsetEq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import foldSupsetEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr foldSupsetEq
# Out:
# Passed sanity check: built 'foldSupsetEq' is the same as the stored Expression.

# %%
# display the expression information
foldSupsetEq.exprInfo()
# Out:
# 0. forall_{A, B} ([forall_{x in B} (x in A)] => (A supseteq B))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. A -> [forall_{B} ([forall_{x in B} (x in A)] => (A supseteq B))]
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. forall_{B} ([forall_{x in B} (x in A)] => (A supseteq B))
#    core type: Operation
#    operator: 9
#    operand: 3
# 3. B -> ([forall_{x in B} (x in A)] => (A supseteq B))
#    core type: Lambda
#    parameter: 21
#    body: 4
# 4. [forall_{x in B} (x in A)] => (A supseteq B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x in B} (x in A) , A supseteq B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. A supseteq B
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. x -> (x in A) | x in B
#     core type: Lambda
#     parameter: 20
#     body: 13
#     conditions: 14\n11. supseteq
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 13. x in A
#     core type: Operation
#     operator: 18
#     operands: 15
# 14. (x in B)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (x , A)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 16. x in B
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x , B)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
