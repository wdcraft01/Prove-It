# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import And, Equals, Forall, NotSupersetEq, Subset, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Forall([B], Equals(Subset(A, B), And(SubsetEq(A, B), NotSupersetEq(A, B))), conditions = [])
# Out:
# expr: forall_{B} ((A subset B) = ((A subseteq B) and (A nsupseteq B)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B} ((A subset B) = ((A subseteq B) and (A nsupseteq B)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> ((A subset B) = ((A subseteq B) and (A nsupseteq B)))
#    core type: Lambda
#    parameter: 17
#    body: 3
# 3. (A subset B) = ((A subseteq B) and (A nsupseteq B))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A subset B , (A subseteq B) and (A nsupseteq B))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A subset B
#    core type: Operation
#    operator: 8
#    operands: 15
# 7. (A subseteq B) and (A nsupseteq B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. subset
#    core type: Literal
#    sub-expressions:
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A subseteq B , A nsupseteq B)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A subseteq B
#     core type: Operation
#     operator: 13
#     operands: 15
# 12. A nsupseteq B
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. subseteq
#     core type: Literal
#     sub-expressions:
# 14. nsupseteq
#     core type: Literal
#     sub-expressions:
# 15. (A , B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
