# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#foldNotSupsetEq">foldNotSupsetEq</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import foldNotSupsetEq

# %%
# check that the built expression is the same as the stored expression
# %check_expr foldNotSupsetEq
# Out:
# Passed sanity check: built 'foldNotSupsetEq' is the same as the stored Expression.

# %%
# display the expression information
foldNotSupsetEq.exprInfo()
# Out:
# 0. forall_{A, B | [not](A supseteq B)} (A nsupseteq B)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | [not](A supseteq B)} (A nsupseteq B)]
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. forall_{B | [not](A supseteq B)} (A nsupseteq B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (A nsupseteq B) | [not](A supseteq B)
#    core type: Lambda
#    parameter: 14
#    body: 5
#    conditions: 6\n5. A nsupseteq B
#    core type: Operation
#    operator: 7
#    operands: 12
# 6. ([not](A supseteq B))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. nsupseteq
#    core type: Literal
#    sub-expressions:
# 8. [not](A supseteq B)
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. A supseteq B
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. supseteq
# ...
