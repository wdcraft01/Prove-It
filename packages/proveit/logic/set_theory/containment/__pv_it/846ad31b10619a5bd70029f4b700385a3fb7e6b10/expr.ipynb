# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Forall, Subset, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Forall([B, C], Subset(A, C), conditions = [Subset(A, B), SubsetEq(B, C)])
# Out:
# expr: forall_{B, C | A subset B , B subseteq C} (A subset C)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B, C | A subset B , B subseteq C} (A subset C)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. B -> [forall_{C | B subseteq C} (A subset C)] | A subset B
#    core type: Lambda
#    parameter: 16
#    body: 2
#    conditions: 3\n2. forall_{C | B subseteq C} (A subset C)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A subset B)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. C -> (A subset C) | B subseteq C
#    core type: Lambda
#    parameter: 17
#    body: 7
#    conditions: 8\n6. A subset B
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. A subset C
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (B subseteq C)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 10. subset
#     core type: Literal
#     sub-expressions:
# 11. (A , C)
#     core type: ExprTuple
#     sub-expressions: 13, 17
# 12. B subseteq C
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. subseteq
#     core type: Literal
#     sub-expressions:
# 15. (B , C)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. C
#     core type: Variable
#     sub-expressions:
