# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#notSupersetEqDef">notSupersetEqDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._axioms_ import notSupersetEqDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr notSupersetEqDef
# Out:
# Passed sanity check: built 'notSupersetEqDef' is the same as the stored Expression.

# %%
# display the expression information
notSupersetEqDef.exprInfo()
# Out:
# 0. forall_{A, B} ((A nsupseteq B) = [not](A supseteq B))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B} ((A nsupseteq B) = [not](A supseteq B))]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{B} ((A nsupseteq B) = [not](A supseteq B))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((A nsupseteq B) = [not](A supseteq B))
#    core type: Lambda
#    parameter: 16
#    body: 5
# 5. (A nsupseteq B) = [not](A supseteq B)
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (A nsupseteq B , [not](A supseteq B))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. A nsupseteq B
#    core type: Operation
#    operator: 10
#    operands: 14
# 9. [not](A supseteq B)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. nsupseteq
#     core type: Literal
#     sub-expressions:
# ...
