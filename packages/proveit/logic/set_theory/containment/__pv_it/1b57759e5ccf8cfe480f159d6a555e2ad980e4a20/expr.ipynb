# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C
from proveit.logic import Forall, Superset, SupersetEq

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Forall([C], Superset(A, C), conditions = [SupersetEq(B, C)]), conditions = [SupersetEq(A, B)])
# Out:
# expr: B -> [forall_{C | B supseteq C} (A supset C)] | A supseteq B

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> [forall_{C | B supseteq C} (A supset C)] | A supseteq B
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. forall_{C | B supseteq C} (A supset C)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A supseteq B)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. C -> (A supset C) | B supseteq C
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n5. A supseteq B
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. A supset C
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (B supseteq C)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (A , B)
#    core type: ExprTuple
#    sub-expressions: 12, 15
# 9. supset
#    core type: Literal
#    sub-expressions:
# 10. (A , C)
#     core type: ExprTuple
#     sub-expressions: 12, 16
# 11. B supseteq C
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. supseteq
#     core type: Literal
#     sub-expressions:
# 14. (B , C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
