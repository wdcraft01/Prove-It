# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, x
from proveit.logic import Forall, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(Forall([x], InSet(x, A), domain = B, conditions = []))
# Out:
# expr: {forall_{x in B} (x in A)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{x in B} (x in A)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x in B} (x in A))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. forall_{x in B} (x in A)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> (x in A) | x in B
#    core type: Lambda
#    parameter: 13
#    body: 6
#    conditions: 7\n6. x in A
#    core type: Operation
#    operator: 11
#    operands: 8
# 7. (x in B)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x , A)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 9. x in B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x , B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
