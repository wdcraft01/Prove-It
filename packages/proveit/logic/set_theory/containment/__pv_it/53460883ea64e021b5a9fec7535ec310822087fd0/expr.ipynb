# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, x
from proveit.logic import Forall, Implies, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([B], Implies(Forall([x], InSet(x, B), domain = A, conditions = subExpr1), SubsetEq(A, B)), conditions = subExpr1)
# Out:
# expr: forall_{B} ([forall_{x in A} (x in B)] => (A subseteq B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B} ([forall_{x in A} (x in B)] => (A subseteq B))
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. B -> ([forall_{x in A} (x in B)] => (A subseteq B))
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. [forall_{x in A} (x in B)] => (A subseteq B)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{x in A} (x in B) , A subseteq B)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. A subseteq B
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> (x in B) | x in A
#    core type: Lambda
#    parameter: 18
#    body: 11
#    conditions: 12\n9. subseteq
#    core type: Literal
#    sub-expressions:
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 11. x in B
#     core type: Operation
#     operator: 16
#     operands: 13
# 12. (x in A)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (x , B)
#     core type: ExprTuple
#     sub-expressions: 18, 15
# 14. x in A
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x , A)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
