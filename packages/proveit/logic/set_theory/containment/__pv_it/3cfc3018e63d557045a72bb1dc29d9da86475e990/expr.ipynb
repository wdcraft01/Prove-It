# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#reverseSupset">reverseSupset</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.containment</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.containment._theorems_ import reverseSupset

# %%
# check that the built expression is the same as the stored expression
# %check_expr reverseSupset
# Out:
# Passed sanity check: built 'reverseSupset' is the same as the stored Expression.

# %%
# display the expression information
reverseSupset.exprInfo()
# Out:
# 0. forall_{A, B | A supset B} (B subset A)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | A supset B} (B subset A)]
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. forall_{B | A supset B} (B subset A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (B subset A) | A supset B
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n5. B subset A
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A supset B)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. subset
#    core type: Literal
#    sub-expressions:
# 8. (B , A)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. A supset B
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. supset
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
# ...
