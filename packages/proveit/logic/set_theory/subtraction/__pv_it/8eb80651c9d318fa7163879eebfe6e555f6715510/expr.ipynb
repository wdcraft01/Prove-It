# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x, y
from proveit.logic import And, Difference, Iff, InSet, NotEquals, Set

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Iff(InSet(x, Difference(S, Set(y))), And(InSet(x, S), NotEquals(x, y))))
# Out:
# expr: y -> ((x in (S - {y})) <=> ((x in S) and (x != y)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> ((x in (S - {y})) <=> ((x in S) and (x != y)))
#    core type: Lambda
#    parameter: 23
#    body: 1
# 1. (x in (S - {y})) <=> ((x in S) and (x != y))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. <=>
#    core type: Literal
#    sub-expressions:
# 3. (x in (S - {y}) , (x in S) and (x != y))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in (S - {y})
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (x in S) and (x != y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x , S - {y})
#    core type: ExprTuple
#    sub-expressions: 20, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in S , x != y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. S - {y}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x in S
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. x != y
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. (S , {y})
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x , S)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 16. !=
#     core type: Literal
#     sub-expressions:
# 17. (x , y)
#     core type: ExprTuple
#     sub-expressions: 20, 23
# 18. {y}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. S
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. Set
#     core type: Literal
#     sub-expressions:
# 22. (y)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. y
#     core type: Variable
#     sub-expressions:
