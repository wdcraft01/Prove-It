# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, x
from proveit.logic import And, Difference, Equals, Forall, InSet, NotInSet

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Equals(InSet(x, Difference(A, B)), And(InSet(x, A), NotInSet(x, B))), conditions = []))
# Out:
# expr: A -> [forall_{B} ((x in (A - B)) = ((x in A) and (x not-in B)))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B} ((x in (A - B)) = ((x in A) and (x not-in B)))]
#    core type: Lambda
#    parameter: 21
#    body: 1
# 1. forall_{B} ((x in (A - B)) = ((x in A) and (x not-in B)))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. B -> ((x in (A - B)) = ((x in A) and (x not-in B)))
#    core type: Lambda
#    parameter: 23
#    body: 4
# 4. (x in (A - B)) = ((x in A) and (x not-in B))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x in (A - B) , (x in A) and (x not-in B))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x in (A - B)
#    core type: Operation
#    operator: 17
#    operands: 9
# 8. (x in A) and (x not-in B)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (x , A - B)
#    core type: ExprTuple
#    sub-expressions: 22, 12
# 10. and
#     core type: Literal
#     sub-expressions:
# ...
