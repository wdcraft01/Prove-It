# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#membershipFolding">membershipFolding</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.subtraction._theorems_ import membershipFolding

# %%
# check that the built expression is the same as the stored expression
# %check_expr membershipFolding
# Out:
# Passed sanity check: built 'membershipFolding' is the same as the stored Expression.

# %%
# display the expression information
membershipFolding.exprInfo()
# Out:
# 0. forall_{x, A, B | x in A , x not-in B} (x in (A - B))
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. x -> [forall_{A, B | x in A , x not-in B} (x in (A - B))]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{A, B | x in A , x not-in B} (x in (A - B))
#    core type: Operation
#    operator: 6
#    operand: 3
# 3. A -> [forall_{B | x not-in B} (x in (A - B))] | x in A
#    core type: Lambda
#    parameter: 21
#    body: 4
#    conditions: 5\n4. forall_{B | x not-in B} (x in (A - B))
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (x in A)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. B -> (x in (A - B)) | x not-in B
#    core type: Lambda
#    parameter: 22
#    body: 9
#    conditions: 10\n8. x in A
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. x in (A - B)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (x not-in B)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. (x , A)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x , A - B)
#     core type: ExprTuple
#     sub-expressions: 20, 15
# 14. x not-in B
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. A - B
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. not-in
#     core type: Literal
#     sub-expressions:
# 17. (x , B)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (A , B)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. B
#     core type: Variable
#     sub-expressions:
