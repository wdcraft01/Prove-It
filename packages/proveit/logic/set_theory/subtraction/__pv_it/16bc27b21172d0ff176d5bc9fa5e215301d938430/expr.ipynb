# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, x
from proveit.logic import Difference, InSet, NotInSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(B, NotInSet(x, Difference(A, B)), conditions = [Or(NotInSet(x, A), InSet(x, B))])
# Out:
# expr: B -> (x not-in (A - B)) | (x not-in A) or (x in B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> (x not-in (A - B)) | (x not-in A) or (x in B)
#    core type: Lambda
#    parameter: 18
#    body: 1
#    conditions: 2\n1. x not-in (A - B)
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. ((x not-in A) or (x in B))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (x , A - B)
#    core type: ExprTuple
#    sub-expressions: 17, 5
# 4. (x not-in A) or (x in B)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A - B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (x not-in A , x in B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. -
#    core type: Literal
#    sub-expressions:
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 16, 18
# 10. x not-in A
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. x in B
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. not-in
#     core type: Literal
#     sub-expressions:
# 13. (x , A)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (x , B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
