# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nonmembershipEquiv">nonmembershipEquiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.subtraction._theorems_ import nonmembershipEquiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr nonmembershipEquiv
# Out:
# Passed sanity check: built 'nonmembershipEquiv' is the same as the stored Expression.

# %%
# display the expression information
nonmembershipEquiv.exprInfo()
# Out:
# 0. forall_{x, A, B} ((x not-in (A - B)) = ((x not-in A) or (x in B)))
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> [forall_{A, B} ((x not-in (A - B)) = ((x not-in A) or (x in B)))]
#    core type: Lambda
#    parameter: 25
#    body: 2
# 2. forall_{A, B} ((x not-in (A - B)) = ((x not-in A) or (x in B)))
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. A -> [forall_{B} ((x not-in (A - B)) = ((x not-in A) or (x in B)))]
#    core type: Lambda
#    parameter: 24
#    body: 4
# 4. forall_{B} ((x not-in (A - B)) = ((x not-in A) or (x in B)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. B -> ((x not-in (A - B)) = ((x not-in A) or (x in B)))
#    core type: Lambda
#    parameter: 26
#    body: 7
# 7. (x not-in (A - B)) = ((x not-in A) or (x in B))
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (x not-in (A - B) , (x not-in A) or (x in B))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x not-in (A - B)
#     core type: Operation
#     operator: 20
#     operands: 12
# 11. (x not-in A) or (x in B)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x , A - B)
#     core type: ExprTuple
#     sub-expressions: 25, 15
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (x not-in A , x in B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. A - B
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. x not-in A
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. x in B
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (A , B)
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 20. not-in
#     core type: Literal
#     sub-expressions:
# 21. (x , A)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (x , B)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. B
#     core type: Variable
#     sub-expressions:
