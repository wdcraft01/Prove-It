# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#membershipUnfolding">membershipUnfolding</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.subtraction._theorems_ import membershipUnfolding

# %%
# check that the built expression is the same as the stored expression
# %check_expr membershipUnfolding
# Out:
# Passed sanity check: built 'membershipUnfolding' is the same as the stored Expression.

# %%
# display the expression information
membershipUnfolding.exprInfo()
# Out:
# 0. forall_{x, A, B | x in (A - B)} ((x in A) and (x not-in B))
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> [forall_{A, B | x in (A - B)} ((x in A) and (x not-in B))]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{A, B | x in (A - B)} ((x in A) and (x not-in B))
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. A -> [forall_{B | x in (A - B)} ((x in A) and (x not-in B))]
#    core type: Lambda
#    parameter: 23
#    body: 4
# 4. forall_{B | x in (A - B)} ((x in A) and (x not-in B))
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. B -> ((x in A) and (x not-in B)) | x in (A - B)
#    core type: Lambda
#    parameter: 24
#    body: 7
#    conditions: 8\n7. (x in A) and (x not-in B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (x in (A - B))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (x in A , x not-in B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. x in (A - B)
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. x in A
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. x not-in B
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (x , A - B)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x , A)
#     core type: ExprTuple
#     sub-expressions: 20, 23
# 17. not-in
#     core type: Literal
#     sub-expressions:
# 18. (x , B)
#     core type: ExprTuple
#     sub-expressions: 20, 24
# 19. A - B
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (A , B)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. B
#     core type: Variable
#     sub-expressions:
