# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, x
from proveit.logic import Difference, Forall, InSet, NotInSet, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], NotInSet(x, Difference(A, B)), conditions = [Or(NotInSet(x, A), InSet(x, B))])
# Out:
# expr: forall_{A, B | (x not-in A) or (x in B)} (x not-in (A - B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B | (x not-in A) or (x in B)} (x not-in (A - B))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | (x not-in A) or (x in B)} (x not-in (A - B))]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{B | (x not-in A) or (x in B)} (x not-in (A - B))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (x not-in (A - B)) | (x not-in A) or (x in B)
#    core type: Lambda
#    parameter: 22
#    body: 5
#    conditions: 6\n5. x not-in (A - B)
#    core type: Operation
#    operator: 16
#    operands: 7
# 6. ((x not-in A) or (x in B))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x , A - B)
#    core type: ExprTuple
#    sub-expressions: 21, 9
# 8. (x not-in A) or (x in B)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. A - B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. or
#     core type: Literal
# ...
