# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#inAllButOne">inAllButOne</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.subtraction._theorems_ import inAllButOne

# %%
# check that the built expression is the same as the stored expression
# %check_expr inAllButOne
# Out:
# Passed sanity check: built 'inAllButOne' is the same as the stored Expression.

# %%
# display the expression information
inAllButOne.exprInfo()
# Out:
# 0. forall_{x, S, y} ((x in (S - {y})) <=> ((x in S) and (x != y)))
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. x -> [forall_{S, y} ((x in (S - {y})) <=> ((x in S) and (x != y)))]
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. forall_{S, y} ((x in (S - {y})) <=> ((x in S) and (x != y)))
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. S -> [forall_{y} ((x in (S - {y})) <=> ((x in S) and (x != y)))]
#    core type: Lambda
#    parameter: 25
#    body: 4
# 4. forall_{y} ((x in (S - {y})) <=> ((x in S) and (x != y)))
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. y -> ((x in (S - {y})) <=> ((x in S) and (x != y)))
#    core type: Lambda
#    parameter: 29
#    body: 7
# 7. (x in (S - {y})) <=> ((x in S) and (x != y))
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. <=>
#    core type: Literal
#    sub-expressions:
# ...
