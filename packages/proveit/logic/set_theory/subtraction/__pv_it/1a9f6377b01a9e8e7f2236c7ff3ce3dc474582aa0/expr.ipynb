# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, x
from proveit.logic import And, Difference, InSet, NotInSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Difference(A, B)), And(InSet(x, A), NotInSet(x, B)))
# Out:
# expr: (x in (A - B) , (x in A) and (x not-in B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in (A - B) , (x in A) and (x not-in B))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in (A - B)
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. (x in A) and (x not-in B)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x , A - B)
#    core type: ExprTuple
#    sub-expressions: 16, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (x in A , x not-in B)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. A - B
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. x in A
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. x not-in B
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x , A)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. not-in
#     core type: Literal
#     sub-expressions:
# 14. (x , B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
