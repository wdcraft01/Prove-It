# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, x
from proveit.logic import And, Difference, Forall, InSet, NotInSet

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], And(InSet(x, A), NotInSet(x, B)), conditions = [InSet(x, Difference(A, B))])
# Out:
# expr: forall_{A, B | x in (A - B)} ((x in A) and (x not-in B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B | x in (A - B)} ((x in A) and (x not-in B))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | x in (A - B)} ((x in A) and (x not-in B))]
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. forall_{B | x in (A - B)} ((x in A) and (x not-in B))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((x in A) and (x not-in B)) | x in (A - B)
#    core type: Lambda
#    parameter: 22
#    body: 5
#    conditions: 6\n5. (x in A) and (x not-in B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in (A - B))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in A , x not-in B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. x in (A - B)
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. x in A
#     core type: Operation
#     operator: 13
#     operands: 14
# ...
