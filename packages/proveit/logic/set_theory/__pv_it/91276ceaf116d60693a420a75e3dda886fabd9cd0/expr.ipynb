# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import InSet
from proveit.number import Interval, one

# %%
# build up the expression from sub-expressions
expr = Lambda(i, InSet(x, Indexed(AA, i, base = 1)), conditions = [InSet(i, Interval(one, m))])
# Out:
# expr: i -> (x in A_i) | i in {1...m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> (x in A_i) | i in {1...m}
#    core type: Lambda
#    parameter: 10
#    body: 1
#    conditions: 2\n1. x in A_i
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (x , A_i)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. i in {1...m}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. x
#    core type: Variable
#    sub-expressions:
# 6. A_i
#    core type: Indexed
#    var: 9
#    index: 10
#    base: "1"
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i , {1...m})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. {1...m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 1
# ...
