# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#each_x_in_S">each_x_in_S</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory</a>

# %%
# import the special expression
from proveit.logic.set_theory._common_ import each_x_in_S

# %%
# check that the built expression is the same as the stored expression
# %check_expr each_x_in_S
# Out:
# Passed sanity check: built 'each_x_in_S' is the same as the stored Expression.

# %%
# display the expression information
each_x_in_S.exprInfo()
# Out:
# 0. (x_1 in S),...,(x_n in S)
#    core type: Iter
#    lambda_map: 1
#    start_index: 15
#    end_index: 16
# 1. i -> (x_i in S) | i in {1...n}
#    core type: Lambda
#    parameter: 11
#    body: 2
#    conditions: 3\n2. x_i in S
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (i in {1...n})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (x_i , S)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. i in {1...n}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. x_i
#    core type: Indexed
#    var: 10
#    index: 11
#    base: "1"
# 7. S
#    core type: Variable
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i , {1...n})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. {1...n}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Interval
# ...
