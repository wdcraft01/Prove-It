# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iter_x_singletons">iter_x_singletons</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory</a>

# %%
# import the special expression
from proveit.logic.set_theory._common_ import iter_x_singletons

# %%
# check that the built expression is the same as the stored expression
# %check_expr iter_x_singletons
# Out:
# Passed sanity check: built 'iter_x_singletons' is the same as the stored Expression.

# %%
# display the expression information
iter_x_singletons.exprInfo()
# Out:
# 0. {x_1},...,{x_l}
#    core type: Iter
#    lambda_map: 1
#    start_index: 15
#    end_index: 16
# 1. i -> {x_i} | i in {1...l}
#    core type: Lambda
#    parameter: 11
#    body: 2
#    conditions: 3\n2. {x_i}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i in {1...l})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (x_i)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. i in {1...l}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. x_i
#    core type: Indexed
#    var: 10
#    index: 11
#    base: "1"
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i , {1...l})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. {1...l}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Interval
#     core type: Literal
#     sub-expressions:
# ...
