# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import i, l, x, yy
from proveit.logic import Equals, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Or(Iter(i, Equals(x, Indexed(yy, i, base = 1)), one, l))
# Out:
# expr: (x = y_1) or  ...  or (x = y_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x = y_1) or  ...  or (x = y_l)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. or
#    core type: Literal
#    sub-expressions:
# 2. (x = y_1 ,  ...  , x = y_l)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x = y_1),...,(x = y_l)
#    core type: Iter
#    lambda_map: 4
#    start_index: 19
#    end_index: 20
# 4. i -> (x = y_i) | i in {1...l}
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. x = y_i
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (i in {1...l})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x , y_i)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. i in {1...l}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. y_i
#     core type: Indexed
#     var: 14
#     index: 15
#     base: "1"
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (i , {1...l})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. y
#     core type: Variable
#     sub-expressions:
# 15. i
#     core type: Variable
#     sub-expressions:
# 16. {1...l}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. l
#     core type: Variable
#     sub-expressions:
