# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Distinct.html">Distinct</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import l, xx
from proveit.logic import Distinct
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Distinct(Iter(Variable("_x_", latexFormat = r"{_{-}x_{-}}"), Indexed(xx, Variable("_x_", latexFormat = r"{_{-}x_{-}}"), base = 1), one, l))
# Out:
# expr: distinct(x_1 ,  ...  , x_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. distinct(x_1 ,  ...  , x_l)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. distinct
#    core type: Literal
#    sub-expressions:
# 2. (x_1 ,  ...  , x_l)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x_1,...,x_l
#    core type: Iter
#    lambda_map: 4
#    start_index: 15
#    end_index: 16
# 4. _x_ -> x__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 11
#    body: 5
#    conditions: 6\n5. x__x_
#    core type: Indexed
#    var: 7
#    index: 11
#    base: "1"
# 6. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. x
#    core type: Variable
#    sub-expressions:
# 8. _x_ in {1...l}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. _x_
#     core type: Variable
#     sub-expressions:
# 12. {1...l}
#     core type: Operation
#     operator: 13
#     operands: 14
# ...
