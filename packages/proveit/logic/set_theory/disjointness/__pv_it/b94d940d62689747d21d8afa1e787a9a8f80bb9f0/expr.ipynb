# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, X
from proveit.logic import And, Disjoint, Forall, Iff, Set
from proveit.logic._common_ import iterA1m

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([B], Iff(Disjoint(iterA1m, B), And(Disjoint(iterA1m), Forall([X], Disjoint(X, B), domain = Set(iterA1m), conditions = subExpr1))).withWrappingAt(2), conditions = subExpr1)
# Out:
# expr: forall_{B} (disjoint(A_1 ,  ...  , A_m , B) <=>  \\ (disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)]))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B} (disjoint(A_1 ,  ...  , A_m , B) <=>  \\ (disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)]))
#    core type: Operation
#    operator: 12
#    operand: 1
# 1. B -> (disjoint(A_1 ,  ...  , A_m , B) <=>  \\ (disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)]))
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. disjoint(A_1 ,  ...  , A_m , B) <=>  \\ (disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)])
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. (disjoint(A_1 ,  ...  , A_m , B) , disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)])
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. disjoint(A_1 ,  ...  , A_m , B)
#    core type: Operation
#    operator: 16
#    operands: 7
# 6. disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A_1 ,  ...  , A_m , B)
#    core type: ExprTuple
#    sub-expressions: 25, 19
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (disjoint(A_1 ,  ...  , A_m) , forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. disjoint(A_1 ,  ...  , A_m)
#     core type: Operation
#     operator: 16
#     operands: 24
# 11. forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)
#     core type: Operation
#     operator: 12
#     operand: 13
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. X -> disjoint(X , B) | X in {A_1 ,  ...  , A_m}
#     core type: Lambda
#     parameter: 21
#     body: 14
#     conditions: 15\n14. disjoint(X , B)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (X in {A_1 ,  ...  , A_m})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. disjoint
#     core type: Literal
#     sub-expressions:
# 17. (X , B)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 18. X in {A_1 ,  ...  , A_m}
#     core type: Operation
#     operator: 31
#     operands: 20
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. (X , {A_1 ,  ...  , A_m})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. X
#     core type: Variable
#     sub-expressions:
# 22. {A_1 ,  ...  , A_m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 25
# 25. A_1,...,A_m
#     core type: Iter
#     lambda_map: 26
#     start_index: 37
#     end_index: 38
# 26. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 33
#     body: 27
#     conditions: 28\n27. A__x_
#     core type: Indexed
#     var: 29
#     index: 33
#     base: "1"
# 28. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 30
# 29. A
#     core type: Variable
#     sub-expressions:
# 30. _x_ in {1...m}
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. _x_
#     core type: Variable
#     sub-expressions:
# 34. {1...m}
#     core type: Operation
#     operator: 35
#     operands: 36
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
