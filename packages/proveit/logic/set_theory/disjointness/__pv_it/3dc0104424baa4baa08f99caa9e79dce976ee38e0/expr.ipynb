# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#disjointPairDef">disjointPairDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.disjointness._axioms_ import disjointPairDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr disjointPairDef
# Out:
# Passed sanity check: built 'disjointPairDef' is the same as the stored Expression.

# %%
# display the expression information
disjointPairDef.exprInfo()
# Out:
# 0. forall_{A, B} (disjoint(A , B) <=> ((A intersect B) = emptyset))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B} (disjoint(A , B) <=> ((A intersect B) = emptyset))]
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. forall_{B} (disjoint(A , B) <=> ((A intersect B) = emptyset))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (disjoint(A , B) <=> ((A intersect B) = emptyset))
#    core type: Lambda
#    parameter: 18
#    body: 5
# 5. disjoint(A , B) <=> ((A intersect B) = emptyset)
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. <=>
#    core type: Literal
#    sub-expressions:
# 7. (disjoint(A , B) , (A intersect B) = emptyset)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. disjoint(A , B)
#    core type: Operation
#    operator: 10
#    operands: 16
# 9. (A intersect B) = emptyset
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. disjoint
#     core type: Literal
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (A intersect B , emptyset)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A intersect B
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. emptyset
#     core type: Literal
#     sub-expressions:
# 15. intersect
#     core type: Literal
#     sub-expressions:
# 16. (A , B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
