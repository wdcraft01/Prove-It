# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import B, X
from proveit.logic import And, Disjoint, Forall, Set
from proveit.logic._common_ import iterA1m

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Disjoint(iterA1m, B), And(Disjoint(iterA1m), Forall([X], Disjoint(X, B), domain = Set(iterA1m), conditions = [])))
# Out:
# expr: (disjoint(A_1 ,  ...  , A_m , B) , disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (disjoint(A_1 ,  ...  , A_m , B) , disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. disjoint(A_1 ,  ...  , A_m , B)
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. disjoint(A_1 ,  ...  , A_m) and [forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A_1 ,  ...  , A_m , B)
#    core type: ExprTuple
#    sub-expressions: 21, 15
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (disjoint(A_1 ,  ...  , A_m) , forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. disjoint(A_1 ,  ...  , A_m)
#    core type: Operation
#    operator: 12
#    operands: 20
# 7. forall_{X in {A_1 ,  ...  , A_m}} disjoint(X , B)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. X -> disjoint(X , B) | X in {A_1 ,  ...  , A_m}
#    core type: Lambda
#    parameter: 17
#    body: 10
#    conditions: 11\n10. disjoint(X , B)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (X in {A_1 ,  ...  , A_m})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. disjoint
#     core type: Literal
#     sub-expressions:
# 13. (X , B)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 14. X in {A_1 ,  ...  , A_m}
#     core type: Operation
#     operator: 27
#     operands: 16
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. (X , {A_1 ,  ...  , A_m})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. X
#     core type: Variable
#     sub-expressions:
# 18. {A_1 ,  ...  , A_m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 21
# 21. A_1,...,A_m
#     core type: Iter
#     lambda_map: 22
#     start_index: 33
#     end_index: 34
# 22. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 29
#     body: 23
#     conditions: 24\n23. A__x_
#     core type: Indexed
#     var: 25
#     index: 29
#     base: "1"
# 24. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 26
# 25. A
#     core type: Variable
#     sub-expressions:
# 26. _x_ in {1...m}
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. _x_
#     core type: Variable
#     sub-expressions:
# 30. {1...m}
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. Interval
#     core type: Literal
#     sub-expressions:
# 32. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. m
#     core type: Variable
#     sub-expressions:
