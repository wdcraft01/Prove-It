# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#distinctDef">distinctDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.disjointness._axioms_ import distinctDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr distinctDef
# Out:
# Passed sanity check: built 'distinctDef' is the same as the stored Expression.

# %%
# display the expression information
distinctDef.exprInfo()
# Out:
# 0. forall_{l in NaturalsPos} [forall_{x_1,...,x_l} (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. l -> [forall_{x_1,...,x_l} (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))] | l in NaturalsPos
#    core type: Lambda
#    parameter: 41
#    body: 2
#    conditions: 3\n2. forall_{x_1,...,x_l} (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x_1,...,x_l) -> (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))
#    core type: Lambda
#    parameter: 18
#    body: 7
# 6. l in NaturalsPos
#    core type: Operation
#    operator: 32
#    operands: 8
# 7. distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (l , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 41, 11
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (distinct(x_1 ,  ...  , x_l) , disjoint({x_1} ,  ...  , {x_l}))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 12. distinct(x_1 ,  ...  , x_l)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. disjoint({x_1} ,  ...  , {x_l})
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. distinct
#     core type: Literal
#     sub-expressions:
# 15. (x_1 ,  ...  , x_l)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. disjoint
#     core type: Literal
#     sub-expressions:
# 17. ({x_1} ,  ...  , {x_l})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. x_1,...,x_l
#     core type: Iter
#     lambda_map: 20
#     start_index: 40
#     end_index: 41
# 19. {x_1},...,{x_l}
#     core type: Iter
#     lambda_map: 21
#     start_index: 40
#     end_index: 41
# 20. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 34
#     body: 22
#     conditions: 23\n21. i -> {x_i} | i in {1...l}
#     core type: Lambda
#     parameter: 36
#     body: 24
#     conditions: 25\n22. x__x_
#     core type: Indexed
#     var: 35
#     index: 34
#     base: "1"
# 23. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. {x_i}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (i in {1...l})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. _x_ in {1...l}
#     core type: Operation
#     operator: 32
#     operands: 30
# 27. Set
#     core type: Literal
#     sub-expressions:
# 28. (x_i)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. i in {1...l}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 34, 37
# 31. x_i
#     core type: Indexed
#     var: 35
#     index: 36
#     base: "1"
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (i , {1...l})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. _x_
#     core type: Variable
#     sub-expressions:
# 35. x
#     core type: Variable
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. {1...l}
#     core type: Operation
#     operator: 38
#     operands: 39
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. l
#     core type: Variable
#     sub-expressions:
