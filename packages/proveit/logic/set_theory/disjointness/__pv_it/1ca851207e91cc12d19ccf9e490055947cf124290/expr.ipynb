# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, X
from proveit.logic import Disjoint, InSet, Set
from proveit.logic._common_ import iterA1m

# %%
# build up the expression from sub-expressions
expr = Lambda(X, Disjoint(X, B), conditions = [InSet(X, Set(iterA1m))])
# Out:
# expr: X -> disjoint(X , B) | X in {A_1 ,  ...  , A_m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. X -> disjoint(X , B) | X in {A_1 ,  ...  , A_m}
#    core type: Lambda
#    parameter: 8
#    body: 1
#    conditions: 2\n1. disjoint(X , B)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (X in {A_1 ,  ...  , A_m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. disjoint
#    core type: Literal
#    sub-expressions:
# 4. (X , B)
#    core type: ExprTuple
#    sub-expressions: 8, 6
# 5. X in {A_1 ,  ...  , A_m}
#    core type: Operation
#    operator: 18
#    operands: 7
# 6. B
#    core type: Variable
#    sub-expressions:
# 7. (X , {A_1 ,  ...  , A_m})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. X
#    core type: Variable
#    sub-expressions:
# 9. {A_1 ,  ...  , A_m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Set
#     core type: Literal
#     sub-expressions:
# 11. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. A_1,...,A_m
#     core type: Iter
#     lambda_map: 13
#     start_index: 24
#     end_index: 25
# 13. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 20
#     body: 14
#     conditions: 15\n14. A__x_
#     core type: Indexed
#     var: 16
#     index: 20
#     base: "1"
# 15. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. _x_ in {1...m}
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. _x_
#     core type: Variable
#     sub-expressions:
# 21. {1...m}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. m
#     core type: Variable
#     sub-expressions:
