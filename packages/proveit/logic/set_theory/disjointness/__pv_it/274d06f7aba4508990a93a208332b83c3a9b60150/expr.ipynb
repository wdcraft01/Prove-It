# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import l, xx
from proveit.logic import Disjoint, Distinct, Equals
from proveit.logic.set_theory._common_ import iter_x_singletons
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Equals(Distinct(Iter(Variable("_x_", latexFormat = r"{_{-}x_{-}}"), Indexed(xx, Variable("_x_", latexFormat = r"{_{-}x_{-}}"), base = 1), one, l)), Disjoint(iter_x_singletons))
# Out:
# expr: distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (distinct(x_1 ,  ...  , x_l) , disjoint({x_1} ,  ...  , {x_l}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. distinct(x_1 ,  ...  , x_l)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. disjoint({x_1} ,  ...  , {x_l})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. distinct
#    core type: Literal
#    sub-expressions:
# 6. (x_1 ,  ...  , x_l)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. disjoint
#    core type: Literal
#    sub-expressions:
# 8. ({x_1} ,  ...  , {x_l})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. x_1,...,x_l
#    core type: Iter
#    lambda_map: 11
#    start_index: 31
#    end_index: 32
# 10. {x_1},...,{x_l}
#     core type: Iter
#     lambda_map: 12
#     start_index: 31
#     end_index: 32
# ...
