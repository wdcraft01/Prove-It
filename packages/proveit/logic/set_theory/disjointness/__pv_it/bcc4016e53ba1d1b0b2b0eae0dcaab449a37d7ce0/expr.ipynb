# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.disjointness</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda, Variable
from proveit._common_ import l, xx
from proveit.logic import Disjoint, Distinct, Equals, Forall, InSet
from proveit.logic.set_theory._common_ import iter_x_singletons
from proveit.number import NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Forall([Iter(Variable("_x_", latexFormat = r"{_{-}x_{-}}"), Indexed(xx, Variable("_x_", latexFormat = r"{_{-}x_{-}}"), base = 1), one, l)], Equals(Distinct(Iter(Variable("_x_", latexFormat = r"{_{-}x_{-}}"), Indexed(xx, Variable("_x_", latexFormat = r"{_{-}x_{-}}"), base = 1), one, l)), Disjoint(iter_x_singletons)), conditions = []), conditions = [InSet(l, NaturalsPos)])
# Out:
# expr: l -> [forall_{x_1,...,x_l} (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))] | l in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{x_1,...,x_l} (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))] | l in NaturalsPos
#    core type: Lambda
#    parameter: 40
#    body: 1
#    conditions: 2\n1. forall_{x_1,...,x_l} (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x_1,...,x_l) -> (distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l}))
#    core type: Lambda
#    parameter: 17
#    body: 6
# 5. l in NaturalsPos
#    core type: Operation
#    operator: 31
#    operands: 7
# 6. distinct(x_1 ,  ...  , x_l) = disjoint({x_1} ,  ...  , {x_l})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (l , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 40, 10
# 8. =
#    core type: Literal
#    sub-expressions:
# ...
