# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import Equals, InSet, Or, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(iterA1m, Equals(InSet(x, Union(iterA1m)), Or(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m))))
# Out:
# expr: (A_1,...,A_m) -> ((x in (A_1 union  ...  union A_m)) = ((x in A_1) or  ...  or (x in A_m)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1,...,A_m) -> ((x in (A_1 union  ...  union A_m)) = ((x in A_1) or  ...  or (x in A_m)))
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. (x in (A_1 union  ...  union A_m)) = ((x in A_1) or  ...  or (x in A_m))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (x in (A_1 union  ...  union A_m) , (x in A_1) or  ...  or (x in A_m))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 28
#    operands: 6
# 5. (x in A_1) or  ...  or (x in A_m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x , A_1 union  ...  union A_m)
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (x in A_1 ,  ...  , x in A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A_1 union  ...  union A_m
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x in A_1),...,(x in A_m)
#     core type: Iter
#     lambda_map: 13
#     start_index: 34
#     end_index: 35
# 11. union
#     core type: Literal
#     sub-expressions:
# 12. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 27
#     body: 15
#     conditions: 16\n14. A_1,...,A_m
#     core type: Iter
#     lambda_map: 17
#     start_index: 34
#     end_index: 35
# 15. x in A_i
#     core type: Operation
#     operator: 28
#     operands: 18
# 16. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 19
# 17. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 30
#     body: 20
#     conditions: 21\n18. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. i in {1...m}
#     core type: Operation
#     operator: 28
#     operands: 24
# 20. A__x_
#     core type: Indexed
#     var: 26
#     index: 30
#     base: "1"
# 21. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. A_i
#     core type: Indexed
#     var: 26
#     index: 27
#     base: "1"
# 24. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 27, 31
# 25. _x_ in {1...m}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. A
#     core type: Variable
#     sub-expressions:
# 27. i
#     core type: Variable
#     sub-expressions:
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. _x_
#     core type: Variable
#     sub-expressions:
# 31. {1...m}
#     core type: Operation
#     operator: 32
#     operands: 33
# 32. Interval
#     core type: Literal
#     sub-expressions:
# 33. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. m
#     core type: Variable
#     sub-expressions:
