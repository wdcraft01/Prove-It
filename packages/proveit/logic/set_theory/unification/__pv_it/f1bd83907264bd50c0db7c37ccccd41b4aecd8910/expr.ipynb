# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import And, NotInSet, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(iterA1m, NotInSet(x, Union(iterA1m)), conditions = [And(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m))])
# Out:
# expr: (A_1,...,A_m) -> (x not-in (A_1 union  ...  union A_m)) | (x not-in A_1) and  ...  and (x not-in A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1,...,A_m) -> (x not-in (A_1 union  ...  union A_m)) | (x not-in A_1) and  ...  and (x not-in A_m)
#    core type: Lambda
#    parameter: 11
#    body: 1
#    conditions: 2\n1. x not-in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 18
#    operands: 3
# 2. ((x not-in A_1) and  ...  and (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (x , A_1 union  ...  union A_m)
#    core type: ExprTuple
#    sub-expressions: 22, 5
# 4. (x not-in A_1) and  ...  and (x not-in A_m)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. A_1 union  ...  union A_m
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x not-in A_1 ,  ...  , x not-in A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. union
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (x not-in A_1),...,(x not-in A_m)
# ...
