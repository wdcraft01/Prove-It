# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Equals, Forall, NotInSet, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([iterA1m], Equals(NotInSet(x, Union(iterA1m)), And(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m))), conditions = []))
# Out:
# expr: x -> [forall_{A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))]
#    core type: Lambda
#    parameter: 26
#    body: 1
# 1. forall_{A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. (A_1,...,A_m) -> ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. (x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x not-in (A_1 union  ...  union A_m) , (x not-in A_1) and  ...  and (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x not-in (A_1 union  ...  union A_m)
#    core type: Operation
# ...
