# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Equals, NotInSet, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(iterA1m, Equals(NotInSet(x, Union(iterA1m)), And(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m))))
# Out:
# expr: (A_1,...,A_m) -> ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1,...,A_m) -> ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. (x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (x not-in (A_1 union  ...  union A_m) , (x not-in A_1) and  ...  and (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x not-in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 18
#    operands: 6
# 5. (x not-in A_1) and  ...  and (x not-in A_m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x , A_1 union  ...  union A_m)
#    core type: ExprTuple
#    sub-expressions: 23, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x not-in A_1 ,  ...  , x not-in A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A_1 union  ...  union A_m
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x not-in A_1),...,(x not-in A_m)
#     core type: Iter
#     lambda_map: 13
#     start_index: 35
#     end_index: 36
# 11. union
#     core type: Literal
#     sub-expressions:
# 12. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. i -> (x not-in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 28
#     body: 15
#     conditions: 16\n14. A_1,...,A_m
#     core type: Iter
#     lambda_map: 17
#     start_index: 35
#     end_index: 36
# 15. x not-in A_i
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 20
# 17. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 31
#     body: 21
#     conditions: 22\n18. not-in
#     core type: Literal
#     sub-expressions:
# 19. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. i in {1...m}
#     core type: Operation
#     operator: 29
#     operands: 25
# 21. A__x_
#     core type: Indexed
#     var: 27
#     index: 31
#     base: "1"
# 22. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. A_i
#     core type: Indexed
#     var: 27
#     index: 28
#     base: "1"
# 25. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 28, 32
# 26. _x_ in {1...m}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. i
#     core type: Variable
#     sub-expressions:
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. _x_
#     core type: Variable
#     sub-expressions:
# 32. {1...m}
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. Interval
#     core type: Literal
#     sub-expressions:
# 34. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. m
#     core type: Variable
#     sub-expressions:
