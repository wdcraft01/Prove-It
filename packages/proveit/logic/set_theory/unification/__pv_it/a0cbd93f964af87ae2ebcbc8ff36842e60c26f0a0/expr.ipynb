# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import InSet, Or, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, Union(iterA1m)), Or(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m)))
# Out:
# expr: (x in (A_1 union  ...  union A_m) , (x in A_1) or  ...  or (x in A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in (A_1 union  ...  union A_m) , (x in A_1) or  ...  or (x in A_m))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 25
#    operands: 3
# 2. (x in A_1) or  ...  or (x in A_m)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x , A_1 union  ...  union A_m)
#    core type: ExprTuple
#    sub-expressions: 19, 6
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (x in A_1 ,  ...  , x in A_m)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_1 union  ...  union A_m
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in A_1),...,(x in A_m)
#    core type: Iter
#    lambda_map: 10
#    start_index: 31
#    end_index: 32
# 8. union
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 24
#     body: 12
# ...
