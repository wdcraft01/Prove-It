# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Forall, NotInSet, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([x, iterA1m], NotInSet(x, Union(iterA1m)), conditions = [And(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m))])
# Out:
# expr: forall_{x, A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))]
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. forall_{A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_1,...,A_m) -> (x not-in (A_1 union  ...  union A_m)) | (x not-in A_1) and  ...  and (x not-in A_m)
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. x not-in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. ((x not-in A_1) and  ...  and (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x , A_1 union  ...  union A_m)
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 8. (x not-in A_1) and  ...  and (x not-in A_m)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. A_1 union  ...  union A_m
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (x not-in A_1 ,  ...  , x not-in A_m)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. union
#     core type: Literal
#     sub-expressions:
# 13. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (x not-in A_1),...,(x not-in A_m)
#     core type: Iter
#     lambda_map: 16
#     start_index: 37
#     end_index: 38
# 15. A_1,...,A_m
#     core type: Iter
#     lambda_map: 17
#     start_index: 37
#     end_index: 38
# 16. i -> (x not-in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 32
#     body: 18
#     conditions: 19\n17. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 33
#     body: 20
#     conditions: 21\n18. x not-in A_i
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 24
# 20. A__x_
#     core type: Indexed
#     var: 31
#     index: 33
#     base: "1"
# 21. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. not-in
#     core type: Literal
#     sub-expressions:
# 23. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. i in {1...m}
#     core type: Operation
#     operator: 29
#     operands: 28
# 25. _x_ in {1...m}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. A_i
#     core type: Indexed
#     var: 31
#     index: 32
#     base: "1"
# 28. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. A
#     core type: Variable
#     sub-expressions:
# 32. i
#     core type: Variable
#     sub-expressions:
# 33. _x_
#     core type: Variable
#     sub-expressions:
# 34. {1...m}
#     core type: Operation
#     operator: 35
#     operands: 36
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
