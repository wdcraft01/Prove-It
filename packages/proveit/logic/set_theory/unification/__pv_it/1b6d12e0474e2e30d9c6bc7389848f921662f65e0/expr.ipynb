# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import Forall, InSet, Or, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([iterA1m], InSet(x, Union(iterA1m)), conditions = [Or(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m))]))
# Out:
# expr: x -> [forall_{A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))]
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. forall_{A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. (A_1,...,A_m) -> (x in (A_1 union  ...  union A_m)) | (x in A_1) or  ...  or (x in A_m)
#    core type: Lambda
#    parameter: 14
#    body: 4
#    conditions: 5\n4. x in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 27
#    operands: 6
# 5. ((x in A_1) or  ...  or (x in A_m))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x , A_1 union  ...  union A_m)
#    core type: ExprTuple
#    sub-expressions: 24, 8
# 7. (x in A_1) or  ...  or (x in A_m)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. A_1 union  ...  union A_m
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (x in A_1 ,  ...  , x in A_m)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. union
#     core type: Literal
#     sub-expressions:
# 12. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (x in A_1),...,(x in A_m)
#     core type: Iter
#     lambda_map: 15
#     start_index: 35
#     end_index: 36
# 14. A_1,...,A_m
#     core type: Iter
#     lambda_map: 16
#     start_index: 35
#     end_index: 36
# 15. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 30
#     body: 17
#     conditions: 18\n16. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 31
#     body: 19
#     conditions: 20\n17. x in A_i
#     core type: Operation
#     operator: 27
#     operands: 21
# 18. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. A__x_
#     core type: Indexed
#     var: 29
#     index: 31
#     base: "1"
# 20. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. i in {1...m}
#     core type: Operation
#     operator: 27
#     operands: 26
# 23. _x_ in {1...m}
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. A_i
#     core type: Indexed
#     var: 29
#     index: 30
#     base: "1"
# 26. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. A
#     core type: Variable
#     sub-expressions:
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. _x_
#     core type: Variable
#     sub-expressions:
# 32. {1...m}
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. Interval
#     core type: Literal
#     sub-expressions:
# 34. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. m
#     core type: Variable
#     sub-expressions:
