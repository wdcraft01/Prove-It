# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nonmembershipEquiv">nonmembershipEquiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.unification._theorems_ import nonmembershipEquiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr nonmembershipEquiv
# Out:
# Passed sanity check: built 'nonmembershipEquiv' is the same as the stored Expression.

# %%
# display the expression information
nonmembershipEquiv.exprInfo()
# Out:
# 0. forall_{m in NaturalsPos} [forall_{x, A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))]
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. m -> [forall_{x, A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))] | m in NaturalsPos
#    core type: Lambda
#    parameter: 46
#    body: 2
#    conditions: 3\n2. forall_{x, A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))]
#    core type: Lambda
#    parameter: 33
#    body: 6
# 5. m in NaturalsPos
#    core type: Operation
#    operator: 39
#    operands: 7
# 6. forall_{A_1,...,A_m} ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (m , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 46, 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (A_1,...,A_m) -> ((x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m)))
#    core type: Lambda
#    parameter: 24
#    body: 11
# 10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. (x not-in (A_1 union  ...  union A_m)) = ((x not-in A_1) and  ...  and (x not-in A_m))
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x not-in (A_1 union  ...  union A_m) , (x not-in A_1) and  ...  and (x not-in A_m))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x not-in (A_1 union  ...  union A_m)
#     core type: Operation
#     operator: 28
#     operands: 16
# 15. (x not-in A_1) and  ...  and (x not-in A_m)
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x , A_1 union  ...  union A_m)
#     core type: ExprTuple
#     sub-expressions: 33, 19
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x not-in A_1 ,  ...  , x not-in A_m)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. A_1 union  ...  union A_m
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (x not-in A_1),...,(x not-in A_m)
#     core type: Iter
#     lambda_map: 23
#     start_index: 45
#     end_index: 46
# 21. union
#     core type: Literal
#     sub-expressions:
# 22. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. i -> (x not-in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 38
#     body: 25
#     conditions: 26\n24. A_1,...,A_m
#     core type: Iter
#     lambda_map: 27
#     start_index: 45
#     end_index: 46
# 25. x not-in A_i
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 30
# 27. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 41
#     body: 31
#     conditions: 32\n28. not-in
#     core type: Literal
#     sub-expressions:
# 29. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30. i in {1...m}
#     core type: Operation
#     operator: 39
#     operands: 35
# 31. A__x_
#     core type: Indexed
#     var: 37
#     index: 41
#     base: "1"
# 32. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 36
# 33. x
#     core type: Variable
#     sub-expressions:
# 34. A_i
#     core type: Indexed
#     var: 37
#     index: 38
#     base: "1"
# 35. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 38, 42
# 36. _x_ in {1...m}
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. A
#     core type: Variable
#     sub-expressions:
# 38. i
#     core type: Variable
#     sub-expressions:
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. _x_
#     core type: Variable
#     sub-expressions:
# 42. {1...m}
#     core type: Operation
#     operator: 43
#     operands: 44
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. m
#     core type: Variable
#     sub-expressions:
