# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import Forall, InSet, Or, Union
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([x, iterA1m], Or(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m)), conditions = [InSet(x, Union(iterA1m))])
# Out:
# expr: forall_{x, A_1,...,A_m | x in (A_1 union  ...  union A_m)} ((x in A_1) or  ...  or (x in A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, A_1,...,A_m | x in (A_1 union  ...  union A_m)} ((x in A_1) or  ...  or (x in A_m))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{A_1,...,A_m | x in (A_1 union  ...  union A_m)} ((x in A_1) or  ...  or (x in A_m))]
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. forall_{A_1,...,A_m | x in (A_1 union  ...  union A_m)} ((x in A_1) or  ...  or (x in A_m))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_1,...,A_m) -> ((x in A_1) or  ...  or (x in A_m)) | x in (A_1 union  ...  union A_m)
#    core type: Lambda
#    parameter: 20
#    body: 5
#    conditions: 6\n5. (x in A_1) or  ...  or (x in A_m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in (A_1 union  ...  union A_m))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (x in A_1 ,  ...  , x in A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. x in (A_1 union  ...  union A_m)
#    core type: Operation
#    operator: 30
#    operands: 11
# 10. (x in A_1),...,(x in A_m)
#     core type: Iter
#     lambda_map: 12
#     start_index: 36
#     end_index: 37
# 11. (x , A_1 union  ...  union A_m)
#     core type: ExprTuple
#     sub-expressions: 21, 13
# 12. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 25
#     body: 14
#     conditions: 15\n13. A_1 union  ...  union A_m
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. x in A_i
#     core type: Operation
#     operator: 30
#     operands: 18
# 15. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. union
#     core type: Literal
#     sub-expressions:
# 17. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. i in {1...m}
#     core type: Operation
#     operator: 30
#     operands: 23
# 20. A_1,...,A_m
#     core type: Iter
#     lambda_map: 24
#     start_index: 36
#     end_index: 37
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. A_i
#     core type: Indexed
#     var: 28
#     index: 25
#     base: "1"
# 23. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 25, 33
# 24. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 32
#     body: 26
#     conditions: 27\n25. i
#     core type: Variable
#     sub-expressions:
# 26. A__x_
#     core type: Indexed
#     var: 28
#     index: 32
#     base: "1"
# 27. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 29
# 28. A
#     core type: Variable
#     sub-expressions:
# 29. _x_ in {1...m}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. _x_
#     core type: Variable
#     sub-expressions:
# 33. {1...m}
#     core type: Operation
#     operator: 34
#     operands: 35
# 34. Interval
#     core type: Literal
#     sub-expressions:
# 35. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
