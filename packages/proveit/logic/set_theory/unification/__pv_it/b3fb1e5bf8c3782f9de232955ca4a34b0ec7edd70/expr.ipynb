# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, x
from proveit.logic import InSet, Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Or(InSet(x, A), InSet(x, B), InSet(x, C)))
# Out:
# expr: ((x in A) or (x in B) or (x in C))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((x in A) or (x in B) or (x in C))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x in A) or (x in B) or (x in C)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. or
#    core type: Literal
#    sub-expressions:
# 3. (x in A , x in B , x in C)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. x in A
#    core type: Operation
#    operator: 9
#    operands: 7
# 5. x in B
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. x in C
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (x , A)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 8. (x , B)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , C)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. C
#     core type: Variable
#     sub-expressions:
