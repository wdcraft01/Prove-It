# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import Forall, InSet, Or, Union
from proveit.logic._common_ import iterA1m
from proveit.number import NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([x, iterA1m], InSet(x, Union(iterA1m)), conditions = [Or(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m))]), conditions = [InSet(m, NaturalsPos)])
# Out:
# expr: m -> [forall_{x, A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))] | m in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{x, A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))] | m in NaturalsPos
#    core type: Lambda
#    parameter: 42
#    body: 1
#    conditions: 2\n1. forall_{x, A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. x -> [forall_{A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))]
#    core type: Lambda
#    parameter: 30
#    body: 5
# 4. m in NaturalsPos
#    core type: Operation
#    operator: 33
#    operands: 6
# 5. forall_{A_1,...,A_m | (x in A_1) or  ...  or (x in A_m)} (x in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (m , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 42, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (A_1,...,A_m) -> (x in (A_1 union  ...  union A_m)) | (x in A_1) or  ...  or (x in A_m)
#    core type: Lambda
#    parameter: 20
#    body: 10
#    conditions: 11\n9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. x in (A_1 union  ...  union A_m)
#     core type: Operation
#     operator: 33
#     operands: 12
# 11. ((x in A_1) or  ...  or (x in A_m))
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (x , A_1 union  ...  union A_m)
#     core type: ExprTuple
#     sub-expressions: 30, 14
# 13. (x in A_1) or  ...  or (x in A_m)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. A_1 union  ...  union A_m
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (x in A_1 ,  ...  , x in A_m)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. union
#     core type: Literal
#     sub-expressions:
# 18. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. (x in A_1),...,(x in A_m)
#     core type: Iter
#     lambda_map: 21
#     start_index: 41
#     end_index: 42
# 20. A_1,...,A_m
#     core type: Iter
#     lambda_map: 22
#     start_index: 41
#     end_index: 42
# 21. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 36
#     body: 23
#     conditions: 24\n22. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 37
#     body: 25
#     conditions: 26\n23. x in A_i
#     core type: Operation
#     operator: 33
#     operands: 27
# 24. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 28
# 25. A__x_
#     core type: Indexed
#     var: 35
#     index: 37
#     base: "1"
# 26. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 29
# 27. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. i in {1...m}
#     core type: Operation
#     operator: 33
#     operands: 32
# 29. _x_ in {1...m}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. A_i
#     core type: Indexed
#     var: 35
#     index: 36
#     base: "1"
# 32. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 36, 38
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. A
#     core type: Variable
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. _x_
#     core type: Variable
#     sub-expressions:
# 38. {1...m}
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. Interval
#     core type: Literal
#     sub-expressions:
# 40. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. m
#     core type: Variable
#     sub-expressions:
