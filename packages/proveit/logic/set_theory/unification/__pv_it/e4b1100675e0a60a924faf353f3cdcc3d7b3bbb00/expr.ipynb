# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nonmembershipFolding">nonmembershipFolding</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.unification</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.unification._theorems_ import nonmembershipFolding

# %%
# check that the built expression is the same as the stored expression
# %check_expr nonmembershipFolding
# Out:
# Passed sanity check: built 'nonmembershipFolding' is the same as the stored Expression.

# %%
# display the expression information
nonmembershipFolding.exprInfo()
# Out:
# 0. forall_{m in NaturalsPos} [forall_{x, A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))]
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. m -> [forall_{x, A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))] | m in NaturalsPos
#    core type: Lambda
#    parameter: 44
#    body: 2
#    conditions: 3\n2. forall_{x, A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))]
#    core type: Lambda
#    parameter: 32
#    body: 6
# 5. m in NaturalsPos
#    core type: Operation
#    operator: 35
#    operands: 7
# 6. forall_{A_1,...,A_m | (x not-in A_1) and  ...  and (x not-in A_m)} (x not-in (A_1 union  ...  union A_m))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (m , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 44, 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (A_1,...,A_m) -> (x not-in (A_1 union  ...  union A_m)) | (x not-in A_1) and  ...  and (x not-in A_m)
#    core type: Lambda
#    parameter: 21
#    body: 11
#    conditions: 12\n10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. x not-in (A_1 union  ...  union A_m)
#     core type: Operation
#     operator: 28
#     operands: 13
# 12. ((x not-in A_1) and  ...  and (x not-in A_m))
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (x , A_1 union  ...  union A_m)
#     core type: ExprTuple
#     sub-expressions: 32, 15
# 14. (x not-in A_1) and  ...  and (x not-in A_m)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. A_1 union  ...  union A_m
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (x not-in A_1 ,  ...  , x not-in A_m)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. union
#     core type: Literal
#     sub-expressions:
# 19. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. (x not-in A_1),...,(x not-in A_m)
#     core type: Iter
#     lambda_map: 22
#     start_index: 43
#     end_index: 44
# 21. A_1,...,A_m
#     core type: Iter
#     lambda_map: 23
#     start_index: 43
#     end_index: 44
# 22. i -> (x not-in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 38
#     body: 24
#     conditions: 25\n23. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 39
#     body: 26
#     conditions: 27\n24. x not-in A_i
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. A__x_
#     core type: Indexed
#     var: 37
#     index: 39
#     base: "1"
# 27. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. not-in
#     core type: Literal
#     sub-expressions:
# 29. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. i in {1...m}
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. _x_ in {1...m}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. A_i
#     core type: Indexed
#     var: 37
#     index: 38
#     base: "1"
# 34. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 38, 40
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. A
#     core type: Variable
#     sub-expressions:
# 38. i
#     core type: Variable
#     sub-expressions:
# 39. _x_
#     core type: Variable
#     sub-expressions:
# 40. {1...m}
#     core type: Operation
#     operator: 41
#     operands: 42
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. m
#     core type: Variable
#     sub-expressions:
