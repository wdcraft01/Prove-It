# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f
from proveit.logic import Forall, InSet
from proveit.number import Exp, six

# %%
# build up the expression from sub-expressions
expr = Forall([f], InSet([a, b, c, d, e, f], Exp(S, six)), domain = S, conditions = [])
# Out:
# expr: forall_{f in S} ((a , b , c , d , e , f) in S^{6})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f in S} ((a , b , c , d , e , f) in S^{6})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. f -> ((a , b , c , d , e , f) in S^{6}) | f in S
#    core type: Lambda
#    parameter: 18
#    body: 3
#    conditions: 4\n3. (a , b , c , d , e , f) in S^{6}
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (f in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((a , b , c , d , e , f) , S^{6})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. f in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (a , b , c , d , e , f)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15, 18
# 8. S^{6}
#    core type: Operation
#    operator: 16
#    operands: 17
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (f , S)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (S , 6)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. f
#     core type: Variable
#     sub-expressions:
# 19. S
#     core type: Variable
#     sub-expressions:
# 20. 6
#     core type: Literal
#     sub-expressions:
