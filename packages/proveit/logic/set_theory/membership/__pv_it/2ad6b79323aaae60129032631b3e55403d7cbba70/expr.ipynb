# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c, d, e, f
from proveit.logic import Forall, InSet
from proveit.number import Exp, six

# %%
# build up the expression from sub-expressions
expr = Lambda(c, Forall([d, e, f], InSet([a, b, c, d, e, f], Exp(S, six)), domain = S, conditions = []), conditions = [InSet(c, S)])
# Out:
# expr: c -> [forall_{d, e, f in S} ((a , b , c , d , e , f) in S^{6})] | c in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> [forall_{d, e, f in S} ((a , b , c , d , e , f) in S^{6})] | c in S
#    core type: Lambda
#    parameter: 27
#    body: 1
#    conditions: 2\n1. forall_{d, e, f in S} ((a , b , c , d , e , f) in S^{6})
#    core type: Operation
#    operator: 13
#    operand: 3
# 2. (c in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. d -> [forall_{e, f in S} ((a , b , c , d , e , f) in S^{6})] | d in S
#    core type: Lambda
#    parameter: 28
#    body: 5
#    conditions: 6\n4. c in S
#    core type: Operation
#    operator: 23
#    operands: 7
# 5. forall_{e, f in S} ((a , b , c , d , e , f) in S^{6})
#    core type: Operation
#    operator: 13
#    operand: 8
# 6. (d in S)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (c , S)
#    core type: ExprTuple
#    sub-expressions: 27, 33
# 8. e -> [forall_{f in S} ((a , b , c , d , e , f) in S^{6})] | e in S
#    core type: Lambda
#    parameter: 29
#    body: 10
#    conditions: 11\n9. d in S
#    core type: Operation
#    operator: 23
#    operands: 12
# 10. forall_{f in S} ((a , b , c , d , e , f) in S^{6})
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. (e in S)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (d , S)
#     core type: ExprTuple
#     sub-expressions: 28, 33
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. f -> ((a , b , c , d , e , f) in S^{6}) | f in S
#     core type: Lambda
#     parameter: 32
#     body: 16
#     conditions: 17\n15. e in S
#     core type: Operation
#     operator: 23
#     operands: 18
# 16. (a , b , c , d , e , f) in S^{6}
#     core type: Operation
#     operator: 23
#     operands: 19
# 17. (f in S)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (e , S)
#     core type: ExprTuple
#     sub-expressions: 29, 33
# 19. ((a , b , c , d , e , f) , S^{6})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. f in S
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (a , b , c , d , e , f)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28, 29, 32
# 22. S^{6}
#     core type: Operation
#     operator: 30
#     operands: 31
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (f , S)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
# 27. c
#     core type: Variable
#     sub-expressions:
# 28. d
#     core type: Variable
#     sub-expressions:
# 29. e
#     core type: Variable
#     sub-expressions:
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (S , 6)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. f
#     core type: Variable
#     sub-expressions:
# 33. S
#     core type: Variable
#     sub-expressions:
# 34. 6
#     core type: Literal
#     sub-expressions:
