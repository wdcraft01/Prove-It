# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#exp_set_9">exp_set_9</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.membership._theorems_ import exp_set_9

# %%
# check that the built expression is the same as the stored expression
# %check_expr exp_set_9
# Out:
# Passed sanity check: built 'exp_set_9' is the same as the stored Expression.

# %%
# display the expression information
exp_set_9.exprInfo()
# Out:
# 0. forall_{S} [forall_{a, b, c, d, e, f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})]
#    core type: Operation
#    operator: 41
#    operand: 1
# 1. S -> [forall_{a, b, c, d, e, f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})]
#    core type: Lambda
#    parameter: 64
#    body: 2
# 2. forall_{a, b, c, d, e, f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})
#    core type: Operation
#    operator: 41
#    operand: 3
# 3. a -> [forall_{b, c, d, e, f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})] | a in S
#    core type: Lambda
#    parameter: 53
#    body: 4
#    conditions: 5\n4. forall_{b, c, d, e, f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})
#    core type: Operation
#    operator: 41
#    operand: 6
# 5. (a in S)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. b -> [forall_{c, d, e, f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})] | b in S
#    core type: Lambda
# ...
