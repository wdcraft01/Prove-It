# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E, F, S
from proveit.logic import InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(A, S), InSet(B, S), InSet(C, S), InSet(D, S), InSet(E, S), InSet(F, S))
# Out:
# expr: {A in S , B in S , C in S , D in S , E in S , F in S}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A in S , B in S , C in S , D in S , E in S , F in S}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A in S , B in S , C in S , D in S , E in S , F in S)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8
# 3. A in S
#    core type: Operation
#    operator: 14
#    operands: 9
# 4. B in S
#    core type: Operation
#    operator: 14
#    operands: 10
# 5. C in S
#    core type: Operation
#    operator: 14
#    operands: 11
# 6. D in S
#    core type: Operation
#    operator: 14
#    operands: 12
# 7. E in S
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. F in S
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. (A , S)
#    core type: ExprTuple
#    sub-expressions: 16, 22
# 10. (B , S)
#     core type: ExprTuple
#     sub-expressions: 17, 22
# 11. (C , S)
#     core type: ExprTuple
#     sub-expressions: 18, 22
# 12. (D , S)
#     core type: ExprTuple
#     sub-expressions: 19, 22
# 13. (E , S)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (F , S)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
# 19. D
#     core type: Variable
#     sub-expressions:
# 20. E
#     core type: Variable
#     sub-expressions:
# 21. F
#     core type: Variable
#     sub-expressions:
# 22. S
#     core type: Variable
#     sub-expressions:
