# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#foldNotInSet">foldNotInSet</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.membership._theorems_ import foldNotInSet

# %%
# check that the built expression is the same as the stored expression
# %check_expr foldNotInSet
# Out:
# Passed sanity check: built 'foldNotInSet' is the same as the stored Expression.

# %%
# display the expression information
foldNotInSet.exprInfo()
# Out:
# 0. forall_{x, S | [not](x in S)} (x not-in S)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{S | [not](x in S)} (x not-in S)]
#    core type: Lambda
#    parameter: 13
#    body: 2
# 2. forall_{S | [not](x in S)} (x not-in S)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. S -> (x not-in S) | [not](x in S)
#    core type: Lambda
#    parameter: 14
#    body: 5
#    conditions: 6\n5. x not-in S
#    core type: Operation
#    operator: 7
#    operands: 12
# 6. ([not](x in S))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. not-in
#    core type: Literal
#    sub-expressions:
# 8. [not](x in S)
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. x in S
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x , S)
# ...
