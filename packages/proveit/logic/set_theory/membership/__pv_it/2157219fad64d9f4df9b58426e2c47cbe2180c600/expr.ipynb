# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g, h, i
from proveit.logic import Forall, InSet
from proveit.number import Exp, nine

# %%
# build up the expression from sub-expressions
expr = Forall([f, g, h, i], InSet([a, b, c, d, e, f, g, h, i], Exp(S, nine)), domain = S, conditions = [])
# Out:
# expr: forall_{f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. f -> [forall_{g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})] | f in S
#    core type: Lambda
#    parameter: 31
#    body: 2
#    conditions: 3\n2. forall_{g, h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. (f in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. g -> [forall_{h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})] | g in S
#    core type: Lambda
#    parameter: 32
#    body: 6
#    conditions: 7\n5. f in S
#    core type: Operation
#    operator: 24
#    operands: 8
# 6. forall_{h, i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})
#    core type: Operation
#    operator: 14
#    operand: 9
# 7. (g in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (f , S)
#    core type: ExprTuple
#    sub-expressions: 31, 37
# 9. h -> [forall_{i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})] | h in S
#    core type: Lambda
#    parameter: 33
#    body: 11
#    conditions: 12\n10. g in S
#     core type: Operation
#     operator: 24
#     operands: 13
# 11. forall_{i in S} ((a , b , c , d , e , f , g , h , i) in S^{9})
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. (h in S)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (g , S)
#     core type: ExprTuple
#     sub-expressions: 32, 37
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. i -> ((a , b , c , d , e , f , g , h , i) in S^{9}) | i in S
#     core type: Lambda
#     parameter: 36
#     body: 17
#     conditions: 18\n16. h in S
#     core type: Operation
#     operator: 24
#     operands: 19
# 17. (a , b , c , d , e , f , g , h , i) in S^{9}
#     core type: Operation
#     operator: 24
#     operands: 20
# 18. (i in S)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (h , S)
#     core type: ExprTuple
#     sub-expressions: 33, 37
# 20. ((a , b , c , d , e , f , g , h , i) , S^{9})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. i in S
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (a , b , c , d , e , f , g , h , i)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29, 30, 31, 32, 33, 36
# 23. S^{9}
#     core type: Operation
#     operator: 34
#     operands: 35
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (i , S)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. d
#     core type: Variable
#     sub-expressions:
# 30. e
#     core type: Variable
#     sub-expressions:
# 31. f
#     core type: Variable
#     sub-expressions:
# 32. g
#     core type: Variable
#     sub-expressions:
# 33. h
#     core type: Variable
#     sub-expressions:
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (S , 9)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. S
#     core type: Variable
#     sub-expressions:
# 38. 9
#     core type: Literal
#     sub-expressions:
