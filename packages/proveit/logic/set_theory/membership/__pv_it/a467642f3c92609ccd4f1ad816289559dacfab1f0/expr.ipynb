# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D, E, F, G, H, I, S
from proveit.logic import InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, S), InSet(B, S), InSet(C, S), InSet(D, S), InSet(E, S), InSet(F, S), InSet(G, S), InSet(H, S), InSet(I, S))
# Out:
# expr: (A in S , B in S , C in S , D in S , E in S , F in S , G in S , H in S , I in S)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in S , B in S , C in S , D in S , E in S , F in S , G in S , H in S , I in S)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7, 8, 9
# 1. A in S
#    core type: Operation
#    operator: 18
#    operands: 10
# 2. B in S
#    core type: Operation
#    operator: 18
#    operands: 11
# 3. C in S
#    core type: Operation
#    operator: 18
#    operands: 12
# 4. D in S
#    core type: Operation
#    operator: 18
#    operands: 13
# 5. E in S
#    core type: Operation
#    operator: 18
#    operands: 14
# 6. F in S
#    core type: Operation
#    operator: 18
#    operands: 15
# 7. G in S
#    core type: Operation
#    operator: 18
#    operands: 16
# 8. H in S
#    core type: Operation
#    operator: 18
#    operands: 17
# 9. I in S
#    core type: Operation
#    operator: 18
#    operands: 19
# 10. (A , S)
#     core type: ExprTuple
#     sub-expressions: 20, 29
# 11. (B , S)
#     core type: ExprTuple
#     sub-expressions: 21, 29
# 12. (C , S)
#     core type: ExprTuple
#     sub-expressions: 22, 29
# 13. (D , S)
#     core type: ExprTuple
#     sub-expressions: 23, 29
# 14. (E , S)
#     core type: ExprTuple
#     sub-expressions: 24, 29
# 15. (F , S)
#     core type: ExprTuple
#     sub-expressions: 25, 29
# 16. (G , S)
#     core type: ExprTuple
#     sub-expressions: 26, 29
# 17. (H , S)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (I , S)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. C
#     core type: Variable
#     sub-expressions:
# 23. D
#     core type: Variable
#     sub-expressions:
# 24. E
#     core type: Variable
#     sub-expressions:
# 25. F
#     core type: Variable
#     sub-expressions:
# 26. G
#     core type: Variable
#     sub-expressions:
# 27. H
#     core type: Variable
#     sub-expressions:
# 28. I
#     core type: Variable
#     sub-expressions:
# 29. S
#     core type: Variable
#     sub-expressions:
