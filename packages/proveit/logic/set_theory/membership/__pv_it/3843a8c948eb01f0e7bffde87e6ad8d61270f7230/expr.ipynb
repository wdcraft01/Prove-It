# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Exp, three

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], InSet([a, b, c], Exp(S, three)), domain = S, conditions = []), conditions = [InSet(b, S)])
# Out:
# expr: b -> [forall_{c in S} ((a , b , c) in S^{3})] | b in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c in S} ((a , b , c) in S^{3})] | b in S
#    core type: Lambda
#    parameter: 16
#    body: 1
#    conditions: 2\n1. forall_{c in S} ((a , b , c) in S^{3})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> ((a , b , c) in S^{3}) | c in S
#    core type: Lambda
#    parameter: 19
#    body: 6
#    conditions: 7\n5. b in S
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. (a , b , c) in S^{3}
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. (c in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (b , S)
#    core type: ExprTuple
#    sub-expressions: 16, 20
# 9. ((a , b , c) , S^{3})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. c in S
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (a , b , c)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 19
# 12. S^{3}
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (c , S)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (S , 3)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. S
#     core type: Variable
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
