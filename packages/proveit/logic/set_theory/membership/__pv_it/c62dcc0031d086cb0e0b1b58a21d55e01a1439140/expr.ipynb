# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D, S
from proveit.logic import InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, S), InSet(B, S), InSet(C, S), InSet(D, S))
# Out:
# expr: (A in S , B in S , C in S , D in S)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in S , B in S , C in S , D in S)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. A in S
#    core type: Operation
#    operator: 8
#    operands: 5
# 2. B in S
#    core type: Operation
#    operator: 8
#    operands: 6
# 3. C in S
#    core type: Operation
#    operator: 8
#    operands: 7
# 4. D in S
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. (A , S)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 6. (B , S)
#    core type: ExprTuple
#    sub-expressions: 11, 14
# 7. (C , S)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (D , S)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. D
#     core type: Variable
#     sub-expressions:
# 14. S
#     core type: Variable
#     sub-expressions:
