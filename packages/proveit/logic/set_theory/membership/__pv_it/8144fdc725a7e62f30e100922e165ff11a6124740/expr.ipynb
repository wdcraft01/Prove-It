# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E, F, G, H, S
from proveit.logic import InSet
from proveit.number import Exp, eight

# %%
# build up the expression from sub-expressions
expr = InSet([A, B, C, D, E, F, G, H], Exp(S, eight))
# Out:
# expr: (A , B , C , D , E , F , G , H) in S^{8}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A , B , C , D , E , F , G , H) in S^{8}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((A , B , C , D , E , F , G , H) , S^{8})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (A , B , C , D , E , F , G , H)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8, 9, 10, 11, 12
# 4. S^{8}
#    core type: Operation
#    operator: 13
#    operands: 14
# 5. A
#    core type: Variable
#    sub-expressions:
# 6. B
#    core type: Variable
#    sub-expressions:
# 7. C
#    core type: Variable
#    sub-expressions:
# 8. D
#    core type: Variable
#    sub-expressions:
# 9. E
#    core type: Variable
#    sub-expressions:
# 10. F
#     core type: Variable
#     sub-expressions:
# 11. G
#     core type: Variable
#     sub-expressions:
# 12. H
#     core type: Variable
#     sub-expressions:
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (S , 8)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. S
#     core type: Variable
#     sub-expressions:
# 16. 8
#     core type: Literal
#     sub-expressions:
