# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D, E, F, S
from proveit.logic import InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, S), InSet(B, S), InSet(C, S), InSet(D, S), InSet(E, S), InSet(F, S))
# Out:
# expr: (A in S , B in S , C in S , D in S , E in S , F in S)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in S , B in S , C in S , D in S , E in S , F in S)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6
# 1. A in S
#    core type: Operation
#    operator: 12
#    operands: 7
# 2. B in S
#    core type: Operation
#    operator: 12
#    operands: 8
# 3. C in S
#    core type: Operation
#    operator: 12
#    operands: 9
# 4. D in S
#    core type: Operation
#    operator: 12
#    operands: 10
# 5. E in S
#    core type: Operation
#    operator: 12
#    operands: 11
# 6. F in S
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. (A , S)
#    core type: ExprTuple
#    sub-expressions: 14, 20
# 8. (B , S)
#    core type: ExprTuple
#    sub-expressions: 15, 20
# 9. (C , S)
#    core type: ExprTuple
#    sub-expressions: 16, 20
# 10. (D , S)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 11. (E , S)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (F , S)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. D
#     core type: Variable
#     sub-expressions:
# 18. E
#     core type: Variable
#     sub-expressions:
# 19. F
#     core type: Variable
#     sub-expressions:
# 20. S
#     core type: Variable
#     sub-expressions:
