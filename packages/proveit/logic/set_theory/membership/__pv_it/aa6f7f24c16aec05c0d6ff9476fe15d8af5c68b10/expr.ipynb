# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D, E, F, G, S
from proveit.logic import InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, S), InSet(B, S), InSet(C, S), InSet(D, S), InSet(E, S), InSet(F, S), InSet(G, S))
# Out:
# expr: (A in S , B in S , C in S , D in S , E in S , F in S , G in S)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in S , B in S , C in S , D in S , E in S , F in S , G in S)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7
# 1. A in S
#    core type: Operation
#    operator: 14
#    operands: 8
# 2. B in S
#    core type: Operation
#    operator: 14
#    operands: 9
# 3. C in S
#    core type: Operation
#    operator: 14
#    operands: 10
# 4. D in S
#    core type: Operation
#    operator: 14
#    operands: 11
# 5. E in S
#    core type: Operation
#    operator: 14
#    operands: 12
# 6. F in S
#    core type: Operation
#    operator: 14
#    operands: 13
# 7. G in S
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. (A , S)
#    core type: ExprTuple
#    sub-expressions: 16, 23
# 9. (B , S)
#    core type: ExprTuple
#    sub-expressions: 17, 23
# 10. (C , S)
#     core type: ExprTuple
#     sub-expressions: 18, 23
# 11. (D , S)
#     core type: ExprTuple
#     sub-expressions: 19, 23
# 12. (E , S)
#     core type: ExprTuple
#     sub-expressions: 20, 23
# 13. (F , S)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (G , S)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
# 19. D
#     core type: Variable
#     sub-expressions:
# 20. E
#     core type: Variable
#     sub-expressions:
# 21. F
#     core type: Variable
#     sub-expressions:
# 22. G
#     core type: Variable
#     sub-expressions:
# 23. S
#     core type: Variable
#     sub-expressions:
