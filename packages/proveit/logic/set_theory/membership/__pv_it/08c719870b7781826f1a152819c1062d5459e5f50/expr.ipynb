# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b
from proveit.logic import Forall, InSet
from proveit.number import Exp, two

# %%
# build up the expression from sub-expressions
subExpr1 = [a, b]
expr = Lambda(S, Forall(subExpr1, InSet(subExpr1, Exp(S, two)), domain = S, conditions = []))
# Out:
# expr: S -> [forall_{a, b in S} ((a , b) in S^{2})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. S -> [forall_{a, b in S} ((a , b) in S^{2})]
#    core type: Lambda
#    parameter: 21
#    body: 1
# 1. forall_{a, b in S} ((a , b) in S^{2})
#    core type: Operation
#    operator: 5
#    operand: 2
# 2. a -> [forall_{b in S} ((a , b) in S^{2})] | a in S
#    core type: Lambda
#    parameter: 17
#    body: 3
#    conditions: 4\n3. forall_{b in S} ((a , b) in S^{2})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (a in S)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. b -> ((a , b) in S^{2}) | b in S
#    core type: Lambda
#    parameter: 20
#    body: 8
#    conditions: 9\n7. a in S
#    core type: Operation
#    operator: 15
#    operands: 10
# 8. (a , b) in S^{2}
#    core type: Operation
#    operator: 15
#    operands: 11
# 9. (b in S)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (a , S)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 11. ((a , b) , S^{2})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. b in S
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (a , b)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 14. S^{2}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b , S)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. Exp
#     core type: Literal
#     sub-expressions:
# 19. (S , 2)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. S
#     core type: Variable
#     sub-expressions:
# 22. 2
#     core type: Literal
#     sub-expressions:
