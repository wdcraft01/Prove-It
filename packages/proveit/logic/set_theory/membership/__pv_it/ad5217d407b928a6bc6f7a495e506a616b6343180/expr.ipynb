# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, n, xx
from proveit.logic import And, Equals, Forall, InSet
from proveit.logic.set_theory._common_ import each_x_in_S
from proveit.number import Exp, Len, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([xx, S], Equals(InSet(xx, Exp(S, n)), And(Equals(Len(xx), n), each_x_in_S)), conditions = []), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{x, S} ((x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S)))] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{x, S} ((x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S)))] | n in Naturals
#    core type: Lambda
#    parameter: 41
#    body: 1
#    conditions: 2\n1. forall_{x, S} ((x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S)))
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. x -> [forall_{S} ((x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S)))]
#    core type: Lambda
#    parameter: 35
#    body: 5
# 4. n in Naturals
#    core type: Operation
#    operator: 33
#    operands: 6
# 5. forall_{S} ((x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S)))
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (n , Naturals)
#    core type: ExprTuple
#    sub-expressions: 41, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. S -> ((x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S)))
#    core type: Lambda
#    parameter: 32
#    body: 10
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. (x in S^{n}) = ((|x| = n) and (x_1 in S) and  ...  and (x_n in S))
#     core type: Operation
#     operator: 22
#     operands: 11
# 11. (x in S^{n} , (|x| = n) and (x_1 in S) and  ...  and (x_n in S))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x in S^{n}
#     core type: Operation
#     operator: 33
#     operands: 14
# 13. (|x| = n) and (x_1 in S) and  ...  and (x_n in S)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x , S^{n})
#     core type: ExprTuple
#     sub-expressions: 35, 17
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (|x| = n , x_1 in S ,  ...  , x_n in S)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. S^{n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. |x| = n
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (x_1 in S),...,(x_n in S)
#     core type: Iter
#     lambda_map: 24
#     start_index: 40
#     end_index: 41
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (S , n)
#     core type: ExprTuple
#     sub-expressions: 32, 41
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (|x| , n)
#     core type: ExprTuple
#     sub-expressions: 25, 41
# 24. i -> (x_i in S) | i in {1...n}
#     core type: Lambda
#     parameter: 36
#     body: 26
#     conditions: 27\n25. |x|
#     core type: Operation
#     operator: 28
#     operand: 35
# 26. x_i in S
#     core type: Operation
#     operator: 33
#     operands: 29
# 27. (i in {1...n})
#     core type: ExprTuple
#     sub-expressions: 30
# 28. length
#     core type: Literal
#     sub-expressions:
# 29. (x_i , S)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. i in {1...n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. x_i
#     core type: Indexed
#     var: 35
#     index: 36
#     base: "1"
# 32. S
#     core type: Variable
#     sub-expressions:
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (i , {1...n})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. x
#     core type: Variable
#     sub-expressions:
# 36. i
#     core type: Variable
#     sub-expressions:
# 37. {1...n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. n
#     core type: Variable
#     sub-expressions:
