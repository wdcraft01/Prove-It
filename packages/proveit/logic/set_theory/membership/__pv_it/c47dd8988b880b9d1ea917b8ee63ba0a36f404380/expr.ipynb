# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, x
from proveit.logic import Booleans, Forall, InSet, NotInSet

# %%
# build up the expression from sub-expressions
expr = Forall([S], InSet(NotInSet(x, S), Booleans), conditions = [InSet(InSet(x, S), Booleans)])
# Out:
# expr: forall_{S | (x in S) in BOOLEANS} ((x not-in S) in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S | (x in S) in BOOLEANS} ((x not-in S) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. S -> ((x not-in S) in BOOLEANS) | (x in S) in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. (x not-in S) in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. ((x in S) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x not-in S , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 11
# 6. (x in S) in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. x not-in S
#    core type: Operation
#    operator: 9
#    operands: 13
# 8. (x in S , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. not-in
#    core type: Literal
#    sub-expressions:
# 10. x in S
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x , S)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. S
#     core type: Variable
#     sub-expressions:
