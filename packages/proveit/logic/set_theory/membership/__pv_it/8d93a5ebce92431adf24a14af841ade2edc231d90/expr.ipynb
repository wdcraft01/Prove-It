# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Forall, InSet, Not, NotInSet

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([S], NotInSet(x, S), conditions = [Not(InSet(x, S))]))
# Out:
# expr: x -> [forall_{S | [not](x in S)} (x not-in S)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{S | [not](x in S)} (x not-in S)]
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. forall_{S | [not](x in S)} (x not-in S)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. S -> (x not-in S) | [not](x in S)
#    core type: Lambda
#    parameter: 13
#    body: 4
#    conditions: 5\n4. x not-in S
#    core type: Operation
#    operator: 6
#    operands: 11
# 5. ([not](x in S))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. not-in
#    core type: Literal
#    sub-expressions:
# 7. [not](x in S)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. x in S
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x , S)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. S
#     core type: Variable
#     sub-expressions:
