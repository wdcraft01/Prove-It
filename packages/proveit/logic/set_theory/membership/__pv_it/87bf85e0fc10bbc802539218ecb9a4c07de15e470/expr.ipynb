# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g, h, i
from proveit.logic import InSet
from proveit.number import Exp, nine

# %%
# build up the expression from sub-expressions
expr = InSet([a, b, c, d, e, f, g, h, i], Exp(S, nine))
# Out:
# expr: (a , b , c , d , e , f , g , h , i) in S^{9}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a , b , c , d , e , f , g , h , i) in S^{9}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((a , b , c , d , e , f , g , h , i) , S^{9})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a , b , c , d , e , f , g , h , i)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8, 9, 10, 11, 12, 13
# 4. S^{9}
#    core type: Operation
#    operator: 14
#    operands: 15
# 5. a
#    core type: Variable
#    sub-expressions:
# 6. b
#    core type: Variable
#    sub-expressions:
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. d
#    core type: Variable
#    sub-expressions:
# 9. e
#    core type: Variable
#    sub-expressions:
# 10. f
#     core type: Variable
#     sub-expressions:
# 11. g
#     core type: Variable
#     sub-expressions:
# 12. h
#     core type: Variable
#     sub-expressions:
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (S , 9)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. S
#     core type: Variable
#     sub-expressions:
# 17. 9
#     core type: Literal
#     sub-expressions:
