# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g
from proveit.logic import Forall, InSet
from proveit.number import Exp, seven

# %%
# build up the expression from sub-expressions
expr = Forall([d, e, f, g], InSet([a, b, c, d, e, f, g], Exp(S, seven)), domain = S, conditions = [])
# Out:
# expr: forall_{d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. d -> [forall_{e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})] | d in S
#    core type: Lambda
#    parameter: 29
#    body: 2
#    conditions: 3\n2. forall_{e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. (d in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. e -> [forall_{f, g in S} ((a , b , c , d , e , f , g) in S^{7})] | e in S
#    core type: Lambda
#    parameter: 30
#    body: 6
#    conditions: 7\n5. d in S
#    core type: Operation
#    operator: 24
#    operands: 8
# 6. forall_{f, g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 14
#    operand: 9
# 7. (e in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (d , S)
#    core type: ExprTuple
#    sub-expressions: 29, 35
# 9. f -> [forall_{g in S} ((a , b , c , d , e , f , g) in S^{7})] | f in S
#    core type: Lambda
#    parameter: 31
#    body: 11
#    conditions: 12\n10. e in S
#     core type: Operation
#     operator: 24
#     operands: 13
# 11. forall_{g in S} ((a , b , c , d , e , f , g) in S^{7})
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. (f in S)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (e , S)
#     core type: ExprTuple
#     sub-expressions: 30, 35
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. g -> ((a , b , c , d , e , f , g) in S^{7}) | g in S
#     core type: Lambda
#     parameter: 34
#     body: 17
#     conditions: 18\n16. f in S
#     core type: Operation
#     operator: 24
#     operands: 19
# 17. (a , b , c , d , e , f , g) in S^{7}
#     core type: Operation
#     operator: 24
#     operands: 20
# 18. (g in S)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (f , S)
#     core type: ExprTuple
#     sub-expressions: 31, 35
# 20. ((a , b , c , d , e , f , g) , S^{7})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. g in S
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (a , b , c , d , e , f , g)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29, 30, 31, 34
# 23. S^{7}
#     core type: Operation
#     operator: 32
#     operands: 33
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (g , S)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. d
#     core type: Variable
#     sub-expressions:
# 30. e
#     core type: Variable
#     sub-expressions:
# 31. f
#     core type: Variable
#     sub-expressions:
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (S , 7)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. g
#     core type: Variable
#     sub-expressions:
# 35. S
#     core type: Variable
#     sub-expressions:
# 36. 7
#     core type: Literal
#     sub-expressions:
