# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Equals, Forall, InSet, Not, NotInSet

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([S], Equals(NotInSet(x, S), Not(InSet(x, S))), conditions = []))
# Out:
# expr: x -> [forall_{S} ((x not-in S) = [not](x in S))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{S} ((x not-in S) = [not](x in S))]
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. forall_{S} ((x not-in S) = [not](x in S))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. S -> ((x not-in S) = [not](x in S))
#    core type: Lambda
#    parameter: 15
#    body: 4
# 4. (x not-in S) = [not](x in S)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x not-in S , [not](x in S))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x not-in S
#    core type: Operation
#    operator: 9
#    operands: 13
# 8. [not](x in S)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. not-in
#    core type: Literal
#    sub-expressions:
# 10. not
#     core type: Literal
#     sub-expressions:
# 11. x in S
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x , S)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. S
#     core type: Variable
#     sub-expressions:
