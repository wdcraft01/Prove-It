# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Booleans, Forall, InSet, NotInSet

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([S], InSet(NotInSet(x, S), Booleans), conditions = [InSet(InSet(x, S), Booleans)]))
# Out:
# expr: x -> [forall_{S | (x in S) in BOOLEANS} ((x not-in S) in BOOLEANS)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{S | (x in S) in BOOLEANS} ((x not-in S) in BOOLEANS)]
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. forall_{S | (x in S) in BOOLEANS} ((x not-in S) in BOOLEANS)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. S -> ((x not-in S) in BOOLEANS) | (x in S) in BOOLEANS
#    core type: Lambda
#    parameter: 16
#    body: 4
#    conditions: 5\n4. (x not-in S) in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 6
# 5. ((x in S) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (x not-in S , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8, 12
# 7. (x in S) in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 9
# 8. x not-in S
#    core type: Operation
#    operator: 10
#    operands: 14
# 9. (x in S , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. not-in
#     core type: Literal
#     sub-expressions:
# 11. x in S
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x , S)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. S
#     core type: Variable
#     sub-expressions:
