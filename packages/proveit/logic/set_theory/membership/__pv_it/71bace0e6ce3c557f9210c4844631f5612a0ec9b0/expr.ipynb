# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.membership</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E, S
from proveit.logic import InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(A, S), InSet(B, S), InSet(C, S), InSet(D, S), InSet(E, S))
# Out:
# expr: {A in S , B in S , C in S , D in S , E in S}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A in S , B in S , C in S , D in S , E in S}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A in S , B in S , C in S , D in S , E in S)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. A in S
#    core type: Operation
#    operator: 12
#    operands: 8
# 4. B in S
#    core type: Operation
#    operator: 12
#    operands: 9
# 5. C in S
#    core type: Operation
#    operator: 12
#    operands: 10
# 6. D in S
#    core type: Operation
#    operator: 12
#    operands: 11
# 7. E in S
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. (A , S)
#    core type: ExprTuple
#    sub-expressions: 14, 19
# 9. (B , S)
#    core type: ExprTuple
#    sub-expressions: 15, 19
# 10. (C , S)
#     core type: ExprTuple
#     sub-expressions: 16, 19
# 11. (D , S)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (E , S)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. D
#     core type: Variable
#     sub-expressions:
# 18. E
#     core type: Variable
#     sub-expressions:
# 19. S
#     core type: Variable
#     sub-expressions:
