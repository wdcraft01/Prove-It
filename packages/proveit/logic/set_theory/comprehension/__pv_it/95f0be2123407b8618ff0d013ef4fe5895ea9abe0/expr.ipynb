# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import S, l, yy
from proveit.logic import InSet
from proveit.logic._common_ import iterQ1k_yIter1l
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(yy, Exp(S, l)), iterQ1k_yIter1l)
# Out:
# expr: (y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. y in S^{l}
#    core type: Operation
#    operator: 24
#    operands: 3
# 2. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#    core type: Iter
#    lambda_map: 4
#    start_index: 31
#    end_index: 26
# 3. (y , S^{l})
#    core type: ExprTuple
#    sub-expressions: 21, 5
# 4. i -> Q_i(y_1,...,y_l) | i in {1...k}
#    core type: Lambda
#    parameter: 19
#    body: 6
#    conditions: 7\n5. S^{l}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. Q_i(y_1,...,y_l)
#    core type: Operation
#    operator: 10
#    operand: 11
# 7. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 12
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (S , l)
#    core type: ExprTuple
#    sub-expressions: 13, 32
# 10. Q_i
#     core type: Indexed
#     var: 14
#     index: 19
#     base: "1"
# 11. y_1,...,y_l
#     core type: Iter
#     lambda_map: 15
#     start_index: 31
#     end_index: 32
# 12. i in {1...k}
#     core type: Operation
#     operator: 24
#     operands: 16
# 13. S
#     core type: Variable
#     sub-expressions:
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 27
#     body: 17
#     conditions: 18\n16. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. y__x_
#     core type: Indexed
#     var: 21
#     index: 27
#     base: "1"
# 18. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. i
#     core type: Variable
#     sub-expressions:
# 20. {1...k}
#     core type: Operation
#     operator: 29
#     operands: 23
# 21. y
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...l}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 31, 26
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. k
#     core type: Variable
#     sub-expressions:
# 27. _x_
#     core type: Variable
#     sub-expressions:
# 28. {1...l}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. l
#     core type: Variable
#     sub-expressions:
