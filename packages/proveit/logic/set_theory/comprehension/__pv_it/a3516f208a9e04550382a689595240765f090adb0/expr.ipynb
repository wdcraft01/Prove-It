# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, x
from proveit.logic import And, InSet
from proveit.logic._common_ import iterQ1k_x

# %%
# build up the expression from sub-expressions
expr = And(InSet(x, S), iterQ1k_x)
# Out:
# expr: (x in S) and Q_1(x) and  ...  and Q_k(x)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in S) and Q_1(x) and  ...  and Q_k(x)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (x in S , Q_1(x) ,  ...  , Q_k(x))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. x in S
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. Q_1(x),...,Q_k(x)
#    core type: Iter
#    lambda_map: 6
#    start_index: 20
#    end_index: 21
# 5. (x , S)
#    core type: ExprTuple
#    sub-expressions: 11, 7
# 6. i -> Q_i(x) | i in {1...k}
#    core type: Lambda
#    parameter: 16
#    body: 8
#    conditions: 9\n7. S
#    core type: Variable
#    sub-expressions:
# 8. Q_i(x)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. Q_i
#     core type: Indexed
#     var: 13
#     index: 16
#     base: "1"
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. i in {1...k}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. Q
#     core type: Variable
#     sub-expressions:
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. {1...k}
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. k
#     core type: Variable
#     sub-expressions:
