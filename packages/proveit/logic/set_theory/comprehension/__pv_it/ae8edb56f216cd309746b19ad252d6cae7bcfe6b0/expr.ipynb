# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x
from proveit.logic import InSet
from proveit.logic.set_theory._common_ import generalComprehension_fy

# %%
# build up the expression from sub-expressions
expr = InSet(x, generalComprehension_fy)
# Out:
# expr: x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 20
#    operands: 1
# 1. (x , {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. x
#    core type: Variable
#    sub-expressions:
# 3. {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. y -> f(y) | y in S , Q_1(y) ,  ...  , Q_k(y)
#    core type: Lambda
#    parameter: 17
#    body: 6
#    conditions: 7\n6. f(y)
#    core type: Operation
#    operator: 8
#    operand: 17
# 7. (y in S , Q_1(y) ,  ...  , Q_k(y))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. f
#    core type: Variable
#    sub-expressions:
# 9. y in S
#    core type: Operation
#    operator: 20
#    operands: 11
# 10. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 12
#     start_index: 26
#     end_index: 27
# 11. (y , S)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 12. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 22
#     body: 14
#     conditions: 15\n13. S
#     core type: Variable
#     sub-expressions:
# 14. Q_i(y)
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. Q_i
#     core type: Indexed
#     var: 19
#     index: 22
#     base: "1"
# 17. y
#     core type: Variable
#     sub-expressions:
# 18. i in {1...k}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. Q
#     core type: Variable
#     sub-expressions:
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. {1...k}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. k
#     core type: Variable
#     sub-expressions:
