# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, l, x, yy
from proveit.logic import Equals, Exists, Forall, Implies, InSet
from proveit.logic._common_ import f_yIter1l, iterQ1k_yIter1l
from proveit.logic.set_theory._common_ import generalComprehension_fy
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([x], Implies(Exists([yy], Equals(x, f_yIter1l), domain = Exp(S, l), conditions = [iterQ1k_yIter1l]), InSet(x, generalComprehension_fy)).withWrappingAt(2), conditions = [])
# Out:
# expr: forall_{x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))
#    core type: Lambda
#    parameter: 20
#    body: 3
# 3. [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l)) , x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 49
#    operands: 10
# 8. exists
#    core type: Literal
#    sub-expressions:
# 9. y -> (x = f(y_1,...,y_l)) | y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 45
#    body: 11
#    conditions: 12\n10. (x , {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 20, 13
# 11. x = f(y_1,...,y_l)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 18
#     operand: 19
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (x , f(y_1,...,y_l))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. y in S^{l}
#     core type: Operation
#     operator: 49
#     operands: 22
# 17. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#     core type: Iter
#     lambda_map: 23
#     start_index: 59
#     end_index: 58
# 18. Set
#     core type: Literal
#     sub-expressions:
# 19. y -> f(y) | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 43
#     body: 24
#     conditions: 25\n20. x
#     core type: Variable
#     sub-expressions:
# 21. f(y_1,...,y_l)
#     core type: Operation
#     operator: 28
#     operand: 33
# 22. (y , S^{l})
#     core type: ExprTuple
#     sub-expressions: 45, 26
# 23. i -> Q_i(y_1,...,y_l) | i in {1...k}
#     core type: Lambda
#     parameter: 51
#     body: 27
#     conditions: 39\n24. f(y)
#     core type: Operation
#     operator: 28
#     operand: 43
# 25. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. S^{l}
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. Q_i(y_1,...,y_l)
#     core type: Operation
#     operator: 42
#     operand: 33
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. y in S
#     core type: Operation
#     operator: 49
#     operands: 34
# 30. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 35
#     start_index: 59
#     end_index: 58
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (S , l)
#     core type: ExprTuple
#     sub-expressions: 37, 60
# 33. y_1,...,y_l
#     core type: Iter
#     lambda_map: 36
#     start_index: 59
#     end_index: 60
# 34. (y , S)
#     core type: ExprTuple
#     sub-expressions: 43, 37
# 35. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 51
#     body: 38
#     conditions: 39\n36. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 53
#     body: 40
#     conditions: 41\n37. S
#     core type: Variable
#     sub-expressions:
# 38. Q_i(y)
#     core type: Operation
#     operator: 42
#     operand: 43
# 39. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 44
# 40. y__x_
#     core type: Indexed
#     var: 45
#     index: 53
#     base: "1"
# 41. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 46
# 42. Q_i
#     core type: Indexed
#     var: 47
#     index: 51
#     base: "1"
# 43. y
#     core type: Variable
#     sub-expressions:
# 44. i in {1...k}
#     core type: Operation
#     operator: 49
#     operands: 48
# 45. y
#     core type: Variable
#     sub-expressions:
# 46. _x_ in {1...l}
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. Q
#     core type: Variable
#     sub-expressions:
# 48. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 49. in
#     core type: Literal
#     sub-expressions:
# 50. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. i
#     core type: Variable
#     sub-expressions:
# 52. {1...k}
#     core type: Operation
#     operator: 56
#     operands: 55
# 53. _x_
#     core type: Variable
#     sub-expressions:
# 54. {1...l}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 59, 58
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 58. k
#     core type: Variable
#     sub-expressions:
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. l
#     core type: Variable
#     sub-expressions:
