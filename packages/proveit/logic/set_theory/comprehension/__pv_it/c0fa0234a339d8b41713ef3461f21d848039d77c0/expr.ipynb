# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, f, fy, x, y
from proveit.logic import Equals, Exists, Forall, InSet
from proveit.logic._common_ import iterQ1k_y
from proveit.logic.set_theory._common_ import generalComprehension_fy

# %%
# build up the expression from sub-expressions
expr = Forall([f, x], Equals(InSet(x, generalComprehension_fy), Exists([y], Equals(x, fy), domain = S, conditions = [iterQ1k_y])).withWrappingAt(1), conditions = [])
# Out:
# expr: forall_{f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. f -> [forall_{x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])]
#    core type: Lambda
#    parameter: 23
#    body: 2
# 2. forall_{x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])
#    core type: Lambda
#    parameter: 19
#    body: 5
# 5. (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))]
#    core type: Operation
#    operator: 16
# ...
