# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, f, l, x, yy
from proveit.logic import Equals, Exists, Forall, Implies, InSet
from proveit.logic._common_ import f_yIter1l, iterQ1k, iterQ1k_yIter1l
from proveit.logic.set_theory._common_ import generalComprehension_fy
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([iterQ1k, f, x], Implies(Exists([yy], Equals(x, f_yIter1l), domain = Exp(S, l), conditions = [iterQ1k_yIter1l]), InSet(x, generalComprehension_fy)).withWrappingAt(2), conditions = [])
# Out:
# expr: forall_{Q_1,...,Q_k, f, x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{Q_1,...,Q_k, f, x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))
#    core type: Operation
#    operator: 10
#    operand: 1
# 1. (Q_1,...,Q_k) -> [forall_{f, x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))]
#    core type: Lambda
#    parameter: 2
#    body: 3
# 2. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 4
#    start_index: 69
#    end_index: 68
# 3. forall_{f, x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))
#    core type: Operation
#    operator: 10
#    operand: 5
# 4. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 63
#    body: 6
#    conditions: 7\n5. f -> [forall_{x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))]
#    core type: Lambda
#    parameter: 38
#    body: 8
# 6. Q__x_
#    core type: Indexed
#    var: 57
#    index: 63
#    base: "1"
# 7. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. forall_{x} ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. _x_ in {1...k}
#    core type: Operation
#    operator: 59
#    operands: 12
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. x -> ([exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}))
#     core type: Lambda
#     parameter: 30
#     body: 13
# 12. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 13. [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))] =>  \\ (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. =>
#     core type: Literal
#     sub-expressions:
# 15. (exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l)) , x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 59
#     operands: 20
# 18. exists
#     core type: Literal
#     sub-expressions:
# 19. y -> (x = f(y_1,...,y_l)) | y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#     core type: Lambda
#     parameter: 55
#     body: 21
#     conditions: 22\n20. (x , {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 21. x = f(y_1,...,y_l)
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 28
#     operand: 29
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (x , f(y_1,...,y_l))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. y in S^{l}
#     core type: Operation
#     operator: 59
#     operands: 32
# 27. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#     core type: Iter
#     lambda_map: 33
#     start_index: 69
#     end_index: 68
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. y -> f(y) | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 53
#     body: 34
#     conditions: 35\n30. x
#     core type: Variable
#     sub-expressions:
# 31. f(y_1,...,y_l)
#     core type: Operation
#     operator: 38
#     operand: 43
# 32. (y , S^{l})
#     core type: ExprTuple
#     sub-expressions: 55, 36
# 33. i -> Q_i(y_1,...,y_l) | i in {1...k}
#     core type: Lambda
#     parameter: 61
#     body: 37
#     conditions: 49\n34. f(y)
#     core type: Operation
#     operator: 38
#     operand: 53
# 35. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. S^{l}
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. Q_i(y_1,...,y_l)
#     core type: Operation
#     operator: 52
#     operand: 43
# 38. f
#     core type: Variable
#     sub-expressions:
# 39. y in S
#     core type: Operation
#     operator: 59
#     operands: 44
# 40. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 45
#     start_index: 69
#     end_index: 68
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (S , l)
#     core type: ExprTuple
#     sub-expressions: 47, 70
# 43. y_1,...,y_l
#     core type: Iter
#     lambda_map: 46
#     start_index: 69
#     end_index: 70
# 44. (y , S)
#     core type: ExprTuple
#     sub-expressions: 53, 47
# 45. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 61
#     body: 48
#     conditions: 49\n46. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 63
#     body: 50
#     conditions: 51\n47. S
#     core type: Variable
#     sub-expressions:
# 48. Q_i(y)
#     core type: Operation
#     operator: 52
#     operand: 53
# 49. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 54
# 50. y__x_
#     core type: Indexed
#     var: 55
#     index: 63
#     base: "1"
# 51. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. Q_i
#     core type: Indexed
#     var: 57
#     index: 61
#     base: "1"
# 53. y
#     core type: Variable
#     sub-expressions:
# 54. i in {1...k}
#     core type: Operation
#     operator: 59
#     operands: 58
# 55. y
#     core type: Variable
#     sub-expressions:
# 56. _x_ in {1...l}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. Q
#     core type: Variable
#     sub-expressions:
# 58. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. in
#     core type: Literal
#     sub-expressions:
# 60. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. i
#     core type: Variable
#     sub-expressions:
# 62. {1...k}
#     core type: Operation
#     operator: 66
#     operands: 65
# 63. _x_
#     core type: Variable
#     sub-expressions:
# 64. {1...l}
#     core type: Operation
#     operator: 66
#     operands: 67
# 65. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 69, 68
# 66. Interval
#     core type: Literal
#     sub-expressions:
# 67. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 68. k
#     core type: Variable
#     sub-expressions:
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. l
#     core type: Variable
#     sub-expressions:
