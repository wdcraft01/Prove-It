# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, fy, x, y
from proveit.logic import Equals, Exists, InSet
from proveit.logic._common_ import iterQ1k_y
from proveit.logic.set_theory._common_ import generalComprehension_fy

# %%
# build up the expression from sub-expressions
expr = Equals(InSet(x, generalComprehension_fy), Exists([y], Equals(x, fy), domain = S, conditions = [iterQ1k_y])).withWrappingAt(1)
# Out:
# expr: (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))]
#    core type: Operation
#    operator: 11
#    operands: 1
# 1. (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} , exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y)))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 28
#    operands: 4
# 3. exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (x , {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 5. exists
#    core type: Literal
#    sub-expressions:
# 6. y -> (x = f(y)) | y in S , Q_1(y) ,  ...  , Q_k(y)
#    core type: Lambda
#    parameter: 25
#    body: 8
#    conditions: 13\n7. {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. x = f(y)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. Set
#    core type: Literal
#    sub-expressions:
# 10. y -> f(y) | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 25
#     body: 15
#     conditions: 13\n11. =
#     core type: Literal
#     sub-expressions:
# 12. (x , f(y))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. f(y)
#     core type: Operation
#     operator: 18
#     operand: 25
# 16. y in S
#     core type: Operation
#     operator: 28
#     operands: 19
# 17. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 20
#     start_index: 34
#     end_index: 35
# 18. f
#     core type: Variable
#     sub-expressions:
# 19. (y , S)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 20. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 30
#     body: 22
#     conditions: 23\n21. S
#     core type: Variable
#     sub-expressions:
# 22. Q_i(y)
#     core type: Operation
#     operator: 24
#     operand: 25
# 23. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. Q_i
#     core type: Indexed
#     var: 27
#     index: 30
#     base: "1"
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. i in {1...k}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. Q
#     core type: Variable
#     sub-expressions:
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. {1...k}
#     core type: Operation
#     operator: 32
#     operands: 33
# 32. Interval
#     core type: Literal
#     sub-expressions:
# 33. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. k
#     core type: Variable
#     sub-expressions:
