# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterQ1k, iterQ1k_x
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(S, Forall([iterQ1k], Forall([x], InSet(x, basicComprehension_y), domain = S, conditions = [iterQ1k_x]), conditions = []))
# Out:
# expr: S -> [forall_{Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. S -> [forall_{Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]]
#    core type: Lambda
#    parameter: 30
#    body: 1
# 1. forall_{Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 2. (Q_1,...,Q_k) -> [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]
#    core type: Lambda
#    parameter: 3
#    body: 4
# 3. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 5
#    start_index: 43
#    end_index: 44
# 4. forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 20
#    body: 8
#    conditions: 9\n6. forall
#    core type: Literal
#    sub-expressions:
# 7. x -> (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) | x in S , Q_1(x) ,  ...  , Q_k(x)
#    core type: Lambda
#    parameter: 25
#    body: 10
#    conditions: 11\n8. Q__x_
#    core type: Indexed
#    var: 36
#    index: 20
#    base: "1"
# 9. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 37
#     operands: 13
# 11. (x in S , Q_1(x) ,  ...  , Q_k(x))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. _x_ in {1...k}
#     core type: Operation
#     operator: 37
#     operands: 16
# 13. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 25, 17
# 14. x in S
#     core type: Operation
#     operator: 37
#     operands: 18
# 15. Q_1(x),...,Q_k(x)
#     core type: Iter
#     lambda_map: 19
#     start_index: 43
#     end_index: 44
# 16. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 20, 40
# 17. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 21
#     operand: 22
# 18. (x , S)
#     core type: ExprTuple
#     sub-expressions: 25, 30
# 19. i -> Q_i(x) | i in {1...k}
#     core type: Lambda
#     parameter: 39
#     body: 23
#     conditions: 32\n20. _x_
#     core type: Variable
#     sub-expressions:
# 21. Set
#     core type: Literal
#     sub-expressions:
# 22. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 34
#     body: 34
#     conditions: 24\n23. Q_i(x)
#     core type: Operation
#     operator: 33
#     operand: 25
# 24. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. y in S
#     core type: Operation
#     operator: 37
#     operands: 28
# 27. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 29
#     start_index: 43
#     end_index: 44
# 28. (y , S)
#     core type: ExprTuple
#     sub-expressions: 34, 30
# 29. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 39
#     body: 31
#     conditions: 32\n30. S
#     core type: Variable
#     sub-expressions:
# 31. Q_i(y)
#     core type: Operation
#     operator: 33
#     operand: 34
# 32. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 35
# 33. Q_i
#     core type: Indexed
#     var: 36
#     index: 39
#     base: "1"
# 34. y
#     core type: Variable
#     sub-expressions:
# 35. i in {1...k}
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. Q
#     core type: Variable
#     sub-expressions:
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 39. i
#     core type: Variable
#     sub-expressions:
# 40. {1...k}
#     core type: Operation
#     operator: 41
#     operands: 42
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. k
#     core type: Variable
#     sub-expressions:
