# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, k
from proveit.logic import Forall, InSet, SubsetEq
from proveit.logic._common_ import iterQ1k
from proveit.logic.set_theory._common_ import basicComprehension_y
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(k, Forall([S, iterQ1k], SubsetEq(basicComprehension_y, S), conditions = []), conditions = [InSet(k, NaturalsPos)])
# Out:
# expr: k -> [forall_{S, Q_1,...,Q_k} ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S)] | k in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. k -> [forall_{S, Q_1,...,Q_k} ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S)] | k in NaturalsPos
#    core type: Lambda
#    parameter: 42
#    body: 1
#    conditions: 2\n1. forall_{S, Q_1,...,Q_k} ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S)
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (k in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. S -> [forall_{Q_1,...,Q_k} ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S)]
#    core type: Lambda
#    parameter: 28
#    body: 5
# 4. k in NaturalsPos
#    core type: Operation
#    operator: 35
#    operands: 6
# 5. forall_{Q_1,...,Q_k} ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (k , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 42, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (Q_1,...,Q_k) -> ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S)
#    core type: Lambda
#    parameter: 10
#    body: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. Q_1,...,Q_k
#     core type: Iter
#     lambda_map: 12
#     start_index: 41
#     end_index: 42
# 11. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} subseteq S
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. _x_ -> Q__x_ | _x_ in {1...k}
#     core type: Lambda
#     parameter: 23
#     body: 15
#     conditions: 16\n13. subseteq
#     core type: Literal
#     sub-expressions:
# 14. ({y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} , S)
#     core type: ExprTuple
#     sub-expressions: 17, 28
# 15. Q__x_
#     core type: Indexed
#     var: 34
#     index: 23
#     base: "1"
# 16. (_x_ in {1...k})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 19
#     operand: 20
# 18. _x_ in {1...k}
#     core type: Operation
#     operator: 35
#     operands: 21
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 32
#     body: 32
#     conditions: 22\n21. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 23, 38
# 22. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. _x_
#     core type: Variable
#     sub-expressions:
# 24. y in S
#     core type: Operation
#     operator: 35
#     operands: 26
# 25. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 27
#     start_index: 41
#     end_index: 42
# 26. (y , S)
#     core type: ExprTuple
#     sub-expressions: 32, 28
# 27. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 37
#     body: 29
#     conditions: 30\n28. S
#     core type: Variable
#     sub-expressions:
# 29. Q_i(y)
#     core type: Operation
#     operator: 31
#     operand: 32
# 30. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 33
# 31. Q_i
#     core type: Indexed
#     var: 34
#     index: 37
#     base: "1"
# 32. y
#     core type: Variable
#     sub-expressions:
# 33. i in {1...k}
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. Q
#     core type: Variable
#     sub-expressions:
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. {1...k}
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. Interval
#     core type: Literal
#     sub-expressions:
# 40. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. k
#     core type: Variable
#     sub-expressions:
