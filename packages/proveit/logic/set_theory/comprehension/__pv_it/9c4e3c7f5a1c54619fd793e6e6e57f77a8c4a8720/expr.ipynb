# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import And, Equals, Forall, InSet
from proveit.logic._common_ import iterQ1k, iterQ1k_x
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(iterQ1k, Forall([x], Equals(InSet(x, basicComprehension_y), And(InSet(x, S), iterQ1k_x)).withWrappingAt(1), conditions = []))
# Out:
# expr: (Q_1,...,Q_k) -> [forall_{x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1,...,Q_k) -> [forall_{x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))]
#    core type: Lambda
#    parameter: 1
#    body: 2
# 1. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 3
#    start_index: 46
#    end_index: 47
# 2. forall_{x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 15
#    body: 6
#    conditions: 7\n4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))
#    core type: Lambda
#    parameter: 30
#    body: 8
# 6. Q__x_
#    core type: Indexed
#    var: 39
#    index: 15
#    base: "1"
# 7. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. _x_ in {1...k}
#    core type: Operation
#    operator: 40
#    operands: 12
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} , (x in S) and Q_1(x) and  ...  and Q_k(x))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 15, 43
# 13. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 40
#     operands: 16
# 14. (x in S) and Q_1(x) and  ...  and Q_k(x)
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. _x_
#     core type: Variable
#     sub-expressions:
# 16. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 30, 19
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x in S , Q_1(x) ,  ...  , Q_k(x))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 22
#     operand: 23
# 20. x in S
#     core type: Operation
#     operator: 40
#     operands: 24
# 21. Q_1(x),...,Q_k(x)
#     core type: Iter
#     lambda_map: 25
#     start_index: 46
#     end_index: 47
# 22. Set
#     core type: Literal
#     sub-expressions:
# 23. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 37
#     body: 37
#     conditions: 26\n24. (x , S)
#     core type: ExprTuple
#     sub-expressions: 30, 33
# 25. i -> Q_i(x) | i in {1...k}
#     core type: Lambda
#     parameter: 42
#     body: 27
#     conditions: 35\n26. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. Q_i(x)
#     core type: Operation
#     operator: 36
#     operand: 30
# 28. y in S
#     core type: Operation
#     operator: 40
#     operands: 31
# 29. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 32
#     start_index: 46
#     end_index: 47
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. (y , S)
#     core type: ExprTuple
#     sub-expressions: 37, 33
# 32. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 42
#     body: 34
#     conditions: 35\n33. S
#     core type: Variable
#     sub-expressions:
# 34. Q_i(y)
#     core type: Operation
#     operator: 36
#     operand: 37
# 35. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 38
# 36. Q_i
#     core type: Indexed
#     var: 39
#     index: 42
#     base: "1"
# 37. y
#     core type: Variable
#     sub-expressions:
# 38. i in {1...k}
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. Q
#     core type: Variable
#     sub-expressions:
# 40. in
#     core type: Literal
#     sub-expressions:
# 41. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 42. i
#     core type: Variable
#     sub-expressions:
# 43. {1...k}
#     core type: Operation
#     operator: 44
#     operands: 45
# 44. Interval
#     core type: Literal
#     sub-expressions:
# 45. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 46. 1
#     core type: Literal
#     sub-expressions:
# 47. k
#     core type: Variable
#     sub-expressions:
