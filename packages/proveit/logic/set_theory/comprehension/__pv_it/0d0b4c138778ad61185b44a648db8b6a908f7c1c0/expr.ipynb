# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import And, Equals, InSet
from proveit.logic._common_ import iterQ1k_x
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Equals(InSet(x, basicComprehension_y), And(InSet(x, S), iterQ1k_x)).withWrappingAt(1))
# Out:
# expr: x -> ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))
#    core type: Lambda
#    parameter: 20
#    body: 1
# 1. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} , (x in S) and Q_1(x) and  ...  and Q_k(x))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 30
#    operands: 6
# 5. (x in S) and Q_1(x) and  ...  and Q_k(x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 20, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in S , Q_1(x) ,  ...  , Q_k(x))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. x in S
#     core type: Operation
#     operator: 30
#     operands: 14
# 11. Q_1(x),...,Q_k(x)
#     core type: Iter
#     lambda_map: 15
#     start_index: 36
#     end_index: 37
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 27
#     body: 27
#     conditions: 16\n14. (x , S)
#     core type: ExprTuple
#     sub-expressions: 20, 23
# 15. i -> Q_i(x) | i in {1...k}
#     core type: Lambda
#     parameter: 32
#     body: 17
#     conditions: 25\n16. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Q_i(x)
#     core type: Operation
#     operator: 26
#     operand: 20
# 18. y in S
#     core type: Operation
#     operator: 30
#     operands: 21
# 19. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 22
#     start_index: 36
#     end_index: 37
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. (y , S)
#     core type: ExprTuple
#     sub-expressions: 27, 23
# 22. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 32
#     body: 24
#     conditions: 25\n23. S
#     core type: Variable
#     sub-expressions:
# 24. Q_i(y)
#     core type: Operation
#     operator: 26
#     operand: 27
# 25. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 28
# 26. Q_i
#     core type: Indexed
#     var: 29
#     index: 32
#     base: "1"
# 27. y
#     core type: Variable
#     sub-expressions:
# 28. i in {1...k}
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. Q
#     core type: Variable
#     sub-expressions:
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. i
#     core type: Variable
#     sub-expressions:
# 33. {1...k}
#     core type: Operation
#     operator: 34
#     operands: 35
# 34. Interval
#     core type: Literal
#     sub-expressions:
# 35. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. k
#     core type: Variable
#     sub-expressions:
