# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, x
from proveit.logic import And, Forall, InSet
from proveit.logic._common_ import iterQ1k, iterQ1k_x
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([S, iterQ1k], Forall([x], And(InSet(x, S), iterQ1k_x), domain = basicComprehension_y, conditions = subExpr1), conditions = subExpr1)
# Out:
# expr: forall_{S, Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S, Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. S -> [forall_{Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]]
#    core type: Lambda
#    parameter: 34
#    body: 2
# 2. forall_{Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]
#    core type: Operation
#    operator: 7
#    operand: 3
# 3. (Q_1,...,Q_k) -> [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]
#    core type: Lambda
#    parameter: 4
#    body: 5
# 4. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 6
#    start_index: 47
#    end_index: 48
# 5. forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))
#    core type: Operation
#    operator: 7
# ...
