# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#comprehensionDef">comprehensionDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.comprehension._axioms_ import comprehensionDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr comprehensionDef
# Out:
# Passed sanity check: built 'comprehensionDef' is the same as the stored Expression.

# %%
# display the expression information
comprehensionDef.exprInfo()
# Out:
# 0. forall_{k in Naturals} [forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])]
#    core type: Operation
#    operator: 18
#    operand: 1
# 1. k -> [forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])] | k in Naturals
#    core type: Lambda
#    parameter: 57
#    body: 2
#    conditions: 3\n2. forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])
#    core type: Operation
#    operator: 18
#    operand: 4
# 3. (k in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. S -> [forall_{Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = [exists_{y in S | Q_1(y) ,  ...  , Q_k(y)} (x = f(y))])]
#    core type: Lambda
#    parameter: 43
#    body: 6
# 5. k in Naturals
# ...
