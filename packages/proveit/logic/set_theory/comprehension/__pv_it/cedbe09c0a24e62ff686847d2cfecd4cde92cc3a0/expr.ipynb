# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, k, x
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterQ1k
from proveit.logic.set_theory._common_ import basicComprehension_y
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(k, Forall([S, iterQ1k], Forall([x], InSet(x, S), domain = basicComprehension_y, conditions = subExpr1), conditions = subExpr1), conditions = [InSet(k, NaturalsPos)])
# Out:
# expr: k -> [forall_{S, Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]] | k in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. k -> [forall_{S, Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]] | k in NaturalsPos
#    core type: Lambda
#    parameter: 47
#    body: 1
#    conditions: 2\n1. forall_{S, Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]
#    core type: Operation
#    operator: 12
#    operand: 3
# 2. (k in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. S -> [forall_{Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]]
#    core type: Lambda
#    parameter: 33
#    body: 5
# 4. k in NaturalsPos
#    core type: Operation
#    operator: 40
#    operands: 6
# 5. forall_{Q_1,...,Q_k} [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]
#    core type: Operation
#    operator: 12
#    operand: 7
# 6. (k , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 47, 8
# 7. (Q_1,...,Q_k) -> [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]
# ...
