# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#basicComprehension">basicComprehension</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.comprehension._theorems_ import basicComprehension

# %%
# check that the built expression is the same as the stored expression
# %check_expr basicComprehension
# Out:
# Passed sanity check: built 'basicComprehension' is the same as the stored Expression.

# %%
# display the expression information
basicComprehension.exprInfo()
# Out:
# 0. forall_{(k, l) in Naturals * NaturalsPos} [forall_{S, Q_1,...,Q_k, x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))]
#    core type: Operation
#    operator: 20
#    operand: 1
# 1. k -> [forall_{l in NaturalsPos} [forall_{S, Q_1,...,Q_k, x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))]] | k in Naturals
#    core type: Lambda
#    parameter: 63
#    body: 2
#    conditions: 3\n2. forall_{l in NaturalsPos} [forall_{S, Q_1,...,Q_k, x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (k in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. l -> [forall_{S, Q_1,...,Q_k, x} ((x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  = ((x in S) and Q_1(x) and  ...  and Q_k(x)))] | l in NaturalsPos
#    core type: Lambda
#    parameter: 15
# ...
