# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterQ1k, iterQ1k_x
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(iterQ1k, Forall([x], InSet(x, basicComprehension_y), domain = S, conditions = [iterQ1k_x]))
# Out:
# expr: (Q_1,...,Q_k) -> [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1,...,Q_k) -> [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]
#    core type: Lambda
#    parameter: 1
#    body: 2
# 1. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 3
#    start_index: 41
#    end_index: 42
# 2. forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 18
#    body: 6
#    conditions: 7\n4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) | x in S , Q_1(x) ,  ...  , Q_k(x)
#    core type: Lambda
#    parameter: 23
#    body: 8
#    conditions: 9\n6. Q__x_
#    core type: Indexed
#    var: 34
#    index: 18
#    base: "1"
# 7. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 35
#    operands: 11
# 9. (x in S , Q_1(x) ,  ...  , Q_k(x))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. _x_ in {1...k}
#     core type: Operation
#     operator: 35
#     operands: 14
# 11. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 23, 15
# 12. x in S
#     core type: Operation
#     operator: 35
#     operands: 16
# 13. Q_1(x),...,Q_k(x)
#     core type: Iter
#     lambda_map: 17
#     start_index: 41
#     end_index: 42
# 14. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 18, 38
# 15. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 19
#     operand: 20
# 16. (x , S)
#     core type: ExprTuple
#     sub-expressions: 23, 28
# 17. i -> Q_i(x) | i in {1...k}
#     core type: Lambda
#     parameter: 37
#     body: 21
#     conditions: 30\n18. _x_
#     core type: Variable
#     sub-expressions:
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 32
#     body: 32
#     conditions: 22\n21. Q_i(x)
#     core type: Operation
#     operator: 31
#     operand: 23
# 22. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y in S
#     core type: Operation
#     operator: 35
#     operands: 26
# 25. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 27
#     start_index: 41
#     end_index: 42
# 26. (y , S)
#     core type: ExprTuple
#     sub-expressions: 32, 28
# 27. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 37
#     body: 29
#     conditions: 30\n28. S
#     core type: Variable
#     sub-expressions:
# 29. Q_i(y)
#     core type: Operation
#     operator: 31
#     operand: 32
# 30. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 33
# 31. Q_i
#     core type: Indexed
#     var: 34
#     index: 37
#     base: "1"
# 32. y
#     core type: Variable
#     sub-expressions:
# 33. i in {1...k}
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. Q
#     core type: Variable
#     sub-expressions:
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. {1...k}
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. Interval
#     core type: Literal
#     sub-expressions:
# 40. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. k
#     core type: Variable
#     sub-expressions:
