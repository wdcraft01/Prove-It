# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, l, x, yy
from proveit.logic import Equals, Exists
from proveit.logic._common_ import f_yIter1l, iterQ1k_yIter1l
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Exists([yy], Equals(x, f_yIter1l), domain = Exp(S, l), conditions = [iterQ1k_yIter1l])
# Out:
# expr: exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. y -> (x = f(y_1,...,y_l)) | y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 30
#    body: 3
#    conditions: 4\n3. x = f(y_1,...,y_l)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (y in S^{l} , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x , f(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. y in S^{l}
#    core type: Operation
#    operator: 33
#    operands: 11
# 8. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#    core type: Iter
#    lambda_map: 12
#    start_index: 40
#    end_index: 35
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. f(y_1,...,y_l)
#     core type: Operation
#     operator: 13
#     operand: 20
# 11. (y , S^{l})
#     core type: ExprTuple
#     sub-expressions: 30, 14
# 12. i -> Q_i(y_1,...,y_l) | i in {1...k}
#     core type: Lambda
#     parameter: 28
#     body: 15
#     conditions: 16\n13. f
#     core type: Variable
#     sub-expressions:
# 14. S^{l}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. Q_i(y_1,...,y_l)
#     core type: Operation
#     operator: 19
#     operand: 20
# 16. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 21
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (S , l)
#     core type: ExprTuple
#     sub-expressions: 22, 41
# 19. Q_i
#     core type: Indexed
#     var: 23
#     index: 28
#     base: "1"
# 20. y_1,...,y_l
#     core type: Iter
#     lambda_map: 24
#     start_index: 40
#     end_index: 41
# 21. i in {1...k}
#     core type: Operation
#     operator: 33
#     operands: 25
# 22. S
#     core type: Variable
#     sub-expressions:
# 23. Q
#     core type: Variable
#     sub-expressions:
# 24. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 36
#     body: 26
#     conditions: 27\n25. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. y__x_
#     core type: Indexed
#     var: 30
#     index: 36
#     base: "1"
# 27. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 31
# 28. i
#     core type: Variable
#     sub-expressions:
# 29. {1...k}
#     core type: Operation
#     operator: 38
#     operands: 32
# 30. y
#     core type: Variable
#     sub-expressions:
# 31. _x_ in {1...l}
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 40, 35
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. k
#     core type: Variable
#     sub-expressions:
# 36. _x_
#     core type: Variable
#     sub-expressions:
# 37. {1...l}
#     core type: Operation
#     operator: 38
#     operands: 39
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. l
#     core type: Variable
#     sub-expressions:
