# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#foldBasicComprehension">foldBasicComprehension</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.comprehension._theorems_ import foldBasicComprehension

# %%
# check that the built expression is the same as the stored expression
# %check_expr foldBasicComprehension
# Out:
# Passed sanity check: built 'foldBasicComprehension' is the same as the stored Expression.

# %%
# display the expression information
foldBasicComprehension.exprInfo()
# Out:
# 0. forall_{k} [forall_{S, Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. k -> [forall_{S, Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]]
#    core type: Lambda
#    parameter: 47
#    body: 2
# 2. forall_{S, Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]
#    core type: Operation
#    operator: 9
#    operand: 3
# 3. S -> [forall_{Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]]
#    core type: Lambda
#    parameter: 33
#    body: 4
# 4. forall_{Q_1,...,Q_k} [forall_{x in S | Q_1(x) ,  ...  , Q_k(x)} (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})]
#    core type: Operation
#    operator: 9
#    operand: 5
# ...
