# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterQ1k
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(iterQ1k, Forall([x], InSet(x, S), domain = basicComprehension_y, conditions = []))
# Out:
# expr: (Q_1,...,Q_k) -> [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1,...,Q_k) -> [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)]
#    core type: Lambda
#    parameter: 1
#    body: 2
# 1. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 3
#    start_index: 38
#    end_index: 39
# 2. forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} (x in S)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 15
#    body: 6
#    conditions: 7\n4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> (x in S) | x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Lambda
#    parameter: 16
#    body: 8
#    conditions: 9\n6. Q__x_
#    core type: Indexed
#    var: 31
#    index: 15
#    base: "1"
# 7. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. x in S
#    core type: Operation
#    operator: 32
#    operands: 11
# 9. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. _x_ in {1...k}
#     core type: Operation
#     operator: 32
#     operands: 13
# 11. (x , S)
#     core type: ExprTuple
#     sub-expressions: 16, 25
# 12. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 32
#     operands: 14
# 13. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 15, 35
# 14. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. _x_
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 18
#     operand: 19
# 18. Set
#     core type: Literal
#     sub-expressions:
# 19. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 29
#     body: 29
#     conditions: 20\n20. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. y in S
#     core type: Operation
#     operator: 32
#     operands: 23
# 22. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 24
#     start_index: 38
#     end_index: 39
# 23. (y , S)
#     core type: ExprTuple
#     sub-expressions: 29, 25
# 24. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 34
#     body: 26
#     conditions: 27\n25. S
#     core type: Variable
#     sub-expressions:
# 26. Q_i(y)
#     core type: Operation
#     operator: 28
#     operand: 29
# 27. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 30
# 28. Q_i
#     core type: Indexed
#     var: 31
#     index: 34
#     base: "1"
# 29. y
#     core type: Variable
#     sub-expressions:
# 30. i in {1...k}
#     core type: Operation
#     operator: 32
#     operands: 33
# 31. Q
#     core type: Variable
#     sub-expressions:
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. i
#     core type: Variable
#     sub-expressions:
# 35. {1...k}
#     core type: Operation
#     operator: 36
#     operands: 37
# 36. Interval
#     core type: Literal
#     sub-expressions:
# 37. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. k
#     core type: Variable
#     sub-expressions:
