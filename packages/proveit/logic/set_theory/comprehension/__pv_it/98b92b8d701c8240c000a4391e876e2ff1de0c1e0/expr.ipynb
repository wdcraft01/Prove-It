# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import And, Forall, InSet
from proveit.logic._common_ import iterQ1k, iterQ1k_x
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(iterQ1k, Forall([x], And(InSet(x, S), iterQ1k_x), domain = basicComprehension_y, conditions = []))
# Out:
# expr: (Q_1,...,Q_k) -> [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1,...,Q_k) -> [forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))]
#    core type: Lambda
#    parameter: 1
#    body: 2
# 1. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 3
#    start_index: 44
#    end_index: 45
# 2. forall_{x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}} ((x in S) and Q_1(x) and  ...  and Q_k(x))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 18
#    body: 6
#    conditions: 7\n4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> ((x in S) and Q_1(x) and  ...  and Q_k(x)) | x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Lambda
#    parameter: 25
#    body: 8
#    conditions: 9\n6. Q__x_
#    core type: Indexed
#    var: 37
#    index: 18
#    base: "1"
# 7. (_x_ in {1...k})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (x in S) and Q_1(x) and  ...  and Q_k(x)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. _x_ in {1...k}
#     core type: Operation
#     operator: 38
#     operands: 14
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (x in S , Q_1(x) ,  ...  , Q_k(x))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 38
#     operands: 17
# 14. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 18, 41
# 15. x in S
#     core type: Operation
#     operator: 38
#     operands: 19
# 16. Q_1(x),...,Q_k(x)
#     core type: Iter
#     lambda_map: 20
#     start_index: 44
#     end_index: 45
# 17. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 18. _x_
#     core type: Variable
#     sub-expressions:
# 19. (x , S)
#     core type: ExprTuple
#     sub-expressions: 25, 31
# 20. i -> Q_i(x) | i in {1...k}
#     core type: Lambda
#     parameter: 40
#     body: 22
#     conditions: 33\n21. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#     core type: Operation
#     operator: 23
#     operand: 24
# 22. Q_i(x)
#     core type: Operation
#     operator: 34
#     operand: 25
# 23. Set
#     core type: Literal
#     sub-expressions:
# 24. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#     core type: Lambda
#     parameter: 35
#     body: 35
#     conditions: 26\n25. x
#     core type: Variable
#     sub-expressions:
# 26. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. y in S
#     core type: Operation
#     operator: 38
#     operands: 29
# 28. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 30
#     start_index: 44
#     end_index: 45
# 29. (y , S)
#     core type: ExprTuple
#     sub-expressions: 35, 31
# 30. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 40
#     body: 32
#     conditions: 33\n31. S
#     core type: Variable
#     sub-expressions:
# 32. Q_i(y)
#     core type: Operation
#     operator: 34
#     operand: 35
# 33. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 36
# 34. Q_i
#     core type: Indexed
#     var: 37
#     index: 40
#     base: "1"
# 35. y
#     core type: Variable
#     sub-expressions:
# 36. i in {1...k}
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. Q
#     core type: Variable
#     sub-expressions:
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. i
#     core type: Variable
#     sub-expressions:
# 41. {1...k}
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. Interval
#     core type: Literal
#     sub-expressions:
# 43. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. k
#     core type: Variable
#     sub-expressions:
