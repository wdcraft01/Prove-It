# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, l, x, yy
from proveit.logic import Equals, Exists, Forall, Implies, InSet
from proveit.logic._common_ import f_yIter1l, iterQ1k_yIter1l
from proveit.logic.set_theory._common_ import generalComprehension_fy
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([x], Implies(InSet(x, generalComprehension_fy), Exists([yy], Equals(x, f_yIter1l), domain = Exp(S, l), conditions = [iterQ1k_yIter1l])).withWrappingAt(1), conditions = [])
# Out:
# expr: forall_{x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])
#    core type: Lambda
#    parameter: 22
#    body: 3
# 3. (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))]
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S} , exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# ...
