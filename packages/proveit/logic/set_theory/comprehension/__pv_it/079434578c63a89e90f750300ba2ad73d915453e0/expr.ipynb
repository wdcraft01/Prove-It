# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import S, x
from proveit.logic import InSet
from proveit.logic._common_ import iterQ1k_x

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(x, S), iterQ1k_x)
# Out:
# expr: (x in S , Q_1(x) ,  ...  , Q_k(x))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in S , Q_1(x) ,  ...  , Q_k(x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x in S
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. Q_1(x),...,Q_k(x)
#    core type: Iter
#    lambda_map: 4
#    start_index: 18
#    end_index: 19
# 3. (x , S)
#    core type: ExprTuple
#    sub-expressions: 9, 5
# 4. i -> Q_i(x) | i in {1...k}
#    core type: Lambda
#    parameter: 14
#    body: 6
#    conditions: 7\n5. S
#    core type: Variable
#    sub-expressions:
# 6. Q_i(x)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Q_i
#    core type: Indexed
#    var: 11
#    index: 14
#    base: "1"
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. i in {1...k}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (i , {1...k})
# ...
