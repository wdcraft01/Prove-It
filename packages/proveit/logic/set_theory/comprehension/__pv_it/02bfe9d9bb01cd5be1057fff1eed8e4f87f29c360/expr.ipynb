# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import InSet
from proveit.logic.set_theory._common_ import basicComprehension_y

# %%
# build up the expression from sub-expressions
expr = Lambda(x, InSet(x, S), conditions = [InSet(x, basicComprehension_y)])
# Out:
# expr: x -> (x in S) | x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> (x in S) | x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Lambda
#    parameter: 6
#    body: 1
#    conditions: 2\n1. x in S
#    core type: Operation
#    operator: 22
#    operands: 3
# 2. (x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (x , S)
#    core type: ExprTuple
#    sub-expressions: 6, 15
# 4. x in {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 22
#    operands: 5
# 5. (x , {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. {y s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. Set
#    core type: Literal
#    sub-expressions:
# 9. y -> y | y in S , Q_1(y) ,  ...  , Q_k(y)
#    core type: Lambda
#    parameter: 19
#    body: 19
#    conditions: 10\n10. (y in S , Q_1(y) ,  ...  , Q_k(y))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. y in S
#     core type: Operation
#     operator: 22
#     operands: 13
# 12. Q_1(y),...,Q_k(y)
#     core type: Iter
#     lambda_map: 14
#     start_index: 28
#     end_index: 29
# 13. (y , S)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 14. i -> Q_i(y) | i in {1...k}
#     core type: Lambda
#     parameter: 24
#     body: 16
#     conditions: 17\n15. S
#     core type: Variable
#     sub-expressions:
# 16. Q_i(y)
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. Q_i
#     core type: Indexed
#     var: 21
#     index: 24
#     base: "1"
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. i in {1...k}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. Q
#     core type: Variable
#     sub-expressions:
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. {1...k}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. k
#     core type: Variable
#     sub-expressions:
