# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.comprehension</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, f, l, x, yy
from proveit.logic import Equals, Exists, Forall, Implies, InSet
from proveit.logic._common_ import f_yIter1l, iterQ1k, iterQ1k_yIter1l
from proveit.logic.set_theory._common_ import generalComprehension_fy
from proveit.number import Exp, NaturalsPos

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([l], Forall([S, iterQ1k, f, x], Implies(InSet(x, generalComprehension_fy), Exists([yy], Equals(x, f_yIter1l), domain = Exp(S, l), conditions = [iterQ1k_yIter1l])).withWrappingAt(1), conditions = subExpr1), domain = NaturalsPos, conditions = subExpr1)
# Out:
# expr: forall_{l in NaturalsPos} [forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{l in NaturalsPos} [forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])]
#    core type: Operation
#    operator: 18
#    operand: 1
# 1. l -> [forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])] | l in NaturalsPos
#    core type: Lambda
#    parameter: 78
#    body: 2
#    conditions: 3\n2. forall_{S, Q_1,...,Q_k, f, x} ((x in {f(y) s.t. (Q_1(y) ,  ...  , Q_k(y))}_{y in S}) \\  => [exists_{y in S^{l} | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (x = f(y_1,...,y_l))])
#    core type: Operation
#    operator: 18
#    operand: 4
# 3. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 5
# ...
