# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import InSet
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m)
# Out:
# expr: (x in A_1),...,(x in A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x in A_1),...,(x in A_m)
#    core type: Iter
#    lambda_map: 1
#    start_index: 15
#    end_index: 16
# 1. i -> (x in A_i) | i in {1...m}
#    core type: Lambda
#    parameter: 11
#    body: 2
#    conditions: 3\n2. x in A_i
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (x , A_i)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. i in {1...m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. A_i
#    core type: Indexed
#    var: 10
#    index: 11
#    base: "1"
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i , {1...m})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. {1...m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
