# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Forall, InSet, Intersect
from proveit.logic._common_ import iterA1m
from proveit.number import NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([x, iterA1m], And(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m)), conditions = [InSet(x, Intersect(iterA1m))]), conditions = [InSet(m, NaturalsPos)])
# Out:
# expr: m -> [forall_{x, A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))] | m in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{x, A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))] | m in NaturalsPos
#    core type: Lambda
#    parameter: 42
#    body: 1
#    conditions: 2\n1. forall_{x, A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. x -> [forall_{A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))]
#    core type: Lambda
#    parameter: 26
#    body: 5
# 4. m in NaturalsPos
#    core type: Operation
#    operator: 35
#    operands: 6
# 5. forall_{A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (m , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 42, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (A_1,...,A_m) -> ((x in A_1) and  ...  and (x in A_m)) | x in (A_1 intersect  ...  intersect A_m)
#    core type: Lambda
#    parameter: 25
#    body: 10
#    conditions: 11\n9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. (x in A_1) and  ...  and (x in A_m)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x in (A_1 intersect  ...  intersect A_m))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (x in A_1 ,  ...  , x in A_m)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. x in (A_1 intersect  ...  intersect A_m)
#     core type: Operation
#     operator: 35
#     operands: 16
# 15. (x in A_1),...,(x in A_m)
#     core type: Iter
#     lambda_map: 17
#     start_index: 41
#     end_index: 42
# 16. (x , A_1 intersect  ...  intersect A_m)
#     core type: ExprTuple
#     sub-expressions: 26, 18
# 17. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 30
#     body: 19
#     conditions: 20\n18. A_1 intersect  ...  intersect A_m
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. x in A_i
#     core type: Operation
#     operator: 35
#     operands: 23
# 20. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. intersect
#     core type: Literal
#     sub-expressions:
# 22. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. i in {1...m}
#     core type: Operation
#     operator: 35
#     operands: 28
# 25. A_1,...,A_m
#     core type: Iter
#     lambda_map: 29
#     start_index: 41
#     end_index: 42
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. A_i
#     core type: Indexed
#     var: 33
#     index: 30
#     base: "1"
# 28. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 30, 38
# 29. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 37
#     body: 31
#     conditions: 32\n30. i
#     core type: Variable
#     sub-expressions:
# 31. A__x_
#     core type: Indexed
#     var: 33
#     index: 37
#     base: "1"
# 32. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 34
# 33. A
#     core type: Variable
#     sub-expressions:
# 34. _x_ in {1...m}
#     core type: Operation
#     operator: 35
#     operands: 36
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. _x_
#     core type: Variable
#     sub-expressions:
# 38. {1...m}
#     core type: Operation
#     operator: 39
#     operands: 40
# 39. Interval
#     core type: Literal
#     sub-expressions:
# 40. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. m
#     core type: Variable
#     sub-expressions:
