# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import And, InSet
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m)))
# Out:
# expr: ((x in A_1) and  ...  and (x in A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((x in A_1) and  ...  and (x in A_m))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x in A_1) and  ...  and (x in A_m)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. (x in A_1 ,  ...  , x in A_m)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (x in A_1),...,(x in A_m)
#    core type: Iter
#    lambda_map: 5
#    start_index: 19
#    end_index: 20
# 5. i -> (x in A_i) | i in {1...m}
#    core type: Lambda
#    parameter: 15
#    body: 6
#    conditions: 7\n6. x in A_i
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x , A_i)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. i in {1...m}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. A_i
#     core type: Indexed
#     var: 14
#     index: 15
#     base: "1"
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. i
#     core type: Variable
#     sub-expressions:
# 16. {1...m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. m
#     core type: Variable
#     sub-expressions:
