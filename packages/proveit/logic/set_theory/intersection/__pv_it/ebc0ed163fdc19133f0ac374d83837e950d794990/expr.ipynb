# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Forall, InSet, Intersect
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([x, iterA1m], And(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m)), conditions = [InSet(x, Intersect(iterA1m))])
# Out:
# expr: forall_{x, A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))]
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. forall_{A_1,...,A_m | x in (A_1 intersect  ...  intersect A_m)} ((x in A_1) and  ...  and (x in A_m))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_1,...,A_m) -> ((x in A_1) and  ...  and (x in A_m)) | x in (A_1 intersect  ...  intersect A_m)
#    core type: Lambda
#    parameter: 20
#    body: 5
#    conditions: 6\n5. (x in A_1) and  ...  and (x in A_m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in (A_1 intersect  ...  intersect A_m))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# ...
