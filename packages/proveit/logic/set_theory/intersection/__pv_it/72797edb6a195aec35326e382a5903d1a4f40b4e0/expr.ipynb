# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import S
from proveit.logic import Forall, Implies, InSet, Intersect, SubsetEq

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Intersect(S, S)
expr = Implies(Forall([subExpr1], InSet(subExpr1, subExpr2), domain = S, conditions = []), SubsetEq(S, subExpr2))
# Out:
# expr: [forall_{_x_ in S} (_x_ in (S intersect S))] => (S subseteq (S intersect S))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [forall_{_x_ in S} (_x_ in (S intersect S))] => (S subseteq (S intersect S))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{_x_ in S} (_x_ in (S intersect S)) , S subseteq (S intersect S))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{_x_ in S} (_x_ in (S intersect S))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. S subseteq (S intersect S)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. _x_ -> (_x_ in (S intersect S)) | _x_ in S
#    core type: Lambda
#    parameter: 18
#    body: 9
#    conditions: 10\n7. subseteq
#    core type: Literal
#    sub-expressions:
# 8. (S , S intersect S)
#    core type: ExprTuple
#    sub-expressions: 19, 13
# 9. _x_ in (S intersect S)
#    core type: Operation
#    operator: 14
#    operands: 11
# 10. (_x_ in S)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (_x_ , S intersect S)
#     core type: ExprTuple
#     sub-expressions: 18, 13
# 12. _x_ in S
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. S intersect S
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (_x_ , S)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. intersect
#     core type: Literal
#     sub-expressions:
# 17. (S , S)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 18. _x_
#     core type: Variable
#     sub-expressions:
# 19. S
#     core type: Variable
#     sub-expressions:
