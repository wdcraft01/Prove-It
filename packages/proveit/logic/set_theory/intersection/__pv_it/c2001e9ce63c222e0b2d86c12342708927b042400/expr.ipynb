# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#intersectionDef">intersectionDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.intersection._axioms_ import intersectionDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr intersectionDef
# Out:
# Passed sanity check: built 'intersectionDef' is the same as the stored Expression.

# %%
# display the expression information
intersectionDef.exprInfo()
# Out:
# 0. forall_{m in NaturalsPos} [forall_{x, A_1,...,A_m} ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))]
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. m -> [forall_{x, A_1,...,A_m} ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))] | m in NaturalsPos
#    core type: Lambda
#    parameter: 45
#    body: 2
#    conditions: 3\n2. forall_{x, A_1,...,A_m} ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{A_1,...,A_m} ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))]
#    core type: Lambda
#    parameter: 32
#    body: 6
# 5. m in NaturalsPos
#    core type: Operation
#    operator: 38
#    operands: 7
# 6. forall_{A_1,...,A_m} ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (m , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 45, 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. (A_1,...,A_m) -> ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))
#    core type: Lambda
#    parameter: 24
#    body: 11
# 10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. (x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m))
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (x in (A_1 intersect  ...  intersect A_m) , (x in A_1) and  ...  and (x in A_m))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. x in (A_1 intersect  ...  intersect A_m)
#     core type: Operation
#     operator: 38
#     operands: 16
# 15. (x in A_1) and  ...  and (x in A_m)
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x , A_1 intersect  ...  intersect A_m)
#     core type: ExprTuple
#     sub-expressions: 32, 19
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x in A_1 ,  ...  , x in A_m)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. A_1 intersect  ...  intersect A_m
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (x in A_1),...,(x in A_m)
#     core type: Iter
#     lambda_map: 23
#     start_index: 44
#     end_index: 45
# 21. intersect
#     core type: Literal
#     sub-expressions:
# 22. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. i -> (x in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 37
#     body: 25
#     conditions: 26\n24. A_1,...,A_m
#     core type: Iter
#     lambda_map: 27
#     start_index: 44
#     end_index: 45
# 25. x in A_i
#     core type: Operation
#     operator: 38
#     operands: 28
# 26. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 29
# 27. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 40
#     body: 30
#     conditions: 31\n28. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. i in {1...m}
#     core type: Operation
#     operator: 38
#     operands: 34
# 30. A__x_
#     core type: Indexed
#     var: 36
#     index: 40
#     base: "1"
# 31. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. A_i
#     core type: Indexed
#     var: 36
#     index: 37
#     base: "1"
# 34. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 37, 41
# 35. _x_ in {1...m}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. A
#     core type: Variable
#     sub-expressions:
# 37. i
#     core type: Variable
#     sub-expressions:
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. _x_
#     core type: Variable
#     sub-expressions:
# 41. {1...m}
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. Interval
#     core type: Literal
#     sub-expressions:
# 43. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. m
#     core type: Variable
#     sub-expressions:
