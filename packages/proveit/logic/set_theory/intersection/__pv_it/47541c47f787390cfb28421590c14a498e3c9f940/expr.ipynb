# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import Equals, Forall, Intersect, NotInSet, Or
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([iterA1m], Equals(NotInSet(x, Intersect(iterA1m)), Or(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m))), conditions = [])
# Out:
# expr: forall_{A_1,...,A_m} ((x not-in (A_1 intersect  ...  intersect A_m)) = ((x not-in A_1) or  ...  or (x not-in A_m)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A_1,...,A_m} ((x not-in (A_1 intersect  ...  intersect A_m)) = ((x not-in A_1) or  ...  or (x not-in A_m)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_1,...,A_m) -> ((x not-in (A_1 intersect  ...  intersect A_m)) = ((x not-in A_1) or  ...  or (x not-in A_m)))
#    core type: Lambda
#    parameter: 16
#    body: 3
# 3. (x not-in (A_1 intersect  ...  intersect A_m)) = ((x not-in A_1) or  ...  or (x not-in A_m))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (x not-in (A_1 intersect  ...  intersect A_m) , (x not-in A_1) or  ...  or (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x not-in (A_1 intersect  ...  intersect A_m)
#    core type: Operation
#    operator: 20
#    operands: 8
# 7. (x not-in A_1) or  ...  or (x not-in A_m)
#    core type: Operation
#    operator: 9
#    operands: 10
# ...
