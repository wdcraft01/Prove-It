# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, x
from proveit.logic import NotInSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(NotInSet(x, A), NotInSet(x, B), NotInSet(x, C)))
# Out:
# expr: {(x not-in A) or (x not-in B) or (x not-in C)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(x not-in A) or (x not-in B) or (x not-in C)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ((x not-in A) or (x not-in B) or (x not-in C))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x not-in A) or (x not-in B) or (x not-in C)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (x not-in A , x not-in B , x not-in C)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. x not-in A
#    core type: Operation
#    operator: 11
#    operands: 9
# 7. x not-in B
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. x not-in C
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (x , A)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 10. (x , B)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. not-in
#     core type: Literal
#     sub-expressions:
# 12. (x , C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
