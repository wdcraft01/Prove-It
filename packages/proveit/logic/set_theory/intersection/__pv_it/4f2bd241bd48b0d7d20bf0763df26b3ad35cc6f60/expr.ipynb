# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Forall, InSet, Intersect
from proveit.logic._common_ import iterA1m
from proveit.number import NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([x, iterA1m], InSet(x, Intersect(iterA1m)), conditions = [And(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m))]), conditions = [InSet(m, NaturalsPos)])
# Out:
# expr: m -> [forall_{x, A_1,...,A_m | (x in A_1) and  ...  and (x in A_m)} (x in (A_1 intersect  ...  intersect A_m))] | m in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{x, A_1,...,A_m | (x in A_1) and  ...  and (x in A_m)} (x in (A_1 intersect  ...  intersect A_m))] | m in NaturalsPos
#    core type: Lambda
#    parameter: 42
#    body: 1
#    conditions: 2\n1. forall_{x, A_1,...,A_m | (x in A_1) and  ...  and (x in A_m)} (x in (A_1 intersect  ...  intersect A_m))
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (m in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. x -> [forall_{A_1,...,A_m | (x in A_1) and  ...  and (x in A_m)} (x in (A_1 intersect  ...  intersect A_m))]
#    core type: Lambda
#    parameter: 30
#    body: 5
# 4. m in NaturalsPos
#    core type: Operation
#    operator: 33
#    operands: 6
# 5. forall_{A_1,...,A_m | (x in A_1) and  ...  and (x in A_m)} (x in (A_1 intersect  ...  intersect A_m))
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (m , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 42, 9
# 7. forall
#    core type: Literal
# ...
