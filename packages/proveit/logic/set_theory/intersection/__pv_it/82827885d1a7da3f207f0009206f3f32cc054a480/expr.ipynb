# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import Intersect, NotInSet, Or
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(NotInSet(x, Intersect(iterA1m)), Or(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m)))
# Out:
# expr: (x not-in (A_1 intersect  ...  intersect A_m) , (x not-in A_1) or  ...  or (x not-in A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x not-in (A_1 intersect  ...  intersect A_m) , (x not-in A_1) or  ...  or (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x not-in (A_1 intersect  ...  intersect A_m)
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (x not-in A_1) or  ...  or (x not-in A_m)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x , A_1 intersect  ...  intersect A_m)
#    core type: ExprTuple
#    sub-expressions: 20, 6
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (x not-in A_1 ,  ...  , x not-in A_m)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. A_1 intersect  ...  intersect A_m
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x not-in A_1),...,(x not-in A_m)
#    core type: Iter
#    lambda_map: 10
#    start_index: 32
#    end_index: 33
# 8. intersect
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. i -> (x not-in A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 25
#     body: 12
#     conditions: 13\n11. A_1,...,A_m
#     core type: Iter
#     lambda_map: 14
#     start_index: 32
#     end_index: 33
# 12. x not-in A_i
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 17
# 14. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 28
#     body: 18
#     conditions: 19\n15. not-in
#     core type: Literal
#     sub-expressions:
# 16. (x , A_i)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. i in {1...m}
#     core type: Operation
#     operator: 26
#     operands: 22
# 18. A__x_
#     core type: Indexed
#     var: 24
#     index: 28
#     base: "1"
# 19. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. A_i
#     core type: Indexed
#     var: 24
#     index: 25
#     base: "1"
# 22. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 25, 29
# 23. _x_ in {1...m}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. i
#     core type: Variable
#     sub-expressions:
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. _x_
#     core type: Variable
#     sub-expressions:
# 29. {1...m}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. m
#     core type: Variable
#     sub-expressions:
