# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import S
from proveit.logic import Forall, InSet, Intersect

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([subExpr1], InSet(subExpr1, Intersect(S, S)), domain = S, conditions = [])
# Out:
# expr: forall_{_x_ in S} (_x_ in (S intersect S))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{_x_ in S} (_x_ in (S intersect S))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. _x_ -> (_x_ in (S intersect S)) | _x_ in S
#    core type: Lambda
#    parameter: 12
#    body: 3
#    conditions: 4\n3. _x_ in (S intersect S)
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (_x_ in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (_x_ , S intersect S)
#    core type: ExprTuple
#    sub-expressions: 12, 7
# 6. _x_ in S
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. S intersect S
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (_x_ , S)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. intersect
#     core type: Literal
#     sub-expressions:
# 11. (S , S)
#     core type: ExprTuple
#     sub-expressions: 13, 13
# 12. _x_
#     core type: Variable
#     sub-expressions:
# 13. S
#     core type: Variable
#     sub-expressions:
