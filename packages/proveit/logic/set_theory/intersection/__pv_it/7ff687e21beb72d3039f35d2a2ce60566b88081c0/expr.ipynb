# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#x_not_in_any_A">x_not_in_any_A</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import the special expression
from proveit.logic.set_theory.intersection._common_ import x_not_in_any_A

# %%
# check that the built expression is the same as the stored expression
# %check_expr x_not_in_any_A
# Out:
# Passed sanity check: built 'x_not_in_any_A' is the same as the stored Expression.

# %%
# display the expression information
x_not_in_any_A.exprInfo()
# Out:
# 0. (x not-in A_1) or  ...  or (x not-in A_n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. or
#    core type: Literal
#    sub-expressions:
# 2. (x not-in A_1 ,  ...  , x not-in A_n)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x not-in A_1),...,(x not-in A_n)
#    core type: Iter
#    lambda_map: 4
#    start_index: 19
#    end_index: 20
# 4. i -> (x not-in A_i) | i in {1...n}
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. x not-in A_i
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (i in {1...n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. not-in
#    core type: Literal
#    sub-expressions:
# 8. (x , A_i)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. i in {1...n}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. A_i
#     core type: Indexed
#     var: 14
#     index: 15
#     base: "1"
# 12. in
# ...
