# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import And, Equals, InSet, Intersect
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(iterA1m, Equals(InSet(x, Intersect(iterA1m)), And(Iter(i, InSet(x, Indexed(AA, i, base = 1)), one, m))))
# Out:
# expr: (A_1,...,A_m) -> ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1,...,A_m) -> ((x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m)))
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. (x in (A_1 intersect  ...  intersect A_m)) = ((x in A_1) and  ...  and (x in A_m))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (x in (A_1 intersect  ...  intersect A_m) , (x in A_1) and  ...  and (x in A_m))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x in (A_1 intersect  ...  intersect A_m)
#    core type: Operation
#    operator: 28
#    operands: 6
# 5. (x in A_1) and  ...  and (x in A_m)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x , A_1 intersect  ...  intersect A_m)
#    core type: ExprTuple
#    sub-expressions: 22, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in A_1 ,  ...  , x in A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A_1 intersect  ...  intersect A_m
# ...
