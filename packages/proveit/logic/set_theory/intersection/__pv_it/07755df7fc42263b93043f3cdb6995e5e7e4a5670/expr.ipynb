# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.intersection</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import Forall, Intersect, NotInSet, Or
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([x, iterA1m], NotInSet(x, Intersect(iterA1m)), conditions = [Or(Iter(i, NotInSet(x, Indexed(AA, i, base = 1)), one, m))])
# Out:
# expr: forall_{x, A_1,...,A_m | (x not-in A_1) or  ...  or (x not-in A_m)} (x not-in (A_1 intersect  ...  intersect A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, A_1,...,A_m | (x not-in A_1) or  ...  or (x not-in A_m)} (x not-in (A_1 intersect  ...  intersect A_m))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{A_1,...,A_m | (x not-in A_1) or  ...  or (x not-in A_m)} (x not-in (A_1 intersect  ...  intersect A_m))]
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. forall_{A_1,...,A_m | (x not-in A_1) or  ...  or (x not-in A_m)} (x not-in (A_1 intersect  ...  intersect A_m))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (A_1,...,A_m) -> (x not-in (A_1 intersect  ...  intersect A_m)) | (x not-in A_1) or  ...  or (x not-in A_m)
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. x not-in (A_1 intersect  ...  intersect A_m)
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. ((x not-in A_1) or  ...  or (x not-in A_m))
#    core type: ExprTuple
#    sub-expressions: 8
# ...
