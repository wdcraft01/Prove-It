# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b
from proveit.logic import Card, Exists, NotEquals
from proveit.number import GreaterEq, two

# %%
# build up the expression from sub-expressions
expr = Lambda(S, Exists([a, b], NotEquals(a, b), domain = S, conditions = []), conditions = [GreaterEq(Card(S), two)])
# Out:
# expr: S -> [exists_{a, b in S} (a != b)] | |S| >= 2

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. S -> [exists_{a, b in S} (a != b)] | |S| >= 2
#    core type: Lambda
#    parameter: 25
#    body: 1
#    conditions: 2\n1. exists_{a, b in S} (a != b)
#    core type: Operation
#    operator: 9
#    operand: 3
# 2. (|S| >= 2)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. a -> [exists_{b in S} (a != b)] | a in S
#    core type: Lambda
#    parameter: 21
#    body: 5
#    conditions: 6\n4. |S| >= 2
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. exists_{b in S} (a != b)
#    core type: Operation
#    operator: 9
#    operand: 10
# 6. (a in S)
#    core type: ExprTuple
#    sub-expressions: 11
# 7. >=
#    core type: Literal
#    sub-expressions:
# 8. (|S| , 2)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. exists
#    core type: Literal
#    sub-expressions:
# 10. b -> (a != b) | b in S
#     core type: Lambda
#     parameter: 24
#     body: 14
#     conditions: 15\n11. a in S
#     core type: Operation
#     operator: 22
#     operands: 16
# 12. |S|
#     core type: Operation
#     operator: 17
#     operand: 25
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. a != b
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (b in S)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. (a , S)
#     core type: ExprTuple
#     sub-expressions: 21, 25
# 17. card
#     core type: Literal
#     sub-expressions:
# 18. !=
#     core type: Literal
#     sub-expressions:
# 19. (a , b)
#     core type: ExprTuple
#     sub-expressions: 21, 24
# 20. b in S
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (b , S)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. S
#     core type: Variable
#     sub-expressions:
