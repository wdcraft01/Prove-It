# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import Card, Distinct, Equals, Forall, Set
from proveit.logic._common_ import xIter1l
from proveit.number import Len

# %%
# build up the expression from sub-expressions
expr = Forall([xIter1l], Equals(Card(Set(xIter1l)), Len(xIter1l)), conditions = [Distinct(xIter1l)])
# Out:
# expr: forall_{x_1,...,x_l | distinct(x_1 ,  ...  , x_l)} (|{x_1 ,  ...  , x_l}| = |x_1,...,x_l|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x_1,...,x_l | distinct(x_1 ,  ...  , x_l)} (|{x_1 ,  ...  , x_l}| = |x_1,...,x_l|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x_1,...,x_l) -> (|{x_1 ,  ...  , x_l}| = |x_1,...,x_l|) | distinct(x_1 ,  ...  , x_l)
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. |{x_1 ,  ...  , x_l}| = |x_1,...,x_l|
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (distinct(x_1 ,  ...  , x_l))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|{x_1 ,  ...  , x_l}| , |x_1,...,x_l|)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. distinct(x_1 ,  ...  , x_l)
#    core type: Operation
#    operator: 10
#    operands: 15
# 8. |{x_1 ,  ...  , x_l}|
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. |x_1,...,x_l|
#    core type: Operation
#    operator: 13
#    operand: 16
# 10. distinct
#     core type: Literal
#     sub-expressions:
# 11. card
#     core type: Literal
#     sub-expressions:
# 12. {x_1 ,  ...  , x_l}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. length
#     core type: Literal
#     sub-expressions:
# 14. Set
#     core type: Literal
#     sub-expressions:
# 15. (x_1 ,  ...  , x_l)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. x_1,...,x_l
#     core type: Iter
#     lambda_map: 17
#     start_index: 28
#     end_index: 29
# 17. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 24
#     body: 18
#     conditions: 19\n18. x__x_
#     core type: Indexed
#     var: 20
#     index: 24
#     base: "1"
# 19. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 21
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. _x_ in {1...l}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. _x_
#     core type: Variable
#     sub-expressions:
# 25. {1...l}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. l
#     core type: Variable
#     sub-expressions:
