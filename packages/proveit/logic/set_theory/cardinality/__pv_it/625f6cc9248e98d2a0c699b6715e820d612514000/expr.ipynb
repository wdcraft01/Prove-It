# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#cardInduction">cardInduction</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.set_theory.cardinality._axioms_ import cardInduction

# %%
# check that the built expression is the same as the stored expression
# %check_expr cardInduction
# Out:
# Passed sanity check: built 'cardInduction' is the same as the stored Expression.

# %%
# display the expression information
cardInduction.exprInfo()
# Out:
# 0. forall_{x, S | |S| in Naturals , x not-in S} (|S union {x}| = (|S| + 1))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{S | |S| in Naturals , x not-in S} (|S union {x}| = (|S| + 1))]
#    core type: Lambda
#    parameter: 30
#    body: 2
# 2. forall_{S | |S| in Naturals , x not-in S} (|S union {x}| = (|S| + 1))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. S -> (|S union {x}| = (|S| + 1)) | |S| in Naturals , x not-in S
#    core type: Lambda
#    parameter: 27
#    body: 5
#    conditions: 6\n5. |S union {x}| = (|S| + 1)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (|S| in Naturals , x not-in S)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|S union {x}| , |S| + 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. |S| in Naturals
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. x not-in S
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. |S union {x}|
#     core type: Operation
#     operator: 26
#     operand: 17
# 12. |S| + 1
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (|S| , Naturals)
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 15. not-in
#     core type: Literal
#     sub-expressions:
# 16. (x , S)
#     core type: ExprTuple
#     sub-expressions: 30, 27
# 17. S union {x}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (|S| , 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. Naturals
#     core type: Literal
#     sub-expressions:
# 21. union
#     core type: Literal
#     sub-expressions:
# 22. (S , {x})
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 23. |S|
#     core type: Operation
#     operator: 26
#     operand: 27
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. {x}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. card
#     core type: Literal
#     sub-expressions:
# 27. S
#     core type: Variable
#     sub-expressions:
# 28. Set
#     core type: Literal
#     sub-expressions:
# 29. (x)
#     core type: ExprTuple
#     sub-expressions: 30
# 30. x
#     core type: Variable
#     sub-expressions:
