# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import N, S, l
from proveit.logic import Card, Distinct, Equals, Exists, Forall, InSet
from proveit.logic._common_ import xIter1l
from proveit.number import GreaterEq, Len, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Forall([S, N], Exists([xIter1l], Distinct(xIter1l), domain = S, conditions = [Equals(Len(xIter1l), N)]), conditions = [GreaterEq(Card(S), N)]), conditions = [InSet(l, NaturalsPos)])
# Out:
# expr: l -> [forall_{S, N | |S| >= N} [exists_{x_1,...,x_l in S | |x_1,...,x_l| = N} distinct(x_1 ,  ...  , x_l)]] | l in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{S, N | |S| >= N} [exists_{x_1,...,x_l in S | |x_1,...,x_l| = N} distinct(x_1 ,  ...  , x_l)]] | l in NaturalsPos
#    core type: Lambda
#    parameter: 45
#    body: 1
#    conditions: 2\n1. forall_{S, N | |S| >= N} [exists_{x_1,...,x_l in S | |x_1,...,x_l| = N} distinct(x_1 ,  ...  , x_l)]
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. S -> [forall_{N | |S| >= N} [exists_{x_1,...,x_l in S | |x_1,...,x_l| = N} distinct(x_1 ,  ...  , x_l)]]
#    core type: Lambda
#    parameter: 28
#    body: 5
# 4. l in NaturalsPos
#    core type: Operation
#    operator: 38
#    operands: 6
# 5. forall_{N | |S| >= N} [exists_{x_1,...,x_l in S | |x_1,...,x_l| = N} distinct(x_1 ,  ...  , x_l)]
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (l , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 45, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# ...
