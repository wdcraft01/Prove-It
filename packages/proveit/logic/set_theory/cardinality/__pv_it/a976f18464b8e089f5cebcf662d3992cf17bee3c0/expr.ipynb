# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b
from proveit.logic import Exists, InSet, NotEquals

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Exists([b], NotEquals(a, b), domain = S, conditions = []), conditions = [InSet(a, S)])
# Out:
# expr: a -> [exists_{b in S} (a != b)] | a in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [exists_{b in S} (a != b)] | a in S
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. exists_{b in S} (a != b)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. b -> (a != b) | b in S
#    core type: Lambda
#    parameter: 15
#    body: 6
#    conditions: 7\n5. a in S
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. a != b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (b in S)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , S)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 9. !=
#    core type: Literal
#    sub-expressions:
# 10. (a , b)
#     core type: ExprTuple
#     sub-expressions: 12, 15
# 11. b in S
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b , S)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. S
#     core type: Variable
#     sub-expressions:
