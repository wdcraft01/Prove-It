# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.set_theory.cardinality</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import N, S
from proveit.logic import Distinct, Equals, InSet
from proveit.logic._common_ import xIter1l
from proveit.number import Len

# %%
# build up the expression from sub-expressions
expr = Lambda(xIter1l, Distinct(xIter1l), conditions = [InSet(xIter1l, S), Equals(Len(xIter1l), N)])
# Out:
# expr: (x_1,...,x_l) -> distinct(x_1 ,  ...  , x_l) | x_1 in  ...  in x_l in S , |x_1,...,x_l| = N

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1,...,x_l) -> distinct(x_1 ,  ...  , x_l) | x_1 in  ...  in x_l in S , |x_1,...,x_l| = N
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. distinct(x_1 ,  ...  , x_l)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x_1 in  ...  in x_l in S , |x_1,...,x_l| = N)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. distinct
#    core type: Literal
#    sub-expressions:
# 4. (x_1 ,  ...  , x_l)
#    core type: ExprTuple
#    sub-expressions: 14
# 5. x_1 in  ...  in x_l in S
#    core type: Operation
#    operator: 20
#    operands: 7
# 6. |x_1,...,x_l| = N
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x_1 ,  ...  , x_l , S)
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (|x_1,...,x_l| , N)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. S
#     core type: Variable
#     sub-expressions:
# 11. |x_1,...,x_l|
#     core type: Operation
# ...
