# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#bundledEquiv">bundledEquiv</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.quantification.universal._theorems_ import bundledEquiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr bundledEquiv
# Out:
# Passed sanity check: built 'bundledEquiv' is the same as the stored Expression.

# %%
# display the expression information
bundledEquiv.exprInfo()
# Out:
# 0. forall_{k, m in Naturals} [forall_{l, n in NaturalsPos} [forall_{P, Q_1,...,Q_k, R_1,...,R_m} ([forall_{x_1,...,x_l, y_1,...,y_n | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l) , R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)] =  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [forall_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)]])]]
#    core type: Operation
#    operator: 47
#    operand: 1
# ...
