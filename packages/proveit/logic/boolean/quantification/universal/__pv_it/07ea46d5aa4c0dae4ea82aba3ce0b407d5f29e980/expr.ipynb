# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function
from proveit._common_ import P, l, xx
from proveit.logic import Equals, Forall
from proveit.number import Add, Len, one

# %%
# build up the expression from sub-expressions
subExpr1 = [xx]
subExpr2 = Len(xx)
subExpr3 = Function(P, subExpr1)
expr = ExprTuple(Forall(subExpr1, subExpr3, conditions = [Equals(subExpr2, l)]), Forall(subExpr1, subExpr3, conditions = [Equals(subExpr2, Add(l, one))]))
# Out:
# expr: (forall_{x | |x| = l} P(x) , forall_{x | |x| = (l + 1)} P(x))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{x | |x| = l} P(x) , forall_{x | |x| = (l + 1)} P(x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x | |x| = l} P(x)
#    core type: Operation
#    operator: 4
#    operand: 3
# 2. forall_{x | |x| = (l + 1)} P(x)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. x -> P(x) | |x| = l
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 6\n4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> P(x) | |x| = (l + 1)
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n6. (|x| = l)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. P(x)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (|x| = (l + 1))
#    core type: ExprTuple
#    sub-expressions: 12
# 9. |x| = l
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. (x)
#     core type: ExprTuple
#     sub-expressions: 19
# 12. |x| = (l + 1)
# ...
