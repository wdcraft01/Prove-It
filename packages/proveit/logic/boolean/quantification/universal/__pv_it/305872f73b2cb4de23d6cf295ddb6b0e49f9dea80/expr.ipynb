# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P, k, l
from proveit.logic import And, Forall, Implies, InSet
from proveit.logic._common_ import P_xIter1l, iterQ1k, iterQ1k_xIter1l, xIter1l
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [xIter1l]
expr = Lambda(k, Forall([l], Forall([P, iterQ1k], Implies(Forall(subExpr2, P_xIter1l, conditions = [iterQ1k_xIter1l]), Forall(subExpr2, P_xIter1l, conditions = [And(iterQ1k_xIter1l)])).withWrappingAt(2), conditions = subExpr1), domain = NaturalsPos, conditions = subExpr1), conditions = [InSet(k, NaturalsPos)])
# Out:
# expr: k -> [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]] | k in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. k -> [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]] | k in NaturalsPos
#    core type: Lambda
#    parameter: 53
#    body: 1
#    conditions: 2\n1. forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]
#    core type: Operation
#    operator: 25
#    operand: 3
# 2. (k in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. l -> [forall_{P, Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l)])] | l in NaturalsPos
#    core type: Lambda
#    parameter: 59
#    body: 5
# ...
