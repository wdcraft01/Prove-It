# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.logic import Equals, Forall
from proveit.logic._common_ import P_xIter1l_yIter1n, iterQ1k, iterQ1k_xIter1l, iterR1m, iterR1m_xIter1l_yIter1n, xIter1l, yIter1n

# %%
# build up the expression from sub-expressions
expr = Lambda(iterQ1k, Forall([iterR1m], Equals(Forall([xIter1l, yIter1n], P_xIter1l_yIter1n, conditions = [iterQ1k_xIter1l, iterR1m_xIter1l_yIter1n]), Forall([xIter1l], Forall([yIter1n], P_xIter1l_yIter1n, conditions = [iterR1m_xIter1l_yIter1n]), conditions = [iterQ1k_xIter1l])).withWrappingAt(2), conditions = []))
# Out:
# expr: (Q_1,...,Q_k) -> [forall_{R_1,...,R_m} ([forall_{x_1,...,x_l, y_1,...,y_n | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l) , R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)] =  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [forall_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)]])]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1,...,Q_k) -> [forall_{R_1,...,R_m} ([forall_{x_1,...,x_l, y_1,...,y_n | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l) , R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)] =  \\ [forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [forall_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)]])]
#    core type: Lambda
#    parameter: 1
#    body: 2
# 1. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 3
#    start_index: 73
#    end_index: 52
# ...
