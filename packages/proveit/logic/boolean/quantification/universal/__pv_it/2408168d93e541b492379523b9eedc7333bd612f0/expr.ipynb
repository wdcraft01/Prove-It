# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import And, Forall
from proveit.logic._common_ import P_xIter1l, iterQ1k_xIter1l, xIter1l

# %%
# build up the expression from sub-expressions
subExpr1 = [xIter1l]
expr = ExprTuple(Forall(subExpr1, P_xIter1l, conditions = [iterQ1k_xIter1l]), Forall(subExpr1, P_xIter1l, conditions = [And(iterQ1k_xIter1l)]))
# Out:
# expr: (forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#    core type: Operation
#    operator: 4
#    operand: 3
# 2. forall_{x_1,...,x_l | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 17
#    body: 6
#    conditions: 11\n4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 17
#    body: 6
#    conditions: 7\n6. P(x_1,...,x_l)
#    core type: Operation
#    operator: 8
#    operand: 17
# ...
