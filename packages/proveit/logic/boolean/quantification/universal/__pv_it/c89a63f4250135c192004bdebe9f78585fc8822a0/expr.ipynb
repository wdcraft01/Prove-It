# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#generalForall_PyNotT">generalForall_PyNotT</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import the special expression
from proveit.logic.boolean.quantification.universal._common_ import generalForall_PyNotT

# %%
# check that the built expression is the same as the stored expression
# %check_expr generalForall_PyNotT
# Out:
# Passed sanity check: built 'generalForall_PyNotT' is the same as the stored Expression.

# %%
# display the expression information
generalForall_PyNotT.exprInfo()
# Out:
# 0. forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) != TRUE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (y_1,...,y_l) -> (P(y_1,...,y_l) != TRUE) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. P(y_1,...,y_l) != TRUE
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. !=
#    core type: Literal
#    sub-expressions:
# 6. (P(y_1,...,y_l) , TRUE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#    core type: Iter
#    lambda_map: 10
#    start_index: 34
#    end_index: 29
# 8. P(y_1,...,y_l)
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. TRUE
#    core type: Literal
#    sub-expressions:
# ...
