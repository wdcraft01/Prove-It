# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function
from proveit._common_ import P, l, xx
from proveit.logic import Equals, Forall, Implies
from proveit.number import Add, Len, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [xx]
subExpr3 = Len(xx)
subExpr4 = Function(P, subExpr2)
expr = ExprTuple(Function(P, [subExpr1]), Forall([l], Implies(Forall(subExpr2, subExpr4, conditions = [Equals(subExpr3, l)]), Forall(subExpr2, subExpr4, conditions = [Equals(subExpr3, Add(l, one))])).withWrappingAt(2), domain = Naturals, conditions = subExpr1))
# Out:
# expr: (P(()) , forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)]))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(()) , forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)]))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(())
#    core type: Operation
#    operator: 23
#    operands: 3
# 2. forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)])
#    core type: Operation
#    operator: 16
#    operand: 4
# 3. (())
#    core type: ExprTuple
#    sub-expressions: 5
# 4. l -> ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)]) | l in Naturals
#    core type: Lambda
#    parameter: 35
#    body: 6
#    conditions: 7\n5. ()
#    core type: ExprTuple
#    sub-expressions:
# 6. [forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. =>
#    core type: Literal
#    sub-expressions:
# ...
