# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.logic import And
from proveit.logic._common_ import P_xIter1l, iterQ1k_xIter1l, xIter1l

# %%
# build up the expression from sub-expressions
expr = Lambda(xIter1l, P_xIter1l, conditions = [And(iterQ1k_xIter1l)])
# Out:
# expr: (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. P(x_1,...,x_l)
#    core type: Operation
#    operator: 3
#    operand: 12
# 2. (Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. P
#    core type: Variable
#    sub-expressions:
# 4. Q_1(x_1,...,x_l) and  ...  and Q_k(x_1,...,x_l)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 7
# 7. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 8
#    start_index: 31
#    end_index: 26
# 8. i -> Q_i(x_1,...,x_l) | i in {1...k}
#    core type: Lambda
#    parameter: 19
#    body: 9
#    conditions: 10\n9. Q_i(x_1,...,x_l)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 13
# 11. Q_i
#     core type: Indexed
#     var: 14
#     index: 19
#     base: "1"
# 12. x_1,...,x_l
#     core type: Iter
#     lambda_map: 15
#     start_index: 31
#     end_index: 32
# 13. i in {1...k}
#     core type: Operation
#     operator: 24
#     operands: 16
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 27
#     body: 17
#     conditions: 18\n16. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. x__x_
#     core type: Indexed
#     var: 21
#     index: 27
#     base: "1"
# 18. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. i
#     core type: Variable
#     sub-expressions:
# 20. {1...k}
#     core type: Operation
#     operator: 29
#     operands: 23
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...l}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 31, 26
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. k
#     core type: Variable
#     sub-expressions:
# 27. _x_
#     core type: Variable
#     sub-expressions:
# 28. {1...l}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. l
#     core type: Variable
#     sub-expressions:
