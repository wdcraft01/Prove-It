# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, l, xx
from proveit.logic import Equals, Forall
from proveit.number import Add, Len, one

# %%
# build up the expression from sub-expressions
subExpr1 = [xx]
expr = Forall(subExpr1, Function(P, subExpr1), conditions = [Equals(Len(xx), Add(l, one))])
# Out:
# expr: forall_{x | |x| = (l + 1)} P(x)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x | |x| = (l + 1)} P(x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> P(x) | |x| = (l + 1)
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. P(x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (|x| = (l + 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. (x)
#    core type: ExprTuple
#    sub-expressions: 13
# 7. |x| = (l + 1)
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (|x| , l + 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. |x|
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. l + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. length
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (l , 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. l
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
