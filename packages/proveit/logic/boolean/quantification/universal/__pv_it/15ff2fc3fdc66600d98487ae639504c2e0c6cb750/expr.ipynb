# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function
from proveit._common_ import P, l, xx
from proveit.logic import And, Equals, Forall, Implies
from proveit.number import Add, Len, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [l]
subExpr3 = [xx]
subExpr4 = Len(xx)
subExpr5 = Function(P, subExpr3)
subExpr6 = Forall(subExpr3, subExpr5, conditions = [Equals(subExpr4, l)])
expr = Implies(And(Function(P, [subExpr1]), Forall(subExpr2, Implies(subExpr6, Forall(subExpr3, subExpr5, conditions = [Equals(subExpr4, Add(l, one))])).withWrappingAt(2), domain = Naturals, conditions = subExpr1)), Forall(subExpr2, subExpr6, domain = Naturals, conditions = subExpr1)).withWrappingAt(1)
# Out:
# expr: (P(()) and [forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)])]) \\  => [forall_{l in Naturals} [forall_{x | |x| = l} P(x)]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(()) and [forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)])]) \\  => [forall_{l in Naturals} [forall_{x | |x| = l} P(x)]]
#    core type: Operation
#    operator: 14
#    operands: 1
# 1. (P(()) and [forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)])] , forall_{l in Naturals} [forall_{x | |x| = l} P(x)])
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. P(()) and [forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)])]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. forall_{l in Naturals} [forall_{x | |x| = l} P(x)]
#    core type: Operation
#    operator: 22
#    operand: 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (P(()) , forall_{l in Naturals} ([forall_{x | |x| = l} P(x)] =>  \\ [forall_{x | |x| = (l + 1)} P(x)]))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# ...
