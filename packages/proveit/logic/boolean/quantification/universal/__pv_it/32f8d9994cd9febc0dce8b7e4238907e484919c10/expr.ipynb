# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#generalForall_Px">generalForall_Px</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import the special expression
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Px

# %%
# check that the built expression is the same as the stored expression
# %check_expr generalForall_Px
# Out:
# Passed sanity check: built 'generalForall_Px' is the same as the stored Expression.

# %%
# display the expression information
generalForall_Px.exprInfo()
# Out:
# 0. forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 11
#    body: 3
#    conditions: 4\n3. P(x_1,...,x_l)
#    core type: Operation
#    operator: 5
#    operand: 11
# 4. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 7
#    start_index: 30
#    end_index: 25
# 7. i -> Q_i(x_1,...,x_l) | i in {1...k}
#    core type: Lambda
#    parameter: 18
#    body: 8
#    conditions: 9\n8. Q_i(x_1,...,x_l)
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. (i in {1...k})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. Q_i
# ...
