# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#generalForall_Rx_given_Px">generalForall_Rx_given_Px</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.universal</a>

# %%
# import the special expression
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Rx_given_Px

# %%
# check that the built expression is the same as the stored expression
# %check_expr generalForall_Rx_given_Px
# Out:
# Passed sanity check: built 'generalForall_Rx_given_Px' is the same as the stored Expression.

# %%
# display the expression information
generalForall_Rx_given_Px.exprInfo()
# Out:
# 0. forall_{x_1,...,x_l | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} R(x_1,...,x_l)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x_1,...,x_l) -> R(x_1,...,x_l) | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. R(x_1,...,x_l)
#    core type: Operation
#    operator: 5
#    operand: 13
# 4. (P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. R
#    core type: Variable
#    sub-expressions:
# 6. P(x_1,...,x_l)
#    core type: Operation
#    operator: 8
#    operand: 13
# 7. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 9
#    start_index: 32
#    end_index: 27
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. i -> Q_i(x_1,...,x_l) | i in {1...k}
#    core type: Lambda
#    parameter: 20
# ...
