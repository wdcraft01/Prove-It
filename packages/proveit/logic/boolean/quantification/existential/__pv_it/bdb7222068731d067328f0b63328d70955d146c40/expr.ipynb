# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B
from proveit.logic import Exists
from proveit.logic._common_ import P_xIter1l, P_yIter1l, iterQ1k_xIter1l, iterQ1k_yIter1l, xIter1l, yIter1l

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Exists([xIter1l], P_xIter1l, domain = A, conditions = [iterQ1k_xIter1l]), Exists([yIter1l], P_yIter1l, domain = B, conditions = [iterQ1k_yIter1l]))
# Out:
# expr: (exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#    core type: Operation
#    operator: 4
#    operand: 3
# 2. exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x_1,...,x_l) -> P(x_1,...,x_l) | x_1 in  ...  in x_l in A , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 24
#    body: 6
#    conditions: 7\n4. exists
#    core type: Literal
#    sub-expressions:
# 5. (y_1,...,y_l) -> P(y_1,...,y_l) | y_1 in  ...  in y_l in B , Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 26
#    body: 8
#    conditions: 9\n6. P(x_1,...,x_l)
# ...
