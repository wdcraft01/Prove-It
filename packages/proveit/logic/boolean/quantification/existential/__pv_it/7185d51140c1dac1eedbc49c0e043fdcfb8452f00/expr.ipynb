# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Exists
from proveit.logic._common_ import P_yIter1l, R_zIter1l, iterQ1k_yIter1l, iterQ1k_zIter1l, yIter1l, zIter1l

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Exists([yIter1l], P_yIter1l, conditions = [iterQ1k_yIter1l]), Exists([zIter1l], R_zIter1l, conditions = [iterQ1k_zIter1l]))
# Out:
# expr: (exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l) , exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l) , exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)
#    core type: Operation
#    operator: 4
#    operand: 3
# 2. exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (y_1,...,y_l) -> P(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 19
#    body: 6
#    conditions: 7\n4. exists
#    core type: Literal
#    sub-expressions:
# 5. (z_1,...,z_l) -> R(z_1,...,z_l) | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)
#    core type: Lambda
#    parameter: 21
#    body: 8
#    conditions: 9\n6. P(y_1,...,y_l)
#    core type: Operation
#    operator: 10
#    operand: 19
# ...
