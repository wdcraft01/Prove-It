# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic._common_ import iterQ1i_xIter1l, iterQjk_xIter1l

# %%
# build up the expression from sub-expressions
expr = ExprTuple(iterQ1i_xIter1l, iterQjk_xIter1l)
# Out:
# expr: (Q_1(x_1,...,x_l) ,  ...  , Q_i(x_1,...,x_l) , Q_j(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1(x_1,...,x_l) ,  ...  , Q_i(x_1,...,x_l) , Q_j(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Q_1(x_1,...,x_l),...,Q_i(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 3
#    start_index: 35
#    end_index: 26
# 2. Q_j(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 4
#    start_index: 29
#    end_index: 30
# 3. j -> Q_j(x_1,...,x_l) | j in {1...i}
#    core type: Lambda
#    parameter: 29
#    body: 5
#    conditions: 6\n4. i -> Q_i(x_1,...,x_l) | i in {j...k}
#    core type: Lambda
#    parameter: 26
#    body: 7
#    conditions: 8\n5. Q_j(x_1,...,x_l)
#    core type: Operation
#    operator: 9
#    operand: 12
# 6. (j in {1...i})
#    core type: ExprTuple
#    sub-expressions: 10
# 7. Q_i(x_1,...,x_l)
#    core type: Operation
#    operator: 11
#    operand: 12
# 8. (i in {j...k})
#    core type: ExprTuple
#    sub-expressions: 13
# 9. Q_j
#    core type: Indexed
#    var: 15
#    index: 29
#    base: "1"
# 10. j in {1...i}
#     core type: Operation
#     operator: 27
#     operands: 14
# 11. Q_i
#     core type: Indexed
#     var: 15
#     index: 26
#     base: "1"
# 12. x_1,...,x_l
#     core type: Iter
#     lambda_map: 16
#     start_index: 35
#     end_index: 36
# 13. i in {j...k}
#     core type: Operation
#     operator: 27
#     operands: 17
# 14. (j , {1...i})
#     core type: ExprTuple
#     sub-expressions: 29, 18
# 15. Q
#     core type: Variable
#     sub-expressions:
# 16. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 31
#     body: 19
#     conditions: 20\n17. (i , {j...k})
#     core type: ExprTuple
#     sub-expressions: 26, 21
# 18. {1...i}
#     core type: Operation
#     operator: 33
#     operands: 22
# 19. x__x_
#     core type: Indexed
#     var: 23
#     index: 31
#     base: "1"
# 20. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. {j...k}
#     core type: Operation
#     operator: 33
#     operands: 25
# 22. (1 , i)
#     core type: ExprTuple
#     sub-expressions: 35, 26
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...l}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (j , k)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. i
#     core type: Variable
#     sub-expressions:
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. j
#     core type: Variable
#     sub-expressions:
# 30. k
#     core type: Variable
#     sub-expressions:
# 31. _x_
#     core type: Variable
#     sub-expressions:
# 32. {1...l}
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. Interval
#     core type: Literal
#     sub-expressions:
# 34. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. l
#     core type: Variable
#     sub-expressions:
