# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#generalNotExists_notPx">generalNotExists_notPx</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.NotExists.html">NotExists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import the special expression
from proveit.logic.boolean.quantification.existential._common_ import generalNotExists_notPx

# %%
# check that the built expression is the same as the stored expression
# %check_expr generalNotExists_notPx
# Out:
# Passed sanity check: built 'generalNotExists_notPx' is the same as the stored Expression.

# %%
# display the expression information
generalNotExists_notPx.exprInfo()
# Out:
# 0. notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [not](P(x_1,...,x_l))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. notexists
#    core type: Literal
#    sub-expressions:
# 2. (x_1,...,x_l) -> [not](P(x_1,...,x_l)) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. [not](P(x_1,...,x_l))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. not
#    core type: Literal
#    sub-expressions:
# 6. P(x_1,...,x_l)
#    core type: Operation
#    operator: 8
#    operand: 13
# 7. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#    core type: Iter
#    lambda_map: 9
#    start_index: 32
#    end_index: 27
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. i -> Q_i(x_1,...,x_l) | i in {1...k}
#    core type: Lambda
#    parameter: 20
#    body: 10
# ...
