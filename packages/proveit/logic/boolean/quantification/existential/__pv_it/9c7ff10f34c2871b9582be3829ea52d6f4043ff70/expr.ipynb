# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import P
from proveit.logic import Booleans, Exists, Forall, InSet
from proveit.logic._common_ import P_xIter1l, iterQ1k, iterQ1k_xIter1l, xIter1l

# %%
# build up the expression from sub-expressions
expr = Forall([P, iterQ1k], InSet(Exists([xIter1l], P_xIter1l, conditions = [iterQ1k_xIter1l]), Booleans), conditions = [])
# Out:
# expr: forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. P -> [forall_{Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] in BOOLEANS)]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (Q_1,...,Q_k) -> ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] in BOOLEANS)
#    core type: Lambda
#    parameter: 5
#    body: 6
# 5. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 7
#    start_index: 44
#    end_index: 39
# 6. [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] in BOOLEANS
#    core type: Operation
#    operator: 37
#    operands: 8
# 7. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 40
#    body: 9
#    conditions: 10\n8. (exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. Q__x_
#    core type: Indexed
#    var: 27
#    index: 40
#    base: "1"
# 10. (_x_ in {1...k})
#     core type: ExprTuple
#     sub-expressions: 13
# 11. exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. _x_ in {1...k}
#     core type: Operation
#     operator: 37
#     operands: 16
# 14. exists
#     core type: Literal
#     sub-expressions:
# 15. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#     core type: Lambda
#     parameter: 25
#     body: 17
#     conditions: 18\n16. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 40, 33
# 17. P(x_1,...,x_l)
#     core type: Operation
#     operator: 19
#     operand: 25
# 18. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. P
#     core type: Variable
#     sub-expressions:
# 20. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#     core type: Iter
#     lambda_map: 21
#     start_index: 44
#     end_index: 39
# 21. i -> Q_i(x_1,...,x_l) | i in {1...k}
#     core type: Lambda
#     parameter: 32
#     body: 22
#     conditions: 23\n22. Q_i(x_1,...,x_l)
#     core type: Operation
#     operator: 24
#     operand: 25
# 23. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. Q_i
#     core type: Indexed
#     var: 27
#     index: 32
#     base: "1"
# 25. x_1,...,x_l
#     core type: Iter
#     lambda_map: 28
#     start_index: 44
#     end_index: 45
# 26. i in {1...k}
#     core type: Operation
#     operator: 37
#     operands: 29
# 27. Q
#     core type: Variable
#     sub-expressions:
# 28. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 40
#     body: 30
#     conditions: 31\n29. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. x__x_
#     core type: Indexed
#     var: 34
#     index: 40
#     base: "1"
# 31. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 35
# 32. i
#     core type: Variable
#     sub-expressions:
# 33. {1...k}
#     core type: Operation
#     operator: 42
#     operands: 36
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. _x_ in {1...l}
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 44, 39
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 39. k
#     core type: Variable
#     sub-expressions:
# 40. _x_
#     core type: Variable
#     sub-expressions:
# 41. {1...l}
#     core type: Operation
#     operator: 42
#     operands: 43
# 42. Interval
#     core type: Literal
#     sub-expressions:
# 43. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. l
#     core type: Variable
#     sub-expressions:
