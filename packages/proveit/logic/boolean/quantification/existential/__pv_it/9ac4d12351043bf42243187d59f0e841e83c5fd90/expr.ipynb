# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P
from proveit.logic import Forall, Implies, Not, NotExists
from proveit.logic._common_ import P_yIter1l, iterQ1k, iterQ1k_yIter1l, yIter1l
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Px

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Forall([iterQ1k], Implies(generalForall_Px, NotExists([yIter1l], Not(P_yIter1l), conditions = [iterQ1k_yIter1l])).withWrappingAt(2), conditions = []))
# Out:
# expr: P -> [forall_{Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l))])]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> [forall_{Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l))])]
#    core type: Lambda
#    parameter: 27
#    body: 1
# 1. forall_{Q_1,...,Q_k} ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l))])
#    core type: Operation
#    operator: 13
#    operand: 2
# 2. (Q_1,...,Q_k) -> ([forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l))])
#    core type: Lambda
#    parameter: 3
#    body: 4
# 3. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 5
#    start_index: 56
#    end_index: 51
# ...
