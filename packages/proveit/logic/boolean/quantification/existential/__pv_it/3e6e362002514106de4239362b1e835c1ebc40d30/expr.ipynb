# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Exists, Not
from proveit.logic._common_ import P_xIter1l, iterQ1k_xIter1l, xIter1l
from proveit.logic.boolean.quantification.universal._common_ import generalForall_PyNotT

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Exists([xIter1l], P_xIter1l, conditions = [iterQ1k_xIter1l]), Not(generalForall_PyNotT))
# Out:
# expr: (exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) != TRUE)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) != TRUE)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) != TRUE))
#    core type: Operation
#    operator: 5
#    operand: 6
# 3. exists
#    core type: Literal
#    sub-expressions:
# 4. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 22
#    body: 7
#    conditions: 8\n5. not
#    core type: Literal
#    sub-expressions:
# 6. forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) != TRUE)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. P(x_1,...,x_l)
# ...
