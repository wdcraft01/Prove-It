# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.logic import Equals, Exists, Not, NotExists
from proveit.logic._common_ import P_xIter1l, P_yIter1l, iterQ1k, iterQ1k_xIter1l, iterQ1k_yIter1l, xIter1l, yIter1l

# %%
# build up the expression from sub-expressions
expr = Lambda(iterQ1k, Equals(NotExists([xIter1l], P_xIter1l, conditions = [iterQ1k_xIter1l]), Not(Exists([yIter1l], P_yIter1l, conditions = [iterQ1k_yIter1l]))).withWrappingAt(2))
# Out:
# expr: (Q_1,...,Q_k) -> ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Q_1,...,Q_k) -> ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))
#    core type: Lambda
#    parameter: 1
#    body: 2
# 1. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 3
#    start_index: 53
#    end_index: 48
# 2. [notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 49
#    body: 6
#    conditions: 7\n4. =
#    core type: Literal
#    sub-expressions:
# 5. (notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))
#    core type: ExprTuple
# ...
