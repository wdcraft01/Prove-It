# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#notExistsDef">notExistsDef</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.quantification.existential._axioms_ import notExistsDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr notExistsDef
# Out:
# Passed sanity check: built 'notExistsDef' is the same as the stored Expression.

# %%
# display the expression information
notExistsDef.exprInfo()
# Out:
# 0. forall_{(k, l) in Naturals * NaturalsPos} [forall_{P, Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. k -> [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]] | k in Naturals
#    core type: Lambda
#    parameter: 64
#    body: 2
#    conditions: 3\n2. forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. (k in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. l -> [forall_{P, Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))] | l in NaturalsPos
#    core type: Lambda
#    parameter: 70
#    body: 6
#    conditions: 7\n5. k in Naturals
#    core type: Operation
#    operator: 62
#    operands: 8
# 6. forall_{P, Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))
#    core type: Operation
#    operator: 14
#    operand: 9
# 7. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (k , Naturals)
#    core type: ExprTuple
#    sub-expressions: 64, 11
# 9. P -> [forall_{Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]
#    core type: Lambda
#    parameter: 39
#    body: 12
# 10. l in NaturalsPos
#     core type: Operation
#     operator: 62
#     operands: 13
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. forall_{Q_1,...,Q_k} ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. (l , NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 70, 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (Q_1,...,Q_k) -> ([notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))
#     core type: Lambda
#     parameter: 17
#     body: 18
# 16. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 17. Q_1,...,Q_k
#     core type: Iter
#     lambda_map: 19
#     start_index: 69
#     end_index: 64
# 18. [notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =  \\ [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. _x_ -> Q__x_ | _x_ in {1...k}
#     core type: Lambda
#     parameter: 65
#     body: 22
#     conditions: 23\n20. =
#     core type: Literal
#     sub-expressions:
# 21. (notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Q__x_
#     core type: Indexed
#     var: 51
#     index: 65
#     base: "1"
# 23. (_x_ in {1...k})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. notexists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#     core type: Operation
#     operator: 27
#     operand: 34
# 25. [not](exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))
#     core type: Operation
#     operator: 28
#     operand: 29
# 26. _x_ in {1...k}
#     core type: Operation
#     operator: 62
#     operands: 30
# 27. notexists
#     core type: Literal
#     sub-expressions:
# 28. not
#     core type: Literal
#     sub-expressions:
# 29. exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)
#     core type: Operation
#     operator: 33
#     operand: 34
# 30. (_x_ , {1...k})
#     core type: ExprTuple
#     sub-expressions: 65, 58
# 31. P(x_1,...,x_l)
#     core type: Operation
#     operator: 39
#     operand: 43
# 32. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#     core type: ExprTuple
#     sub-expressions: 35
# 33. exists
#     core type: Literal
#     sub-expressions:
# 34. (y_1,...,y_l) -> P(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#     core type: Lambda
#     parameter: 48
#     body: 36
#     conditions: 37\n35. Q_1(x_1,...,x_l),...,Q_k(x_1,...,x_l)
#     core type: Iter
#     lambda_map: 38
#     start_index: 69
#     end_index: 64
# 36. P(y_1,...,y_l)
#     core type: Operation
#     operator: 39
#     operand: 48
# 37. (Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#     core type: ExprTuple
#     sub-expressions: 40
# 38. i -> Q_i(x_1,...,x_l) | i in {1...k}
#     core type: Lambda
#     parameter: 57
#     body: 41
#     conditions: 45\n39. P
#     core type: Variable
#     sub-expressions:
# 40. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#     core type: Iter
#     lambda_map: 42
#     start_index: 69
#     end_index: 64
# 41. Q_i(x_1,...,x_l)
#     core type: Operation
#     operator: 47
#     operand: 43
# 42. i -> Q_i(y_1,...,y_l) | i in {1...k}
#     core type: Lambda
#     parameter: 57
#     body: 44
#     conditions: 45\n43. x_1,...,x_l
#     core type: Iter
#     lambda_map: 46
#     start_index: 69
#     end_index: 70
# 44. Q_i(y_1,...,y_l)
#     core type: Operation
#     operator: 47
#     operand: 48
# 45. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 49
# 46. _x_ -> x__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 65
#     body: 50
#     conditions: 56\n47. Q_i
#     core type: Indexed
#     var: 51
#     index: 57
#     base: "1"
# 48. y_1,...,y_l
#     core type: Iter
#     lambda_map: 52
#     start_index: 69
#     end_index: 70
# 49. i in {1...k}
#     core type: Operation
#     operator: 62
#     operands: 53
# 50. x__x_
#     core type: Indexed
#     var: 54
#     index: 65
#     base: "1"
# 51. Q
#     core type: Variable
#     sub-expressions:
# 52. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 65
#     body: 55
#     conditions: 56\n53. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. x
#     core type: Variable
#     sub-expressions:
# 55. y__x_
#     core type: Indexed
#     var: 59
#     index: 65
#     base: "1"
# 56. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 60
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. {1...k}
#     core type: Operation
#     operator: 67
#     operands: 61
# 59. y
#     core type: Variable
#     sub-expressions:
# 60. _x_ in {1...l}
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 69, 64
# 62. in
#     core type: Literal
#     sub-expressions:
# 63. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 64. k
#     core type: Variable
#     sub-expressions:
# 65. _x_
#     core type: Variable
#     sub-expressions:
# 66. {1...l}
#     core type: Operation
#     operator: 67
#     operands: 68
# 67. Interval
#     core type: Literal
#     sub-expressions:
# 68. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 69. 1
#     core type: Literal
#     sub-expressions:
# 70. l
#     core type: Variable
#     sub-expressions:
