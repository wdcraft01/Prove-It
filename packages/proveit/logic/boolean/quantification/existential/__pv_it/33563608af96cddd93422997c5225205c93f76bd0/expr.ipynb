# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P, i, j, k, l
from proveit.logic import Exists, Forall, Implies, InSet
from proveit.logic._common_ import P_xIter1l, iterQ1i_xIter1l, iterQ1k, iterQ1k_xIter1l, iterQjk_xIter1l, xIter1l
from proveit.number import Less, LessEq, LesserSequence, Naturals, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [xIter1l]
expr = Lambda(j, Forall([k], Forall([l], Forall([P, iterQ1k], Implies(Exists(subExpr2, P_xIter1l, conditions = [iterQ1k_xIter1l]), Exists(subExpr2, P_xIter1l, conditions = [iterQ1i_xIter1l, iterQjk_xIter1l])).withWrappingAt(2), conditions = subExpr1), domain = NaturalsPos, conditions = subExpr1), domain = Naturals, conditions = [LesserSequence([LessEq._operator_, Less._operator_, LessEq._operator_], [one, i, j, k])]), conditions = [InSet(j, Naturals)])
# Out:
# expr: j -> [forall_{k in Naturals | 1 <= i < j <= k} [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_i(x_1,...,x_l) , Q_j(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]]] | j in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. j -> [forall_{k in Naturals | 1 <= i < j <= k} [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_i(x_1,...,x_l) , Q_j(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]]] | j in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 1
#    conditions: 2\n1. forall_{k in Naturals | 1 <= i < j <= k} [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_i(x_1,...,x_l) , Q_j(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]]
#    core type: Operation
#    operator: 23
#    operand: 3
# 2. (j in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# ...
