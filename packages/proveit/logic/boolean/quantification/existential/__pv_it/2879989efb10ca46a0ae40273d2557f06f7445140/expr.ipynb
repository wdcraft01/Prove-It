# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P, k, l
from proveit.logic import Exists, Forall, Implies, InSet, Not
from proveit.logic._common_ import P_xIter1l, iterQ1k, iterQ1k_xIter1l, xIter1l
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Py
from proveit.number import Naturals, NaturalsPos

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(k, Forall([l], Forall([P, iterQ1k], Implies(Exists([xIter1l], Not(P_xIter1l), conditions = [iterQ1k_xIter1l]), Not(generalForall_Py)).withWrappingAt(2), conditions = subExpr1), domain = NaturalsPos, conditions = subExpr1), conditions = [InSet(k, Naturals)])
# Out:
# expr: k -> [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [not](P(x_1,...,x_l))] =>  \\ [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]] | k in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. k -> [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [not](P(x_1,...,x_l))] =>  \\ [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]] | k in Naturals
#    core type: Lambda
#    parameter: 64
#    body: 1
#    conditions: 2\n1. forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [not](P(x_1,...,x_l))] =>  \\ [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))]
#    core type: Operation
#    operator: 31
#    operand: 3
# 2. (k in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. l -> [forall_{P, Q_1,...,Q_k} ([exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [not](P(x_1,...,x_l))] =>  \\ [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)))] | l in NaturalsPos
#    core type: Lambda
# ...
