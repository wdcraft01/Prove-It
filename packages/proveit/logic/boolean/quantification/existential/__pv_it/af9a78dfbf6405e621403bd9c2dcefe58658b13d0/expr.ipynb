# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import Not
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Py

# %%
# build up the expression from sub-expressions
expr = Not(generalForall_Py)
# Out:
# expr: [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not](forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. not
#    core type: Literal
#    sub-expressions:
# 2. forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (y_1,...,y_l) -> P(y_1,...,y_l) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n5. P(y_1,...,y_l)
#    core type: Operation
#    operator: 7
#    operand: 13
# 6. (Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. P
#    core type: Variable
#    sub-expressions:
# 8. Q_1(y_1,...,y_l),...,Q_k(y_1,...,y_l)
#    core type: Iter
#    lambda_map: 9
#    start_index: 32
#    end_index: 27
# 9. i -> Q_i(y_1,...,y_l) | i in {1...k}
#    core type: Lambda
#    parameter: 20
#    body: 10
#    conditions: 11\n10. Q_i(y_1,...,y_l)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. (i in {1...k})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. Q_i
#     core type: Indexed
#     var: 15
#     index: 20
#     base: "1"
# 13. y_1,...,y_l
#     core type: Iter
#     lambda_map: 16
#     start_index: 32
#     end_index: 33
# 14. i in {1...k}
#     core type: Operation
#     operator: 25
#     operands: 17
# 15. Q
#     core type: Variable
#     sub-expressions:
# 16. _x_ -> y__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 28
#     body: 18
#     conditions: 19\n17. (i , {1...k})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. y__x_
#     core type: Indexed
#     var: 22
#     index: 28
#     base: "1"
# 19. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. i
#     core type: Variable
#     sub-expressions:
# 21. {1...k}
#     core type: Operation
#     operator: 30
#     operands: 24
# 22. y
#     core type: Variable
#     sub-expressions:
# 23. _x_ in {1...l}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (1 , k)
#     core type: ExprTuple
#     sub-expressions: 32, 27
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. k
#     core type: Variable
#     sub-expressions:
# 28. _x_
#     core type: Variable
#     sub-expressions:
# 29. {1...l}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. l
#     core type: Variable
#     sub-expressions:
