# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import Exists
from proveit.logic._common_ import P_xIter1l_yIter1n, iterR1m_xIter1l_yIter1n, yIter1n

# %%
# build up the expression from sub-expressions
expr = Exists([yIter1n], P_xIter1l_yIter1n, conditions = [iterR1m_xIter1l_yIter1n])
# Out:
# expr: exists_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. exists_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. exists
#    core type: Literal
#    sub-expressions:
# 2. (y_1,...,y_n) -> P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: Operation
#    operator: 5
#    operands: 11
# 4. (R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n),...,R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: Iter
#    lambda_map: 7
#    start_index: 41
# ...
