# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#existentialImplication">existentialImplication</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.quantification.existential._theorems_ import existentialImplication

# %%
# check that the built expression is the same as the stored expression
# %check_expr existentialImplication
# Out:
# Passed sanity check: built 'existentialImplication' is the same as the stored Expression.

# %%
# display the expression information
existentialImplication.exprInfo()
# Out:
# 0. forall_{(k, l) in Naturals * NaturalsPos} [forall_{P, Q_1,...,Q_k, R} ([forall_{x_1,...,x_l | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} R(x_1,...,x_l)] =>  \\ ([exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)] =>  \\ [exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l)]))]
#    core type: Operation
#    operator: 28
#    operand: 1
# 1. k -> [forall_{l in NaturalsPos} [forall_{P, Q_1,...,Q_k, R} ([forall_{x_1,...,x_l | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} R(x_1,...,x_l)] =>  \\ ([exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)] =>  \\ [exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l)]))]] | k in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 2
# ...
