# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, P, l
from proveit.logic import Exists, Forall, Implies, InSet, SubsetEq
from proveit.logic._common_ import P_xIter1l, P_yIter1l, iterQ1k, iterQ1k_xIter1l, iterQ1k_yIter1l, xIter1l, yIter1l
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Forall([P, A, B, iterQ1k], Implies(Exists([xIter1l], P_xIter1l, domain = A, conditions = [iterQ1k_xIter1l]), Exists([yIter1l], P_yIter1l, domain = B, conditions = [iterQ1k_yIter1l])).withWrappingAt(2), conditions = [SubsetEq(A, B)]), conditions = [InSet(l, NaturalsPos)])
# Out:
# expr: l -> [forall_{P, A, B, Q_1,...,Q_k | A subseteq B} ([exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)])] | l in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{P, A, B, Q_1,...,Q_k | A subseteq B} ([exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)])] | l in NaturalsPos
#    core type: Lambda
#    parameter: 75
#    body: 1
#    conditions: 2\n1. forall_{P, A, B, Q_1,...,Q_k | A subseteq B} ([exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)])
#    core type: Operation
#    operator: 13
#    operand: 3
# 2. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. P -> [forall_{A, B, Q_1,...,Q_k | A subseteq B} ([exists_{x_1,...,x_l in A | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)] =>  \\ [exists_{y_1,...,y_l in B | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)])]
#    core type: Lambda
#    parameter: 38
# ...
