# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Not, NotExists
from proveit.logic._common_ import P_yIter1l, iterQ1k_yIter1l, yIter1l
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Px

# %%
# build up the expression from sub-expressions
expr = ExprTuple(generalForall_Px, NotExists([yIter1l], Not(P_yIter1l), conditions = [iterQ1k_yIter1l]))
# Out:
# expr: (forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l) , notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. notexists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} [not](P(y_1,...,y_l))
#    core type: Operation
#    operator: 5
#    operand: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x_1,...,x_l) -> P(x_1,...,x_l) | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 21
#    body: 7
#    conditions: 8\n5. notexists
#    core type: Literal
#    sub-expressions:
# 6. (y_1,...,y_l) -> [not](P(y_1,...,y_l)) | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)
#    core type: Lambda
#    parameter: 23
#    body: 9
#    conditions: 10\n7. P(x_1,...,x_l)
# ...
