# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#generalNestedExists_Pxy">generalNestedExists_Pxy</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Exists.html">Exists</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import the special expression
from proveit.logic.boolean.quantification.existential._common_ import generalNestedExists_Pxy

# %%
# check that the built expression is the same as the stored expression
# %check_expr generalNestedExists_Pxy
# Out:
# Passed sanity check: built 'generalNestedExists_Pxy' is the same as the stored Expression.

# %%
# display the expression information
generalNestedExists_Pxy.exprInfo()
# Out:
# 0. exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} [exists_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. (x_1,...,x_l) -> [exists_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)] | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)
#    core type: Lambda
#    parameter: 26
#    body: 2
#    conditions: 3\n2. exists_{y_1,...,y_n | R_1(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n) ,  ...  , R_m(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)} P(x_1 ,  ...  , x_l , y_1 ,  ...  , y_n)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. exists
#    core type: Literal
#    sub-expressions:
# ...
