# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P, R, l
from proveit.logic import Exists, Forall, Implies, InSet
from proveit.logic._common_ import P_yIter1l, R_zIter1l, iterQ1k, iterQ1k_yIter1l, iterQ1k_zIter1l, yIter1l, zIter1l
from proveit.logic.boolean.quantification.universal._common_ import generalForall_Rx_given_Px
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Forall([P, iterQ1k, R], Implies(generalForall_Rx_given_Px, Implies(Exists([yIter1l], P_yIter1l, conditions = [iterQ1k_yIter1l]), Exists([zIter1l], R_zIter1l, conditions = [iterQ1k_zIter1l])).withWrappingAt(2)).withWrappingAt(2), conditions = []), conditions = [InSet(l, NaturalsPos)])
# Out:
# expr: l -> [forall_{P, Q_1,...,Q_k, R} ([forall_{x_1,...,x_l | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} R(x_1,...,x_l)] =>  \\ ([exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)] =>  \\ [exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l)]))] | l in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{P, Q_1,...,Q_k, R} ([forall_{x_1,...,x_l | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} R(x_1,...,x_l)] =>  \\ ([exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)] =>  \\ [exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l)]))] | l in NaturalsPos
#    core type: Lambda
#    parameter: 78
#    body: 1
#    conditions: 2\n1. forall_{P, Q_1,...,Q_k, R} ([forall_{x_1,...,x_l | P(x_1,...,x_l) , Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} R(x_1,...,x_l)] =>  \\ ([exists_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} P(y_1,...,y_l)] =>  \\ [exists_{z_1,...,z_l | Q_1(z_1,...,z_l) ,  ...  , Q_k(z_1,...,z_l)} R(z_1,...,z_l)]))
#    core type: Operation
#    operator: 21
#    operand: 3
# 2. (l in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# ...
