# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.quantification.existential</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import Exists, Forall, Implies
from proveit.logic._common_ import P_xIter1l, P_yIter1l, iterQ1k, iterQ1k_xIter1l, iterQ1k_yIter1l, xIter1l, yIter1l

# %%
# build up the expression from sub-expressions
expr = Forall([iterQ1k], Forall([yIter1l], Implies(P_yIter1l, Exists([xIter1l], P_xIter1l, conditions = [iterQ1k_xIter1l])).withWrappingAt(2), conditions = [iterQ1k_yIter1l]), conditions = [])
# Out:
# expr: forall_{Q_1,...,Q_k} [forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{Q_1,...,Q_k} [forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (Q_1,...,Q_k) -> [forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])]
#    core type: Lambda
#    parameter: 2
#    body: 3
# 2. Q_1,...,Q_k
#    core type: Iter
#    lambda_map: 4
#    start_index: 53
#    end_index: 48
# 3. forall_{y_1,...,y_l | Q_1(y_1,...,y_l) ,  ...  , Q_k(y_1,...,y_l)} (P(y_1,...,y_l) =>  \\ [exists_{x_1,...,x_l | Q_1(x_1,...,x_l) ,  ...  , Q_k(x_1,...,x_l)} P(x_1,...,x_l)])
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. _x_ -> Q__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 49
#    body: 7
#    conditions: 8\n5. forall
#    core type: Literal
# ...
