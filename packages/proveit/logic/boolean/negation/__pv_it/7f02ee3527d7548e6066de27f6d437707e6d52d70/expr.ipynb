# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#operandInBool">operandInBool</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.negation._theorems_ import operandInBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr operandInBool
# Out:
# Passed sanity check: built 'operandInBool' is the same as the stored Expression.

# %%
# display the expression information
operandInBool.exprInfo()
# Out:
# 0. forall_{A | [not](A) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> (A in BOOLEANS) | [not](A) in BOOLEANS
#    core type: Lambda
#    parameter: 12
#    body: 3
#    conditions: 4\n3. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 5
# 4. ([not](A) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 10
# 6. [not](A) in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. ([not](A) , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. [not](A)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
