# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.negation</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, C
from proveit.logic import Booleans, Forall, Implies, Not

# %%
# build up the expression from sub-expressions
expr = Forall([C], Forall([A], C, domain = Booleans, conditions = [Implies(A, C), Implies(Not(A), C)]), conditions = [])
# Out:
# expr: forall_{C} [forall_{A in BOOLEANS | A => C , [not](A) => C} C]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C} [forall_{A in BOOLEANS | A => C , [not](A) => C} C]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. C -> [forall_{A in BOOLEANS | A => C , [not](A) => C} C]
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. forall_{A in BOOLEANS | A => C , [not](A) => C} C
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> C | A in BOOLEANS , A => C , [not](A) => C
#    core type: Lambda
#    parameter: 18
#    body: 16
#    conditions: 5\n5. (A in BOOLEANS , A => C , [not](A) => C)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. A in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. A => C
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. [not](A) => C
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 11. (A , C)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. ([not](A) , C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. [not](A)
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. not
#     core type: Literal
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
