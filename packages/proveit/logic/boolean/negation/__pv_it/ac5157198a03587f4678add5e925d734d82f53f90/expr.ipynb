# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#doubleNegClosure">doubleNegClosure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.negation._theorems_ import doubleNegClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr doubleNegClosure
# Out:
# Passed sanity check: built 'doubleNegClosure' is the same as the stored Expression.

# %%
# display the expression information
doubleNegClosure.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} ([not]([not](A)) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ([not]([not](A)) in BOOLEANS) | A in BOOLEANS
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. [not]([not](A)) in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ([not]([not](A)) , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 11
# 6. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. [not]([not](A))
#    core type: Operation
#    operator: 12
#    operand: 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 10. [not](A)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
