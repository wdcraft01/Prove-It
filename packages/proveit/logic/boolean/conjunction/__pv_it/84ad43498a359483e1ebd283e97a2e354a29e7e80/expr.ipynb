# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#demorgansLawOrToAndBin">demorgansLawOrToAndBin</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import demorgansLawOrToAndBin

# %%
# check that the built expression is the same as the stored expression
# %check_expr demorgansLawOrToAndBin
# Out:
# Passed sanity check: built 'demorgansLawOrToAndBin' is the same as the stored Expression.

# %%
# display the expression information
demorgansLawOrToAndBin.exprInfo()
# Out:
# 0. forall_{A, B | [not]([not](A) or [not](B))} (A and B)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | [not]([not](A) or [not](B))} (A and B)]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{B | [not]([not](A) or [not](B))} (A and B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (A and B) | [not]([not](A) or [not](B))
#    core type: Lambda
#    parameter: 17
#    body: 5
#    conditions: 6\n5. A and B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ([not]([not](A) or [not](B)))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A , B)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 9. [not]([not](A) or [not](B))
#    core type: Operation
#    operator: 16
#    operand: 10
# 10. [not](A) or [not](B)
#     core type: Operation
#     operator: 11
#     operands: 12
# ...
