# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import CC
from proveit.logic import And
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, And(iterB1m), conditions = [And(iterA1l, iterB1m, iterC1n)])
# Out:
# expr: C -> (B_1 and  ...  and B_m) | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> (B_1 and  ...  and B_m) | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n
#    core type: Lambda
#    parameter: 23
#    body: 1
#    conditions: 2\n1. B_1 and  ...  and B_m
#    core type: Operation
#    operator: 5
#    operands: 3
# 2. (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (B_1 ,  ...  , B_m)
#    core type: ExprTuple
#    sub-expressions: 8
# 4. A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A_1,...,A_l
#    core type: Iter
#    lambda_map: 10
#    start_index: 39
#    end_index: 37
# 8. B_1,...,B_m
#    core type: Iter
#    lambda_map: 11
#    start_index: 39
#    end_index: 38
# 9. C_1,...,C_n
#    core type: Iter
#    lambda_map: 12
#    start_index: 39
#    end_index: 40
# 10. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 31
#     body: 13
#     conditions: 14\n11. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 31
#     body: 15
#     conditions: 16\n12. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 31
#     body: 17
#     conditions: 18\n13. A__x_
#     core type: Indexed
#     var: 19
#     index: 31
#     base: "1"
# 14. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 20
# 15. B__x_
#     core type: Indexed
#     var: 21
#     index: 31
#     base: "1"
# 16. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. C__x_
#     core type: Indexed
#     var: 23
#     index: 31
#     base: "1"
# 18. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...l}
#     core type: Operation
#     operator: 27
#     operands: 25
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...m}
#     core type: Operation
#     operator: 27
#     operands: 26
# 23. C
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 26. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 31, 30
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. {1...l}
#     core type: Operation
#     operator: 35
#     operands: 33
# 30. {1...m}
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. _x_
#     core type: Variable
#     sub-expressions:
# 32. {1...n}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 34. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. l
#     core type: Variable
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
