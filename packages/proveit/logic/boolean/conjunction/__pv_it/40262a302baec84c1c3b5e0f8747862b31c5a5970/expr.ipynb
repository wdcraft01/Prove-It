# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m
from proveit.logic import Not, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Or(Iter(i, Not(Indexed(AA, i, base = 1)), one, m))
# Out:
# expr: [not](A_1) or  ...  or [not](A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not](A_1) or  ...  or [not](A_m)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. or
#    core type: Literal
#    sub-expressions:
# 2. ([not](A_1) ,  ...  , [not](A_m))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. [not](A_1),...,[not](A_m)
#    core type: Iter
#    lambda_map: 4
#    start_index: 17
#    end_index: 18
# 4. i -> [not](A_i) | i in {1...m}
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n5. [not](A_i)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. not
#    core type: Literal
#    sub-expressions:
# 8. A_i
#    core type: Indexed
#    var: 10
#    index: 13
#    base: "1"
# 9. i in {1...m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. {1...m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
