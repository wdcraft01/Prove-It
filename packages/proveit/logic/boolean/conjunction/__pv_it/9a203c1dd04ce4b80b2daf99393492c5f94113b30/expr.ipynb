# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, CC, DD
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, Forall([DD], And(iterA1l, iterC1m, B, iterD1n), conditions = [And(iterA1l, B, iterC1m, iterD1n)]))
# Out:
# expr: C -> [forall_{D | A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> [forall_{D | A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)]
#    core type: Lambda
#    parameter: 25
#    body: 1
# 1. forall_{D | A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. D -> (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n) | A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n
#    core type: Lambda
#    parameter: 27
#    body: 4
#    conditions: 5\n4. A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 8
#    operands: 6
# 5. (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A_1 ,  ...  , A_l , C_1 ,  ...  , C_m , B , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 10, 12, 11, 13
# 7. A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_l , B , C_1 ,  ...  , C_m , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 10. A_1,...,A_l
#     core type: Iter
#     lambda_map: 14
#     start_index: 43
#     end_index: 41
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. C_1,...,C_m
#     core type: Iter
#     lambda_map: 15
#     start_index: 43
#     end_index: 42
# 13. D_1,...,D_n
#     core type: Iter
#     lambda_map: 16
#     start_index: 43
#     end_index: 44
# 14. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 35
#     body: 17
#     conditions: 18\n15. _x_ -> C__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 35
#     body: 19
#     conditions: 20\n16. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 35
#     body: 21
#     conditions: 22\n17. A__x_
#     core type: Indexed
#     var: 23
#     index: 35
#     base: "1"
# 18. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. C__x_
#     core type: Indexed
#     var: 25
#     index: 35
#     base: "1"
# 20. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 26
# 21. D__x_
#     core type: Indexed
#     var: 27
#     index: 35
#     base: "1"
# 22. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 28
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...l}
#     core type: Operation
#     operator: 31
#     operands: 29
# 25. C
#     core type: Variable
#     sub-expressions:
# 26. _x_ in {1...m}
#     core type: Operation
#     operator: 31
#     operands: 30
# 27. D
#     core type: Variable
#     sub-expressions:
# 28. _x_ in {1...n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 35, 33
# 30. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. {1...l}
#     core type: Operation
#     operator: 39
#     operands: 37
# 34. {1...m}
#     core type: Operation
#     operator: 39
#     operands: 38
# 35. _x_
#     core type: Variable
#     sub-expressions:
# 36. {1...n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 43, 41
# 38. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 43, 42
# 39. Interval
#     core type: Literal
#     sub-expressions:
# 40. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. l
#     core type: Variable
#     sub-expressions:
# 42. m
#     core type: Variable
#     sub-expressions:
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. n
#     core type: Variable
#     sub-expressions:
