# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, BB, CC, l, m, n
from proveit.logic import And, Booleans, Equals, Forall, InSet
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([AA, BB, CC], Equals(And(iterA1l, iterB1m, iterC1n), And(iterA1l, And(iterB1m), iterC1n)), domains = [Exp(Booleans, l), Exp(Booleans, m), Exp(Booleans, n)], conditions = []), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n))] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n))] | n in Naturals
#    core type: Lambda
#    parameter: 68
#    body: 1
#    conditions: 2\n1. forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n))
#    core type: Operation
#    operator: 14
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. A -> [forall_{(B, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n))] | A in BOOLEANS^{l}
#    core type: Lambda
#    parameter: 48
#    body: 5
# ...
