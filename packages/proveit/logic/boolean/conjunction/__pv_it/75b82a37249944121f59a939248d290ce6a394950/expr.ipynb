# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, B, CC, DD, l, m, n
from proveit.logic import And, Booleans, Equals, Forall, InSet
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(l, Forall([m, n], Forall([AA, B, CC, DD], Equals(And(iterA1l, B, iterC1m, iterD1n), And(iterA1l, iterC1m, B, iterD1n)), domains = [Exp(Booleans, l), Booleans, Exp(Booleans, m), Exp(Booleans, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1), conditions = [InSet(l, Naturals)])
# Out:
# expr: l -> [forall_{m, n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))]] | l in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{m, n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))]] | l in Naturals
#    core type: Lambda
#    parameter: 83
#    body: 1
#    conditions: 2\n1. forall_{m, n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))]
#    core type: Operation
#    operator: 31
#    operand: 3
# 2. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# ...
