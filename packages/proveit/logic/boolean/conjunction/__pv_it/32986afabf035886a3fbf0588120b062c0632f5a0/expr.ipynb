# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, BB, C, DD, l, m, n
from proveit.logic import And, Booleans, Equals, Forall, InSet
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, Forall([BB, C, DD], Equals(And(iterA1l, iterB1m, C, iterD1n), And(iterA1l, C, iterB1m, iterD1n)), domains = [Exp(Booleans, m), Booleans, Exp(Booleans, n)], conditions = []), conditions = [InSet(AA, Exp(Booleans, l))])
# Out:
# expr: A -> [forall_{(B, C, D) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n))] | A in BOOLEANS^{l}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{(B, C, D) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n))] | A in BOOLEANS^{l}
#    core type: Lambda
#    parameter: 49
#    body: 1
#    conditions: 2\n1. forall_{(B, C, D) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n))
#    core type: Operation
#    operator: 15
#    operand: 3
# 2. (A in BOOLEANS^{l})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. B -> [forall_{(C, D) in BOOLEANS * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n))] | B in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 51
# ...
