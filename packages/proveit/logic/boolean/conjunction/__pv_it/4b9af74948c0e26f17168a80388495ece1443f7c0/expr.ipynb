# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, CC, m, n
from proveit.logic import And, Booleans, Equals, FALSE, Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([AA, CC], Equals(And(iterA1m, FALSE, iterC1n), FALSE), domains = [Exp(Booleans, m), Exp(Booleans, n)], conditions = []), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)] | n in Naturals
#    core type: Lambda
#    parameter: 52
#    body: 1
#    conditions: 2\n1. forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. A -> [forall_{C in BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)] | A in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 37
#    body: 5
#    conditions: 6\n4. n in Naturals
#    core type: Operation
#    operator: 42
#    operands: 7
# 5. forall_{C in BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (A in BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 10
# ...
