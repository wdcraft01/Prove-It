# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], InSet(A, Booleans), conditions = [InSet(And(A, B), Booleans)]))
# Out:
# expr: A -> [forall_{B | (A and B) in BOOLEANS} (A in BOOLEANS)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | (A and B) in BOOLEANS} (A in BOOLEANS)]
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. forall_{B | (A and B) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. B -> (A in BOOLEANS) | (A and B) in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 4
#    conditions: 5\n4. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 6
# 5. ((A and B) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 7. (A and B) in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A and B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A and B
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (A , B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
