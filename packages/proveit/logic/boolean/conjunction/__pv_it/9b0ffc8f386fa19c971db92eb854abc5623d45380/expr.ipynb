# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], B, domain = Booleans, conditions = [And(A, B)]), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B in BOOLEANS | A and B} B] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in BOOLEANS | A and B} B] | A in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. forall_{B in BOOLEANS | A and B} B
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> B | B in BOOLEANS , A and B
#    core type: Lambda
#    parameter: 16
#    body: 16
#    conditions: 6\n5. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 7
# 6. (B in BOOLEANS , A and B)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. A and B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (A , B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
