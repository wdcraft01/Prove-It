# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nandIfNotLeft">nandIfNotLeft</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import nandIfNotLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr nandIfNotLeft
# Out:
# Passed sanity check: built 'nandIfNotLeft' is the same as the stored Expression.

# %%
# display the expression information
nandIfNotLeft.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | [not](A)} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS} [not](A and B)] | A in BOOLEANS , [not](A)
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS , [not](A))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> [not](A and B) | B in BOOLEANS
#    core type: Lambda
#    parameter: 19
#    body: 8
#    conditions: 9\n6. A in BOOLEANS
#    core type: Operation
#    operator: 16
#    operands: 10
# 7. [not](A)
#    core type: Operation
#    operator: 11
#    operand: 18
# 8. [not](A and B)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. A and B
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. B in BOOLEANS
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. BOOLEANS
#     core type: Literal
#     sub-expressions:
