# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import BB, CC
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Lambda(BB, Forall([CC], And(iterA1l, And(iterB1m), iterC1n), conditions = [And(iterA1l, iterB1m, iterC1n)]))
# Out:
# expr: B -> [forall_{C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> [forall_{C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)]
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. forall_{C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. C -> (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n) | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n
#    core type: Lambda
#    parameter: 26
#    body: 4
#    conditions: 5\n4. A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (A_1 ,  ...  , A_l , B_1 and  ...  and B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 12, 8, 13
# 7. A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. B_1 and  ...  and B_m
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 12, 14, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. A_1,...,A_l
#     core type: Iter
#     lambda_map: 15
#     start_index: 44
#     end_index: 42
# 13. C_1,...,C_n
#     core type: Iter
#     lambda_map: 16
#     start_index: 44
#     end_index: 43
# 14. B_1,...,B_m
#     core type: Iter
#     lambda_map: 17
#     start_index: 44
#     end_index: 45
# 15. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 36
#     body: 18
#     conditions: 19\n16. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 36
#     body: 20
#     conditions: 21\n17. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 36
#     body: 22
#     conditions: 23\n18. A__x_
#     core type: Indexed
#     var: 24
#     index: 36
#     base: "1"
# 19. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 25
# 20. C__x_
#     core type: Indexed
#     var: 26
#     index: 36
#     base: "1"
# 21. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 27
# 22. B__x_
#     core type: Indexed
#     var: 28
#     index: 36
#     base: "1"
# 23. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 29
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. _x_ in {1...l}
#     core type: Operation
#     operator: 32
#     operands: 30
# 26. C
#     core type: Variable
#     sub-expressions:
# 27. _x_ in {1...n}
#     core type: Operation
#     operator: 32
#     operands: 31
# 28. B
#     core type: Variable
#     sub-expressions:
# 29. _x_ in {1...m}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 36, 34
# 31. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. {1...l}
#     core type: Operation
#     operator: 40
#     operands: 38
# 35. {1...n}
#     core type: Operation
#     operator: 40
#     operands: 39
# 36. _x_
#     core type: Variable
#     sub-expressions:
# 37. {1...m}
#     core type: Operation
#     operator: 40
#     operands: 41
# 38. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 44, 42
# 39. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 44, 43
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. l
#     core type: Variable
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. m
#     core type: Variable
#     sub-expressions:
