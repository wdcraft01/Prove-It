# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, BB
from proveit.logic import And, Equals, Forall
from proveit.logic._common_ import iterB1n

# %%
# build up the expression from sub-expressions
expr = Forall([BB], Equals(And(A, iterB1n), And(A, And(iterB1n))), conditions = [])
# Out:
# expr: forall_{B} ((A and B_1 and  ...  and B_n) = (A and (B_1 and  ...  and B_n)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B} ((A and B_1 and  ...  and B_n) = (A and (B_1 and  ...  and B_n)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> ((A and B_1 and  ...  and B_n) = (A and (B_1 and  ...  and B_n)))
#    core type: Lambda
#    parameter: 18
#    body: 3
# 3. (A and B_1 and  ...  and B_n) = (A and (B_1 and  ...  and B_n))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A and B_1 and  ...  and B_n , A and (B_1 and  ...  and B_n))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A and B_1 and  ...  and B_n
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. A and (B_1 and  ...  and B_n)
#    core type: Operation
#    operator: 12
#    operands: 9
# 8. (A , B_1 ,  ...  , B_n)
#    core type: ExprTuple
#    sub-expressions: 10, 14
# 9. (A , B_1 and  ...  and B_n)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B_1 and  ...  and B_n
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (B_1 ,  ...  , B_n)
#     core type: ExprTuple
#     sub-expressions: 14
# 14. B_1,...,B_n
#     core type: Iter
#     lambda_map: 15
#     start_index: 26
#     end_index: 27
# 15. _x_ -> B__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 22
#     body: 16
#     conditions: 17\n16. B__x_
#     core type: Indexed
#     var: 18
#     index: 22
#     base: "1"
# 17. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. _x_ in {1...n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. _x_
#     core type: Variable
#     sub-expressions:
# 23. {1...n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
