# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#leftFromAndExplicit">leftFromAndExplicit</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import leftFromAndExplicit

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftFromAndExplicit
# Out:
# Passed sanity check: built 'leftFromAndExplicit' is the same as the stored Expression.

# %%
# display the expression information
leftFromAndExplicit.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | A and B} A
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS | A and B} A] | A in BOOLEANS
#    core type: Lambda
#    parameter: 16
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS | A and B} A
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> A | B in BOOLEANS , A and B
#    core type: Lambda
#    parameter: 17
#    body: 16
#    conditions: 7\n6. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 8
# 7. (B in BOOLEANS , A and B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 15
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. A and B
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. in
# ...
