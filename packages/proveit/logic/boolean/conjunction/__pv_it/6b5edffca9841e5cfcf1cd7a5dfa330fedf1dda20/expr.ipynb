# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import BB, CC, m, n
from proveit.logic import And, Booleans, Equals, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([BB, CC], Equals(And(iterA1l, And(iterB1m), iterC1n), And(iterA1l, iterB1m, iterC1n)), domains = [Exp(Booleans, m), Exp(Booleans, n)], conditions = [])
# Out:
# expr: forall_{(B, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(B, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. B -> [forall_{C in BOOLEANS^{n}} ((A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n))] | B in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 45
#    body: 2
#    conditions: 3\n2. forall_{C in BOOLEANS^{n}} ((A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n) = (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (B in BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# ...
