# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.logic import And, Booleans, Forall, InSet, TRUE

# %%
# build up the expression from sub-expressions
expr = Forall([B], InSet(And(TRUE, B), Booleans), domain = Booleans, conditions = [])
# Out:
# expr: forall_{B in BOOLEANS} ((TRUE and B) in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS} ((TRUE and B) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> ((TRUE and B) in BOOLEANS) | B in BOOLEANS
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. (TRUE and B) in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (TRUE and B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 12
# 6. B in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. TRUE and B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (TRUE , B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. TRUE
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
