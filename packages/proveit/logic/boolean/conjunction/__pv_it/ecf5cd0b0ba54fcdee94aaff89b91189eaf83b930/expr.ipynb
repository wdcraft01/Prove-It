# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, BB, CC
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Forall([AA, BB, CC], And(iterA1l, And(iterB1m), iterC1n), conditions = [And(iterA1l, iterB1m, iterC1n)])
# Out:
# expr: forall_{A, B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. A -> [forall_{B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)]
#    core type: Lambda
#    parameter: 27
#    body: 2
# 2. forall_{B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. B -> [forall_{C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)]
#    core type: Lambda
#    parameter: 31
#    body: 4
# 4. forall_{C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. C -> (A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n) | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n
#    core type: Lambda
#    parameter: 29
#    body: 7
#    conditions: 8\n7. A_1 and  ...  and A_l and (B_1 and  ...  and B_m) and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 13
#    operands: 9
# 8. (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (A_1 ,  ...  , A_l , B_1 and  ...  and B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 15, 11, 16
# 10. A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. B_1 and  ...  and B_m
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 15, 17, 16
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 17
# 15. A_1,...,A_l
#     core type: Iter
#     lambda_map: 18
#     start_index: 47
#     end_index: 45
# 16. C_1,...,C_n
#     core type: Iter
#     lambda_map: 19
#     start_index: 47
#     end_index: 46
# 17. B_1,...,B_m
#     core type: Iter
#     lambda_map: 20
#     start_index: 47
#     end_index: 48
# 18. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 39
#     body: 21
#     conditions: 22\n19. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 39
#     body: 23
#     conditions: 24\n20. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 39
#     body: 25
#     conditions: 26\n21. A__x_
#     core type: Indexed
#     var: 27
#     index: 39
#     base: "1"
# 22. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 28
# 23. C__x_
#     core type: Indexed
#     var: 29
#     index: 39
#     base: "1"
# 24. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 30
# 25. B__x_
#     core type: Indexed
#     var: 31
#     index: 39
#     base: "1"
# 26. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 32
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. _x_ in {1...l}
#     core type: Operation
#     operator: 35
#     operands: 33
# 29. C
#     core type: Variable
#     sub-expressions:
# 30. _x_ in {1...n}
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. B
#     core type: Variable
#     sub-expressions:
# 32. _x_ in {1...m}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 34. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. {1...l}
#     core type: Operation
#     operator: 43
#     operands: 41
# 38. {1...n}
#     core type: Operation
#     operator: 43
#     operands: 42
# 39. _x_
#     core type: Variable
#     sub-expressions:
# 40. {1...m}
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 47, 45
# 42. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 47, 46
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. l
#     core type: Variable
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. m
#     core type: Variable
#     sub-expressions:
