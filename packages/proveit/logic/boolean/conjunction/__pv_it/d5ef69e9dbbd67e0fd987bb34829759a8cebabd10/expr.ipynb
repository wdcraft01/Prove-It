# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import And, FALSE
from proveit.logic._common_ import iterA1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(iterA1m, FALSE, iterC1n), FALSE)
# Out:
# expr: (A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n , FALSE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n , FALSE)
#    core type: ExprTuple
#    sub-expressions: 1, 5
# 1. A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. (A_1 ,  ...  , A_m , FALSE , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. A_1,...,A_m
#    core type: Iter
#    lambda_map: 7
#    start_index: 27
#    end_index: 26
# 5. FALSE
#    core type: Literal
#    sub-expressions:
# 6. C_1,...,C_n
#    core type: Iter
#    lambda_map: 8
#    start_index: 27
#    end_index: 28
# 7. _x_ -> A__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 21
#    body: 9
#    conditions: 10\n8. _x_ -> C__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 21
#    body: 11
#    conditions: 12\n9. A__x_
#    core type: Indexed
#    var: 13
#    index: 21
#    base: "1"
# 10. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. C__x_
#     core type: Indexed
#     var: 15
#     index: 21
#     base: "1"
# 12. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. _x_ in {1...m}
#     core type: Operation
#     operator: 18
#     operands: 17
# 15. C
#     core type: Variable
#     sub-expressions:
# 16. _x_ in {1...n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. {1...m}
#     core type: Operation
#     operator: 24
#     operands: 23
# 21. _x_
#     core type: Variable
#     sub-expressions:
# 22. {1...n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. m
#     core type: Variable
#     sub-expressions:
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
