# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nandIfNeither">nandIfNeither</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import nandIfNeither

# %%
# check that the built expression is the same as the stored expression
# %check_expr nandIfNeither
# Out:
# Passed sanity check: built 'nandIfNeither' is the same as the stored Expression.

# %%
# display the expression information
nandIfNeither.exprInfo()
# Out:
# 0. forall_{A, B | [not](A) , [not](B)} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B | [not](B)} [not](A and B)] | [not](A)
#    core type: Lambda
#    parameter: 14
#    body: 2
#    conditions: 3\n2. forall_{B | [not](B)} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> [not](A and B) | [not](B)
#    core type: Lambda
#    parameter: 15
#    body: 7
#    conditions: 8\n6. [not](A)
#    core type: Operation
#    operator: 13
#    operand: 14
# 7. [not](A and B)
#    core type: Operation
#    operator: 13
#    operand: 9
# 8. ([not](B))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. A and B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. [not](B)
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. and
#     core type: Literal
# ...
