# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nandIfRightButNotLeft">nandIfRightButNotLeft</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import nandIfRightButNotLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr nandIfRightButNotLeft
# Out:
# Passed sanity check: built 'nandIfRightButNotLeft' is the same as the stored Expression.

# %%
# display the expression information
nandIfRightButNotLeft.exprInfo()
# Out:
# 0. forall_{A, B | [not](A) , B} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B | B} [not](A and B)] | [not](A)
#    core type: Lambda
#    parameter: 13
#    body: 2
#    conditions: 3\n2. forall_{B | B} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> [not](A and B) | B
#    core type: Lambda
#    parameter: 14
#    body: 7
#    conditions: 8\n6. [not](A)
#    core type: Operation
#    operator: 9
#    operand: 13
# 7. [not](A and B)
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. (B)
#    core type: ExprTuple
#    sub-expressions: 14
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. A and B
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
# ...
