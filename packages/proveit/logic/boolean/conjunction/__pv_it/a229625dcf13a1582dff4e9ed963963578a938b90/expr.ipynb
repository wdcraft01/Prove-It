# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E
from proveit.logic import And, Booleans, InSet, Or

# %%
# build up the expression from sub-expressions
expr = InSet(Or(A, B, And(And(C, D), E)), Booleans)
# Out:
# expr: (A or B or ((C and D) and E)) in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A or B or ((C and D) and E)) in BOOLEANS
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (A or B or ((C and D) and E) , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A or B or ((C and D) and E)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A , B , (C and D) and E)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. (C and D) and E
#    core type: Operation
#    operator: 13
#    operands: 10
# 10. (C and D , E)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. C and D
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. E
#     core type: Variable
#     sub-expressions:
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (C , D)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. C
#     core type: Variable
#     sub-expressions:
# 16. D
#     core type: Variable
#     sub-expressions:
