# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Equals, FALSE, Forall, Not

# %%
# build up the expression from sub-expressions
subExpr1 = [B]
expr = Lambda(A, Forall(subExpr1, Equals(And(A, B), FALSE), conditions = subExpr1), conditions = [Not(A)])
# Out:
# expr: A -> [forall_{B | B} ((A and B) = FALSE)] | [not](A)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | B} ((A and B) = FALSE)] | [not](A)
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. forall_{B | B} ((A and B) = FALSE)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((A and B) = FALSE) | B
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n5. [not](A)
#    core type: Operation
#    operator: 8
#    operand: 15
# 6. (A and B) = FALSE
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (B)
#    core type: ExprTuple
#    sub-expressions: 16
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A and B , FALSE)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A and B
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. FALSE
#     core type: Literal
#     sub-expressions:
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
