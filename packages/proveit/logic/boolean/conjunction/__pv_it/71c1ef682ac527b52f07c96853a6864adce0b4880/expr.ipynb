# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import C
from proveit.logic import And
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n

# %%
# build up the expression from sub-expressions
expr = And(iterA1l, iterB1m, C, iterD1n)
# Out:
# expr: A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. A_1,...,A_l
#    core type: Iter
#    lambda_map: 7
#    start_index: 36
#    end_index: 34
# 4. B_1,...,B_m
#    core type: Iter
#    lambda_map: 8
#    start_index: 36
#    end_index: 35
# 5. C
#    core type: Variable
#    sub-expressions:
# 6. D_1,...,D_n
#    core type: Iter
#    lambda_map: 9
#    start_index: 36
#    end_index: 37
# 7. _x_ -> A__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 28
#    body: 10
#    conditions: 11\n8. _x_ -> B__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 28
#    body: 12
#    conditions: 13\n9. _x_ -> D__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 28
#    body: 14
#    conditions: 15\n10. A__x_
#     core type: Indexed
#     var: 16
#     index: 28
#     base: "1"
# 11. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 17
# 12. B__x_
#     core type: Indexed
#     var: 18
#     index: 28
#     base: "1"
# 13. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 19
# 14. D__x_
#     core type: Indexed
#     var: 20
#     index: 28
#     base: "1"
# 15. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. _x_ in {1...l}
#     core type: Operation
#     operator: 24
#     operands: 22
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. _x_ in {1...m}
#     core type: Operation
#     operator: 24
#     operands: 23
# 20. D
#     core type: Variable
#     sub-expressions:
# 21. _x_ in {1...n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 23. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. {1...l}
#     core type: Operation
#     operator: 32
#     operands: 30
# 27. {1...m}
#     core type: Operation
#     operator: 32
#     operands: 31
# 28. _x_
#     core type: Variable
#     sub-expressions:
# 29. {1...n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 36, 34
# 31. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 32. Interval
#     core type: Literal
#     sub-expressions:
# 33. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. l
#     core type: Variable
#     sub-expressions:
# 35. m
#     core type: Variable
#     sub-expressions:
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. n
#     core type: Variable
#     sub-expressions:
