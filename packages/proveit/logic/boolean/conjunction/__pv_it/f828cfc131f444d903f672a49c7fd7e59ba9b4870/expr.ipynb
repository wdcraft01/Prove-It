# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#falseEval">falseEval</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import falseEval

# %%
# check that the built expression is the same as the stored expression
# %check_expr falseEval
# Out:
# Passed sanity check: built 'falseEval' is the same as the stored Expression.

# %%
# display the expression information
falseEval.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)]
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)]] | m in Naturals
#    core type: Lambda
#    parameter: 56
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)]
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)] | n in Naturals
#    core type: Lambda
#    parameter: 58
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 48
#    operands: 8
# 6. forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)
#    core type: Operation
#    operator: 14
#    operand: 9
# 7. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 56, 17
# 9. A -> [forall_{C in BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)] | A in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 43
#    body: 11
#    conditions: 12\n10. n in Naturals
#     core type: Operation
#     operator: 48
#     operands: 13
# 11. forall_{C in BOOLEANS^{n}} ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. (A in BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 58, 17
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. C -> ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE) | C in BOOLEANS^{n}
#     core type: Lambda
#     parameter: 45
#     body: 18
#     conditions: 19\n16. A in BOOLEANS^{m}
#     core type: Operation
#     operator: 48
#     operands: 20
# 17. Naturals
#     core type: Literal
#     sub-expressions:
# 18. (A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. (C in BOOLEANS^{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. (A , BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 43, 24
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n , FALSE)
#     core type: ExprTuple
#     sub-expressions: 25, 32
# 23. C in BOOLEANS^{n}
#     core type: Operation
#     operator: 48
#     operands: 26
# 24. BOOLEANS^{m}
#     core type: Operation
#     operator: 34
#     operands: 27
# 25. A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. (C , BOOLEANS^{n})
#     core type: ExprTuple
#     sub-expressions: 45, 30
# 27. (BOOLEANS , m)
#     core type: ExprTuple
#     sub-expressions: 38, 56
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. (A_1 ,  ...  , A_m , FALSE , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 31, 32, 33
# 30. BOOLEANS^{n}
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. A_1,...,A_m
#     core type: Iter
#     lambda_map: 36
#     start_index: 57
#     end_index: 56
# 32. FALSE
#     core type: Literal
#     sub-expressions:
# 33. C_1,...,C_n
#     core type: Iter
#     lambda_map: 37
#     start_index: 57
#     end_index: 58
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (BOOLEANS , n)
#     core type: ExprTuple
#     sub-expressions: 38, 58
# 36. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 51
#     body: 39
#     conditions: 40\n37. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 51
#     body: 41
#     conditions: 42\n38. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 39. A__x_
#     core type: Indexed
#     var: 43
#     index: 51
#     base: "1"
# 40. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 44
# 41. C__x_
#     core type: Indexed
#     var: 45
#     index: 51
#     base: "1"
# 42. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 46
# 43. A
#     core type: Variable
#     sub-expressions:
# 44. _x_ in {1...m}
#     core type: Operation
#     operator: 48
#     operands: 47
# 45. C
#     core type: Variable
#     sub-expressions:
# 46. _x_ in {1...n}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 51, 50
# 48. in
#     core type: Literal
#     sub-expressions:
# 49. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 50. {1...m}
#     core type: Operation
#     operator: 54
#     operands: 53
# 51. _x_
#     core type: Variable
#     sub-expressions:
# 52. {1...n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 53. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 57, 56
# 54. Interval
#     core type: Literal
#     sub-expressions:
# 55. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 56. m
#     core type: Variable
#     sub-expressions:
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. n
#     core type: Variable
#     sub-expressions:
