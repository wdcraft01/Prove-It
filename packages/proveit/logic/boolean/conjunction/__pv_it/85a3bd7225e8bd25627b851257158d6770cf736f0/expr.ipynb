# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, B, CC, DD, l, m, n
from proveit.logic import And, Booleans, Equals, Forall, InSet
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([AA, B, CC, DD], Equals(And(iterA1l, B, iterC1m, iterD1n), And(iterA1l, iterC1m, B, iterD1n)), domains = [Exp(Booleans, l), Booleans, Exp(Booleans, m), Exp(Booleans, n)], conditions = []), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | n in Naturals
#    core type: Lambda
#    parameter: 76
#    body: 1
#    conditions: 2\n1. forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))
#    core type: Operation
#    operator: 21
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. A -> [forall_{(B, C, D) in BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | A in BOOLEANS^{l}
#    core type: Lambda
#    parameter: 55
#    body: 5
#    conditions: 6\n4. n in Naturals
#    core type: Operation
#    operator: 63
#    operands: 7
# 5. forall_{(B, C, D) in BOOLEANS * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))
#    core type: Operation
#    operator: 21
#    operand: 8
# 6. (A in BOOLEANS^{l})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (n , Naturals)
#    core type: ExprTuple
#    sub-expressions: 76, 10
# 8. B -> [forall_{(C, D) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | B in BOOLEANS
#    core type: Lambda
#    parameter: 41
#    body: 11
#    conditions: 12\n9. A in BOOLEANS^{l}
#    core type: Operation
#    operator: 63
#    operands: 13
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. forall_{(C, D) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))
#     core type: Operation
#     operator: 21
#     operand: 14
# 12. (B in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (A , BOOLEANS^{l})
#     core type: ExprTuple
#     sub-expressions: 55, 16
# 14. C -> [forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | C in BOOLEANS^{m}
#     core type: Lambda
#     parameter: 57
#     body: 17
#     conditions: 18\n15. B in BOOLEANS
#     core type: Operation
#     operator: 63
#     operands: 19
# 16. BOOLEANS^{l}
#     core type: Operation
#     operator: 43
#     operands: 20
# 17. forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))
#     core type: Operation
#     operator: 21
#     operand: 22
# 18. (C in BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 23
# 19. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 41, 48
# 20. (BOOLEANS , l)
#     core type: ExprTuple
#     sub-expressions: 48, 73
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. D -> ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)) | D in BOOLEANS^{n}
#     core type: Lambda
#     parameter: 59
#     body: 24
#     conditions: 25\n23. C in BOOLEANS^{m}
#     core type: Operation
#     operator: 63
#     operands: 26
# 24. (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (D in BOOLEANS^{n})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. (C , BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 57, 30
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n , A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. D in BOOLEANS^{n}
#     core type: Operation
#     operator: 63
#     operands: 33
# 30. BOOLEANS^{m}
#     core type: Operation
#     operator: 43
#     operands: 34
# 31. A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n
#     core type: Operation
#     operator: 36
#     operands: 35
# 32. A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (D , BOOLEANS^{n})
#     core type: ExprTuple
#     sub-expressions: 59, 38
# 34. (BOOLEANS , m)
#     core type: ExprTuple
#     sub-expressions: 48, 74
# 35. (A_1 ,  ...  , A_l , B , C_1 ,  ...  , C_m , D_1 ,  ...  , D_n)
#     core type: ExprTuple
#     sub-expressions: 39, 41, 40, 42
# 36. and
#     core type: Literal
#     sub-expressions:
# 37. (A_1 ,  ...  , A_l , C_1 ,  ...  , C_m , B , D_1 ,  ...  , D_n)
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41, 42
# 38. BOOLEANS^{n}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. A_1,...,A_l
#     core type: Iter
#     lambda_map: 45
#     start_index: 75
#     end_index: 73
# 40. C_1,...,C_m
#     core type: Iter
#     lambda_map: 46
#     start_index: 75
#     end_index: 74
# 41. B
#     core type: Variable
#     sub-expressions:
# 42. D_1,...,D_n
#     core type: Iter
#     lambda_map: 47
#     start_index: 75
#     end_index: 76
# 43. Exp
#     core type: Literal
#     sub-expressions:
# 44. (BOOLEANS , n)
#     core type: ExprTuple
#     sub-expressions: 48, 76
# 45. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 67
#     body: 49
#     conditions: 50\n46. _x_ -> C__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 67
#     body: 51
#     conditions: 52\n47. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 67
#     body: 53
#     conditions: 54\n48. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 49. A__x_
#     core type: Indexed
#     var: 55
#     index: 67
#     base: "1"
# 50. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 56
# 51. C__x_
#     core type: Indexed
#     var: 57
#     index: 67
#     base: "1"
# 52. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 58
# 53. D__x_
#     core type: Indexed
#     var: 59
#     index: 67
#     base: "1"
# 54. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 60
# 55. A
#     core type: Variable
#     sub-expressions:
# 56. _x_ in {1...l}
#     core type: Operation
#     operator: 63
#     operands: 61
# 57. C
#     core type: Variable
#     sub-expressions:
# 58. _x_ in {1...m}
#     core type: Operation
#     operator: 63
#     operands: 62
# 59. D
#     core type: Variable
#     sub-expressions:
# 60. _x_ in {1...n}
#     core type: Operation
#     operator: 63
#     operands: 64
# 61. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 67, 65
# 62. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 67, 66
# 63. in
#     core type: Literal
#     sub-expressions:
# 64. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 65. {1...l}
#     core type: Operation
#     operator: 71
#     operands: 69
# 66. {1...m}
#     core type: Operation
#     operator: 71
#     operands: 70
# 67. _x_
#     core type: Variable
#     sub-expressions:
# 68. {1...n}
#     core type: Operation
#     operator: 71
#     operands: 72
# 69. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 75, 73
# 70. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 75, 74
# 71. Interval
#     core type: Literal
#     sub-expressions:
# 72. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. l
#     core type: Variable
#     sub-expressions:
# 74. m
#     core type: Variable
#     sub-expressions:
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. n
#     core type: Variable
#     sub-expressions:
