# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, BB, CC, n
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([AA, BB, CC], And(iterB1m), conditions = [And(iterA1l, iterB1m, iterC1n)]), domain = Naturals, conditions = [])
# Out:
# expr: forall_{n in Naturals} [forall_{A, B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (B_1 and  ...  and B_m)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{A, B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (B_1 and  ...  and B_m)]
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. n -> [forall_{A, B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (B_1 and  ...  and B_m)] | n in Naturals
#    core type: Lambda
#    parameter: 52
#    body: 2
#    conditions: 3\n2. forall_{A, B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (B_1 and  ...  and B_m)
#    core type: Operation
#    operator: 11
#    operand: 4
# 3. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. A -> [forall_{B, C | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C_1 and  ...  and C_n} (B_1 and  ...  and B_m)]
#    core type: Lambda
#    parameter: 31
#    body: 6
# 5. n in Naturals
#    core type: Operation
#    operator: 39
#    operands: 7
# ...
