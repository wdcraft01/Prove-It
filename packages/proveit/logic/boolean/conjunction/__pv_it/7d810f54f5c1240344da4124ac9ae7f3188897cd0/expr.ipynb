# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import CC, n
from proveit.logic import And, Booleans, Equals, FALSE, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, Equals(And(iterA1m, FALSE, iterC1n), FALSE), conditions = [InSet(CC, Exp(Booleans, n))])
# Out:
# expr: C -> ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE) | C in BOOLEANS^{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> ((A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE) | C in BOOLEANS^{n}
#    core type: Lambda
#    parameter: 25
#    body: 1
#    conditions: 2\n1. (A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n) = FALSE
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (C in BOOLEANS^{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n , FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 12
# 5. C in BOOLEANS^{n}
#    core type: Operation
#    operator: 28
#    operands: 7
# 6. A_1 and  ...  and A_m and FALSE and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (C , BOOLEANS^{n})
#    core type: ExprTuple
#    sub-expressions: 25, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_m , FALSE , C_1 ,  ...  , C_n)
#    core type: ExprTuple
# ...
