# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(B, And(A, B), conditions = [Not(Or(Not(A), Not(B)))])
# Out:
# expr: B -> (A and B) | [not]([not](A) or [not](B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> (A and B) | [not]([not](A) or [not](B))
#    core type: Lambda
#    parameter: 13
#    body: 1
#    conditions: 2\n1. A and B
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. ([not]([not](A) or [not](B)))
#    core type: ExprTuple
#    sub-expressions: 5
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (A , B)
#    core type: ExprTuple
#    sub-expressions: 11, 13
# 5. [not]([not](A) or [not](B))
#    core type: Operation
#    operator: 12
#    operand: 6
# 6. [not](A) or [not](B)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. ([not](A) , [not](B))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. [not](A)
#    core type: Operation
#    operator: 12
#    operand: 11
# 10. [not](B)
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
