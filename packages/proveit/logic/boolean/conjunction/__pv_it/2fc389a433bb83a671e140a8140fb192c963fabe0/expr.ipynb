# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a
from proveit.logic import Forall, InSet
from proveit.number import Exp, one

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [a]
expr = Forall([S], Forall(subExpr2, InSet(subExpr2, Exp(S, one)), domain = S, conditions = subExpr1), conditions = subExpr1)
# Out:
# expr: forall_{S} [forall_{a in S} ((a) in S^{1})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S} [forall_{a in S} ((a) in S^{1})]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. S -> [forall_{a in S} ((a) in S^{1})]
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. forall_{a in S} ((a) in S^{1})
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. a -> ((a) in S^{1}) | a in S
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. (a) in S^{1}
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. (a in S)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. ((a) , S^{1})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a in S
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (a)
#    core type: ExprTuple
#    sub-expressions: 15
# 10. S^{1}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (a , S)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (S , 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. S
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
