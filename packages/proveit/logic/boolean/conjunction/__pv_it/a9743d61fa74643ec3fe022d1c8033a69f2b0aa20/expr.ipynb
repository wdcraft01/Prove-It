# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, B, CC, n
from proveit.logic import Booleans, Forall, InSet, Or
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([AA, B, CC], InSet(B, Booleans), conditions = [InSet(Or(iterA1m, B, iterC1n), Booleans)]), domain = Naturals, conditions = [])
# Out:
# expr: forall_{n in Naturals} [forall_{A, B, C | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS} (B in BOOLEANS)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{A, B, C | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS} (B in BOOLEANS)]
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. n -> [forall_{A, B, C | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS} (B in BOOLEANS)] | n in Naturals
#    core type: Lambda
#    parameter: 46
#    body: 2
#    conditions: 3\n2. forall_{A, B, C | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS} (B in BOOLEANS)
#    core type: Operation
#    operator: 11
#    operand: 4
# 3. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. A -> [forall_{B, C | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS} (B in BOOLEANS)]
#    core type: Lambda
#    parameter: 31
#    body: 6
# 5. n in Naturals
#    core type: Operation
#    operator: 36
#    operands: 7
# 6. forall_{B, C | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS} (B in BOOLEANS)
#    core type: Operation
# ...
