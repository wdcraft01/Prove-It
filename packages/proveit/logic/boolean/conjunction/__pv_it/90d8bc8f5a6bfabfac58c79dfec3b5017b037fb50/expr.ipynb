# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, CC
from proveit.logic import Booleans, InSet, Or
from proveit.logic._common_ import iterA1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, InSet(B, Booleans), conditions = [InSet(Or(iterA1m, B, iterC1n), Booleans)])
# Out:
# expr: C -> (B in BOOLEANS) | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> (B in BOOLEANS) | (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. B in BOOLEANS
#    core type: Operation
#    operator: 24
#    operands: 3
# 2. ((A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 7
# 4. (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) in BOOLEANS
#    core type: Operation
#    operator: 24
#    operands: 5
# 5. (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. A_1 or  ...  or A_m or B or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_m , B , C_1 ,  ...  , C_n)
#    core type: ExprTuple
# ...
