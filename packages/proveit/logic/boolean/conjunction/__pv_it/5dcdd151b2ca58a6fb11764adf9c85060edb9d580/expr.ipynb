# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, m
from proveit.logic import And, Booleans, Forall, InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([AA], InSet(And(iterA1m), Booleans), domain = Exp(Booleans, m), conditions = []), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{A in BOOLEANS^{m}} ((A_1 and  ...  and A_m) in BOOLEANS)] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{A in BOOLEANS^{m}} ((A_1 and  ...  and A_m) in BOOLEANS)] | m in Naturals
#    core type: Lambda
#    parameter: 33
#    body: 1
#    conditions: 2\n1. forall_{A in BOOLEANS^{m}} ((A_1 and  ...  and A_m) in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> ((A_1 and  ...  and A_m) in BOOLEANS) | A in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 24
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 26
#    operands: 8
# 6. (A_1 and  ...  and A_m) in BOOLEANS
#    core type: Operation
#    operator: 26
#    operands: 9
# 7. (A in BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 33, 11
# 9. (A_1 and  ...  and A_m , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 21
# ...
