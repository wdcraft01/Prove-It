# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#nandIfNotRight">nandIfNotRight</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import nandIfNotRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr nandIfNotRight
# Out:
# Passed sanity check: built 'nandIfNotRight' is the same as the stored Expression.

# %%
# display the expression information
nandIfNotRight.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | [not](B)} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS | [not](B)} [not](A and B)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS | [not](B)} [not](A and B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> [not](A and B) | B in BOOLEANS , [not](B)
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n6. A in BOOLEANS
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. [not](A and B)
#    core type: Operation
#    operator: 17
#    operand: 10
# 8. (B in BOOLEANS , [not](B))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 20
# 10. A and B
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. B in BOOLEANS
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. [not](B)
#     core type: Operation
#     operator: 17
#     operand: 19
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. not
#     core type: Literal
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. BOOLEANS
#     core type: Literal
#     sub-expressions:
