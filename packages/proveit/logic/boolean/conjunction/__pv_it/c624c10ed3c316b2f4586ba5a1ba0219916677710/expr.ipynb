# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.logic import And, Booleans, FALSE, Forall, Not

# %%
# build up the expression from sub-expressions
expr = Forall([B], Not(And(FALSE, B)), domain = Booleans, conditions = [Not(B)])
# Out:
# expr: forall_{B in BOOLEANS | [not](B)} [not](FALSE and B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS | [not](B)} [not](FALSE and B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> [not](FALSE and B) | B in BOOLEANS , [not](B)
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. [not](FALSE and B)
#    core type: Operation
#    operator: 12
#    operand: 5
# 4. (B in BOOLEANS , [not](B))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. FALSE and B
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. [not](B)
#    core type: Operation
#    operator: 12
#    operand: 14
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (FALSE , B)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. FALSE
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
