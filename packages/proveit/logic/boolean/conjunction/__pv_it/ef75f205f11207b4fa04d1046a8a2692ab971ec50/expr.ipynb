# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, B, CC
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Forall([AA, B, CC], B, conditions = [And(iterA1m, B, iterC1n)])
# Out:
# expr: forall_{A, B, C | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n} B

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B, C | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n} B
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. A -> [forall_{B, C | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n} B]
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. forall_{B, C | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n} B
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. B -> [forall_{C | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n} B]
#    core type: Lambda
#    parameter: 12
#    body: 4
# 4. forall_{C | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n} B
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. C -> B | A_1 and  ...  and A_m and B and C_1 and  ...  and C_n
#    core type: Lambda
#    parameter: 22
#    body: 12
#    conditions: 7\n7. (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)
#    core type: ExprTuple
#    sub-expressions: 8
# 8. A_1 and  ...  and A_m and B and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A_1 ,  ...  , A_m , B , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13
# 11. A_1,...,A_m
#     core type: Iter
#     lambda_map: 14
#     start_index: 34
#     end_index: 33
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. C_1,...,C_n
#     core type: Iter
#     lambda_map: 15
#     start_index: 34
#     end_index: 35
# 14. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 28
#     body: 16
#     conditions: 17\n15. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 28
#     body: 18
#     conditions: 19\n16. A__x_
#     core type: Indexed
#     var: 20
#     index: 28
#     base: "1"
# 17. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 21
# 18. C__x_
#     core type: Indexed
#     var: 22
#     index: 28
#     base: "1"
# 19. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 23
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. _x_ in {1...m}
#     core type: Operation
#     operator: 25
#     operands: 24
# 22. C
#     core type: Variable
#     sub-expressions:
# 23. _x_ in {1...n}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. {1...m}
#     core type: Operation
#     operator: 31
#     operands: 30
# 28. _x_
#     core type: Variable
#     sub-expressions:
# 29. {1...n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 34, 33
# 31. Interval
#     core type: Literal
#     sub-expressions:
# 32. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. m
#     core type: Variable
#     sub-expressions:
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. n
#     core type: Variable
#     sub-expressions:
