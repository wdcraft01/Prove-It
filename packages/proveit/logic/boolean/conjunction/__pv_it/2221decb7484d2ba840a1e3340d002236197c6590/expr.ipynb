# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Forall, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Not(And(A, B)), conditions = [Not(B)]), conditions = [A])
# Out:
# expr: A -> [forall_{B | [not](B)} [not](A and B)] | A

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | [not](B)} [not](A and B)] | A
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. forall_{B | [not](B)} [not](A and B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A)
#    core type: ExprTuple
#    sub-expressions: 12
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> [not](A and B) | [not](B)
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n5. [not](A and B)
#    core type: Operation
#    operator: 11
#    operand: 7
# 6. ([not](B))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. A and B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [not](B)
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
