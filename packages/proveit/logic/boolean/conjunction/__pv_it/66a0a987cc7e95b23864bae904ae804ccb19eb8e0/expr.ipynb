# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, DD, n
from proveit.logic import And, Booleans, Equals, InSet
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Lambda(DD, Equals(And(iterA1l, B, iterC1m, iterD1n), And(iterA1l, iterC1m, B, iterD1n)), conditions = [InSet(DD, Exp(Booleans, n))])
# Out:
# expr: D -> ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)) | D in BOOLEANS^{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. D -> ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)) | D in BOOLEANS^{n}
#    core type: Lambda
#    parameter: 33
#    body: 1
#    conditions: 2\n1. (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (D in BOOLEANS^{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n , A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. D in BOOLEANS^{n}
#    core type: Operation
#    operator: 37
#    operands: 8
# ...
