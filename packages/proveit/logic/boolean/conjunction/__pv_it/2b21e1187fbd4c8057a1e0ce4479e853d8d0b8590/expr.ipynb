# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.logic import And, Forall, Not
from proveit.logic._common_ import iterA1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Forall([B, iterC1n], Not(And(iterA1m, B, iterC1n)), conditions = [Not(B)])
# Out:
# expr: forall_{B, C_1,...,C_n | [not](B)} [not](A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B, C_1,...,C_n | [not](B)} [not](A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. B -> [forall_{C_1,...,C_n} [not](A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)] | [not](B)
#    core type: Lambda
#    parameter: 13
#    body: 2
#    conditions: 3\n2. forall_{C_1,...,C_n} [not](A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. ([not](B))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (C_1,...,C_n) -> [not](A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)
#    core type: Lambda
#    parameter: 14
#    body: 7
# 6. [not](B)
#    core type: Operation
#    operator: 8
#    operand: 13
# 7. [not](A_1 and  ...  and A_m and B and C_1 and  ...  and C_n)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. A_1 and  ...  and A_m and B and C_1 and  ...  and C_n
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A_1 ,  ...  , A_m , B , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14
# 12. A_1,...,A_m
#     core type: Iter
#     lambda_map: 15
#     start_index: 35
#     end_index: 34
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. C_1,...,C_n
#     core type: Iter
#     lambda_map: 16
#     start_index: 35
#     end_index: 36
# 15. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 29
#     body: 17
#     conditions: 18\n16. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 29
#     body: 19
#     conditions: 20\n17. A__x_
#     core type: Indexed
#     var: 21
#     index: 29
#     base: "1"
# 18. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. C__x_
#     core type: Indexed
#     var: 23
#     index: 29
#     base: "1"
# 20. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...m}
#     core type: Operation
#     operator: 26
#     operands: 25
# 23. C
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. {1...m}
#     core type: Operation
#     operator: 32
#     operands: 31
# 29. _x_
#     core type: Variable
#     sub-expressions:
# 30. {1...n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 31. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 32. Interval
#     core type: Literal
#     sub-expressions:
# 33. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. n
#     core type: Variable
#     sub-expressions:
