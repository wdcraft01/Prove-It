# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import B
from proveit.logic import And
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(iterA1l, B, iterC1m, iterD1n))
# Out:
# expr: (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. (A_1 ,  ...  , A_l , B , C_1 ,  ...  , C_m , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6, 7
# 4. A_1,...,A_l
#    core type: Iter
#    lambda_map: 8
#    start_index: 37
#    end_index: 35
# 5. B
#    core type: Variable
#    sub-expressions:
# 6. C_1,...,C_m
#    core type: Iter
#    lambda_map: 9
#    start_index: 37
#    end_index: 36
# 7. D_1,...,D_n
#    core type: Iter
#    lambda_map: 10
#    start_index: 37
#    end_index: 38
# 8. _x_ -> A__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 29
#    body: 11
#    conditions: 12\n9. _x_ -> C__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 29
#    body: 13
#    conditions: 14\n10. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 29
#     body: 15
#     conditions: 16\n11. A__x_
#     core type: Indexed
#     var: 17
#     index: 29
#     base: "1"
# 12. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 18
# 13. C__x_
#     core type: Indexed
#     var: 19
#     index: 29
#     base: "1"
# 14. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 20
# 15. D__x_
#     core type: Indexed
#     var: 21
#     index: 29
#     base: "1"
# 16. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. _x_ in {1...l}
#     core type: Operation
#     operator: 25
#     operands: 23
# 19. C
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...m}
#     core type: Operation
#     operator: 25
#     operands: 24
# 21. D
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...n}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 29, 27
# 24. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. {1...l}
#     core type: Operation
#     operator: 33
#     operands: 31
# 28. {1...m}
#     core type: Operation
#     operator: 33
#     operands: 32
# 29. _x_
#     core type: Variable
#     sub-expressions:
# 30. {1...n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 37, 35
# 32. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 37, 36
# 33. Interval
#     core type: Literal
#     sub-expressions:
# 34. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. l
#     core type: Variable
#     sub-expressions:
# 36. m
#     core type: Variable
#     sub-expressions:
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. n
#     core type: Variable
#     sub-expressions:
