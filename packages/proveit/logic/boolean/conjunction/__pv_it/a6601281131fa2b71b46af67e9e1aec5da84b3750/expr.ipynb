# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Equals, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Equals(And(A, B), And(B, A)), domain = Booleans, conditions = []), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B in BOOLEANS} ((A and B) = (B and A))] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in BOOLEANS} ((A and B) = (B and A))] | A in BOOLEANS
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. forall_{B in BOOLEANS} ((A and B) = (B and A))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((A and B) = (B and A)) | B in BOOLEANS
#    core type: Lambda
#    parameter: 20
#    body: 6
#    conditions: 7\n5. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. (A and B) = (B and A)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 21, 19
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A and B , B and A)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. B in BOOLEANS
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. A and B
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. B and A
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 16. (A , B)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (B , A)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
# 21. A
#     core type: Variable
#     sub-expressions:
