# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Exp, four

# %%
# build up the expression from sub-expressions
expr = Forall([c, d], InSet([a, b, c, d], Exp(S, four)), domain = S, conditions = [])
# Out:
# expr: forall_{c, d in S} ((a , b , c , d) in S^{4})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c, d in S} ((a , b , c , d) in S^{4})
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. c -> [forall_{d in S} ((a , b , c , d) in S^{4})] | c in S
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{d in S} ((a , b , c , d) in S^{4})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (c in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. d -> ((a , b , c , d) in S^{4}) | d in S
#    core type: Lambda
#    parameter: 21
#    body: 7
#    conditions: 8\n6. c in S
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (a , b , c , d) in S^{4}
#    core type: Operation
#    operator: 14
#    operands: 10
# 8. (d in S)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (c , S)
#    core type: ExprTuple
#    sub-expressions: 18, 22
# 10. ((a , b , c , d) , S^{4})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. d in S
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (a , b , c , d)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 21
# 13. S^{4}
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (d , S)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. Exp
#     core type: Literal
#     sub-expressions:
# 20. (S , 4)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. d
#     core type: Variable
#     sub-expressions:
# 22. S
#     core type: Variable
#     sub-expressions:
# 23. 4
#     core type: Literal
#     sub-expressions:
