# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#falsifiedAndIfNotLeft">falsifiedAndIfNotLeft</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import falsifiedAndIfNotLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr falsifiedAndIfNotLeft
# Out:
# Passed sanity check: built 'falsifiedAndIfNotLeft' is the same as the stored Expression.

# %%
# display the expression information
falsifiedAndIfNotLeft.exprInfo()
# Out:
# 0. forall_{A, B | [not](A) , B} ((A and B) = FALSE)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B | B} ((A and B) = FALSE)] | [not](A)
#    core type: Lambda
#    parameter: 16
#    body: 2
#    conditions: 3\n2. forall_{B | B} ((A and B) = FALSE)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> ((A and B) = FALSE) | B
#    core type: Lambda
#    parameter: 17
#    body: 7
#    conditions: 8\n6. [not](A)
#    core type: Operation
#    operator: 9
#    operand: 16
# 7. (A and B) = FALSE
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (B)
#    core type: ExprTuple
#    sub-expressions: 17
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (A and B , FALSE)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A and B
# ...
