# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, CC, DD, m, n
from proveit.logic import And, Booleans, Equals, Forall, InSet
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, Forall([DD], Equals(And(iterA1l, B, iterC1m, iterD1n), And(iterA1l, iterC1m, B, iterD1n)), domain = Exp(Booleans, n), conditions = []), conditions = [InSet(CC, Exp(Booleans, m))])
# Out:
# expr: C -> [forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | C in BOOLEANS^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> [forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))] | C in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 39
#    body: 1
#    conditions: 2\n1. forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (C in BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. D -> ((A_1 and  ...  and A_l and B and C_1 and  ...  and C_m and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C_1 and  ...  and C_m and B and D_1 and  ...  and D_n)) | D in BOOLEANS^{n}
#    core type: Lambda
#    parameter: 41
#    body: 6
#    conditions: 7\n5. C in BOOLEANS^{m}
# ...
