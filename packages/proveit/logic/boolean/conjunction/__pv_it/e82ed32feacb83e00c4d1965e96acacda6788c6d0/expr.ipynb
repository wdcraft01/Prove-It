# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E
from proveit.logic import And, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(A, B, And(And(C, D), E)))
# Out:
# expr: {A or B or ((C and D) and E)}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A or B or ((C and D) and E)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A or B or ((C and D) and E))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. A or B or ((C and D) and E)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A , B , (C and D) and E)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. A
#    core type: Variable
#    sub-expressions:
# 7. B
#    core type: Variable
#    sub-expressions:
# 8. (C and D) and E
#    core type: Operation
#    operator: 12
#    operands: 9
# 9. (C and D , E)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. C and D
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. E
#     core type: Variable
#     sub-expressions:
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (C , D)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. C
#     core type: Variable
#     sub-expressions:
# 15. D
#     core type: Variable
#     sub-expressions:
