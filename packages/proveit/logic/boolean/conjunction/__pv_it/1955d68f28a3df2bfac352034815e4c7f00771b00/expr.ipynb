# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#falsifiedAndIfNeither">falsifiedAndIfNeither</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.conjunction._theorems_ import falsifiedAndIfNeither

# %%
# check that the built expression is the same as the stored expression
# %check_expr falsifiedAndIfNeither
# Out:
# Passed sanity check: built 'falsifiedAndIfNeither' is the same as the stored Expression.

# %%
# display the expression information
falsifiedAndIfNeither.exprInfo()
# Out:
# 0. forall_{A, B | [not](A) , [not](B)} ((A and B) = FALSE)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B | [not](B)} ((A and B) = FALSE)] | [not](A)
#    core type: Lambda
#    parameter: 17
#    body: 2
#    conditions: 3\n2. forall_{B | [not](B)} ((A and B) = FALSE)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> ((A and B) = FALSE) | [not](B)
#    core type: Lambda
#    parameter: 18
#    body: 7
#    conditions: 8\n6. [not](A)
#    core type: Operation
#    operator: 14
#    operand: 17
# 7. (A and B) = FALSE
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ([not](B))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A and B , FALSE)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. [not](B)
# ...
