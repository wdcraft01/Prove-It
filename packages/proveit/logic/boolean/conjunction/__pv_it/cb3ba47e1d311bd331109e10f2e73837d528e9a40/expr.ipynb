# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import C, DD
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n

# %%
# build up the expression from sub-expressions
expr = Forall([DD], And(iterA1l, C, iterB1m, iterD1n), conditions = [And(iterA1l, iterB1m, C, iterD1n)])
# Out:
# expr: forall_{D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. D -> (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n) | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n
#    core type: Lambda
#    parameter: 26
#    body: 3
#    conditions: 4\n3. A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 7
#    operands: 5
# 4. (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A_1 ,  ...  , A_l , C , B_1 ,  ...  , B_m , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 9, 11, 10, 12
# 6. A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 9. A_1,...,A_l
#    core type: Iter
#    lambda_map: 13
#    start_index: 42
#    end_index: 40
# 10. B_1,...,B_m
#     core type: Iter
#     lambda_map: 14
#     start_index: 42
#     end_index: 41
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. D_1,...,D_n
#     core type: Iter
#     lambda_map: 15
#     start_index: 42
#     end_index: 43
# 13. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 34
#     body: 16
#     conditions: 17\n14. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 34
#     body: 18
#     conditions: 19\n15. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 34
#     body: 20
#     conditions: 21\n16. A__x_
#     core type: Indexed
#     var: 22
#     index: 34
#     base: "1"
# 17. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 23
# 18. B__x_
#     core type: Indexed
#     var: 24
#     index: 34
#     base: "1"
# 19. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 25
# 20. D__x_
#     core type: Indexed
#     var: 26
#     index: 34
#     base: "1"
# 21. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 27
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. _x_ in {1...l}
#     core type: Operation
#     operator: 30
#     operands: 28
# 24. B
#     core type: Variable
#     sub-expressions:
# 25. _x_ in {1...m}
#     core type: Operation
#     operator: 30
#     operands: 29
# 26. D
#     core type: Variable
#     sub-expressions:
# 27. _x_ in {1...n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 34, 32
# 29. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 34, 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. {1...l}
#     core type: Operation
#     operator: 38
#     operands: 36
# 33. {1...m}
#     core type: Operation
#     operator: 38
#     operands: 37
# 34. _x_
#     core type: Variable
#     sub-expressions:
# 35. {1...n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 42, 40
# 37. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 42, 41
# 38. Interval
#     core type: Literal
#     sub-expressions:
# 39. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. m
#     core type: Variable
#     sub-expressions:
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
