# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import C, DD, n
from proveit.logic import And, Booleans, Equals, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([DD], Equals(And(iterA1l, iterB1m, C, iterD1n), And(iterA1l, C, iterB1m, iterD1n)), domain = Exp(Booleans, n), conditions = [])
# Out:
# expr: forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{D in BOOLEANS^{n}} ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. D -> ((A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)) | D in BOOLEANS^{n}
#    core type: Lambda
#    parameter: 35
#    body: 3
#    conditions: 4\n3. (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n) = (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (D in BOOLEANS^{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# ...
