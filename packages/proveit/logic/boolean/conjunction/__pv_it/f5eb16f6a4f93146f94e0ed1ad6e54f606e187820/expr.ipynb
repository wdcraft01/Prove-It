# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A
from proveit.logic import And
from proveit.logic._common_ import iterB1n

# %%
# build up the expression from sub-expressions
expr = ExprTuple(A, And(iterB1n))
# Out:
# expr: (A , B_1 and  ...  and B_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A , B_1 and  ...  and B_n)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A
#    core type: Variable
#    sub-expressions:
# 2. B_1 and  ...  and B_n
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. (B_1 ,  ...  , B_n)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. B_1,...,B_n
#    core type: Iter
#    lambda_map: 6
#    start_index: 17
#    end_index: 18
# 6. _x_ -> B__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 13
#    body: 7
#    conditions: 8\n7. B__x_
#    core type: Indexed
#    var: 9
#    index: 13
#    base: "1"
# 8. (_x_ in {1...n})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. _x_ in {1...n}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. _x_
#     core type: Variable
#     sub-expressions:
# 14. {1...n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
