# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import BB, C, DD
from proveit.logic import And, Forall
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n

# %%
# build up the expression from sub-expressions
expr = Lambda(BB, Forall([C, DD], And(iterA1l, C, iterB1m, iterD1n), conditions = [And(iterA1l, iterB1m, C, iterD1n)]))
# Out:
# expr: B -> [forall_{C, D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> [forall_{C, D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)]
#    core type: Lambda
#    parameter: 27
#    body: 1
# 1. forall_{C, D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)
#    core type: Operation
#    operator: 4
#    operand: 2
# 2. C -> [forall_{D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)]
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. forall_{D | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n} (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. D -> (A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n) | A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n
#    core type: Lambda
#    parameter: 29
#    body: 6
#    conditions: 7\n6. A_1 and  ...  and A_l and C and B_1 and  ...  and B_m and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 10
#    operands: 8
# 7. (A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (A_1 ,  ...  , A_l , C , B_1 ,  ...  , B_m , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 12, 14, 13, 15
# 9. A_1 and  ...  and A_l and B_1 and  ...  and B_m and C and D_1 and  ...  and D_n
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C , D_1 ,  ...  , D_n)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14, 15
# 12. A_1,...,A_l
#     core type: Iter
#     lambda_map: 16
#     start_index: 45
#     end_index: 43
# 13. B_1,...,B_m
#     core type: Iter
#     lambda_map: 17
#     start_index: 45
#     end_index: 44
# 14. C
#     core type: Variable
#     sub-expressions:
# 15. D_1,...,D_n
#     core type: Iter
#     lambda_map: 18
#     start_index: 45
#     end_index: 46
# 16. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 37
#     body: 19
#     conditions: 20\n17. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 37
#     body: 21
#     conditions: 22\n18. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 37
#     body: 23
#     conditions: 24\n19. A__x_
#     core type: Indexed
#     var: 25
#     index: 37
#     base: "1"
# 20. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 26
# 21. B__x_
#     core type: Indexed
#     var: 27
#     index: 37
#     base: "1"
# 22. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 28
# 23. D__x_
#     core type: Indexed
#     var: 29
#     index: 37
#     base: "1"
# 24. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 30
# 25. A
#     core type: Variable
#     sub-expressions:
# 26. _x_ in {1...l}
#     core type: Operation
#     operator: 33
#     operands: 31
# 27. B
#     core type: Variable
#     sub-expressions:
# 28. _x_ in {1...m}
#     core type: Operation
#     operator: 33
#     operands: 32
# 29. D
#     core type: Variable
#     sub-expressions:
# 30. _x_ in {1...n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 37, 35
# 32. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 37, 36
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. {1...l}
#     core type: Operation
#     operator: 41
#     operands: 39
# 36. {1...m}
#     core type: Operation
#     operator: 41
#     operands: 40
# 37. _x_
#     core type: Variable
#     sub-expressions:
# 38. {1...n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 45, 43
# 40. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 45, 44
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. l
#     core type: Variable
#     sub-expressions:
# 44. m
#     core type: Variable
#     sub-expressions:
# 45. 1
#     core type: Literal
#     sub-expressions:
# 46. n
#     core type: Variable
#     sub-expressions:
