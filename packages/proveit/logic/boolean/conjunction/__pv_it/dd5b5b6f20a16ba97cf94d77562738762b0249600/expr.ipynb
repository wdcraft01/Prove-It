# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.conjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m
from proveit.logic import And, Forall, InSet, Not, Or
from proveit.logic._common_ import iterA1m
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([AA], And(iterA1m), conditions = [Not(Or(Iter(i, Not(Indexed(AA, i, base = 1)), one, m)))]), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{A | [not]([not](A_1) or  ...  or [not](A_m))} (A_1 and  ...  and A_m)] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{A | [not]([not](A_1) or  ...  or [not](A_m))} (A_1 and  ...  and A_m)] | m in Naturals
#    core type: Lambda
#    parameter: 38
#    body: 1
#    conditions: 2\n1. forall_{A | [not]([not](A_1) or  ...  or [not](A_m))} (A_1 and  ...  and A_m)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> (A_1 and  ...  and A_m) | [not]([not](A_1) or  ...  or [not](A_m))
#    core type: Lambda
#    parameter: 30
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 31
#    operands: 8
# 6. A_1 and  ...  and A_m
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. ([not]([not](A_1) or  ...  or [not](A_m)))
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 38, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# ...
