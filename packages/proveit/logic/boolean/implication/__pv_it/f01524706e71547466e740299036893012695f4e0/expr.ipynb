# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#eqFromMutualImpl">eqFromMutualImpl</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._theorems_ import eqFromMutualImpl

# %%
# check that the built expression is the same as the stored expression
# %check_expr eqFromMutualImpl
# Out:
# Passed sanity check: built 'eqFromMutualImpl' is the same as the stored Expression.

# %%
# display the expression information
eqFromMutualImpl.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | A => B , B => A} (A = B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS | A => B , B => A} (A = B)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 21
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS | A => B , B => A} (A = B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> (A = B) | B in BOOLEANS , A => B , B => A
#    core type: Lambda
#    parameter: 20
#    body: 7
#    conditions: 8\n6. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. A = B
#    core type: Operation
#    operator: 10
#    operands: 16
# 8. (B in BOOLEANS , A => B , B => A)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 21, 19
# 10. =
#     core type: Literal
# ...
