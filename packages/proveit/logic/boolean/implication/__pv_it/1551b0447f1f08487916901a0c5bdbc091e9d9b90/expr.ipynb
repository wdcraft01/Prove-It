# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Forall, Implies, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Implies(B, A), conditions = [Not(Implies(A, B))]))
# Out:
# expr: A -> [forall_{B | [not](A => B)} (B => A)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | [not](A => B)} (B => A)]
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. forall_{B | [not](A => B)} (B => A)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. B -> (B => A) | [not](A => B)
#    core type: Lambda
#    parameter: 13
#    body: 4
#    conditions: 5\n4. B => A
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. ([not](A => B))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (B , A)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 7. [not](A => B)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. A => B
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
