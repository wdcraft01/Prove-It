# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Implies, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(Implies(A, B), Implies(B, A), InSet(B, Booleans), InSet(A, Booleans))
# Out:
# expr: {A => B , B => A , B in BOOLEANS , A in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A => B , B => A , B in BOOLEANS , A in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A => B , B => A , B in BOOLEANS , A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. A => B
#    core type: Operation
#    operator: 8
#    operands: 7
# 4. B => A
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 10
# 6. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (A , B)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (B , A)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 15
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
