# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Implies(Not(B), A), conditions = [Implies(Not(A), B), InSet(A, Booleans)])
# Out:
# expr: B -> ([not](B) => A) | [not](A) => B , A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> ([not](B) => A) | [not](A) => B , A in BOOLEANS
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. [not](B) => A
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. ([not](A) => B , A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. ([not](B) , A)
#    core type: ExprTuple
#    sub-expressions: 6, 15
# 4. [not](A) => B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. [not](B)
#    core type: Operation
#    operator: 14
#    operand: 12
# 7. =>
#    core type: Literal
#    sub-expressions:
# 8. ([not](A) , B)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. [not](A)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. not
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
