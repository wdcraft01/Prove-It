# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#doubleNegateConsequent">doubleNegateConsequent</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._theorems_ import doubleNegateConsequent

# %%
# check that the built expression is the same as the stored expression
# %check_expr doubleNegateConsequent
# Out:
# Passed sanity check: built 'doubleNegateConsequent' is the same as the stored Expression.

# %%
# display the expression information
doubleNegateConsequent.exprInfo()
# Out:
# 0. forall_{A, B | A => B , B in BOOLEANS} (A => [not]([not](B)))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | A => B , B in BOOLEANS} (A => [not]([not](B)))]
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. forall_{B | A => B , B in BOOLEANS} (A => [not]([not](B)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (A => [not]([not](B))) | A => B , B in BOOLEANS
#    core type: Lambda
#    parameter: 19
#    body: 5
#    conditions: 6\n5. A => [not]([not](B))
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. (A => B , B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (A , [not]([not](B)))
#    core type: ExprTuple
#    sub-expressions: 16, 10
# 8. A => B
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. [not]([not](B))
#     core type: Operation
#     operator: 18
#     operand: 15
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
#     core type: ExprTuple
#     sub-expressions: 16, 19
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 15. [not](B)
#     core type: Operation
#     operator: 18
#     operand: 19
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 18. not
#     core type: Literal
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
