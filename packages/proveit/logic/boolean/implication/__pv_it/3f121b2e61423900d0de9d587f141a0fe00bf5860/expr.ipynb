# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Forall([B], Implies(A, B), conditions = [Implies(Not(B), Not(A)), InSet(B, Booleans)])
# Out:
# expr: forall_{B | [not](B) => [not](A) , B in BOOLEANS} (A => B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B | [not](B) => [not](A) , B in BOOLEANS} (A => B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (A => B) | [not](B) => [not](A) , B in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. A => B
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. ([not](B) => [not](A) , B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (A , B)
#    core type: ExprTuple
#    sub-expressions: 17, 15
# 6. [not](B) => [not](A)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. ([not](B) , [not](A))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 15
# 13. [not](A)
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
