# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Implies(Not(B), Not(A)), conditions = [Implies(A, B), InSet(A, Booleans)])
# Out:
# expr: B -> ([not](B) => [not](A)) | A => B , A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> ([not](B) => [not](A)) | A => B , A in BOOLEANS
#    core type: Lambda
#    parameter: 13
#    body: 1
#    conditions: 2\n1. [not](B) => [not](A)
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (A => B , A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. ([not](B) , [not](A))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. A => B
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. [not](B)
#    core type: Operation
#    operator: 12
#    operand: 13
# 7. [not](A)
#    core type: Operation
#    operator: 12
#    operand: 14
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
