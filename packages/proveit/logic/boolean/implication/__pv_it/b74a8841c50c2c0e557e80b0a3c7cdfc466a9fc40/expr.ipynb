# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#iffClosure">iffClosure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._theorems_ import iffClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr iffClosure
# Out:
# Passed sanity check: built 'iffClosure' is the same as the stored Expression.

# %%
# display the expression information
iffClosure.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS} ((A <=> B) in BOOLEANS)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS} ((A <=> B) in BOOLEANS)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> ((A <=> B) in BOOLEANS) | B in BOOLEANS
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n6. A in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. (A <=> B) in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 10
# 8. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 10. (A <=> B , BOOLEANS)
#     core type: ExprTuple
# ...
