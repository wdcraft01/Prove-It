# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Implies, InSet, Not, Set

# %%
# build up the expression from sub-expressions
expr = Set(Implies(Not(B), Not(A)), InSet(B, Booleans))
# Out:
# expr: {[not](B) => [not](A) , B in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not](B) => [not](A) , B in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ([not](B) => [not](A) , B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [not](B) => [not](A)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. ([not](B) , [not](A))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. [not](B)
#    core type: Operation
#    operator: 13
#    operand: 12
# 10. [not](A)
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
