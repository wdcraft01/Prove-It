# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Forall, Iff, Implies, Not

# %%
# build up the expression from sub-expressions
expr = Forall([B], Not(Iff(A, B)), conditions = [Not(Implies(B, A))])
# Out:
# expr: forall_{B | [not](B => A)} [not](A <=> B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B | [not](B => A)} [not](A <=> B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> [not](A <=> B) | [not](B => A)
#    core type: Lambda
#    parameter: 13
#    body: 3
#    conditions: 4\n3. [not](A <=> B)
#    core type: Operation
#    operator: 9
#    operand: 5
# 4. ([not](B => A))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. A <=> B
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. [not](B => A)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. <=>
#    core type: Literal
#    sub-expressions:
# 8. (A , B)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. B => A
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. =>
#     core type: Literal
#     sub-expressions:
# 12. (B , A)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
