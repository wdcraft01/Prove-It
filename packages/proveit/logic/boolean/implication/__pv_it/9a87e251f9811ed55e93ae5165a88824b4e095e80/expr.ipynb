# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#untrueAntecedentImplication">untrueAntecedentImplication</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._axioms_ import untrueAntecedentImplication

# %%
# check that the built expression is the same as the stored expression
# %check_expr untrueAntecedentImplication
# Out:
# Passed sanity check: built 'untrueAntecedentImplication' is the same as the stored Expression.

# %%
# display the expression information
untrueAntecedentImplication.exprInfo()
# Out:
# 0. forall_{A, B | A != TRUE} (A => B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B} (A => B)] | A != TRUE
#    core type: Lambda
#    parameter: 13
#    body: 2
#    conditions: 3\n2. forall_{B} (A => B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A != TRUE)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> (A => B)
#    core type: Lambda
#    parameter: 14
#    body: 7
# 6. A != TRUE
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. A => B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. !=
#    core type: Literal
#    sub-expressions:
# 9. (A , TRUE)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. TRUE
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
# ...
