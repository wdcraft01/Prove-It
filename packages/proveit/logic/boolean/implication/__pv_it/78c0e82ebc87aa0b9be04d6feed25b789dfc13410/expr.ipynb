# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, PofA, Q, QofA
from proveit.logic import Booleans, Forall
from proveit.logic._common_ import QimplPofFalse, QimplPofTrue

# %%
# build up the expression from sub-expressions
expr = Lambda(Q, Forall([A], PofA, domain = Booleans, conditions = [QofA]), conditions = [QimplPofTrue, QimplPofFalse])
# Out:
# expr: Q -> [forall_{A in BOOLEANS | Q(A)} P(A)] | Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. Q -> [forall_{A in BOOLEANS | Q(A)} P(A)] | Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE)
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. forall_{A in BOOLEANS | Q(A)} P(A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> P(A) | A in BOOLEANS , Q(A)
#    core type: Lambda
#    parameter: 24
#    body: 7
#    conditions: 8\n5. Q(TRUE) => P(TRUE)
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. Q(FALSE) => P(FALSE)
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. P(A)
#    core type: Operation
#    operator: 22
#    operand: 24
# 8. (A in BOOLEANS , Q(A))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (Q(TRUE) , P(TRUE))
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. =>
#     core type: Literal
#     sub-expressions:
# ...
