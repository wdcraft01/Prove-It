# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#rightFromIff">rightFromIff</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._theorems_ import rightFromIff

# %%
# check that the built expression is the same as the stored expression
# %check_expr rightFromIff
# Out:
# Passed sanity check: built 'rightFromIff' is the same as the stored Expression.

# %%
# display the expression information
rightFromIff.exprInfo()
# Out:
# 0. forall_{A, B | A , A <=> B} B
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B | A <=> B} B] | A
#    core type: Lambda
#    parameter: 10
#    body: 2
#    conditions: 3\n2. forall_{B | A <=> B} B
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A)
#    core type: ExprTuple
#    sub-expressions: 10
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> B | A <=> B
#    core type: Lambda
#    parameter: 11
#    body: 11
#    conditions: 6\n6. (A <=> B)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. A <=> B
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. <=>
#    core type: Literal
#    sub-expressions:
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
