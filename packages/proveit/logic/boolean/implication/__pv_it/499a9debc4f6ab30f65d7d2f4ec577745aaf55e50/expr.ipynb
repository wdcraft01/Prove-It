# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Equals, Forall, Iff, Implies

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Equals(Iff(A, B), And(Implies(A, B), Implies(B, A))), conditions = []))
# Out:
# expr: A -> [forall_{B} ((A <=> B) = ((A => B) and (B => A)))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B} ((A <=> B) = ((A => B) and (B => A)))]
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. forall_{B} ((A <=> B) = ((A => B) and (B => A)))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. B -> ((A <=> B) = ((A => B) and (B => A)))
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. (A <=> B) = ((A => B) and (B => A))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (A <=> B , (A => B) and (B => A))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. A <=> B
#    core type: Operation
#    operator: 9
#    operands: 14
# 8. (A => B) and (B => A)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. <=>
#    core type: Literal
#    sub-expressions:
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (A => B , B => A)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A => B
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. B => A
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (B , A)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
