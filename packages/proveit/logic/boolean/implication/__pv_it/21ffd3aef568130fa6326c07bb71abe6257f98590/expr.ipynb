# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Forall([B], Implies(B, Not(A)), conditions = [Implies(A, Not(B)), InSet(A, Booleans)])
# Out:
# expr: forall_{B | A => [not](B) , A in BOOLEANS} (B => [not](A))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B | A => [not](B) , A in BOOLEANS} (B => [not](A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (B => [not](A)) | A => [not](B) , A in BOOLEANS
#    core type: Lambda
#    parameter: 17
#    body: 3
#    conditions: 4\n3. B => [not](A)
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (A => [not](B) , A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (B , [not](A))
#    core type: ExprTuple
#    sub-expressions: 17, 8
# 6. A => [not](B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. [not](A)
#    core type: Operation
#    operator: 16
#    operand: 14
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (A , [not](B))
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
