# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Not(A), conditions = [Implies(A, B), Not(B)]), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B | A => B , [not](B)} [not](A)] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | A => B , [not](B)} [not](A)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 16
#    body: 1
#    conditions: 2\n1. forall_{B | A => B , [not](B)} [not](A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> [not](A) | A => B , [not](B)
#    core type: Lambda
#    parameter: 17
#    body: 6
#    conditions: 7\n5. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. [not](A)
#    core type: Operation
#    operator: 15
#    operand: 16
# 7. (A => B , [not](B))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 12
# 10. A => B
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. [not](B)
#     core type: Operation
#     operator: 15
#     operand: 17
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
