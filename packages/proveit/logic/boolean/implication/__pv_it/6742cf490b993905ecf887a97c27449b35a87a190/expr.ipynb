# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#notIffViaNotLeftImpl">notIffViaNotLeftImpl</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._theorems_ import notIffViaNotLeftImpl

# %%
# check that the built expression is the same as the stored expression
# %check_expr notIffViaNotLeftImpl
# Out:
# Passed sanity check: built 'notIffViaNotLeftImpl' is the same as the stored Expression.

# %%
# display the expression information
notIffViaNotLeftImpl.exprInfo()
# Out:
# 0. forall_{A, B | [not](B => A)} [not](A <=> B)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | [not](B => A)} [not](A <=> B)]
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. forall_{B | [not](B => A)} [not](A <=> B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> [not](A <=> B) | [not](B => A)
#    core type: Lambda
#    parameter: 15
#    body: 5
#    conditions: 6\n5. [not](A <=> B)
#    core type: Operation
#    operator: 11
#    operand: 7
# 6. ([not](B => A))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. A <=> B
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [not](B => A)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. <=>
#    core type: Literal
#    sub-expressions:
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. B => A
# ...
