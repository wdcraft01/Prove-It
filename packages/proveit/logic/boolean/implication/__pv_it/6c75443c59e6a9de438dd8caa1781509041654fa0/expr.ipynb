# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Implies, InSet, Not, Set

# %%
# build up the expression from sub-expressions
expr = Set(Implies(Not(A), Not(B)), InSet(A, Booleans))
# Out:
# expr: {[not](A) => [not](B) , A in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not](A) => [not](B) , A in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ([not](A) => [not](B) , A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. [not](A) => [not](B)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. ([not](A) , [not](B))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. [not](A)
#    core type: Operation
#    operator: 13
#    operand: 12
# 10. [not](B)
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
