# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Equals, Implies, InSet

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Equals(A, B), conditions = [InSet(B, Booleans), Implies(A, B), Implies(B, A)])
# Out:
# expr: B -> (A = B) | B in BOOLEANS , A => B , B => A

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> (A = B) | B in BOOLEANS , A => B , B => A
#    core type: Lambda
#    parameter: 13
#    body: 1
#    conditions: 2\n1. A = B
#    core type: Operation
#    operator: 3
#    operands: 9
# 2. (B in BOOLEANS , A => B , B => A)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. A => B
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. B => A
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (B , A)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
