# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Equals, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([B], Equals(A, B), domain = Booleans, conditions = [Implies(A, B), Implies(B, A)])
# Out:
# expr: forall_{B in BOOLEANS | A => B , B => A} (A = B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS | A => B , B => A} (A = B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (A = B) | B in BOOLEANS , A => B , B => A
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. A = B
#    core type: Operation
#    operator: 5
#    operands: 11
# 4. (B in BOOLEANS , A => B , B => A)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. B in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. A => B
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. B => A
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (B , A)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
