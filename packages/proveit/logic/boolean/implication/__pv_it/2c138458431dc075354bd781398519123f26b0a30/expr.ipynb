# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], A, conditions = [Implies(Not(A), B), Not(B)]), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B | [not](A) => B , [not](B)} A] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | [not](A) => B , [not](B)} A] | A in BOOLEANS
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. forall_{B | [not](A) => B , [not](B)} A
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> A | [not](A) => B , [not](B)
#    core type: Lambda
#    parameter: 15
#    body: 17
#    conditions: 6\n5. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. ([not](A) => B , [not](B))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 11
# 9. [not](A) => B
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 15
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. ([not](A) , B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. [not](A)
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
