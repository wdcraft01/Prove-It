# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#affirmViaContradiction">affirmViaContradiction</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.implication._theorems_ import affirmViaContradiction

# %%
# check that the built expression is the same as the stored expression
# %check_expr affirmViaContradiction
# Out:
# Passed sanity check: built 'affirmViaContradiction' is the same as the stored Expression.

# %%
# display the expression information
affirmViaContradiction.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS | [not](A) => FALSE} A
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> A | A in BOOLEANS , [not](A) => FALSE
#    core type: Lambda
#    parameter: 14
#    body: 14
#    conditions: 3\n3. (A in BOOLEANS , [not](A) => FALSE)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A in BOOLEANS
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. [not](A) => FALSE
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. ([not](A) , FALSE)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. [not](A)
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. FALSE
#     core type: Literal
# ...
