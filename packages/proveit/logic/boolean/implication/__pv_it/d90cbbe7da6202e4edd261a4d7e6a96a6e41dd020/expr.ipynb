# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.implication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C
from proveit.logic import Forall, Iff

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B, C], Iff(A, C), conditions = [Iff(A, B), Iff(B, C)]))
# Out:
# expr: A -> [forall_{B, C | A <=> B , B <=> C} (A <=> C)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B, C | A <=> B , B <=> C} (A <=> C)]
#    core type: Lambda
#    parameter: 13
#    body: 1
# 1. forall_{B, C | A <=> B , B <=> C} (A <=> C)
#    core type: Operation
#    operator: 5
#    operand: 2
# 2. B -> [forall_{C | B <=> C} (A <=> C)] | A <=> B
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. forall_{C | B <=> C} (A <=> C)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (A <=> B)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. C -> (A <=> C) | B <=> C
#    core type: Lambda
#    parameter: 17
#    body: 8
#    conditions: 9\n7. A <=> B
#    core type: Operation
#    operator: 14
#    operands: 10
# 8. A <=> C
#    core type: Operation
#    operator: 14
#    operands: 11
# 9. (B <=> C)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 13, 16
# 11. (A , C)
#     core type: ExprTuple
#     sub-expressions: 13, 17
# 12. B <=> C
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. <=>
#     core type: Literal
#     sub-expressions:
# 15. (B , C)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. C
#     core type: Variable
#     sub-expressions:
