# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, CC, DD, m, n
from proveit.logic import Booleans, Equals, Forall, Or
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([CC, DD], Equals(Or(iterA1l, B, iterC1m, iterD1n), Or(iterA1l, iterC1m, B, iterD1n)), domains = [Exp(Booleans, m), Exp(Booleans, n)], conditions = [])
# Out:
# expr: forall_{(C, D) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(C, D) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. C -> [forall_{D in BOOLEANS^{n}} ((A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n))] | C in BOOLEANS^{m}
#    core type: Lambda
#    parameter: 40
#    body: 2
#    conditions: 3\n2. forall_{D in BOOLEANS^{n}} ((A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (C in BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# ...
