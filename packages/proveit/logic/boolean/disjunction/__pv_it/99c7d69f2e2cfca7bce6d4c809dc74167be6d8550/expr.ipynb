# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, B, CC, DD, n
from proveit.logic import Forall, InSet, Or
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([AA, B, CC, DD], Or(iterA1l, iterC1m, B, iterD1n), conditions = [Or(iterA1l, B, iterC1m, iterD1n)]), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{A, B, C, D | A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{A, B, C, D | A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)] | n in Naturals
#    core type: Lambda
#    parameter: 54
#    body: 1
#    conditions: 2\n1. forall_{A, B, C, D | A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)
#    core type: Operation
#    operator: 12
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. A -> [forall_{B, C, D | A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)]
#    core type: Lambda
#    parameter: 33
#    body: 5
# 4. n in Naturals
#    core type: Operation
#    operator: 41
#    operands: 6
# ...
