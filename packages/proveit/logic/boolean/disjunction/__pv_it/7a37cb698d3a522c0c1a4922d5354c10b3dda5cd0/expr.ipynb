# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#associate">associate</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import associate

# %%
# check that the built expression is the same as the stored expression
# %check_expr associate
# Out:
# Passed sanity check: built 'associate' is the same as the stored Expression.

# %%
# display the expression information
associate.exprInfo()
# Out:
# 0. forall_{l, m, n in Naturals} [forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]
#    core type: Operation
#    operator: 21
#    operand: 1
# 1. l -> [forall_{m, n in Naturals} [forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]] | l in Naturals
#    core type: Lambda
#    parameter: 61
#    body: 2
#    conditions: 3\n2. forall_{m, n in Naturals} [forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]
#    core type: Operation
#    operator: 21
#    operand: 4
# 3. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. m -> [forall_{n in Naturals} [forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]] | m in Naturals
#    core type: Lambda
#    parameter: 64
#    body: 6
#    conditions: 7\n5. l in Naturals
#    core type: Operation
#    operator: 51
#    operands: 8
# 6. forall_{n in Naturals} [forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]
#    core type: Operation
#    operator: 21
#    operand: 9
# 7. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (l , Naturals)
#    core type: ExprTuple
#    sub-expressions: 61, 19
# 9. n -> [forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)] | n in Naturals
#    core type: Lambda
#    parameter: 62
#    body: 11
#    conditions: 12\n10. m in Naturals
#     core type: Operation
#     operator: 51
#     operands: 13
# 11. forall_{A, B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#     core type: Operation
#     operator: 21
#     operand: 14
# 12. (n in Naturals)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 64, 19
# 14. A -> [forall_{B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]
#     core type: Lambda
#     parameter: 43
#     body: 16
# 15. n in Naturals
#     core type: Operation
#     operator: 51
#     operands: 17
# 16. forall_{B, C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#     core type: Operation
#     operator: 21
#     operand: 18
# 17. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 62, 19
# 18. B -> [forall_{C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)]
#     core type: Lambda
#     parameter: 47
#     body: 20
# 19. Naturals
#     core type: Literal
#     sub-expressions:
# 20. forall_{C | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#     core type: Operation
#     operator: 21
#     operand: 22
# 21. forall
#     core type: Literal
#     sub-expressions:
# 22. C -> (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n) | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n
#     core type: Lambda
#     parameter: 45
#     body: 23
#     conditions: 24\n23. A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#     core type: Operation
#     operator: 29
#     operands: 25
# 24. (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n)
#     core type: ExprTuple
#     sub-expressions: 26
# 25. (A_1 ,  ...  , A_l , B_1 or  ...  or B_m , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 31, 27, 32
# 26. A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n
#     core type: Operation
#     operator: 29
#     operands: 28
# 27. B_1 or  ...  or B_m
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 31, 33, 32
# 29. or
#     core type: Literal
#     sub-expressions:
# 30. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. A_1,...,A_l
#     core type: Iter
#     lambda_map: 34
#     start_index: 63
#     end_index: 61
# 32. C_1,...,C_n
#     core type: Iter
#     lambda_map: 35
#     start_index: 63
#     end_index: 62
# 33. B_1,...,B_m
#     core type: Iter
#     lambda_map: 36
#     start_index: 63
#     end_index: 64
# 34. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 55
#     body: 37
#     conditions: 38\n35. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 55
#     body: 39
#     conditions: 40\n36. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 55
#     body: 41
#     conditions: 42\n37. A__x_
#     core type: Indexed
#     var: 43
#     index: 55
#     base: "1"
# 38. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 44
# 39. C__x_
#     core type: Indexed
#     var: 45
#     index: 55
#     base: "1"
# 40. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 46
# 41. B__x_
#     core type: Indexed
#     var: 47
#     index: 55
#     base: "1"
# 42. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 48
# 43. A
#     core type: Variable
#     sub-expressions:
# 44. _x_ in {1...l}
#     core type: Operation
#     operator: 51
#     operands: 49
# 45. C
#     core type: Variable
#     sub-expressions:
# 46. _x_ in {1...n}
#     core type: Operation
#     operator: 51
#     operands: 50
# 47. B
#     core type: Variable
#     sub-expressions:
# 48. _x_ in {1...m}
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 55, 53
# 50. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 53. {1...l}
#     core type: Operation
#     operator: 59
#     operands: 57
# 54. {1...n}
#     core type: Operation
#     operator: 59
#     operands: 58
# 55. _x_
#     core type: Variable
#     sub-expressions:
# 56. {1...m}
#     core type: Operation
#     operator: 59
#     operands: 60
# 57. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 63, 61
# 58. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 63, 62
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. l
#     core type: Variable
#     sub-expressions:
# 62. n
#     core type: Variable
#     sub-expressions:
# 63. 1
#     core type: Literal
#     sub-expressions:
# 64. m
#     core type: Variable
#     sub-expressions:
