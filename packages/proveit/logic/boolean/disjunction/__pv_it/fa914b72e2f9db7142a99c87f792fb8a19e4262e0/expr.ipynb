# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, C, D
from proveit.logic import Booleans, Implies, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(D, Or(C, D), conditions = [InSet(D, Booleans), Implies(B, D)])
# Out:
# expr: D -> (C or D) | D in BOOLEANS , B => D

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. D -> (C or D) | D in BOOLEANS , B => D
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. C or D
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (D in BOOLEANS , B => D)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (C , D)
#    core type: ExprTuple
#    sub-expressions: 7, 14
# 5. D in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. B => D
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. C
#    core type: Variable
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (D , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (B , D)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. D
#     core type: Variable
#     sub-expressions:
