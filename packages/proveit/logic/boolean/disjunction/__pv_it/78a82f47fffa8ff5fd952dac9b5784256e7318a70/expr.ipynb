# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, CC, n
from proveit.logic import Booleans, Forall, Or
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([CC], Or(iterA1m, B, iterC1n), domain = Exp(Booleans, n), conditions = [])
# Out:
# expr: forall_{C in BOOLEANS^{n}} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C in BOOLEANS^{n}} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n) | C in BOOLEANS^{n}
#    core type: Lambda
#    parameter: 23
#    body: 3
#    conditions: 4\n3. A_1 or  ...  or A_m or B or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (C in BOOLEANS^{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A_1 ,  ...  , A_m , B , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. C in BOOLEANS^{n}
#    core type: Operation
#    operator: 27
#    operands: 11
# 8. A_1,...,A_m
#    core type: Iter
#    lambda_map: 12
#    start_index: 36
#    end_index: 35
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C_1,...,C_n
#     core type: Iter
#     lambda_map: 13
# ...
