# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c, d, e, f, g, h
from proveit.logic import Forall, InSet
from proveit.number import Exp, eight

# %%
# build up the expression from sub-expressions
expr = Lambda(g, Forall([h], InSet([a, b, c, d, e, f, g, h], Exp(S, eight)), domain = S, conditions = []), conditions = [InSet(g, S)])
# Out:
# expr: g -> [forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | g in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. g -> [forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | g in S
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (g in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. h -> ((a , b , c , d , e , f , g , h) in S^{8}) | h in S
#    core type: Lambda
#    parameter: 24
#    body: 6
#    conditions: 7\n5. g in S
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. (a , b , c , d , e , f , g , h) in S^{8}
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. (h in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (g , S)
#    core type: ExprTuple
#    sub-expressions: 21, 25
# 9. ((a , b , c , d , e , f , g , h) , S^{8})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. h in S
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (a , b , c , d , e , f , g , h)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18, 19, 20, 21, 24
# 12. S^{8}
#     core type: Operation
#     operator: 22
#     operands: 23
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (h , S)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. d
#     core type: Variable
#     sub-expressions:
# 19. e
#     core type: Variable
#     sub-expressions:
# 20. f
#     core type: Variable
#     sub-expressions:
# 21. g
#     core type: Variable
#     sub-expressions:
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (S , 8)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. h
#     core type: Variable
#     sub-expressions:
# 25. S
#     core type: Variable
#     sub-expressions:
# 26. 8
#     core type: Literal
#     sub-expressions:
