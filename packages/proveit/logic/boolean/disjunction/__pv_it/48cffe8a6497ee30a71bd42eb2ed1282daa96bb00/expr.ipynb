# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Forall, Implies, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Forall([C], C, conditions = [Implies(A, C), Implies(B, C)]), domain = Booleans, conditions = [Or(A, B)]), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B in BOOLEANS | A or B} [forall_{C | A => C , B => C} C]] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in BOOLEANS | A or B} [forall_{C | A => C , B => C} C]] | A in BOOLEANS
#    core type: Lambda
#    parameter: 23
#    body: 1
#    conditions: 2\n1. forall_{B in BOOLEANS | A or B} [forall_{C | A => C , B => C} C]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. B -> [forall_{C | A => C , B => C} C] | B in BOOLEANS , A or B
#    core type: Lambda
#    parameter: 24
#    body: 5
#    conditions: 6\n4. A in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. forall_{C | A => C , B => C} C
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (B in BOOLEANS , A or B)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 23, 19
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. C -> C | A => C , B => C
#    core type: Lambda
#    parameter: 25
#    body: 25
#    conditions: 12\n10. B in BOOLEANS
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. A or B
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (A => C , B => C)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24, 19
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (A , B)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 17. A => C
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. B => C
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 20. (A , C)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 21. =>
#     core type: Literal
#     sub-expressions:
# 22. (B , C)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. B
#     core type: Variable
#     sub-expressions:
# 25. C
#     core type: Variable
#     sub-expressions:
