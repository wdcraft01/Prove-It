# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, P, PofA
from proveit.logic import Booleans, Forall
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Forall([A], PofA, domain = Booleans, conditions = []), conditions = [PofTrue, PofFalse])
# Out:
# expr: P -> [forall_{A in BOOLEANS} P(A)] | P(TRUE) , P(FALSE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> [forall_{A in BOOLEANS} P(A)] | P(TRUE) , P(FALSE)
#    core type: Lambda
#    parameter: 11
#    body: 1
#    conditions: 2\n1. forall_{A in BOOLEANS} P(A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (P(TRUE) , P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> P(A) | A in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 7
#    conditions: 8\n5. P(TRUE)
#    core type: Operation
#    operator: 11
#    operand: 9
# 6. P(FALSE)
#    core type: Operation
#    operator: 11
#    operand: 10
# 7. P(A)
#    core type: Operation
#    operator: 11
#    operand: 15
# 8. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. TRUE
#    core type: Literal
#    sub-expressions:
# 10. FALSE
#     core type: Literal
#     sub-expressions:
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. A in BOOLEANS
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
