# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b
from proveit.logic import InSet
from proveit.number import Exp, two

# %%
# build up the expression from sub-expressions
expr = Lambda(b, InSet([a, b], Exp(S, two)), conditions = [InSet(b, S)])
# Out:
# expr: b -> ((a , b) in S^{2}) | b in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> ((a , b) in S^{2}) | b in S
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. (a , b) in S^{2}
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (b in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. ((a , b) , S^{2})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. b in S
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (a , b)
#    core type: ExprTuple
#    sub-expressions: 9, 12
# 6. S^{2}
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b , S)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (S , 2)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. S
#     core type: Variable
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
