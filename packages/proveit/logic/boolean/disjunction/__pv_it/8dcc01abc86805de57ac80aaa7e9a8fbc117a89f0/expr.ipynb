# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, InSet, Not, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(A, Booleans), InSet(B, Booleans), Not(A), Or(A, B))
# Out:
# expr: {A in BOOLEANS , B in BOOLEANS , [not](A) , A or B}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A in BOOLEANS , B in BOOLEANS , [not](A) , A or B}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A in BOOLEANS , B in BOOLEANS , [not](A) , A or B)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 7
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. [not](A)
#    core type: Operation
#    operator: 10
#    operand: 14
# 6. A or B
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 10. not
#     core type: Literal
#     sub-expressions:
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
