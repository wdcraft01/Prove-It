# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D, E, F, G, H
from proveit.logic import Booleans
from proveit.number import Exp, eight

# %%
# build up the expression from sub-expressions
expr = ExprTuple([A, B, C, D, E, F, G, H], Exp(Booleans, eight))
# Out:
# expr: ((A , B , C , D , E , F , G , H) , BOOLEANS^{8})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((A , B , C , D , E , F , G , H) , BOOLEANS^{8})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (A , B , C , D , E , F , G , H)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8, 9, 10
# 2. BOOLEANS^{8}
#    core type: Operation
#    operator: 11
#    operands: 12
# 3. A
#    core type: Variable
#    sub-expressions:
# 4. B
#    core type: Variable
#    sub-expressions:
# 5. C
#    core type: Variable
#    sub-expressions:
# 6. D
#    core type: Variable
#    sub-expressions:
# 7. E
#    core type: Variable
#    sub-expressions:
# 8. F
#    core type: Variable
#    sub-expressions:
# 9. G
#    core type: Variable
#    sub-expressions:
# 10. H
#     core type: Variable
#     sub-expressions:
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (BOOLEANS , 8)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. 8
#     core type: Literal
#     sub-expressions:
