# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Forall, Implies, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B, C], C, domain = Booleans, conditions = [Or(A, B), Implies(A, C), Implies(B, C)])
# Out:
# expr: forall_{A, B, C in BOOLEANS | A or B , A => C , B => C} C

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B, C in BOOLEANS | A or B , A => C , B => C} C
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. A -> [forall_{B, C in BOOLEANS | A or B , A => C , B => C} C] | A in BOOLEANS
#    core type: Lambda
#    parameter: 26
#    body: 2
#    conditions: 3\n2. forall_{B, C in BOOLEANS | A or B , A => C , B => C} C
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. B -> [forall_{C in BOOLEANS | A => C , B => C} C] | B in BOOLEANS , A or B
#    core type: Lambda
#    parameter: 27
#    body: 6
#    conditions: 7\n5. A in BOOLEANS
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall_{C in BOOLEANS | A => C , B => C} C
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (B in BOOLEANS , A or B)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 26, 25
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. C -> C | C in BOOLEANS , A => C , B => C
#     core type: Lambda
#     parameter: 28
#     body: 28
#     conditions: 13\n11. B in BOOLEANS
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. A or B
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (C in BOOLEANS , A => C , B => C)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 14. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 15. or
#     core type: Literal
#     sub-expressions:
# 16. (A , B)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 17. C in BOOLEANS
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. A => C
#     core type: Operation
#     operator: 23
#     operands: 22
# 19. B => C
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (C , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 28, 25
# 22. (A , C)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 23. =>
#     core type: Literal
#     sub-expressions:
# 24. (B , C)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 26. A
#     core type: Variable
#     sub-expressions:
# 27. B
#     core type: Variable
#     sub-expressions:
# 28. C
#     core type: Variable
#     sub-expressions:
