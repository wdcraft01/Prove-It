# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, BB, i, m
from proveit.logic import Implies
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Iter(i, Implies(Indexed(AA, i, base = 1), Indexed(BB, i, base = 1)), one, m)
# Out:
# expr: (A_1 => B_1),...,(A_m => B_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 => B_1),...,(A_m => B_m)
#    core type: Iter
#    lambda_map: 1
#    start_index: 17
#    end_index: 18
# 1. i -> (A_i => B_i) | i in {1...m}
#    core type: Lambda
#    parameter: 13
#    body: 2
#    conditions: 3\n2. A_i => B_i
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (A_i , B_i)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. i in {1...m}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. A_i
#    core type: Indexed
#    var: 11
#    index: 13
#    base: "1"
# 8. B_i
#    core type: Indexed
#    var: 12
#    index: 13
#    base: "1"
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. i
# ...
