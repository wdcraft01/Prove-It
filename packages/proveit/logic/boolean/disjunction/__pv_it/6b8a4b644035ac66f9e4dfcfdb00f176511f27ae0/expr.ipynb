# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Forall, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Not(Or(A, B)), conditions = [Not(B)]), conditions = [Not(A)])
# Out:
# expr: A -> [forall_{B | [not](B)} [not](A or B)] | [not](A)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | [not](B)} [not](A or B)] | [not](A)
#    core type: Lambda
#    parameter: 13
#    body: 1
#    conditions: 2\n1. forall_{B | [not](B)} [not](A or B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> [not](A or B) | [not](B)
#    core type: Lambda
#    parameter: 14
#    body: 6
#    conditions: 7\n5. [not](A)
#    core type: Operation
#    operator: 12
#    operand: 13
# 6. [not](A or B)
#    core type: Operation
#    operator: 12
#    operand: 8
# 7. ([not](B))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. [not](B)
#    core type: Operation
#    operator: 12
#    operand: 14
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. not
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
