# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Not.html">Not</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m
from proveit.logic import And, Not
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Not(And(Iter(i, Not(Indexed(AA, i, base = 1)), one, m)))
# Out:
# expr: [not]([not](A_1) and  ...  and [not](A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not]([not](A_1) and  ...  and [not](A_m))
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. [not](A_1) and  ...  and [not](A_m)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. ([not](A_1) ,  ...  , [not](A_m))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. [not](A_1),...,[not](A_m)
#    core type: Iter
#    lambda_map: 5
#    start_index: 18
#    end_index: 19
# 5. i -> [not](A_i) | i in {1...m}
#    core type: Lambda
#    parameter: 14
#    body: 6
#    conditions: 7\n6. [not](A_i)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. A_i
#    core type: Indexed
#    var: 11
#    index: 14
#    base: "1"
# 10. i in {1...m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. {1...m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
