# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Variable
from proveit._common_ import C
from proveit.logic import Booleans, Or
from proveit.number import four, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = ExprTuple(Or(Iter(subExpr1, Indexed(C, subExpr1, base = 1), one, four)), Booleans)
# Out:
# expr: (C_1 or  ...  or C_4 , BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (C_1 or  ...  or C_4 , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. C_1 or  ...  or C_4
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (C_1 ,  ...  , C_4)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. C_1,...,C_4
#    core type: Iter
#    lambda_map: 6
#    start_index: 17
#    end_index: 18
# 6. _x_ -> C__x_ | _x_ in {1...4}
#    core type: Lambda
#    parameter: 13
#    body: 7
#    conditions: 8\n7. C__x_
#    core type: Indexed
#    var: 9
#    index: 13
#    base: "1"
# 8. (_x_ in {1...4})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. _x_ in {1...4}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (_x_ , {1...4})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. _x_
#     core type: Variable
#     sub-expressions:
# 14. {1...4}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , 4)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 4
#     core type: Literal
#     sub-expressions:
