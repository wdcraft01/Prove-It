# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A
from proveit.logic import Booleans, Equals, FALSE, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Equals(Or(A), Or(FALSE, A)), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> ([or](A) = (FALSE or A)) | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> ([or](A) = (FALSE or A)) | A in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. [or](A) = (FALSE or A)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ([or](A) , FALSE or A)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. [or](A)
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. FALSE or A
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 10. (A)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (FALSE , A)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. FALSE
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
