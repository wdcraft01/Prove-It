# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, C, i, m
from proveit.logic import Forall, Implies
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([C], C, conditions = [Iter(i, Implies(Indexed(AA, i, base = 1), C), one, m)])
# Out:
# expr: forall_{C | A_1 => C ,  ...  , A_m => C} C

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C | A_1 => C ,  ...  , A_m => C} C
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> C | A_1 => C ,  ...  , A_m => C
#    core type: Lambda
#    parameter: 12
#    body: 12
#    conditions: 3\n3. (A_1 => C ,  ...  , A_m => C)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (A_1 => C),...,(A_m => C)
#    core type: Iter
#    lambda_map: 5
#    start_index: 20
#    end_index: 21
# 5. i -> (A_i => C) | i in {1...m}
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n6. A_i => C
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (A_i , C)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. i in {1...m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. A_i
#     core type: Indexed
#     var: 15
#     index: 16
#     base: "1"
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. {1...m}
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. m
#     core type: Variable
#     sub-expressions:
