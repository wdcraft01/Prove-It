# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#orIfLeft">orIfLeft</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import orIfLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr orIfLeft
# Out:
# Passed sanity check: built 'orIfLeft' is the same as the stored Expression.

# %%
# display the expression information
orIfLeft.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | A} (A or B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS} (A or B)] | A in BOOLEANS , A
#    core type: Lambda
#    parameter: 13
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS} (A or B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS , A)
#    core type: ExprTuple
#    sub-expressions: 6, 13
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> (A or B) | B in BOOLEANS
#    core type: Lambda
#    parameter: 16
#    body: 7
#    conditions: 8\n6. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 17
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
# ...
