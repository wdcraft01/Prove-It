# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import Equals, Or
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Equals(Or(iterA1l, iterB1m, iterC1n), Or(iterA1l, Or(iterB1m), iterC1n))
# Out:
# expr: (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n , A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 11
#    operands: 5
# 4. A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 11
#    operands: 6
# 5. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 7, 16, 9
# 6. (A_1 ,  ...  , A_l , B_1 or  ...  or B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A_1,...,A_l
#    core type: Iter
#    lambda_map: 10
#    start_index: 42
#    end_index: 36
# 8. B_1 or  ...  or B_m
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. C_1,...,C_n
#    core type: Iter
#    lambda_map: 13
#    start_index: 42
#    end_index: 39
# 10. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 37
#     body: 14
#     conditions: 15\n11. or
#     core type: Literal
#     sub-expressions:
# 12. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 37
#     body: 17
#     conditions: 18\n14. A__x_
#     core type: Indexed
#     var: 19
#     index: 37
#     base: "1"
# 15. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 20
# 16. B_1,...,B_m
#     core type: Iter
#     lambda_map: 21
#     start_index: 42
#     end_index: 43
# 17. C__x_
#     core type: Indexed
#     var: 22
#     index: 37
#     base: "1"
# 18. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 23
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...l}
#     core type: Operation
#     operator: 33
#     operands: 24
# 21. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 37
#     body: 25
#     conditions: 26\n22. C
#     core type: Variable
#     sub-expressions:
# 23. _x_ in {1...n}
#     core type: Operation
#     operator: 33
#     operands: 27
# 24. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 37, 28
# 25. B__x_
#     core type: Indexed
#     var: 29
#     index: 37
#     base: "1"
# 26. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 30
# 27. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 37, 31
# 28. {1...l}
#     core type: Operation
#     operator: 40
#     operands: 32
# 29. B
#     core type: Variable
#     sub-expressions:
# 30. _x_ in {1...m}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. {1...n}
#     core type: Operation
#     operator: 40
#     operands: 35
# 32. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 42, 36
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 42, 39
# 36. l
#     core type: Variable
#     sub-expressions:
# 37. _x_
#     core type: Variable
#     sub-expressions:
# 38. {1...m}
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. n
#     core type: Variable
#     sub-expressions:
# 40. Interval
#     core type: Literal
#     sub-expressions:
# 41. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 42. 1
#     core type: Literal
#     sub-expressions:
# 43. m
#     core type: Variable
#     sub-expressions:
