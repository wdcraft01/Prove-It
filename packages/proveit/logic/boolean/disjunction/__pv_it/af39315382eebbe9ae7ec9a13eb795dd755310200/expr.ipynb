# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Lambda
from proveit._common_ import AA, C, i, m
from proveit.logic import Implies, InSet
from proveit.number import Interval, one

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Implies(Indexed(AA, i, base = 1), C), conditions = [InSet(i, Interval(one, m))])
# Out:
# expr: i -> (A_i => C) | i in {1...m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> (A_i => C) | i in {1...m}
#    core type: Lambda
#    parameter: 11
#    body: 1
#    conditions: 2\n1. A_i => C
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (A_i , C)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. i in {1...m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. A_i
#    core type: Indexed
#    var: 10
#    index: 11
#    base: "1"
# 7. C
#    core type: Variable
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i , {1...m})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. {1...m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (1 , m)
# ...
