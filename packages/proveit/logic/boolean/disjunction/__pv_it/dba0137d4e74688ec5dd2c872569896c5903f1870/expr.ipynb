# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([C], C, domain = Booleans, conditions = [Implies(A, C), Implies(B, C)])
# Out:
# expr: forall_{C in BOOLEANS | A => C , B => C} C

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C in BOOLEANS | A => C , B => C} C
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> C | C in BOOLEANS , A => C , B => C
#    core type: Lambda
#    parameter: 15
#    body: 15
#    conditions: 3\n3. (C in BOOLEANS , A => C , B => C)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. C in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. A => C
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. B => C
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (C , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 9. (A , C)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (B , C)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. C
#     core type: Variable
#     sub-expressions:
