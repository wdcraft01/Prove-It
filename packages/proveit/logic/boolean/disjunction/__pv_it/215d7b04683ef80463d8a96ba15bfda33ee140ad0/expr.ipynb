# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, B, CC, m, n
from proveit.logic import And, Booleans, Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([m, n], Forall([AA, B, CC], InSet(B, Booleans), conditions = [InSet(And(iterA1m, B, iterC1n), Booleans)]), domain = Naturals, conditions = [])
# Out:
# expr: forall_{m, n in Naturals} [forall_{A, B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{A, B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)]
#    core type: Operation
#    operator: 16
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{A, B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)]] | m in Naturals
#    core type: Lambda
#    parameter: 49
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{A, B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)]
#    core type: Operation
#    operator: 16
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{A, B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)] | n in Naturals
#    core type: Lambda
#    parameter: 51
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 41
#    operands: 8
# ...
