# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import CC, n
from proveit.logic import Booleans, Equals, Forall, Or, TRUE
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([CC], Equals(Or(iterA1m, TRUE, iterC1n), TRUE), domain = Exp(Booleans, n), conditions = [])
# Out:
# expr: forall_{C in BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C in BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE) | C in BOOLEANS^{n}
#    core type: Lambda
#    parameter: 27
#    body: 3
#    conditions: 4\n3. (A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (C in BOOLEANS^{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n , TRUE)
#    core type: ExprTuple
#    sub-expressions: 8, 14
# 7. C in BOOLEANS^{n}
#    core type: Operation
#    operator: 30
#    operands: 9
# 8. A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (C , BOOLEANS^{n})
#    core type: ExprTuple
# ...
