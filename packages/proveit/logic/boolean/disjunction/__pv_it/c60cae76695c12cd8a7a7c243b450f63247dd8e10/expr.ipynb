# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Or.html">Or</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import BB, i, m
from proveit.logic import Not, Or
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Or(Iter(i, Not(Indexed(BB, i, base = 1)), one, m))
# Out:
# expr: [not](B_1) or  ...  or [not](B_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [not](B_1) or  ...  or [not](B_m)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. or
#    core type: Literal
#    sub-expressions:
# 2. ([not](B_1) ,  ...  , [not](B_m))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. [not](B_1),...,[not](B_m)
#    core type: Iter
#    lambda_map: 4
#    start_index: 17
#    end_index: 18
# 4. i -> [not](B_i) | i in {1...m}
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n5. [not](B_i)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. not
#    core type: Literal
#    sub-expressions:
# 8. B_i
#    core type: Indexed
#    var: 10
#    index: 13
#    base: "1"
# 9. i in {1...m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. {1...m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
