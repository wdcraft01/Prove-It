# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#association">association</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import association

# %%
# check that the built expression is the same as the stored expression
# %check_expr association
# Out:
# Passed sanity check: built 'association' is the same as the stored Expression.

# %%
# display the expression information
association.exprInfo()
# Out:
# 0. forall_{l, m, n in Naturals} [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))]
#    core type: Operation
#    operator: 25
#    operand: 1
# 1. l -> [forall_{m, n in Naturals} [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))]] | l in Naturals
#    core type: Lambda
#    parameter: 76
#    body: 2
#    conditions: 3\n2. forall_{m, n in Naturals} [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))]
#    core type: Operation
#    operator: 25
#    operand: 4
# 3. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. m -> [forall_{n in Naturals} [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))]] | m in Naturals
#    core type: Lambda
#    parameter: 83
#    body: 6
#    conditions: 7\n5. l in Naturals
#    core type: Operation
#    operator: 73
#    operands: 8
# 6. forall_{n in Naturals} [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))]
#    core type: Operation
#    operator: 25
#    operand: 9
# 7. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (l , Naturals)
#    core type: ExprTuple
#    sub-expressions: 76, 21
# 9. n -> [forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))] | n in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 11
#    conditions: 12\n10. m in Naturals
#     core type: Operation
#     operator: 73
#     operands: 13
# 11. forall_{(A, B, C) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))
#     core type: Operation
#     operator: 25
#     operand: 14
# 12. (n in Naturals)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 83, 21
# 14. A -> [forall_{(B, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))] | A in BOOLEANS^{l}
#     core type: Lambda
#     parameter: 59
#     body: 16
#     conditions: 17\n15. n in Naturals
#     core type: Operation
#     operator: 73
#     operands: 18
# 16. forall_{(B, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))
#     core type: Operation
#     operator: 25
#     operand: 19
# 17. (A in BOOLEANS^{l})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 79, 21
# 19. B -> [forall_{C in BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))] | B in BOOLEANS^{m}
#     core type: Lambda
#     parameter: 69
#     body: 22
#     conditions: 23\n20. A in BOOLEANS^{l}
#     core type: Operation
#     operator: 73
#     operands: 24
# 21. Naturals
#     core type: Literal
#     sub-expressions:
# 22. forall_{C in BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n))
#     core type: Operation
#     operator: 25
#     operand: 26
# 23. (B in BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. (A , BOOLEANS^{l})
#     core type: ExprTuple
#     sub-expressions: 59, 28
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. C -> ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)) | C in BOOLEANS^{n}
#     core type: Lambda
#     parameter: 62
#     body: 29
#     conditions: 30\n27. B in BOOLEANS^{m}
#     core type: Operation
#     operator: 73
#     operands: 31
# 28. BOOLEANS^{l}
#     core type: Operation
#     operator: 47
#     operands: 32
# 29. (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) = (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (C in BOOLEANS^{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 31. (B , BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 69, 36
# 32. (BOOLEANS , l)
#     core type: ExprTuple
#     sub-expressions: 53, 76
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n , A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. C in BOOLEANS^{n}
#     core type: Operation
#     operator: 73
#     operands: 39
# 36. BOOLEANS^{m}
#     core type: Operation
#     operator: 47
#     operands: 40
# 37. A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n
#     core type: Operation
#     operator: 50
#     operands: 41
# 38. A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#     core type: Operation
#     operator: 50
#     operands: 42
# 39. (C , BOOLEANS^{n})
#     core type: ExprTuple
#     sub-expressions: 62, 43
# 40. (BOOLEANS , m)
#     core type: ExprTuple
#     sub-expressions: 53, 83
# 41. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 44, 56, 46
# 42. (A_1 ,  ...  , A_l , B_1 or  ...  or B_m , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 43. BOOLEANS^{n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. A_1,...,A_l
#     core type: Iter
#     lambda_map: 49
#     start_index: 82
#     end_index: 76
# 45. B_1 or  ...  or B_m
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. C_1,...,C_n
#     core type: Iter
#     lambda_map: 52
#     start_index: 82
#     end_index: 79
# 47. Exp
#     core type: Literal
#     sub-expressions:
# 48. (BOOLEANS , n)
#     core type: ExprTuple
#     sub-expressions: 53, 79
# 49. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 77
#     body: 54
#     conditions: 55\n50. or
#     core type: Literal
#     sub-expressions:
# 51. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 77
#     body: 57
#     conditions: 58\n53. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 54. A__x_
#     core type: Indexed
#     var: 59
#     index: 77
#     base: "1"
# 55. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 60
# 56. B_1,...,B_m
#     core type: Iter
#     lambda_map: 61
#     start_index: 82
#     end_index: 83
# 57. C__x_
#     core type: Indexed
#     var: 62
#     index: 77
#     base: "1"
# 58. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 63
# 59. A
#     core type: Variable
#     sub-expressions:
# 60. _x_ in {1...l}
#     core type: Operation
#     operator: 73
#     operands: 64
# 61. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 77
#     body: 65
#     conditions: 66\n62. C
#     core type: Variable
#     sub-expressions:
# 63. _x_ in {1...n}
#     core type: Operation
#     operator: 73
#     operands: 67
# 64. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 77, 68
# 65. B__x_
#     core type: Indexed
#     var: 69
#     index: 77
#     base: "1"
# 66. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 70
# 67. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 77, 71
# 68. {1...l}
#     core type: Operation
#     operator: 80
#     operands: 72
# 69. B
#     core type: Variable
#     sub-expressions:
# 70. _x_ in {1...m}
#     core type: Operation
#     operator: 73
#     operands: 74
# 71. {1...n}
#     core type: Operation
#     operator: 80
#     operands: 75
# 72. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 82, 76
# 73. in
#     core type: Literal
#     sub-expressions:
# 74. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 82, 79
# 76. l
#     core type: Variable
#     sub-expressions:
# 77. _x_
#     core type: Variable
#     sub-expressions:
# 78. {1...m}
#     core type: Operation
#     operator: 80
#     operands: 81
# 79. n
#     core type: Variable
#     sub-expressions:
# 80. Interval
#     core type: Literal
#     sub-expressions:
# 81. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 82. 1
#     core type: Literal
#     sub-expressions:
# 83. m
#     core type: Variable
#     sub-expressions:
