# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, BB, C, DD, l, m, n
from proveit.logic import Booleans, Equals, Forall, InSet, Or
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([AA, BB, C, DD], Equals(Or(iterA1l, iterB1m, C, iterD1n), Or(iterA1l, C, iterB1m, iterD1n)), domains = [Exp(Booleans, l), Exp(Booleans, m), Booleans, Exp(Booleans, n)], conditions = []), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))] | n in Naturals
#    core type: Lambda
#    parameter: 76
#    body: 1
#    conditions: 2\n1. forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))
#    core type: Operation
#    operator: 21
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. A -> [forall_{(B, C, D) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))] | A in BOOLEANS^{l}
#    core type: Lambda
#    parameter: 55
#    body: 5
# ...
