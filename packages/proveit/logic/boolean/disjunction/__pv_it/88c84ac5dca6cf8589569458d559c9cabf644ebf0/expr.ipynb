# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, C, D
from proveit.logic import Booleans, Implies, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(C, Booleans), InSet(D, Booleans), Implies(B, D), B)
# Out:
# expr: {C in BOOLEANS , D in BOOLEANS , B => D , B}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {C in BOOLEANS , D in BOOLEANS , B => D , B}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (C in BOOLEANS , D in BOOLEANS , B => D , B)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 13
# 3. C in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 6
# 4. D in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. B => D
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (C , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (D , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 9. =>
#    core type: Literal
#    sub-expressions:
# 10. (B , D)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. D
#     core type: Variable
#     sub-expressions:
