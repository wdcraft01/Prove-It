# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], B, domain = Booleans, conditions = [Or(A, B), Not(A)]), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B in BOOLEANS | A or B , [not](A)} B] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in BOOLEANS | A or B , [not](A)} B] | A in BOOLEANS
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. forall_{B in BOOLEANS | A or B , [not](A)} B
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> B | B in BOOLEANS , A or B , [not](A)
#    core type: Lambda
#    parameter: 18
#    body: 18
#    conditions: 6\n5. A in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. (B in BOOLEANS , A or B , [not](A))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 16
# 8. B in BOOLEANS
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. A or B
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. [not](A)
#     core type: Operation
#     operator: 15
#     operand: 17
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
