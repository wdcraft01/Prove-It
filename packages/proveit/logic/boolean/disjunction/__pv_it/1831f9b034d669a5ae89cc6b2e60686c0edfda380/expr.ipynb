# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E
from proveit.logic import Booleans, Implies, InSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(A, B, C, D), Implies(A, E), Implies(B, E), Implies(C, E), Implies(D, E), InSet(A, Booleans), InSet(B, Booleans), InSet(C, Booleans), InSet(D, Booleans))
# Out:
# expr: {A or B or C or D , A => E , B => E , C => E , D => E , A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A or B or C or D , A => E , B => E , C => E , D => E , A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D , A => E , B => E , C => E , D => E , A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8, 9, 10, 11
# 3. A or B or C or D
#    core type: Operation
#    operator: 12
#    operands: 13
# 4. A => E
#    core type: Operation
#    operator: 17
#    operands: 14
# 5. B => E
#    core type: Operation
#    operator: 17
#    operands: 15
# 6. C => E
#    core type: Operation
#    operator: 17
#    operands: 16
# 7. D => E
#    core type: Operation
#    operator: 17
#    operands: 18
# 8. A in BOOLEANS
#    core type: Operation
#    operator: 22
#    operands: 19
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 22
#    operands: 20
# ...
