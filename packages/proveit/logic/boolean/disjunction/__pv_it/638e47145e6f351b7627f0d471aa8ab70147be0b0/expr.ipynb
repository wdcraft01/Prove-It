# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import H, I, J, K
from proveit.logic import Booleans, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(H, Booleans), InSet(I, Booleans), InSet(J, Booleans), InSet(K, Booleans))
# Out:
# expr: {H in BOOLEANS , I in BOOLEANS , J in BOOLEANS , K in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {H in BOOLEANS , I in BOOLEANS , J in BOOLEANS , K in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (H in BOOLEANS , I in BOOLEANS , J in BOOLEANS , K in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. H in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 7
# 4. I in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. J in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. K in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (H , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. (I , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. (J , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (K , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. H
#     core type: Variable
#     sub-expressions:
# 13. I
#     core type: Variable
#     sub-expressions:
# 14. J
#     core type: Variable
#     sub-expressions:
# 15. K
#     core type: Variable
#     sub-expressions:
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
