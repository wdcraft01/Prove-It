# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import CC
from proveit.logic import Or
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, Or(iterA1l, iterB1m, iterC1n), conditions = [Or(iterA1l, Or(iterB1m), iterC1n)])
# Out:
# expr: C -> (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) | A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) | A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 6, 15, 8
# 4. A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 10
#    operands: 5
# 5. (A_1 ,  ...  , A_l , B_1 or  ...  or B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. A_1,...,A_l
#    core type: Iter
#    lambda_map: 9
#    start_index: 41
#    end_index: 35
# 7. B_1 or  ...  or B_m
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. C_1,...,C_n
#    core type: Iter
#    lambda_map: 12
#    start_index: 41
#    end_index: 38
# 9. _x_ -> A__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 36
#    body: 13
#    conditions: 14\n10. or
#     core type: Literal
#     sub-expressions:
# 11. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 36
#     body: 16
#     conditions: 17\n13. A__x_
#     core type: Indexed
#     var: 18
#     index: 36
#     base: "1"
# 14. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 19
# 15. B_1,...,B_m
#     core type: Iter
#     lambda_map: 20
#     start_index: 41
#     end_index: 42
# 16. C__x_
#     core type: Indexed
#     var: 21
#     index: 36
#     base: "1"
# 17. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 22
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. _x_ in {1...l}
#     core type: Operation
#     operator: 32
#     operands: 23
# 20. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 36
#     body: 24
#     conditions: 25\n21. C
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...n}
#     core type: Operation
#     operator: 32
#     operands: 26
# 23. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 36, 27
# 24. B__x_
#     core type: Indexed
#     var: 28
#     index: 36
#     base: "1"
# 25. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 29
# 26. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 36, 30
# 27. {1...l}
#     core type: Operation
#     operator: 39
#     operands: 31
# 28. B
#     core type: Variable
#     sub-expressions:
# 29. _x_ in {1...m}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. {1...n}
#     core type: Operation
#     operator: 39
#     operands: 34
# 31. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 41, 35
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 41, 38
# 35. l
#     core type: Variable
#     sub-expressions:
# 36. _x_
#     core type: Variable
#     sub-expressions:
# 37. {1...m}
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. n
#     core type: Variable
#     sub-expressions:
# 39. Interval
#     core type: Literal
#     sub-expressions:
# 40. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. m
#     core type: Variable
#     sub-expressions:
