# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import And, Booleans, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Or(A, B), conditions = [InSet(B, Booleans), Not(And(Not(A), Not(B)))])
# Out:
# expr: B -> (A or B) | B in BOOLEANS , [not]([not](A) and [not](B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> (A or B) | B in BOOLEANS , [not]([not](A) and [not](B))
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. A or B
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (B in BOOLEANS , [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (A , B)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 16
#    operand: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 9. [not](A) and [not](B)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. ([not](A) , [not](B))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. [not](A)
#     core type: Operation
#     operator: 16
#     operand: 15
# 14. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
