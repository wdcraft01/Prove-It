# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g, h
from proveit.logic import Forall, InSet
from proveit.number import Exp, eight

# %%
# build up the expression from sub-expressions
expr = Forall([h], InSet([a, b, c, d, e, f, g, h], Exp(S, eight)), domain = S, conditions = [])
# Out:
# expr: forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. h -> ((a , b , c , d , e , f , g , h) in S^{8}) | h in S
#    core type: Lambda
#    parameter: 20
#    body: 3
#    conditions: 4\n3. (a , b , c , d , e , f , g , h) in S^{8}
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (h in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((a , b , c , d , e , f , g , h) , S^{8})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. h in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (a , b , c , d , e , f , g , h)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15, 16, 17, 20
# 8. S^{8}
#    core type: Operation
#    operator: 18
#    operands: 19
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (h , S)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. g
#     core type: Variable
#     sub-expressions:
# 18. Exp
#     core type: Literal
#     sub-expressions:
# 19. (S , 8)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. h
#     core type: Variable
#     sub-expressions:
# 21. S
#     core type: Variable
#     sub-expressions:
# 22. 8
#     core type: Literal
#     sub-expressions:
