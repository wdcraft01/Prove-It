# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#leftwardCommute">leftwardCommute</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import leftwardCommute

# %%
# check that the built expression is the same as the stored expression
# %check_expr leftwardCommute
# Out:
# Passed sanity check: built 'leftwardCommute' is the same as the stored Expression.

# %%
# display the expression information
leftwardCommute.exprInfo()
# Out:
# 0. forall_{l, m, n in Naturals} [forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]
#    core type: Operation
#    operator: 23
#    operand: 1
# 1. l -> [forall_{m, n in Naturals} [forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]] | l in Naturals
#    core type: Lambda
#    parameter: 62
#    body: 2
#    conditions: 3\n2. forall_{m, n in Naturals} [forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]
#    core type: Operation
#    operator: 23
#    operand: 4
# 3. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. m -> [forall_{n in Naturals} [forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]] | m in Naturals
#    core type: Lambda
#    parameter: 63
#    body: 6
#    conditions: 7\n5. l in Naturals
#    core type: Operation
#    operator: 52
#    operands: 8
# 6. forall_{n in Naturals} [forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]
#    core type: Operation
#    operator: 23
#    operand: 9
# 7. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (l , Naturals)
#    core type: ExprTuple
#    sub-expressions: 62, 19
# 9. n -> [forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)] | n in Naturals
#    core type: Lambda
#    parameter: 65
#    body: 11
#    conditions: 12\n10. m in Naturals
#     core type: Operation
#     operator: 52
#     operands: 13
# 11. forall_{A, B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)
#     core type: Operation
#     operator: 23
#     operand: 14
# 12. (n in Naturals)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 63, 19
# 14. A -> [forall_{B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]
#     core type: Lambda
#     parameter: 44
#     body: 16
# 15. n in Naturals
#     core type: Operation
#     operator: 52
#     operands: 17
# 16. forall_{B, C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)
#     core type: Operation
#     operator: 23
#     operand: 18
# 17. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 65, 19
# 18. B -> [forall_{C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]
#     core type: Lambda
#     parameter: 46
#     body: 20
# 19. Naturals
#     core type: Literal
#     sub-expressions:
# 20. forall_{C, D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)
#     core type: Operation
#     operator: 23
#     operand: 21
# 21. C -> [forall_{D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)]
#     core type: Lambda
#     parameter: 33
#     body: 22
# 22. forall_{D | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n} (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n)
#     core type: Operation
#     operator: 23
#     operand: 24
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. D -> (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n) | A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n
#     core type: Lambda
#     parameter: 48
#     body: 25
#     conditions: 26\n25. A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n
#     core type: Operation
#     operator: 29
#     operands: 27
# 26. (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. (A_1 ,  ...  , A_l , C , B_1 ,  ...  , B_m , D_1 ,  ...  , D_n)
#     core type: ExprTuple
#     sub-expressions: 31, 33, 32, 34
# 28. A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. or
#     core type: Literal
#     sub-expressions:
# 30. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C , D_1 ,  ...  , D_n)
#     core type: ExprTuple
#     sub-expressions: 31, 32, 33, 34
# 31. A_1,...,A_l
#     core type: Iter
#     lambda_map: 35
#     start_index: 64
#     end_index: 62
# 32. B_1,...,B_m
#     core type: Iter
#     lambda_map: 36
#     start_index: 64
#     end_index: 63
# 33. C
#     core type: Variable
#     sub-expressions:
# 34. D_1,...,D_n
#     core type: Iter
#     lambda_map: 37
#     start_index: 64
#     end_index: 65
# 35. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 56
#     body: 38
#     conditions: 39\n36. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 56
#     body: 40
#     conditions: 41\n37. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 56
#     body: 42
#     conditions: 43\n38. A__x_
#     core type: Indexed
#     var: 44
#     index: 56
#     base: "1"
# 39. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 45
# 40. B__x_
#     core type: Indexed
#     var: 46
#     index: 56
#     base: "1"
# 41. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 47
# 42. D__x_
#     core type: Indexed
#     var: 48
#     index: 56
#     base: "1"
# 43. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 49
# 44. A
#     core type: Variable
#     sub-expressions:
# 45. _x_ in {1...l}
#     core type: Operation
#     operator: 52
#     operands: 50
# 46. B
#     core type: Variable
#     sub-expressions:
# 47. _x_ in {1...m}
#     core type: Operation
#     operator: 52
#     operands: 51
# 48. D
#     core type: Variable
#     sub-expressions:
# 49. _x_ in {1...n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 50. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 56, 54
# 51. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 54. {1...l}
#     core type: Operation
#     operator: 60
#     operands: 58
# 55. {1...m}
#     core type: Operation
#     operator: 60
#     operands: 59
# 56. _x_
#     core type: Variable
#     sub-expressions:
# 57. {1...n}
#     core type: Operation
#     operator: 60
#     operands: 61
# 58. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 64, 62
# 59. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 64, 63
# 60. Interval
#     core type: Literal
#     sub-expressions:
# 61. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. l
#     core type: Variable
#     sub-expressions:
# 63. m
#     core type: Variable
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
