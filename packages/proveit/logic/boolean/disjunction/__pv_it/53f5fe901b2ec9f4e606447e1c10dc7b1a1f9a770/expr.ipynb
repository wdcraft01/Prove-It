# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import And, Forall, Not, Or

# %%
# build up the expression from sub-expressions
expr = Forall([B], Or(A, B), conditions = [Not(And(Not(A), Not(B)))])
# Out:
# expr: forall_{B | [not]([not](A) and [not](B))} (A or B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B | [not]([not](A) and [not](B))} (A or B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (A or B) | [not]([not](A) and [not](B))
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. A or B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. ([not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A , B)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 7. [not]([not](A) and [not](B))
#    core type: Operation
#    operator: 14
#    operand: 8
# 8. [not](A) and [not](B)
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. ([not](A) , [not](B))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. [not](A)
#     core type: Operation
#     operator: 14
#     operand: 13
# 12. [not](B)
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. not
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
