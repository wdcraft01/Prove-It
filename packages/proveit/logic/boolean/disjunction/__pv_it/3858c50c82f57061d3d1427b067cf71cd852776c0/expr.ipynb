# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, m
from proveit.logic import Equals, FALSE, Forall, InSet, Or, Set
from proveit.logic._common_ import iterA1m
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([AA], Equals(Or(iterA1m), FALSE), domain = Exp(Set(FALSE), m), conditions = []), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{A in {FALSE}^{m}} ((A_1 or  ...  or A_m) = FALSE)] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{A in {FALSE}^{m}} ((A_1 or  ...  or A_m) = FALSE)] | m in Naturals
#    core type: Lambda
#    parameter: 37
#    body: 1
#    conditions: 2\n1. forall_{A in {FALSE}^{m}} ((A_1 or  ...  or A_m) = FALSE)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> ((A_1 or  ...  or A_m) = FALSE) | A in {FALSE}^{m}
#    core type: Lambda
#    parameter: 27
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 30
#    operands: 8
# 6. (A_1 or  ...  or A_m) = FALSE
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (A in {FALSE}^{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 37, 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (A_1 or  ...  or A_m , FALSE)
#     core type: ExprTuple
# ...
