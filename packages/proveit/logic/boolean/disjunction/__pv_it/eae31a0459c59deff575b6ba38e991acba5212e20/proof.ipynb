# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td>0</td><td>specialization</td><td>1, 2, 3, 4, 5</td><td><span style="font-size:20px;"><a class="ProveItLink" href="../fca18e0d442d6d642db8db9027bbb77fae4f7fd60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="proof.ipynb" style="text-decoration: none">&#x22A2;&nbsp;</a><a class="ProveItLink" href="../833147bb5744d30a323b0c86d7141c015af04b560/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# ...
