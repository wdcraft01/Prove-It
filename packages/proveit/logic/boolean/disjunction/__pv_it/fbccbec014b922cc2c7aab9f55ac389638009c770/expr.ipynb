# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m
from proveit.logic import FALSE, Forall, InSet, Not, Or
from proveit.logic._common_ import iterA1m
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([AA], FALSE, conditions = [Or(iterA1m), Iter(i, Not(Indexed(AA, i, base = 1)), one, m)]), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{A | A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m)} FALSE] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{A | A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m)} FALSE] | m in Naturals
#    core type: Lambda
#    parameter: 35
#    body: 1
#    conditions: 2\n1. forall_{A | A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m)} FALSE
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> FALSE | A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m)
#    core type: Lambda
#    parameter: 25
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 28
#    operands: 8
# 6. FALSE
#    core type: Literal
#    sub-expressions:
# 7. (A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 35, 11
# 9. A_1 or  ...  or A_m
#    core type: Operation
#    operator: 12
#    operands: 13
# ...
