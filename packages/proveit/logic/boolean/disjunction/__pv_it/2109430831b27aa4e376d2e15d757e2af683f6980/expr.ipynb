# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E, F, G, H
from proveit.logic import Booleans, InSet, Or

# %%
# build up the expression from sub-expressions
expr = InSet(Or(A, B, C, D, E, F, G, H), Booleans)
# Out:
# expr: (A or B or C or D or E or F or G or H) in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A or B or C or D or E or F or G or H) in BOOLEANS
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D or E or F or G or H , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A or B or C or D or E or F or G or H
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A , B , C , D , E , F , G , H)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11, 12, 13, 14
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. D
#     core type: Variable
#     sub-expressions:
# 11. E
#     core type: Variable
#     sub-expressions:
# 12. F
#     core type: Variable
#     sub-expressions:
# 13. G
#     core type: Variable
#     sub-expressions:
# 14. H
#     core type: Variable
#     sub-expressions:
