# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Implies, InSet, Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Booleans), InSet(B, Booleans), Or(A, B), InSet(C, Booleans), Implies(A, C), InSet(D, Booleans), Implies(B, D))
# Out:
# expr: (A in BOOLEANS , B in BOOLEANS , A or B , C in BOOLEANS , A => C , D in BOOLEANS , B => D)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS , B in BOOLEANS , A or B , C in BOOLEANS , A => C , D in BOOLEANS , B => D)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6, 7
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 8
# 2. B in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 9
# 3. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 4. C in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 12
# 5. A => C
#    core type: Operation
#    operator: 16
#    operands: 13
# 6. D in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 15
# 7. B => D
#    core type: Operation
#    operator: 16
#    operands: 17
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 20
# 9. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 21, 20
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 21
# 12. (C , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 13. (A , C)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (B , D)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. C
#     core type: Variable
#     sub-expressions:
# 20. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. D
#     core type: Variable
#     sub-expressions:
