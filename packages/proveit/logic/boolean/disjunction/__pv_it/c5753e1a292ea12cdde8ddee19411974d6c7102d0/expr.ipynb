# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import And, Booleans, Forall, InSet

# %%
# build up the expression from sub-expressions
expr = Forall([B], InSet(A, Booleans), conditions = [InSet(And(A, B), Booleans)])
# Out:
# expr: forall_{B | (A and B) in BOOLEANS} (A in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B | (A and B) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (A in BOOLEANS) | (A and B) in BOOLEANS
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 5
# 4. ((A and B) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 6. (A and B) in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A and B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. A and B
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
