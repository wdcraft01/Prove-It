# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#orIfOnlyRight">orIfOnlyRight</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import orIfOnlyRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr orIfOnlyRight
# Out:
# Passed sanity check: built 'orIfOnlyRight' is the same as the stored Expression.

# %%
# display the expression information
orIfOnlyRight.exprInfo()
# Out:
# 0. forall_{A, B | [not](A) , B} (A or B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B | B} (A or B)] | [not](A)
#    core type: Lambda
#    parameter: 12
#    body: 2
#    conditions: 3\n2. forall_{B | B} (A or B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. ([not](A))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> (A or B) | B
#    core type: Lambda
#    parameter: 13
#    body: 7
#    conditions: 8\n6. [not](A)
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (B)
#    core type: ExprTuple
#    sub-expressions: 13
# 9. not
#    core type: Literal
#    sub-expressions:
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
# ...
