# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A
from proveit.logic import Equals, Or
from proveit.logic._common_ import iterB1n

# %%
# build up the expression from sub-expressions
expr = Equals(Or(iterB1n, A), Or(Or(iterB1n), A))
# Out:
# expr: (B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (B_1 or  ...  or B_n or A , (B_1 or  ...  or B_n) or A)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. B_1 or  ...  or B_n or A
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (B_1 or  ...  or B_n) or A
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (B_1 ,  ...  , B_n , A)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 6. (B_1 or  ...  or B_n , A)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. B_1 or  ...  or B_n
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. A
#    core type: Variable
#    sub-expressions:
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (B_1 ,  ...  , B_n)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. B_1,...,B_n
#     core type: Iter
#     lambda_map: 12
#     start_index: 23
#     end_index: 24
# 12. _x_ -> B__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 19
#     body: 13
#     conditions: 14\n13. B__x_
#     core type: Indexed
#     var: 15
#     index: 19
#     base: "1"
# 14. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. _x_ in {1...n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. _x_
#     core type: Variable
#     sub-expressions:
# 20. {1...n}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. n
#     core type: Variable
#     sub-expressions:
