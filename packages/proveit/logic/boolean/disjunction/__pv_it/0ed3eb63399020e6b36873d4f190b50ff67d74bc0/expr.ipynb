# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#notRightIfNeither">notRightIfNeither</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import notRightIfNeither

# %%
# check that the built expression is the same as the stored expression
# %check_expr notRightIfNeither
# Out:
# Passed sanity check: built 'notRightIfNeither' is the same as the stored Expression.

# %%
# display the expression information
notRightIfNeither.exprInfo()
# Out:
# 0. forall_{A, B | [not](A or B)} [not](B)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | [not](A or B)} [not](B)]
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. forall_{B | [not](A or B)} [not](B)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> [not](B) | [not](A or B)
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n5. [not](B)
#    core type: Operation
#    operator: 8
#    operand: 13
# 6. ([not](A or B))
#    core type: ExprTuple
#    sub-expressions: 7
# 7. [not](A or B)
#    core type: Operation
#    operator: 8
#    operand: 9
# 8. not
#    core type: Literal
#    sub-expressions:
# 9. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. A
#     core type: Variable
# ...
