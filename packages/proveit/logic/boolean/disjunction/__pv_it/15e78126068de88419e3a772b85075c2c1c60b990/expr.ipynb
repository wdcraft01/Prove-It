# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], InSet(Or(A, B), Booleans), domain = Booleans, conditions = []), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B in BOOLEANS} ((A or B) in BOOLEANS)] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in BOOLEANS} ((A or B) in BOOLEANS)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. forall_{B in BOOLEANS} ((A or B) in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((A or B) in BOOLEANS) | B in BOOLEANS
#    core type: Lambda
#    parameter: 18
#    body: 6
#    conditions: 7\n5. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 8
# 6. (A or B) in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 9
# 7. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 16
# 9. (A or B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11, 16
# 10. B in BOOLEANS
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. A or B
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 14. or
#     core type: Literal
#     sub-expressions:
# 15. (A , B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
