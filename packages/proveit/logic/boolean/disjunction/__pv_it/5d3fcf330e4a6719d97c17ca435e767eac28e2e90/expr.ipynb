# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Implies, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(D, Booleans), Or(Not(C), Not(D)), Implies(A, C), Implies(B, D))
# Out:
# expr: (D in BOOLEANS , [not](C) or [not](D) , A => C , B => D)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (D in BOOLEANS , [not](C) or [not](D) , A => C , B => D)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. D in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 2. [not](C) or [not](D)
#    core type: Operation
#    operator: 7
#    operands: 8
# 3. A => C
#    core type: Operation
#    operator: 10
#    operands: 9
# 4. B => D
#    core type: Operation
#    operator: 10
#    operands: 11
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (D , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. ([not](C) , [not](D))
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. (A , C)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (B , D)
#     core type: ExprTuple
#     sub-expressions: 16, 19
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. [not](C)
#     core type: Operation
#     operator: 18
#     operand: 17
# 14. [not](D)
#     core type: Operation
#     operator: 18
#     operand: 19
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. C
#     core type: Variable
#     sub-expressions:
# 18. not
#     core type: Literal
#     sub-expressions:
# 19. D
#     core type: Variable
#     sub-expressions:
