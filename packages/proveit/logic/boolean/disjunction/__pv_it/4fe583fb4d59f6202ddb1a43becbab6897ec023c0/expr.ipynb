# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import CC
from proveit.logic import Forall, Or
from proveit.logic._common_ import iterA1l, iterB1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Forall([CC], Or(iterA1l, iterB1m, iterC1n), conditions = [Or(iterA1l, Or(iterB1m), iterC1n)])
# Out:
# expr: forall_{C | A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C | A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n} (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> (A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n) | A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#    core type: Lambda
#    parameter: 23
#    body: 3
#    conditions: 4\n3. A_1 or  ...  or A_l or B_1 or  ...  or B_m or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A_1 ,  ...  , A_l , B_1 ,  ...  , B_m , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 8, 17, 10
# 6. A_1 or  ...  or A_l or (B_1 or  ...  or B_m) or C_1 or  ...  or C_n
#    core type: Operation
#    operator: 12
# ...
