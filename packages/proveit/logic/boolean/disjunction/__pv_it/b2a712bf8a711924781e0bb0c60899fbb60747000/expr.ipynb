# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, D, E
from proveit.logic import Booleans, InSet

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Booleans), InSet(B, Booleans), InSet(C, Booleans), InSet(D, Booleans), InSet(E, Booleans))
# Out:
# expr: (A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS , E in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS , E in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 6
# 2. B in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 7
# 3. C in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. D in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. E in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 12, 17
# 7. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 13, 17
# 8. (C , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 17
# 9. (D , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (E , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. C
#     core type: Variable
#     sub-expressions:
# 15. D
#     core type: Variable
#     sub-expressions:
# 16. E
#     core type: Variable
#     sub-expressions:
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
