# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, Not, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], A, domain = Booleans, conditions = [Or(A, B), Not(B)])
# Out:
# expr: forall_{A, B in BOOLEANS | A or B , [not](B)} A

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | A or B , [not](B)} A
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS | A or B , [not](B)} A] | A in BOOLEANS
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS | A or B , [not](B)} A
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> A | B in BOOLEANS , A or B , [not](B)
#    core type: Lambda
#    parameter: 19
#    body: 18
#    conditions: 7\n6. A in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. (B in BOOLEANS , A or B , [not](B))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 9. B in BOOLEANS
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. A or B
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. [not](B)
#     core type: Operation
#     operator: 16
#     operand: 19
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 14. or
#     core type: Literal
#     sub-expressions:
# 15. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. not
#     core type: Literal
#     sub-expressions:
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
