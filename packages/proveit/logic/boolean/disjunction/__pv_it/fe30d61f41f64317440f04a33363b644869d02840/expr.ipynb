# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E
from proveit.logic import Equals, Or

# %%
# build up the expression from sub-expressions
expr = Equals(Or(A, B, C, D, E), Or(E, A, B, C, D))
# Out:
# expr: (A or B or C or D or E) = (E or A or B or C or D)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A or B or C or D or E) = (E or A or B or C or D)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D or E , E or A or B or C or D)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A or B or C or D or E
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. E or A or B or C or D
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A , B , C , D , E)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 8
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (E , A , B , C , D)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12
# 8. E
#    core type: Variable
#    sub-expressions:
# 9. A
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. D
#     core type: Variable
#     sub-expressions:
