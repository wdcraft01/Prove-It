# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Implies, InSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(A, Booleans), InSet(B, Booleans), Or(A, B), InSet(C, Booleans), Implies(A, C), Implies(B, C))
# Out:
# expr: {A in BOOLEANS , B in BOOLEANS , A or B , C in BOOLEANS , A => C , B => C}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A in BOOLEANS , B in BOOLEANS , A or B , C in BOOLEANS , A => C , B => C}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A in BOOLEANS , B in BOOLEANS , A or B , C in BOOLEANS , A => C , B => C)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 9
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 10
# 5. A or B
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. C in BOOLEANS
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. A => C
#    core type: Operation
#    operator: 16
#    operands: 15
# 8. B => C
#    core type: Operation
#    operator: 16
#    operands: 17
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 19, 18
# 10. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A , B)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (C , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 15. (A , C)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (B , C)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
# 21. C
#     core type: Variable
#     sub-expressions:
