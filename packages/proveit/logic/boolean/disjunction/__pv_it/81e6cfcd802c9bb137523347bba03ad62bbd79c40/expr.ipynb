# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m
from proveit.logic import FALSE, Not, Or
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, FALSE, conditions = [Or(iterA1m), Iter(i, Not(Indexed(AA, i, base = 1)), one, m)])
# Out:
# expr: A -> FALSE | A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> FALSE | A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m)
#    core type: Lambda
#    parameter: 18
#    body: 1
#    conditions: 2\n1. FALSE
#    core type: Literal
#    sub-expressions:
# 2. (A_1 or  ...  or A_m , [not](A_1) ,  ...  , [not](A_m))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_1 or  ...  or A_m
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. [not](A_1),...,[not](A_m)
#    core type: Iter
#    lambda_map: 7
#    start_index: 27
#    end_index: 28
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. i -> [not](A_i) | i in {1...m}
#    core type: Lambda
#    parameter: 20
#    body: 9
#    conditions: 10\n8. A_1,...,A_m
#    core type: Iter
#    lambda_map: 11
#    start_index: 27
#    end_index: 28
# 9. [not](A_i)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 14
# 11. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 23
#     body: 15
#     conditions: 16\n12. not
#     core type: Literal
#     sub-expressions:
# 13. A_i
#     core type: Indexed
#     var: 18
#     index: 20
#     base: "1"
# 14. i in {1...m}
#     core type: Operation
#     operator: 21
#     operands: 17
# 15. A__x_
#     core type: Indexed
#     var: 18
#     index: 23
#     base: "1"
# 16. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 20, 24
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. _x_ in {1...m}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. i
#     core type: Variable
#     sub-expressions:
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. _x_
#     core type: Variable
#     sub-expressions:
# 24. {1...m}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. m
#     core type: Variable
#     sub-expressions:
