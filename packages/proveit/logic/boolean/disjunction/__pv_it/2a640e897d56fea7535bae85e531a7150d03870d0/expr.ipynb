# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E, F, G, H, I
from proveit.logic import Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(A, B, C, D, E, F, G, H, I))
# Out:
# expr: {A or B or C or D or E or F or G or H or I}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A or B or C or D or E or F or G or H or I}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A or B or C or D or E or F or G or H or I)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. A or B or C or D or E or F or G or H or I
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A , B , C , D , E , F , G , H , I)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11, 12, 13, 14
# 6. A
#    core type: Variable
#    sub-expressions:
# 7. B
#    core type: Variable
#    sub-expressions:
# 8. C
#    core type: Variable
#    sub-expressions:
# 9. D
#    core type: Variable
#    sub-expressions:
# 10. E
#     core type: Variable
#     sub-expressions:
# 11. F
#     core type: Variable
#     sub-expressions:
# 12. G
#     core type: Variable
#     sub-expressions:
# 13. H
#     core type: Variable
#     sub-expressions:
# 14. I
#     core type: Variable
#     sub-expressions:
