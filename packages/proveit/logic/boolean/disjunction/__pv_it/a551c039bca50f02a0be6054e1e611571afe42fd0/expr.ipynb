# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#unaryDisjunctionLemma">unaryDisjunctionLemma</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import unaryDisjunctionLemma

# %%
# check that the built expression is the same as the stored expression
# %check_expr unaryDisjunctionLemma
# Out:
# Passed sanity check: built 'unaryDisjunctionLemma' is the same as the stored Expression.

# %%
# display the expression information
unaryDisjunctionLemma.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} ([or](A) = (FALSE or A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ([or](A) = (FALSE or A)) | A in BOOLEANS
#    core type: Lambda
#    parameter: 17
#    body: 3
#    conditions: 4\n3. [or](A) = (FALSE or A)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ([or](A) , FALSE or A)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. [or](A)
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. FALSE or A
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. (A)
#     core type: ExprTuple
# ...
