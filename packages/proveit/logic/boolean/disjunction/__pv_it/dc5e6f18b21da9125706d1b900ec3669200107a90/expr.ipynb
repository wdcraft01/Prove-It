# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, CC
from proveit.logic import And, Booleans, Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n

# %%
# build up the expression from sub-expressions
expr = Forall([B, CC], InSet(B, Booleans), conditions = [InSet(And(iterA1m, B, iterC1n), Booleans)])
# Out:
# expr: forall_{B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B, C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. B -> [forall_{C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{C | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS} (B in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. C -> (B in BOOLEANS) | (A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS
#    core type: Lambda
#    parameter: 25
#    body: 5
#    conditions: 6\n5. B in BOOLEANS
#    core type: Operation
#    operator: 28
#    operands: 7
# 6. ((A_1 and  ...  and A_m and B and C_1 and  ...  and C_n) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# ...
