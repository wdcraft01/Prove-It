# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Forall, Implies, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Forall([C, D], Or(Not(A), Not(B)), domain = Booleans, conditions = [Or(Not(C), Not(D)), Implies(A, C), Implies(B, D)]), conditions = [InSet(B, Booleans)])
# Out:
# expr: B -> [forall_{C, D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))] | B in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> [forall_{C, D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))] | B in BOOLEANS
#    core type: Lambda
#    parameter: 32
#    body: 1
#    conditions: 2\n1. forall_{C, D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. C -> [forall_{D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))] | C in BOOLEANS
#    core type: Lambda
#    parameter: 33
#    body: 5
#    conditions: 6\n4. B in BOOLEANS
#    core type: Operation
#    operator: 21
#    operands: 7
# 5. forall_{D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (C in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 32, 28
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. D -> ([not](A) or [not](B)) | D in BOOLEANS , [not](C) or [not](D) , A => C , B => D
#    core type: Lambda
#    parameter: 35
#    body: 11
#    conditions: 12\n10. C in BOOLEANS
#     core type: Operation
#     operator: 21
#     operands: 13
# 11. [not](A) or [not](B)
#     core type: Operation
#     operator: 23
#     operands: 14
# 12. (D in BOOLEANS , [not](C) or [not](D) , A => C , B => D)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 13. (C , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 33, 28
# 14. ([not](A) , [not](B))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. D in BOOLEANS
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. [not](C) or [not](D)
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. A => C
#     core type: Operation
#     operator: 26
#     operands: 25
# 18. B => D
#     core type: Operation
#     operator: 26
#     operands: 27
# 19. [not](A)
#     core type: Operation
#     operator: 34
#     operand: 31
# 20. [not](B)
#     core type: Operation
#     operator: 34
#     operand: 32
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 35, 28
# 23. or
#     core type: Literal
#     sub-expressions:
# 24. ([not](C) , [not](D))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. (A , C)
#     core type: ExprTuple
#     sub-expressions: 31, 33
# 26. =>
#     core type: Literal
#     sub-expressions:
# 27. (B , D)
#     core type: ExprTuple
#     sub-expressions: 32, 35
# 28. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 29. [not](C)
#     core type: Operation
#     operator: 34
#     operand: 33
# 30. [not](D)
#     core type: Operation
#     operator: 34
#     operand: 35
# 31. A
#     core type: Variable
#     sub-expressions:
# 32. B
#     core type: Variable
#     sub-expressions:
# 33. C
#     core type: Variable
#     sub-expressions:
# 34. not
#     core type: Literal
#     sub-expressions:
# 35. D
#     core type: Variable
#     sub-expressions:
