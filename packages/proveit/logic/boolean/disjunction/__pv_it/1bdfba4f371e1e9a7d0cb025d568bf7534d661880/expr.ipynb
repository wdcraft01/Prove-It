# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, C, D
from proveit.logic import Booleans, Forall, Implies, Or

# %%
# build up the expression from sub-expressions
expr = Forall([D], Or(C, D), domain = Booleans, conditions = [Implies(B, D)])
# Out:
# expr: forall_{D in BOOLEANS | B => D} (C or D)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{D in BOOLEANS | B => D} (C or D)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. D -> (C or D) | D in BOOLEANS , B => D
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. C or D
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (D in BOOLEANS , B => D)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (C , D)
#    core type: ExprTuple
#    sub-expressions: 9, 16
# 7. D in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. B => D
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (B , D)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. D
#     core type: Variable
#     sub-expressions:
