# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.logic import And, Booleans, FALSE, Forall, Not, Or
from proveit.logic.boolean.negation._theorems_ import notFalse

# %%
# build up the expression from sub-expressions
expr = Forall([B], Or(FALSE, B), domain = Booleans, conditions = [Not(And(notFalse.expr, Not(B)))])
# Out:
# expr: forall_{B in BOOLEANS | [not]([not](FALSE) and [not](B))} (FALSE or B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS | [not]([not](FALSE) and [not](B))} (FALSE or B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (FALSE or B) | B in BOOLEANS , [not]([not](FALSE) and [not](B))
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. FALSE or B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B in BOOLEANS , [not]([not](FALSE) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (FALSE , B)
#    core type: ExprTuple
#    sub-expressions: 17, 19
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [not]([not](FALSE) and [not](B))
#    core type: Operation
#    operator: 18
#    operand: 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19, 12
# 11. [not](FALSE) and [not](B)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. and
#     core type: Literal
#     sub-expressions:
# 14. ([not](FALSE) , [not](B))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. [not](FALSE)
#     core type: Operation
#     operator: 18
#     operand: 17
# 16. [not](B)
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. FALSE
#     core type: Literal
#     sub-expressions:
# 18. not
#     core type: Literal
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
