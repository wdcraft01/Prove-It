# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#demorgansLawAndToOrBinExplicit">demorgansLawAndToOrBinExplicit</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import demorgansLawAndToOrBinExplicit

# %%
# check that the built expression is the same as the stored expression
# %check_expr demorgansLawAndToOrBinExplicit
# Out:
# Passed sanity check: built 'demorgansLawAndToOrBinExplicit' is the same as the stored Expression.

# %%
# display the expression information
demorgansLawAndToOrBinExplicit.exprInfo()
# Out:
# 0. forall_{A, B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 22
#    body: 2
#    conditions: 3\n2. forall_{B in BOOLEANS | [not]([not](A) and [not](B))} (A or B)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. B -> (A or B) | B in BOOLEANS , [not]([not](A) and [not](B))
#    core type: Lambda
#    parameter: 24
#    body: 7
#    conditions: 8\n6. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (B in BOOLEANS , [not]([not](A) and [not](B)))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 22, 17
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 12. B in BOOLEANS
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. [not]([not](A) and [not](B))
#     core type: Operation
#     operator: 23
#     operand: 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24, 17
# 16. [not](A) and [not](B)
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. ([not](A) , [not](B))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. [not](A)
#     core type: Operation
#     operator: 23
#     operand: 22
# 21. [not](B)
#     core type: Operation
#     operator: 23
#     operand: 24
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. not
#     core type: Literal
#     sub-expressions:
# 24. B
#     core type: Variable
#     sub-expressions:
