# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, BB, C, DD, l, m, n
from proveit.logic import Booleans, Equals, Forall, Or
from proveit.logic._common_ import iterA1l, iterB1m, iterD1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([m, n], Forall([AA, BB, C, DD], Equals(Or(iterA1l, iterB1m, C, iterD1n), Or(iterA1l, C, iterB1m, iterD1n)), domains = [Exp(Booleans, l), Exp(Booleans, m), Booleans, Exp(Booleans, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1)
# Out:
# expr: forall_{m, n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))]
#    core type: Operation
#    operator: 27
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))]] | m in Naturals
#    core type: Lambda
#    parameter: 80
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{(A, B, C, D) in BOOLEANS^{l} * BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n}} ((A_1 or  ...  or A_l or B_1 or  ...  or B_m or C or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C or B_1 or  ...  or B_m or D_1 or  ...  or D_n))]
#    core type: Operation
#    operator: 27
#    operand: 4
# ...
