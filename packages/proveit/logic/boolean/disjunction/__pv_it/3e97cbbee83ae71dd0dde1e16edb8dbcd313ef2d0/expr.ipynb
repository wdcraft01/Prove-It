# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, BB, i, m
from proveit.logic import Booleans, Forall, Implies, InSet, Not, Or
from proveit.number import Exp, one

# %%
# build up the expression from sub-expressions
subExpr1 = Indexed(BB, i, base = 1)
subExpr2 = Indexed(AA, i, base = 1)
subExpr3 = Exp(Booleans, m)
expr = Lambda(AA, Forall([BB], Or(Iter(i, Not(subExpr1), one, m)), domain = subExpr3, conditions = [Iter(i, Implies(subExpr2, subExpr1), one, m)]), conditions = [InSet(AA, subExpr3), Or(Iter(i, Not(subExpr2), one, m))])
# Out:
# expr: A -> [forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} ([not](B_1) or  ...  or [not](B_m))] | A in BOOLEANS^{m} , [not](A_1) or  ...  or [not](A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} ([not](B_1) or  ...  or [not](B_m))] | A in BOOLEANS^{m} , [not](A_1) or  ...  or [not](A_m)
#    core type: Lambda
#    parameter: 37
#    body: 1
#    conditions: 2\n1. forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} ([not](B_1) or  ...  or [not](B_m))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in BOOLEANS^{m} , [not](A_1) or  ...  or [not](A_m))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ([not](B_1) or  ...  or [not](B_m)) | B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m
#    core type: Lambda
#    parameter: 38
#    body: 7
#    conditions: 8\n5. A in BOOLEANS^{m}
#    core type: Operation
#    operator: 35
#    operands: 9
# 6. [not](A_1) or  ...  or [not](A_m)
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. [not](B_1) or  ...  or [not](B_m)
#    core type: Operation
# ...
