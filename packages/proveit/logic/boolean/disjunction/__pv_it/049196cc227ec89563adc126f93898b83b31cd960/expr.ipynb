# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D, E, F, G, H
from proveit.logic import Booleans, InSet, Set

# %%
# build up the expression from sub-expressions
expr = Set(InSet(A, Booleans), InSet(B, Booleans), InSet(C, Booleans), InSet(D, Booleans), InSet(E, Booleans), InSet(F, Booleans), InSet(G, Booleans), InSet(H, Booleans))
# Out:
# expr: {A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS , E in BOOLEANS , F in BOOLEANS , G in BOOLEANS , H in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS , E in BOOLEANS , F in BOOLEANS , G in BOOLEANS , H in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS , E in BOOLEANS , F in BOOLEANS , G in BOOLEANS , H in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8, 9, 10
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 11
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 12
# 5. C in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 13
# 6. D in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 14
# 7. E in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 15
# 8. F in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 16
# 9. G in BOOLEANS
#    core type: Operation
# ...
