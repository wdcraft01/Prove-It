# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g, h
from proveit.logic import Forall, InSet
from proveit.number import Exp, eight

# %%
# build up the expression from sub-expressions
expr = Forall([c, d, e, f, g, h], InSet([a, b, c, d, e, f, g, h], Exp(S, eight)), domain = S, conditions = [])
# Out:
# expr: forall_{c, d, e, f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c, d, e, f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 24
#    operand: 1
# 1. c -> [forall_{d, e, f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | c in S
#    core type: Lambda
#    parameter: 38
#    body: 2
#    conditions: 3\n2. forall_{d, e, f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 24
#    operand: 4
# 3. (c in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. d -> [forall_{e, f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | d in S
#    core type: Lambda
#    parameter: 39
#    body: 6
#    conditions: 7\n5. c in S
#    core type: Operation
#    operator: 34
#    operands: 8
# 6. forall_{e, f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 24
#    operand: 9
# 7. (d in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (c , S)
#    core type: ExprTuple
#    sub-expressions: 38, 46
# 9. e -> [forall_{f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | e in S
#    core type: Lambda
#    parameter: 40
#    body: 11
#    conditions: 12\n10. d in S
#     core type: Operation
#     operator: 34
#     operands: 13
# 11. forall_{f, g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#     core type: Operation
#     operator: 24
#     operand: 14
# 12. (e in S)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (d , S)
#     core type: ExprTuple
#     sub-expressions: 39, 46
# 14. f -> [forall_{g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | f in S
#     core type: Lambda
#     parameter: 41
#     body: 16
#     conditions: 17\n15. e in S
#     core type: Operation
#     operator: 34
#     operands: 18
# 16. forall_{g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#     core type: Operation
#     operator: 24
#     operand: 19
# 17. (f in S)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (e , S)
#     core type: ExprTuple
#     sub-expressions: 40, 46
# 19. g -> [forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | g in S
#     core type: Lambda
#     parameter: 42
#     body: 21
#     conditions: 22\n20. f in S
#     core type: Operation
#     operator: 34
#     operands: 23
# 21. forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#     core type: Operation
#     operator: 24
#     operand: 25
# 22. (g in S)
#     core type: ExprTuple
#     sub-expressions: 26
# 23. (f , S)
#     core type: ExprTuple
#     sub-expressions: 41, 46
# 24. forall
#     core type: Literal
#     sub-expressions:
# 25. h -> ((a , b , c , d , e , f , g , h) in S^{8}) | h in S
#     core type: Lambda
#     parameter: 45
#     body: 27
#     conditions: 28\n26. g in S
#     core type: Operation
#     operator: 34
#     operands: 29
# 27. (a , b , c , d , e , f , g , h) in S^{8}
#     core type: Operation
#     operator: 34
#     operands: 30
# 28. (h in S)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. (g , S)
#     core type: ExprTuple
#     sub-expressions: 42, 46
# 30. ((a , b , c , d , e , f , g , h) , S^{8})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. h in S
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (a , b , c , d , e , f , g , h)
#     core type: ExprTuple
#     sub-expressions: 36, 37, 38, 39, 40, 41, 42, 45
# 33. S^{8}
#     core type: Operation
#     operator: 43
#     operands: 44
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (h , S)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. b
#     core type: Variable
#     sub-expressions:
# 38. c
#     core type: Variable
#     sub-expressions:
# 39. d
#     core type: Variable
#     sub-expressions:
# 40. e
#     core type: Variable
#     sub-expressions:
# 41. f
#     core type: Variable
#     sub-expressions:
# 42. g
#     core type: Variable
#     sub-expressions:
# 43. Exp
#     core type: Literal
#     sub-expressions:
# 44. (S , 8)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. h
#     core type: Variable
#     sub-expressions:
# 46. S
#     core type: Variable
#     sub-expressions:
# 47. 8
#     core type: Literal
#     sub-expressions:
