# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, m
from proveit.logic import Equals, FALSE, InSet, Or, Set
from proveit.logic._common_ import iterA1m
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, Equals(Or(iterA1m), FALSE), conditions = [InSet(AA, Exp(Set(FALSE), m))])
# Out:
# expr: A -> ((A_1 or  ...  or A_m) = FALSE) | A in {FALSE}^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> ((A_1 or  ...  or A_m) = FALSE) | A in {FALSE}^{m}
#    core type: Lambda
#    parameter: 20
#    body: 1
#    conditions: 2\n1. (A_1 or  ...  or A_m) = FALSE
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in {FALSE}^{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_1 or  ...  or A_m , FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 22
# 5. A in {FALSE}^{m}
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. A_1 or  ...  or A_m
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (A , {FALSE}^{m})
#    core type: ExprTuple
#    sub-expressions: 20, 10
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. {FALSE}^{m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. A_1,...,A_m
#     core type: Iter
#     lambda_map: 14
#     start_index: 29
#     end_index: 30
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. ({FALSE} , m)
#     core type: ExprTuple
#     sub-expressions: 15, 30
# 14. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 25
#     body: 16
#     conditions: 17\n15. {FALSE}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. A__x_
#     core type: Indexed
#     var: 20
#     index: 25
#     base: "1"
# 17. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 21
# 18. Set
#     core type: Literal
#     sub-expressions:
# 19. (FALSE)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. _x_ in {1...m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. FALSE
#     core type: Literal
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. _x_
#     core type: Variable
#     sub-expressions:
# 26. {1...m}
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. Interval
#     core type: Literal
#     sub-expressions:
# 28. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. m
#     core type: Variable
#     sub-expressions:
