# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B
from proveit.logic import Equals, Or
from proveit.logic._common_ import iterA1l, iterC1m, iterD1n

# %%
# build up the expression from sub-expressions
expr = Equals(Or(iterA1l, B, iterC1m, iterD1n), Or(iterA1l, iterC1m, B, iterD1n))
# Out:
# expr: (A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n) = (A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n , A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A_1 or  ...  or A_l or B or C_1 or  ...  or C_m or D_1 or  ...  or D_n
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. A_1 or  ...  or A_l or C_1 or  ...  or C_m or B or D_1 or  ...  or D_n
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A_1 ,  ...  , A_l , B , C_1 ,  ...  , C_m , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 8, 10, 9, 11
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (A_1 ,  ...  , A_l , C_1 ,  ...  , C_m , B , D_1 ,  ...  , D_n)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. A_1,...,A_l
#    core type: Iter
#    lambda_map: 12
#    start_index: 41
#    end_index: 39
# 9. C_1,...,C_m
#    core type: Iter
#    lambda_map: 13
#    start_index: 41
#    end_index: 40
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. D_1,...,D_n
#     core type: Iter
#     lambda_map: 14
#     start_index: 41
#     end_index: 42
# 12. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 33
#     body: 15
#     conditions: 16\n13. _x_ -> C__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 33
#     body: 17
#     conditions: 18\n14. _x_ -> D__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 33
#     body: 19
#     conditions: 20\n15. A__x_
#     core type: Indexed
#     var: 21
#     index: 33
#     base: "1"
# 16. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. C__x_
#     core type: Indexed
#     var: 23
#     index: 33
#     base: "1"
# 18. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. D__x_
#     core type: Indexed
#     var: 25
#     index: 33
#     base: "1"
# 20. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 26
# 21. A
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...l}
#     core type: Operation
#     operator: 29
#     operands: 27
# 23. C
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...m}
#     core type: Operation
#     operator: 29
#     operands: 28
# 25. D
#     core type: Variable
#     sub-expressions:
# 26. _x_ in {1...n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 28. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 33, 32
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. {1...l}
#     core type: Operation
#     operator: 37
#     operands: 35
# 32. {1...m}
#     core type: Operation
#     operator: 37
#     operands: 36
# 33. _x_
#     core type: Variable
#     sub-expressions:
# 34. {1...n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 35. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 41, 39
# 36. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 41, 40
# 37. Interval
#     core type: Literal
#     sub-expressions:
# 38. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. l
#     core type: Variable
#     sub-expressions:
# 40. m
#     core type: Variable
#     sub-expressions:
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. n
#     core type: Variable
#     sub-expressions:
