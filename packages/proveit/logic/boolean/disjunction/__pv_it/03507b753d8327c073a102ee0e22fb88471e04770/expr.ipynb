# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import AA, m
from proveit.logic import Booleans, InSet, Or
from proveit.logic._common_ import iterA1m
from proveit.number import Exp

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(AA, Exp(Booleans, m)), Or(iterA1m))
# Out:
# expr: (A in BOOLEANS^{m} , A_1 or  ...  or A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS^{m} , A_1 or  ...  or A_m)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. A in BOOLEANS^{m}
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. A_1 or  ...  or A_m
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A , BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 14, 6
# 4. or
#    core type: Literal
#    sub-expressions:
# 5. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. BOOLEANS^{m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. A_1,...,A_m
#    core type: Iter
#    lambda_map: 10
#    start_index: 22
#    end_index: 23
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (BOOLEANS , m)
#    core type: ExprTuple
#    sub-expressions: 11, 23
# 10. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 18
#     body: 12
#     conditions: 13\n11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. A__x_
#     core type: Indexed
#     var: 14
#     index: 18
#     base: "1"
# 13. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. _x_ in {1...m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. _x_
#     core type: Variable
#     sub-expressions:
# 19. {1...m}
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. m
#     core type: Variable
#     sub-expressions:
