# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, BB
from proveit.logic import Equals, Forall, Or
from proveit.logic._common_ import iterB1n

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([BB], Equals(Or(iterB1n, A), Or(Or(iterB1n), A)), conditions = []))
# Out:
# expr: A -> [forall_{B} ((B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B} ((B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A))]
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. forall_{B} ((B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A))
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. B -> ((B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A))
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. (B_1 or  ...  or B_n or A) = ((B_1 or  ...  or B_n) or A)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (B_1 or  ...  or B_n or A , (B_1 or  ...  or B_n) or A)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. B_1 or  ...  or B_n or A
#    core type: Operation
#    operator: 13
#    operands: 9
# 8. (B_1 or  ...  or B_n) or A
#    core type: Operation
#    operator: 13
#    operands: 10
# 9. (B_1 ,  ...  , B_n , A)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. (B_1 or  ...  or B_n , A)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. B_1 or  ...  or B_n
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (B_1 ,  ...  , B_n)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. B_1,...,B_n
#     core type: Iter
#     lambda_map: 16
#     start_index: 27
#     end_index: 28
# 16. _x_ -> B__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 23
#     body: 17
#     conditions: 18\n17. B__x_
#     core type: Indexed
#     var: 19
#     index: 23
#     base: "1"
# 18. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...n}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. _x_
#     core type: Variable
#     sub-expressions:
# 24. {1...n}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
