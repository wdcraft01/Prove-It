# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import C
from proveit.logic import Booleans, Forall, InSet, Or
from proveit.number import Exp, four, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([C], InSet(Or(Iter(subExpr1, Indexed(C, subExpr1, base = 1), one, four)), Booleans), domain = Exp(Booleans, four), conditions = [])
# Out:
# expr: forall_{C in BOOLEANS^{4}} ((C_1 or  ...  or C_4) in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C in BOOLEANS^{4}} ((C_1 or  ...  or C_4) in BOOLEANS)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> ((C_1 or  ...  or C_4) in BOOLEANS) | C in BOOLEANS^{4}
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. (C_1 or  ...  or C_4) in BOOLEANS
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (C in BOOLEANS^{4})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (C_1 or  ...  or C_4 , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7, 16
# 6. C in BOOLEANS^{4}
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. C_1 or  ...  or C_4
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (C , BOOLEANS^{4})
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (C_1 ,  ...  , C_4)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. BOOLEANS^{4}
# ...
