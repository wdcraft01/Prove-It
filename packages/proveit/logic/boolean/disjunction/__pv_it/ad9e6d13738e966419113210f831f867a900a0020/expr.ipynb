# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Implies, InSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(A, B), InSet(B, Booleans), Implies(A, C), Implies(B, C), InSet(A, Booleans))
# Out:
# expr: {A or B , B in BOOLEANS , A => C , B => C , A in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {A or B , B in BOOLEANS , A => C , B => C , A in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (A or B , B in BOOLEANS , A => C , B => C , A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7
# 3. A or B
#    core type: Operation
#    operator: 8
#    operands: 9
# 4. B in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 10
# 5. A => C
#    core type: Operation
#    operator: 12
#    operands: 11
# 6. B => C
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (A , B)
#    core type: ExprTuple
#    sub-expressions: 18, 16
# 10. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 16, 19
# 11. (A , C)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 12. =>
#     core type: Literal
#     sub-expressions:
# 13. (B , C)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. B
#     core type: Variable
#     sub-expressions:
# 17. C
#     core type: Variable
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. BOOLEANS
#     core type: Literal
#     sub-expressions:
