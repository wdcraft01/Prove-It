# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Forall, Implies, Not, Or

# %%
# build up the expression from sub-expressions
expr = Forall([C, D], Or(Not(A), Not(B)), domain = Booleans, conditions = [Or(Not(C), Not(D)), Implies(A, C), Implies(B, D)])
# Out:
# expr: forall_{C, D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C, D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. C -> [forall_{D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))] | C in BOOLEANS
#    core type: Lambda
#    parameter: 29
#    body: 2
#    conditions: 3\n2. forall_{D in BOOLEANS | [not](C) or [not](D) , A => C , B => D} ([not](A) or [not](B))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (C in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. D -> ([not](A) or [not](B)) | D in BOOLEANS , [not](C) or [not](D) , A => C , B => D
#    core type: Lambda
#    parameter: 31
#    body: 7
#    conditions: 8\n6. C in BOOLEANS
#    core type: Operation
#    operator: 17
#    operands: 9
# 7. [not](A) or [not](B)
#    core type: Operation
#    operator: 19
#    operands: 10
# 8. (D in BOOLEANS , [not](C) or [not](D) , A => C , B => D)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. (C , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 29, 24
# 10. ([not](A) , [not](B))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. D in BOOLEANS
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. [not](C) or [not](D)
#     core type: Operation
#     operator: 19
#     operands: 20
# 13. A => C
#     core type: Operation
#     operator: 22
#     operands: 21
# 14. B => D
#     core type: Operation
#     operator: 22
#     operands: 23
# 15. [not](A)
#     core type: Operation
#     operator: 30
#     operand: 27
# 16. [not](B)
#     core type: Operation
#     operator: 30
#     operand: 28
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 31, 24
# 19. or
#     core type: Literal
#     sub-expressions:
# 20. ([not](C) , [not](D))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 21. (A , C)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 22. =>
#     core type: Literal
#     sub-expressions:
# 23. (B , D)
#     core type: ExprTuple
#     sub-expressions: 28, 31
# 24. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 25. [not](C)
#     core type: Operation
#     operator: 30
#     operand: 29
# 26. [not](D)
#     core type: Operation
#     operator: 30
#     operand: 31
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. B
#     core type: Variable
#     sub-expressions:
# 29. C
#     core type: Variable
#     sub-expressions:
# 30. not
#     core type: Literal
#     sub-expressions:
# 31. D
#     core type: Variable
#     sub-expressions:
