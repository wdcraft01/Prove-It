# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Exp, four

# %%
# build up the expression from sub-expressions
expr = Forall([d], InSet([a, b, c, d], Exp(S, four)), domain = S, conditions = [])
# Out:
# expr: forall_{d in S} ((a , b , c , d) in S^{4})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{d in S} ((a , b , c , d) in S^{4})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. d -> ((a , b , c , d) in S^{4}) | d in S
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. (a , b , c , d) in S^{4}
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (d in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((a , b , c , d) , S^{4})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. d in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (a , b , c , d)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 16
# 8. S^{4}
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (d , S)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (S , 4)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. d
#     core type: Variable
#     sub-expressions:
# 17. S
#     core type: Variable
#     sub-expressions:
# 18. 4
#     core type: Literal
#     sub-expressions:
