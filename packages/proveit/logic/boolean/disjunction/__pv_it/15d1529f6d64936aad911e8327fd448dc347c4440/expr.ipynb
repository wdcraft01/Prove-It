# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#constructiveMultiDilemma">constructiveMultiDilemma</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import constructiveMultiDilemma

# %%
# check that the built expression is the same as the stored expression
# %check_expr constructiveMultiDilemma
# Out:
# Passed sanity check: built 'constructiveMultiDilemma' is the same as the stored Expression.

# %%
# display the expression information
constructiveMultiDilemma.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{A, B in BOOLEANS^{m} | A_1 or  ...  or A_m , A_1 => B_1 ,  ...  , A_m => B_m} (B_1 or  ...  or B_m)]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. m -> [forall_{A, B in BOOLEANS^{m} | A_1 or  ...  or A_m , A_1 => B_1 ,  ...  , A_m => B_m} (B_1 or  ...  or B_m)] | m in Naturals
#    core type: Lambda
#    parameter: 54
#    body: 2
#    conditions: 3\n2. forall_{A, B in BOOLEANS^{m} | A_1 or  ...  or A_m , A_1 => B_1 ,  ...  , A_m => B_m} (B_1 or  ...  or B_m)
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. A -> [forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} (B_1 or  ...  or B_m)] | A in BOOLEANS^{m} , A_1 or  ...  or A_m
#    core type: Lambda
#    parameter: 46
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 44
#    operands: 8
# 6. forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} (B_1 or  ...  or B_m)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (A in BOOLEANS^{m} , A_1 or  ...  or A_m)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 54, 13
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. B -> (B_1 or  ...  or B_m) | B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m
#     core type: Lambda
#     parameter: 47
#     body: 14
#     conditions: 15\n11. A in BOOLEANS^{m}
#     core type: Operation
#     operator: 44
#     operands: 16
# 12. A_1 or  ...  or A_m
#     core type: Operation
#     operator: 18
#     operands: 17
# 13. Naturals
#     core type: Literal
#     sub-expressions:
# 14. B_1 or  ...  or B_m
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. (A , BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 46, 28
# 17. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. or
#     core type: Literal
#     sub-expressions:
# 19. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 23
# 20. B in BOOLEANS^{m}
#     core type: Operation
#     operator: 44
#     operands: 24
# 21. (A_1 => B_1),...,(A_m => B_m)
#     core type: Iter
#     lambda_map: 25
#     start_index: 53
#     end_index: 54
# 22. A_1,...,A_m
#     core type: Iter
#     lambda_map: 26
#     start_index: 53
#     end_index: 54
# 23. B_1,...,B_m
#     core type: Iter
#     lambda_map: 27
#     start_index: 53
#     end_index: 54
# 24. (B , BOOLEANS^{m})
#     core type: ExprTuple
#     sub-expressions: 47, 28
# 25. i -> (A_i => B_i) | i in {1...m}
#     core type: Lambda
#     parameter: 48
#     body: 29
#     conditions: 30\n26. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 49
#     body: 31
#     conditions: 33\n27. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 49
#     body: 32
#     conditions: 33\n28. BOOLEANS^{m}
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. A_i => B_i
#     core type: Operation
#     operator: 36
#     operands: 37
# 30. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 38
# 31. A__x_
#     core type: Indexed
#     var: 46
#     index: 49
#     base: "1"
# 32. B__x_
#     core type: Indexed
#     var: 47
#     index: 49
#     base: "1"
# 33. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 39
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (BOOLEANS , m)
#     core type: ExprTuple
#     sub-expressions: 40, 54
# 36. =>
#     core type: Literal
#     sub-expressions:
# 37. (A_i , B_i)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. i in {1...m}
#     core type: Operation
#     operator: 44
#     operands: 43
# 39. _x_ in {1...m}
#     core type: Operation
#     operator: 44
#     operands: 45
# 40. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 41. A_i
#     core type: Indexed
#     var: 46
#     index: 48
#     base: "1"
# 42. B_i
#     core type: Indexed
#     var: 47
#     index: 48
#     base: "1"
# 43. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 48, 50
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 46. A
#     core type: Variable
#     sub-expressions:
# 47. B
#     core type: Variable
#     sub-expressions:
# 48. i
#     core type: Variable
#     sub-expressions:
# 49. _x_
#     core type: Variable
#     sub-expressions:
# 50. {1...m}
#     core type: Operation
#     operator: 51
#     operands: 52
# 51. Interval
#     core type: Literal
#     sub-expressions:
# 52. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. m
#     core type: Variable
#     sub-expressions:
