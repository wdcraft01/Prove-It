# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, C, i, m
from proveit.logic import Booleans, Forall, Implies, InSet, Or
from proveit.logic._common_ import iterA1m
from proveit.number import Exp, Naturals, one

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([AA], Forall([C], C, conditions = [Iter(i, Implies(Indexed(AA, i, base = 1), C), one, m)]), domain = Exp(Booleans, m), conditions = [Or(iterA1m)]), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{A in BOOLEANS^{m} | A_1 or  ...  or A_m} [forall_{C | A_1 => C ,  ...  , A_m => C} C]] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{A in BOOLEANS^{m} | A_1 or  ...  or A_m} [forall_{C | A_1 => C ,  ...  , A_m => C} C]] | m in Naturals
#    core type: Lambda
#    parameter: 45
#    body: 1
#    conditions: 2\n1. forall_{A in BOOLEANS^{m} | A_1 or  ...  or A_m} [forall_{C | A_1 => C ,  ...  , A_m => C} C]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. A -> [forall_{C | A_1 => C ,  ...  , A_m => C} C] | A in BOOLEANS^{m} , A_1 or  ...  or A_m
#    core type: Lambda
#    parameter: 38
#    body: 5
#    conditions: 6\n4. m in Naturals
#    core type: Operation
#    operator: 36
#    operands: 7
# 5. forall_{C | A_1 => C ,  ...  , A_m => C} C
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (A in BOOLEANS^{m} , A_1 or  ...  or A_m)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 45, 12
# 8. forall
#    core type: Literal
# ...
