# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import AA, BB, i, m
from proveit.logic import Booleans, Implies, InSet
from proveit.number import Exp, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(BB, Exp(Booleans, m)), Iter(i, Implies(Indexed(AA, i, base = 1), Indexed(BB, i, base = 1)), one, m))
# Out:
# expr: (B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. B in BOOLEANS^{m}
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. (A_1 => B_1),...,(A_m => B_m)
#    core type: Iter
#    lambda_map: 4
#    start_index: 24
#    end_index: 25
# 3. (B , BOOLEANS^{m})
#    core type: ExprTuple
#    sub-expressions: 19, 5
# 4. i -> (A_i => B_i) | i in {1...m}
#    core type: Lambda
#    parameter: 20
#    body: 6
#    conditions: 7\n5. BOOLEANS^{m}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. A_i => B_i
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 12
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (BOOLEANS , m)
#    core type: ExprTuple
#    sub-expressions: 13, 25
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (A_i , B_i)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# ...
