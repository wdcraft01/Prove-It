# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, BB, i, m
from proveit.logic import Booleans, Forall, Implies, Not, Or
from proveit.number import Exp, one

# %%
# build up the expression from sub-expressions
subExpr1 = Indexed(BB, i, base = 1)
expr = Forall([BB], Or(Iter(i, Not(subExpr1), one, m)), domain = Exp(Booleans, m), conditions = [Iter(i, Implies(Indexed(AA, i, base = 1), subExpr1), one, m)])
# Out:
# expr: forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} ([not](B_1) or  ...  or [not](B_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in BOOLEANS^{m} | A_1 => B_1 ,  ...  , A_m => B_m} ([not](B_1) or  ...  or [not](B_m))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> ([not](B_1) or  ...  or [not](B_m)) | B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m
#    core type: Lambda
#    parameter: 29
#    body: 3
#    conditions: 4\n3. [not](B_1) or  ...  or [not](B_m)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B in BOOLEANS^{m} , A_1 => B_1 ,  ...  , A_m => B_m)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. ([not](B_1) ,  ...  , [not](B_m))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. B in BOOLEANS^{m}
#    core type: Operation
#    operator: 26
#    operands: 10
# 8. (A_1 => B_1),...,(A_m => B_m)
#    core type: Iter
#    lambda_map: 11
#    start_index: 34
#    end_index: 35
# 9. [not](B_1),...,[not](B_m)
#    core type: Iter
# ...
