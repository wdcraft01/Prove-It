# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import And, Booleans, InSet, Or

# %%
# build up the expression from sub-expressions
expr = InSet(And(A, B, Or(A, B, C, D)), Booleans)
# Out:
# expr: (A and B and (A or B or C or D)) in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A and B and (A or B or C or D)) in BOOLEANS
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (A and B and (A or B or C or D) , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A and B and (A or B or C or D)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A , B , A or B or C or D)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 7
# 7. A or B or C or D
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. or
#    core type: Literal
#    sub-expressions:
# 9. (A , B , C , D)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. B
#     core type: Variable
#     sub-expressions:
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. D
#     core type: Variable
#     sub-expressions:
