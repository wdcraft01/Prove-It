# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td>0</td><td>generalizaton</td><td>1</td><td><span style="font-size:20px;"> <a class="ProveItLink" href="proof.ipynb" style="text-decoration: none">&#x22A2;&nbsp;</a><a class="ProveItLink" href="../f979cfc1b658c41823f668f85654e0f5f421d65e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# <tr><td>1</td><td>specialization</td><td>2, 3, 4</td><td><span style="font-size:20px;"><a class="ProveItLink" href="../fb1e69792e12fa6dd01a639e1c1a817bb7412f080/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../1e9a6e1bb1fbe7ca88289f5de2afade1ba75b2250/proof.ipynb" style="text-decoration: none">&#x22A2;&nbsp;</a><a class="ProveItLink" href="../0f1bf4090acd92174180531bf3e50944b30066e50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# ...
