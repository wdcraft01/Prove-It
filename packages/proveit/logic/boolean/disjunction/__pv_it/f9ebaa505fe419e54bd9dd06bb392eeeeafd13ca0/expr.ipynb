# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C
from proveit.logic import Booleans, Implies, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Booleans), InSet(B, Booleans), Or(A, B), Implies(A, C), Implies(B, C), Not(C))
# Out:
# expr: (A in BOOLEANS , B in BOOLEANS , A or B , A => C , B => C , [not](C))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS , B in BOOLEANS , A or B , A => C , B => C , [not](C))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 7
# 2. B in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 3. A or B
#    core type: Operation
#    operator: 10
#    operands: 11
# 4. A => C
#    core type: Operation
#    operator: 13
#    operands: 12
# 5. B => C
#    core type: Operation
#    operator: 13
#    operands: 14
# 6. [not](C)
#    core type: Operation
#    operator: 15
#    operand: 19
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 17, 16
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 16
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 12. (A , C)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (B , C)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. not
#     core type: Literal
#     sub-expressions:
# 16. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. B
#     core type: Variable
#     sub-expressions:
# 19. C
#     core type: Variable
#     sub-expressions:
