# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Implies, InSet, Not, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(D, Or(Not(A), Not(B)), conditions = [InSet(D, Booleans), Or(Not(C), Not(D)), Implies(A, C), Implies(B, D)])
# Out:
# expr: D -> ([not](A) or [not](B)) | D in BOOLEANS , [not](C) or [not](D) , A => C , B => D

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. D -> ([not](A) or [not](B)) | D in BOOLEANS , [not](C) or [not](D) , A => C , B => D
#    core type: Lambda
#    parameter: 24
#    body: 1
#    conditions: 2\n1. [not](A) or [not](B)
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (D in BOOLEANS , [not](C) or [not](D) , A => C , B => D)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6, 7
# 3. ([not](A) , [not](B))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 4. D in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 5. [not](C) or [not](D)
#    core type: Operation
#    operator: 12
#    operands: 13
# 6. A => C
#    core type: Operation
#    operator: 15
#    operands: 14
# 7. B => D
#    core type: Operation
#    operator: 15
#    operands: 16
# 8. [not](A)
#    core type: Operation
#    operator: 23
#    operand: 20
# 9. [not](B)
#    core type: Operation
#    operator: 23
#    operand: 21
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24, 17
# 12. or
#     core type: Literal
#     sub-expressions:
# 13. ([not](C) , [not](D))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. (A , C)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 15. =>
#     core type: Literal
#     sub-expressions:
# 16. (B , D)
#     core type: ExprTuple
#     sub-expressions: 21, 24
# 17. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 18. [not](C)
#     core type: Operation
#     operator: 23
#     operand: 22
# 19. [not](D)
#     core type: Operation
#     operator: 23
#     operand: 24
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. C
#     core type: Variable
#     sub-expressions:
# 23. not
#     core type: Literal
#     sub-expressions:
# 24. D
#     core type: Variable
#     sub-expressions:
