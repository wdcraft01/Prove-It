# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m
from proveit.logic import And, Forall, Not, Or
from proveit.logic._common_ import iterA1m
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([AA], Or(iterA1m), conditions = [Not(And(Iter(i, Not(Indexed(AA, i, base = 1)), one, m)))])
# Out:
# expr: forall_{A | [not]([not](A_1) and  ...  and [not](A_m))} (A_1 or  ...  or A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A | [not]([not](A_1) and  ...  and [not](A_m))} (A_1 or  ...  or A_m)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> (A_1 or  ...  or A_m) | [not]([not](A_1) and  ...  and [not](A_m))
#    core type: Lambda
#    parameter: 25
#    body: 3
#    conditions: 4\n3. A_1 or  ...  or A_m
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. ([not]([not](A_1) and  ...  and [not](A_m)))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. [not]([not](A_1) and  ...  and [not](A_m))
#    core type: Operation
#    operator: 22
#    operand: 9
# 8. A_1,...,A_m
#    core type: Iter
#    lambda_map: 10
#    start_index: 32
#    end_index: 33
# 9. [not](A_1) and  ...  and [not](A_m)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 21
#     body: 13
#     conditions: 14\n11. and
#     core type: Literal
#     sub-expressions:
# 12. ([not](A_1) ,  ...  , [not](A_m))
#     core type: ExprTuple
#     sub-expressions: 15
# 13. A__x_
#     core type: Indexed
#     var: 25
#     index: 21
#     base: "1"
# 14. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 16
# 15. [not](A_1),...,[not](A_m)
#     core type: Iter
#     lambda_map: 17
#     start_index: 32
#     end_index: 33
# 16. _x_ in {1...m}
#     core type: Operation
#     operator: 26
#     operands: 18
# 17. i -> [not](A_i) | i in {1...m}
#     core type: Lambda
#     parameter: 28
#     body: 19
#     conditions: 20\n18. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 21, 29
# 19. [not](A_i)
#     core type: Operation
#     operator: 22
#     operand: 23
# 20. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. _x_
#     core type: Variable
#     sub-expressions:
# 22. not
#     core type: Literal
#     sub-expressions:
# 23. A_i
#     core type: Indexed
#     var: 25
#     index: 28
#     base: "1"
# 24. i in {1...m}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. A
#     core type: Variable
#     sub-expressions:
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. i
#     core type: Variable
#     sub-expressions:
# 29. {1...m}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. m
#     core type: Variable
#     sub-expressions:
