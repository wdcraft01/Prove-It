# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Implies, InSet, Not, Or, Set

# %%
# build up the expression from sub-expressions
expr = Set(Or(Not(C), Not(D)), Implies(A, C), Implies(B, D), InSet(A, Booleans), InSet(B, Booleans), InSet(C, Booleans), InSet(D, Booleans))
# Out:
# expr: {[not](C) or [not](D) , A => C , B => D , A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {[not](C) or [not](D) , A => C , B => D , A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. ([not](C) or [not](D) , A => C , B => D , A in BOOLEANS , B in BOOLEANS , C in BOOLEANS , D in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8, 9
# 3. [not](C) or [not](D)
#    core type: Operation
#    operator: 10
#    operands: 11
# 4. A => C
#    core type: Operation
#    operator: 13
#    operands: 12
# 5. B => D
#    core type: Operation
#    operator: 13
#    operands: 14
# 6. A in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 15
# 7. B in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 16
# 8. C in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 17
# 9. D in BOOLEANS
#    core type: Operation
#    operator: 18
#    operands: 19
# 10. or
#     core type: Literal
#     sub-expressions:
# 11. ([not](C) , [not](D))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 12. (A , C)
#     core type: ExprTuple
#     sub-expressions: 22, 25
# 13. =>
#     core type: Literal
#     sub-expressions:
# 14. (B , D)
#     core type: ExprTuple
#     sub-expressions: 23, 27
# 15. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 16. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 17. (C , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 20. [not](C)
#     core type: Operation
#     operator: 26
#     operand: 25
# 21. [not](D)
#     core type: Operation
#     operator: 26
#     operand: 27
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. B
#     core type: Variable
#     sub-expressions:
# 24. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 25. C
#     core type: Variable
#     sub-expressions:
# 26. not
#     core type: Literal
#     sub-expressions:
# 27. D
#     core type: Variable
#     sub-expressions:
