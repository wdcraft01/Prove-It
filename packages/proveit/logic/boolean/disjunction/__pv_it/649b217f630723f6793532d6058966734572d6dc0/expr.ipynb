# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#unaryDisjunctionDef">unaryDisjunctionDef</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean.disjunction._theorems_ import unaryDisjunctionDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr unaryDisjunctionDef
# Out:
# Passed sanity check: built 'unaryDisjunctionDef' is the same as the stored Expression.

# %%
# display the expression information
unaryDisjunctionDef.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} ([or](A) = A)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ([or](A) = A) | A in BOOLEANS
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. [or](A) = A
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ([or](A) , A)
#    core type: ExprTuple
#    sub-expressions: 8, 14
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [or](A)
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (A)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. BOOLEANS
#     core type: Literal
# ...
