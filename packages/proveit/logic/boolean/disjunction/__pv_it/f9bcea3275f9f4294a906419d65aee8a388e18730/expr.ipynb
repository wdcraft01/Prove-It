# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B
from proveit.logic import Booleans, Equals, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(B, Equals(Or(A, B), Or(B, A)), conditions = [InSet(B, Booleans)])
# Out:
# expr: B -> ((A or B) = (B or A)) | B in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> ((A or B) = (B or A)) | B in BOOLEANS
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. (A or B) = (B or A)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (B in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A or B , B or A)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. B in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. A or B
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. B or A
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (B , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. (A , B)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (B , A)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
