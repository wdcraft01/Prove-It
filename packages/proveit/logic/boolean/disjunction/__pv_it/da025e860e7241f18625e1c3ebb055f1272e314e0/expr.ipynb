# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Forall, Implies, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(C, Forall([D], Or(C, D), domain = Booleans, conditions = [Implies(B, D)]), conditions = [InSet(C, Booleans), Implies(A, C)])
# Out:
# expr: C -> [forall_{D in BOOLEANS | B => D} (C or D)] | C in BOOLEANS , A => C

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> [forall_{D in BOOLEANS | B => D} (C or D)] | C in BOOLEANS , A => C
#    core type: Lambda
#    parameter: 16
#    body: 1
#    conditions: 2\n1. forall_{D in BOOLEANS | B => D} (C or D)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (C in BOOLEANS , A => C)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. D -> (C or D) | D in BOOLEANS , B => D
#    core type: Lambda
#    parameter: 23
#    body: 7
#    conditions: 8\n5. C in BOOLEANS
#    core type: Operation
#    operator: 17
#    operands: 9
# 6. A => C
#    core type: Operation
#    operator: 19
#    operands: 10
# 7. C or D
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (D in BOOLEANS , B => D)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. (C , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 21
# 10. (A , C)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (C , D)
#     core type: ExprTuple
#     sub-expressions: 16, 23
# 13. D in BOOLEANS
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. B => D
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 19. =>
#     core type: Literal
#     sub-expressions:
# 20. (B , D)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 22. B
#     core type: Variable
#     sub-expressions:
# 23. D
#     core type: Variable
#     sub-expressions:
