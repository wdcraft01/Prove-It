# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean.disjunction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, CC, m, n
from proveit.logic import Booleans, Equals, Forall, InSet, Or, TRUE
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Exp, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(m, Forall([n], Forall([AA, CC], Equals(Or(iterA1m, TRUE, iterC1n), TRUE), domains = [Exp(Booleans, m), Exp(Booleans, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{n in Naturals} [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)]] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{n in Naturals} [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)]] | m in Naturals
#    core type: Lambda
#    parameter: 55
#    body: 1
#    conditions: 2\n1. forall_{n in Naturals} [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)]
#    core type: Operation
#    operator: 13
#    operand: 3
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. n -> [forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)] | n in Naturals
#    core type: Lambda
#    parameter: 57
#    body: 5
#    conditions: 6\n4. m in Naturals
#    core type: Operation
#    operator: 47
#    operands: 7
# 5. forall_{(A, C) in BOOLEANS^{m} * BOOLEANS^{n}} ((A_1 or  ...  or A_m or TRUE or C_1 or  ...  or C_n) = TRUE)
#    core type: Operation
#    operator: 13
#    operand: 8
# 6. (n in Naturals)
# ...
