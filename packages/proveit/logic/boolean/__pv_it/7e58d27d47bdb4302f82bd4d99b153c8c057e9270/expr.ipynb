# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, PofA
from proveit.logic import Booleans, Equals, FALSE, Forall

# %%
# build up the expression from sub-expressions
expr = Equals(Forall([A], PofA, domain = Booleans, conditions = []), FALSE)
# Out:
# expr: [forall_{A in BOOLEANS} P(A)] = FALSE

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [forall_{A in BOOLEANS} P(A)] = FALSE
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (forall_{A in BOOLEANS} P(A) , FALSE)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{A in BOOLEANS} P(A)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. FALSE
#    core type: Literal
#    sub-expressions:
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. A -> P(A) | A in BOOLEANS
#    core type: Lambda
#    parameter: 13
#    body: 7
#    conditions: 8\n7. P(A)
#    core type: Operation
#    operator: 9
#    operand: 13
# 8. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. P
#    core type: Variable
#    sub-expressions:
# 10. A in BOOLEANS
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. BOOLEANS
#     core type: Literal
#     sub-expressions:
