# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, PofA, QofA
from proveit.logic import Booleans, Forall, Implies

# %%
# build up the expression from sub-expressions
expr = Forall([A], Implies(QofA, PofA), domain = Booleans, conditions = [])
# Out:
# expr: forall_{A in BOOLEANS} (Q(A) => P(A))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} (Q(A) => P(A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> (Q(A) => P(A)) | A in BOOLEANS
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. Q(A) => P(A)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (Q(A) , P(A))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. Q(A)
#    core type: Operation
#    operator: 12
#    operand: 14
# 9. P(A)
#    core type: Operation
#    operator: 13
#    operand: 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Q
#     core type: Variable
#     sub-expressions:
# 13. P
#     core type: Variable
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. BOOLEANS
#     core type: Literal
#     sub-expressions:
