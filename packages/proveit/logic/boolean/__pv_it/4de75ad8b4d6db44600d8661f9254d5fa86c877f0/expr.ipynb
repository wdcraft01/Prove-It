# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A
from proveit.logic import Booleans, Equals, FALSE, InSet, Or, TRUE

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Equals(InSet(A, Booleans), Or(Equals(A, TRUE), Equals(A, FALSE))))
# Out:
# expr: A -> ((A in BOOLEANS) = ((A = TRUE) or (A = FALSE)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> ((A in BOOLEANS) = ((A = TRUE) or (A = FALSE)))
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. (A in BOOLEANS) = ((A = TRUE) or (A = FALSE))
#    core type: Operation
#    operator: 13
#    operands: 2
# 2. (A in BOOLEANS , (A = TRUE) or (A = FALSE))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A = TRUE) or (A = FALSE)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (A = TRUE , A = FALSE)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. BOOLEANS
#    core type: Literal
#    sub-expressions:
# 10. A = TRUE
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. A = FALSE
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A , TRUE)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (A , FALSE)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. TRUE
#     core type: Literal
#     sub-expressions:
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. FALSE
#     core type: Literal
#     sub-expressions:
