# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, P, PofA
from proveit.logic import And, Booleans, Equals, FALSE, Forall, Implies
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Implies(And(Equals(PofTrue, FALSE), Equals(PofFalse, FALSE)), Equals(Forall([A], PofA, domain = Booleans, conditions = []), FALSE)))
# Out:
# expr: P -> (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> (((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE))
#    core type: Lambda
#    parameter: 23
#    body: 1
# 1. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE) , [forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (P(TRUE) = FALSE) and (P(FALSE) = FALSE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. [forall_{A in BOOLEANS} P(A)] = FALSE
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(TRUE) = FALSE , P(FALSE) = FALSE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (forall_{A in BOOLEANS} P(A) , FALSE)
#    core type: ExprTuple
#    sub-expressions: 11, 22
# 9. P(TRUE) = FALSE
#    core type: Operation
#    operator: 13
#    operands: 12
# 10. P(FALSE) = FALSE
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. forall_{A in BOOLEANS} P(A)
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. (P(TRUE) , FALSE)
#     core type: ExprTuple
#     sub-expressions: 17, 22
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (P(FALSE) , FALSE)
#     core type: ExprTuple
#     sub-expressions: 18, 22
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. A -> P(A) | A in BOOLEANS
#     core type: Lambda
#     parameter: 27
#     body: 19
#     conditions: 20\n17. P(TRUE)
#     core type: Operation
#     operator: 23
#     operand: 21
# 18. P(FALSE)
#     core type: Operation
#     operator: 23
#     operand: 22
# 19. P(A)
#     core type: Operation
#     operator: 23
#     operand: 27
# 20. (A in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 24
# 21. TRUE
#     core type: Literal
#     sub-expressions:
# 22. FALSE
#     core type: Literal
#     sub-expressions:
# 23. P
#     core type: Variable
#     sub-expressions:
# 24. A in BOOLEANS
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. BOOLEANS
#     core type: Literal
#     sub-expressions:
