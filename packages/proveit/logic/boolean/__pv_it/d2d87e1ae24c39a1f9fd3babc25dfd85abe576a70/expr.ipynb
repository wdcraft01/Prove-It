# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, QofA
from proveit.logic import Booleans, InSet
from proveit.logic._common_ import QimplPofFalse, QimplPofTrue

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(A, Booleans), QofA, QimplPofTrue, QimplPofFalse)
# Out:
# expr: (A in BOOLEANS , Q(A) , Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in BOOLEANS , Q(A) , Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 2. Q(A)
#    core type: Operation
#    operator: 17
#    operand: 10
# 3. Q(TRUE) => P(TRUE)
#    core type: Operation
#    operator: 8
#    operands: 7
# 4. Q(FALSE) => P(FALSE)
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (Q(TRUE) , P(TRUE))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. (Q(FALSE) , P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 12. Q(TRUE)
#     core type: Operation
#     operator: 17
#     operand: 16
# 13. P(TRUE)
#     core type: Operation
#     operator: 18
#     operand: 16
# 14. Q(FALSE)
#     core type: Operation
#     operator: 17
#     operand: 19
# 15. P(FALSE)
#     core type: Operation
#     operator: 18
#     operand: 19
# 16. TRUE
#     core type: Literal
#     sub-expressions:
# 17. Q
#     core type: Variable
#     sub-expressions:
# 18. P
#     core type: Variable
#     sub-expressions:
# 19. FALSE
#     core type: Literal
#     sub-expressions:
