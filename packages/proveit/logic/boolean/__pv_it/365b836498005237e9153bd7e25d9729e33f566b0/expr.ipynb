# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B
from proveit.logic import Booleans, Forall, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Forall([A, B], InSet(A, Booleans), conditions = [InSet(Or(A, B), Booleans)])
# Out:
# expr: forall_{A, B | (A or B) in BOOLEANS} (A in BOOLEANS)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B | (A or B) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. A -> [forall_{B | (A or B) in BOOLEANS} (A in BOOLEANS)]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{B | (A or B) in BOOLEANS} (A in BOOLEANS)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> (A in BOOLEANS) | (A or B) in BOOLEANS
#    core type: Lambda
#    parameter: 16
#    body: 5
#    conditions: 6\n5. A in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 7
# 6. ((A or B) in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 8. (A or B) in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A or B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. A or B
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 13. or
#     core type: Literal
#     sub-expressions:
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. B
#     core type: Variable
#     sub-expressions:
