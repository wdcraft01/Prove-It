# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, P, PofA
from proveit.logic import Booleans, Equals, Forall, TRUE
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Equals(Forall([A], PofA, domain = Booleans, conditions = []), TRUE), conditions = [Equals(PofTrue, TRUE), Equals(PofFalse, TRUE)])
# Out:
# expr: P -> ([forall_{A in BOOLEANS} P(A)] = TRUE) | P(TRUE) = TRUE , P(FALSE) = TRUE

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> ([forall_{A in BOOLEANS} P(A)] = TRUE) | P(TRUE) = TRUE , P(FALSE) = TRUE
#    core type: Lambda
#    parameter: 18
#    body: 1
#    conditions: 2\n1. [forall_{A in BOOLEANS} P(A)] = TRUE
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (P(TRUE) = TRUE , P(FALSE) = TRUE)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. (forall_{A in BOOLEANS} P(A) , TRUE)
#    core type: ExprTuple
#    sub-expressions: 6, 16
# 4. P(TRUE) = TRUE
#    core type: Operation
#    operator: 8
#    operands: 7
# 5. P(FALSE) = TRUE
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall_{A in BOOLEANS} P(A)
#    core type: Operation
#    operator: 10
#    operand: 11
# 7. (P(TRUE) , TRUE)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (P(FALSE) , TRUE)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. A -> P(A) | A in BOOLEANS
#     core type: Lambda
#     parameter: 22
#     body: 14
#     conditions: 15\n12. P(TRUE)
#     core type: Operation
#     operator: 18
#     operand: 16
# 13. P(FALSE)
#     core type: Operation
#     operator: 18
#     operand: 17
# 14. P(A)
#     core type: Operation
#     operator: 18
#     operand: 22
# 15. (A in BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. TRUE
#     core type: Literal
#     sub-expressions:
# 17. FALSE
#     core type: Literal
#     sub-expressions:
# 18. P
#     core type: Variable
#     sub-expressions:
# 19. A in BOOLEANS
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. BOOLEANS
#     core type: Literal
#     sub-expressions:
