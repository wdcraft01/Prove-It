# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#unfoldInBool">unfoldInBool</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean._theorems_ import unfoldInBool

# %%
# check that the built expression is the same as the stored expression
# %check_expr unfoldInBool
# Out:
# Passed sanity check: built 'unfoldInBool' is the same as the stored Expression.

# %%
# display the expression information
unfoldInBool.exprInfo()
# Out:
# 0. forall_{A in BOOLEANS} (A or [not](A))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> (A or [not](A)) | A in BOOLEANS
#    core type: Lambda
#    parameter: 12
#    body: 3
#    conditions: 4\n3. A or [not](A)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (A , [not](A))
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 7. A in BOOLEANS
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. [not](A)
#    core type: Operation
#    operator: 11
#    operand: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (A , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. not
#     core type: Literal
#     sub-expressions:
# 12. A
#     core type: Variable
#     sub-expressions:
# 13. BOOLEANS
#     core type: Literal
# ...
