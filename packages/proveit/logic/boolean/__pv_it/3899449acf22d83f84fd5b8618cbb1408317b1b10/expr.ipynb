# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import i, l, x, yy
from proveit.logic import Equals, Forall, InSet, Or, Set
from proveit.logic._common_ import yIter1l
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Forall([l], Forall([x, yIter1l], Or(Iter(i, Equals(x, Indexed(yy, i, base = 1)), one, l)), conditions = [InSet(x, Set(yIter1l))]), domain = Naturals, conditions = [])
# Out:
# expr: forall_{l in Naturals} [forall_{x, y_1,...,y_l | x in {y_1 ,  ...  , y_l}} ((x = y_1) or  ...  or (x = y_l))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{l in Naturals} [forall_{x, y_1,...,y_l | x in {y_1 ,  ...  , y_l}} ((x = y_1) or  ...  or (x = y_l))]
#    core type: Operation
#    operator: 8
#    operand: 1
# 1. l -> [forall_{x, y_1,...,y_l | x in {y_1 ,  ...  , y_l}} ((x = y_1) or  ...  or (x = y_l))] | l in Naturals
#    core type: Lambda
#    parameter: 44
#    body: 2
#    conditions: 3\n2. forall_{x, y_1,...,y_l | x in {y_1 ,  ...  , y_l}} ((x = y_1) or  ...  or (x = y_l))
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{y_1,...,y_l | x in {y_1 ,  ...  , y_l}} ((x = y_1) or  ...  or (x = y_l))]
#    core type: Lambda
#    parameter: 28
#    body: 6
# 5. l in Naturals
#    core type: Operation
#    operator: 37
#    operands: 7
# 6. forall_{y_1,...,y_l | x in {y_1 ,  ...  , y_l}} ((x = y_1) or  ...  or (x = y_l))
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. (l , Naturals)
# ...
