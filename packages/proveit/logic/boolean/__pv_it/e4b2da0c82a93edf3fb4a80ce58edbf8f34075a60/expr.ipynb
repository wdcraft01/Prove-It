# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#inBoolDef">inBoolDef</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.logic.boolean._theorems_ import inBoolDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr inBoolDef
# Out:
# Passed sanity check: built 'inBoolDef' is the same as the stored Expression.

# %%
# display the expression information
inBoolDef.exprInfo()
# Out:
# 0. forall_{A} ((A in BOOLEANS) = ((A = TRUE) or (A = FALSE)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ((A in BOOLEANS) = ((A = TRUE) or (A = FALSE)))
#    core type: Lambda
#    parameter: 18
#    body: 3
# 3. (A in BOOLEANS) = ((A = TRUE) or (A = FALSE))
#    core type: Operation
#    operator: 15
#    operands: 4
# 4. (A in BOOLEANS , (A = TRUE) or (A = FALSE))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A = TRUE) or (A = FALSE)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 18, 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (A = TRUE , A = FALSE)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. BOOLEANS
#     core type: Literal
# ...
