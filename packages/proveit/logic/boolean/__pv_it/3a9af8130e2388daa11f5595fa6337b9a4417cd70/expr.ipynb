# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, PofA
from proveit.logic import And, Booleans, Forall
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([A], PofA, domain = Booleans, conditions = []), And(PofTrue, PofFalse))
# Out:
# expr: (forall_{A in BOOLEANS} P(A) , P(TRUE) and P(FALSE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{A in BOOLEANS} P(A) , P(TRUE) and P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{A in BOOLEANS} P(A)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. P(TRUE) and P(FALSE)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> P(A) | A in BOOLEANS
#    core type: Lambda
#    parameter: 17
#    body: 7
#    conditions: 8\n5. and
#    core type: Literal
#    sub-expressions:
# 6. (P(TRUE) , P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. P(A)
#    core type: Operation
#    operator: 13
#    operand: 17
# 8. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. P(TRUE)
#    core type: Operation
#    operator: 13
#    operand: 12
# 10. P(FALSE)
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. A in BOOLEANS
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. TRUE
# ...
