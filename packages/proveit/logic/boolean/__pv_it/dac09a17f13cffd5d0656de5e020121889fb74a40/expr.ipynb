# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import A
from proveit.logic import Equals, FALSE, InSet, Or, TRUE

# %%
# build up the expression from sub-expressions
expr = Equals(InSet(A, Variable("_x_", latexFormat = r"{_{-}x_{-}}")), Or(Equals(A, TRUE), Equals(A, FALSE)))
# Out:
# expr: (A in _x_) = ((A = TRUE) or (A = FALSE))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in _x_) = ((A = TRUE) or (A = FALSE))
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. (A in _x_ , (A = TRUE) or (A = FALSE))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. A in _x_
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A = TRUE) or (A = FALSE)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (A , _x_)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 6. or
#    core type: Literal
#    sub-expressions:
# 7. (A = TRUE , A = FALSE)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. _x_
#    core type: Variable
#    sub-expressions:
# 9. A = TRUE
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. A = FALSE
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (A , TRUE)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (A , FALSE)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. TRUE
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. FALSE
#     core type: Literal
#     sub-expressions:
