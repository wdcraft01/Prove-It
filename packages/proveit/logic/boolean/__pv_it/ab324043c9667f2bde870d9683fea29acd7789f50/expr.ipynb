# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, C, D
from proveit.logic import Booleans, Forall, Implies, InSet, Or

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B, C, D], Or(C, D), domain = Booleans, conditions = [Or(A, B), Implies(A, C), Implies(B, D)]), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> [forall_{B, C, D in BOOLEANS | A or B , A => C , B => D} (C or D)] | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B, C, D in BOOLEANS | A or B , A => C , B => D} (C or D)] | A in BOOLEANS
#    core type: Lambda
#    parameter: 27
#    body: 1
#    conditions: 2\n1. forall_{B, C, D in BOOLEANS | A or B , A => C , B => D} (C or D)
#    core type: Operation
#    operator: 15
#    operand: 3
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. B -> [forall_{C, D in BOOLEANS | A => C , B => D} (C or D)] | B in BOOLEANS , A or B
#    core type: Lambda
#    parameter: 34
#    body: 5
#    conditions: 6\n4. A in BOOLEANS
#    core type: Operation
#    operator: 29
#    operands: 7
# 5. forall_{C, D in BOOLEANS | A => C , B => D} (C or D)
#    core type: Operation
#    operator: 15
#    operand: 8
# 6. (B in BOOLEANS , A or B)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 27, 33
# 8. C -> [forall_{D in BOOLEANS | B => D} (C or D)] | C in BOOLEANS , A => C
#    core type: Lambda
#    parameter: 28
#    body: 11
#    conditions: 12\n9. B in BOOLEANS
#    core type: Operation
#    operator: 29
#    operands: 13
# 10. A or B
#     core type: Operation
#     operator: 23
#     operands: 14
# 11. forall_{D in BOOLEANS | B => D} (C or D)
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. (C in BOOLEANS , A => C)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 13. (B , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 34, 33
# 14. (A , B)
#     core type: ExprTuple
#     sub-expressions: 27, 34
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. D -> (C or D) | D in BOOLEANS , B => D
#     core type: Lambda
#     parameter: 35
#     body: 19
#     conditions: 20\n17. C in BOOLEANS
#     core type: Operation
#     operator: 29
#     operands: 21
# 18. A => C
#     core type: Operation
#     operator: 31
#     operands: 22
# 19. C or D
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. (D in BOOLEANS , B => D)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 21. (C , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 28, 33
# 22. (A , C)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. or
#     core type: Literal
#     sub-expressions:
# 24. (C , D)
#     core type: ExprTuple
#     sub-expressions: 28, 35
# 25. D in BOOLEANS
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. B => D
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. A
#     core type: Variable
#     sub-expressions:
# 28. C
#     core type: Variable
#     sub-expressions:
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (D , BOOLEANS)
#     core type: ExprTuple
#     sub-expressions: 35, 33
# 31. =>
#     core type: Literal
#     sub-expressions:
# 32. (B , D)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 34. B
#     core type: Variable
#     sub-expressions:
# 35. D
#     core type: Variable
#     sub-expressions:
