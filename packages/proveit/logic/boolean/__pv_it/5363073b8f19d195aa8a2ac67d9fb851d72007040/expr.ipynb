# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, PofA
from proveit.logic import And, Booleans, Equals, FALSE, Forall, Implies
from proveit.logic._common_ import PofFalse, PofTrue

# %%
# build up the expression from sub-expressions
expr = Implies(And(Equals(PofTrue, FALSE), Equals(PofFalse, FALSE)), Equals(Forall([A], PofA, domain = Booleans, conditions = []), FALSE))
# Out:
# expr: ((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE)) => ([forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((P(TRUE) = FALSE) and (P(FALSE) = FALSE) , [forall_{A in BOOLEANS} P(A)] = FALSE)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (P(TRUE) = FALSE) and (P(FALSE) = FALSE)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. [forall_{A in BOOLEANS} P(A)] = FALSE
#    core type: Operation
#    operator: 12
#    operands: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (P(TRUE) = FALSE , P(FALSE) = FALSE)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (forall_{A in BOOLEANS} P(A) , FALSE)
#    core type: ExprTuple
#    sub-expressions: 10, 21
# 8. P(TRUE) = FALSE
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. P(FALSE) = FALSE
#    core type: Operation
#    operator: 12
#    operands: 13
# ...
