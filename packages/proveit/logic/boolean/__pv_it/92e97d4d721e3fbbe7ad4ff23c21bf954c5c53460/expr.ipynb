# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, PofA, Q, QofA
from proveit.logic import Booleans, Forall, Implies
from proveit.logic._common_ import QimplPofFalse, QimplPofTrue

# %%
# build up the expression from sub-expressions
expr = Forall([Q], Forall([A], Implies(QofA, PofA), domain = Booleans, conditions = []), conditions = [QimplPofTrue, QimplPofFalse])
# Out:
# expr: forall_{Q | Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE)} [forall_{A in BOOLEANS} (Q(A) => P(A))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{Q | Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE)} [forall_{A in BOOLEANS} (Q(A) => P(A))]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. Q -> [forall_{A in BOOLEANS} (Q(A) => P(A))] | Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE)
#    core type: Lambda
#    parameter: 25
#    body: 2
#    conditions: 3\n2. forall_{A in BOOLEANS} (Q(A) => P(A))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (Q(TRUE) => P(TRUE) , Q(FALSE) => P(FALSE))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. A -> (Q(A) => P(A)) | A in BOOLEANS
#    core type: Lambda
#    parameter: 27
#    body: 8
#    conditions: 9\n6. Q(TRUE) => P(TRUE)
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. Q(FALSE) => P(FALSE)
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. Q(A) => P(A)
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (A in BOOLEANS)
# ...
