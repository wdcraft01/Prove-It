# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, C
from proveit.logic import Booleans, Implies, InSet, Not

# %%
# build up the expression from sub-expressions
expr = Lambda(A, C, conditions = [InSet(A, Booleans), Implies(A, C), Implies(Not(A), C)])
# Out:
# expr: A -> C | A in BOOLEANS , A => C , [not](A) => C

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> C | A in BOOLEANS , A => C , [not](A) => C
#    core type: Lambda
#    parameter: 14
#    body: 12
#    conditions: 1\n1. (A in BOOLEANS , A => C , [not](A) => C)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. A in BOOLEANS
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. A => C
#    core type: Operation
#    operator: 8
#    operands: 7
# 4. [not](A) => C
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 7. (A , C)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 8. =>
#    core type: Literal
#    sub-expressions:
# 9. ([not](A) , C)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 11. [not](A)
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. C
#     core type: Variable
#     sub-expressions:
# 13. not
#     core type: Literal
#     sub-expressions:
# 14. A
#     core type: Variable
#     sub-expressions:
