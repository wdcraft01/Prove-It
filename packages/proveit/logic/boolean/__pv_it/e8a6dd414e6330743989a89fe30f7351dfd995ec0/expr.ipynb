# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.logic.boolean</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A
from proveit.logic import Booleans, Equals, FALSE, InSet, Or, TRUE

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Or(Equals(A, TRUE), Equals(A, FALSE)), conditions = [InSet(A, Booleans)])
# Out:
# expr: A -> ((A = TRUE) or (A = FALSE)) | A in BOOLEANS

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> ((A = TRUE) or (A = FALSE)) | A in BOOLEANS
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. (A = TRUE) or (A = FALSE)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (A in BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (A = TRUE , A = FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. A in BOOLEANS
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. A = TRUE
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. A = FALSE
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (A , BOOLEANS)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 10. (A , TRUE)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (A , FALSE)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. BOOLEANS
#     core type: Literal
#     sub-expressions:
# 14. TRUE
#     core type: Literal
#     sub-expressions:
# 15. A
#     core type: Variable
#     sub-expressions:
# 16. FALSE
#     core type: Literal
#     sub-expressions:
