# %% [markdown]
# Demonstrations for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.graphs.paths</a>
# ========

# %%
import proveit
# %begin demonstrations

from proveit import E, G, P, V
from proveit.logic import InClass, NotInClass
from proveit.logic.sets import NotInSet, InSet
# from proveit.graphs import Path, Paths
# from proveit.graphs import IsPath

# %% [markdown]
# ### The Class of Paths, and Elements of That Class: $\mathrm{Paths}$, $\mathrm{Path}(V, E)$

# %% [markdown]
# #### MISC. TESTING

# %% [markdown]
# #### Basic Constructions

# %% [markdown]
# For many path-related objects and classes, see walks.py and the walks subpackage.

# %%
# paths_class = Paths()

# %%
# does this not automatically convert to InClass notation?
# InSet(P, paths_class)

# %%
# NotInSet(P, paths_class)

# %%
# InClass(P, paths_class)

# %%
# NotInClass(P, paths_class)

# %%
# example_path = Path(V, E)

# %%
# InSet(example_path, Paths())

# %% [markdown]
# We can assert that $P$ is a path in graph $G$:

# %%
# from proveit import u, v, G, P
# IsPath(P, G)

# %% [markdown]
# And we can assert that $P$ is a $u$-$v$ path in graph $G$:

# %%
# IsPath(P, G, u, v)

# %% [markdown]
# We can still return to asserting more generally that $P$ is a path in graph $G$, without specifying the endpoints:

# %%
# IsPath(P, G)

# %%
# %end demonstrations
