# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theory.ipynb">walks</a>.<a class="ProveItLink" href="../../theorems.ipynb#walks_of_graph_membership_exists_folding">walks_of_graph_membership_exists_folding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving walks_of_graph_membership_exists_folding
