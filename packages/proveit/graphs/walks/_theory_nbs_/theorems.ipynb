# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.graphs.walks</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.

from proveit import i, j, k, n, u, v, C, G, P, S, T, W, Function, IndexedVar
from proveit.logic import And, Equals, Exists, Forall, in_bool
from proveit.logic.sets import (Disjoint, Functions, Injections, InSet,
        Set, SetOfAll, SubsetEq, Union)
from proveit.numbers import (zero, one, three, Add, greater_eq,
        Interval, LessEq, Natural, NaturalPos, subtract)
from proveit.graphs import (AdjacentVertices, BeginningVertex, Circuits,
        ClosedTrails, ClosedWalks, Edges, EdgeSet, EdgeSequence, EndingVertex,
        EndVertices, Graphs, IsGraph, Paths, StepCount, Trails, VertexSequence, Vertices, WalkLength, Walks,
        WalksOf, vert_seq_v1_to_vn)
# some convenient common expressions:
from proveit.graphs.walks import W_1_to_n, e_1_to_n, EdgeSet_W_1_to_n, Cycles_e_1_to_n

# %%
# %begin theorems

# %% [markdown]
# #### WalksMembership($k$, $G$)

# %%
walks_membership_def = (
    Forall(G, Forall(k, Forall(W,
    Equals(
        InSet(W, Walks(k, G)),
        InSet(W,
        SetOfAll(S,
             S,
             conditions = [Forall(i, AdjacentVertices(Function(S, i), Function(S, Add(i, one)), G),
                                  domain = Interval(zero, subtract(k, one)))],
             domain = Functions(Interval(zero, k), Vertices(G))))
    )), domain = Natural), conditions = [IsGraph(G)])
)

# %%
walks_membership_unfolding = (
    Forall(G, Forall(k, Forall(W,
    InSet(W,
          SetOfAll(S, S,
              conditions = [Forall(i, AdjacentVertices(Function(S, i), Function(S, Add(i, one)), G),
                                  domain = Interval(zero, subtract(k, one)))],
          domain = Functions(Interval(zero, k), Vertices(G)))),
    conditions = [InSet(W, Walks(k, G))]), domain = Natural), conditions = [IsGraph(G)])
)

# %%
walks_membership_folding = (
    Forall(G, Forall(k, Forall(W,
    InSet(W, Walks(k, G)),
    conditions = [InSet(W,
          SetOfAll(S, S,
              conditions = [Forall(i, AdjacentVertices(Function(S, i), Function(S, Add(i, one)), G),
                                  domain = Interval(zero, subtract(k, one)))],
          domain = Functions(Interval(zero, k), Vertices(G))))]), domain = Natural), conditions = [IsGraph(G)])
)

# %%
walks_membership_unfolding_components = (
    Forall(G, Forall(k, Forall(W,
    And(InSet(W, Functions(Interval(zero, k), Vertices(G))),
        Forall(i, AdjacentVertices(Function(W, i), Function(W, Add(i, one)), G), domain = Interval(zero, subtract(k, one)))),
    conditions = [InSet(W, Walks(k, G))]), domain = Natural), conditions = [IsGraph(G)])
)

# %%
walks_membership_folding_components = (
    Forall(G, Forall(k, Forall(W,
    InSet(W, Walks(k, G)),
    conditions = [Forall(i, AdjacentVertices(Function(W, i), Function(W, Add(i, one)), G),
        domain = Interval(zero, subtract(k, one)))],
    domain = Functions(Interval(zero, k), Vertices(G))),
    domain = Natural), conditions = [IsGraph(G)])
)

# %%
walk_length_from_membership = (
    Forall(G,
    Forall(k,
    Forall(W,
        Equals(WalkLength(W), k),
    domain = Walks(k, G)),
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %% [markdown]
# #### WalksOfMembership: $W \in \textrm{WalksOf}(G)$ and $W \in \textrm{WalksOf}(G, a \rightarrow b)$

# %%
from proveit import G, W, X, ExprRange, ExprTuple
from proveit.logic.sets import InSet, UnionAll
from proveit.graphs import WalksOf
walks_of_graph_membership_def = (
    Forall(G,
    Forall(W,
        Equals(InSet(W, WalksOf(G)),
               InSet(W, UnionAll(n,
                        SetOfAll(ExprRange(i, IndexedVar(v, i), one, n),
                                 ExprTuple(ExprRange(i, IndexedVar(v, i), one, n)),
                                 conditions=[Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                                    domain=Interval(one, subtract(n, one)))],
                                 domain=Vertices(G)),
                    domain=NaturalPos))).with_wrap_after_operator()
    ),
    conditions=[IsGraph(G)])
)

# %%
from proveit import a, b
walks_of_graph_with_ends_membership_def = (
    Forall(G,
    Forall(W,
    Forall((a, b),
        Equals(InSet(W, WalksOf(G, ends=(a,b))),
               InSet(W, UnionAll(n,
                        SetOfAll(ExprRange(i, IndexedVar(v, i), one, n),
                                 ExprTuple(ExprRange(i, IndexedVar(v, i), one, n)),
                                 conditions=[And(Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                                    domain=Interval(one, subtract(n, one))),
                                                 Equals(IndexedVar(v, one), a),
                                                 Equals(IndexedVar(v, n), b))],
                                 domain=Vertices(G)),
                    domain=NaturalPos))).with_wrap_after_operator()
    )),
    conditions=[IsGraph(G)])
)

# %%
from proveit import G, W, X, ExprRange, ExprTuple
from proveit.logic.sets import InSet, UnionAll
from proveit.graphs import WalksOf
walks_of_graph_membership_unfolding = (
    Forall(G,
    Forall(W,
        InSet(W, UnionAll(n,
                        SetOfAll(ExprRange(i, IndexedVar(v, i), one, n),
                                 ExprTuple(ExprRange(i, IndexedVar(v, i), one, n)),
                                 conditions=[Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                                    domain=Interval(one, subtract(n, one)))],
                                 domain=Vertices(G)),
                    domain=NaturalPos)),
    domain=WalksOf(G)),
    conditions=[IsGraph(G)])
)

# %%
walks_of_graph_with_ends_membership_unfolding = (
    Forall(G,
    Forall((a,b),
    Forall(W,
           InSet(W, UnionAll(n,
                    SetOfAll(ExprRange(i, IndexedVar(v, i), one, n),
                             ExprTuple(ExprRange(i, IndexedVar(v, i), one, n)),
                             conditions=[And(Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                                    domain=Interval(one, subtract(n, one))),
                                             Equals(IndexedVar(v, one), a),
                                             Equals(IndexedVar(v, n), b))],
                             domain=Vertices(G)),
                    domain=NaturalPos)),
    domain=WalksOf(G, ends=(a,b)))),
    conditions=[IsGraph(G)])
)

# %%
walks_of_graph_membership_folding = (
Forall(G,
Forall(W,
    InSet(W, WalksOf(G)),
    domain = UnionAll(n,
         SetOfAll(ExprRange(i, IndexedVar(v, i), one, n),
                  ExprTuple(ExprRange(i, IndexedVar(v, i), one, n)),
                  conditions=[Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                              domain=Interval(one, subtract(n, one)))],
                  domain=Vertices(G)),
         domain=NaturalPos)),
conditions=[IsGraph(G)])
)

# %%
walks_of_graph_with_ends_membership_folding = (
Forall(G,
Forall((a, b),
Forall(W,
    InSet(W, WalksOf(G, ends=(a,b))),
domain=UnionAll(n,
                    SetOfAll(ExprRange(i, IndexedVar(v, i), one, n),
                             ExprTuple(ExprRange(i, IndexedVar(v, i), one, n)),
                             conditions=[And(Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                                domain=Interval(one, subtract(n, one))),
                                             Equals(IndexedVar(v, one), a),
                                             Equals(IndexedVar(v, n), b))],
                             domain=Vertices(G)),
                domain=NaturalPos)).with_wrapping()).with_wrapping(),
conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_graph_membership_exists_def = (
    Forall(G,
    Forall(W,
    Equals(
        InSet(W, WalksOf(G)), 
        Exists(n,
               Exists(ExprRange(i, IndexedVar(v, i), one, n),
                      And(Equals(W,ExprTuple(ExprRange(i, IndexedVar(v, i), one, n))),
                          Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                 domain=Interval(one, subtract(n, one)))),
               domain=Vertices(G)),
        domain=NaturalPos)
    ).with_wrap_after_operator()
    ).with_wrapping(),
    conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_graph_membership_with_ends_exists_def = (
    Forall(G,
    Forall((a, b),
    Forall(W,
    Equals(
        InSet(W, WalksOf(G, ends=(a,b))), 
        Exists(n,
               Exists(ExprRange(i, IndexedVar(v, i), one, n),
                      And(Equals(W,ExprTuple(ExprRange(i, IndexedVar(v, i), one, n))),
                          Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                 domain=Interval(one, subtract(n, one))),
                          Equals(IndexedVar(v, one), a),
                          Equals(IndexedVar(v, n), b)),
               domain=Vertices(G)),
        domain=NaturalPos)
    ).with_wrap_after_operator()
    ).with_wrapping()).with_wrapping(),
    conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_graph_membership_exists_unfolding = (
Forall(G,
Forall(W,
    Exists(n,
           Exists(ExprRange(i, IndexedVar(v, i), one, n),
                  And(Equals(W,ExprTuple(ExprRange(i, IndexedVar(v, i), one, n))),
                      Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                             domain=Interval(one, subtract(n, one)))),
           domain=Vertices(G)).with_wrapping(),
    domain=NaturalPos).with_wrapping(),
domain=WalksOf(G)).with_wrapping(),
conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_graph_membership_with_ends_exists_unfolding = (
Forall(G,
Forall((a, b),
Forall(W,
    Exists(n,
           Exists(ExprRange(i, IndexedVar(v, i), one, n),
                  And(Equals(W,ExprTuple(ExprRange(i, IndexedVar(v, i), one, n))),
                      Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                             domain=Interval(one, subtract(n, one))),
                      Equals(IndexedVar(v, one), a),
                      Equals(IndexedVar(v, n), b)),
           domain=Vertices(G)).with_wrapping(),
    domain=NaturalPos).with_wrapping(),
domain=WalksOf(G, ends=(a,b))).with_wrapping()).with_wrapping(),
conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_graph_membership_exists_folding = (
Forall(G,
Forall(W,
    InSet(W, WalksOf(G)),
    conditions=[Exists(n,
               Exists(ExprRange(i, IndexedVar(v, i), one, n),
                      And(Equals(W,ExprTuple(ExprRange(i, IndexedVar(v, i), one, n))),
                          Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                 domain=Interval(one, subtract(n, one)))),
               domain=Vertices(G)),
        domain=NaturalPos)]).with_wrapping(),
conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_graph_membership_with_ends_exists_folding = (
Forall(G,
Forall((a, b),
Forall(W,
    InSet(W, WalksOf(G, ends=(a,b))),
    conditions=[Exists(n,
               Exists(ExprRange(i, IndexedVar(v, i), one, n),
                      And(Equals(W,ExprTuple(ExprRange(i, IndexedVar(v, i), one, n))),
                          Forall(i, AdjacentVertices(IndexedVar(v, i), IndexedVar(v, Add(i, one)), G),
                                 domain=Interval(one, subtract(n, one))),
                          Equals(IndexedVar(v, one), a),
                          Equals(IndexedVar(v, n), b)),
               domain=Vertices(G)),
        domain=NaturalPos)]).with_wrapping()).with_wrapping(),
conditions=[IsGraph(G)]).with_wrapping()
)

# %%
walks_of_membership_explicit = (
    Forall(G,
    Forall(n,
    Forall(vert_seq_v1_to_vn,
    Equals(
    InSet(VertexSequence(vert_seq_v1_to_vn), WalksOf(G)),
    And( Forall(i, InSet(IndexedVar(v, i), Vertices(G)),
           domain=Interval(one, n)),
         Forall(i, InSet(Set(IndexedVar(v, i), IndexedVar(v, Add(i, one))), Edges(G)),
           domain=Interval(one, subtract(n, one))))
    ).with_wrap_after_operator()),
    domain = NaturalPos),
    conditions = [IsGraph(G)])
)

# %%
# from proveit.graphs import WalksOf
# walks_of_simple_length_reduction_unfolding = (
# Forall(G,
# Forall(k,
# Forall(W,
# And( InSet(W, WalksOf(G)),
#      Equals(StepCount(W), k)), conditions = [InSet(W, WalksOf(G, length=k))]
# ), domain = Natural),
# conditions = [IsGraph(G)])
# )

# %%
# from proveit.graphs.walks import others
# from proveit.graphs import WalksOf
# walks_of_length_reduction_unfolding = (
# Forall(G,
# Forall(others,
# Forall(k,
# Forall(W,
# And( InSet(W, WalksOf(G, operands=others)),
#      Equals(StepCount(W), k)), conditions = [InSet(W, WalksOf(G, length=k, operands=others))]
# ), domain = Natural),
# ),
# conditions = [IsGraph(G)])
# )

# %% [markdown]
# #### ClosedWalksMembership($k$, $G$)

# %%
closed_walks_membership_def = (
Forall(G, Forall(k, Forall(W,
Equals(
    InSet(W, ClosedWalks(k, G)),
    InSet(W,
    SetOfAll(S,
         S,
         conditions = [Equals(BeginningVertex(S), EndingVertex(S))],
         domain = Walks(k, G)))
)), domain = Natural), conditions = [IsGraph(G)])
)

# %%
closed_walks_membership_unfolding = (
Forall(G, Forall(k, Forall(W,
InSet(W,
      SetOfAll(S,
               S,
               conditions = [Equals(BeginningVertex(S), EndingVertex(S))],
               domain = Walks(k, G))),
domain = ClosedWalks(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %%
closed_walks_membership_folding = (
Forall(G, Forall(k, Forall(W,
    InSet(W,ClosedWalks(k, G)),
    domain = SetOfAll(S, S,
                  conditions = [Equals(BeginningVertex(S), EndingVertex(S))],
                  domain = Walks(k, G))),
domain = Natural), conditions = [IsGraph(G)])
)

# %% [markdown]
# #### TrailsMembership($k$, $G$)

# %%
trails_membership_def = (
    Forall(G, Forall(k, Forall(T,
    Equals(
        InSet(T, Trails(k, G)),
        InSet(T,
        SetOfAll(W,
                 W,
                 conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
                 domain = Walks(k, G) ))
    )), domain = Natural), conditions = [IsGraph(G)])
)

# %%
trails_membership_unfolding = (
    Forall(G, Forall(k, Forall(T,
    InSet(T,
        SetOfAll(W,
        W,
        conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
        domain = Walks(k, G) )),
    domain = Trails(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %%
trails_membership_folding = (
    Forall(G, Forall(k, Forall(T,
    InSet(T, Trails(k, G)),
    conditions = [],
    domain = SetOfAll(W,
        W,
        conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
        domain = Walks(k, G) )), domain = Natural), conditions = [IsGraph(G)])
)

# %%
trails_membership_unfolding_components = (
    Forall(G, Forall(k, Forall(T,
    And(InSet(T, Walks(k, G)),
        InSet(EdgeSequence(T), Injections(Interval(zero, subtract(k, one)), Edges(G)))),
    domain = Trails(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %%
trails_membership_folding_components = (
    Forall(G, Forall(k, Forall(W,
    InSet(W, Trails(k, G)),
    conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
    domain = Walks(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %% [markdown]
# #### ClosedTrailsMembership($k$, $G$)

# %%
closed_trails_membership_def = (
    Forall(G, Forall(k, Forall(T,
    Equals(
        InSet(T, ClosedTrails(k, G)),
        InSet(T,
        SetOfAll(W,
                 W,
                 conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
                 domain = ClosedWalks(k, G) ))
    )), domain = Natural), conditions = [IsGraph(G)])
)

# %%
closed_trails_membership_unfolding = (
    Forall(G, Forall(k, Forall(T,
    InSet(T,
        SetOfAll(W,
        W,
        conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
        domain = ClosedWalks(k, G) )),
    domain = ClosedTrails(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %%
closed_trails_membership_folding = (
    Forall(G, Forall(k, Forall(T,
    InSet(T, ClosedTrails(k, G)),
    conditions = [],
    domain = SetOfAll(W,
        W,
        conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
        domain = ClosedWalks(k, G) )), domain = Natural), conditions = [IsGraph(G)])
)

# %%
closed_trails_membership_unfolding_components = (
    Forall(G, Forall(k, Forall(T,
    And(InSet(T, ClosedWalks(k, G)),
        InSet(EdgeSequence(T), Injections(Interval(zero, subtract(k, one)), Edges(G)))),
    domain = ClosedTrails(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %%
closed_trails_membership_folding_components = (
    Forall(G, Forall(k, Forall(W,
    InSet(W, ClosedTrails(k, G)),
    conditions = [InSet(EdgeSequence(W), Injections(Interval(zero, subtract(k, one)), Edges(G)))],
    domain = ClosedWalks(k, G)), domain = Natural), conditions = [IsGraph(G)])
)

# %% [markdown]
# #### PathsMembership($k$, $G$)

# %%
paths_membership_def = (
    Forall(G, Forall(k, Forall(P,
    Equals(
        InSet(P, Paths(k, G)),
        InSet(P,
        SetOfAll(W,
             W,
             conditions = [InSet(W, Injections(Interval(zero, k), Vertices(G)))],
             domain = Walks(k, G)))
    )), domain = Natural), conditions = [IsGraph(G)])
)

# %%
paths_membership_unfolding = (
    Forall(G, Forall(k, Forall(P,
        InSet(P,
        SetOfAll(W,
             W,
             conditions = [InSet(W, Injections(Interval(zero, k), Vertices(G)))],
             domain = Walks(k, G))),
    conditions = [InSet(P, Paths(k, G))]),
    domain = Natural), conditions = [IsGraph(G)])
)

# %%
paths_membership_folding = (
    Forall(G, Forall(k, Forall(P,
        InSet(P, Paths(k, G)),
        domain = SetOfAll(W, W,
             conditions = [InSet(W, Injections(Interval(zero, k), Vertices(G)))],
             domain = Walks(k, G))),
    domain = Natural), conditions = [IsGraph(G)])
)

# %%
paths_membership_unfolding_components = (
    Forall(G, Forall(k, Forall(P,
        And(InSet(P, Walks(k, G)),
        InSet(P, Injections(Interval(zero, k), Vertices(G)))),
    conditions = [InSet(P, Paths(k, G))]),
    domain = Natural), conditions = [IsGraph(G)])
)

# %%
paths_membership_folding_components = (
    Forall(G, Forall(k, Forall(W,
        InSet(W, Paths(k, G)),
    conditions = [InSet(W, Injections(Interval(zero, k), Vertices(G)))], domain = Walks(k, G)),
    domain = Natural), conditions = [IsGraph(G)])
)

# %% [markdown]
# #### CircuitsMembership($k$, $G$)

# %%
circuits_membership_def = (
    Forall(G, Forall(k, Forall(C,
    Equals(
        InSet(C, Circuits(k, G)),
        InSet(C, ClosedTrails(k, G))
    )), conditions = [greater_eq(k, three)], domain = Natural), conditions = [IsGraph(G)])
)

# %%
circuits_membership_unfolding = (
    Forall(G, Forall(k, Forall(C,
        InSet(C, ClosedTrails(k, G)),
        domain = Circuits(k, G)), conditions = [greater_eq(k, three)], domain = Natural), conditions = [IsGraph(G)])
)

# %%
circuits_membership_folding = (
    Forall(G, Forall(k, Forall(C,
        InSet(C, Circuits(k, G)),
        domain = ClosedTrails(k, G)),
    conditions = [greater_eq(k, three)], domain = Natural),
    conditions = [IsGraph(G)])
)

# %% [markdown]
# #### EulerianCircuitsMembership($G$)

# %%
from proveit.graphs import EulerianCircuits, Size

# %%
eulerian_circuits_membership_def = (
    Forall(G, Forall(C,
    Equals(
        InSet(C, EulerianCircuits(G)),
        InSet(C, Circuits(Size(G), G))
    )), conditions = [IsGraph(G)])
)

# %%
eulerian_circuits_membership_unfolding = (
    Forall(G, Forall(C,
    InSet(C, Circuits(Size(G), G)
    ), domain = EulerianCircuits(G)), conditions = [IsGraph(G)])
)

# %%
eulerian_circuits_membership_folding = (
    Forall(G, Forall(C,
    InSet(C, EulerianCircuits(G)
    ), domain = Circuits(Size(G), G)), conditions = [IsGraph(G)])
)

# %% [markdown]
# #### CycesMembership($k$, $G$)

# %%
from proveit.logic.sets import Restriction
from proveit.graphs import Cycles

# %%
cycles_membership_def = (
    Forall(G, Forall(k, Forall(C,
    Equals(
        InSet(C, Cycles(k, G)),
        InSet(C, SetOfAll(W, W,
               conditions = [InSet(Restriction(W, Interval(zero, subtract(k, one))),
                                   Paths(subtract(k, one), G))],
               domain = Circuits(k, G)))
    )), conditions = [greater_eq(k, three)], domain = Natural), conditions = [IsGraph(G)])
)

# %%
cycles_membership_unfolding = (
    Forall(G, Forall(k, Forall(C,
    InSet(C, SetOfAll(W, W,
             conditions = [InSet(Restriction(W, Interval(zero, subtract(k, one))),
                                   Paths(subtract(k, one), G))],
             domain = Circuits(k, G))),
    domain = Cycles(k, G)),
    conditions = [greater_eq(k, three)],
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %%
cycles_membership_folding = (
    Forall(G, Forall(k, Forall(C,
    InSet(C, Cycles(k, G)),
    domain = SetOfAll(W, W,
             conditions = [InSet(Restriction(W, Interval(zero, subtract(k, one))),
                                   Paths(subtract(k, one), G))],
             domain = Circuits(k, G))),
    conditions = [greater_eq(k, three)],
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %% [markdown]
# #### General Theorems Involving Walks, Trails, Paths, Circuits, & Cycles

# %% [markdown]
# ##### The existence of a $u$-$v$ walk implies the existence of a $u$-$v$ path:

# %%
walk_implies_path = Forall(G,
Forall((u, v),
Forall((j, W),
Exists((k, P), Equals(EndVertices(P), Set(u, v)),
       conditions = [LessEq(k, j)], domains = [Natural, Paths(k, G)]),
conditions = [Equals(EndVertices(W), Set(u, v))],
domains = [Natural, Walks(j, G)]),
domain = Vertices(G)),
conditions = [IsGraph(G)])

# %% [markdown]
# ##### Every circuit can be partitioned into a collection of edge-disjoint cycles:

# %%
circuit_partitions_into_cycles = (
Forall(G,
Forall(k,
Forall(C,
    Exists(n,
    Exists(e_1_to_n,
    Exists(W_1_to_n,
    And(Equals(EdgeSet(C), Union(*EdgeSet_W_1_to_n)), Disjoint(*EdgeSet_W_1_to_n)).with_wrapping_at(1),
    domains = [*Cycles_e_1_to_n]),
    domain  = NaturalPos),
    domain = NaturalPos),
domain = Circuits(k, G)),
domain = Natural),
conditions = [IsGraph(G)])
)

# %% [markdown]
# #### Subset/Superset Relationships Among Various Walks

# %%
closed_walks_within_walks = (
    Forall(G,
    Forall(k,
        SubsetEq(ClosedWalks(k, G), Walks(k, G)),
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %%
trails_within_walks = (
    Forall(G,
    Forall(k,
        SubsetEq(Trails(k, G), Walks(k, G)),
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %%
closed_trails_within_closed_walks = (
    Forall(G,
    Forall(k,
        SubsetEq(ClosedTrails(k, G), ClosedWalks(k, G)),
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %%
paths_within_trails = (
    Forall(G,
    Forall(k,
        SubsetEq(Paths(k, G), Trails(k, G)),
    domain = Natural),
    conditions = [IsGraph(G)])
)

# %%
circuits_within_closed_trails = (
Forall(G,
Forall(k,
    SubsetEq(Circuits(k, G), ClosedTrails(k, G)),
    conditions = [greater_eq(k, three)],
domain = Natural),
conditions = [IsGraph(G)])
)

# %%
eulerian_circuits_within_closed_walks = (
Forall(G,
    SubsetEq(EulerianCircuits(G), ClosedWalks(Size(G), G)),
conditions = [IsGraph(G)])
)

# %%
cycles_within_circuits = (
    Forall(G, Forall(k,
    SubsetEq(Cycles(k, G), Circuits(k, G)),
    conditions = [greater_eq(k, three)], domain = Natural),
    conditions = [IsGraph(G)])
)

# %% [markdown]
# #### Some standard membership boolean claims

# %%
walks_membership_is_bool = Forall(G,
Forall(k,
Forall(W, in_bool(InSet(W, Walks(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
closed_walks_membership_is_bool = Forall(G,
Forall(k,
Forall(W, in_bool(InSet(W, ClosedWalks(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
trails_membership_is_bool = Forall(G,
Forall(k,
Forall(T, in_bool(InSet(T, Trails(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
closed_trails_membership_is_bool = Forall(G,
Forall(k,
Forall(T, in_bool(InSet(T, ClosedTrails(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
paths_membership_is_bool = Forall(G,
Forall(k,
Forall(P, in_bool(InSet(P, Paths(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
circuits_membership_is_bool = Forall(G,
Forall(k,
Forall(C, in_bool(InSet(C, Circuits(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
eulerian_circuits_membership_is_bool = Forall(G,
Forall(C, in_bool(InSet(C, EulerianCircuits(G)))),
conditions = [IsGraph(G)]
)

# %%
cycles_membership_is_bool = Forall(G, Forall(k, 
Forall(C, in_bool(InSet(C, Cycles(k, G)))),
domain = Natural),
conditions = [IsGraph(G)]
)

# %%
# %end theorems
