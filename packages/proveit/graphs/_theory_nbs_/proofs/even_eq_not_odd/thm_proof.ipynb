# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#even_eq_not_odd">even_eq_not_odd</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.logic import Iff
from proveit.graphs import deg_is_odd_xor_even

# %%
# %proving even_eq_not_odd

# %%
defaults.assumptions = even_eq_not_odd.all_conditions()

# %%
deg_is_odd_xor_even

# %%
deg_is_odd_xor_even_inst = deg_is_odd_xor_even.instantiate(num_forall_eliminations=2)

# %%
deg_is_odd_xor_even_inst.derive_left_if_not_right(assumptions = [even_eq_not_odd.instance_expr.instance_expr.rhs])

# %%
intermed_conc = deg_is_odd_xor_even_inst.derive_not_right_if_left(assumptions = [even_eq_not_odd.instance_expr.instance_expr.lhs])

# %%
even_eq_not_odd.instance_expr.instance_expr.rhs.prove(
        assumptions = defaults.assumptions + [even_eq_not_odd.instance_expr.instance_expr.lhs])

# %%
Iff(even_eq_not_odd.instance_expr.instance_expr.lhs, even_eq_not_odd.instance_expr.instance_expr.rhs).prove()

# %%
# %qed
