# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#g_in_graphs_folding">g_in_graphs_folding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving g_in_graphs_folding

# %%
defaults.assumptions = g_in_graphs_folding.all_conditions()

# %%
from proveit import G, H
from proveit.logic import Equals
from proveit.graphs import Edges, Graph, Vertices
H_ordered_pair_def = Equals(H, Graph(Vertices(G), Edges(G)))
G_ordered_pair_def = Equals(G, Graph(Vertices(G), Edges(G)))

# %%
defaults.assumptions += [G_ordered_pair_def]
defaults.assumptions

# %%
from proveit.graphs import g_in_graphs_existential_def
g_in_graphs_existential_def

# %%
g_in_graphs_existential_def_inst = g_in_graphs_existential_def.instantiate({G:G})

# %%
existence_expr = g_in_graphs_existential_def_inst.rhs

# %%
from proveit.logic import And
example_instance = (Vertices(G), Edges(G))

# %%
_x = existence_expr.instance_params

# %%
_n = _x.num_elements()

# %%
from proveit import Lambda
_P = Lambda(_x, existence_expr.instance_expr)

# %%
existence_expr_jdgmt = existence_expr.conclude_via_example(example_instance)

# %%
g_in_graphs_existential_def_inst.sub_left_side_into(existence_expr_jdgmt)
