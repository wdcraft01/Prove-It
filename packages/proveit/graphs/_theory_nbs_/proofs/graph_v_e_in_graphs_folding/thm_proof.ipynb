# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#graph_v_e_in_graphs_folding">graph_v_e_in_graphs_folding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.graphs import graph_v_e_in_graphs_def

# %%
# %proving graph_v_e_in_graphs_folding

# %%
defaults.assumptions = graph_v_e_in_graphs_folding.all_conditions()

# %%
graph_v_e_in_graphs_def

# %%
graph_v_e_in_graphs_def_inst = graph_v_e_in_graphs_def.instantiate(num_forall_eliminations=2)

# %%
e_subseteq_v_2 = graph_v_e_in_graphs_def_inst.rhs.prove(assumptions=[graph_v_e_in_graphs_def_inst.rhs])

# %%
graph_v_e_in_graphs_def_inst.sub_left_side_into(e_subseteq_v_2)

# %%
# %qed
