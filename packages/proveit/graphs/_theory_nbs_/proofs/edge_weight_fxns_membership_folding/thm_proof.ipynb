# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#edge_weight_fxns_membership_folding">edge_weight_fxns_membership_folding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.graphs import edge_weight_fxns_membership_def

# %%
# %proving edge_weight_fxns_membership_folding

# %%
defaults.assumptions = edge_weight_fxns_membership_folding.all_conditions()

# %%
edge_weight_fxns_membership_def

# %%
edge_weight_fxns_membership_def_inst = (
    edge_weight_fxns_membership_def.instantiate().instantiate()
)

# %%
w_edges_to_r_fxn = defaults.assumptions[1].prove()

# %%
edge_weight_fxns_membership_def_inst.sub_left_side_into(w_edges_to_r_fxn)

# %%
# %qed
