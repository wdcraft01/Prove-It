# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#odd_vertices_membership_def">odd_vertices_membership_def</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import v, x, Lambda
from proveit.logic import InSet

# %%
# %proving odd_vertices_membership_def

# %%
defaults.assumptions = odd_vertices_membership_def.all_conditions()

# %%
from proveit.graphs import odd_vertices_def
odd_vertices_def

# %%
odd_vertices_def_inst = odd_vertices_def.instantiate()

# %%
odd_vertices_def_inst.substitution(Lambda(x, InSet(v, x)))

# %%
# %qed
