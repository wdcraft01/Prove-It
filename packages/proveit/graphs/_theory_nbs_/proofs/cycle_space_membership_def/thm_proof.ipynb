# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#cycle_space_membership_def">cycle_space_membership_def</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import H, x, Lambda
from proveit.logic import InSet
from proveit.graphs import cycle_space_def
from proveit.graphs.inclusion import elem_in_subgraphs_is_subgraph

# %%
# %proving cycle_space_membership_def

# %%
defaults.assumptions = cycle_space_membership_def.all_conditions()

# %%
cycle_space_def

# %%
cycle_space_def_inst = cycle_space_def.instantiate()

# %%
membership_eq = cycle_space_def_inst.substitution(Lambda(x, InSet(H, x)))

# %%
membership_items = membership_eq.rhs.definition(assumptions = defaults.assumptions + [membership_eq.rhs])

# %%
membership_eq_h = membership_eq.sub_left_side_into(membership_items)

# %%
elem_in_subgraphs_is_subgraph

# %%
elem_in_subgraphs_is_subgraph_inst = elem_in_subgraphs_is_subgraph.instantiate(num_forall_eliminations=2)

# %%
conc_01 = elem_in_subgraphs_is_subgraph_inst.sub_right_side_into(membership_eq_h)

# %%
conc_01.inner_expr().rhs.disassociate(1)

# %%
# %qed
