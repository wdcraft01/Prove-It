# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#g_in_graphs_def">g_in_graphs_def</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving g_in_graphs_def

# %%
defaults.assumptions = g_in_graphs_def.all_conditions()

# %%
from proveit.graphs import graph_v_e_in_graphs_def
graph_v_e_in_graphs_def

# %%
graph_v_e_in_graphs_def_inst = graph_v_e_in_graphs_def.instantiate(num_forall_eliminations=2)

# %%
from proveit.graphs import g_in_graphs_existential_def
g_in_graphs_existential_def

# %%
g_in_graphs_existential_def_inst = g_in_graphs_existential_def.instantiate()

# %%
from proveit import E, V
g_in_graphs_existential_def_inst.rhs.choose(V, E)

# %%
from proveit.graphs import vertices_def
vertices_def

# %%
vertices_def_inst = vertices_def.instantiate(num_forall_eliminations=2)

# %%
vertices_def_inst_rev = vertices_def_inst.reversed().prove()

# %%
graph_v_e_in_graphs_def_inst

# %%
conc_01 = graph_v_e_in_graphs_def_inst.inner_expr().rhs.operands[1].operands[0].substitute(vertices_def_inst_rev)

# %%
from proveit.graphs import edges_def
edges_def

# %%
edges_def_inst = edges_def.instantiate(num_forall_eliminations=2)

# %%
edges_def_inst_rev = edges_def_inst.reversed().prove()

# %%
conc_02 = conc_01.inner_expr().rhs.operands[0].substitute(edges_def_inst_rev)

# %%
from proveit import G, V, E, X
from proveit.logic import Equals, InClass
from proveit.graphs import Graph, Graphs
conc_03 = Equals(G, Graph(V, E)).sub_left_side_into(conc_02)

# %%
# from proveit.logic import Exists
# Exists.eliminate((V, E), conc_03)

# %%
# from proveit import G, V, E, X
# from proveit.logic import Equals, InClass
# from proveit.graphs import Graph, Graphs
# conc_01 = Equals(G, Graph(V, E)).sub_left_side_into(graph_v_e_in_graphs_def_inst)
