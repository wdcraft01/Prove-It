# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#graph_v_e_is_graph_def">graph_v_e_is_graph_def</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving graph_v_e_is_graph_def

# %%
from proveit.graphs import is_graph_def
is_graph_def

# %%
from proveit import G, E, V
from proveit.graphs import Graph
is_graph_def_inst = is_graph_def.instantiate({G:Graph(V,E)})

# %%
from proveit.graphs import vertices_def, edges_def
display(vertices_def)
display(edges_def)

# %%
vertices_def_inst = vertices_def.instantiate(num_forall_eliminations=2)

# %%
edges_def_inst = edges_def.instantiate(num_forall_eliminations=2)

# %%
vertices_def_inst_02 = vertices_def_inst.sub_right_side_into(is_graph_def_inst)

# %%
edges_def_inst.sub_right_side_into(vertices_def_inst_02)

# %%
# %qed
