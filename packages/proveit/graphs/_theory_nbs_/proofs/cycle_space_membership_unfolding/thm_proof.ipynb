# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#cycle_space_membership_unfolding">cycle_space_membership_unfolding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.graphs import cycle_space_membership_def

# %%
# %proving cycle_space_membership_unfolding

# %%
defaults.assumptions = cycle_space_membership_unfolding.all_conditions()

# %%
cycle_space_membership_def

# %%
cycle_space_membership_def_inst = cycle_space_membership_def.instantiate(num_forall_eliminations=2)

# %%
cycle_space_membership_def_inst.derive_right_via_equality()

# %%
# %qed
