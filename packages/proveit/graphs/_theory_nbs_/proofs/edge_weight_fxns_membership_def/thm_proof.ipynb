# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#edge_weight_fxns_membership_def">edge_weight_fxns_membership_def</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import s, w, Lambda
from proveit.logic import InSet

# %%
# %proving edge_weight_fxns_membership_def

# %%
defaults.assumptions = edge_weight_fxns_membership_def.all_conditions()

# %%
from proveit.graphs import edge_weight_fxns_def
edge_weight_fxns_def

# %%
edge_weight_fxns_def_inst = edge_weight_fxns_def.instantiate()

# %%
edge_weight_fxns_def_inst.substitution(Lambda(s, InSet(w, s)))

# %%
# %qed
