# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#edge_weight_fxns_membership_unfolding">edge_weight_fxns_membership_unfolding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving edge_weight_fxns_membership_unfolding

# %%
defaults.assumptions = edge_weight_fxns_membership_unfolding.all_conditions()

# %%
from proveit.graphs import edge_weight_fxns_membership_def
edge_weight_fxns_membership_def

# %%
edge_weight_fxns_membership_def_inst = (
    edge_weight_fxns_membership_def.instantiate().instantiate()
)

# %%
w_in_edge_weight_fxns = defaults.assumptions[1]

# %%
w_in_edge_weight_fxns_by_assumption = w_in_edge_weight_fxns.prove()

# %%
edge_weight_fxns_membership_def_inst.sub_right_side_into(w_in_edge_weight_fxns_by_assumption)

# %%
# %qed
