# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#square_grid_edges_membership_def">square_grid_edges_membership_def</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import v, x, Lambda
from proveit.logic import InSet
from proveit.graphs import square_grid_edges_def

# %%
# %proving square_grid_edges_membership_def

# %%
defaults.assumptions = square_grid_edges_membership_def.all_conditions()

# %%
square_grid_edges_def

# %%
square_grid_edges_def_inst = square_grid_edges_def.instantiate()

# %%
square_grid_edges_def_inst.substitution(Lambda(x, InSet(v, x)))

# %%
# %qed
