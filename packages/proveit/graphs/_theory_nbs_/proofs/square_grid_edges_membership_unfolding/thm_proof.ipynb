# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#square_grid_edges_membership_unfolding">square_grid_edges_membership_unfolding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.graphs import square_grid_edges_membership_def

# %%
# %proving square_grid_edges_membership_unfolding

# %%
defaults.assumptions = square_grid_edges_membership_unfolding.all_conditions()

# %%
square_grid_edges_membership_def

# %%
square_grid_edges_membership_def_inst = square_grid_edges_membership_def.instantiate(num_forall_eliminations=2)

# %%
unfold_condition = square_grid_edges_membership_def_inst.lhs

# %%
unfold_condition_jdgmt = unfold_condition.prove()

# %%
square_grid_edges_membership_def_inst.sub_right_side_into(unfold_condition_jdgmt)

# %%
# %qed
