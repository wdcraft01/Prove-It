# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#graph_v_e_is_graph_folding">graph_v_e_is_graph_folding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving graph_v_e_is_graph_folding

# %%
defaults.assumptions = graph_v_e_is_graph_folding.all_conditions()

# %%
from proveit.graphs import graph_v_e_is_graph_def
graph_v_e_is_graph_def

# %%
graph_v_e_is_graph_def_inst = graph_v_e_is_graph_def.instantiate(num_forall_eliminations=2)

# %%
graph_v_e_is_graph_def_inst.derive_left_via_equality()

# %%
# %qed
