# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">graphs</a>.<a class="ProveItLink" href="../../theorems.ipynb#odd_vertices_membership_unfolding">odd_vertices_membership_unfolding</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit.graphs import odd_vertices_membership_def

# %%
# %proving odd_vertices_membership_unfolding

# %%
defaults.assumptions = odd_vertices_membership_unfolding.all_conditions()

# %%
odd_vertices_membership_def

# %%
odd_vertices_membership_def_inst = (
    odd_vertices_membership_def.instantiate(num_forall_eliminations=2))

# %%
v_in_odd_vertices = defaults.assumptions[1].prove(assumptions=[defaults.assumptions[1]])

# %%
odd_vertices_membership_def_inst.sub_right_side_into(v_in_odd_vertices)

# %%
# %qed
