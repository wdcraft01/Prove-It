# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.graphs.paths_of</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.

# from ... import ...

# %%
# %begin theorems

# %%
from proveit import G, P, X
from proveit.logic import Forall
from proveit.graphs import Graphs, PathsOf, Subgraph

# %%
path_is_subgraph = Forall(G, Forall(P, Subgraph(P, G), domain=PathsOf(G)), domain=Graphs)

# %%
# %end theorems
