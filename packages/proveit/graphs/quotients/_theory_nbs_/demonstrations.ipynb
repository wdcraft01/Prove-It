# %% [markdown]
# Demonstrations for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.graphs.quotients</a>
# ========

# %%
import proveit
from proveit import defaults, display_provers # useful imports
from proveit import q, r, G
from proveit.graphs import QuotientGraph
# %begin demonstrations

# %% [markdown]
# #### Basic Constructions

# %% [markdown]
# Let $H_{1}$ be a quotient graph of $G$ under the (unspecified) quotient mapping $q$:

# %%
H1 = QuotientGraph(G, q)

# %% [markdown]
# Let $H_{2}$ be a (possibly different) quotient graph of $G$ under the (unspecified) quotient mapping $r$:

# %%
H2 = QuotientGraph(G, r)

# %%
# %end demonstrations
