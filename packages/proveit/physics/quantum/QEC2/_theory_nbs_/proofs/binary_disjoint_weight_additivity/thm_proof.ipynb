# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QEC2</a>.<a class="ProveItLink" href="../../theorems.ipynb#binary_disjoint_weight_additivity">binary_disjoint_weight_additivity</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers, A, B # useful imports
from proveit.physics.quantum.QEC2 import binary_weight_additivity, weight_empty_set
from proveit.logic.sets.disjointness import disjoint_pair_unfolding

# %%
# %proving binary_disjoint_weight_additivity
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="binary_disjoint_weight_additivity">binary_disjoint_weight_additivity:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/20c19fbfed39c92e9694209e18adc1a9279739910/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/773c33ba88548519a29e248680817d9eb8094d5f0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = binary_disjoint_weight_additivity.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_binary_disjoint_weight_additivity/4f4c07ae5103cc4d9717fdb2e63e28c1ad01f2380/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
binary_weight_additivity_pf = binary_weight_additivity.instantiate({A:A, B:B})
# Out:
# <strong id="binary_weight_additivity_pf">binary_weight_additivity_pf:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_binary_disjoint_weight_additivity/a622f00b2ad83c758c948eec2f248bf08582ab7e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/0219c5f307f2fa023a032796c6a87cb6c1dac7db0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
disjoint_pair_unfolding_pf = disjoint_pair_unfolding.instantiate({A:A, B:B})
# Out:
# <strong id="disjoint_pair_unfolding_pf">disjoint_pair_unfolding_pf:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../logic/sets/disjointness/__pv_it/theorems/9d03d66d130309cdd60e8a226ba1af2e973c4e8b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_binary_disjoint_weight_additivity/0db8699c389f025e6c284b22adc7a87055c088820/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../logic/sets/disjointness/__pv_it/theorems/2c3da683fe626f6c9574ffc0ccaee071773601ad0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
binary_weight_additivity_pf = disjoint_pair_unfolding_pf.sub_right_side_into(binary_weight_additivity_pf)
# Out:
# <strong id="binary_weight_additivity_pf">binary_weight_additivity_pf:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../logic/sets/disjointness/__pv_it/theorems/9d03d66d130309cdd60e8a226ba1af2e973c4e8b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_binary_disjoint_weight_additivity/5f884531c7f629ab6edd1fd056996cd49933f1b90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_binary_disjoint_weight_additivity/afa96c22c73db88f5161b24c07ca76be1e68c95c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
weight_empty_set.sub_right_side_into(binary_weight_additivity_pf)
# Out:
# {disjoint(A, B)} |- w(A union B) = (w(A) + w(B))
# binary_disjoint_weight_additivity may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QEC2.binary_disjoint_weight_additivity has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | disjoint(A, B)} (w(A union B) = (w(A) + w(B)))
# 1	instantiation	5, 2, 3, 4*	{disjoint(A, B)} |- w(A union B) = (w(A) + w(B))
# 	P(_a) : w(A union B) = (w(A) + w(B) - _a), x : w(emptyset), y : 0
# 2	instantiation	5, 6, 7	{disjoint(A, B)} |- w(A union B) = (w(A) + w(B) - w(emptyset))
# 	P(_a) : w(A union B) = (w(A) + w(B) - w(_a)), x : A intersect B, y : emptyset
# 3	axiom		|- w(emptyset) = 0
# 	proveit.physics.quantum.QEC2.weight_empty_set
# 4	instantiation	8, 9, 10	|- (w(A) + w(B) - 0) = (w(A) + w(B))
# 	x : w(A) + w(B) - 0, y : w(A) + w(B) + 0, z : w(A) + w(B)
# 5	conjecture		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 6	instantiation	11	|- w(A union B) = (w(A) + w(B) - w(A intersect B))
# 	A : A, B : B
# 7	instantiation	12, 13	{disjoint(A, B)} |- (A intersect B) = emptyset
# ...
