# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QEC2</a>.<a class="ProveItLink" href="../../theorems.ipynb#weight_of_differences_inequality">weight_of_differences_inequality</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers, A, B, Lambda, x # useful imports
from proveit.numbers import LessEq, Neg
from proveit.logic.sets import Disjoint, Intersect, union_of_diff_and_intersect
from proveit.physics.quantum.QEC2 import Weight

# %%
# %proving weight_of_differences_inequality
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="weight_of_differences_inequality">weight_of_differences_inequality:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fd071326add77d76f625f412178861e1d950e1c20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/6a6a206422e7b4e1526bd7d6bb1ff39497179ecc0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = weight_of_differences_inequality.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/3f96b769bdcf894a2d7279502dfa054ac20e2f360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_as_union_of_diff_and_int = union_of_diff_and_intersect.instantiate({A:A, B:B})
# Out:
# <strong id="A_as_union_of_diff_and_int">A_as_union_of_diff_and_int:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/4e97a61c1c8b5cca6b843e46bbd32355aa0fa67d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../logic/sets/__pv_it/theorems/20ddb7f607f665178df1ee5eb4299ed6a367ea860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
B_as_union_of_diff_and_int = union_of_diff_and_intersect.instantiate({A:B, B:A})
# Out:
# <strong id="B_as_union_of_diff_and_int">B_as_union_of_diff_and_int:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/6e2651a87531e1bfebc8aef81161511bdc7a795b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/c30767b621e99d0f6f3cc3db99b2b5a29232eb230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Disjoint(*A_as_union_of_diff_and_int.rhs.operands).prove()
# Out:
# Found form Disjoint(A-B,AnB).
# |- disjoint(A - B, A intersect B)

# %%
Disjoint(*B_as_union_of_diff_and_int.rhs.operands).prove()
# Out:
# Found form Disjoint(A-B,AnB).
# |- disjoint(B - A, B intersect A)

# %%
weight_A_eq_weight_union = A_as_union_of_diff_and_int.substitution(Lambda(x, Weight(x)))
# Out:
# <strong id="weight_A_eq_weight_union">weight_A_eq_weight_union:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/4e21541d242b2890fe95c901b5b4212a3d664d850/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/d852e78e1396c9329085da559586402888c6343d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
weight_A_eq_weight_sum = weight_A_eq_weight_union.inner_expr().rhs.distribute_over_union()
# Out:
# <strong id="weight_A_eq_weight_sum">weight_A_eq_weight_sum:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/2ddc2bb14d17c079ef652618793b22c0a3f157780/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/07acb4fd4096d248bc0c32855e4663dde06783af0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
weight_B_eq_weight_union = B_as_union_of_diff_and_int.substitution(Lambda(x, Weight(x)))
# Out:
# <strong id="weight_B_eq_weight_union">weight_B_eq_weight_union:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/cce2a00d87f7f0601dec5437a3950d2f498276310/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/27dd7822ce71ef5f5f00ba253aa26548c99e9b0e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
weight_B_eq_weight_sum = weight_B_eq_weight_union.inner_expr().rhs.distribute_over_union()
# Out:
# <strong id="weight_B_eq_weight_sum">weight_B_eq_weight_sum:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/0bc9972be0cad7f51765fda95a5768b6025418200/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/edb1019bd8c8a8f4cfa8d128e8bced4e7a3667450/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
inequality = defaults.assumptions[0]
# Out:
# <strong id="inequality">inequality:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e8a3c69cfb4d2a8a8c83fa06b65833c180ec27830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
inequality = weight_A_eq_weight_sum.sub_right_side_into(inequality)
# Out:
# <strong id="inequality">inequality:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e8a3c69cfb4d2a8a8c83fa06b65833c180ec27830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/9a3a7edc40996f2318b7098d550039c8b69aa6950/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/003ea612a91ec96e12629fc1cdb9f3ea8fe5a6d50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
inequality = weight_B_eq_weight_sum.sub_right_side_into(inequality)
# Out:
# <strong id="inequality">inequality:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e8a3c69cfb4d2a8a8c83fa06b65833c180ec27830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/1bdb122b5d4312694ae6de0db291bffc7cc510210/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/0593a929e58c40ed0bb2e6ccde2d463443b26ace0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
inequality = inequality.inner_expr().lhs.operands[1].operand.commute(0,1)
# Out:
# <strong id="inequality">inequality:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e8a3c69cfb4d2a8a8c83fa06b65833c180ec27830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/82567fd087451bf74c42576caa98e88c7c3d0f710/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_weight_of_differences_inequality/5780355a557f7d302e5a0bcbde86bfac9978d49e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# weight_of_differences_inequality may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QEC2.weight_of_differences_inequality has been proven.
