# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QEC2</a>.<a class="ProveItLink" href="../../theorems.ipynb#difference_is_subset_of_symmetric_difference">difference_is_subset_of_symmetric_difference</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers, A, B # useful imports
from proveit.logic.sets import SubsetEq, Difference
from proveit.logic.sets.symmetric_difference import sym_diff_as_union

# %%
# %proving difference_is_subset_of_symmetric_difference
# Out:
# With these <a href="allowed_presumptions.txt">allowed</a>/<a href="disallowed_presumptions.txt">disallowed</a> theorem/theory presumptions (e.g., to avoid circular dependencies), we begin our proof of<br><strong id="difference_is_subset_of_symmetric_difference">difference_is_subset_of_symmetric_difference:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/4ae75b2b37bb1727c3c913744e727cb40c1fbc520/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/b8de3db943dd1e03044c8bc883b84ba015ece3f30/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = difference_is_subset_of_symmetric_difference.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_difference_is_subset_of_symmetric_difference/1a4193f1deeaf7a4a6b6289328d46189ae6a257f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
A_delta_B_as_union = sym_diff_as_union.instantiate({A:A, B:B})
# Out:
# Attempting to use proveit.logic.sets.symmetric_difference.sym_diff_as_union which has neither been
#  allowed nor disallowed for use in this proof.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel?  a
# <strong id="A_delta_B_as_union">A_delta_B_as_union:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_difference_is_subset_of_symmetric_difference/65cd6d43649d821ec3a296731c2476a32d8d5b560/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../logic/sets/symmetric_difference/__pv_it/theorems/1d9b31803206debb735e1bdf35643cb931bf65070/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_diff_B_subset_union = SubsetEq(Difference(A, B), A_delta_B_as_union.rhs).prove()
# Out:
# <strong id="A_diff_B_subset_union">A_diff_B_subset_union:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_difference_is_subset_of_symmetric_difference/a7f3122c26f1b8cf799a64a99f047e022d1536bc0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_difference_is_subset_of_symmetric_difference/b56c900ec82c1fd1fdbeeb89f75e4611665f9e8a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_delta_B_as_union.sub_left_side_into(A_diff_B_subset_union)
# Out:
# Attempting to use proveit.logic.equality.sub_left_side_into which has neither been
#  allowed nor disallowed for use in this proof.
# Do you wish to (a)llow, (d)isallow, go (u)p a level, or (c)ancel?  a
# |- (A - B) subset_eq (A SymDiff B)
# difference_is_subset_of_symmetric_difference may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QEC2.difference_is_subset_of_symmetric_difference has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B} ((A - B) subset_eq (A SymDiff B))
# 1	instantiation	2, 3, 4	|- (A - B) subset_eq (A SymDiff B)
# 	P(_a) : (A - B) subset_eq _a, x : A SymDiff B, y : (A - B) union (B - A)
# 2	conjecture		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 7, 8	|- (A - B) subset_eq ((A - B) union (B - A))
# 	m : 0, n : 1, X : A - B, A : (), B : (B - A)
# 4	instantiation	9	|- (A SymDiff B) = ((A - B) union (B - A))
# 	A : A, B : B
# 5	conjecture		|- forall_{m, n in Natural} [forall_{X, A_{1}, A_{2}, ..., A_{m}, B_{1}, B_{2}, ..., B_{n}} (X subset_eq (A_{1} union  A_{2} union  ... union  A_{m} union Xunion B_{1} union  B_{2} union  ... union  B_{n}))]
# 	proveit.logic.sets.unification.union_inclusion_of_union_operand
# 6	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 7	conjecture		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 8	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 9	conjecture		|- forall_{A, B} ((A SymDiff B) = ((A - B) union (B - A)))
# 	proveit.logic.sets.symmetric_difference.sym_diff_as_union
