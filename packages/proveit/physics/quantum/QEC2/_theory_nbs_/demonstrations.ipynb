# %% [markdown]
# Demonstrations for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.physics.quantum.QEC2</a>
# ========

# %%
import proveit
from proveit import defaults, display_provers # useful imports
from proveit import b, m, A, B, C
from proveit.logic import InSet
from proveit.logic.sets import Disjoint, Union

# %begin demonstrations

# %% [markdown]
# ### Misc Testing: Constructing Expressions, Representing Sets

# %%
from proveit.physics.quantum.QEC2 import BufiloSets
BufiloSets

# %%
InSet(b, BufiloSets)

# %%
from proveit.physics.quantum.QEC2 import IrreducibleBufiloSets
IrreducibleBufiloSets

# %%
from proveit.physics.quantum.QEC2 import MalignantSets
MalignantSets

# %%
InSet(m, MalignantSets)

# %%
from proveit.physics.quantum.QEC2 import Errors
Errors

# %%
from proveit import e
InSet(e, Errors)

# %%
from proveit.physics.quantum.QEC2 import States
States

# %%
from proveit import s
InSet(s, States)

# %%
from proveit import D
from proveit.logic.sets import EmptySet
from proveit.numbers import zero, one
from proveit.physics.quantum.QEC2 import _ell, State
State(EmptySet, one, _ell)

# %%
State(EmptySet, one)

# %%
from proveit.physics.quantum.QEC2 import StateSyndrome
StateSyndrome(s)

# %%
from proveit.physics.quantum.QEC2 import StateAction
StateAction(s)

# %%
from proveit.physics.quantum.QEC2 import CheckFunction
CheckFunction(e)

# %%
from proveit.physics.quantum.QEC2 import ActionFunction, _ell
ActionFunction(_ell, e)

# %%
from proveit import f, s, t
from proveit.physics.quantum.QEC2 import EdgeFaults
EdgeFaults(s, t)

# %%
InSet(f, EdgeFaults(s, t))

# %%
from proveit import p, G
from proveit.physics.quantum.QEC2 import f_one_to_n, Realizations
Realizations(p, G)

# %%
from proveit import G, ExprTuple
from proveit.physics.quantum.QEC2 import AllStatesGraph, f_one_to_n_minus_one, s_one_to_n
InSet(ExprTuple(f_one_to_n_minus_one), Realizations(ExprTuple(s_one_to_n), AllStatesGraph))

# %%
from proveit.physics.quantum.QEC2 import realizations_membership_def
realizations_membership_def

# %%
# from proveit import a, b, c, d, e, n, s, G
# from proveit.core_expr_types import v_1_to_n
# from proveit.logic import Equals
# from proveit.graphs import IsGraph, IsPath
# from proveit.numbers import two, five, Natural, greater
# from proveit.physics.quantum.QEC2 import f_i, f_one_to_n_minus_one, Faults, s_one_to_n
# _G_sub = AllStatesGraph
# _n_sub = n
# _s_sub = v_1_to_n
# realizations_membership_def.instantiate(
#         {G:_G_sub, n:_n_sub, s:_s_sub},
#         assumptions = [IsGraph(AllStatesGraph), InSet(n, Natural), greater(n, two),
#                       IsPath(ExprTuple(v_1_to_n), AllStatesGraph)]
# )

# %%
# from proveit import i, n, ExprRange, ExprTuple
# from proveit.graphs import IsGraph, IsPath
# from proveit.numbers import two, Natural, greater
# from proveit.physics.quantum.QEC2 import f_i, f_one_to_n_minus_one, Faults, s_one_to_n
# InSet(ExprTuple(f_one_to_n_minus_one), Realizations(ExprTuple(s_one_to_n), G)).definition(
#         assumptions = [IsGraph(G), InSet(n, Natural), greater(n, two), IsPath(ExprTuple(s_one_to_n), G),
#                       ExprRange(i, InSet(f_i, Faults), one, n)]
# )

# %%
from proveit.physics.quantum.QEC2 import Weight
Weight(m)

# %%
Weight(Union(A, B)).distribution_over_union()

# %%
Weight(Union(A, B)).distribution_over_union(assumptions = [Disjoint(A, B)])

# %%
# %end demonstrations
