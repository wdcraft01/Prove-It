# %% [markdown]
# Common expressions for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.physics.quantum.QEC2</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the common expressions of a theory:
# %common_expressions_notebook # Keep this at the top following 'import proveit'.

from proveit import b, e, f, i, j, k, n, s, v, ExprRange, IndexedVar, Literal, Variable
from proveit.logic.sets import Card
from proveit.numbers import zero, one, two, Add, subtract
from proveit.physics.quantum.QEC2 import (
        AllStatesGraphLiteral, BufiloGeneratingGraphLiteral,
        BufiloSetsLiteral, BufiloSequencesLiteral, DetectorsLiteral,
        ErrorsLiteral, FaultsLiteral, IrreducibleBufiloSetsLiteral, 
        MalignantSetsLiteral, ObservableSetsLiteral, StatesLiteral,
        SyndromesLiteral)

# %%
# %begin common

# %%
BufiloSets = BufiloSetsLiteral()

# %%
IrreducibleBufiloSets = IrreducibleBufiloSetsLiteral()

# %%
BufiloSequences = BufiloSequencesLiteral()

# %%
MalignantSets = MalignantSetsLiteral()

# %%
Faults = FaultsLiteral()

# %%
Syndromes = SyndromesLiteral()

# %%
Detectors = DetectorsLiteral()

# %%
Errors = ErrorsLiteral()

# %%
States = StatesLiteral()

# %%
AllStatesGraph = AllStatesGraphLiteral()

# %%
BufiloGeneratingGraph = BufiloGeneratingGraphLiteral()

# %%
ObservableSets = ObservableSetsLiteral()

# %% [markdown]
# ##### A Maximum Weight $w_{\text{BUF}}$ for BUFILOs

# %%
_max_buf_weight = Literal('w_BUF', r'w_{\textsc{buf}}')

# %% [markdown]
# ##### A Literal $\ell$ to Represent the Logical Operator With Which the BUFILOs Anti-Commute

# %%
_ell = Literal('l', r'\ell')

# %% [markdown]
# A literal $\nu$ to represent the choice function used for selecting a detector to de-activate.

# %%
_nu = Literal('v', r'\nu', fence_when_forced=True)

# %%
_start = Literal('START', r'\textsc{start}', fence_when_forced=True)

# %%
_end = Literal('END', r'\textsc{end}', fence_when_forced=True)

# %% [markdown]
# ##### Useful Variables

# %%
b_prime = Variable("b'", r"b'", fence_when_forced=True)

# %%
b_star = Variable("b*", r"b^{*}", fence_when_forced=True)

# %%
c_star = Variable("c*", r"c^{*}", fence_when_forced=True)

# %%
m_prime = Variable("m'", r"m'", fence_when_forced=True)

# %%
n_p = Variable("n_p", r"n_{p}", fence_when_forced=True )

# %%
n_star = Variable("n*", r"n^{*}", fence_when_forced=True )

# %%
pk, ek = (
    Variable("p_k", r'p_{k}', fence_when_forced=True),
    Variable("e_k", r'e_{k}', fence_when_forced=True)
)

# %%
s_prime = Variable("s'", r"s'", fence_when_forced=True)

# %%
s_0, s_1, s_2, s_k = IndexedVar(s, zero), IndexedVar(s, one), IndexedVar(s, two), IndexedVar(s, k)

# %%
nu = Variable("nu", r"\nu", fence_when_forced=True)

# %% [markdown]
# ##### Other Useful Common Expressions

# %%
e_i = IndexedVar(e, i)

# %%
e_one_to_n = ExprRange(i, IndexedVar(e, i), one, n)

# %%
f_i = IndexedVar(f, i)

# %%
f_one_to_n = ExprRange(i, IndexedVar(f, i), one, n)

# %%
f_one_to_n_minus_one = ExprRange(i, IndexedVar(f, i), one, subtract(n, one))

# %%
f_one_to_i = ExprRange(j, IndexedVar(f, j), one, i)

# %%
f_one_to_card_b = ExprRange(j, IndexedVar(f, j), one, Card(b))

# %%
from proveit import k
s_one_to_k = ExprRange(i, IndexedVar(s, i), one, k)

# %%
s_one_to_n = ExprRange(i, IndexedVar(s, i), one, n)

# %%
s_i, s_i_plus_one = IndexedVar(s, i), IndexedVar(s, Add(i, one))

# %%
v_i_plus_one = IndexedVar(v, Add(i, one))

# %%
# %end common
