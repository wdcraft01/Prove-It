# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">QEC</a>.<a class="ProveItLink" href="../../theory.ipynb">kitaev_planar_hadamard</a>.<a class="ProveItLink" href="../../theorems.ipynb#std_interior_verts_disjoint_from_rba_rbb_i_1_to_n_minus_2">std_interior_verts_disjoint_from_rba_rbb_i_1_to_n_minus_2</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving std_interior_verts_disjoint_from_rba_rbb_i_1_to_n_minus_2

# %%
defaults.assumptions = std_interior_verts_disjoint_from_rba_rbb_i_1_to_n_minus_2.all_conditions()

# %% [markdown]
# Pull in the characteristics of the parameter $n$ (the literal `_n`):

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import _n_in_integer, _n_ge_three
display(_n_in_integer)
display(_n_ge_three)

# %% [markdown]
# Our definition of the interior vertices of the “standard” graphical representation of the surface code, for index $i \in \{1, 2, \ldots, n-2\}$:

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import std_interior_verts_def_i_1_to_n_minus_2
std_interior_verts_def_i_1_to_n_minus_2

# %%
std_interior_verts_def_i_1_to_n_minus_2_inst = std_interior_verts_def_i_1_to_n_minus_2.instantiate()

# %% [markdown]
# Our key disjointness theorem (from `logc/sets/disjointness`):

# %%
from proveit.logic.sets.disjointness import disjoint_diff
disjoint_diff

# %% [markdown]
# We prepare our instantiation substitutions for utilizing the `disjoint_diff` theorem, and then instantiate (one cell further below):

# %%
from proveit.numbers import three
_n_sub, _A_sub, _B_sub, _C_sub = (
        three,
        std_interior_verts_def_i_1_to_n_minus_2_inst.rhs.operands[0],
        std_interior_verts_def_i_1_to_n_minus_2_inst.rhs.operands[1].operands,
        std_interior_verts_def_i_1_to_n_minus_2_inst.lhs)

# %%
from proveit import n, A, B, C
disjoint_diff_inst = disjoint_diff.instantiate(
        {n:_n_sub, A:_A_sub, B:_B_sub, C:_C_sub})

# %% [markdown]
# We pull out the second and third items in that conjunction:

# %%
intermed_conclusion_01 = disjoint_diff_inst.derive_some(1, 2)

# %% [markdown]
# Then we pull in our theorems/definitions for the rough boundary point sets $A$ and $B$ and eventually substitute to get our desired result:

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import (
        rough_boundary_pts_A_i_1_to_n_minus_1, rough_boundary_pts_B_i_1_to_n_minus_2)
display(rough_boundary_pts_A_i_1_to_n_minus_1)
display(rough_boundary_pts_B_i_1_to_n_minus_2)

# %% [markdown]
# We instantiate those definitions. Note that our default assumption is $i \in \{1, \ldots, n-2\}$, while the definition for $RB_{A}$ is for all $i \in \{1, \ldots, n-1\}$, but the system can figure out that $\{1, \ldots, n-2\} \subseteq \{1, \ldots, n-1\}$:

# %%
rough_boundary_pts_A_i_1_to_n_minus_1_inst = rough_boundary_pts_A_i_1_to_n_minus_1.instantiate()

# %%
rough_boundary_pts_B_i_1_to_n_minus_2_inst = rough_boundary_pts_B_i_1_to_n_minus_2.instantiate()

# %%
intermed_conclusion_02 = rough_boundary_pts_A_i_1_to_n_minus_1_inst.sub_left_side_into(intermed_conclusion_01)

# %%
rough_boundary_pts_B_i_1_to_n_minus_2_inst.sub_left_side_into(intermed_conclusion_02)

# %%
# %qed
