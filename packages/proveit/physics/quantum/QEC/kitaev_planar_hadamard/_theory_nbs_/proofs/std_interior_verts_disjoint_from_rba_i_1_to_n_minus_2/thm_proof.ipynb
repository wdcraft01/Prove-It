# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">QEC</a>.<a class="ProveItLink" href="../../theory.ipynb">kitaev_planar_hadamard</a>.<a class="ProveItLink" href="../../theorems.ipynb#std_interior_verts_disjoint_from_rba_i_1_to_n_minus_2">std_interior_verts_disjoint_from_rba_i_1_to_n_minus_2</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving std_interior_verts_disjoint_from_rba_i_1_to_n_minus_2

# %%
defaults.assumptions = std_interior_verts_disjoint_from_rba_i_1_to_n_minus_2.all_conditions()

# %% [markdown]
# We need to explicitly pull in the characteristics of our constant $n$:

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import _n_in_integer
_n_in_integer

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import _n_ge_three
_n_ge_three

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import std_internal_verts_def_i_1_to_n_minus_2
std_internal_verts_def_i_1_to_n_minus_2

# %%
std_internal_verts_def_i_1_to_n_minus_2_inst = std_internal_verts_def_i_1_to_n_minus_2.instantiate()

# %%
from proveit.logic.sets.disjointness import disjoint_diff
disjoint_diff

# %%
std_internal_verts_def_i_1_to_n_minus_2_inst.rhs.operands[1].operands

# %% [markdown]
# We prepare our instantiation substitutions for utilizing the `disjoint_diff` theorem, and then instantiate (one cell further below):

# %%
from proveit.numbers import three
_n_sub, _A_sub, _B_sub, _C_sub = (
        three,
        std_internal_verts_def_i_1_to_n_minus_2_inst.rhs.operands[0],
        std_internal_verts_def_i_1_to_n_minus_2_inst.rhs.operands[1].operands,
        std_internal_verts_def_i_1_to_n_minus_2_inst.lhs)

# %%
from proveit import n, A, B, C
disjoint_diff_inst = disjoint_diff.instantiate(
        {n:_n_sub, A:_A_sub, B:_B_sub, C:_C_sub})

# %% [markdown]
# We pull out the second piece of that conjunction:

# %%
disjoint_claim_01 = disjoint_diff_inst.operands[1].prove()

# %% [markdown]
# And we pull in our definition for the rough boundary point set $A$ and eventually substitute to get our desired result:

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import rough_boundary_pts_A_i_1_to_n_minus_1
rough_boundary_pts_A_i_1_to_n_minus_1

# %% [markdown]
# We instantiate, but for our default assumptions that $i \in \{1, \ldots, n-2\}$, which works because we know (or more accurately, the system can figure out) that $\{1, \ldots, n-2\} \subseteq \{1, \ldots, n-1\}$:

# %%
rough_boundary_pts_A_i_1_to_n_minus_1_inst = rough_boundary_pts_A_i_1_to_n_minus_1.instantiate()

# %%
rough_boundary_pts_A_i_1_to_n_minus_1_inst.sub_left_side_into(disjoint_claim_01)

# %%
# %qed
