# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">QEC</a>.<a class="ProveItLink" href="../../theory.ipynb">kitaev_planar_hadamard</a>.<a class="ProveItLink" href="../../theorems.ipynb#x_site_verts_disjoint_from_rough_boundary_b_verts">x_site_verts_disjoint_from_rough_boundary_b_verts</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving x_site_verts_disjoint_from_rough_boundary_b_verts

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import x_site_vertices_def
x_site_vertices_def

# %%
from proveit.logic.sets.disjointness import disjoint_diff
disjoint_diff

# %%
from proveit import n, A, B, C
from proveit.numbers import two
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import (
        CoreVertices, OriginVertices, RoughBoundaryBVertices, XSiteVertices)
disjoint_diff.instantiate(
        {n:two, A:CoreVertices, B:(OriginVertices, RoughBoundaryBVertices),
         C:XSiteVertices})

# %%
# %qed
