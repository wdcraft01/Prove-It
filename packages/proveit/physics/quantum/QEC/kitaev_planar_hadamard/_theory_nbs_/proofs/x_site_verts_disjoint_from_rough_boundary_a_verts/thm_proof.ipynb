# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">QEC</a>.<a class="ProveItLink" href="../../theory.ipynb">kitaev_planar_hadamard</a>.<a class="ProveItLink" href="../../theorems.ipynb#x_site_verts_disjoint_from_rough_boundary_a_verts">x_site_verts_disjoint_from_rough_boundary_a_verts</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving x_site_verts_disjoint_from_rough_boundary_a_verts

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import (
        rough_boundary_a_vertices_def, x_site_vertices_def)
display(rough_boundary_a_vertices_def)
display(x_site_vertices_def)

# %%
from proveit.logic.sets import Intersect
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import RoughBoundaryAVertices, XSiteVertices
current_eq = x_site_vertices_def.substitution(Intersect(XSiteVertices, RoughBoundaryAVertices))

# %%
current_eq = current_eq.inner_expr().rhs.distribute(0)

# %%
current_eq = current_eq.inner_expr().rhs.operands[1].distribute(0)

# %% [markdown]
# We can then use one of our other disjointness theorems to eliminate the $\textrm{RBBVerts}\cap\textrm{RBAVerts}$ as the empty set $\emptyset$:

# %%
from proveit.physics.quantum.QEC.kitaev_planar_hadamard import rough_boundary_a_verts_disjoint_from_rough_boundary_b_verts
rough_boundary_a_verts_disjoint_from_rough_boundary_b_verts

# %%
RBA_RBB_intersect_empty = rough_boundary_a_verts_disjoint_from_rough_boundary_b_verts.unfold()

# %%
RBB_RBA_intersect_empty = RBA_RBB_intersect_empty.inner_expr().lhs.commute()

# %%
current_eq.inner_expr().rhs.operands[1].operands[1].substitute(RBB_RBA_intersect_empty)
