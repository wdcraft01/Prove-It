# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QEC</a>.<a class="ProveItLink" href="../../theorems.ipynb#empty_syndrome_non_stabilizer_imp_path_between_mbg_boundary_verts">empty_syndrome_non_stabilizer_imp_path_between_mbg_boundary_verts</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving empty_syndrome_non_stabilizer_imp_path_between_mbg_boundary_verts

# %%
defaults.assumptions = empty_syndrome_non_stabilizer_imp_path_between_mbg_boundary_verts.all_conditions()

# %% [markdown]
# #### Some convenient abbreviations

# %%
thm_antecedent = (empty_syndrome_non_stabilizer_imp_path_between_mbg_boundary_verts.
 instance_expr.instance_expr.instance_expr.antecedent)

# %%
from proveit import E, K
from proveit.physics.quantum.QEC import MergedBoundsGraphOfZError
mbg_zerr = MergedBoundsGraphOfZError(E, K)

# %% [markdown]
# #### End of convenient abbreviations

# %%
defaults.assumptions = defaults.assumptions + [thm_antecedent]

# %%
from proveit.physics.quantum.QEC import empty_syndrome_non_stabilizer_imp_mbg_has_2_odd_verts_and_the_odd_verts_are_bound_verts
empty_syndrome_non_stabilizer_imp_mbg_has_2_odd_verts_and_the_odd_verts_are_bound_verts

# %%
empty_syndrome_non_stabilizer_imp_mbg_has_2_odd_verts_and_the_odd_verts_are_bound_verts_inst = (
    empty_syndrome_non_stabilizer_imp_mbg_has_2_odd_verts_and_the_odd_verts_are_bound_verts.
    instantiate(num_forall_eliminations=3)
)

# %%
two_odd_verts_eq_bound_verts = (
    empty_syndrome_non_stabilizer_imp_mbg_has_2_odd_verts_and_the_odd_verts_are_bound_verts_inst.
    derive_consequent())

# %%
odd_verts_eq_bound_verts = two_odd_verts_eq_bound_verts.derive_right()

# %%
from proveit.physics.quantum.QEC import merged_bounds_graph_of_z_error_chain_is_graph
merged_bounds_graph_of_z_error_chain_is_graph

# %%
merged_bounds_graph_of_z_error_chain_is_graph_inst = (
    merged_bounds_graph_of_z_error_chain_is_graph.instantiate(num_forall_eliminations=3))

# %%
from proveit.graphs import path_between_two_odd_vertices
path_between_two_odd_vertices

# %%
from proveit import G
path_between_two_odd_vertices_inst = path_between_two_odd_vertices.instantiate(
        {G: mbg_zerr}
)

# %%
path_between_two_odd_vertices_inst.inner_expr().instance_expr.rhs.substitute(odd_verts_eq_bound_verts)

# %%
# %qed
