# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit.number import Add
from proveit.number._common_ import iter_a1l, iter_c1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = Add(iter_a1l, iter_c1m, iter_d1n)
# Out:
# expr: a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (a_1 ,  ...  , a_l , c_1 ,  ...  , c_m , d_1 ,  ...  , d_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a_1,...,a_l
#    core type: Iter
#    lambda_map: 6
#    start_index: 35
#    end_index: 33
# 4. c_1,...,c_m
#    core type: Iter
#    lambda_map: 7
#    start_index: 35
#    end_index: 34
# 5. d_1,...,d_n
#    core type: Iter
#    lambda_map: 8
#    start_index: 35
#    end_index: 36
# 6. _x_ -> a__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 27
#    body: 9
#    conditions: 10\n7. _x_ -> c__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 27
#    body: 11
#    conditions: 12\n8. _x_ -> d__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 27
#    body: 13
#    conditions: 14\n9. a__x_
#    core type: Indexed
#    var: 15
#    index: 27
#    base: "1"
# 10. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 16
# 11. c__x_
#     core type: Indexed
#     var: 17
#     index: 27
#     base: "1"
# 12. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 18
# 13. d__x_
#     core type: Indexed
#     var: 19
#     index: 27
#     base: "1"
# 14. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 20
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. _x_ in {1...l}
#     core type: Operation
#     operator: 23
#     operands: 21
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. _x_ in {1...m}
#     core type: Operation
#     operator: 23
#     operands: 22
# 19. d
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 22. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. {1...l}
#     core type: Operation
#     operator: 31
#     operands: 29
# 26. {1...m}
#     core type: Operation
#     operator: 31
#     operands: 30
# 27. _x_
#     core type: Variable
#     sub-expressions:
# 28. {1...n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 35, 33
# 30. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 31. Interval
#     core type: Literal
#     sub-expressions:
# 32. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. l
#     core type: Variable
#     sub-expressions:
# 34. m
#     core type: Variable
#     sub-expressions:
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. n
#     core type: Variable
#     sub-expressions:
