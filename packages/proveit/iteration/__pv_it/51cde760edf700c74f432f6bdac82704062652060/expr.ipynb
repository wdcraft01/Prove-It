# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import j, k
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(j)
expr = Equals(InSet(Add(k, one, subExpr1, Neg(one)), Naturals), InSet(Add(k, subExpr1).withSubtractionAt(1,1), Naturals))
# Out:
# expr: ((k + 1 - j - 1) in Naturals) = ((k - j) in Naturals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((k + 1 - j - 1) in Naturals) = ((k - j) in Naturals)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((k + 1 - j - 1) in Naturals , (k - j) in Naturals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (k + 1 - j - 1) in Naturals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (k - j) in Naturals
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (k + 1 - j - 1 , Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k - j , Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k + 1 - j - 1
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. k - j
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. (k , 1 , -j , -1)
#     core type: ExprTuple
#     sub-expressions: 15, 17, 16, 14
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (k , -j)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. -1
#     core type: Operation
#     operator: 18
#     operand: 17
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. -j
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. j
#     core type: Variable
#     sub-expressions:
