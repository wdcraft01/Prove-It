# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import j, k, yy, zz
from proveit.number import Add, Mult, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_y_", latexFormat = r"{_{-}y_{-}}")
expr = Iter(subExpr1, Mult(Indexed(yy, subExpr1, base = 1), Indexed(zz, Add(subExpr1, j).withSubtractionAt(1), base = 1)), one, Add(k, Neg(j)).withSubtractionAt(1,1))
# Out:
# expr: (y_1 * z_(1 + j)),...,(y_(k - j) * z_((k - j) + j))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (y_1 * z_(1 + j)),...,(y_(k - j) * z_((k - j) + j))
#    core type: Iter
#    lambda_map: 1
#    start_index: 19
#    end_index: 20
# 1. _y_ -> (y__y_ * z_(_y_ + j)) | _y_ in {1...k - j}
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. y__y_ * z_(_y_ + j)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_y_ in {1...k - j})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (y__y_ , z_(_y_ + j))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. _y_ in {1...k - j}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. y__y_
#    core type: Indexed
#    var: 11
#    index: 18
#    base: "1"
# 8. z_(_y_ + j)
#    core type: Indexed
#    var: 12
#    index: 13
#    base: "1"
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (_y_ , {1...k - j})
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 11. y
#     core type: Variable
#     sub-expressions:
# ...
