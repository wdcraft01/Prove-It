# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Lambda
from proveit._common_ import aa, bb, n, q
from proveit.logic import InSet
from proveit.number import Interval, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda(q, Mult(Indexed(aa, q, base = 1), Indexed(bb, q, base = 1)), conditions = [InSet(q, Interval(one, n))])
# Out:
# expr: q -> (a_q * b_q) | q in {1...n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. q -> (a_q * b_q) | q in {1...n}
#    core type: Lambda
#    parameter: 12
#    body: 1
#    conditions: 2\n1. a_q * b_q
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (q in {1...n})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (a_q , b_q)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. q in {1...n}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. a_q
#    core type: Indexed
#    var: 10
#    index: 12
#    base: "1"
# 7. b_q
#    core type: Indexed
#    var: 11
#    index: 12
#    base: "1"
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (q , {1...n})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. q
#     core type: Variable
#     sub-expressions:
# 13. {1...n}
#     core type: Operation
#     operator: 14
#     operands: 15
# ...
