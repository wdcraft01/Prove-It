# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Lambda, Variable
from proveit._common_ import aa
from proveit.logic import InSet
from proveit.number import DecimalSequence, Interval, one, three, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Lambda(subExpr1, Indexed(aa, subExpr1, base = 1), conditions = [InSet(subExpr1, Interval(three, DecimalSequence(one, zero)))])
# Out:
# expr: _x_ -> a__x_ | _x_ in {3...10}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. _x_ -> a__x_ | _x_ in {3...10}
#    core type: Lambda
#    parameter: 7
#    body: 1
#    conditions: 2\n1. a__x_
#    core type: Indexed
#    var: 3
#    index: 7
#    base: "1"
# 2. (_x_ in {3...10})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. a
#    core type: Variable
#    sub-expressions:
# 4. _x_ in {3...10}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (_x_ , {3...10})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. _x_
#    core type: Variable
#    sub-expressions:
# 8. {3...10}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Interval
#    core type: Literal
#    sub-expressions:
# 10. (3 , 10)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. 10
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Decimal
#     core type: Literal
#     sub-expressions:
# 14. (1 , 0)
# ...
