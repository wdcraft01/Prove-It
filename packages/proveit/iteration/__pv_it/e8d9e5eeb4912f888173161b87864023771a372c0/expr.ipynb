# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Equals(Add(a, b), Add(b, a)), conditions = [InSet(b, Complexes)])
# Out:
# expr: b -> ((a + b) = (b + a)) | b in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> ((a + b) = (b + a)) | b in Complexes
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. (a + b) = (b + a)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a + b , b + a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. b in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. a + b
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. b + a
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. (a , b)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (b , a)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
