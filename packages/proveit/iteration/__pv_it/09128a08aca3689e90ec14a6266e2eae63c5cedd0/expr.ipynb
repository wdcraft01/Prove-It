# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import j, k, xx, yy, zz
from proveit.number import Add, Mult, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_y_", latexFormat = r"{_{-}y_{-}}")
subExpr2 = Indexed(xx, subExpr1, base = 1)
subExpr3 = Neg(j)
expr = Add(Iter(subExpr1, Mult(subExpr2, Indexed(zz, subExpr1, base = 1)), one, j), Iter(subExpr1, Mult(Indexed(yy, subExpr1, base = 1), Indexed(zz, Add(subExpr1, j).withSubtractionAt(1), base = 1)), one, Add(k, subExpr3).withSubtractionAt(1,1)), Iter(subExpr1, Mult(Indexed(yy, Add(subExpr1, k, subExpr3).withSubtractionAt(2,2), base = 1), subExpr2), one, j)).withWrappingAt(5,11)
# Out:
# expr: (x_1 * z_1) +  ...  + (x_j * z_j) \\  + (y_1 * z_(1 + j)) +  ...  + (y_(k - j) * z_((k - j) + j)) \\  + (y_(1 + k - j) * x_1) +  ...  + (y_(j + k - j) * x_j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1 * z_1) +  ...  + (x_j * z_j) \\  + (y_1 * z_(1 + j)) +  ...  + (y_(k - j) * z_((k - j) + j)) \\  + (y_(1 + k - j) * x_1) +  ...  + (y_(j + k - j) * x_j)
#    core type: Operation
#    operator: 42
#    operands: 1
# 1. (x_1 * z_1 ,  ...  , x_j * z_j , y_1 * z_(1 + j) ,  ...  , y_(k - j) * z_((k - j) + j) , y_(1 + k - j) * x_1 ,  ...  , y_(j + k - j) * x_j)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. (x_1 * z_1),...,(x_j * z_j)
#    core type: Iter
#    lambda_map: 5
#    start_index: 41
#    end_index: 47
# 3. (y_1 * z_(1 + j)),...,(y_(k - j) * z_((k - j) + j))
#    core type: Iter
#    lambda_map: 6
#    start_index: 41
#    end_index: 39
# 4. (y_(1 + k - j) * x_1),...,(y_(j + k - j) * x_j)
#    core type: Iter
#    lambda_map: 7
#    start_index: 41
#    end_index: 47
# 5. _y_ -> (x__y_ * z__y_) | _y_ in {1...j}
#    core type: Lambda
#    parameter: 40
#    body: 8
#    conditions: 12\n6. _y_ -> (y__y_ * z_(_y_ + j)) | _y_ in {1...k - j}
# ...
