# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import A, B, x
from proveit.logic import Forall, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
expr = Lambda(A, Forall([B], Forall([x], InSet(x, B), domain = A, conditions = []), conditions = [SubsetEq(A, B)]))
# Out:
# expr: A -> [forall_{B | A subseteq B} [forall_{x in A} (x in B)]]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B | A subseteq B} [forall_{x in A} (x in B)]]
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. forall_{B | A subseteq B} [forall_{x in A} (x in B)]
#    core type: Operation
#    operator: 5
#    operand: 2
# 2. B -> [forall_{x in A} (x in B)] | A subseteq B
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (A subseteq B)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> (x in B) | x in A
#    core type: Lambda
#    parameter: 17
#    body: 8
#    conditions: 9\n7. A subseteq B
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x in B
#    core type: Operation
#    operator: 15
#    operands: 12
# 9. (x in A)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. subseteq
#     core type: Literal
#     sub-expressions:
# 11. (A , B)
#     core type: ExprTuple
#     sub-expressions: 18, 14
# 12. (x , B)
#     core type: ExprTuple
#     sub-expressions: 17, 14
# 13. x in A
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. B
#     core type: Variable
#     sub-expressions:
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x , A)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
