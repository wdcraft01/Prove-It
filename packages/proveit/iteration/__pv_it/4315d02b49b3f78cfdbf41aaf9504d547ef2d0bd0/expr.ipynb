# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import aa, bb, n, q
from proveit.logic import Equals, Forall
from proveit.number import Add, Mult, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = ExprTuple(Forall([n], Forall([aa, bb], Equals(Mult(aa, bb), Add(Iter(q, Mult(Indexed(aa, q, base = 1), Indexed(bb, q, base = 1)), one, n))), conditions = subExpr1), domain = Naturals, conditions = subExpr1))
# Out:
# expr: (forall_{n in Naturals} [forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{n in Naturals} [forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. forall_{n in Naturals} [forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))]
#    core type: Operation
#    operator: 9
#    operand: 2
# 2. n -> [forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))] | n in Naturals
#    core type: Lambda
#    parameter: 38
#    body: 3
#    conditions: 4\n3. forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))
#    core type: Operation
#    operator: 9
#    operand: 5
# 4. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. a -> [forall_{b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))]
#    core type: Lambda
#    parameter: 31
#    body: 7
# 6. n in Naturals
#    core type: Operation
#    operator: 29
#    operands: 8
# 7. forall_{b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))
#    core type: Operation
#    operator: 9
#    operand: 10
# ...
