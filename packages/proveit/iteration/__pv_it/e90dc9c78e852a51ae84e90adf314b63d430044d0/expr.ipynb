# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import k, l, m
from proveit.logic import Equals
from proveit.number import Add, Neg, four, one

# %%
# build up the expression from sub-expressions
expr = Equals(Add(k, l, Neg(one)), Add(Add(m, four), one))
# Out:
# expr: (k + l - 1) = ((m + 4) + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (k + l - 1) = ((m + 4) + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (k + l - 1 , (m + 4) + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. k + l - 1
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (m + 4) + 1
#    core type: Operation
#    operator: 13
#    operands: 6
# 5. (k , l , -1)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (m + 4 , 1)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 7. k
#    core type: Variable
#    sub-expressions:
# 8. l
#    core type: Variable
#    sub-expressions:
# 9. -1
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. m + 4
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (m , 4)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. m
#     core type: Variable
#     sub-expressions:
# 16. 4
#     core type: Literal
#     sub-expressions:
