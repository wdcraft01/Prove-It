# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import k, l, m
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, Neg, four, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Equals(Add(k, l, Neg(two)), Add(m, four)), InSet(l, Naturals), InSet(m, Naturals), InSet(k, Naturals))
# Out:
# expr: ((k + l - 2) = (m + 4) , l in Naturals , m in Naturals , k in Naturals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((k + l - 2) = (m + 4) , l in Naturals , m in Naturals , k in Naturals)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. (k + l - 2) = (m + 4)
#    core type: Operation
#    operator: 5
#    operands: 6
# 2. l in Naturals
#    core type: Operation
#    operator: 9
#    operands: 7
# 3. m in Naturals
#    core type: Operation
#    operator: 9
#    operands: 8
# 4. k in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (k + l - 2 , m + 4)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. (l , Naturals)
#    core type: ExprTuple
#    sub-expressions: 18, 13
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 20, 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (k , Naturals)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 11. k + l - 2
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. m + 4
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. Naturals
#     core type: Literal
#     sub-expressions:
# 14. (k , l , -2)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (m , 4)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. l
#     core type: Variable
#     sub-expressions:
# 19. -2
#     core type: Operation
#     operator: 22
#     operand: 23
# 20. m
#     core type: Variable
#     sub-expressions:
# 21. 4
#     core type: Literal
#     sub-expressions:
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. 2
#     core type: Literal
#     sub-expressions:
