# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import bb, c, dd, m, n
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Exp
from proveit.number._common_ import iter_a1l, iter_b1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = Forall([bb, c, dd], Equals(Add(iter_a1l, iter_b1m, c, iter_d1n), Add(iter_a1l, c, iter_b1m, iter_d1n)), domains = [Exp(Complexes, m), Complexes, Exp(Complexes, n)], conditions = [])
# Out:
# expr: forall_{(b, c, d) in Complexes^{m} * Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(b, c, d) in Complexes^{m} * Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. b -> [forall_{(c, d) in Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))] | b in Complexes^{m}
#    core type: Lambda
#    parameter: 45
#    body: 2
#    conditions: 3\n2. forall_{(c, d) in Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (b in Complexes^{m})
#    core type: ExprTuple
#    sub-expressions: 5
# ...
