# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Forall
from proveit.number import Add, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Forall([c], LessEq(Add(a, c), Add(b, c)), domain = Reals, conditions = [])
# Out:
# expr: forall_{c in Reals} ((a + c) <= (b + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c in Reals} ((a + c) <= (b + c))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. c -> ((a + c) <= (b + c)) | c in Reals
#    core type: Lambda
#    parameter: 18
#    body: 3
#    conditions: 4\n3. (a + c) <= (b + c)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (a + c , b + c)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. c in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a + c
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 18, 15
# 12. (a , c)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (b , c)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Reals
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
