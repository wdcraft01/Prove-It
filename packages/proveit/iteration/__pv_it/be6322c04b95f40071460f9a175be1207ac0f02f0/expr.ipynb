# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import aa, bb, n, q
from proveit.logic import Equals, Forall
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
expr = Forall([aa, bb], Equals(Mult(aa, bb), Add(Iter(q, Mult(Indexed(aa, q, base = 1), Indexed(bb, q, base = 1)), one, n))), conditions = [])
# Out:
# expr: forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. a -> [forall_{b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))]
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. forall_{b} ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> ((a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n)))
#    core type: Lambda
#    parameter: 25
#    body: 5
# 5. (a * b) = ((a_1 * b_1) +  ...  + (a_n * b_n))
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a * b , (a_1 * b_1) +  ...  + (a_n * b_n))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. a * b
#    core type: Operation
#    operator: 17
#    operands: 10
# 9. (a_1 * b_1) +  ...  + (a_n * b_n)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (a , b)
# ...
