# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import aa, bb, cc, l, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Exp
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
expr = Lambda(aa, Forall([bb, cc], Equals(Add(iter_a1l, Add(iter_b1m), iter_c1n), Add(iter_a1l, iter_b1m, iter_c1n)), domains = [Exp(Complexes, m), Exp(Complexes, n)], conditions = []), conditions = [InSet(aa, Exp(Complexes, l))])
# Out:
# expr: a -> [forall_{(b, c) in Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))] | a in Complexes^{l}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{(b, c) in Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))] | a in Complexes^{l}
#    core type: Lambda
#    parameter: 43
#    body: 1
#    conditions: 2\n1. forall_{(b, c) in Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Complexes^{l})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{c in Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))] | b in Complexes^{m}
#    core type: Lambda
#    parameter: 51
#    body: 5
#    conditions: 6\n4. a in Complexes^{l}
#    core type: Operation
#    operator: 55
#    operands: 7
# ...
