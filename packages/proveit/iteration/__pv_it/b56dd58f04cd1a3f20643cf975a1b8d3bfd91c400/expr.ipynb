# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import i, j, q, xx, yy
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Mult, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(j, Forall([xx, yy], Equals(Mult(xx, yy), Add(Iter(q, Mult(Indexed(xx, q, base = 1), Indexed(yy, q, base = 1)), i, j))), conditions = []), conditions = [InSet(j, Naturals)])
# Out:
# expr: j -> [forall_{x, y} ((x * y) = ((x_i * y_i) +  ...  + (x_j * y_j)))] | j in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. j -> [forall_{x, y} ((x * y) = ((x_i * y_i) +  ...  + (x_j * y_j)))] | j in Naturals
#    core type: Lambda
#    parameter: 36
#    body: 1
#    conditions: 2\n1. forall_{x, y} ((x * y) = ((x_i * y_i) +  ...  + (x_j * y_j)))
#    core type: Operation
#    operator: 7
#    operand: 3
# 2. (j in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. x -> [forall_{y} ((x * y) = ((x_i * y_i) +  ...  + (x_j * y_j)))]
#    core type: Lambda
#    parameter: 29
#    body: 5
# 4. j in Naturals
#    core type: Operation
#    operator: 27
#    operands: 6
# 5. forall_{y} ((x * y) = ((x_i * y_i) +  ...  + (x_j * y_j)))
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (j , Naturals)
#    core type: ExprTuple
#    sub-expressions: 36, 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. y -> ((x * y) = ((x_i * y_i) +  ...  + (x_j * y_j)))
#    core type: Lambda
#    parameter: 30
#    body: 10
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# ...
