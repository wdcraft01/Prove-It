# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import aa, bb, cc, l, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Exp, Naturals
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(l, Forall([m, n], Forall([aa, bb, cc], Equals(Add(iter_a1l, Add(iter_b1m), iter_c1n), Add(iter_a1l, iter_b1m, iter_c1n)), domains = [Exp(Complexes, l), Exp(Complexes, m), Exp(Complexes, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1), conditions = [InSet(l, Naturals)])
# Out:
# expr: l -> [forall_{m, n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))]] | l in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{m, n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))]] | l in Naturals
#    core type: Lambda
#    parameter: 77
#    body: 1
#    conditions: 2\n1. forall_{m, n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))]
#    core type: Operation
#    operator: 24
#    operand: 3
# 2. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. m -> [forall_{n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n))]] | m in Naturals
#    core type: Lambda
#    parameter: 82
#    body: 5
# ...
