# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Iter.html">Iter</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import j, xx, zz
from proveit.number import Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_y_", latexFormat = r"{_{-}y_{-}}")
expr = Iter(subExpr1, Mult(Indexed(xx, subExpr1, base = 1), Indexed(zz, subExpr1, base = 1)), one, j)
# Out:
# expr: (x_1 * z_1),...,(x_j * z_j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1 * z_1),...,(x_j * z_j)
#    core type: Iter
#    lambda_map: 1
#    start_index: 17
#    end_index: 18
# 1. _y_ -> (x__y_ * z__y_) | _y_ in {1...j}
#    core type: Lambda
#    parameter: 13
#    body: 2
#    conditions: 3\n2. x__y_ * z__y_
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_y_ in {1...j})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (x__y_ , z__y_)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. _y_ in {1...j}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. x__y_
#    core type: Indexed
#    var: 11
#    index: 13
#    base: "1"
# 8. z__y_
#    core type: Indexed
#    var: 12
#    index: 13
#    base: "1"
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (_y_ , {1...j})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. z
#     core type: Variable
#     sub-expressions:
# 13. _y_
#     core type: Variable
#     sub-expressions:
# 14. {1...j}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , j)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. j
#     core type: Variable
#     sub-expressions:
