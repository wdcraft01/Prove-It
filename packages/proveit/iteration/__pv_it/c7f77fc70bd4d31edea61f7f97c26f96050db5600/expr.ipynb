# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import j, k
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Equals(InSet(Add(j, k, one, Neg(k), Neg(one)), Naturals), InSet(j, Naturals))
# Out:
# expr: ((j + k + 1 - k - 1) in Naturals) = (j in Naturals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((j + k + 1 - k - 1) in Naturals) = (j in Naturals)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((j + k + 1 - k - 1) in Naturals , j in Naturals)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (j + k + 1 - k - 1) in Naturals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. j in Naturals
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (j + k + 1 - k - 1 , Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (j , Naturals)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 8. j + k + 1 - k - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. Naturals
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (j , k , 1 , -k , -1)
#     core type: ExprTuple
#     sub-expressions: 12, 15, 17, 13, 14
# 12. j
#     core type: Variable
#     sub-expressions:
# 13. -k
#     core type: Operation
#     operator: 16
#     operand: 15
# 14. -1
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
