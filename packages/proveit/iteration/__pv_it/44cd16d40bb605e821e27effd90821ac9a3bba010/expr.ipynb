# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import i, j, q, xx, yy
from proveit.number import Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Iter(q, Mult(Indexed(xx, q, base = 1), Indexed(yy, q, base = 1)), i, j))
# Out:
# expr: (x_i * y_i ,  ...  , x_j * y_j)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_i * y_i ,  ...  , x_j * y_j)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_i * y_i),...,(x_j * y_j)
#    core type: Iter
#    lambda_map: 2
#    start_index: 18
#    end_index: 19
# 2. q -> (x_q * y_q) | q in {i...j}
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. x_q * y_q
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (q in {i...j})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (x_q , y_q)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. q in {i...j}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x_q
#    core type: Indexed
#    var: 12
#    index: 14
#    base: "1"
# 9. y_q
#    core type: Indexed
#    var: 13
#    index: 14
#    base: "1"
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (q , {i...j})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. y
#     core type: Variable
#     sub-expressions:
# 14. q
#     core type: Variable
#     sub-expressions:
# 15. {i...j}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (i , j)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. i
#     core type: Variable
#     sub-expressions:
# 19. j
#     core type: Variable
#     sub-expressions:
