# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Forall, InSet
from proveit.number import Add, Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], InSet(Add(a, b), Naturals), domain = Naturals, conditions = [])
# Out:
# expr: forall_{a, b in Naturals} ((a + b) in Naturals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, b in Naturals} ((a + b) in Naturals)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Naturals} ((a + b) in Naturals)] | a in Naturals
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{b in Naturals} ((a + b) in Naturals)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Naturals)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((a + b) in Naturals) | b in Naturals
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n6. a in Naturals
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. (a + b) in Naturals
#    core type: Operation
#    operator: 13
#    operands: 10
# 8. (b in Naturals)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (a , Naturals)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 10. (a + b , Naturals)
#     core type: ExprTuple
#     sub-expressions: 12, 17
# 11. b in Naturals
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. a + b
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b , Naturals)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a , b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Naturals
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
