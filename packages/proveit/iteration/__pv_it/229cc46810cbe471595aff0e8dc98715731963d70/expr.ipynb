# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import aa, b, cc, dd, l, m, n
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Exp, Naturals, Neg
from proveit.number._common_ import iter_a1l, iter_c1m, iter_d1n

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([n], Forall([aa, b, cc, dd], Equals(Add(iter_a1l, b, iter_c1m, Neg(b), iter_d1n), Add(iter_a1l, iter_c1m, iter_d1n)), domains = [Exp(Complexes, l), Complexes, Exp(Complexes, m), Exp(Complexes, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1)
# Out:
# expr: forall_{n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))]
#    core type: Operation
#    operator: 22
#    operand: 1
# 1. n -> [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))] | n in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 2
#    conditions: 3\n2. forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))
#    core type: Operation
#    operator: 22
#    operand: 4
# 3. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# ...
