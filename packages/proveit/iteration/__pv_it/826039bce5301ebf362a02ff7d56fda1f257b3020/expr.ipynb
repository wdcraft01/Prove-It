# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b, c], Equals(Add(b, Neg(c)), Neg(a)), domain = Complexes, conditions = [Equals(Add(a, b), c)]), conditions = [InSet(a, Complexes)])
# Out:
# expr: a -> [forall_{b, c in Complexes | (a + b) = c} ((b - c) = (-a))] | a in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b, c in Complexes | (a + b) = c} ((b - c) = (-a))] | a in Complexes
#    core type: Lambda
#    parameter: 31
#    body: 1
#    conditions: 2\n1. forall_{b, c in Complexes | (a + b) = c} ((b - c) = (-a))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{c in Complexes | (a + b) = c} ((b - c) = (-a))] | b in Complexes
#    core type: Lambda
#    parameter: 32
#    body: 5
#    conditions: 6\n4. a in Complexes
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall_{c in Complexes | (a + b) = c} ((b - c) = (-a))
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 31, 24
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. c -> ((b - c) = (-a)) | c in Complexes , (a + b) = c
#    core type: Lambda
#    parameter: 30
#    body: 11
#    conditions: 12\n10. b in Complexes
#     core type: Operation
#     operator: 19
#     operands: 13
# 11. (b - c) = (-a)
#     core type: Operation
#     operator: 21
#     operands: 14
# 12. (c in Complexes , (a + b) = c)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 32, 24
# 14. (b - c , -a)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. c in Complexes
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (a + b) = c
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. b - c
#     core type: Operation
#     operator: 27
#     operands: 23
# 18. -a
#     core type: Operation
#     operator: 29
#     operand: 31
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 24
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 25, 30
# 23. (b , -c)
#     core type: ExprTuple
#     sub-expressions: 32, 26
# 24. Complexes
#     core type: Literal
#     sub-expressions:
# 25. a + b
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. -c
#     core type: Operation
#     operator: 29
#     operand: 30
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (a , b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. -
#     core type: Literal
#     sub-expressions:
# 30. c
#     core type: Variable
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
