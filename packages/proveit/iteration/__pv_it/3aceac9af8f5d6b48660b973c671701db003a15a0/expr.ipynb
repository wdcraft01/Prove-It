# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.iteration</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Variable
from proveit._common_ import j, k, xx, yy, zz
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(xx, subExpr1, base = 1), one, j)
expr = ExprTuple([subExpr2, Iter(subExpr1, Indexed(yy, subExpr1, base = 1), one, k)], [Iter(subExpr1, Indexed(zz, subExpr1, base = 1), one, k), subExpr2])
# Out:
# expr: ((x_1 ,  ...  , x_j , y_1 ,  ...  , y_k) , (z_1 ,  ...  , z_k , x_1 ,  ...  , x_j))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((x_1 ,  ...  , x_j , y_1 ,  ...  , y_k) , (z_1 ,  ...  , z_k , x_1 ,  ...  , x_j))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (x_1 ,  ...  , x_j , y_1 ,  ...  , y_k)
#    core type: ExprTuple
#    sub-expressions: 5, 3
# 2. (z_1 ,  ...  , z_k , x_1 ,  ...  , x_j)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. y_1,...,y_k
#    core type: Iter
#    lambda_map: 6
#    start_index: 29
#    end_index: 28
# 4. z_1,...,z_k
#    core type: Iter
#    lambda_map: 7
#    start_index: 29
#    end_index: 28
# 5. x_1,...,x_j
#    core type: Iter
#    lambda_map: 8
#    start_index: 29
#    end_index: 30
# 6. _x_ -> y__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 23
#    body: 9
#    conditions: 11\n7. _x_ -> z__x_ | _x_ in {1...k}
#    core type: Lambda
#    parameter: 23
#    body: 10
#    conditions: 11\n8. _x_ -> x__x_ | _x_ in {1...j}
#    core type: Lambda
#    parameter: 23
#    body: 12
#    conditions: 13\n9. y__x_
#    core type: Indexed
# ...
