# %% [markdown]
# Demonstrations for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.abstract_algebra.fields</a>
# ========

# %%
import proveit
# %begin demonstrations

# %%
from proveit.abstract_algebra import FiniteField
from proveit.numbers import two
FiniteField(two)

# %%
print(FiniteField(two))

# %%
# %end demonstrations
