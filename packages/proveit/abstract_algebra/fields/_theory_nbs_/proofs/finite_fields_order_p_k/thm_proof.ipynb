# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">abstract_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">fields</a>.<a class="ProveItLink" href="../../theorems.ipynb#finite_fields_order_p_k">finite_fields_order_p_k</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports

# %%
# %proving finite_fields_order_p_k
