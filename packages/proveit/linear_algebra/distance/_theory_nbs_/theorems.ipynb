# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.linear_algebra.distance</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
from proveit import a, b, c, d
from proveit.logic import Equals, Forall
from proveit.numbers import two, Abs, Add, Exp, Real, sqrt, subtract
from proveit.linear_algebra import EuclideanDistance, ManhattanDistance

# %%
# %begin theorems

# %% [markdown]
# #### Manhattan distance in 2D

# %%
manhattan_distance_2d = (
    Forall((a, b, c, d),
           Equals(ManhattanDistance((a, b), (c, d)),
                  Add(Abs(subtract(a, c)), Abs(subtract(b, d)))),
           domain = Real)
)

# %% [markdown]
# #### Euclidean distance in 2D

# %%
euclidean_distance_2d = (
    Forall((a, b, c, d),
        Equals(EuclideanDistance((a, b), (c, d)),
               sqrt(Add(Exp(subtract(a, c), two), Exp(subtract(b, d), two)))),
        domain = Real)
)

# %%
# %end theorems
