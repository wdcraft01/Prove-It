# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.linear_algebra.distance</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.

# from ... import ...

# %%
# %begin theorems

# %%
from proveit.linear_algebra import ManhattanDistance

# %% [markdown]
# Manhattan distance in 2D

# %%
# from proveit import x, y, X, ExprTuple
# from proveit.logic import Equals, Forall
# from proveit.numbers import Abs, Add, Real, subtract
# from proveit.linear_algebra import x_1, x_2, y_1, y_2
# manhattan_distance_2d = Forall((x, y),
#        Equals(ManhattanDistance(x, y),
#              Add(Abs(subtract(x_1, y_1)), Abs(subtract(x_2, y_2)))),
#        conditions=[Equals(x, ExprTuple(x_1, x_2)), Equals(y, ExprTuple(y_1, y_2))])

# %%
# This works, but leaves the theorem in a state that is difficult then to instantiate!
from proveit import a, b, c, d, i, u, v, x, y, X, ExprRange, ExprTuple, IndexedVar
from proveit.core_expr_types import a_i, b_i, x_i, y_i
from proveit.logic import CartExp, Equals, Forall
from proveit.numbers import one, two, Abs, Add, Real, subtract
from proveit.linear_algebra import (
        a_1, a_2, b_1, b_2, x_1, x_2, y_1, y_2, x_prime, y_prime)

manhattan_distance_2d = (
    Forall((u, v),
    Forall((ExprRange(i, a_i, one, two), ExprRange(i, b_i, one, two)),
           Equals(ManhattanDistance(u, v),
                  Add(Abs(subtract(a_1, b_1)), Abs(subtract(a_2, b_2)))),
           conditions=[Equals(u, ExprTuple(a_1, a_2)), Equals(v, ExprTuple(b_1, b_2))],
           domain=Real),
    domain=CartExp(Real, two))
)

# %%
# %end theorems
