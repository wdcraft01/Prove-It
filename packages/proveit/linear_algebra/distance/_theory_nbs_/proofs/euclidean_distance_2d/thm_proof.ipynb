# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theory.ipynb">distance</a>.<a class="ProveItLink" href="../../theorems.ipynb#euclidean_distance_2d">euclidean_distance_2d</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, display_provers # useful imports
from proveit import a, b, c, d, n, p, u, v, ExprTuple
from proveit.numbers import two
from proveit.linear_algebra.distance import euclidean_distance_def, minkowski_distance_def

# %%
# %proving euclidean_distance_2d

# %%
defaults.assumptions = euclidean_distance_2d.all_conditions()

# %%
euclidean_distance_def

# %%
euclidean_distance_def_inst = euclidean_distance_def.instantiate(
    {n:two, u:ExprTuple(a, b), v:ExprTuple(c, d)}, num_forall_eliminations=2)

# %%
minkowski_distance_def

# %%
minkowski_distance_def_inst = minkowski_distance_def.instantiate(
     {p:two, n:two, u:ExprTuple(a, b), v:ExprTuple(c, d), a:ExprTuple(a, b), b:ExprTuple(c, d)},
     num_forall_eliminations=4)

# %%
# %qed
