# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Lambda, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("f")
subExpr2 = Variable("i")
subExpr3 = Variable("j")
subExpr4 = Variable("a")
expr = Lambda([subExpr1, subExpr2, subExpr3], Conditional(Equals([ExprRange(subExpr4, Function(subExpr1, subExpr4), subExpr2, subExpr3)], []), Equals(Add(subExpr3, one), subExpr2)))
# Out:
# expr: (f, i, j) -> {(f(i) ,  ...  , f(j)) = () if (j + 1) = i.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j\right) \mapsto \left\{\left(f\left(i\right) , \ldots , f\left(j\right)\right) = () \textrm{ if } \left(j + 1\right) = i\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f, i, j) -> {(f(i) ,  ...  , f(j)) = () if (j + 1) = i.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 19, 15, 16
# 2. {(f(i) ,  ...  , f(j)) = () if (j + 1) = i.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (f(i) ,  ...  , f(j)) = ()
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (j + 1) = i
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f(i) ,  ...  , f(j)) , ())
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (j + 1 , i)
#    core type: ExprTuple
#    sub-expressions: 10, 15
# 8. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. ()
#    core type: ExprTuple
#    sub-expressions:
# 10. j + 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
# ...
