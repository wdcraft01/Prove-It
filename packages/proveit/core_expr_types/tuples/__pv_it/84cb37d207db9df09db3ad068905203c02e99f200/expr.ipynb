# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import k
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_i
from proveit.logic import Equals, Forall
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i, b_1_to_i], Equals([a_1_to_i], [b_1_to_i]), condition = ExprRange(k, Equals(IndexedVar(Variable("a"), k), IndexedVar(Variable("b"), k)), one, Variable("i")))
# Out:
# expr: forall_{a_{1},...,a_{i}, b_{1},...,b_{i} | a_{1} = b_{1} ,  ...  , a_{i} = b_{i}} ((a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1},\ldots,a_{i}, b_{1},\ldots,b_{i}~|~a_{1} = b_{1} , \ldots , a_{i} = b_{i}}~\left(\left(a_{1} , \ldots , a_{i}\right) = \left(b_{1} , \ldots , b_{i}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1},...,a_{i}, b_{1},...,b_{i} | a_{1} = b_{1} ,  ...  , a_{i} = b_{i}} ((a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1},...,a_{i}, b_{1},...,b_{i}) -> {(a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}) if (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1} ,  ...  , a_{i} , b_{1} ,  ...  , b_{i})
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 4. {(a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}) if (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i})
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i})
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
