# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = Add(Variable("m"), one)
expr = ExprTuple(Equals([ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("m"))], [ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("m"))]), Equals(IndexedVar(subExpr2, subExpr3), IndexedVar(subExpr1, subExpr3)))
# Out:
# expr: ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) , a_{m + 1} = b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right) , a_{m + 1} = b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a_{m + 1} = b_{m + 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((a_{1} ,  ...  , a_{m}) , (b_{1} ,  ...  , b_{m}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a_{m + 1} , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. (a_{1} ,  ...  , a_{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (b_{1} ,  ...  , b_{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. a_{m + 1}
#    core type: IndexedVar
# variable: 22
# index: 12
# 9. b_{m + 1}
#    core type: IndexedVar
# variable: 21
# index: 12
# 10. a_{1},...,a_{m}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 20
#     end_index: 19
# ...
