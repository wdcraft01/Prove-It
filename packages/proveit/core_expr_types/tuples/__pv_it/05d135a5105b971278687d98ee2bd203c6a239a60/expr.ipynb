# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import Forall

# %%
# build up the expression from sub-expressions
subExpr1 = [A_1_to_m, Variable("B"), C_1_to_n]
expr = Forall(subExpr1, Variable("B"), conditions = subExpr1)
# Out:
# expr: forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A_{1},\ldots,A_{m}, B, C_{1},\ldots,C_{n}~|~A_{1} , \ldots , A_{m} , B , C_{1} , \ldots , C_{n}}~B

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (A_{1},...,A_{m}, B, C_{1},...,C_{n}) -> {B if A_{1} ,   ...  ,  A_{m} ,  B ,  C_{1} ,   ...  ,  C_{n}.
#    core type: Lambda
#    parameters: 6\n   body: 3
# 3. {B if A_{1} ,   ...  ,  A_{m} ,  B ,  C_{1} ,   ...  ,  C_{n}.
#    core type: Conditional
#    value: 8
#    condition: 4
# 4. A_{1} and  ...  and A_{m} and B and C_{1} and  ...  and C_{n}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A_{1},...,A_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 13
#    end_index: 11
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C_{1},...,C_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. a -> A_{a}
#     core type: Lambda
#     parameter: 19
#     body: 15
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. a -> C_{a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. A_{a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 16. C_{a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
