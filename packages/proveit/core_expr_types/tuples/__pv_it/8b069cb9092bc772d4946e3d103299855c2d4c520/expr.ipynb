# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#tuple_eq_def">tuple_eq_def</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._axioms_ import tuple_eq_def

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_eq_def
# Out:
# Passed sanity check: built 'tuple_eq_def' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_eq_def.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1},\ldots,a_{i}, b, c_{1},\ldots,c_{i}, d}~\left(\begin{array}{c} \left(\left(a_{1} , \ldots , a_{i} , b\right) = \left(c_{1} , \ldots , c_{i} , d\right)\right) =  \\ \left(\left(\left(a_{1} , \ldots , a_{i}\right) = \left(c_{1} , \ldots , c_{i}\right)\right) \land \left(b = d\right)\right) \end{array}\right)\right]

# %%
# display the expression information
tuple_eq_def.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1},...,a_{i}, b, c_{1},...,c_{i}, d} (((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)) =  \\ (((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d)))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1},...,a_{i}, b, c_{1},...,c_{i}, d} (((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)) =  \\ (((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))) if i in Naturals.
#    core type: Lambda
#    parameter: 33
#    body: 2
# 2. {forall_{a_{1},...,a_{i}, b, c_{1},...,c_{i}, d} (((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)) =  \\ (((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1},...,a_{i}, b, c_{1},...,c_{i}, d} (((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)) =  \\ (((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d)))
# ...
