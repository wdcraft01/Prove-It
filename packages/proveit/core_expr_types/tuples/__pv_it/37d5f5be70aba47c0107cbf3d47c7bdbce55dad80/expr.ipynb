# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Len
from proveit._common_ import i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
subExpr1 = [a_1_to_i]
expr = Forall(subExpr1, Equals(Len(subExpr1), i))
# Out:
# expr: forall_{a_{1},...,a_{i}} (|(a_{1} ,  ...  , a_{i})| = i)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1},\ldots,a_{i}}~\left(|\left(a_{1} , \ldots , a_{i}\right)| = i\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1},...,a_{i}} (|(a_{1} ,  ...  , a_{i})| = i)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1},...,a_{i}) -> (|(a_{1} ,  ...  , a_{i})| = i)
#    core type: Lambda
#    parameter: 10
#    body: 3
# 3. |(a_{1} ,  ...  , a_{i})| = i
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (|(a_{1} ,  ...  , a_{i})| , i)
#    core type: ExprTuple
#    sub-expressions: 6, 13
# 6. |(a_{1} ,  ...  , a_{i})|
#    core type: Operation
#    operator: 7
#    operand: 9
# 7. length
#    core type: Literal
#    sub-expressions:
# 8. ((a_{1} ,  ...  , a_{i}))
#    core type: ExprTuple
#    sub-expressions: 9
# 9. (a_{1} ,  ...  , a_{i})
#    core type: ExprTuple
#    sub-expressions: 10
# 10. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 11
#     start_index: 12
#     end_index: 13
# 11. b -> a_{b}
#     core type: Lambda
#     parameter: 16
#     body: 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. a_{b}
#     core type: IndexedVar
# variable: 15
# index: 16
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
