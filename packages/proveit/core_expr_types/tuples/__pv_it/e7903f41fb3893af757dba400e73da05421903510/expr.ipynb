# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable
from proveit.logic import And, Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("m"))
subExpr4 = ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("m"))
expr = Lambda([subExpr3, subExpr4], Conditional(Equals([subExpr3], [subExpr4]), And(ExprRange(Variable("k"), Equals(IndexedVar(subExpr2, Variable("k")), IndexedVar(subExpr1, Variable("k"))), one, Variable("m")))))
# Out:
# expr: (a_{1},...,a_{m}, b_{1},...,b_{m}) -> {(a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) if (a_{1} = b_{1}) and  ...  and (a_{m} = b_{m}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1},\ldots,a_{m}, b_{1},\ldots,b_{m}\right) \mapsto \left\{\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right) \textrm{ if } \left(a_{1} = b_{1}\right) \land \ldots \land \left(a_{m} = b_{m}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1},...,a_{m}, b_{1},...,b_{m}) -> {(a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) if (a_{1} = b_{1}) and  ...  and (a_{m} = b_{m}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1} ,  ...  , a_{m} , b_{1} ,  ...  , b_{m})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 2. {(a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) if (a_{1} = b_{1}) and  ...  and (a_{m} = b_{m}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (a_{1} = b_{1}) and  ...  and (a_{m} = b_{m})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a_{1} ,  ...  , a_{m}) , (b_{1} ,  ...  , b_{m}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} = b_{1} ,  ...  , a_{m} = b_{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (a_{1} ,  ...  , a_{m})
# ...
