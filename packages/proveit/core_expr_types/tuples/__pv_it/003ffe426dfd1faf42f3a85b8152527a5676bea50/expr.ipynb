# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import d
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_i
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
expr = And(Equals([a_1_to_i], [c_1_to_i]), Equals(Variable("b"), d))
# Out:
# expr: ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} , \ldots , a_{i}\right) = \left(c_{1} , \ldots , c_{i}\right)\right) \land \left(b = d\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i}) , b = d)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. b = d
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a_{1} ,  ...  , a_{i}) , (c_{1} ,  ...  , c_{i}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (b , d)
#    core type: ExprTuple
#    sub-expressions: 19, 10
# 8. (a_{1} ,  ...  , a_{i})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (c_{1} ,  ...  , c_{i})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. d
#     core type: Variable
#     sub-expressions:
# 11. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 15
#     end_index: 16
# 12. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 13. b -> a_{b}
#     core type: Lambda
#     parameter: 19
#     body: 17
# 14. a -> c_{a}
#     core type: Lambda
#     parameter: 21
#     body: 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. a_{b}
#     core type: IndexedVar
# variable: 21
# index: 19
# 18. c_{a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
