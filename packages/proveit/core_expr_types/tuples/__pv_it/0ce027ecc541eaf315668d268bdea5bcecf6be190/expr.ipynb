# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#range_extension_def">range_extension_def</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._axioms_ import range_extension_def

# %%
# check that the built expression is the same as the stored expression
# %check_expr range_extension_def
# Out:
# Passed sanity check: built 'range_extension_def' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(range_extension_def.latex())
# Out:
# \vdash \forall_{f, i, j~|~|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| \in \mathbb{N}}~\left(\begin{array}{c} \left(f\left(i\right) , \ldots , f\left(j + 1\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right) \end{array}\right)

# %%
# display the expression information
range_extension_def.exprInfo()
# Out:
# 0. forall_{f, i, j | |(f(i) ,  ...  , f(j))| in Naturals} ((f(i) ,  ...  , f(j + 1)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {(f(i) ,  ...  , f(j + 1)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1)) if |(f(i) ,  ...  , f(j))| in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 29, 26, 27
# 4. {(f(i) ,  ...  , f(j + 1)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1)) if |(f(i) ,  ...  , f(j))| in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i) ,  ...  , f(j + 1)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. |(f(i) ,  ...  , f(j))| in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. ((f(i) ,  ...  , f(j + 1)) , (f(i) ,  ...  , f(j) , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (|(f(i) ,  ...  , f(j))| , Naturals)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (f(i) ,  ...  , f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (f(i) ,  ...  , f(j) , f(j + 1))
#     core type: ExprTuple
#     sub-expressions: 23, 16
# 13. |(f(i) ,  ...  , f(j))|
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. Naturals
#     core type: Literal
#     sub-expressions:
# 15. f(i),...,f(j + 1)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 19
# 16. f(j + 1)
#     core type: Operation
#     operator: 29
#     operand: 19
# 17. length
#     core type: Literal
#     sub-expressions:
# 18. ((f(i) ,  ...  , f(j)))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. j + 1
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (f(i) ,  ...  , f(j))
#     core type: ExprTuple
#     sub-expressions: 23
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 23. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. a -> f(a)
#     core type: Lambda
#     parameter: 30
#     body: 28
# 26. i
#     core type: Variable
#     sub-expressions:
# 27. j
#     core type: Variable
#     sub-expressions:
# 28. f(a)
#     core type: Operation
#     operator: 29
#     operand: 30
# 29. f
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
