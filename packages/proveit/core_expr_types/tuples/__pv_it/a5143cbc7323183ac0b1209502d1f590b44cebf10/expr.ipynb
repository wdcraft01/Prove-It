# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Lambda, Len
from proveit._common_ import a, f, fa, i, j
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j], Conditional(Equals(Len([ExprRange(a, fa, i, j)]), Add(j, Neg(i), one)), InSet(Add(j, Neg(i), one), Naturals)))
# Out:
# expr: (f, i, j) -> {|(f(i) ,  ...  , f(j))| = (j - i + 1) if (j - i + 1) in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j\right) \mapsto \left\{|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| = \left(j - i + 1\right) \textrm{ if } \left(j - i + 1\right) \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f, i, j) -> {|(f(i) ,  ...  , f(j))| = (j - i + 1) if (j - i + 1) in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 25, 22, 23
# 2. {|(f(i) ,  ...  , f(j))| = (j - i + 1) if (j - i + 1) in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |(f(i) ,  ...  , f(j))| = (j - i + 1)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (j - i + 1) in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(f(i) ,  ...  , f(j))| , j - i + 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (j - i + 1 , Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. |(f(i) ,  ...  , f(j))|
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. j - i + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Naturals
#     core type: Literal
#     sub-expressions:
# 12. length
#     core type: Literal
#     sub-expressions:
# 13. ((f(i) ,  ...  , f(j)))
#     core type: ExprTuple
#     sub-expressions: 16
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (j , -i , 1)
#     core type: ExprTuple
#     sub-expressions: 23, 17, 18
# 16. (f(i) ,  ...  , f(j))
#     core type: ExprTuple
#     sub-expressions: 19
# 17. -i
#     core type: Operation
#     operator: 20
#     operand: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. a -> f(a)
#     core type: Lambda
#     parameter: 26
#     body: 24
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. j
#     core type: Variable
#     sub-expressions:
# 24. f(a)
#     core type: Operation
#     operator: 25
#     operand: 26
# 25. f
#     core type: Variable
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
