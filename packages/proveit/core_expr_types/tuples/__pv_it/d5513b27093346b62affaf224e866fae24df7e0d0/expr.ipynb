# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import m
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(m, one)
expr = Equals([ExprRange(Variable("b"), IndexedVar(Variable("a"), Variable("b")), one, m), IndexedVar(Variable("a"), subExpr1)], [ExprRange(Variable("a"), IndexedVar(Variable("b"), Variable("a")), one, m), IndexedVar(Variable("b"), subExpr1)])
# Out:
# expr: (a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} , \ldots , a_{m} , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m} , b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} ,  ...  , a_{m} , a_{m + 1}) , (b_{1} ,  ...  , b_{m} , b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_{1} ,  ...  , a_{m} , a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (b_{1} ,  ...  , b_{m} , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. a_{1},...,a_{m}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 19
#    end_index: 18
# 6. a_{m + 1}
#    core type: IndexedVar
# variable: 17
# index: 11
# 7. b_{1},...,b_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 19
#    end_index: 18
# 8. b_{m + 1}
#    core type: IndexedVar
# variable: 16
# index: 11
# 9. b -> a_{b}
#    core type: Lambda
#    parameter: 16
#    body: 12
# 10. a -> b_{a}
#     core type: Lambda
#     parameter: 17
#     body: 13
# 11. m + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. a_{b}
#     core type: IndexedVar
# variable: 17
# index: 16
# 13. b_{a}
#     core type: IndexedVar
# variable: 16
# index: 17
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (m , 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
