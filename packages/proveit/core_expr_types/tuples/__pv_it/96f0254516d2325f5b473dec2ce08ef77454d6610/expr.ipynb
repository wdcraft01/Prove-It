# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function
from proveit._common_ import a, f, fa, i, j
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals([ExprRange(a, fa, i, j)], [ExprRange(a, fa, i, Add(j, Neg(one))), Function(f, j)]).withWrappingAt(2), InSet(Add(j, Neg(i)), Naturals))
# Out:
# expr: {(f(i) ,  ...  , f(j)) =  \\ (f(i) ,  ...  , f(j - 1) , f(j)) if (j - i) in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left(f\left(i\right) , \ldots , f\left(j\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(j - 1\right) , f\left(j\right)\right) \end{array} \textrm{ if } \left(j - i\right) \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(f(i) ,  ...  , f(j)) =  \\ (f(i) ,  ...  , f(j - 1) , f(j)) if (j - i) in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (f(i) ,  ...  , f(j)) =  \\ (f(i) ,  ...  , f(j - 1) , f(j))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (j - i) in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((f(i) ,  ...  , f(j)) , (f(i) ,  ...  , f(j - 1) , f(j)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j - i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (f(i) ,  ...  , f(j - 1) , f(j))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. j - i
#    core type: Operation
#    operator: 19
#    operands: 14
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. f(i),...,f(j)
# ...
