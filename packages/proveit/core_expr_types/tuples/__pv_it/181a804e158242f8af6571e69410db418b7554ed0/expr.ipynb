# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, Variable
from proveit.logic import Forall
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Function(Variable("P"), one), Forall([Variable("m")], Function(Variable("P"), Add(Variable("m"), one)), domain = NaturalsPos, condition = Function(Variable("P"), Variable("m"))))
# Out:
# expr: (P(1) , forall_{m in NaturalsPos | P(m)} P(m + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P\left(1\right) , \forall_{m \in \mathbb{N}^+~|~P\left(m\right)}~P\left(m + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(1) , forall_{m in NaturalsPos | P(m)} P(m + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(1)
#    core type: Operation
#    operator: 18
#    operand: 15
# 2. forall_{m in NaturalsPos | P(m)} P(m + 1)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. m -> {P(m + 1) if m in NaturalsPos ,  P(m).
#    core type: Lambda
#    parameter: 19
#    body: 5
# 5. {P(m + 1) if m in NaturalsPos ,  P(m).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. P(m + 1)
#    core type: Operation
#    operator: 18
#    operand: 8
# 7. (m in NaturalsPos) and P(m)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. m + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (m in NaturalsPos , P(m))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. +
#     core type: Literal
#     sub-expressions:
# ...
