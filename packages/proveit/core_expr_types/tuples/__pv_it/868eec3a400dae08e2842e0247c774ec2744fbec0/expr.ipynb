# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Lambda, Len
from proveit._common_ import a, f, fa, i, j
from proveit.logic import InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j], Conditional(InSet(Len([ExprRange(a, fa, i, j)]), Naturals), InSet(Add(j, Neg(i), one), Naturals)))
# Out:
# expr: (f, i, j) -> {|(f(i) ,  ...  , f(j))| in Naturals if (j - i + 1) in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j\right) \mapsto \left\{|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| \in \mathbb{N} \textrm{ if } \left(j - i + 1\right) \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f, i, j) -> {|(f(i) ,  ...  , f(j))| in Naturals if (j - i + 1) in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 24, 21, 22
# 2. {|(f(i) ,  ...  , f(j))| in Naturals if (j - i + 1) in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |(f(i) ,  ...  , f(j))| in Naturals
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (j - i + 1) in Naturals
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|(f(i) ,  ...  , f(j))| , Naturals)
#    core type: ExprTuple
#    sub-expressions: 8, 10
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (j - i + 1 , Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. |(f(i) ,  ...  , f(j))|
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. j - i + 1
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. length
#     core type: Literal
#     sub-expressions:
# 12. ((f(i) ,  ...  , f(j)))
#     core type: ExprTuple
#     sub-expressions: 15
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (j , -i , 1)
#     core type: ExprTuple
#     sub-expressions: 22, 16, 17
# 15. (f(i) ,  ...  , f(j))
#     core type: ExprTuple
#     sub-expressions: 18
# 16. -i
#     core type: Operation
#     operator: 19
#     operand: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 22
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. a -> f(a)
#     core type: Lambda
#     parameter: 25
#     body: 23
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. j
#     core type: Variable
#     sub-expressions:
# 23. f(a)
#     core type: Operation
#     operator: 24
#     operand: 25
# 24. f
#     core type: Variable
#     sub-expressions:
# 25. a
#     core type: Variable
#     sub-expressions:
