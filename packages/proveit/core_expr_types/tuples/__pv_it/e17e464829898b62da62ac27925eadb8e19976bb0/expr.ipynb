# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit.logic import Equals, Forall, InSet, Set
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("m"))
subExpr4 = ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("m"))
subExpr5 = Equals(IndexedVar(subExpr2, Variable("k")), IndexedVar(subExpr1, Variable("k")))
expr = Set(InSet(Variable("m"), NaturalsPos), Forall([subExpr3, subExpr4], Equals([subExpr3], [subExpr4]), condition = ExprRange(Variable("k"), subExpr5, one, Variable("m"))), ExprRange(Variable("k"), subExpr5, one, Add(Variable("m"), one)))
# Out:
# expr: {m in NaturalsPos , forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) , a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{m \in \mathbb{N}^+ , \forall_{a_{1},\ldots,a_{m}, b_{1},\ldots,b_{m}~|~a_{1} = b_{1} , \ldots , a_{m} = b_{m}}~\left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right)\right) , a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}\right\}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {m in NaturalsPos , forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) , a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (m in NaturalsPos , forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) , a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. m in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}))
#    core type: Operation
#    operator: 8
#    operand: 9
# 5. (a_{1} = b_{1}),...,(a_{m + 1} = b_{m + 1})
#    core type: ExprRange
#    lambda_map: 26
#    start_index: 29
# ...
