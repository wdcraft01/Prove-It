# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit.core_expr_types._common_ import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = Lambda([A_1_to_l, B_1_to_m, C_1_to_n], Conditional(And(B_1_to_m), And(A_1_to_l, B_1_to_m, C_1_to_n)))
# Out:
# expr: (A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n}) -> {B_{1} and  ...  and B_{m} if A_{1} ,   ...  ,  A_{l} ,  B_{1} ,   ...  ,  B_{m} ,  C_{1} ,   ...  ,  C_{n}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A_{1},\ldots,A_{l}, B_{1},\ldots,B_{m}, C_{1},\ldots,C_{n}\right) \mapsto \left\{B_{1} \land \ldots \land B_{m} \textrm{ if } A_{1} ,  \ldots ,  A_{l} ,  B_{1} ,  \ldots ,  B_{m} ,  C_{1} ,  \ldots ,  C_{n}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n}) -> {B_{1} and  ...  and B_{m} if A_{1} ,   ...  ,  A_{l} ,  B_{1} ,   ...  ,  B_{m} ,  C_{1} ,   ...  ,  C_{n}.
#    core type: Lambda
#    parameters: 6\n   body: 1
# 1. {B_{1} and  ...  and B_{m} if A_{1} ,   ...  ,  A_{l} ,  B_{1} ,   ...  ,  B_{m} ,  C_{1} ,   ...  ,  C_{n}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. B_{1} and  ...  and B_{m}
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. A_{1} and  ...  and A_{l} and B_{1} and  ...  and B_{m} and C_{1} and  ...  and C_{n}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B_{1} ,  ...  , B_{m})
#    core type: ExprTuple
#    sub-expressions: 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. A_{1},...,A_{l}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 15
#    end_index: 11
# 8. B_{1},...,B_{m}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 15
#    end_index: 13
# 9. C_{1},...,C_{n}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 15
#    end_index: 16
# 10. a -> A_{a}
#     core type: Lambda
#     parameter: 23
#     body: 17
# 11. l
#     core type: Variable
#     sub-expressions:
# 12. a -> B_{a}
#     core type: Lambda
#     parameter: 23
#     body: 18
# 13. m
#     core type: Variable
#     sub-expressions:
# 14. a -> C_{a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. A_{a}
#     core type: IndexedVar
# variable: 20
# index: 23
# 18. B_{a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 19. C_{a}
#     core type: IndexedVar
# variable: 22
# index: 23
# 20. A
#     core type: Variable
#     sub-expressions:
# 21. B
#     core type: Variable
#     sub-expressions:
# 22. C
#     core type: Variable
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
