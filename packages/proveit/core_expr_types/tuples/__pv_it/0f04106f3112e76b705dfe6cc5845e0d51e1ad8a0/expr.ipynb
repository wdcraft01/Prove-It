# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("d")
subExpr2 = Variable("a")
subExpr3 = Variable("b")
subExpr4 = Add(Variable("m"), one)
expr = ExprTuple(ExprRange(subExpr1, Equals(IndexedVar(subExpr2, subExpr1), IndexedVar(subExpr3, subExpr1)), one, Variable("m")), Equals(IndexedVar(subExpr2, subExpr4), IndexedVar(subExpr3, subExpr4)))
# Out:
# expr: (a_{1} = b_{1} ,  ...  , a_{m} = b_{m} , a_{m + 1} = b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} = b_{1} , \ldots , a_{m} = b_{m} , a_{m + 1} = b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} = b_{1} ,  ...  , a_{m} = b_{m} , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} = b_{1}),...,(a_{m} = b_{m})
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 19
#    end_index: 18
# 2. a_{m + 1} = b_{m + 1}
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. d -> (a_{d} = b_{d})
#    core type: Lambda
#    parameter: 17
#    body: 5
# 4. (a_{m + 1} , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. a_{d} = b_{d}
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. a_{m + 1}
#    core type: IndexedVar
# variable: 15
# index: 10
# 7. b_{m + 1}
#    core type: IndexedVar
# variable: 16
# index: 10
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (a_{d} , b_{d})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. m + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. a_{d}
#     core type: IndexedVar
# variable: 15
# index: 17
# 12. b_{d}
# ...
