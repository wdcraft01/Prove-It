# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Len
from proveit._common_ import a, fa, i, j, k
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Len([ExprRange(a, fa, i, j)]), Len([ExprRange(k, k, i, j)])), InSet(Add(j, Neg(i), one), Naturals))
# Out:
# expr: {|(f(i) ,  ...  , f(j))| = |(i ,  ...  , j)| if (j - i + 1) in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| = |\left(i , \ldots , j\right)| \textrm{ if } \left(j - i + 1\right) \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {|(f(i) ,  ...  , f(j))| = |(i ,  ...  , j)| if (j - i + 1) in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |(f(i) ,  ...  , f(j))| = |(i ,  ...  , j)|
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (j - i + 1) in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|(f(i) ,  ...  , f(j))| , |(i ,  ...  , j)|)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j - i + 1 , Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. |(f(i) ,  ...  , f(j))|
#    core type: Operation
#    operator: 12
#    operand: 16
# 8. |(i ,  ...  , j)|
#    core type: Operation
#    operator: 12
#    operand: 17
# 9. j - i + 1
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. ((f(i) ,  ...  , f(j)))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. length
#     core type: Literal
#     sub-expressions:
# 13. ((i ,  ...  , j))
#     core type: ExprTuple
#     sub-expressions: 17
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (j , -i , 1)
#     core type: ExprTuple
#     sub-expressions: 26, 18, 19
# 16. (f(i) ,  ...  , f(j))
#     core type: ExprTuple
#     sub-expressions: 20
# 17. (i ,  ...  , j)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. -i
#     core type: Operation
#     operator: 22
#     operand: 25
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 25
#     end_index: 26
# 21. i,...,j
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. a -> f(a)
#     core type: Lambda
#     parameter: 30
#     body: 27
# 24. k -> k
#     core type: Lambda
#     parameter: 28
#     body: 28
# 25. i
#     core type: Variable
#     sub-expressions:
# 26. j
#     core type: Variable
#     sub-expressions:
# 27. f(a)
#     core type: Operation
#     operator: 29
#     operand: 30
# 28. k
#     core type: Variable
#     sub-expressions:
# 29. f
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
