# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import P, n
from proveit.core_expr_types._common_ import P__x_1_to_n, P__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([P, x_1_to_n, y_1_to_n], P__y_1_to_n, conditions = [P__x_1_to_n, Equals([x_1_to_n], [y_1_to_n])]), InSet(n, Naturals)))
# Out:
# expr: n -> {forall_{P, x_{1},...,x_{n}, y_{1},...,y_{n} | P(x_{1} ,  ...  , x_{n}) , (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} P(y_{1} ,  ...  , y_{n}) if n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{P, x_{1},\ldots,x_{n}, y_{1},\ldots,y_{n}~|~P\left(x_{1} , \ldots , x_{n}\right) , \left(x_{1} , \ldots , x_{n}\right) = \left(y_{1} , \ldots , y_{n}\right)}~P\left(y_{1} , \ldots , y_{n}\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{P, x_{1},...,x_{n}, y_{1},...,y_{n} | P(x_{1} ,  ...  , x_{n}) , (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} P(y_{1} ,  ...  , y_{n}) if n in Naturals.
#    core type: Lambda
#    parameter: 27
#    body: 1
# 1. {forall_{P, x_{1},...,x_{n}, y_{1},...,y_{n} | P(x_{1} ,  ...  , x_{n}) , (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} P(y_{1} ,  ...  , y_{n}) if n in Naturals.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{P, x_{1},...,x_{n}, y_{1},...,y_{n} | P(x_{1} ,  ...  , x_{n}) , (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} P(y_{1} ,  ...  , y_{n})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in Naturals
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (P, x_{1},...,x_{n}, y_{1},...,y_{n}) -> {P(y_{1} ,  ...  , y_{n}) if P(x_{1} ,  ...  , x_{n}) ,  (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n}).
#    core type: Lambda
# ...
