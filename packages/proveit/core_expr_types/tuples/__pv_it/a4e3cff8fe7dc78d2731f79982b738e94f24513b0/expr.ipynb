# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#tuple_len_incr">tuple_len_incr</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._axioms_ import tuple_len_incr

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_len_incr
# Out:
# Passed sanity check: built 'tuple_len_incr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len_incr.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1},\ldots,a_{i}, b}~\left(|\left(a_{1} , \ldots , a_{i} , b\right)| = \left(i + 1\right)\right)\right]

# %%
# display the expression information
tuple_len_incr.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1},...,a_{i}, b} (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1},...,a_{i}, b} (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1)) if i in Naturals.
#    core type: Lambda
#    parameter: 23
#    body: 2
# 2. {forall_{a_{1},...,a_{i}, b} (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1)) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1},...,a_{i}, b} (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1},...,a_{i}, b) -> (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1))
#    core type: Lambda
#    parameters: 19\n   body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 23, 10
# 9. |(a_{1} ,  ...  , a_{i} , b)| = (i + 1)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (|(a_{1} ,  ...  , a_{i} , b)| , i + 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. |(a_{1} ,  ...  , a_{i} , b)|
#     core type: Operation
#     operator: 15
#     operand: 19
# 14. i + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. length
#     core type: Literal
#     sub-expressions:
# 16. ((a_{1} ,  ...  , a_{i} , b))
#     core type: ExprTuple
#     sub-expressions: 19
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (i , 1)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 19. (a_{1} ,  ...  , a_{i} , b)
#     core type: ExprTuple
#     sub-expressions: 20, 26
# 20. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 21. b -> a_{b}
#     core type: Lambda
#     parameter: 26
#     body: 24
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. i
#     core type: Variable
#     sub-expressions:
# 24. a_{b}
#     core type: IndexedVar
# variable: 25
# index: 26
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
