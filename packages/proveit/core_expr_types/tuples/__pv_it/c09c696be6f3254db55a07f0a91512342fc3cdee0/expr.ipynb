# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, Len
from proveit._common_ import a, b, fa, i
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([ExprRange(a, fa, one, i), b]), Add(i, one))
# Out:
# expr: |(f(1) ,  ...  , f(i) , b)| = (i + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(f\left(1\right) , \ldots , f\left(i\right) , b\right)| = \left(i + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(f(1) ,  ...  , f(i) , b)| = (i + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(f(1) ,  ...  , f(i) , b)| , i + 1)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(f(1) ,  ...  , f(i) , b)|
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. i + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((f(1) ,  ...  , f(i) , b))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (i , 1)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 9. (f(1) ,  ...  , f(i) , b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. f(1),...,f(i)
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. a -> f(a)
#     core type: Lambda
#     parameter: 17
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. f(a)
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
