# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable
from proveit._common_ import d
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_i
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
expr = ExprTuple(Equals([a_1_to_i, subExpr1], [c_1_to_i, d]), And(Equals([a_1_to_i], [c_1_to_i]), Equals(subExpr1, d)))
# Out:
# expr: ((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d) , ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} , \ldots , a_{i} , b\right) = \left(c_{1} , \ldots , c_{i} , d\right) , \left(\left(a_{1} , \ldots , a_{i}\right) = \left(c_{1} , \ldots , c_{i}\right)\right) \land \left(b = d\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d) , ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((a_{1} ,  ...  , a_{i} , b) , (c_{1} ,  ...  , c_{i} , d))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i}) , b = d)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. (a_{1} ,  ...  , a_{i} , b)
#    core type: ExprTuple
#    sub-expressions: 16, 24
# 7. (c_{1} ,  ...  , c_{i} , d)
#    core type: ExprTuple
#    sub-expressions: 17, 15
# 8. (a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})
#    core type: Operation
#    operator: 11
#    operands: 10
# 9. b = d
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. ((a_{1} ,  ...  , a_{i}) , (c_{1} ,  ...  , c_{i}))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (b , d)
#     core type: ExprTuple
#     sub-expressions: 24, 15
# 13. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 16
# 14. (c_{1} ,  ...  , c_{i})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. d
#     core type: Variable
#     sub-expressions:
# 16. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 20
#     end_index: 21
# 17. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. b -> a_{b}
#     core type: Lambda
#     parameter: 24
#     body: 22
# 19. a -> c_{a}
#     core type: Lambda
#     parameter: 26
#     body: 23
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. a_{b}
#     core type: IndexedVar
# variable: 26
# index: 24
# 23. c_{a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
