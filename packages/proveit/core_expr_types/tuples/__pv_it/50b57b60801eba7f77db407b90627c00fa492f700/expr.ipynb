# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Len, Variable
from proveit.logic import Equals, InSet
from proveit.number import Add, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("f")
subExpr2 = Add(Variable("j"), one)
subExpr3 = ExprRange(Variable("a"), Function(subExpr1, Variable("a")), Variable("i"), Variable("j"))
expr = Conditional(Equals([subExpr3, Function(subExpr1, subExpr2)], [ExprRange(Variable("a"), Function(subExpr1, Variable("a")), Variable("i"), subExpr2)]), InSet(Len([subExpr3]), Naturals))
# Out:
# expr: {(f(i) ,  ...  , f(j) , f(j + 1)) = (f(i) ,  ...  , f(j + 1)) if |(f(i) ,  ...  , f(j))| in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right) = \left(f\left(i\right) , \ldots , f\left(j + 1\right)\right) \textrm{ if } |\left(f\left(i\right) , \ldots , f\left(j\right)\right)| \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(f(i) ,  ...  , f(j) , f(j + 1)) = (f(i) ,  ...  , f(j + 1)) if |(f(i) ,  ...  , f(j))| in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (f(i) ,  ...  , f(j) , f(j + 1)) = (f(i) ,  ...  , f(j + 1))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. |(f(i) ,  ...  , f(j))| in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((f(i) ,  ...  , f(j) , f(j + 1)) , (f(i) ,  ...  , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (|(f(i) ,  ...  , f(j))| , Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 8. (f(i) ,  ...  , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 12
# 9. |(f(i) ,  ...  , f(j))|
#    core type: Operation
#    operator: 13
#    operand: 16
# 10. Naturals
# ...
