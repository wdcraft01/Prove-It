# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#extension_range_len_val">extension_range_len_val</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import extension_range_len_val

# %%
# check that the built expression is the same as the stored expression
# %check_expr extension_range_len_val
# Out:
# Passed sanity check: built 'extension_range_len_val' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(extension_range_len_val.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{i, j~|~|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| \in \mathbb{N}}~\left(|\left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right)| = \left(j - i\right)\right)\right]

# %%
# display the expression information
extension_range_len_val.exprInfo()
# Out:
# 0. forall_{f} [forall_{i, j | |(f(i) ,  ...  , f(j))| in Naturals} (|(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i))]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. f -> [forall_{i, j | |(f(i) ,  ...  , f(j))| in Naturals} (|(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i))]
#    core type: Lambda
#    parameter: 35
#    body: 2
# 2. forall_{i, j | |(f(i) ,  ...  , f(j))| in Naturals} (|(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i))
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (i, j) -> {|(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i) if |(f(i) ,  ...  , f(j))| in Naturals.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (i , j)
#    core type: ExprTuple
#    sub-expressions: 29, 33
# 6. {|(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i) if |(f(i) ,  ...  , f(j))| in Naturals.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. |(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i)
# ...
