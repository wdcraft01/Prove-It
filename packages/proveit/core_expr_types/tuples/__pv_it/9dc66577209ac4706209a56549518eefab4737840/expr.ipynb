# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit._common_ import l, m, n
from proveit.core_expr_types._common_ import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = [A_1_to_l, B_1_to_m, C_1_to_n]
expr = Lambda([l, m, n], Conditional(Forall(subExpr1, And(B_1_to_m), conditions = subExpr1), And(InSet(l, Naturals), InSet(m, Naturals), InSet(n, Naturals))))
# Out:
# expr: (l, m, n) -> {forall_{A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n} | A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n}} (B_{1} and  ...  and B_{m}) if l in Naturals ,  m in Naturals ,  n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l, m, n\right) \mapsto \left\{\forall_{A_{1},\ldots,A_{l}, B_{1},\ldots,B_{m}, C_{1},\ldots,C_{n}~|~A_{1} , \ldots , A_{l} , B_{1} , \ldots , B_{m} , C_{1} , \ldots , C_{n}}~\left(B_{1} \land \ldots \land B_{m}\right) \textrm{ if } l \in \mathbb{N} ,  m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (l, m, n) -> {forall_{A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n} | A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n}} (B_{1} and  ...  and B_{m}) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (l , m , n)
#    core type: ExprTuple
#    sub-expressions: 26, 28, 31
# 2. {forall_{A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n} | A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n}} (B_{1} and  ...  and B_{m}) if l in Naturals ,  m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n} | A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n}} (B_{1} and  ...  and B_{m})
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (l in Naturals) and (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (A_{1},...,A_{l}, B_{1},...,B_{m}, C_{1},...,C_{n}) -> {B_{1} and  ...  and B_{m} if A_{1} ,   ...  ,  A_{l} ,  B_{1} ,   ...  ,  B_{m} ,  C_{1} ,   ...  ,  C_{n}.
#    core type: Lambda
#    parameters: 20\n   body: 8
# 7. (l in Naturals , m in Naturals , n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. {B_{1} and  ...  and B_{m} if A_{1} ,   ...  ,  A_{l} ,  B_{1} ,   ...  ,  B_{m} ,  C_{1} ,   ...  ,  C_{n}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 9. l in Naturals
#    core type: Operation
#    operator: 16
#    operands: 14
# 10. m in Naturals
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. n in Naturals
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. B_{1} and  ...  and B_{m}
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. A_{1} and  ...  and A_{l} and B_{1} and  ...  and B_{m} and C_{1} and  ...  and C_{n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (l , Naturals)
#     core type: ExprTuple
#     sub-expressions: 26, 21
# 15. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 28, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 31, 21
# 18. (B_{1} ,  ...  , B_{m})
#     core type: ExprTuple
#     sub-expressions: 23
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n})
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 21. Naturals
#     core type: Literal
#     sub-expressions:
# 22. A_{1},...,A_{l}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 30
#     end_index: 26
# 23. B_{1},...,B_{m}
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 30
#     end_index: 28
# 24. C_{1},...,C_{n}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 30
#     end_index: 31
# 25. a -> A_{a}
#     core type: Lambda
#     parameter: 38
#     body: 32
# 26. l
#     core type: Variable
#     sub-expressions:
# 27. a -> B_{a}
#     core type: Lambda
#     parameter: 38
#     body: 33
# 28. m
#     core type: Variable
#     sub-expressions:
# 29. a -> C_{a}
#     core type: Lambda
#     parameter: 38
#     body: 34
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. n
#     core type: Variable
#     sub-expressions:
# 32. A_{a}
#     core type: IndexedVar
# variable: 35
# index: 38
# 33. B_{a}
#     core type: IndexedVar
# variable: 36
# index: 38
# 34. C_{a}
#     core type: IndexedVar
# variable: 37
# index: 38
# 35. A
#     core type: Variable
#     sub-expressions:
# 36. B
#     core type: Variable
#     sub-expressions:
# 37. C
#     core type: Variable
#     sub-expressions:
# 38. a
#     core type: Variable
#     sub-expressions:
