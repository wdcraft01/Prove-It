# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Lambda
from proveit._common_ import a, f, fa, i, j
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j], Conditional(Equals([Function(f, i), Function(f, j)], [ExprRange(a, fa, i, j)]), Equals(j, Add(i, one))))
# Out:
# expr: (f, i, j) -> {(f(i) , f(j)) = (f(i) ,  ...  , f(j)) if j = (i + 1).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j\right) \mapsto \left\{\left(f\left(i\right) , f\left(j\right)\right) = \left(f\left(i\right) , \ldots , f\left(j\right)\right) \textrm{ if } j = \left(i + 1\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f, i, j) -> {(f(i) , f(j)) = (f(i) ,  ...  , f(j)) if j = (i + 1).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 21, 18, 17
# 2. {(f(i) , f(j)) = (f(i) ,  ...  , f(j)) if j = (i + 1).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (f(i) , f(j)) = (f(i) ,  ...  , f(j))
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. j = (i + 1)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f(i) , f(j)) , (f(i) ,  ...  , f(j)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (j , i + 1)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 8. (f(i) , f(j))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 13
# 10. i + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. f(i)
#     core type: Operation
#     operator: 21
#     operand: 18
# 12. f(j)
#     core type: Operation
#     operator: 21
#     operand: 17
# 13. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 18
#     end_index: 17
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (i , 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. a -> f(a)
#     core type: Lambda
#     parameter: 22
#     body: 20
# 17. j
#     core type: Variable
#     sub-expressions:
# 18. i
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. f(a)
#     core type: Operation
#     operator: 21
#     operand: 22
# 21. f
#     core type: Variable
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
