# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Len
from proveit._common_ import a, f, fa, i, j, k
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_i, f, j, k], Equals(Len([a_1_to_i, ExprRange(a, fa, j, k)]), Add(i, k, Neg(j), one)).withWrappingAt(2), condition = InSet(Add(k, Neg(j), one), Naturals)), InSet(i, Naturals))
# Out:
# expr: {forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1)) if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1},\ldots,a_{i}, f, j, k~|~\left(k - j + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} |\left(a_{1} , \ldots , a_{i} , f\left(j\right) , \ldots , f\left(k\right)\right)| =  \\ \left(i + k - j + 1\right) \end{array}\right) \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1)) if i in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. i in Naturals
#    core type: Operation
#    operator: 12
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1},...,a_{i}, f, j, k) -> {|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1) if (k - j + 1) in Naturals.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 5. (i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 30, 17
# 6. (a_{1} ,  ...  , a_{i} , f , j , k)
#    core type: ExprTuple
#    sub-expressions: 25, 37, 32, 33
# ...
