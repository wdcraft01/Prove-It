# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit.logic import Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("c")
subExpr2 = Variable("a")
subExpr3 = Variable("b")
expr = Equals([ExprRange(subExpr1, Equals(IndexedVar(subExpr2, subExpr1), IndexedVar(subExpr3, subExpr1)), one, one)], [Equals(IndexedVar(subExpr2, one), IndexedVar(subExpr3, one))])
# Out:
# expr: (a_{1} = b_{1} ,  ...  , a_{1} = b_{1}) = (a_{1} = b_{1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} = b_{1} , \ldots , a_{1} = b_{1}\right) = \left(a_{1} = b_{1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} = b_{1} ,  ...  , a_{1} = b_{1}) = (a_{1} = b_{1})
#    core type: Operation
#    operator: 11
#    operands: 1
# 1. ((a_{1} = b_{1} ,  ...  , a_{1} = b_{1}) , (a_{1} = b_{1}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (a_{1} = b_{1} ,  ...  , a_{1} = b_{1})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (a_{1} = b_{1})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (a_{1} = b_{1}),...,(a_{1} = b_{1})
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 13
#    end_index: 13
# 5. a_{1} = b_{1}
#    core type: Operation
#    operator: 11
#    operands: 7
# 6. c -> (a_{c} = b_{c})
#    core type: Lambda
#    parameter: 18
#    body: 8
# 7. (a_{1} , b_{1})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. a_{c} = b_{c}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a_{1}
#    core type: IndexedVar
# variable: 16
# index: 13
# 10. b_{1}
#     core type: IndexedVar
# variable: 17
# index: 13
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (a_{c} , b_{c})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. a_{c}
#     core type: IndexedVar
# variable: 16
# index: 18
# 15. b_{c}
#     core type: IndexedVar
# variable: 17
# index: 18
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
