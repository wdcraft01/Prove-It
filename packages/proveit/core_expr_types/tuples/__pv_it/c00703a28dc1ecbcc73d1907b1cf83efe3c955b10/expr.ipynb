# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import m, n
from proveit.core_expr_types._common_ import A_1_to_m, C_1_to_n
from proveit.logic import Forall
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = [A_1_to_m, Variable("B"), C_1_to_n]
expr = Forall([m, n], Forall(subExpr1, Variable("B"), conditions = subExpr1), domains = [Naturals, Naturals])
# Out:
# expr: forall_{m in Naturals , n in Naturals} [forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N} , n \in \mathbb{N}}~\left[\forall_{A_{1},\ldots,A_{m}, B, C_{1},\ldots,C_{n}~|~A_{1} , \ldots , A_{m} , B , C_{1} , \ldots , C_{n}}~B\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m in Naturals , n in Naturals} [forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B]
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. (m, n) -> {forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B if m in Naturals ,  n in Naturals.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (m , n)
#    core type: ExprTuple
#    sub-expressions: 23, 26
# 3. {forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B if m in Naturals ,  n in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{A_{1},...,A_{m}, B, C_{1},...,C_{n} | A_{1} ,  ...  , A_{m} , B , C_{1} ,  ...  , C_{n}} B
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (m in Naturals) and (n in Naturals)
#    core type: Operation
#    operator: 16
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# ...
