# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#tuple_len">tuple_len</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import tuple_len

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_len
# Out:
# Passed sanity check: built 'tuple_len' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_len.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1},\ldots,a_{i}}~\left(|\left(a_{1} , \ldots , a_{i}\right)| = i\right)\right]

# %%
# display the expression information
tuple_len.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1},...,a_{i}} (|(a_{1} ,  ...  , a_{i})| = i)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1},...,a_{i}} (|(a_{1} ,  ...  , a_{i})| = i) if i in Naturals.
#    core type: Lambda
#    parameter: 20
#    body: 2
# 2. {forall_{a_{1},...,a_{i}} (|(a_{1} ,  ...  , a_{i})| = i) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1},...,a_{i}} (|(a_{1} ,  ...  , a_{i})| = i)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Naturals
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (a_{1},...,a_{i}) -> (|(a_{1} ,  ...  , a_{i})| = i)
#    core type: Lambda
#    parameter: 17
#    body: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 20, 10
# 9. |(a_{1} ,  ...  , a_{i})| = i
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. Naturals
#     core type: Literal
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (|(a_{1} ,  ...  , a_{i})| , i)
#     core type: ExprTuple
#     sub-expressions: 13, 20
# 13. |(a_{1} ,  ...  , a_{i})|
#     core type: Operation
#     operator: 14
#     operand: 16
# 14. length
#     core type: Literal
#     sub-expressions:
# 15. ((a_{1} ,  ...  , a_{i}))
#     core type: ExprTuple
#     sub-expressions: 16
# 16. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 19
#     end_index: 20
# 18. b -> a_{b}
#     core type: Lambda
#     parameter: 23
#     body: 21
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. i
#     core type: Variable
#     sub-expressions:
# 21. a_{b}
#     core type: IndexedVar
# variable: 22
# index: 23
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
