# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = Add(Variable("m"), one)
expr = Equals([ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, subExpr3)], [ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, subExpr3)])
# Out:
# expr: (a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} , \ldots , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} ,  ...  , a_{m + 1}) , (b_{1} ,  ...  , b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_{1} ,  ...  , a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (b_{1} ,  ...  , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. a_{1},...,a_{m + 1}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 17
#    end_index: 9
# 6. b_{1},...,b_{m + 1}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 17
#    end_index: 9
# 7. b -> a_{b}
#    core type: Lambda
#    parameter: 14
#    body: 10
# 8. a -> b_{a}
#    core type: Lambda
#    parameter: 15
#    body: 11
# 9. m + 1
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a_{b}
#     core type: IndexedVar
# variable: 15
# index: 14
# 11. b_{a}
#     core type: IndexedVar
# variable: 14
# index: 15
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (m , 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
