# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable
from proveit.logic import Equals, Forall, InSet
from proveit.number import NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("n"))
subExpr4 = ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("n"))
expr = Lambda(Variable("n"), Conditional(Forall([subExpr3, subExpr4], Equals([subExpr3], [subExpr4]), condition = ExprRange(Variable("k"), Equals(IndexedVar(subExpr2, Variable("k")), IndexedVar(subExpr1, Variable("k"))), one, Variable("n"))), InSet(Variable("n"), NaturalsPos)))
# Out:
# expr: n -> {forall_{a_{1},...,a_{n}, b_{1},...,b_{n} | a_{1} = b_{1} ,  ...  , a_{n} = b_{n}} ((a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n})) if n in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a_{1},\ldots,a_{n}, b_{1},\ldots,b_{n}~|~a_{1} = b_{1} , \ldots , a_{n} = b_{n}}~\left(\left(a_{1} , \ldots , a_{n}\right) = \left(b_{1} , \ldots , b_{n}\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> {forall_{a_{1},...,a_{n}, b_{1},...,b_{n} | a_{1} = b_{1} ,  ...  , a_{n} = b_{n}} ((a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n})) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 25
#    body: 1
# 1. {forall_{a_{1},...,a_{n}, b_{1},...,b_{n} | a_{1} = b_{1} ,  ...  , a_{n} = b_{n}} ((a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n})) if n in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1},...,a_{n}, b_{1},...,b_{n} | a_{1} = b_{1} ,  ...  , a_{n} = b_{n}} ((a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n}))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. n in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (a_{1},...,a_{n}, b_{1},...,b_{n}) -> {(a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n}) if (a_{1} = b_{1}) and  ...  and (a_{n} = b_{n}).
#    core type: Lambda
#    parameters: 8\n   body: 9
# 6. in
# ...
