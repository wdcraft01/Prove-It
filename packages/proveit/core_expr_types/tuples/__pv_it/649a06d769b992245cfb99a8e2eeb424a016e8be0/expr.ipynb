# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda
from proveit._common_ import a, b, i, k
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_i
from proveit.logic import And, Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
expr = Lambda([a_1_to_i, b_1_to_i], Conditional(Equals([a_1_to_i], [b_1_to_i]), And(ExprRange(k, Equals(IndexedVar(a, k), IndexedVar(b, k)), one, i))))
# Out:
# expr: (a_{1},...,a_{i}, b_{1},...,b_{i}) -> {(a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}) if (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1},\ldots,a_{i}, b_{1},\ldots,b_{i}\right) \mapsto \left\{\left(a_{1} , \ldots , a_{i}\right) = \left(b_{1} , \ldots , b_{i}\right) \textrm{ if } \left(a_{1} = b_{1}\right) \land \ldots \land \left(a_{i} = b_{i}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1},...,a_{i}, b_{1},...,b_{i}) -> {(a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}) if (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i}).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1} ,  ...  , a_{i} , b_{1} ,  ...  , b_{i})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 2. {(a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}) if (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i})
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (a_{1} = b_{1}) and  ...  and (a_{i} = b_{i})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a_{1} ,  ...  , a_{i}) , (b_{1} ,  ...  , b_{i}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} = b_{1} ,  ...  , a_{i} = b_{i})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (a_{1} ,  ...  , a_{i})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (b_{1} ,  ...  , b_{i})
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (a_{1} = b_{1}),...,(a_{i} = b_{i})
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 16
#     end_index: 17
# 11. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 16
#     end_index: 17
# 12. b_{1},...,b_{i}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 13. k -> (a_{k} = b_{k})
#     core type: Lambda
#     parameter: 27
#     body: 18
# 14. b -> a_{b}
#     core type: Lambda
#     parameter: 26
#     body: 19
# 15. a -> b_{a}
#     core type: Lambda
#     parameter: 25
#     body: 20
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. a_{k} = b_{k}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. a_{b}
#     core type: IndexedVar
# variable: 25
# index: 26
# 20. b_{a}
#     core type: IndexedVar
# variable: 26
# index: 25
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a_{k} , b_{k})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. a_{k}
#     core type: IndexedVar
# variable: 25
# index: 27
# 24. b_{k}
#     core type: IndexedVar
# variable: 26
# index: 27
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
# 27. k
#     core type: Variable
#     sub-expressions:
