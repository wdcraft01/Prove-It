# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, Len, Variable
from proveit.logic import Equals, Forall
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Forall([Variable("i")], Equals(Len([ExprRange(Variable("a"), Function(Variable("f"), Variable("a")), one, Variable("i"))]), Len([ExprRange(Variable("k"), Variable("k"), one, Variable("i"))])), domain = Naturals)
# Out:
# expr: forall_{i in Naturals} (|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{i \in \mathbb{N}}~\left(|\left(f\left(1\right) , \ldots , f\left(i\right)\right)| = |\left(1 , \ldots , i\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{i in Naturals} (|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. i -> {|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)| if i in Naturals.
#    core type: Lambda
#    parameter: 23
#    body: 3
# 3. {|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)| if i in Naturals.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. |(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. i in Naturals
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (|(f(1) ,  ...  , f(i))| , |(1 ,  ...  , i)|)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 23, 12
# 10. |(f(1) ,  ...  , f(i))|
#     core type: Operation
#     operator: 14
# ...
