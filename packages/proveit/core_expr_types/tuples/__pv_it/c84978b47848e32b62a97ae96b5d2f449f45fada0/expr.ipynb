# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Function
from proveit._common_ import a, f, fa, i, j
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple([ExprRange(a, fa, i, j), Function(f, Add(j, one))], [ExprRange(a, fa, i, Add(j, one))])
# Out:
# expr: ((f(i) ,  ...  , f(j) , f(j + 1)) , (f(i) ,  ...  , f(j + 1)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right) , \left(f\left(i\right) , \ldots , f\left(j + 1\right)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((f(i) ,  ...  , f(j) , f(j + 1)) , (f(i) ,  ...  , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 2. (f(i) ,  ...  , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 5
# 3. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 14
# 4. f(j + 1)
#    core type: Operation
#    operator: 12
#    operand: 8
# 5. f(i),...,f(j + 1)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. a -> f(a)
#    core type: Lambda
#    parameter: 13
#    body: 9
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. j + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. f(a)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. f
#     core type: Variable
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. j
#     core type: Variable
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
