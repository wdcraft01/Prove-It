# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Len
from proveit._common_ import a, fa, i
from proveit.logic import Equals, InSet
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Len([ExprRange(a, fa, one, i)]), i), InSet(i, Naturals))
# Out:
# expr: {|(f(1) ,  ...  , f(i))| = i if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{|\left(f\left(1\right) , \ldots , f\left(i\right)\right)| = i \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {|(f(1) ,  ...  , f(i))| = i if i in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |(f(1) ,  ...  , f(i))| = i
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. i in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|(f(1) ,  ...  , f(i))| , i)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 15, 8
# 7. |(f(1) ,  ...  , f(i))|
#    core type: Operation
#    operator: 9
#    operand: 11
# 8. Naturals
#    core type: Literal
#    sub-expressions:
# 9. length
#    core type: Literal
#    sub-expressions:
# 10. ((f(1) ,  ...  , f(i)))
#     core type: ExprTuple
#     sub-expressions: 11
# 11. (f(1) ,  ...  , f(i))
#     core type: ExprTuple
#     sub-expressions: 12
# 12. f(1),...,f(i)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 13. a -> f(a)
#     core type: Lambda
#     parameter: 18
#     body: 16
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. i
#     core type: Variable
#     sub-expressions:
# 16. f(a)
#     core type: Operation
#     operator: 17
#     operand: 18
# 17. f
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
