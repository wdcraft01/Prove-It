# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import A_1_to_l, B_1_to_m, C_1_to_n
from proveit.logic import And

# %%
# build up the expression from sub-expressions
expr = And(A_1_to_l, B_1_to_m, C_1_to_n)
# Out:
# expr: A_{1} and  ...  and A_{l} and B_{1} and  ...  and B_{m} and C_{1} and  ...  and C_{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# A_{1} \land \ldots \land A_{l} \land B_{1} \land \ldots \land B_{m} \land C_{1} \land \ldots \land C_{n}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_{1} and  ...  and A_{l} and B_{1} and  ...  and B_{m} and C_{1} and  ...  and C_{n}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (A_{1} ,  ...  , A_{l} , B_{1} ,  ...  , B_{m} , C_{1} ,  ...  , C_{n})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. A_{1},...,A_{l}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 11
#    end_index: 7
# 4. B_{1},...,B_{m}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 11
#    end_index: 9
# 5. C_{1},...,C_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 6. a -> A_{a}
#    core type: Lambda
#    parameter: 19
#    body: 13
# 7. l
#    core type: Variable
#    sub-expressions:
# 8. a -> B_{a}
#    core type: Lambda
#    parameter: 19
#    body: 14
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. a -> C_{a}
#     core type: Lambda
#     parameter: 19
#     body: 15
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
# 13. A_{a}
#     core type: IndexedVar
# variable: 16
# index: 19
# 14. B_{a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 15. C_{a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
