# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("c")
subExpr2 = Variable("a")
subExpr3 = Variable("b")
subExpr4 = Add(Variable("m"), one)
subExpr5 = Equals(IndexedVar(subExpr2, subExpr1), IndexedVar(subExpr3, subExpr1))
expr = Equals([ExprRange(subExpr1, subExpr5, one, subExpr4)], [ExprRange(subExpr1, subExpr5, one, Variable("m")), Equals(IndexedVar(subExpr2, subExpr4), IndexedVar(subExpr3, subExpr4))])
# Out:
# expr: (a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}) = (a_{1} = b_{1} ,  ...  , a_{m} = b_{m} , a_{m + 1} = b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}\right) = \left(a_{1} = b_{1} , \ldots , a_{m} = b_{m} , a_{m + 1} = b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}) = (a_{1} = b_{1} ,  ...  , a_{m} = b_{m} , a_{m + 1} = b_{m + 1})
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. ((a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}) , (a_{1} = b_{1} ,  ...  , a_{m} = b_{m} , a_{m + 1} = b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (a_{1} = b_{1} ,  ...  , a_{m} = b_{m} , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (a_{1} = b_{1}),...,(a_{m + 1} = b_{m + 1})
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 23
#    end_index: 14
# 5. (a_{1} = b_{1}),...,(a_{m} = b_{m})
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 23
#    end_index: 22
# 6. a_{m + 1} = b_{m + 1}
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. c -> (a_{c} = b_{c})
#    core type: Lambda
#    parameter: 21
# ...
