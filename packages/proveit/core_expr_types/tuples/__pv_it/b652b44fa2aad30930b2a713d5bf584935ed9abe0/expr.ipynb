# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange
from proveit._common_ import a, fa, i, j, k, l
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals([ExprRange(a, fa, i, j), ExprRange(a, fa, k, l)], [ExprRange(a, fa, i, l)]).withWrappingAt(2), And(InSet(Add(k, Neg(i)), Naturals), InSet(Add(l, Neg(j)), Naturals), Equals(k, Add(j, one))))
# Out:
# expr: {(f(i) ,  ...  , f(j) , f(k) ,  ...  , f(l)) =  \\ (f(i) ,  ...  , f(l)) if (k - i) in Naturals ,  (l - j) in Naturals ,  k = (j + 1).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(k\right) , \ldots , f\left(l\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(l\right)\right) \end{array} \textrm{ if } \left(k - i\right) \in \mathbb{N} ,  \left(l - j\right) \in \mathbb{N} ,  k = \left(j + 1\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(f(i) ,  ...  , f(j) , f(k) ,  ...  , f(l)) =  \\ (f(i) ,  ...  , f(l)) if (k - i) in Naturals ,  (l - j) in Naturals ,  k = (j + 1).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (f(i) ,  ...  , f(j) , f(k) ,  ...  , f(l)) =  \\ (f(i) ,  ...  , f(l))
#    core type: Operation
#    operator: 17
#    operands: 3
# 2. ((k - i) in Naturals) and ((l - j) in Naturals) and (k = (j + 1))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((f(i) ,  ...  , f(j) , f(k) ,  ...  , f(l)) , (f(i) ,  ...  , f(l)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((k - i) in Naturals , (l - j) in Naturals , k = (j + 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 6. (f(i) ,  ...  , f(j) , f(k) ,  ...  , f(l))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 7. (f(i) ,  ...  , f(l))
#    core type: ExprTuple
#    sub-expressions: 13
# 8. (k - i) in Naturals
# ...
