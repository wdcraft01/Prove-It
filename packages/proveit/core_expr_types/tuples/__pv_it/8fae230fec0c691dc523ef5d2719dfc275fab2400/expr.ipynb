# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals([ExprRange(Variable("a"), Function(Variable("f"), Variable("a")), Variable("i"), Variable("j"))], []), Equals(Add(Variable("j"), one), Variable("i")))
# Out:
# expr: {(f(i) ,  ...  , f(j)) = () if (j + 1) = i.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(f\left(i\right) , \ldots , f\left(j\right)\right) = () \textrm{ if } \left(j + 1\right) = i\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(f(i) ,  ...  , f(j)) = () if (j + 1) = i.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (f(i) ,  ...  , f(j)) = ()
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (j + 1) = i
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((f(i) ,  ...  , f(j)) , ())
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (j + 1 , i)
#    core type: ExprTuple
#    sub-expressions: 8, 13
# 6. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. ()
#    core type: ExprTuple
#    sub-expressions:
# 8. j + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. a -> f(a)
#     core type: Lambda
#     parameter: 18
#     body: 16
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. j
#     core type: Variable
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. f(a)
#     core type: Operation
#     operator: 17
#     operand: 18
# 17. f
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
