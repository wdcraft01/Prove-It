# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable
from proveit.logic import And, Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
expr = Conditional(Equals([ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("n"))], [ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("n"))]), And(ExprRange(Variable("k"), Equals(IndexedVar(subExpr2, Variable("k")), IndexedVar(subExpr1, Variable("k"))), one, Variable("n"))))
# Out:
# expr: {(a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n}) if (a_{1} = b_{1}) and  ...  and (a_{n} = b_{n}).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} , \ldots , a_{n}\right) = \left(b_{1} , \ldots , b_{n}\right) \textrm{ if } \left(a_{1} = b_{1}\right) \land \ldots \land \left(a_{n} = b_{n}\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n}) if (a_{1} = b_{1}) and  ...  and (a_{n} = b_{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} ,  ...  , a_{n}) = (b_{1} ,  ...  , b_{n})
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (a_{1} = b_{1}) and  ...  and (a_{n} = b_{n})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((a_{1} ,  ...  , a_{n}) , (b_{1} ,  ...  , b_{n}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} = b_{1} ,  ...  , a_{n} = b_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 6. (a_{1} ,  ...  , a_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (b_{1} ,  ...  , b_{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (a_{1} = b_{1}),...,(a_{n} = b_{n})
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 14
#    end_index: 15
# 9. a_{1},...,a_{n}
#    core type: ExprRange
# ...
