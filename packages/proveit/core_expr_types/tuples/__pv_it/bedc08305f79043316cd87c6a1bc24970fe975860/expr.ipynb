# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Len, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("c")
subExpr2 = Add(Variable("m"), one)
expr = Equals(Len([ExprRange(subExpr1, Equals(IndexedVar(Variable("a"), subExpr1), IndexedVar(Variable("b"), subExpr1)), one, subExpr2)]), Len([ExprRange(Variable("k"), Variable("k"), one, subExpr2)]))
# Out:
# expr: |(a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})| = |(1 ,  ...  , m + 1)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}\right)| = |\left(1 , \ldots , m + 1\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})| = |(1 ,  ...  , m + 1)|
#    core type: Operation
#    operator: 18
#    operands: 1
# 1. (|(a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})| , |(1 ,  ...  , m + 1)|)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. |(a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})|
#    core type: Operation
#    operator: 5
#    operand: 7
# 3. |(1 ,  ...  , m + 1)|
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. ((a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((1 ,  ...  , m + 1))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (1 ,  ...  , m + 1)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (a_{1} = b_{1}),...,(a_{m + 1} = b_{m + 1})
#    core type: ExprRange
#    lambda_map: 11
# ...
