# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function
from proveit._common_ import a, f, fa, i, j
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(a, fa, i, j), Function(f, Add(j, one))], [ExprRange(a, fa, i, Add(j, one))])
# Out:
# expr: (f(i) ,  ...  , f(j) , f(j + 1)) = (f(i) ,  ...  , f(j + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right) = \left(f\left(i\right) , \ldots , f\left(j + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f(i) ,  ...  , f(j) , f(j + 1)) = (f(i) ,  ...  , f(j + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i) ,  ...  , f(j) , f(j + 1)) , (f(i) ,  ...  , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (f(i) ,  ...  , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 16
# 6. f(j + 1)
#    core type: Operation
#    operator: 14
#    operand: 10
# 7. f(i),...,f(j + 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 8. a -> f(a)
#    core type: Lambda
#    parameter: 15
#    body: 11
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. j + 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. f(a)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. j
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
