# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Len
from proveit._common_ import a, fa, i
from proveit.logic import InSet
from proveit.number import Naturals, one

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Len([ExprRange(a, fa, one, i)]), Naturals), InSet(i, Naturals))
# Out:
# expr: {|(f(1) ,  ...  , f(i))| in Naturals if i in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{|\left(f\left(1\right) , \ldots , f\left(i\right)\right)| \in \mathbb{N} \textrm{ if } i \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {|(f(1) ,  ...  , f(i))| in Naturals if i in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |(f(1) ,  ...  , f(i))| in Naturals
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. i in Naturals
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|(f(1) ,  ...  , f(i))| , Naturals)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (i , Naturals)
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 6. |(f(1) ,  ...  , f(i))|
#    core type: Operation
#    operator: 8
#    operand: 10
# 7. Naturals
#    core type: Literal
#    sub-expressions:
# 8. length
#    core type: Literal
#    sub-expressions:
# 9. ((f(1) ,  ...  , f(i)))
#    core type: ExprTuple
#    sub-expressions: 10
# 10. (f(1) ,  ...  , f(i))
#     core type: ExprTuple
#     sub-expressions: 11
# 11. f(1),...,f(i)
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. a -> f(a)
#     core type: Lambda
#     parameter: 17
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. f(a)
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
