# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#simple_extension_range_len_val">simple_extension_range_len_val</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import simple_extension_range_len_val

# %%
# check that the built expression is the same as the stored expression
# %check_expr simple_extension_range_len_val
# Out:
# Passed sanity check: built 'simple_extension_range_len_val' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(simple_extension_range_len_val.latex())
# Out:
# \vdash \forall_{f, b}~\left[\forall_{i \in \mathbb{N}}~\left(|\left(f\left(1\right) , \ldots , f\left(i\right) , b\right)| = \left(i + 1\right)\right)\right]

# %%
# display the expression information
simple_extension_range_len_val.exprInfo()
# Out:
# 0. forall_{f, b} [forall_{i in Naturals} (|(f(1) ,  ...  , f(i) , b)| = (i + 1))]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. (f, b) -> [forall_{i in Naturals} (|(f(1) ,  ...  , f(i) , b)| = (i + 1))]
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f , b)
#    core type: ExprTuple
#    sub-expressions: 27, 22
# 3. forall_{i in Naturals} (|(f(1) ,  ...  , f(i) , b)| = (i + 1))
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. i -> {|(f(1) ,  ...  , f(i) , b)| = (i + 1) if i in Naturals.
#    core type: Lambda
#    parameter: 25
#    body: 6
# 6. {|(f(1) ,  ...  , f(i) , b)| = (i + 1) if i in Naturals.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. |(f(1) ,  ...  , f(i) , b)| = (i + 1)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. i in Naturals
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. =
#    core type: Literal
# ...
