# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import k, m
from proveit.logic import Equals, Forall
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = IndexedVar(subExpr2, subExpr1)
subExpr4 = IndexedVar(subExpr1, subExpr2)
subExpr5 = Add(m, one)
subExpr6 = ExprRange(subExpr1, subExpr3, one, subExpr5)
subExpr7 = ExprRange(subExpr2, subExpr4, one, subExpr5)
subExpr8 = Equals(IndexedVar(subExpr2, k), IndexedVar(subExpr1, k))
subExpr9 = ExprRange(subExpr1, subExpr3, one, m)
subExpr10 = ExprRange(subExpr2, subExpr4, one, m)
expr = Forall([m], Forall([subExpr6, subExpr7], Equals([subExpr6], [subExpr7]), condition = ExprRange(k, subExpr8, one, subExpr5)), domain = NaturalsPos, condition = Forall([subExpr9, subExpr10], Equals([subExpr9], [subExpr10]), condition = ExprRange(k, subExpr8, one, m)))
# Out:
# expr: forall_{m in NaturalsPos | forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}))} [forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m \in \mathbb{N}^+~|~\forall_{a_{1},\ldots,a_{m}, b_{1},\ldots,b_{m}~|~a_{1} = b_{1} , \ldots , a_{m} = b_{m}}~\left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right)\right)}~\left[\forall_{a_{1},\ldots,a_{m + 1}, b_{1},\ldots,b_{m + 1}~|~a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}}~\left(\left(a_{1} , \ldots , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m + 1}\right)\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m in NaturalsPos | forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}))} [forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))]
#    core type: Operation
#    operator: 15
#    operand: 1
# 1. m -> {forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1})) if m in NaturalsPos ,  forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})).
#    core type: Lambda
#    parameter: 44
#    body: 2
# ...
