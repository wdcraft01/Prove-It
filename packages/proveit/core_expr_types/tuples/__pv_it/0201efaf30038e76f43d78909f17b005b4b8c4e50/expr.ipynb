# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import d
from proveit.core_expr_types._common_ import a_1_to_i, c_1_to_i
from proveit.logic import And, Equals

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
expr = Equals(Equals([a_1_to_i, subExpr1], [c_1_to_i, d]), And(Equals([a_1_to_i], [c_1_to_i]), Equals(subExpr1, d))).withWrappingAt(2)
# Out:
# expr: ((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)) =  \\ (((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(\left(a_{1} , \ldots , a_{i} , b\right) = \left(c_{1} , \ldots , c_{i} , d\right)\right) =  \\ \left(\left(\left(a_{1} , \ldots , a_{i}\right) = \left(c_{1} , \ldots , c_{i}\right)\right) \land \left(b = d\right)\right) \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)) =  \\ (((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. ((a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d) , ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (a_{1} ,  ...  , a_{i} , b) = (c_{1} ,  ...  , c_{i} , d)
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i})) and (b = d)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. ((a_{1} ,  ...  , a_{i} , b) , (c_{1} ,  ...  , c_{i} , d))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1} ,  ...  , a_{i}) = (c_{1} ,  ...  , c_{i}) , b = d)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a_{1} ,  ...  , a_{i} , b)
#    core type: ExprTuple
# ...
