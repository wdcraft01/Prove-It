# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Lambda, Len
from proveit._common_ import b, i
from proveit.core_expr_types._common_ import a_1_to_i
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = [a_1_to_i, b]
expr = Lambda(subExpr1, Equals(Len(subExpr1), Add(i, one)))
# Out:
# expr: (a_{1},...,a_{i}, b) -> (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1},\ldots,a_{i}, b\right) \mapsto \left(|\left(a_{1} , \ldots , a_{i} , b\right)| = \left(i + 1\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_{1},...,a_{i}, b) -> (|(a_{1} ,  ...  , a_{i} , b)| = (i + 1))
#    core type: Lambda
#    parameters: 10\n   body: 1
# 1. |(a_{1} ,  ...  , a_{i} , b)| = (i + 1)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (|(a_{1} ,  ...  , a_{i} , b)| , i + 1)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. |(a_{1} ,  ...  , a_{i} , b)|
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. i + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1} ,  ...  , a_{i} , b))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (i , 1)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. (a_{1} ,  ...  , a_{i} , b)
#     core type: ExprTuple
#     sub-expressions: 11, 17
# 11. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. b -> a_{b}
#     core type: Lambda
#     parameter: 17
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. a_{b}
#     core type: IndexedVar
# variable: 16
# index: 17
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
