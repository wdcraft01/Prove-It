# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Len
from proveit._common_ import a, fa, i, j, k

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(a, fa, i, j)]), Len([ExprRange(k, k, i, j)]))
# Out:
# expr: (|(f(i) ,  ...  , f(j))| , |(i ,  ...  , j)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| , |\left(i , \ldots , j\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(f(i) ,  ...  , f(j))| , |(i ,  ...  , j)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(f(i) ,  ...  , f(j))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(i ,  ...  , j)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((f(i) ,  ...  , f(j)))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((i ,  ...  , j))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (i ,  ...  , j)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 12
#    end_index: 13
# 9. i,...,j
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 10. a -> f(a)
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. j
#     core type: Variable
#     sub-expressions:
# 14. f(a)
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
