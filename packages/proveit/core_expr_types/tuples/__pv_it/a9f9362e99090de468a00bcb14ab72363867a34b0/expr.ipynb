# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#range_len_in_nats">range_len_in_nats</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import range_len_in_nats

# %%
# check that the built expression is the same as the stored expression
# %check_expr range_len_in_nats
# Out:
# Passed sanity check: built 'range_len_in_nats' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(range_len_in_nats.latex())
# Out:
# \vdash \forall_{f, i, j~|~\left(j - i + 1\right) \in \mathbb{N}}~\left(|\left(f\left(i\right) , \ldots , f\left(j\right)\right)| \in \mathbb{N}\right)

# %%
# display the expression information
range_len_in_nats.exprInfo()
# Out:
# 0. forall_{f, i, j | (j - i + 1) in Naturals} (|(f(i) ,  ...  , f(j))| in Naturals)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {|(f(i) ,  ...  , f(j))| in Naturals if (j - i + 1) in Naturals.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 26, 23, 24
# 4. {|(f(i) ,  ...  , f(j))| in Naturals if (j - i + 1) in Naturals.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |(f(i) ,  ...  , f(j))| in Naturals
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. (j - i + 1) in Naturals
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (|(f(i) ,  ...  , f(j))| , Naturals)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (j - i + 1 , Naturals)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. |(f(i) ,  ...  , f(j))|
# ...
