# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#simple_range_len">simple_range_len</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import simple_range_len

# %%
# check that the built expression is the same as the stored expression
# %check_expr simple_range_len
# Out:
# Passed sanity check: built 'simple_range_len' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(simple_range_len.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{i \in \mathbb{N}}~\left(|\left(f\left(1\right) , \ldots , f\left(i\right)\right)| = |\left(1 , \ldots , i\right)|\right)\right]

# %%
# display the expression information
simple_range_len.exprInfo()
# Out:
# 0. forall_{f} [forall_{i in Naturals} (|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|)]
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. f -> [forall_{i in Naturals} (|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|)]
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. forall_{i in Naturals} (|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. i -> {|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)| if i in Naturals.
#    core type: Lambda
#    parameter: 25
#    body: 5
# 5. {|(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)| if i in Naturals.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. |(f(1) ,  ...  , f(i))| = |(1 ,  ...  , i)|
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. i in Naturals
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# ...
