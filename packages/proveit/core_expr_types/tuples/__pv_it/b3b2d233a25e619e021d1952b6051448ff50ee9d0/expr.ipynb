# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit.logic import Equals, Forall
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("a")
subExpr2 = Variable("b")
subExpr3 = IndexedVar(subExpr1, one)
subExpr4 = IndexedVar(subExpr2, one)
subExpr5 = IndexedVar(subExpr1, subExpr2)
subExpr6 = IndexedVar(subExpr2, subExpr1)
subExpr7 = Add(Variable("m"), one)
subExpr8 = ExprRange(subExpr2, subExpr5, one, subExpr7)
subExpr9 = ExprRange(subExpr1, subExpr6, one, subExpr7)
subExpr10 = Equals(IndexedVar(subExpr1, Variable("k")), IndexedVar(subExpr2, Variable("k")))
subExpr11 = ExprRange(subExpr2, subExpr5, one, Variable("m"))
subExpr12 = ExprRange(subExpr1, subExpr6, one, Variable("m"))
expr = ExprTuple(Forall([subExpr3, subExpr4], Equals([subExpr3], [subExpr4]), condition = Equals(subExpr3, subExpr4)), Forall([Variable("m")], Forall([subExpr8, subExpr9], Equals([subExpr8], [subExpr9]), condition = ExprRange(Variable("k"), subExpr10, one, subExpr7)), domain = NaturalsPos, condition = Forall([subExpr11, subExpr12], Equals([subExpr11], [subExpr12]), condition = ExprRange(Variable("k"), subExpr10, one, Variable("m")))))
# Out:
# expr: (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})) , forall_{m in NaturalsPos | forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}))} [forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{a_{1}, b_{1}~|~a_{1} = b_{1}}~\left(\left(a_{1}\right) = \left(b_{1}\right)\right) , \forall_{m \in \mathbb{N}^+~|~\forall_{a_{1},\ldots,a_{m}, b_{1},\ldots,b_{m}~|~a_{1} = b_{1} , \ldots , a_{m} = b_{m}}~\left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right)\right)}~\left[\forall_{a_{1},\ldots,a_{m + 1}, b_{1},\ldots,b_{m + 1}~|~a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}}~\left(\left(a_{1} , \ldots , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m + 1}\right)\right)\right]\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1})) , forall_{m in NaturalsPos | forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}))} [forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{a_{1}, b_{1} | a_{1} = b_{1}} ((a_{1}) = (b_{1}))
#    core type: Operation
#    operator: 27
#    operand: 3
# 2. forall_{m in NaturalsPos | forall_{a_{1},...,a_{m}, b_{1},...,b_{m} | a_{1} = b_{1} ,  ...  , a_{m} = b_{m}} ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}))} [forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))]
#    core type: Operation
#    operator: 27
#    operand: 4
# ...
