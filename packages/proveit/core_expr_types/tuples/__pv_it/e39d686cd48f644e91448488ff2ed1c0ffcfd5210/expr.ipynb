# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable
from proveit.logic import And, Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = Add(Variable("m"), one)
subExpr4 = ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("m"))
subExpr5 = IndexedVar(subExpr2, subExpr3)
subExpr6 = ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("m"))
subExpr7 = IndexedVar(subExpr1, subExpr3)
expr = ExprTuple(Equals([subExpr4, subExpr5], [subExpr6, subExpr7]), And(Equals([subExpr4], [subExpr6]), Equals(subExpr5, subExpr7)))
# Out:
# expr: ((a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1}) , ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} , \ldots , a_{m} , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m} , b_{m + 1}\right) , \left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right)\right) \land \left(a_{m + 1} = b_{m + 1}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1}) , ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1})
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((a_{1} ,  ...  , a_{m} , a_{m + 1}) , (b_{1} ,  ...  , b_{m} , b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. (a_{1} ,  ...  , a_{m} , a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 17, 15
# 7. (b_{1} ,  ...  , b_{m} , b_{m + 1})
#    core type: ExprTuple
# ...
