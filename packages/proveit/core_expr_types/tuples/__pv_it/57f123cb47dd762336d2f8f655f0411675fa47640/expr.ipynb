# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function, Lambda
from proveit._common_ import a, f, fa, i, j, k
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Lambda([f, i, j, k], Conditional(Equals([ExprRange(a, fa, i, j), Function(f, k)], [ExprRange(a, fa, i, k)]).withWrappingAt(2), And(InSet(Add(k, Neg(i)), Naturals), Equals(k, Add(j, one)))))
# Out:
# expr: (f, i, j, k) -> {(f(i) ,  ...  , f(j) , f(k)) =  \\ (f(i) ,  ...  , f(k)) if (k - i) in Naturals ,  k = (j + 1).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, i, j, k\right) \mapsto \left\{\begin{array}{c} \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(k\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(k\right)\right) \end{array} \textrm{ if } \left(k - i\right) \in \mathbb{N} ,  k = \left(j + 1\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f, i, j, k) -> {(f(i) ,  ...  , f(j) , f(k)) =  \\ (f(i) ,  ...  , f(k)) if (k - i) in Naturals ,  k = (j + 1).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f , i , j , k)
#    core type: ExprTuple
#    sub-expressions: 27, 34, 31, 29
# 2. {(f(i) ,  ...  , f(j) , f(k)) =  \\ (f(i) ,  ...  , f(k)) if (k - i) in Naturals ,  k = (j + 1).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (f(i) ,  ...  , f(j) , f(k)) =  \\ (f(i) ,  ...  , f(k))
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. ((k - i) in Naturals) and (k = (j + 1))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((f(i) ,  ...  , f(j) , f(k)) , (f(i) ,  ...  , f(k)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. ((k - i) in Naturals , k = (j + 1))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (f(i) ,  ...  , f(j) , f(k))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# ...
