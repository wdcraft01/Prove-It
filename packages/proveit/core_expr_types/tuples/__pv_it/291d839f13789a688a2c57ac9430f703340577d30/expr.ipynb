# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Function, Len
from proveit._common_ import a, f, fa, i, j, k
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([ExprRange(a, fa, i, j), Function(f, Add(j, one))]), Len([ExprRange(k, k, i, Add(j, one))]))
# Out:
# expr: (|(f(i) ,  ...  , f(j) , f(j + 1))| , |(i ,  ...  , j + 1)|)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right)| , |\left(i , \ldots , j + 1\right)|\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(f(i) ,  ...  , f(j) , f(j + 1))| , |(i ,  ...  , j + 1)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(f(i) ,  ...  , f(j) , f(j + 1))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(i ,  ...  , j + 1)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((f(i) ,  ...  , f(j) , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((i ,  ...  , j + 1))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (i ,  ...  , j + 1)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 13
#    end_index: 21
# 9. f(j + 1)
#    core type: Operation
#    operator: 19
#    operand: 14
# 10. i,...,(j + 1)
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 11. a -> f(a)
#     core type: Lambda
#     parameter: 20
#     body: 15
# 12. k -> k
#     core type: Lambda
#     parameter: 16
#     body: 16
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. j + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. f(a)
#     core type: Operation
#     operator: 19
#     operand: 20
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. f
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. j
#     core type: Variable
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
