# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, IndexedVar, Variable
from proveit.logic import And, Equals
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = IndexedVar(Variable("a"), one)
subExpr2 = IndexedVar(Variable("b"), one)
subExpr3 = Equals(subExpr1, subExpr2)
subExpr4 = Equals([subExpr1], [subExpr2])
expr = Equals(Conditional(subExpr4, And(subExpr3)), Conditional(subExpr4, subExpr3))
# Out:
# expr: {(a_{1}) = (b_{1}) if [and](a_{1} = b_{1}). = {(a_{1}) = (b_{1}) if a_{1} = b_{1}.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1}\right) = \left(b_{1}\right) \textrm{ if } \left[\land\right]\left(a_{1} = b_{1}\right)\right.. = \left\{\left(a_{1}\right) = \left(b_{1}\right) \textrm{ if } a_{1} = b_{1}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(a_{1}) = (b_{1}) if [and](a_{1} = b_{1}). = {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Operation
#    operator: 9
#    operands: 1
# 1. ((a_{1}) = (b_{1}) if [and](a_{1} = b_{1}) , (a_{1}) = (b_{1}) if a_{1} = b_{1})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. {(a_{1}) = (b_{1}) if [and](a_{1} = b_{1}).
#    core type: Conditional
#    value: 5
#    condition: 4
# 3. {(a_{1}) = (b_{1}) if a_{1} = b_{1}.
#    core type: Conditional
#    value: 5
#    condition: 7
# 4. [and](a_{1} = b_{1})
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (a_{1}) = (b_{1})
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. a_{1} = b_{1}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. ((a_{1}) , (b_{1}))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} , b_{1})
#     core type: ExprTuple
# ...
