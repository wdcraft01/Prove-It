# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import A, B
from proveit.logic import Forall, InSet, SubsetEq

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("x")
expr = Forall([A, B], Forall([subExpr1], InSet(subExpr1, B), domain = A), condition = SubsetEq(A, B))
# Out:
# expr: forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, B~|~A \subseteq B}~\left[\forall_{x \in A}~\left(x \in B\right)\right]

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A, B | A subseteq B} [forall_{x in A} (x in B)]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. (A, B) -> {forall_{x in A} (x in B) if A subseteq B.
#    core type: Lambda
#    parameters: 8\n   body: 2
# 2. {forall_{x in A} (x in B) if A subseteq B.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in A} (x in B)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. A subseteq B
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. x -> {x in B if x in A.
#    core type: Lambda
#    parameter: 16
#    body: 9
# 7. subseteq
#    core type: Literal
#    sub-expressions:
# 8. (A , B)
#    core type: ExprTuple
#    sub-expressions: 17, 15
# 9. {x in B if x in A.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. x in B
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. x in A
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (x , B)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (x , A)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
