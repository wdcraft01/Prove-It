# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit._common_ import m
from proveit.logic import And, Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Add(m, one)
expr = And(Equals([ExprRange(Variable("b"), IndexedVar(Variable("a"), Variable("b")), one, m)], [ExprRange(Variable("a"), IndexedVar(Variable("b"), Variable("a")), one, m)]), Equals(IndexedVar(Variable("a"), subExpr1), IndexedVar(Variable("b"), subExpr1)))
# Out:
# expr: ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right)\right) \land \left(a_{m + 1} = b_{m + 1}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a_{m + 1} = b_{m + 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((a_{1} ,  ...  , a_{m}) , (b_{1} ,  ...  , b_{m}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a_{m + 1} , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (a_{1} ,  ...  , a_{m})
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (b_{1} ,  ...  , b_{m})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. a_{m + 1}
#     core type: IndexedVar
# ...
