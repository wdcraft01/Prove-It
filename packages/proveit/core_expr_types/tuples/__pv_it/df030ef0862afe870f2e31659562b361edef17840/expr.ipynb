# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#concatIterLenVal">concatIterLenVal</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import concatIterLenVal

# %%
# check that the built expression is the same as the stored expression
# %check_expr concatIterLenVal
# Out:
# Passed sanity check: built 'concatIterLenVal' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(concatIterLenVal.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}}~\left[\forall_{a_{1},\ldots,a_{i}, f, j, k~|~\left(k - j + 1\right) \in \mathbb{N}}~\left(\begin{array}{c} |\left(a_{1} , \ldots , a_{i} , f\left(j\right) , \ldots , f\left(k\right)\right)| =  \\ \left(i + k - j + 1\right) \end{array}\right)\right]

# %%
# display the expression information
concatIterLenVal.exprInfo()
# Out:
# 0. forall_{i in Naturals} [forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1)) if i in Naturals.
#    core type: Lambda
#    parameter: 32
#    body: 2
# 2. {forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1)) if i in Naturals.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1},...,a_{i}, f, j, k | (k - j + 1) in Naturals} (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| =  \\ (i + k - j + 1))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in Naturals
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
