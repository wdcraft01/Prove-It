# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit.logic import Equals, Forall
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = Add(Variable("m"), one)
subExpr4 = ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, subExpr3)
subExpr5 = ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, subExpr3)
expr = Forall([subExpr4, subExpr5], Equals([subExpr4], [subExpr5]), condition = ExprRange(Variable("k"), Equals(IndexedVar(subExpr2, Variable("k")), IndexedVar(subExpr1, Variable("k"))), one, subExpr3))
# Out:
# expr: forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1},\ldots,a_{m + 1}, b_{1},\ldots,b_{m + 1}~|~a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}}~\left(\left(a_{1} , \ldots , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m + 1}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1} | a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}} ((a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1},...,a_{m + 1}, b_{1},...,b_{m + 1}) -> {(a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}) if (a_{1} = b_{1}) and  ...  and (a_{m + 1} = b_{m + 1}).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a_{1} ,  ...  , a_{m + 1} , b_{1} ,  ...  , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 4. {(a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1}) if (a_{1} = b_{1}) and  ...  and (a_{m + 1} = b_{m + 1}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} ,  ...  , a_{m + 1}) = (b_{1} ,  ...  , b_{m + 1})
#    core type: Operation
#    operator: 24
#    operands: 7
# 6. (a_{1} = b_{1}) and  ...  and (a_{m + 1} = b_{m + 1})
# ...
