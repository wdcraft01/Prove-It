# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#merge_pair">merge_pair</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import merge_pair

# %%
# check that the built expression is the same as the stored expression
# %check_expr merge_pair
# Out:
# Passed sanity check: built 'merge_pair' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_pair.latex())
# Out:
# \vdash \forall_{f, i, j~|~j = \left(i + 1\right)}~\left(\left(f\left(i\right) , f\left(j\right)\right) = \left(f\left(i\right) , \ldots , f\left(j\right)\right)\right)

# %%
# display the expression information
merge_pair.exprInfo()
# Out:
# 0. forall_{f, i, j | j = (i + 1)} ((f(i) , f(j)) = (f(i) ,  ...  , f(j)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, i, j) -> {(f(i) , f(j)) = (f(i) ,  ...  , f(j)) if j = (i + 1).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f , i , j)
#    core type: ExprTuple
#    sub-expressions: 23, 20, 19
# 4. {(f(i) , f(j)) = (f(i) ,  ...  , f(j)) if j = (i + 1).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (f(i) , f(j)) = (f(i) ,  ...  , f(j))
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. j = (i + 1)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((f(i) , f(j)) , (f(i) ,  ...  , f(j)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (j , i + 1)
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 10. (f(i) , f(j))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (f(i) ,  ...  , f(j))
#     core type: ExprTuple
#     sub-expressions: 15
# 12. i + 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. f(i)
#     core type: Operation
#     operator: 23
#     operand: 20
# 14. f(j)
#     core type: Operation
#     operator: 23
#     operand: 19
# 15. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 20
#     end_index: 19
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (i , 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a -> f(a)
#     core type: Lambda
#     parameter: 24
#     body: 22
# 19. j
#     core type: Variable
#     sub-expressions:
# 20. i
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. f(a)
#     core type: Operation
#     operator: 23
#     operand: 24
# 23. f
#     core type: Variable
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
