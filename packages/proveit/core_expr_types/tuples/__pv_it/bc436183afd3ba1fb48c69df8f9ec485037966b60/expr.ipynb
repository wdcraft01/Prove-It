# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#merge_series">merge_series</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import merge_series

# %%
# check that the built expression is the same as the stored expression
# %check_expr merge_series
# Out:
# Passed sanity check: built 'merge_series' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_series.latex())
# Out:
# \vdash \forall_{f, x, i, j~|~\left(j - i\right) \in \mathbb{N} , x_{0} = f\left(i + 0\right) , \ldots , x_{j - i} = f\left(i + j - i\right)}~\left(\begin{array}{c} \left(x_{0} , \ldots , x_{j - i}\right) =  \\ \left(f\left(i\right) , \ldots , f\left(j\right)\right) \end{array}\right)

# %%
# display the expression information
merge_series.exprInfo()
# Out:
# 0. forall_{f, x, i, j | (j - i) in Naturals , x_{0} = f(i + 0) ,  ...  , x_{j - i} = f(i + j - i)} ((x_{0} ,  ...  , x_{j - i}) =  \\ (f(i) ,  ...  , f(j)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (f, x, i, j) -> {(x_{0} ,  ...  , x_{j - i}) =  \\ (f(i) ,  ...  , f(j)) if (j - i) in Naturals ,  x_{0} = f(i + 0) ,   ...  ,  x_{j - i} = f(i + j - i).
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f , x , i , j)
#    core type: ExprTuple
#    sub-expressions: 37, 36, 41, 31
# 4. {(x_{0} ,  ...  , x_{j - i}) =  \\ (f(i) ,  ...  , f(j)) if (j - i) in Naturals ,  x_{0} = f(i + 0) ,   ...  ,  x_{j - i} = f(i + j - i).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x_{0} ,  ...  , x_{j - i}) =  \\ (f(i) ,  ...  , f(j))
#    core type: Operation
#    operator: 28
#    operands: 7
# 6. ((j - i) in Naturals) and (x_{0} = f(i + 0)) and  ...  and (x_{j - i} = f(i + j - i))
# ...
