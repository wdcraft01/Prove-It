# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, Function
from proveit._common_ import a, f, fa, i, j, k
from proveit.logic import And, Equals, InSet
from proveit.number import Add, Naturals, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals([Function(f, i), ExprRange(a, fa, j, k)], [ExprRange(a, fa, i, k)]).withWrappingAt(2), And(InSet(Add(k, Neg(i)), Naturals), Equals(j, Add(i, one))))
# Out:
# expr: {(f(i) , f(j) ,  ...  , f(k)) =  \\ (f(i) ,  ...  , f(k)) if (k - i) in Naturals ,  j = (i + 1).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{c} \left(f\left(i\right) , f\left(j\right) , \ldots , f\left(k\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(k\right)\right) \end{array} \textrm{ if } \left(k - i\right) \in \mathbb{N} ,  j = \left(i + 1\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {(f(i) , f(j) ,  ...  , f(k)) =  \\ (f(i) ,  ...  , f(k)) if (k - i) in Naturals ,  j = (i + 1).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (f(i) , f(j) ,  ...  , f(k)) =  \\ (f(i) ,  ...  , f(k))
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. ((k - i) in Naturals) and (j = (i + 1))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((f(i) , f(j) ,  ...  , f(k)) , (f(i) ,  ...  , f(k)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((k - i) in Naturals , j = (i + 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. (f(i) , f(j) ,  ...  , f(k))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (f(i) ,  ...  , f(k))
#    core type: ExprTuple
#    sub-expressions: 12
# 8. (k - i) in Naturals
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. j = (i + 1)
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. f(i)
# ...
