# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable
from proveit.logic import And, Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("a")
subExpr3 = Add(Variable("m"), one)
subExpr4 = ExprRange(subExpr1, IndexedVar(subExpr2, subExpr1), one, Variable("m"))
subExpr5 = IndexedVar(subExpr2, subExpr3)
subExpr6 = ExprRange(subExpr2, IndexedVar(subExpr1, subExpr2), one, Variable("m"))
subExpr7 = IndexedVar(subExpr1, subExpr3)
expr = Equals(Equals([subExpr4, subExpr5], [subExpr6, subExpr7]), And(Equals([subExpr4], [subExpr6]), Equals(subExpr5, subExpr7)))
# Out:
# expr: ((a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1})) = (((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} , \ldots , a_{m} , a_{m + 1}\right) = \left(b_{1} , \ldots , b_{m} , b_{m + 1}\right)\right) = \left(\left(\left(a_{1} , \ldots , a_{m}\right) = \left(b_{1} , \ldots , b_{m}\right)\right) \land \left(a_{m + 1} = b_{m + 1}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1})) = (((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1}))
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. ((a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1}) , ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (a_{1} ,  ...  , a_{m} , a_{m + 1}) = (b_{1} ,  ...  , b_{m} , b_{m + 1})
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})) and (a_{m + 1} = b_{m + 1})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. ((a_{1} ,  ...  , a_{m} , a_{m + 1}) , (b_{1} ,  ...  , b_{m} , b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. ((a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m}) , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a_{1} ,  ...  , a_{m} , a_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 18, 16
# 8. (b_{1} ,  ...  , b_{m} , b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 19, 17
# 9. (a_{1} ,  ...  , a_{m}) = (b_{1} ,  ...  , b_{m})
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. a_{m + 1} = b_{m + 1}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. ((a_{1} ,  ...  , a_{m}) , (b_{1} ,  ...  , b_{m}))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (a_{m + 1} , b_{m + 1})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. (a_{1} ,  ...  , a_{m})
#     core type: ExprTuple
#     sub-expressions: 18
# 15. (b_{1} ,  ...  , b_{m})
#     core type: ExprTuple
#     sub-expressions: 19
# 16. a_{m + 1}
#     core type: IndexedVar
# variable: 30
# index: 20
# 17. b_{m + 1}
#     core type: IndexedVar
# variable: 29
# index: 20
# 18. a_{1},...,a_{m}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 28
#     end_index: 27
# 19. b_{1},...,b_{m}
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 28
#     end_index: 27
# 20. m + 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. b -> a_{b}
#     core type: Lambda
#     parameter: 29
#     body: 25
# 22. a -> b_{a}
#     core type: Lambda
#     parameter: 30
#     body: 26
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (m , 1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. a_{b}
#     core type: IndexedVar
# variable: 30
# index: 29
# 26. b_{a}
#     core type: IndexedVar
# variable: 29
# index: 30
# 27. m
#     core type: Variable
#     sub-expressions:
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
