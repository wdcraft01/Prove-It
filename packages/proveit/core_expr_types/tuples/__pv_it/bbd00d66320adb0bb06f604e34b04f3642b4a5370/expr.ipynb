# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Variable
from proveit.logic import And, Equals, Forall

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("d")
subExpr3 = []
expr = Forall([subExpr1, subExpr2], Equals(Equals([subExpr1], [subExpr2]), And(Equals(subExpr3, subExpr3), Equals(subExpr1, subExpr2))).withWrappingAt(2))
# Out:
# expr: forall_{b, d} (((b) = (d)) =  \\ ((() = ()) and (b = d)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{b, d}~\left(\begin{array}{c} \left(\left(b\right) = \left(d\right)\right) =  \\ \left(\left(() = ()\right) \land \left(b = d\right)\right) \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, d} (((b) = (d)) =  \\ ((() = ()) and (b = d)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (b, d) -> (((b) = (d)) =  \\ ((() = ()) and (b = d)))
#    core type: Lambda
#    parameters: 16\n   body: 3
# 3. ((b) = (d)) =  \\ ((() = ()) and (b = d))
#    core type: Operation
#    operator: 15
#    operands: 4
# 4. ((b) = (d) , (() = ()) and (b = d))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (b) = (d)
#    core type: Operation
#    operator: 15
#    operands: 7
# 6. (() = ()) and (b = d)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((b) , (d))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (() = () , b = d)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. (b)
#     core type: ExprTuple
#     sub-expressions: 18
# 11. (d)
#     core type: ExprTuple
#     sub-expressions: 19
# 12. () = ()
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. b = d
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (() , ())
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (b , d)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. ()
#     core type: ExprTuple
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. d
#     core type: Variable
#     sub-expressions:
