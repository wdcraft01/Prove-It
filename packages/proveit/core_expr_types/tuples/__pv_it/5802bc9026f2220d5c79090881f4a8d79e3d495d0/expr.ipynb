# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, Len
from proveit._common_ import a, fa, i, j, k
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = Equals(Len([ExprRange(a, fa, i, j)]), Len([ExprRange(k, k, i, j)]))
# Out:
# expr: |(f(i) ,  ...  , f(j))| = |(i ,  ...  , j)|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(f\left(i\right) , \ldots , f\left(j\right)\right)| = |\left(i , \ldots , j\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(f(i) ,  ...  , f(j))| = |(i ,  ...  , j)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(f(i) ,  ...  , f(j))| , |(i ,  ...  , j)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(f(i) ,  ...  , f(j))|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(i ,  ...  , j)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((f(i) ,  ...  , f(j)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((i ,  ...  , j))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (i ,  ...  , j)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 14
#     end_index: 15
# 11. i,...,j
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. a -> f(a)
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. k -> k
#     core type: Lambda
#     parameter: 17
#     body: 17
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. j
#     core type: Variable
#     sub-expressions:
# 16. f(a)
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. f
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
