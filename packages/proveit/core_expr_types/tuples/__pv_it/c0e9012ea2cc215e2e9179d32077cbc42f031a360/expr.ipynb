# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Len.html">Len</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Len, Variable
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("c")
expr = Len([ExprRange(subExpr1, Equals(IndexedVar(Variable("a"), subExpr1), IndexedVar(Variable("b"), subExpr1)), one, Add(Variable("m"), one))])
# Out:
# expr: |(a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})|

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a_{1} = b_{1} , \ldots , a_{m + 1} = b_{m + 1}\right)|

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1} = b_{1} ,  ...  , a_{m + 1} = b_{m + 1})
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (a_{1} = b_{1}),...,(a_{m + 1} = b_{m + 1})
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 13
#    end_index: 6
# 5. c -> (a_{c} = b_{c})
#    core type: Lambda
#    parameter: 18
#    body: 7
# 6. m + 1
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. a_{c} = b_{c}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (m , 1)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (a_{c} , b_{c})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. a_{c}
#     core type: IndexedVar
# variable: 16
# index: 18
# 15. b_{c}
#     core type: IndexedVar
# variable: 17
# index: 18
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
