# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, Variable
from proveit.logic import And, Forall
from proveit.number import Add, NaturalsPos, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(Function(Variable("P"), one), Forall([Variable("m")], Function(Variable("P"), Add(Variable("m"), one)), domain = NaturalsPos, condition = Function(Variable("P"), Variable("m")))), Forall([Variable("n")], Function(Variable("P"), Variable("n")), domain = NaturalsPos))
# Out:
# expr: (P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)] , forall_{n in NaturalsPos} P(n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P\left(1\right) \land \left[\forall_{m \in \mathbb{N}^+~|~P\left(m\right)}~P\left(m + 1\right)\right] , \forall_{n \in \mathbb{N}^+}~P\left(n\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)] , forall_{n in NaturalsPos} P(n))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(1) and [forall_{m in NaturalsPos | P(m)} P(m + 1)]
#    core type: Operation
#    operator: 18
#    operands: 3
# 2. forall_{n in NaturalsPos} P(n)
#    core type: Operation
#    operator: 8
#    operand: 4
# 3. (P(1) , forall_{m in NaturalsPos | P(m)} P(m + 1))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. n -> {P(n) if n in NaturalsPos.
#    core type: Lambda
#    parameter: 16
#    body: 7
# 5. P(1)
#    core type: Operation
#    operator: 27
#    operand: 24
# 6. forall_{m in NaturalsPos | P(m)} P(m + 1)
#    core type: Operation
#    operator: 8
#    operand: 9
# 7. {P(n) if n in NaturalsPos.
#    core type: Conditional
#    value: 10
#    condition: 11
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. m -> {P(m + 1) if m in NaturalsPos ,  P(m).
#    core type: Lambda
#    parameter: 28
#    body: 12
# ...
