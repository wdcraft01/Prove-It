# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#tuple_eq_via_elem_eq">tuple_eq_via_elem_eq</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.tuples._theorems_ import tuple_eq_via_elem_eq

# %%
# check that the built expression is the same as the stored expression
# %check_expr tuple_eq_via_elem_eq
# Out:
# Passed sanity check: built 'tuple_eq_via_elem_eq' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tuple_eq_via_elem_eq.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}^+}~\left[\forall_{a_{1},\ldots,a_{i}, b_{1},\ldots,b_{i}~|~a_{1} = b_{1} , \ldots , a_{i} = b_{i}}~\left(\left(a_{1} , \ldots , a_{i}\right) = \left(b_{1} , \ldots , b_{i}\right)\right)\right]

# %%
# display the expression information
tuple_eq_via_elem_eq.exprInfo()
# Out:
# 0. forall_{i in NaturalsPos} [forall_{a_{1},...,a_{i}, b_{1},...,b_{i} | a_{1} = b_{1} ,  ...  , a_{i} = b_{i}} ((a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}))]
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. i -> {forall_{a_{1},...,a_{i}, b_{1},...,b_{i} | a_{1} = b_{1} ,  ...  , a_{i} = b_{i}} ((a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i})) if i in NaturalsPos.
#    core type: Lambda
#    parameter: 26
#    body: 2
# 2. {forall_{a_{1},...,a_{i}, b_{1},...,b_{i} | a_{1} = b_{1} ,  ...  , a_{i} = b_{i}} ((a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i})) if i in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a_{1},...,a_{i}, b_{1},...,b_{i} | a_{1} = b_{1} ,  ...  , a_{i} = b_{i}} ((a_{1} ,  ...  , a_{i}) = (b_{1} ,  ...  , b_{i}))
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. i in NaturalsPos
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
# ...
