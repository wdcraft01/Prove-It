# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, Len
from proveit._common_ import a, f, fa, i, j
from proveit.logic import Equals
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
expr = Equals(Len([ExprRange(a, fa, i, j), Function(f, Add(j, one))]), Add(j, Neg(i)))
# Out:
# expr: |(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right)| = \left(j - i\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. |(f(i) ,  ...  , f(j) , f(j + 1))| = (j - i)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(f(i) ,  ...  , f(j) , f(j + 1))| , j - i)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(f(i) ,  ...  , f(j) , f(j + 1))|
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. j - i
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((f(i) ,  ...  , f(j) , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (j , -i)
#    core type: ExprTuple
#    sub-expressions: 21, 9
# 8. (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. -i
#    core type: Operation
#    operator: 12
#    operand: 14
# 10. f(i),...,f(j)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 21
# 11. f(j + 1)
#     core type: Operation
#     operator: 19
#     operand: 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. a -> f(a)
#     core type: Lambda
#     parameter: 20
#     body: 16
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. j + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. f(a)
#     core type: Operation
#     operator: 19
#     operand: 20
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. f
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. j
#     core type: Variable
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
