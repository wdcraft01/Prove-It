# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../_context_.ipynb">proveit</a>.<a class="ProveItLink" href="../../_context_.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../_context_.ipynb">tuples</a>.<a class="ProveItLink" href="../_theorems_.ipynb#extension_range_len">extension_range_len</a> theorem
# ========

# %%
import proveit
context = proveit.Context('..') # the theorem's context is in the parent directory

# %%
# %proving extension_range_len presuming []
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# c:\users\wwitzel\prove-it\packages\proveit\_core_\proof.py in _instantiated_expr(original_known_truth, num_forall_eliminations, parameters, repl_map, assumptions, requirements)
#    1105                     try:
# -> 1106                         requirements.append(subbed_cond.prove(assumptions))
#    1107                     except ProofFailure:
#
# c:\users\wwitzel\prove-it\packages\proveit\_core_\expression\expr.py in prove(self, assumptions, automation)
#     500         if not automation:
# --> 501             raise ProofFailure(self, assumptions, "No pre-existing proof")
#     502
#
# ProofFailure: Unable to prove |(f(b) ,  ...  , f(c))| in Naturals: No pre-existing proof
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# ...
