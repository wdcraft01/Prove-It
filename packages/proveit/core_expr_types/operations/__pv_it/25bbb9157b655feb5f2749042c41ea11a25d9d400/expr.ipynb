# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import f__x_1_to_n, f__y_1_to_n
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = Equals(f__x_1_to_n, f__y_1_to_n)
# Out:
# expr: f(x_{1} ,  ...  , x_{n}) = f(y_{1} ,  ...  , y_{n})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# f\left(x_{1} , \ldots , x_{n}\right) = f\left(y_{1} , \ldots , y_{n}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. f(x_{1} ,  ...  , x_{n}) = f(y_{1} ,  ...  , y_{n})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (f(x_{1} ,  ...  , x_{n}) , f(y_{1} ,  ...  , y_{n}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. f(x_{1} ,  ...  , x_{n})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. f(y_{1} ,  ...  , y_{n})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x_{1} ,  ...  , x_{n})
#    core type: ExprTuple
#    sub-expressions: 8
# 6. f
#    core type: Variable
#    sub-expressions:
# 7. (y_{1} ,  ...  , y_{n})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. x_{1},...,x_{n}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 12
#    end_index: 13
# 9. y_{1},...,y_{n}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 10. a -> x_{a}
#     core type: Lambda
#     parameter: 18
#     body: 14
# 11. a -> y_{a}
#     core type: Lambda
#     parameter: 18
#     body: 15
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. x_{a}
#     core type: IndexedVar
# variable: 16
# index: 18
# 15. y_{a}
#     core type: IndexedVar
# variable: 17
# index: 18
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. y
#     core type: Variable
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
