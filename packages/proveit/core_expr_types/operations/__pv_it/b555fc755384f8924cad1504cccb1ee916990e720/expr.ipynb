# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Variable
from proveit.core_expr_types._common_ import f__x_1_to_n, f__y_1_to_n, x_1_to_n, y_1_to_n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Naturals

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([Variable("f"), x_1_to_n, y_1_to_n], Equals(f__x_1_to_n, f__y_1_to_n), condition = Equals([x_1_to_n], [y_1_to_n])), InSet(Variable("n"), Naturals))
# Out:
# expr: {forall_{f, x_{1},...,x_{n}, y_{1},...,y_{n} | (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} (f(x_{1} ,  ...  , x_{n}) = f(y_{1} ,  ...  , y_{n})) if n in Naturals.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{f, x_{1},\ldots,x_{n}, y_{1},\ldots,y_{n}~|~\left(x_{1} , \ldots , x_{n}\right) = \left(y_{1} , \ldots , y_{n}\right)}~\left(f\left(x_{1} , \ldots , x_{n}\right) = f\left(y_{1} , \ldots , y_{n}\right)\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {forall_{f, x_{1},...,x_{n}, y_{1},...,y_{n} | (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} (f(x_{1} ,  ...  , x_{n}) = f(y_{1} ,  ...  , y_{n})) if n in Naturals.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f, x_{1},...,x_{n}, y_{1},...,y_{n} | (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n})} (f(x_{1} ,  ...  , x_{n}) = f(y_{1} ,  ...  , y_{n}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. n in Naturals
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (f, x_{1},...,x_{n}, y_{1},...,y_{n}) -> {f(x_{1} ,  ...  , x_{n}) = f(y_{1} ,  ...  , y_{n}) if (x_{1} ,  ...  , x_{n}) = (y_{1} ,  ...  , y_{n}).
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (n , Naturals)
#    core type: ExprTuple
#    sub-expressions: 25, 9
# 7. (f , x_{1} ,  ...  , x_{n} , y_{1} ,  ...  , y_{n})
# ...
