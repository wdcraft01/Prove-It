# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#iter_ext_equiv">iter_ext_equiv</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types._common_ import iter_ext_equiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr iter_ext_equiv
# Out:
# Passed sanity check: built 'iter_ext_equiv' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(iter_ext_equiv.latex())
# Out:
# \begin{array}{c} \left(f\left(i\right) , \ldots , f\left(j + 1\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right)\right) \end{array}

# %%
# display the expression information
iter_ext_equiv.exprInfo()
# Out:
# 0. (f(i) ,  ...  , f(j + 1)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i) ,  ...  , f(j + 1)) , (f(i) ,  ...  , f(j) , f(j + 1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i) ,  ...  , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f(i) ,  ...  , f(j) , f(j + 1))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. f(i),...,f(j + 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 6. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 16
# 7. f(j + 1)
#    core type: Operation
#    operator: 14
#    operand: 10
# 8. a -> f(a)
#    core type: Lambda
#    parameter: 15
#    body: 11
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. j + 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. f(a)
# ...
