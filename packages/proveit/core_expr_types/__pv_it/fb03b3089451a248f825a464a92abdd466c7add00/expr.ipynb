# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Len, Variable
from proveit._common_ import a, fa
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("b")
subExpr2 = Variable("i")
subExpr3 = Variable("j")
subExpr4 = Variable("k")
expr = ExprTuple(Len([ExprRange(subExpr1, IndexedVar(a, subExpr1), one, subExpr2), ExprRange(a, fa, subExpr3, subExpr4)]), Add(subExpr2, subExpr4, Neg(subExpr3), one))
# Out:
# expr: (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| , i + k - j + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a_{1} , \ldots , a_{i} , f\left(j\right) , \ldots , f\left(k\right)\right)| , i + k - j + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))| , i + k - j + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))|
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. i + k - j + 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k)))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (i , k , -j , 1)
#    core type: ExprTuple
#    sub-expressions: 14, 17, 8, 13
# 7. (a_{1} ,  ...  , a_{i} , f(j) ,  ...  , f(k))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. -j
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. a_{1},...,a_{i}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. f(j),...,f(k)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
# ...
