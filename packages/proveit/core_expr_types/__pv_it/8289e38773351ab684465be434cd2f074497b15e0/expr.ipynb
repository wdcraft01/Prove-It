# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#merge_back_equiv">merge_back_equiv</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types._common_ import merge_back_equiv

# %%
# check that the built expression is the same as the stored expression
# %check_expr merge_back_equiv
# Out:
# Passed sanity check: built 'merge_back_equiv' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_back_equiv.latex())
# Out:
# \begin{array}{c} \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(k\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(k\right)\right) \end{array}

# %%
# display the expression information
merge_back_equiv.exprInfo()
# Out:
# 0. (f(i) ,  ...  , f(j) , f(k)) =  \\ (f(i) ,  ...  , f(k))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i) ,  ...  , f(j) , f(k)) , (f(i) ,  ...  , f(k)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i) ,  ...  , f(j) , f(k))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (f(i) ,  ...  , f(k))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 8
# 6. f(k)
#    core type: Operation
#    operator: 13
#    operand: 11
# 7. f(i),...,f(k)
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. a -> f(a)
#    core type: Lambda
#    parameter: 14
#    body: 12
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. f(a)
# ...
