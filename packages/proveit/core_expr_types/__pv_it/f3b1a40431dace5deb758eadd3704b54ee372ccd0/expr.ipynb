# %% [markdown]
# Common Expression <a class="ProveItLink" href="../../_common_.ipynb#merge_series_conditions">merge_series_conditions</a> of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types._common_ import merge_series_conditions

# %%
# check that the built expression is the same as the stored expression
# %check_expr merge_series_conditions
# Out:
# Passed sanity check: built 'merge_series_conditions' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(merge_series_conditions.latex())
# Out:
# \left(x_{0} = f\left(i + 0\right)\right),\ldots,\left(x_{j - i} = f\left(i + j - i\right)\right)

# %%
# display the expression information
merge_series_conditions.exprInfo()
# Out:
# 0. (x_{0} = f(i + 0)),...,(x_{j - i} = f(i + j - i))
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 2
#    end_index: 3
# 1. k -> (x_{k} = f(i + k))
#    core type: Lambda
#    parameter: 19
#    body: 4
# 2. 0
#    core type: Literal
#    sub-expressions:
# 3. j - i
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. x_{k} = f(i + k)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (j , -i)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (x_{k} , f(i + k))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. -i
#    core type: Operation
#    operator: 12
#    operand: 18
# 10. x_{k}
#     core type: IndexedVar
# variable: 13
# index: 19
# 11. f(i + k)
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. i + k
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (i , k)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. i
#     core type: Variable
#     sub-expressions:
# 19. k
#     core type: Variable
#     sub-expressions:
