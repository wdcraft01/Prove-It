# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Function, Variable
from proveit._common_ import a, f, fa
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("i")
subExpr2 = Variable("j")
expr = ExprTuple([ExprRange(a, fa, subExpr1, subExpr2)], [ExprRange(a, fa, subExpr1, Add(subExpr2, Neg(one))), Function(f, subExpr2)])
# Out:
# expr: ((f(i) ,  ...  , f(j)) , (f(i) ,  ...  , f(j - 1) , f(j)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f\left(i\right) , \ldots , f\left(j\right)\right) , \left(f\left(i\right) , \ldots , f\left(j - 1\right) , f\left(j\right)\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((f(i) ,  ...  , f(j)) , (f(i) ,  ...  , f(j - 1) , f(j)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (f(i) ,  ...  , f(j - 1) , f(j))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 14
# 4. f(i),...,f(j - 1)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 5. f(j)
#    core type: Operation
#    operator: 12
#    operand: 14
# 6. a -> f(a)
#    core type: Lambda
#    parameter: 13
#    body: 9
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. j - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. f(a)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (j , -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. f
#     core type: Variable
# ...
