# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, IndexedVar, Variable
from proveit.logic import Equals
from proveit.number import Add, Neg, zero

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(Variable("i"), IndexedVar(Variable("x"), Variable("i")), zero, Add(Variable("j"), Neg(Variable("i"))))], [ExprRange(Variable("a"), Function(Variable("f"), Variable("a")), Variable("i"), Variable("j"))]).withWrappingAt(2)
# Out:
# expr: (x_{0} ,  ...  , x_{j - i}) =  \\ (f(i) ,  ...  , f(j))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(x_{0} , \ldots , x_{j - i}\right) =  \\ \left(f\left(i\right) , \ldots , f\left(j\right)\right) \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_{0} ,  ...  , x_{j - i}) =  \\ (f(i) ,  ...  , f(j))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((x_{0} ,  ...  , x_{j - i}) , (f(i) ,  ...  , f(j)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (x_{0} ,  ...  , x_{j - i})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f(i) ,  ...  , f(j))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. x_{0},...,x_{j - i}
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 6. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 21
#    end_index: 16
# 7. i -> x_{i}
#    core type: Lambda
#    parameter: 21
#    body: 11
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. j - i
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. a -> f(a)
#     core type: Lambda
#     parameter: 19
#     body: 14
# 11. x_{i}
#     core type: IndexedVar
# variable: 15
# index: 21
# ...
