# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Len, Variable
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = ExprRange(Variable("b"), IndexedVar(Variable("a"), Variable("b")), one, Variable("i"))
expr = ExprTuple(Len([subExpr1, Variable("b")]), Add(Len([subExpr1]), one))
# Out:
# expr: (|(a_{1} ,  ...  , a_{i} , b)| , |(a_{1} ,  ...  , a_{i})| + 1)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a_{1} , \ldots , a_{i} , b\right)| , |\left(a_{1} , \ldots , a_{i}\right)| + 1\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (|(a_{1} ,  ...  , a_{i} , b)| , |(a_{1} ,  ...  , a_{i})| + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a_{1} ,  ...  , a_{i} , b)|
#    core type: Operation
#    operator: 8
#    operand: 6
# 2. |(a_{1} ,  ...  , a_{i})| + 1
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((a_{1} ,  ...  , a_{i} , b))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (|(a_{1} ,  ...  , a_{i})| , 1)
#    core type: ExprTuple
#    sub-expressions: 7, 13
# 6. (a_{1} ,  ...  , a_{i} , b)
#    core type: ExprTuple
#    sub-expressions: 11, 17
# 7. |(a_{1} ,  ...  , a_{i})|
#    core type: Operation
#    operator: 8
#    operand: 10
# 8. length
#    core type: Literal
#    sub-expressions:
# 9. ((a_{1} ,  ...  , a_{i}))
#    core type: ExprTuple
#    sub-expressions: 10
# 10. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 11
# 11. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. b -> a_{b}
#     core type: Lambda
#     parameter: 17
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. a_{b}
#     core type: IndexedVar
# variable: 16
# index: 17
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
