# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprRange
from proveit._common_ import a, fa, i, j, k
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(a, fa, i, k)], [ExprRange(a, fa, i, j), ExprRange(a, fa, Add(j, one), k)]).withWrappingAt(2)
# Out:
# expr: (f(i) ,  ...  , f(k)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1) ,  ...  , f(k))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left(f\left(i\right) , \ldots , f\left(k\right)\right) =  \\ \left(f\left(i\right) , \ldots , f\left(j\right) , f\left(j + 1\right) , \ldots , f\left(k\right)\right) \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (f(i) ,  ...  , f(k)) =  \\ (f(i) ,  ...  , f(j) , f(j + 1) ,  ...  , f(k))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i) ,  ...  , f(k)) , (f(i) ,  ...  , f(j) , f(j + 1) ,  ...  , f(k)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i) ,  ...  , f(k))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f(i) ,  ...  , f(j) , f(j + 1) ,  ...  , f(k))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. f(i),...,f(k)
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 8
#    end_index: 11
# 6. f(i),...,f(j)
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 8
#    end_index: 17
# 7. f(j + 1),...,f(k)
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 10
#    end_index: 11
# 8. i
#    core type: Variable
#    sub-expressions:
# 9. a -> f(a)
#    core type: Lambda
#    parameter: 16
#    body: 12
# 10. j + 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. f(a)
#     core type: Operation
#     operator: 15
#     operand: 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (j , 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. f
#     core type: Variable
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. j
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
