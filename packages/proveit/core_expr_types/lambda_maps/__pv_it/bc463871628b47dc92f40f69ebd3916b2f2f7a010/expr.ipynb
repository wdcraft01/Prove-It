# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda
from proveit.core_expr_types._common_ import Q__b_1_to_i, Q__c_1_to_i, b_1_to_i, c_1_to_i, f__b_1_to_i, g__c_1_to_i
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = Equals(Lambda(b_1_to_i, Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda(c_1_to_i, Conditional(g__c_1_to_i, Q__c_1_to_i))).withWrappingAt(2)
# Out:
# expr: [(b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).] =  \\ [(c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left[\left(b_{1},\ldots,b_{i}\right) \mapsto \left\{f\left(b_{1} , \ldots , b_{i}\right) \textrm{ if } Q\left(b_{1} , \ldots , b_{i}\right)\right..\right] =  \\ \left[\left(c_{1},\ldots,c_{i}\right) \mapsto \left\{g\left(c_{1} , \ldots , c_{i}\right) \textrm{ if } Q\left(c_{1} , \ldots , c_{i}\right)\right..\right] \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [(b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).] =  \\ [(c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}). , (c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).
#    core type: Lambda
#    parameter: 16
#    body: 5
# 4. (c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).
#    core type: Lambda
#    parameter: 17
#    body: 6
# 5. {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).
#    core type: Conditional
#    value: 7
#    condition: 8
# 6. {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).
#    core type: Conditional
#    value: 9
#    condition: 10
# 7. f(b_{1} ,  ...  , b_{i})
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. Q(b_{1} ,  ...  , b_{i})
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. g(c_{1} ,  ...  , c_{i})
#    core type: Operation
#    operator: 13
#    operands: 15
# 10. Q(c_{1} ,  ...  , c_{i})
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. (b_{1} ,  ...  , b_{i})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. g
#     core type: Variable
#     sub-expressions:
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. (c_{1} ,  ...  , c_{i})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. b_{1},...,b_{i}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 20
#     end_index: 21
# 17. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. a -> b_{a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 19. a -> c_{a}
#     core type: Lambda
#     parameter: 26
#     body: 23
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. b_{a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 23. c_{a}
#     core type: IndexedVar
# variable: 25
# index: 26
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
