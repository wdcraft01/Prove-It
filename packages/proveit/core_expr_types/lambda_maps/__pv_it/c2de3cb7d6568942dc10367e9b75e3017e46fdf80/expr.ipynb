# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import a_1_to_i, f__a_1_to_i, g__a_1_to_i
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i))
# Out:
# expr: forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1},\ldots,a_{i}}~\left(f\left(a_{1} , \ldots , a_{i}\right) = g\left(a_{1} , \ldots , a_{i}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1},...,a_{i}) -> (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))
#    core type: Lambda
#    parameter: 11
#    body: 3
# 3. f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (f(a_{1} ,  ...  , a_{i}) , g(a_{1} ,  ...  , a_{i}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. f(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 8
#    operands: 10
# 7. g(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. f
#    core type: Variable
#    sub-expressions:
# 9. g
#    core type: Variable
#    sub-expressions:
# 10. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 11
# 11. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 12. b -> a_{b}
#     core type: Lambda
#     parameter: 17
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. a_{b}
#     core type: IndexedVar
# variable: 16
# index: 17
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
