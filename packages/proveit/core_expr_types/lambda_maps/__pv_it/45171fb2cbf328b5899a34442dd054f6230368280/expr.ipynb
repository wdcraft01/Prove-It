# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda
from proveit.core_expr_types._common_ import Q__a_1_to_i, Q__b_1_to_i, Q__c_1_to_i, a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i), Equals(Lambda(b_1_to_i, Conditional(f__b_1_to_i, Q__b_1_to_i)), Lambda(c_1_to_i, Conditional(g__c_1_to_i, Q__c_1_to_i))).withWrappingAt(2))
# Out:
# expr: (forall_{a_{1},...,a_{i} | Q(a_{1} ,  ...  , a_{i})} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})) , [(b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).] =  \\ [(c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{a_{1},\ldots,a_{i}~|~Q\left(a_{1} , \ldots , a_{i}\right)}~\left(f\left(a_{1} , \ldots , a_{i}\right) = g\left(a_{1} , \ldots , a_{i}\right)\right) , \begin{array}{c} \left[\left(b_{1},\ldots,b_{i}\right) \mapsto \left\{f\left(b_{1} , \ldots , b_{i}\right) \textrm{ if } Q\left(b_{1} , \ldots , b_{i}\right)\right..\right] =  \\ \left[\left(c_{1},\ldots,c_{i}\right) \mapsto \left\{g\left(c_{1} , \ldots , c_{i}\right) \textrm{ if } Q\left(c_{1} , \ldots , c_{i}\right)\right..\right] \end{array}\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (forall_{a_{1},...,a_{i} | Q(a_{1} ,  ...  , a_{i})} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})) , [(b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).] =  \\ [(c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{a_{1},...,a_{i} | Q(a_{1} ,  ...  , a_{i})} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. [(b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).] =  \\ [(c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).]
#    core type: Operation
#    operator: 13
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a_{1},...,a_{i}) -> {f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}) if Q(a_{1} ,  ...  , a_{i}).
#    core type: Lambda
#    parameter: 29
#    body: 6
# 5. ((b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}). , (c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}) if Q(a_{1} ,  ...  , a_{i}).
#    core type: Conditional
#    value: 9
#    condition: 10
# 7. (b_{1},...,b_{i}) -> {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).
#    core type: Lambda
#    parameter: 27
#    body: 11
# 8. (c_{1},...,c_{i}) -> {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).
#    core type: Lambda
#    parameter: 28
#    body: 12
# 9. f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Q(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 22
#     operands: 26
# 11. {f(b_{1} ,  ...  , b_{i}) if Q(b_{1} ,  ...  , b_{i}).
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. {g(c_{1} ,  ...  , c_{i}) if Q(c_{1} ,  ...  , c_{i}).
#     core type: Conditional
#     value: 17
#     condition: 18
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (f(a_{1} ,  ...  , a_{i}) , g(a_{1} ,  ...  , a_{i}))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. f(b_{1} ,  ...  , b_{i})
#     core type: Operation
#     operator: 24
#     operands: 21
# 16. Q(b_{1} ,  ...  , b_{i})
#     core type: Operation
#     operator: 22
#     operands: 21
# 17. g(c_{1} ,  ...  , c_{i})
#     core type: Operation
#     operator: 25
#     operands: 23
# 18. Q(c_{1} ,  ...  , c_{i})
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. f(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 24
#     operands: 26
# 20. g(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. (b_{1} ,  ...  , b_{i})
#     core type: ExprTuple
#     sub-expressions: 27
# 22. Q
#     core type: Variable
#     sub-expressions:
# 23. (c_{1} ,  ...  , c_{i})
#     core type: ExprTuple
#     sub-expressions: 28
# 24. f
#     core type: Variable
#     sub-expressions:
# 25. g
#     core type: Variable
#     sub-expressions:
# 26. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 29
# 27. b_{1},...,b_{i}
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 33
#     end_index: 34
# 28. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 33
#     end_index: 34
# 29. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 32
#     start_index: 33
#     end_index: 34
# 30. a -> b_{a}
#     core type: Lambda
#     parameter: 39
#     body: 35
# 31. a -> c_{a}
#     core type: Lambda
#     parameter: 39
#     body: 36
# 32. b -> a_{b}
#     core type: Lambda
#     parameter: 40
#     body: 37
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. i
#     core type: Variable
#     sub-expressions:
# 35. b_{a}
#     core type: IndexedVar
# variable: 40
# index: 39
# 36. c_{a}
#     core type: IndexedVar
# variable: 38
# index: 39
# 37. a_{b}
#     core type: IndexedVar
# variable: 39
# index: 40
# 38. c
#     core type: Variable
#     sub-expressions:
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. b
#     core type: Variable
#     sub-expressions:
