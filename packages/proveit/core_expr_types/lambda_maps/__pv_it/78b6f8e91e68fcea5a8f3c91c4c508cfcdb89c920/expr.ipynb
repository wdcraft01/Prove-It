# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#lambda_substitution">lambda_substitution</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.lambda_maps._axioms_ import lambda_substitution

# %%
# check that the built expression is the same as the stored expression
# %check_expr lambda_substitution
# Out:
# Passed sanity check: built 'lambda_substitution' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(lambda_substitution.latex())
# Out:
# \vdash \forall_{i \in \mathbb{N}^+}~\left[\forall_{f, g}~\left(\begin{array}{c} \left[\forall_{a_{1},\ldots,a_{i}}~\left(f\left(a_{1} , \ldots , a_{i}\right) = g\left(a_{1} , \ldots , a_{i}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\left(b_{1},\ldots,b_{i}\right) \mapsto f\left(b_{1} , \ldots , b_{i}\right)\right] =  \\ \left[\left(c_{1},\ldots,c_{i}\right) \mapsto g\left(c_{1} , \ldots , c_{i}\right)\right] \end{array}\right) \end{array}\right)\right]

# %%
# display the expression information
lambda_substitution.exprInfo()
# Out:
# 0. forall_{i in NaturalsPos} [forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})]))]
#    core type: Operation
#    operator: 15
#    operand: 1
# 1. i -> {forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])) if i in NaturalsPos.
#    core type: Lambda
#    parameter: 39
#    body: 2
# 2. {forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])) if i in NaturalsPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# ...
