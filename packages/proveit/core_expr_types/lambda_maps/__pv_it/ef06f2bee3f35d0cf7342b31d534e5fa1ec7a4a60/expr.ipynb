# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Variable
from proveit.core_expr_types._common_ import a_1_to_i, b_1_to_i, c_1_to_i, f__a_1_to_i, f__b_1_to_i, g__a_1_to_i, g__c_1_to_i
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.number import NaturalsPos

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("i")
expr = Lambda(subExpr1, Conditional(Forall([Variable("f"), Variable("g")], Implies(Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i)), Equals(Lambda(b_1_to_i, f__b_1_to_i), Lambda(c_1_to_i, g__c_1_to_i)).withWrappingAt(2)).withWrappingAt(2)), InSet(subExpr1, NaturalsPos)))
# Out:
# expr: i -> {forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])) if i in NaturalsPos.

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left\{\forall_{f, g}~\left(\begin{array}{c} \left[\forall_{a_{1},\ldots,a_{i}}~\left(f\left(a_{1} , \ldots , a_{i}\right) = g\left(a_{1} , \ldots , a_{i}\right)\right)\right] \Rightarrow  \\ \left(\begin{array}{c} \left[\left(b_{1},\ldots,b_{i}\right) \mapsto f\left(b_{1} , \ldots , b_{i}\right)\right] =  \\ \left[\left(c_{1},\ldots,c_{i}\right) \mapsto g\left(c_{1} , \ldots , c_{i}\right)\right] \end{array}\right) \end{array}\right) \textrm{ if } i \in \mathbb{N}^+\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. i -> {forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])) if i in NaturalsPos.
#    core type: Lambda
#    parameter: 38
#    body: 1
# 1. {forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])) if i in NaturalsPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{f, g} ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})]))
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. i in NaturalsPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (f, g) -> ([forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})]))
#    core type: Lambda
#    parameters: 7\n   body: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 38, 9
# 7. (f , g)
#    core type: ExprTuple
#    sub-expressions: 28, 29
# 8. [forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))] =>  \\ ([(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 10. =>
#     core type: Literal
#     sub-expressions:
# 11. (forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})) , [(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})])
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. forall_{a_{1},...,a_{i}} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. [(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})]
#     core type: Operation
#     operator: 20
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. (a_{1},...,a_{i}) -> (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))
#     core type: Lambda
#     parameter: 33
#     body: 17
# 16. ((b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i}) , (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})
#     core type: Lambda
#     parameter: 31
#     body: 22
# 19. (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})
#     core type: Lambda
#     parameter: 32
#     body: 23
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (f(a_{1} ,  ...  , a_{i}) , g(a_{1} ,  ...  , a_{i}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. f(b_{1} ,  ...  , b_{i})
#     core type: Operation
#     operator: 28
#     operands: 26
# 23. g(c_{1} ,  ...  , c_{i})
#     core type: Operation
#     operator: 29
#     operands: 27
# 24. f(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 28
#     operands: 30
# 25. g(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (b_{1} ,  ...  , b_{i})
#     core type: ExprTuple
#     sub-expressions: 31
# 27. (c_{1} ,  ...  , c_{i})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. g
#     core type: Variable
#     sub-expressions:
# 30. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 33
# 31. b_{1},...,b_{i}
#     core type: ExprRange
#     lambda_map: 34
#     start_index: 37
#     end_index: 38
# 32. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 37
#     end_index: 38
# 33. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 36
#     start_index: 37
#     end_index: 38
# 34. a -> b_{a}
#     core type: Lambda
#     parameter: 43
#     body: 39
# 35. a -> c_{a}
#     core type: Lambda
#     parameter: 43
#     body: 40
# 36. b -> a_{b}
#     core type: Lambda
#     parameter: 44
#     body: 41
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. i
#     core type: Variable
#     sub-expressions:
# 39. b_{a}
#     core type: IndexedVar
# variable: 44
# index: 43
# 40. c_{a}
#     core type: IndexedVar
# variable: 42
# index: 43
# 41. a_{b}
#     core type: IndexedVar
# variable: 43
# index: 44
# 42. c
#     core type: Variable
#     sub-expressions:
# 43. a
#     core type: Variable
#     sub-expressions:
# 44. b
#     core type: Variable
#     sub-expressions:
