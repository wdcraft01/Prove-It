# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit.core_expr_types._common_ import b_1_to_i, c_1_to_i, f__b_1_to_i, g__c_1_to_i
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = Equals(Lambda(b_1_to_i, f__b_1_to_i), Lambda(c_1_to_i, g__c_1_to_i)).withWrappingAt(2)
# Out:
# expr: [(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array}{c} \left[\left(b_{1},\ldots,b_{i}\right) \mapsto f\left(b_{1} , \ldots , b_{i}\right)\right] =  \\ \left[\left(c_{1},\ldots,c_{i}\right) \mapsto g\left(c_{1} , \ldots , c_{i}\right)\right] \end{array}

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. [(b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})] =  \\ [(c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i}) , (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})
#    core type: Lambda
#    parameter: 11
#    body: 5
# 4. (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})
#    core type: Lambda
#    parameter: 12
#    body: 6
# 5. f(b_{1} ,  ...  , b_{i})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. g(c_{1} ,  ...  , c_{i})
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. f
#    core type: Variable
#    sub-expressions:
# 8. (b_{1} ,  ...  , b_{i})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. g
#    core type: Variable
#    sub-expressions:
# 10. (c_{1} ,  ...  , c_{i})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. b_{1},...,b_{i}
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 15
#     end_index: 16
# 12. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 13. a -> b_{a}
#     core type: Lambda
#     parameter: 21
#     body: 17
# 14. a -> c_{a}
#     core type: Lambda
#     parameter: 21
#     body: 18
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. b_{a}
#     core type: IndexedVar
# variable: 19
# index: 21
# 18. c_{a}
#     core type: IndexedVar
# variable: 20
# index: 21
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
