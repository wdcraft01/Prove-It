# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda
from proveit.core_expr_types._common_ import b_1_to_i, c_1_to_i, f__b_1_to_i, g__c_1_to_i

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(b_1_to_i, f__b_1_to_i), Lambda(c_1_to_i, g__c_1_to_i))
# Out:
# expr: ((b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i}) , (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(b_{1},\ldots,b_{i}\right) \mapsto f\left(b_{1} , \ldots , b_{i}\right) , \left(c_{1},\ldots,c_{i}\right) \mapsto g\left(c_{1} , \ldots , c_{i}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i}) , (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (b_{1},...,b_{i}) -> f(b_{1} ,  ...  , b_{i})
#    core type: Lambda
#    parameter: 9
#    body: 3
# 2. (c_{1},...,c_{i}) -> g(c_{1} ,  ...  , c_{i})
#    core type: Lambda
#    parameter: 10
#    body: 4
# 3. f(b_{1} ,  ...  , b_{i})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. g(c_{1} ,  ...  , c_{i})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. f
#    core type: Variable
#    sub-expressions:
# 6. (b_{1} ,  ...  , b_{i})
#    core type: ExprTuple
#    sub-expressions: 9
# 7. g
#    core type: Variable
#    sub-expressions:
# 8. (c_{1} ,  ...  , c_{i})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. b_{1},...,b_{i}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 13
#    end_index: 14
# 10. c_{1},...,c_{i}
#     core type: ExprRange
#     lambda_map: 12
#     start_index: 13
#     end_index: 14
# 11. a -> b_{a}
#     core type: Lambda
#     parameter: 19
#     body: 15
# 12. a -> c_{a}
#     core type: Lambda
#     parameter: 19
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. b_{a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 16. c_{a}
#     core type: IndexedVar
# variable: 18
# index: 19
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
