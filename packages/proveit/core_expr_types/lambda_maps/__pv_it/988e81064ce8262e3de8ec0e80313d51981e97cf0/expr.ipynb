# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit.core_expr_types._common_ import Q__a_1_to_i, a_1_to_i, f__a_1_to_i, g__a_1_to_i
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i], Equals(f__a_1_to_i, g__a_1_to_i), condition = Q__a_1_to_i)
# Out:
# expr: forall_{a_{1},...,a_{i} | Q(a_{1} ,  ...  , a_{i})} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1},\ldots,a_{i}~|~Q\left(a_{1} , \ldots , a_{i}\right)}~\left(f\left(a_{1} , \ldots , a_{i}\right) = g\left(a_{1} , \ldots , a_{i}\right)\right)

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a_{1},...,a_{i} | Q(a_{1} ,  ...  , a_{i})} (f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a_{1},...,a_{i}) -> {f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}) if Q(a_{1} ,  ...  , a_{i}).
#    core type: Lambda
#    parameter: 14
#    body: 3
# 3. {f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i}) if Q(a_{1} ,  ...  , a_{i}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. f(a_{1} ,  ...  , a_{i}) = g(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. Q(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 8
#    operands: 13
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (f(a_{1} ,  ...  , a_{i}) , g(a_{1} ,  ...  , a_{i}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. Q
#    core type: Variable
#    sub-expressions:
# 9. f(a_{1} ,  ...  , a_{i})
#    core type: Operation
#    operator: 11
#    operands: 13
# 10. g(a_{1} ,  ...  , a_{i})
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. g
#     core type: Variable
#     sub-expressions:
# 13. (a_{1} ,  ...  , a_{i})
#     core type: ExprTuple
#     sub-expressions: 14
# 14. a_{1},...,a_{i}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 16
#     end_index: 17
# 15. b -> a_{b}
#     core type: Lambda
#     parameter: 20
#     body: 18
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. a_{b}
#     core type: IndexedVar
# variable: 19
# index: 20
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
