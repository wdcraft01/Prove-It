# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Variable
from proveit.logic import Equals, Implies

# %%
# build up the expression from sub-expressions
expr = Lambda([Variable("a"), Variable("b"), Variable("Q")], Conditional(Equals(Conditional(Variable("a"), Variable("Q")), Conditional(Variable("b"), Variable("Q"))).withWrappingAt(1), Implies(Variable("Q"), Equals(Variable("a"), Variable("b")))))
# Out:
# expr: (a, b, Q) -> {{a if Q. \\  = {b if Q. if Q => (a = b).

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, Q\right) \mapsto \left\{\begin{array}{c} \left\{a \textrm{ if } Q\right.. \\  = \left\{b \textrm{ if } Q\right.. \end{array} \textrm{ if } Q \Rightarrow \left(a = b\right)\right..

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a, b, Q) -> {{a if Q. \\  = {b if Q. if Q => (a = b).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a , b , Q)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 11
# 2. {{a if Q. \\  = {b if Q. if Q => (a = b).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. {a if Q. \\  = {b if Q.
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. Q => (a = b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a if Q , b if Q)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =>
#    core type: Literal
#    sub-expressions:
# 7. (Q , a = b)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. {a if Q.
#    core type: Conditional
#    value: 14
#    condition: 11
# 9. {b if Q.
#    core type: Conditional
#    value: 15
#    condition: 11
# 10. a = b
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Q
#     core type: Variable
#     sub-expressions:
# 12. =
#     core type: Literal
# ...
