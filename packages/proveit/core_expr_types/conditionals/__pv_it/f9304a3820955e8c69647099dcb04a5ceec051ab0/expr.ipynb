# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#single_condition_reduction">single_condition_reduction</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.core_expr_types.conditionals</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
# import the special expression
from proveit.core_expr_types.conditionals._theorems_ import single_condition_reduction

# %%
# check that the built expression is the same as the stored expression
# %check_expr single_condition_reduction
# Out:
# Passed sanity check: built 'single_condition_reduction' is the same as the stored Expression.

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(single_condition_reduction.latex())
# Out:
# \vdash \forall_{a, b}~\left(\begin{array}{c} \left\{a \textrm{ if } \left[\land\right]\left(b\right)\right.. \\  = \left\{a \textrm{ if } b\right.. \end{array}\right)

# %%
# display the expression information
single_condition_reduction.exprInfo()
# Out:
# 0. forall_{a, b} ({a if [and](b). \\  = {a if b.)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a, b) -> ({a if [and](b). \\  = {a if b.)
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a , b)
#    core type: ExprTuple
#    sub-expressions: 10, 12
# 4. {a if [and](b). \\  = {a if b.
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a if [and](b) , a if b)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. {a if [and](b).
#    core type: Conditional
#    value: 10
#    condition: 9
# 8. {a if b.
#    core type: Conditional
#    value: 10
#    condition: 12
# 9. [and](b)
#    core type: Operation
#    operator: 11
#    operand: 12
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. and
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
