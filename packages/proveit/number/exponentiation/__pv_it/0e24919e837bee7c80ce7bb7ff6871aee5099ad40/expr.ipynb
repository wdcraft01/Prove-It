# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Forall, NotEquals
from proveit.number import Complexes, Exp, zero

# %%
# build up the expression from sub-expressions
expr = Forall([b], NotEquals(Exp(a, b), zero), domain = Complexes, conditions = [])
# Out:
# expr: forall_{b in Complexes} (a^{b} != 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b in Complexes} (a^{b} != 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. b -> (a^{b} != 0) | b in Complexes
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. a^{b} != 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. !=
#    core type: Literal
#    sub-expressions:
# 6. (a^{b} , 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. b in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a^{b}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 16, 14
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (a , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
