# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#exponentiatedZero">exponentiatedZero</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.exponentiation._theorems_ import exponentiatedZero

# %%
# check that the built expression is the same as the stored expression
# %check_expr exponentiatedZero
# Out:
# Passed sanity check: built 'exponentiatedZero' is the same as the stored Expression.

# %%
# display the expression information
exponentiatedZero.exprInfo()
# Out:
# 0. forall_{x in Complexes | x != 0} (0^{x} = 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> (0^{x} = 0) | x in Complexes , x != 0
#    core type: Lambda
#    parameter: 18
#    body: 3
#    conditions: 4\n3. 0^{x} = 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complexes , x != 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (0^{x} , 0)
#    core type: ExprTuple
#    sub-expressions: 9, 17
# 7. x in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x != 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. 0^{x}
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 12. !=
#     core type: Literal
#     sub-expressions:
# ...
