# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Forall, InSet, NotEquals
from proveit.number import Complexes, Exp, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], NotEquals(Exp(a, b), zero), domain = Complexes, conditions = []), conditions = [InSet(a, Complexes), NotEquals(a, zero)])
# Out:
# expr: a -> [forall_{b in Complexes} (a^{b} != 0)] | a in Complexes , a != 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b in Complexes} (a^{b} != 0)] | a in Complexes , a != 0
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. forall_{b in Complexes} (a^{b} != 0)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Complexes , a != 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> (a^{b} != 0) | b in Complexes
#    core type: Lambda
#    parameter: 22
#    body: 7
#    conditions: 8\n5. a in Complexes
#    core type: Operation
#    operator: 16
#    operands: 9
# 6. a != 0
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. a^{b} != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 13
# 9. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 21, 20
# 10. (a , 0)
#     core type: ExprTuple
#     sub-expressions: 21, 15
# 11. !=
#     core type: Literal
# ...
