# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.exponentiation</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a
from proveit.logic import Equals, InSet, NotEquals
from proveit.number import Complexes, Exp, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Equals(Exp(a, zero), one), conditions = [InSet(a, Complexes), NotEquals(a, zero)])
# Out:
# expr: a -> (a^{0} = 1) | a in Complexes , a != 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> (a^{0} = 1) | a in Complexes , a != 0
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. a^{0} = 1
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Complexes , a != 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a^{0} , 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. a in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. a != 0
#    core type: Operation
#    operator: 11
#    operands: 13
# 7. a^{0}
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (a , Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (a , 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
