# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#elimZeroLeft">elimZeroLeft</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.addition._theorems_ import elimZeroLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr elimZeroLeft
# Out:
# Passed sanity check: built 'elimZeroLeft' is the same as the stored Expression.

# %%
# display the expression information
elimZeroLeft.exprInfo()
# Out:
# 0. forall_{a in Complexes} ((0 + a) = a)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> ((0 + a) = a) | a in Complexes
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. (0 + a) = a
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (0 + a , a)
#    core type: ExprTuple
#    sub-expressions: 8, 15
# 7. a in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. 0 + a
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (a , Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (0 , a)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Complexes
# ...
