# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, four, nine, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, a)
subExpr2 = Mult(two, c)
subExpr3 = Mult(two, b)
expr = ExprTuple(Add(subExpr1, subExpr2, subExpr3, Add(two, three, four)), Add(subExpr1, subExpr2, subExpr3, nine))
# Out:
# expr: ((2 * a) + (2 * c) + (2 * b) + (2 + 3 + 4) , (2 * a) + (2 * c) + (2 * b) + 9)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * a) + (2 * c) + (2 * b) + (2 + 3 + 4) , (2 * a) + (2 * c) + (2 * b) + 9)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * a) + (2 * c) + (2 * b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (2 * a) + (2 * c) + (2 * b) + 9
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (2 * a , 2 * c , 2 * b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 5
# 4. (2 * a , 2 * c , 2 * b , 9)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 2 + 3 + 4
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. 2 * a
#    core type: Operation
#    operator: 14
#    operands: 12
# 7. 2 * c
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. 2 * b
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. 9
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 20, 16, 17
# 12. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 13. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 4
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
