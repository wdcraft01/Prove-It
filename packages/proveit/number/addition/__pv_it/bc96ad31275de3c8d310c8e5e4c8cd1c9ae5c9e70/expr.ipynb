# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter
from proveit._common_ import AA, i, m, x
from proveit.logic import Equals, Forall
from proveit.logic._common_ import iterA1m
from proveit.number import Add, Complexes, Mult, one

# %%
# build up the expression from sub-expressions
expr = Forall([x], Equals(Add(iterA1m), Mult(m, x)), domain = Complexes, conditions = [Iter(i, Equals(Indexed(AA, i, base = 1), x), one, m)])
# Out:
# expr: forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((A_1 +  ...  + A_m) = (m * x)) | x in Complexes , A_1 = x ,  ...  , A_m = x
#    core type: Lambda
#    parameter: 25
#    body: 3
#    conditions: 4\n3. (A_1 +  ...  + A_m) = (m * x)
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. (x in Complexes , A_1 = x ,  ...  , A_m = x)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (A_1 +  ...  + A_m , m * x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. x in Complexes
#    core type: Operation
#    operator: 32
#    operands: 10
# 7. (A_1 = x),...,(A_m = x)
#    core type: Iter
#    lambda_map: 11
#    start_index: 38
#    end_index: 39
# 8. A_1 +  ...  + A_m
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. m * x
#    core type: Operation
#    operator: 14
# ...
