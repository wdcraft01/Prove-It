# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = Equals(Add(c, c, subExpr1, subExpr2, two), Add(Add(c, c), subExpr1, subExpr2, two))
# Out:
# expr: (c + c + (3 * b) + (2 * b) + 2) = ((c + c) + (3 * b) + (2 * b) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (c + c + (3 * b) + (2 * b) + 2) = ((c + c) + (3 * b) + (2 * b) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (c + c + (3 * b) + (2 * b) + 2 , (c + c) + (3 * b) + (2 * b) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. c + c + (3 * b) + (2 * b) + 2
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (c + c) + (3 * b) + (2 * b) + 2
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (c , c , 3 * b , 2 * b , 2)
#    core type: ExprTuple
#    sub-expressions: 15, 15, 8, 9, 17
# 6. (c + c , 3 * b , 2 * b , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 17
# 7. c + c
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 2 * b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (c , c)
#     core type: ExprTuple
#     sub-expressions: 15, 15
# 12. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
