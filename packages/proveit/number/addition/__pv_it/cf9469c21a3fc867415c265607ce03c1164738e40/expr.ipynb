# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import aa, bb, c, dd, l, m, n
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Exp, Naturals
from proveit.number._common_ import iter_a1l, iter_b1m, iter_d1n

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([m, n], Forall([aa, bb, c, dd], Equals(Add(iter_a1l, iter_b1m, c, iter_d1n), Add(iter_a1l, c, iter_b1m, iter_d1n)), domains = [Exp(Complexes, l), Exp(Complexes, m), Complexes, Exp(Complexes, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1)
# Out:
# expr: forall_{m, n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes^{m} * Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes^{m} * Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))]
#    core type: Operation
#    operator: 27
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes^{m} * Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))]] | m in Naturals
#    core type: Lambda
#    parameter: 80
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes^{m} * Complexes * Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))]
#    core type: Operation
#    operator: 27
#    operand: 4
# 3. (m in Naturals)
# ...
