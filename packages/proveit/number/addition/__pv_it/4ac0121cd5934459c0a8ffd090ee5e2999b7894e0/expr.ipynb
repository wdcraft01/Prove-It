# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(Add(a, a), Add(c, c, c), b, b, one, two, three))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((a + a) + (c + c + c) + b + b + 1 + 2 + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((a + a) + (c + c + c) + b + b + 1 + 2 + 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3 , (a + a) + (c + c + c) + b + b + 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. (a + a) + (c + c + c) + b + b + 1 + 2 + 3
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a , 1 , 2 , c , b , a , 0 , b , c , c , 3)
#    core type: ExprTuple
#    sub-expressions: 17, 11, 12, 18, 10, 17, 7, 10, 18, 18, 13
# 6. (a + a , c + c + c , b , b , 1 , 2 , 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 10, 11, 12, 13
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. a + a
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. c + c + c
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. (a , a)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (c , c , c)
#     core type: ExprTuple
#     sub-expressions: 18, 18, 18
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
