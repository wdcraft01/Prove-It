# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, m
from proveit.logic import InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Add, Exp, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, InSet(Add(iterA1m), Reals), conditions = [InSet(AA, Exp(Reals, m))])
# Out:
# expr: A -> ((A_1 +  ...  + A_m) in Reals) | A in Reals^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> ((A_1 +  ...  + A_m) in Reals) | A in Reals^{m}
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. (A_1 +  ...  + A_m) in Reals
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (A in Reals^{m})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (A_1 +  ...  + A_m , Reals)
#    core type: ExprTuple
#    sub-expressions: 5, 14
# 4. A in Reals^{m}
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. A_1 +  ...  + A_m
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A , Reals^{m})
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. Reals^{m}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. A_1,...,A_m
#     core type: Iter
#     lambda_map: 13
#     start_index: 25
#     end_index: 26
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (Reals , m)
#     core type: ExprTuple
#     sub-expressions: 14, 26
# 13. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 21
#     body: 15
#     conditions: 16\n14. Reals
#     core type: Literal
#     sub-expressions:
# 15. A__x_
#     core type: Indexed
#     var: 17
#     index: 21
#     base: "1"
# 16. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. _x_ in {1...m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. _x_
#     core type: Variable
#     sub-expressions:
# 22. {1...m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. m
#     core type: Variable
#     sub-expressions:
