# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, five

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, b, c, a, b, a, c, b, a, c, a), Add(Mult(five, a), Add(b, b, b), Add(c, c, c)))
# Out:
# expr: (a + b + c + a + b + a + c + b + a + c + a) = ((5 * a) + (b + b + b) + (c + c + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + b + c + a + b + a + c + b + a + c + a) = ((5 * a) + (b + b + b) + (c + c + c))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + b + c + a + b + a + c + b + a + c + a , (5 * a) + (b + b + b) + (c + c + c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + b + c + a + b + a + c + b + a + c + a
#    core type: Operation
#    operator: 13
#    operands: 5
# 4. (5 * a) + (b + b + b) + (c + c + c)
#    core type: Operation
#    operator: 13
#    operands: 6
# 5. (a , b , c , a , b , a , c , b , a , c , a)
#    core type: ExprTuple
#    sub-expressions: 16, 17, 18, 16, 17, 16, 18, 17, 16, 18, 16
# 6. (5 * a , b + b + b , c + c + c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. 5 * a
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. b + b + b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. c + c + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (5 , a)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (b , b , b)
#     core type: ExprTuple
#     sub-expressions: 17, 17, 17
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (c , c , c)
#     core type: ExprTuple
#     sub-expressions: 18, 18, 18
# 15. 5
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
