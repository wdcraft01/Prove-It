# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g
from proveit.logic import Forall, InSet
from proveit.number import Exp, seven

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [a, b, c, d, e, f, g]
expr = Forall([S], Forall(subExpr2, InSet(subExpr2, Exp(S, seven)), domain = S, conditions = subExpr1), conditions = subExpr1)
# Out:
# expr: forall_{S} [forall_{a, b, c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S} [forall_{a, b, c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})]
#    core type: Operation
#    operator: 31
#    operand: 1
# 1. S -> [forall_{a, b, c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})]
#    core type: Lambda
#    parameter: 52
#    body: 2
# 2. forall_{a, b, c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 31
#    operand: 3
# 3. a -> [forall_{b, c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})] | a in S
#    core type: Lambda
#    parameter: 43
#    body: 4
#    conditions: 5\n4. forall_{b, c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 31
#    operand: 6
# 5. (a in S)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. b -> [forall_{c, d, e, f, g in S} ((a , b , c , d , e , f , g) in S^{7})] | b in S
#    core type: Lambda
#    parameter: 44
#    body: 8
#    conditions: 9\n7. a in S
#    core type: Operation
# ...
