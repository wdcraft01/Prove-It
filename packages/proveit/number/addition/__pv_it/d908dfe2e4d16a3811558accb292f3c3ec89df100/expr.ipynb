# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b
from proveit.number import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Neg(b)
subExpr2 = Mult(three, b)
expr = ExprTuple(Add(Mult(two, b), subExpr2, b, subExpr1), Add(Mult(b, two), subExpr2, b, subExpr1))
# Out:
# expr: ((2 * b) + (3 * b) + b - b , (b * 2) + (3 * b) + b - b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * b) + (3 * b) + b - b , (b * 2) + (3 * b) + b - b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (b * 2) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 * b , 3 * b , b , -b)
#    core type: ExprTuple
#    sub-expressions: 6, 8, 17, 9
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (b * 2 , 3 * b , b , -b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 17, 9
# 6. 2 * b
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. b * 2
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. -b
#    core type: Operation
#    operator: 14
#    operand: 17
# 10. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 11. (b , 2)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
