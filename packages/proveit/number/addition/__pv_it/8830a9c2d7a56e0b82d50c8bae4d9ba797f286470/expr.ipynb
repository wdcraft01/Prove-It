# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit.number import Add, zero
from proveit.number._common_ import iter_a1l, iter_b1m

# %%
# build up the expression from sub-expressions
expr = Add(iter_a1l, zero, iter_b1m)
# Out:
# expr: a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (a_1 ,  ...  , a_l , 0 , b_1 ,  ...  , b_m)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. a_1,...,a_l
#    core type: Iter
#    lambda_map: 6
#    start_index: 26
#    end_index: 25
# 4. 0
#    core type: Literal
#    sub-expressions:
# 5. b_1,...,b_m
#    core type: Iter
#    lambda_map: 7
#    start_index: 26
#    end_index: 27
# 6. _x_ -> a__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 20
#    body: 8
#    conditions: 9\n7. _x_ -> b__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 20
#    body: 10
#    conditions: 11\n8. a__x_
#    core type: Indexed
#    var: 12
#    index: 20
#    base: "1"
# 9. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. b__x_
#     core type: Indexed
#     var: 14
#     index: 20
#     base: "1"
# 11. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 15
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. _x_ in {1...l}
#     core type: Operation
#     operator: 17
#     operands: 16
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. _x_ in {1...m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. {1...l}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. _x_
#     core type: Variable
#     sub-expressions:
# 21. {1...m}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. l
#     core type: Variable
#     sub-expressions:
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. m
#     core type: Variable
#     sub-expressions:
