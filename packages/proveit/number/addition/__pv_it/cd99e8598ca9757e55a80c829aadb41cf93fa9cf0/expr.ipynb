# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda, Variable
from proveit._common_ import aa, b, cc, dd, l, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Exp, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = []
subExpr3 = Iter(subExpr1, Indexed(aa, subExpr1, base = 1), one, l)
subExpr4 = Iter(subExpr1, Indexed(cc, subExpr1, base = 1), one, m)
subExpr5 = Iter(subExpr1, Indexed(dd, subExpr1, base = 1), one, n)
expr = Lambda(l, Forall([m, n], Forall([aa, b, cc, dd], Equals(Add(subExpr3, b, subExpr4, subExpr5), Add(subExpr3, subExpr4, b, subExpr5)), domains = [Exp(Complexes, l), Complexes, Exp(Complexes, m), Exp(Complexes, n)], conditions = subExpr2), domain = Naturals, conditions = subExpr2), conditions = [InSet(l, Naturals)])
# Out:
# expr: l -> [forall_{m, n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + b + c_1 +  ...  + c_m + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + b + d_1 +  ...  + d_n))]] | l in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. l -> [forall_{m, n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + b + c_1 +  ...  + c_m + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + b + d_1 +  ...  + d_n))]] | l in Naturals
#    core type: Lambda
#    parameter: 83
#    body: 1
#    conditions: 2\n1. forall_{m, n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + b + c_1 +  ...  + c_m + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + b + d_1 +  ...  + d_n))]
#    core type: Operation
#    operator: 31
#    operand: 3
# 2. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. m -> [forall_{n in Naturals} [forall_{(a, b, c, d) in Complexes^{l} * Complexes * Complexes^{m} * Complexes^{n}} ((a_1 +  ...  + a_l + b + c_1 +  ...  + c_m + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + b + d_1 +  ...  + d_n))]] | m in Naturals
# ...
