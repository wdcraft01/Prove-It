# %% [markdown]
# Show the Proof
# ========

# %%
import proveit
# %show_proof
# Out:
# <table><tr><th>&nbsp;</th><th>step type</th><th>requirements</th><th>statement</th></tr>
# <tr><td>0</td><td>specialization</td><td>1, 2, 3, 4, 5, 6, 7, 8</td><td><span style="font-size:20px;"><a class="ProveItLink" href="../6dd3a43797febab56714189e5c1010f6ce71232f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="proof.ipynb" style="text-decoration: none">&#x22A2;&nbsp;</a><a class="ProveItLink" href="../08babce9a96fc039620d806314d218088da681ff0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span></td></tr>
# ...
