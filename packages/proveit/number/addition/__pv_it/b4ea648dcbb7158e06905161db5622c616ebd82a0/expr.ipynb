# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import B, CC, n
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Add, Exp, Naturals, NaturalsPos, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([CC], InSet(Add(iterA1m, B, Iter(subExpr1, Indexed(CC, subExpr1, base = 1), one, n)), NaturalsPos), domain = Exp(Naturals, n), conditions = [])
# Out:
# expr: forall_{C in Naturals^{n}} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{C in Naturals^{n}} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. C -> ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos) | C in Naturals^{n}
#    core type: Lambda
#    parameter: 27
#    body: 3
#    conditions: 4\n3. (A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos
#    core type: Operation
#    operator: 30
#    operands: 5
# 4. (C in Naturals^{n})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A_1 +  ...  + A_m + B + C_1 +  ...  + C_n , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. C in Naturals^{n}
#    core type: Operation
#    operator: 30
#    operands: 9
# 7. A_1 +  ...  + A_m + B + C_1 +  ...  + C_n
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 9. (C , Naturals^{n})
#    core type: ExprTuple
# ...
