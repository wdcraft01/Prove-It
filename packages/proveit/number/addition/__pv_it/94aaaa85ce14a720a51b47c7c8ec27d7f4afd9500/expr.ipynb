# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b
from proveit.logic import InSet
from proveit.number import Add, Complexes, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = InSet(Add(b, Mult(three, b), Mult(two, b)), Complexes)
# Out:
# expr: (b + (3 * b) + (2 * b)) in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (b + (3 * b) + (2 * b)) in Complexes
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (b + (3 * b) + (2 * b) , Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. Complexes
#    core type: Literal
#    sub-expressions:
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (b , 3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 14, 7, 8
# 7. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (3 , b)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
