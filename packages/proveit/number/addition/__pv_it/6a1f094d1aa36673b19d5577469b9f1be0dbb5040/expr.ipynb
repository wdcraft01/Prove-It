# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(b, Mult(three, b), Mult(two, b))
expr = Equals(Add(subExpr1, c, c, two), Add(subExpr1, Add(c, c), two))
# Out:
# expr: ((b + (3 * b) + (2 * b)) + c + c + 2) = ((b + (3 * b) + (2 * b)) + (c + c) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((b + (3 * b) + (2 * b)) + c + c + 2) = ((b + (3 * b) + (2 * b)) + (c + c) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((b + (3 * b) + (2 * b)) + c + c + 2 , (b + (3 * b) + (2 * b)) + (c + c) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (b + (3 * b) + (2 * b)) + c + c + 2
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (b + (3 * b) + (2 * b)) + (c + c) + 2
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (b + (3 * b) + (2 * b) , c , c , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 14, 14, 19
# 6. (b + (3 * b) + (2 * b) , c + c , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 19
# 7. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. c + c
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (b , 3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 20, 12, 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (c , c)
#     core type: ExprTuple
#     sub-expressions: 14, 14
# 12. 3 * b
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. 2 * b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
