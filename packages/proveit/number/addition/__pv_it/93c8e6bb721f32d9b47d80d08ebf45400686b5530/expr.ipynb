# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(two, three, four, a, a, c, zero, c, b, b), Add(a, a, two, three, four, c, c, b, b))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b) = (a + a + 2 + 3 + 4 + c + c + b + b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b) = (a + a + 2 + 3 + 4 + c + c + b + b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + 3 + 4 + a + a + c + 0 + c + b + b , a + a + 2 + 3 + 4 + c + c + b + b)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + a + 2 + 3 + 4 + c + c + b + b
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2 , 3 , 4 , a , a , c , 0 , c , b , b)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 9, 9, 13, 8, 13, 14, 14
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a , a , 2 , 3 , 4 , c , c , b , b)
#    core type: ExprTuple
#    sub-expressions: 9, 9, 10, 11, 12, 13, 13, 14, 14
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. 3
#     core type: Literal
#     sub-expressions:
# 12. 4
#     core type: Literal
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
