# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import aa, bb, c, dd, l, m, n
from proveit.logic import Equals
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(aa, subExpr1, base = 1), one, l)
subExpr3 = Iter(subExpr1, Indexed(bb, subExpr1, base = 1), one, m)
subExpr4 = Iter(subExpr1, Indexed(dd, subExpr1, base = 1), one, n)
expr = Equals(Add(subExpr2, subExpr3, c, subExpr4), Add(subExpr2, c, subExpr3, subExpr4))
# Out:
# expr: (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n , a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_1 ,  ...  , a_l , b_1 ,  ...  , b_m , c , d_1 ,  ...  , d_n)
#    core type: ExprTuple
#    sub-expressions: 8, 10, 9, 11
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a_1 ,  ...  , a_l , c , b_1 ,  ...  , b_m , d_1 ,  ...  , d_n)
#    core type: ExprTuple
# ...
