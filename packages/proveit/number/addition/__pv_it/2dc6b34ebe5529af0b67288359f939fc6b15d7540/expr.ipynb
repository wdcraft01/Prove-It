# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import cc, n
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes, Exp
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
expr = Lambda(cc, Equals(Add(iter_a1l, iter_b1m, iter_c1n), Add(iter_a1l, Add(iter_b1m), iter_c1n)), conditions = [InSet(cc, Exp(Complexes, n))])
# Out:
# expr: c -> ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n)) | c in Complexes^{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n)) | c in Complexes^{n}
#    core type: Lambda
#    parameter: 30
#    body: 1
#    conditions: 2\n1. (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n) = (a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (c in Complexes^{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n , a_1 +  ...  + a_l + (b_1 +  ...  + b_m) + c_1 +  ...  + c_n)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. c in Complexes^{n}
#    core type: Operation
#    operator: 41
#    operands: 8
# 6. a_1 +  ...  + a_l + b_1 +  ...  + b_m + c_1 +  ...  + c_n
#    core type: Operation
#    operator: 18
#    operands: 9
# ...
