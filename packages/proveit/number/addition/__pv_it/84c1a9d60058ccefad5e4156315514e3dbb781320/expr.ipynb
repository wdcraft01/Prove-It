# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d
from proveit.logic import Equals
from proveit.number import Add, Mult, two, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, b)
expr = Equals(Add(subExpr1, b, a, c, Mult(zero, d)), Add(subExpr1, b, a, c))
# Out:
# expr: ((2 * b) + b + a + c + (0 * d)) = ((2 * b) + b + a + c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * b) + b + a + c + (0 * d)) = ((2 * b) + b + a + c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * b) + b + a + c + (0 * d) , (2 * b) + b + a + c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * b) + b + a + c + (0 * d)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * b) + b + a + c
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2 * b , b , a , c , 0 * d)
#    core type: ExprTuple
#    sub-expressions: 9, 18, 10, 11, 8
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2 * b , b , a , c)
#    core type: ExprTuple
#    sub-expressions: 9, 18, 10, 11
# 8. 0 * d
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 2 * b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. (0 , d)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. d
#     core type: Variable
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
