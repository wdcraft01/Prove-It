# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(two, b, c, subExpr1, subExpr2, Neg(b), c), Add(Mult(two, c), Add(subExpr1, subExpr2), two))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) - b + c , (2 * c) + ((3 * b) + (2 * b)) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) - b + c , (2 * c) + ((3 * b) + (2 * b)) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + b + c + (3 * b) + (2 * b) - b + c
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (2 * c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (2 , b , c , 3 * b , 2 * b , -b , c)
#    core type: ExprTuple
#    sub-expressions: 19, 20, 12, 13, 14, 5, 12
# 4. (2 * c , (3 * b) + (2 * b) , 2)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 19
# 5. -b
#    core type: Operation
#    operator: 8
#    operand: 20
# 6. 2 * c
#    core type: Operation
#    operator: 16
#    operands: 9
# 7. (3 * b) + (2 * b)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. -
#    core type: Literal
#    sub-expressions:
# 9. (2 , c)
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (3 * b , 2 * b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. 3 * b
#     core type: Operation
#     operator: 16
#     operands: 15
# 14. 2 * b
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
