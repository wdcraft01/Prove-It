# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import InSet
from proveit.number import Add, Complexes, Exp, three

# %%
# build up the expression from sub-expressions
expr = InSet([Add(a, a), Add(c, c), Add(b, b)], Exp(Complexes, three))
# Out:
# expr: (a + a , c + c , b + b) in Complexes^{3}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + a , c + c , b + b) in Complexes^{3}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((a + a , c + c , b + b) , Complexes^{3})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a + a , c + c , b + b)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 4. Complexes^{3}
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. a + a
#    core type: Operation
#    operator: 12
#    operands: 10
# 6. c + c
#    core type: Operation
#    operator: 12
#    operands: 11
# 7. b + b
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (Complexes , 3)
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. (a , a)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 11. (c , c)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (b , b)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
