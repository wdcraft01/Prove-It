# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import aa, bb, l, m
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Exp, Naturals, one, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = []
subExpr3 = Iter(subExpr1, Indexed(aa, subExpr1, base = 1), one, l)
subExpr4 = Iter(subExpr1, Indexed(bb, subExpr1, base = 1), one, m)
expr = Forall([m], Forall([aa, bb], Equals(Add(subExpr3, zero, subExpr4), Add(subExpr3, subExpr4)), domains = [Exp(Complexes, l), Exp(Complexes, m)], conditions = subExpr2), domain = Naturals, conditions = subExpr2)
# Out:
# expr: forall_{m in Naturals} [forall_{(a, b) in Complexes^{l} * Complexes^{m}} ((a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{(a, b) in Complexes^{l} * Complexes^{m}} ((a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m))]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. m -> [forall_{(a, b) in Complexes^{l} * Complexes^{m}} ((a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m))] | m in Naturals
#    core type: Lambda
#    parameter: 55
#    body: 2
#    conditions: 3\n2. forall_{(a, b) in Complexes^{l} * Complexes^{m}} ((a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. a -> [forall_{b in Complexes^{m}} ((a_1 +  ...  + a_l + 0 + b_1 +  ...  + b_m) = (a_1 +  ...  + a_l + b_1 +  ...  + b_m))] | a in Complexes^{l}
#    core type: Lambda
#    parameter: 40
#    body: 6
#    conditions: 7\n5. m in Naturals
# ...
