# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, B, CC, m, n
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Add, Exp, Less, Reals, RealsNeg

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(AA, Forall([CC], Forall([B], Less(Add(iterA1m, B, iterC1n), B), domain = Reals, conditions = subExpr1), domain = Exp(RealsNeg, n), conditions = subExpr1), conditions = [InSet(AA, Exp(RealsNeg, m))])
# Out:
# expr: A -> [forall_{C in (RealsNeg)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) < B)]] | A in (RealsNeg)^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{C in (RealsNeg)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) < B)]] | A in (RealsNeg)^{m}
#    core type: Lambda
#    parameter: 37
#    body: 1
#    conditions: 2\n1. forall_{C in (RealsNeg)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) < B)]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (A in (RealsNeg)^{m})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. C -> [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) < B)] | C in (RealsNeg)^{n}
#    core type: Lambda
#    parameter: 39
#    body: 5
#    conditions: 6\n4. A in (RealsNeg)^{m}
#    core type: Operation
#    operator: 42
#    operands: 7
# 5. forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) < B)
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (C in (RealsNeg)^{n})
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (A , (RealsNeg)^{m})
#    core type: ExprTuple
# ...
