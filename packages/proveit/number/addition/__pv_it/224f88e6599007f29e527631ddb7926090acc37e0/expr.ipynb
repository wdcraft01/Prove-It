# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import a, b
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = Add(Mult(two, a), Variable("_x_", latexFormat = r"{_{-}x_{-}}"), Add(b, b), Add(two, three, four))
# Out:
# expr: (2 * a) + _x_ + (b + b) + (2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 * a) + _x_ + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 9
#    operands: 1
# 1. (2 * a , _x_ , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. 2 * a
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. _x_
#    core type: Variable
#    sub-expressions:
# 4. b + b
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. 2 + 3 + 4
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. *
#    core type: Literal
#    sub-expressions:
# 7. (2 , a)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 8. (b , b)
#    core type: ExprTuple
#    sub-expressions: 12, 12
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 4
#     core type: Literal
#     sub-expressions:
