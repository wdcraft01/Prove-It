# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Variable
from proveit._common_ import b, c
from proveit.number import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
expr = Add(Variable("_x_", latexFormat = r"{_{-}x_{-}}"), b, c, Mult(three, b), Mult(two, b), Neg(b), Mult(one, c))
# Out:
# expr: _x_ + b + c + (3 * b) + (2 * b) - b + (1 * c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. _x_ + b + c + (3 * b) + (2 * b) - b + (1 * c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (_x_ , b , c , 3 * b , 2 * b , -b , 1 * c)
#    core type: ExprTuple
#    sub-expressions: 3, 15, 17, 4, 5, 6, 7
# 3. _x_
#    core type: Variable
#    sub-expressions:
# 4. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 8
# 5. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 9
# 6. -b
#    core type: Operation
#    operator: 10
#    operand: 15
# 7. 1 * c
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (3 , b)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 9. (2 , b)
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (1 , c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
