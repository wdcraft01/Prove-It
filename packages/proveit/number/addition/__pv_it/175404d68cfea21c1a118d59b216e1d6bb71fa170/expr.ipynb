# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(c, c)
subExpr2 = Add(b, b)
subExpr3 = Add(two, three, four)
expr = ExprTuple(Add(Add(a, a), subExpr1, subExpr2, subExpr3), Add(Mult(two, a), subExpr1, subExpr2, subExpr3))
# Out:
# expr: ((a + a) + (c + c) + (b + b) + (2 + 3 + 4) , (2 * a) + (c + c) + (b + b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a + a) + (c + c) + (b + b) + (2 + 3 + 4) , (2 * a) + (c + c) + (b + b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a + a) + (c + c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (2 * a) + (c + c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 15
#    operands: 4
# 3. (a + a , c + c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 5, 7, 8, 9
# 4. (2 * a , c + c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. a + a
#    core type: Operation
#    operator: 15
#    operands: 10
# 6. 2 * a
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. c + c
#    core type: Operation
#    operator: 15
#    operands: 13
# 8. b + b
#    core type: Operation
#    operator: 15
#    operands: 14
# 9. 2 + 3 + 4
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. (a , a)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 13. (c , c)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 14. (b , b)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
# 22. 4
#     core type: Literal
#     sub-expressions:
