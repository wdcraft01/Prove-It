# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, Neg, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(Mult(one, two), b, c, subExpr1, subExpr2, Neg(b), Mult(one, c)), Add(Mult(two, c), subExpr1, subExpr2, two))
# Out:
# expr: ((1 * 2) + b + c + (3 * b) + (2 * b) - b + (1 * c) , (2 * c) + (3 * b) + (2 * b) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1 * 2) + b + c + (3 * b) + (2 * b) - b + (1 * c) , (2 * c) + (3 * b) + (2 * b) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 * 2) + b + c + (3 * b) + (2 * b) - b + (1 * c)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (2 * c) + (3 * b) + (2 * b) + 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 * 2 , b , c , 3 * b , 2 * b , -b , 1 * c)
#    core type: ExprTuple
#    sub-expressions: 6, 23, 20, 10, 11, 7, 8
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2 * c , 3 * b , 2 * b , 2)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 22
# 6. 1 * 2
#    core type: Operation
#    operator: 17
#    operands: 12
# 7. -b
#    core type: Operation
#    operator: 13
#    operand: 23
# 8. 1 * c
#    core type: Operation
#    operator: 17
#    operands: 14
# 9. 2 * c
#    core type: Operation
#    operator: 17
#    operands: 15
# 10. 3 * b
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. 2 * b
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (1 , 2)
#     core type: ExprTuple
#     sub-expressions: 19, 22
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (1 , c)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 16. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
# 22. 2
#     core type: Literal
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
