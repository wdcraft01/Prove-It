# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d
from proveit.logic import InSet, Set
from proveit.number import Reals

# %%
# build up the expression from sub-expressions
expr = Set(InSet(a, Reals), InSet(b, Reals), InSet(c, Reals), InSet(d, Reals))
# Out:
# expr: {a in Reals , b in Reals , c in Reals , d in Reals}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a in Reals , b in Reals , c in Reals , d in Reals}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (a in Reals , b in Reals , c in Reals , d in Reals)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. a in Reals
#    core type: Operation
#    operator: 10
#    operands: 7
# 4. b in Reals
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. c in Reals
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. d in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. (b , Reals)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. (c , Reals)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. d
#     core type: Variable
#     sub-expressions:
# 16. Reals
#     core type: Literal
#     sub-expressions:
