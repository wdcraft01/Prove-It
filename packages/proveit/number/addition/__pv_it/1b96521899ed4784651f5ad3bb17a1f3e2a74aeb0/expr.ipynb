# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, a, b, c
from proveit.number import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(one, one, three)
expr = ExprTuple(Add(a, Add(A, A), b, B, C, c, subExpr1), Add(a, Mult(two, A), b, B, C, c, subExpr1))
# Out:
# expr: (a + (A + A) + b + B + C + c + (1 + 1 + 3) , a + (2 * A) + b + B + C + c + (1 + 1 + 3))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + (A + A) + b + B + C + c + (1 + 1 + 3) , a + (2 * A) + b + B + C + c + (1 + 1 + 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + (A + A) + b + B + C + c + (1 + 1 + 3)
#    core type: Operation
#    operator: 16
#    operands: 3
# 2. a + (2 * A) + b + B + C + c + (1 + 1 + 3)
#    core type: Operation
#    operator: 16
#    operands: 4
# 3. (a , A + A , b , B , C , c , 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 5, 8, 9, 10, 11, 12
# 4. (a , 2 * A , b , B , C , c , 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11, 12
# 5. A + A
#    core type: Operation
#    operator: 16
#    operands: 13
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. 2 * A
#    core type: Operation
#    operator: 14
#    operands: 15
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 1 + 1 + 3
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (A , A)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2 , A)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (1 , 1 , 3)
#     core type: ExprTuple
#     sub-expressions: 20, 20, 21
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. 3
#     core type: Literal
#     sub-expressions:
