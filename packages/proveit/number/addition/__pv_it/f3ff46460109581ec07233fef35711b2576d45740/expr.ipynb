# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(Mult(three, b), Mult(two, b))
expr = Equals(Add(Add(c, c), subExpr1, two), Add(Mult(two, c), subExpr1, two))
# Out:
# expr: ((c + c) + ((3 * b) + (2 * b)) + 2) = ((2 * c) + ((3 * b) + (2 * b)) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((c + c) + ((3 * b) + (2 * b)) + 2) = ((2 * c) + ((3 * b) + (2 * b)) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((c + c) + ((3 * b) + (2 * b)) + 2 , (2 * c) + ((3 * b) + (2 * b)) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (c + c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (2 * c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (c + c , (3 * b) + (2 * b) , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 9, 21
# 6. (2 * c , (3 * b) + (2 * b) , 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 21
# 7. c + c
#    core type: Operation
#    operator: 12
#    operands: 10
# 8. 2 * c
#    core type: Operation
#    operator: 18
#    operands: 11
# 9. (3 * b) + (2 * b)
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (c , c)
#     core type: ExprTuple
#     sub-expressions: 14, 14
# 11. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 21, 14
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (3 * b , 2 * b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. 3 * b
#     core type: Operation
#     operator: 18
#     operands: 17
# 16. 2 * b
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
