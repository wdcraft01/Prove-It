# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes

# %%
# build up the expression from sub-expressions
expr = Forall([b], Equals(Add(a, b), Add(b, a)), domain = Complexes, conditions = [])
# Out:
# expr: forall_{b in Complexes} ((a + b) = (b + a))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b in Complexes} ((a + b) = (b + a))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. b -> ((a + b) = (b + a)) | b in Complexes
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. (a + b) = (b + a)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a + b , b + a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. b in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. a + b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. b + a
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 12. (a , b)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (b , a)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. Complexes
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
