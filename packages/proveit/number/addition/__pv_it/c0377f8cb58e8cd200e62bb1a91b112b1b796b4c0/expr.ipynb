# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(Mult(two, a), Mult(three, c), Add(b, b), Add(one, two, three)))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((2 * a) + (3 * c) + (b + b) + (1 + 2 + 3))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((2 * a) + (3 * c) + (b + b) + (1 + 2 + 3))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3 , (2 * a) + (3 * c) + (b + b) + (1 + 2 + 3))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 16
#    operands: 5
# 4. (2 * a) + (3 * c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (a , 1 , 2 , c , b , a , 0 , b , c , c , 3)
#    core type: ExprTuple
#    sub-expressions: 18, 21, 22, 19, 20, 18, 7, 20, 19, 19, 23
# 6. (2 * a , 3 * c , b + b , 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. 2 * a
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 3 * c
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. b + b
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. 1 + 2 + 3
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 22, 18
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (3 , c)
#     core type: ExprTuple
#     sub-expressions: 23, 19
# 15. (b , b)
#     core type: ExprTuple
#     sub-expressions: 20, 20
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (1 , 2 , 3)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. 2
#     core type: Literal
#     sub-expressions:
# 23. 3
#     core type: Literal
#     sub-expressions:
