# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, a)
subExpr2 = Add(b, b)
subExpr3 = Add(two, three, four)
expr = Equals(Add(subExpr1, Add(c, c), subExpr2, subExpr3), Add(subExpr1, Mult(two, c), subExpr2, subExpr3))
# Out:
# expr: ((2 * a) + (c + c) + (b + b) + (2 + 3 + 4)) = ((2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * a) + (c + c) + (b + b) + (2 + 3 + 4)) = ((2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * a) + (c + c) + (b + b) + (2 + 3 + 4) , (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * a) + (c + c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 17
#    operands: 5
# 4. (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. (2 * a , c + c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 8, 7, 10, 11
# 6. (2 * a , 2 * c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. c + c
#    core type: Operation
#    operator: 17
#    operands: 12
# 8. 2 * a
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. 2 * c
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. b + b
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. 2 + 3 + 4
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. (c , c)
#     core type: ExprTuple
#     sub-expressions: 20, 20
# 13. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 22, 19
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 16. (b , b)
#     core type: ExprTuple
#     sub-expressions: 21, 21
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. 2
#     core type: Literal
#     sub-expressions:
# 23. 3
#     core type: Literal
#     sub-expressions:
# 24. 4
#     core type: Literal
#     sub-expressions:
