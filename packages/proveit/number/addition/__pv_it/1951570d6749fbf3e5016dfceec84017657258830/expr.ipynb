# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, five

# %%
# build up the expression from sub-expressions
subExpr1 = Add(b, b, b)
subExpr2 = Add(c, c, c)
expr = Equals(Add(Add(a, a, a, a, a), subExpr1, subExpr2), Add(Mult(five, a), subExpr1, subExpr2))
# Out:
# expr: ((a + a + a + a + a) + (b + b + b) + (c + c + c)) = ((5 * a) + (b + b + b) + (c + c + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a + a + a + a + a) + (b + b + b) + (c + c + c)) = ((5 * a) + (b + b + b) + (c + c + c))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a + a + a + a + a) + (b + b + b) + (c + c + c) , (5 * a) + (b + b + b) + (c + c + c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a + a + a + a + a) + (b + b + b) + (c + c + c)
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. (5 * a) + (b + b + b) + (c + c + c)
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a + a + a + a + a , b + b + b , c + c + c)
#    core type: ExprTuple
#    sub-expressions: 7, 9, 10
# 6. (5 * a , b + b + b , c + c + c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. a + a + a + a + a
#    core type: Operation
#    operator: 15
#    operands: 11
# 8. 5 * a
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. b + b + b
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. c + c + c
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (a , a , a , a , a)
#     core type: ExprTuple
#     sub-expressions: 18, 18, 18, 18, 18
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (5 , a)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (b , b , b)
#     core type: ExprTuple
#     sub-expressions: 19, 19, 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (c , c , c)
#     core type: ExprTuple
#     sub-expressions: 20, 20, 20
# 17. 5
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
