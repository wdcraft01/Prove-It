# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, a, a, a, a, b, b, b, c, c, c), Add(Add(a, a, a, a, a), b, b, b, c, c, c))
# Out:
# expr: (a + a + a + a + a + b + b + b + c + c + c) = ((a + a + a + a + a) + b + b + b + c + c + c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + a + a + a + a + b + b + b + c + c + c) = ((a + a + a + a + a) + b + b + b + c + c + c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + a + a + a + a + b + b + b + c + c + c , (a + a + a + a + a) + b + b + b + c + c + c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + a + a + a + a + b + b + b + c + c + c
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. (a + a + a + a + a) + b + b + b + c + c + c
#    core type: Operation
#    operator: 10
#    operands: 6
# 5. (a , a , a , a , a , b , b , b , c , c , c)
#    core type: ExprTuple
#    sub-expressions: 12, 12, 12, 12, 12, 8, 8, 8, 9, 9, 9
# 6. (a + a + a + a + a , b , b , b , c , c , c)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 8, 8, 9, 9, 9
# 7. a + a + a + a + a
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (a , a , a , a , a)
#     core type: ExprTuple
#     sub-expressions: 12, 12, 12, 12, 12
# 12. a
#     core type: Variable
#     sub-expressions:
