# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
subExpr3 = Mult(one, c)
expr = Equals(Add(Mult(one, two), b, c, subExpr1, subExpr2, subExpr3), Add(two, b, c, subExpr1, subExpr2, subExpr3))
# Out:
# expr: ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)) = (2 + b + c + (3 * b) + (2 * b) + (1 * c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)) = (2 + b + c + (3 * b) + (2 * b) + (1 * c))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c) , 2 + b + c + (3 * b) + (2 * b) + (1 * c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. 2 + b + c + (3 * b) + (2 * b) + (1 * c)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (1 * 2 , b , c , 3 * b , 2 * b , 1 * c)
#    core type: ExprTuple
#    sub-expressions: 8, 19, 21, 9, 10, 11
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2 , b , c , 3 * b , 2 * b , 1 * c)
#    core type: ExprTuple
#    sub-expressions: 18, 19, 21, 9, 10, 11
# 8. 1 * 2
#    core type: Operation
#    operator: 15
#    operands: 12
# 9. 3 * b
#    core type: Operation
#    operator: 15
#    operands: 13
# 10. 2 * b
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. 1 * c
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (1 , 2)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 13. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 14. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (1 , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
