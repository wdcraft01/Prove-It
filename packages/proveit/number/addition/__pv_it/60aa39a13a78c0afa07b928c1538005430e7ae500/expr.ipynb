# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Exp, three

# %%
# build up the expression from sub-expressions
expr = Forall([b, c], InSet([a, b, c], Exp(S, three)), domain = S, conditions = [])
# Out:
# expr: forall_{b, c in S} ((a , b , c) in S^{3})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c in S} ((a , b , c) in S^{3})
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. b -> [forall_{c in S} ((a , b , c) in S^{3})] | b in S
#    core type: Lambda
#    parameter: 17
#    body: 2
#    conditions: 3\n2. forall_{c in S} ((a , b , c) in S^{3})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (b in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. c -> ((a , b , c) in S^{3}) | c in S
#    core type: Lambda
#    parameter: 20
#    body: 7
#    conditions: 8\n6. b in S
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (a , b , c) in S^{3}
#    core type: Operation
#    operator: 14
#    operands: 10
# 8. (c in S)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (b , S)
#    core type: ExprTuple
#    sub-expressions: 17, 21
# 10. ((a , b , c) , S^{3})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. c in S
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (a , b , c)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 20
# 13. S^{3}
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (c , S)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. Exp
#     core type: Literal
#     sub-expressions:
# 19. (S , 3)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. S
#     core type: Variable
#     sub-expressions:
# 22. 3
#     core type: Literal
#     sub-expressions:
