# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, a, b, c
from proveit.logic import InSet, Set
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = Set(InSet(a, Complexes), InSet(A, Complexes), InSet(b, Complexes), InSet(B, Complexes), InSet(c, Complexes), InSet(C, Complexes))
# Out:
# expr: {a in Complexes , A in Complexes , b in Complexes , B in Complexes , c in Complexes , C in Complexes}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {a in Complexes , A in Complexes , b in Complexes , B in Complexes , c in Complexes , C in Complexes}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (a in Complexes , A in Complexes , b in Complexes , B in Complexes , c in Complexes , C in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6, 7, 8
# 3. a in Complexes
#    core type: Operation
#    operator: 14
#    operands: 9
# 4. A in Complexes
#    core type: Operation
#    operator: 14
#    operands: 10
# 5. b in Complexes
#    core type: Operation
#    operator: 14
#    operands: 11
# 6. B in Complexes
#    core type: Operation
#    operator: 14
#    operands: 12
# 7. c in Complexes
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. C in Complexes
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 16, 22
# 10. (A , Complexes)
#     core type: ExprTuple
#     sub-expressions: 17, 22
# 11. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 22
# 12. (B , Complexes)
#     core type: ExprTuple
#     sub-expressions: 19, 22
# 13. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (C , Complexes)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. B
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. C
#     core type: Variable
#     sub-expressions:
# 22. Complexes
#     core type: Literal
#     sub-expressions:
