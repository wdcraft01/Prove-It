# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(c, two, subExpr1, subExpr2, c), Add(c, c, two, subExpr1, subExpr2))
# Out:
# expr: (c + 2 + (3 * b) + (2 * b) + c , c + c + 2 + (3 * b) + (2 * b))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (c + 2 + (3 * b) + (2 * b) + c , c + c + 2 + (3 * b) + (2 * b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. c + 2 + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. c + c + 2 + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (c , 2 , 3 * b , 2 * b , c)
#    core type: ExprTuple
#    sub-expressions: 6, 13, 7, 8, 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (c , c , 2 , 3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 6, 6, 13, 7, 8
# 6. c
#    core type: Variable
#    sub-expressions:
# 7. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (3 , b)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
