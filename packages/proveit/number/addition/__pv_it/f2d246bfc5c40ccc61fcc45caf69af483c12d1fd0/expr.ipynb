# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, a, b, c
from proveit.logic import Equals
from proveit.number import Add, one, three

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, A, A, b, B, C, c, one, one, three), Add(a, Add(A, A), b, B, C, c, one, one, three))
# Out:
# expr: (a + A + A + b + B + C + c + 1 + 1 + 3) = (a + (A + A) + b + B + C + c + 1 + 1 + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + A + A + b + B + C + c + 1 + 1 + 3) = (a + (A + A) + b + B + C + c + 1 + 1 + 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + A + A + b + B + C + c + 1 + 1 + 3 , a + (A + A) + b + B + C + c + 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + A + A + b + B + C + c + 1 + 1 + 3
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. a + (A + A) + b + B + C + c + 1 + 1 + 3
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a , A , A , b , B , C , c , 1 , 1 , 3)
#    core type: ExprTuple
#    sub-expressions: 7, 17, 17, 9, 10, 11, 12, 13, 13, 14
# 6. (a , A + A , b , B , C , c , 1 , 1 , 3)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10, 11, 12, 13, 13, 14
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. A + A
#    core type: Operation
#    operator: 15
#    operands: 16
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. B
#     core type: Variable
#     sub-expressions:
# 11. C
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (A , A)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 17. A
#     core type: Variable
#     sub-expressions:
