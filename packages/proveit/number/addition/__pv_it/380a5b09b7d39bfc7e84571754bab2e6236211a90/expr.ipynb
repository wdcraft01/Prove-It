# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(Add(a, a), Add(c, c, c), Add(b, b), Add(one, two, three)))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((a + a) + (c + c + c) + (b + b) + (1 + 2 + 3))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = ((a + a) + (c + c + c) + (b + b) + (1 + 2 + 3))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3 , (a + a) + (c + c + c) + (b + b) + (1 + 2 + 3))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. (a + a) + (c + c + c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. (a , 1 , 2 , c , b , a , 0 , b , c , c , 3)
#    core type: ExprTuple
#    sub-expressions: 17, 20, 21, 18, 19, 17, 7, 19, 18, 18, 22
# 6. (a + a , c + c + c , b + b , 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. a + a
#    core type: Operation
#    operator: 15
#    operands: 12
# 9. c + c + c
#    core type: Operation
#    operator: 15
#    operands: 13
# 10. b + b
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. 1 + 2 + 3
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. (a , a)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 13. (c , c , c)
#     core type: ExprTuple
#     sub-expressions: 18, 18, 18
# 14. (b , b)
#     core type: ExprTuple
#     sub-expressions: 19, 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (1 , 2 , 3)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. 3
#     core type: Literal
#     sub-expressions:
