# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, c], Equals(Add(c, Neg(b)), a), domain = Complexes, conditions = [Equals(Add(a, b), c)])
# Out:
# expr: forall_{a, b, c in Complexes | (a + b) = c} ((c - b) = a)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, b, c in Complexes | (a + b) = c} ((c - b) = a)
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b, c in Complexes | (a + b) = c} ((c - b) = a)] | a in Complexes
#    core type: Lambda
#    parameter: 31
#    body: 2
#    conditions: 3\n2. forall_{b, c in Complexes | (a + b) = c} ((c - b) = a)
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{c in Complexes | (a + b) = c} ((c - b) = a)] | b in Complexes
#    core type: Lambda
#    parameter: 32
#    body: 6
#    conditions: 7\n5. a in Complexes
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall_{c in Complexes | (a + b) = c} ((c - b) = a)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 31, 24
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. c -> ((c - b) = a) | c in Complexes , (a + b) = c
#     core type: Lambda
#     parameter: 26
#     body: 12
#     conditions: 13\n11. b in Complexes
#     core type: Operation
#     operator: 19
#     operands: 14
# 12. (c - b) = a
#     core type: Operation
#     operator: 21
#     operands: 15
# 13. (c in Complexes , (a + b) = c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 32, 24
# 15. (c - b , a)
#     core type: ExprTuple
#     sub-expressions: 18, 31
# 16. c in Complexes
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (a + b) = c
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. c - b
#     core type: Operation
#     operator: 28
#     operands: 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. (c , -b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. Complexes
#     core type: Literal
#     sub-expressions:
# 25. a + b
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. c
#     core type: Variable
#     sub-expressions:
# 27. -b
#     core type: Operation
#     operator: 30
#     operand: 32
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (a , b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. -
#     core type: Literal
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
