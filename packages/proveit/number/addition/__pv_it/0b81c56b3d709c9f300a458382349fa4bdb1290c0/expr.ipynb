# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#commutation">commutation</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.addition._theorems_ import commutation

# %%
# check that the built expression is the same as the stored expression
# %check_expr commutation
# Out:
# Passed sanity check: built 'commutation' is the same as the stored Expression.

# %%
# display the expression information
commutation.exprInfo()
# Out:
# 0. forall_{a, b in Complexes} ((a + b) = (b + a))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Complexes} ((a + b) = (b + a))] | a in Complexes
#    core type: Lambda
#    parameter: 22
#    body: 2
#    conditions: 3\n2. forall_{b in Complexes} ((a + b) = (b + a))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((a + b) = (b + a)) | b in Complexes
#    core type: Lambda
#    parameter: 21
#    body: 7
#    conditions: 8\n6. a in Complexes
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. (a + b) = (b + a)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 22, 20
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (a + b , b + a)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. b in Complexes
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. a + b
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. b + a
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 17. (a , b)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (b , a)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. Complexes
#     core type: Literal
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
