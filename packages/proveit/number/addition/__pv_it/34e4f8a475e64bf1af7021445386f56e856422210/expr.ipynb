# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(b, Mult(three, b), Mult(two, b))
expr = ExprTuple(Add(subExpr1, Add(c, c), two), Add(subExpr1, Mult(two, c), two))
# Out:
# expr: ((b + (3 * b) + (2 * b)) + (c + c) + 2 , (b + (3 * b) + (2 * b)) + (2 * c) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((b + (3 * b) + (2 * b)) + (c + c) + 2 , (b + (3 * b) + (2 * b)) + (2 * c) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (b + (3 * b) + (2 * b)) + (c + c) + 2
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (b + (3 * b) + (2 * b)) + (2 * c) + 2
#    core type: Operation
#    operator: 9
#    operands: 4
# 3. (b + (3 * b) + (2 * b) , c + c , 2)
#    core type: ExprTuple
#    sub-expressions: 6, 5, 19
# 4. (b + (3 * b) + (2 * b) , 2 * c , 2)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 19
# 5. c + c
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. 2 * c
#    core type: Operation
#    operator: 16
#    operands: 11
# 8. (c , c)
#    core type: ExprTuple
#    sub-expressions: 14, 14
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (b , 3 * b , 2 * b)
#     core type: ExprTuple
#     sub-expressions: 20, 12, 13
# 11. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 19, 14
# 12. 3 * b
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. 2 * b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
