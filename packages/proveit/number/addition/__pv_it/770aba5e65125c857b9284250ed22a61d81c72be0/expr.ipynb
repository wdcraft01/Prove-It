# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Variable
from proveit._common_ import aa, bb, l, m
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = ExprTuple(Iter(subExpr1, Indexed(aa, subExpr1, base = 1), one, l), Iter(subExpr1, Indexed(bb, subExpr1, base = 1), one, m))
# Out:
# expr: (a_1 ,  ...  , a_l , b_1 ,  ...  , b_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_1 ,  ...  , a_l , b_1 ,  ...  , b_m)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_1,...,a_l
#    core type: Iter
#    lambda_map: 3
#    start_index: 23
#    end_index: 22
# 2. b_1,...,b_m
#    core type: Iter
#    lambda_map: 4
#    start_index: 23
#    end_index: 24
# 3. _x_ -> a__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 17
#    body: 5
#    conditions: 6\n4. _x_ -> b__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 17
#    body: 7
#    conditions: 8\n5. a__x_
#    core type: Indexed
#    var: 9
#    index: 17
#    base: "1"
# 6. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 10
# 7. b__x_
#    core type: Indexed
#    var: 11
#    index: 17
#    base: "1"
# 8. (_x_ in {1...m})
#    core type: ExprTuple
#    sub-expressions: 12
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. _x_ in {1...l}
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. _x_ in {1...m}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {1...l}
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. _x_
#     core type: Variable
#     sub-expressions:
# 18. {1...m}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. l
#     core type: Variable
#     sub-expressions:
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. m
#     core type: Variable
#     sub-expressions:
