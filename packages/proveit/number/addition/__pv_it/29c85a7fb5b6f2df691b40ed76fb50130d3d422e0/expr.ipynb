# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b
from proveit.number import Add, Complexes, Exp, Mult, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple([Add(b, Mult(three, b), Mult(two, b))], Exp(Complexes, one))
# Out:
# expr: ((b + (3 * b) + (2 * b)) , Complexes^{1})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((b + (3 * b) + (2 * b)) , Complexes^{1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (b + (3 * b) + (2 * b))
#    core type: ExprTuple
#    sub-expressions: 3
# 2. Complexes^{1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. Exp
#    core type: Literal
#    sub-expressions:
# 5. (Complexes , 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (b , 3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 17, 10, 11
# 8. Complexes
#    core type: Literal
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 3 * b
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. 2 * b
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
