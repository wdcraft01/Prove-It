# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import B, C, b, c
from proveit.logic import InSet, Set
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = Set(InSet(b, Complexes), InSet(B, Complexes), InSet(c, Complexes), InSet(C, Complexes))
# Out:
# expr: {b in Complexes , B in Complexes , c in Complexes , C in Complexes}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {b in Complexes , B in Complexes , c in Complexes , C in Complexes}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (b in Complexes , B in Complexes , c in Complexes , C in Complexes)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. b in Complexes
#    core type: Operation
#    operator: 10
#    operands: 7
# 4. B in Complexes
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. c in Complexes
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. C in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 12, 16
# 8. (B , Complexes)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. (c , Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 16
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (C , Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. C
#     core type: Variable
#     sub-expressions:
# 16. Complexes
#     core type: Literal
#     sub-expressions:
