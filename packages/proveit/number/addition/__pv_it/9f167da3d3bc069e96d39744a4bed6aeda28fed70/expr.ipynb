# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, a, b, c
from proveit.number import Add, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, A, A, b, B, C, one, c, one, three), Add(a, A, A, b, B, C, c, one, one, three))
# Out:
# expr: (a + A + A + b + B + C + 1 + c + 1 + 3 , a + A + A + b + B + C + c + 1 + 1 + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + A + A + b + B + C + 1 + c + 1 + 3 , a + A + A + b + B + C + c + 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + A + A + b + B + C + 1 + c + 1 + 3
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a + A + A + b + B + C + c + 1 + 1 + 3
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a , A , A , b , B , C , 1 , c , 1 , 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 7, 8, 9, 10, 12, 11, 12, 13
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (a , A , A , b , B , C , c , 1 , 1 , 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 7, 8, 9, 10, 11, 12, 12, 13
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. A
#    core type: Variable
#    sub-expressions:
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
