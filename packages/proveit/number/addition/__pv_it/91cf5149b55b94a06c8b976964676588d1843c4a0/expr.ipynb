# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, a, b, c
from proveit.number import Add, Mult, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(one, a, A, zero, b, B, C, c, one, three, A), Add(a, Mult(two, A), b, B, C, c, Add(one, one, three)))
# Out:
# expr: (1 + a + A + 0 + b + B + C + c + 1 + 3 + A , a + (2 * A) + b + B + C + c + (1 + 1 + 3))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 + a + A + 0 + b + B + C + c + 1 + 3 + A , a + (2 * A) + b + B + C + c + (1 + 1 + 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 + a + A + 0 + b + B + C + c + 1 + 3 + A
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. a + (2 * A) + b + B + C + c + (1 + 1 + 3)
#    core type: Operation
#    operator: 15
#    operands: 4
# 3. (1 , a , A , 0 , b , B , C , c , 1 , 3 , A)
#    core type: ExprTuple
#    sub-expressions: 19, 6, 18, 5, 8, 9, 10, 11, 19, 20, 18
# 4. (a , 2 * A , b , B , C , c , 1 + 1 + 3)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11, 12
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. 2 * A
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. B
#    core type: Variable
#    sub-expressions:
# 10. C
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. 1 + 1 + 3
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2 , A)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (1 , 1 , 3)
#     core type: ExprTuple
#     sub-expressions: 19, 19, 20
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
