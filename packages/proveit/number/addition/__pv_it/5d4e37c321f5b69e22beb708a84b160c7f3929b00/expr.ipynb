# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Variable
from proveit._common_ import aa, bb, c, dd, l, m, n
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = ExprTuple(Iter(subExpr1, Indexed(aa, subExpr1, base = 1), one, l), c, Iter(subExpr1, Indexed(bb, subExpr1, base = 1), one, m), Iter(subExpr1, Indexed(dd, subExpr1, base = 1), one, n))
# Out:
# expr: (a_1 ,  ...  , a_l , c , b_1 ,  ...  , b_m , d_1 ,  ...  , d_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_1 ,  ...  , a_l , c , b_1 ,  ...  , b_m , d_1 ,  ...  , d_n)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. a_1,...,a_l
#    core type: Iter
#    lambda_map: 5
#    start_index: 34
#    end_index: 32
# 2. c
#    core type: Variable
#    sub-expressions:
# 3. b_1,...,b_m
#    core type: Iter
#    lambda_map: 6
#    start_index: 34
#    end_index: 33
# 4. d_1,...,d_n
#    core type: Iter
#    lambda_map: 7
#    start_index: 34
#    end_index: 35
# 5. _x_ -> a__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 26
#    body: 8
#    conditions: 9\n6. _x_ -> b__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 26
#    body: 10
#    conditions: 11\n7. _x_ -> d__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 26
#    body: 12
#    conditions: 13\n8. a__x_
#    core type: Indexed
#    var: 14
#    index: 26
#    base: "1"
# 9. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 15
# 10. b__x_
#     core type: Indexed
# ...
