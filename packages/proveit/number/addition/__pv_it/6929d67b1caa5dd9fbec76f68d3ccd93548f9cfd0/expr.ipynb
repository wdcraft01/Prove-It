# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda
from proveit._common_ import AA, i, m, x
from proveit.logic import Equals, Forall, InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Add, Complexes, Exp, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, Forall([x], Equals(Add(iterA1m), Mult(m, x)), domain = Complexes, conditions = [Iter(i, Equals(Indexed(AA, i, base = 1), x), one, m)]), conditions = [InSet(AA, Exp(Complexes, m))])
# Out:
# expr: A -> [forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))] | A in Complexes^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))] | A in Complexes^{m}
#    core type: Lambda
#    parameter: 37
#    body: 1
#    conditions: 2\n1. forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in Complexes^{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. x -> ((A_1 +  ...  + A_m) = (m * x)) | x in Complexes , A_1 = x ,  ...  , A_m = x
#    core type: Lambda
#    parameter: 32
#    body: 6
#    conditions: 7\n5. A in Complexes^{m}
#    core type: Operation
#    operator: 39
#    operands: 8
# 6. (A_1 +  ...  + A_m) = (m * x)
#    core type: Operation
#    operator: 27
#    operands: 9
# 7. (x in Complexes , A_1 = x ,  ...  , A_m = x)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (A , Complexes^{m})
#    core type: ExprTuple
#    sub-expressions: 37, 12
# ...
