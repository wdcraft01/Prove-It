# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, one, six, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, a)
subExpr2 = Mult(three, c)
subExpr3 = Mult(two, b)
expr = Equals(Add(subExpr1, subExpr2, subExpr3, Add(one, two, three)), Add(subExpr1, subExpr2, subExpr3, six))
# Out:
# expr: ((2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3)) = ((2 * a) + (3 * c) + (2 * b) + 6)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3)) = ((2 * a) + (3 * c) + (2 * b) + 6)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3) , (2 * a) + (3 * c) + (2 * b) + 6)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * a) + (3 * c) + (2 * b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (2 * a) + (3 * c) + (2 * b) + 6
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (2 * a , 3 * c , 2 * b , 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 7
# 6. (2 * a , 3 * c , 2 * b , 6)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. 1 + 2 + 3
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. 2 * a
#    core type: Operation
#    operator: 16
#    operands: 14
# 9. 3 * c
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. 2 * b
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. 6
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (1 , 2 , 3)
#     core type: ExprTuple
#     sub-expressions: 18, 22, 20
# 14. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 22, 19
# 15. (3 , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. 2
#     core type: Literal
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
