# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(two, a), Add(c, c), Add(b, b), Add(two, three, four))
# Out:
# expr: (2 * a , c + c , b + b , 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 * a , c + c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. 2 * a
#    core type: Operation
#    operator: 5
#    operands: 6
# 2. c + c
#    core type: Operation
#    operator: 9
#    operands: 7
# 3. b + b
#    core type: Operation
#    operator: 9
#    operands: 8
# 4. 2 + 3 + 4
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (2 , a)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 7. (c , c)
#    core type: ExprTuple
#    sub-expressions: 12, 12
# 8. (b , b)
#    core type: ExprTuple
#    sub-expressions: 13, 13
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. 4
#     core type: Literal
#     sub-expressions:
