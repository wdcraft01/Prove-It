# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, one, two, c, b, a, zero, b, c, c, three), Add(a, one, two, c, b, a, b, c, c, three))
# Out:
# expr: (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = (a + 1 + 2 + c + b + a + b + c + c + 3)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3) = (a + 1 + 2 + c + b + a + b + c + c + 3)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + 1 + 2 + c + b + a + 0 + b + c + c + 3 , a + 1 + 2 + c + b + a + b + c + c + 3)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + 1 + 2 + c + b + a + 0 + b + c + c + 3
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + 1 + 2 + c + b + a + b + c + c + 3
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a , 1 , 2 , c , b , a , 0 , b , c , c , 3)
#    core type: ExprTuple
#    sub-expressions: 11, 9, 10, 13, 12, 11, 8, 12, 13, 13, 14
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a , 1 , 2 , c , b , a , b , c , c , 3)
#    core type: ExprTuple
#    sub-expressions: 11, 9, 10, 13, 12, 11, 12, 13, 13, 14
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
