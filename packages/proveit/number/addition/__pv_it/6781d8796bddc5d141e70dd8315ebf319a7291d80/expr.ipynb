# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(b, subExpr1, subExpr2, c, c, two), Add(Add(b, subExpr1, subExpr2), c, c, two))
# Out:
# expr: (b + (3 * b) + (2 * b) + c + c + 2 , (b + (3 * b) + (2 * b)) + c + c + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (b + (3 * b) + (2 * b) + c + c + 2 , (b + (3 * b) + (2 * b)) + c + c + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. b + (3 * b) + (2 * b) + c + c + 2
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (b + (3 * b) + (2 * b)) + c + c + 2
#    core type: Operation
#    operator: 7
#    operands: 4
# 3. (b , 3 * b , 2 * b , c , c , 2)
#    core type: ExprTuple
#    sub-expressions: 16, 9, 10, 6, 6, 15
# 4. (b + (3 * b) + (2 * b) , c , c , 2)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 6, 15
# 5. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. c
#    core type: Variable
#    sub-expressions:
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (b , 3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 16, 9, 10
# 9. 3 * b
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. 2 * b
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
