# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c, d
from proveit.number import Add, Mult, two, zero

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(two, b)
expr = ExprTuple(Add(subExpr1, b, a, c, Mult(zero, d)), Add(subExpr1, b, a, c))
# Out:
# expr: ((2 * b) + b + a + c + (0 * d) , (2 * b) + b + a + c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * b) + b + a + c + (0 * d) , (2 * b) + b + a + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * b) + b + a + c + (0 * d)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (2 * b) + b + a + c
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 * b , b , a , c , 0 * d)
#    core type: ExprTuple
#    sub-expressions: 7, 16, 8, 9, 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2 * b , b , a , c)
#    core type: ExprTuple
#    sub-expressions: 7, 16, 8, 9
# 6. 0 * d
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. (0 , d)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. 0
#     core type: Literal
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
