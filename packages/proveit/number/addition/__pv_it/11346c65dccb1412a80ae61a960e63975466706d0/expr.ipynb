# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c, d, e, f, g, h
from proveit.logic import Forall, InSet
from proveit.number import Exp, eight

# %%
# build up the expression from sub-expressions
expr = Lambda(f, Forall([g, h], InSet([a, b, c, d, e, f, g, h], Exp(S, eight)), domain = S, conditions = []), conditions = [InSet(f, S)])
# Out:
# expr: f -> [forall_{g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | f in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. f -> [forall_{g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | f in S
#    core type: Lambda
#    parameter: 25
#    body: 1
#    conditions: 2\n1. forall_{g, h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (f in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. g -> [forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})] | g in S
#    core type: Lambda
#    parameter: 26
#    body: 5
#    conditions: 6\n4. f in S
#    core type: Operation
#    operator: 18
#    operands: 7
# 5. forall_{h in S} ((a , b , c , d , e , f , g , h) in S^{8})
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (g in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (f , S)
#    core type: ExprTuple
#    sub-expressions: 25, 30
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. h -> ((a , b , c , d , e , f , g , h) in S^{8}) | h in S
#    core type: Lambda
#    parameter: 29
#    body: 11
#    conditions: 12\n10. g in S
#     core type: Operation
#     operator: 18
#     operands: 13
# 11. (a , b , c , d , e , f , g , h) in S^{8}
#     core type: Operation
#     operator: 18
#     operands: 14
# 12. (h in S)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (g , S)
#     core type: ExprTuple
#     sub-expressions: 26, 30
# 14. ((a , b , c , d , e , f , g , h) , S^{8})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. h in S
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (a , b , c , d , e , f , g , h)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22, 23, 24, 25, 26, 29
# 17. S^{8}
#     core type: Operation
#     operator: 27
#     operands: 28
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (h , S)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. c
#     core type: Variable
#     sub-expressions:
# 23. d
#     core type: Variable
#     sub-expressions:
# 24. e
#     core type: Variable
#     sub-expressions:
# 25. f
#     core type: Variable
#     sub-expressions:
# 26. g
#     core type: Variable
#     sub-expressions:
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (S , 8)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. h
#     core type: Variable
#     sub-expressions:
# 30. S
#     core type: Variable
#     sub-expressions:
# 31. 8
#     core type: Literal
#     sub-expressions:
