# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import c, dd, n
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Exp
from proveit.number._common_ import iter_a1l, iter_b1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = Forall([dd], Equals(Add(iter_a1l, iter_b1m, c, iter_d1n), Add(iter_a1l, c, iter_b1m, iter_d1n)), domain = Exp(Complexes, n), conditions = [])
# Out:
# expr: forall_{d in Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{d in Complexes^{n}} ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. d -> ((a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n)) | d in Complexes^{n}
#    core type: Lambda
#    parameter: 35
#    body: 3
#    conditions: 4\n3. (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n) = (a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (d in Complexes^{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_1 +  ...  + a_l + b_1 +  ...  + b_m + c + d_1 +  ...  + d_n , a_1 +  ...  + a_l + c + b_1 +  ...  + b_m + d_1 +  ...  + d_n)
# ...
