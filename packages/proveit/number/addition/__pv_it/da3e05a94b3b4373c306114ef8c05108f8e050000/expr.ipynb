# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, a, b, c
from proveit.number import Add, Mult, five, one, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(one, a, A, zero, b, B, C, c, one, three, A), Add(a, Mult(two, A), b, B, C, c, five))
# Out:
# expr: (1 + a + A + 0 + b + B + C + c + 1 + 3 + A , a + (2 * A) + b + B + C + c + 5)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (1 + a + A + 0 + b + B + C + c + 1 + 3 + A , a + (2 * A) + b + B + C + c + 5)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 + a + A + 0 + b + B + C + c + 1 + 3 + A
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a + (2 * A) + b + B + C + c + 5
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 , a , A , 0 , b , B , C , c , 1 , 3 , A)
#    core type: ExprTuple
#    sub-expressions: 7, 9, 19, 6, 11, 12, 13, 14, 7, 8, 19
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (a , 2 * A , b , B , C , c , 5)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13, 14, 15
# 6. 0
#    core type: Literal
#    sub-expressions:
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. 2 * A
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. C
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. 5
#     core type: Literal
#     sub-expressions:
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2 , A)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. A
#     core type: Variable
#     sub-expressions:
