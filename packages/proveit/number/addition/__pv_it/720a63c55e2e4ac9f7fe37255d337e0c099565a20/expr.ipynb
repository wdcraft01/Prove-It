# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Set.html">Set</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import InSet, Set
from proveit.number import Neg, Reals, RealsNeg, one, three, two

# %%
# build up the expression from sub-expressions
expr = Set(InSet(three, Reals), InSet(Neg(one), RealsNeg), InSet(Neg(two), RealsNeg))
# Out:
# expr: {3 in Reals , (-1) in RealsNeg , (-2) in RealsNeg}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. {3 in Reals , (-1) in RealsNeg , (-2) in RealsNeg}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. Set
#    core type: Literal
#    sub-expressions:
# 2. (3 in Reals , (-1) in RealsNeg , (-2) in RealsNeg)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. 3 in Reals
#    core type: Operation
#    operator: 8
#    operands: 6
# 4. (-1) in RealsNeg
#    core type: Operation
#    operator: 8
#    operands: 7
# 5. (-2) in RealsNeg
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (3 , Reals)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (-1 , RealsNeg)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (-2 , RealsNeg)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. Reals
#     core type: Literal
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 16
#     operand: 15
# 13. -2
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. RealsNeg
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
