# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, a, b, c
from proveit.logic import InSet
from proveit.number import Add, Complexes, Exp, six

# %%
# build up the expression from sub-expressions
expr = InSet([a, Add(A, A), b, B, C, c], Exp(Complexes, six))
# Out:
# expr: (a , A + A , b , B , C , c) in Complexes^{6}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a , A + A , b , B , C , c) in Complexes^{6}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((a , A + A , b , B , C , c) , Complexes^{6})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a , A + A , b , B , C , c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8, 9, 10
# 4. Complexes^{6}
#    core type: Operation
#    operator: 11
#    operands: 12
# 5. a
#    core type: Variable
#    sub-expressions:
# 6. A + A
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. b
#    core type: Variable
#    sub-expressions:
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. C
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (Complexes , 6)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (A , A)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 15. Complexes
#     core type: Literal
#     sub-expressions:
# 16. 6
#     core type: Literal
#     sub-expressions:
# 17. A
#     core type: Variable
#     sub-expressions:
