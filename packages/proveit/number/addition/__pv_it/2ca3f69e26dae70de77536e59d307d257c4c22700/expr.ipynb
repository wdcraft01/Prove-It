# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(Mult(one, two), b, c, subExpr1, subExpr2, Mult(one, c)), Add(b, subExpr1, subExpr2, Mult(two, c), two))
# Out:
# expr: ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c) , b + (3 * b) + (2 * b) + (2 * c) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c) , b + (3 * b) + (2 * b) + (2 * c) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 * 2) + b + c + (3 * b) + (2 * b) + (1 * c)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. b + (3 * b) + (2 * b) + (2 * c) + 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (1 * 2 , b , c , 3 * b , 2 * b , 1 * c)
#    core type: ExprTuple
#    sub-expressions: 6, 19, 21, 8, 9, 7
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (b , 3 * b , 2 * b , 2 * c , 2)
#    core type: ExprTuple
#    sub-expressions: 19, 8, 9, 10, 20
# 6. 1 * 2
#    core type: Operation
#    operator: 15
#    operands: 11
# 7. 1 * c
#    core type: Operation
#    operator: 15
#    operands: 12
# 8. 3 * b
#    core type: Operation
#    operator: 15
#    operands: 13
# 9. 2 * b
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. 2 * c
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (1 , 2)
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 12. (1 , c)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 13. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
