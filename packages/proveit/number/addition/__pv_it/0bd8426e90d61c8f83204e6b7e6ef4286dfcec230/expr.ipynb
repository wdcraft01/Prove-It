# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, B, CC, m, n
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Add, Exp, Greater, Naturals, NaturalsPos, zero

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([AA, B, CC], InSet(Add(iterA1m, B, iterC1n), NaturalsPos), domains = [Exp(Naturals, m), Naturals, Exp(Naturals, n)], conditions = [Greater(B, zero)]), domain = Naturals, conditions = [])
# Out:
# expr: forall_{n in Naturals} [forall_{(A, B, C) in Naturals^{m} * Naturals * Naturals^{n} | B > 0} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{(A, B, C) in Naturals^{m} * Naturals * Naturals^{n} | B > 0} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)]
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. n -> [forall_{(A, B, C) in Naturals^{m} * Naturals * Naturals^{n} | B > 0} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)] | n in Naturals
#    core type: Lambda
#    parameter: 61
#    body: 2
#    conditions: 3\n2. forall_{(A, B, C) in Naturals^{m} * Naturals * Naturals^{n} | B > 0} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. A -> [forall_{(B, C) in Naturals * Naturals^{n} | B > 0} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) in NaturalsPos)] | A in Naturals^{m}
#    core type: Lambda
#    parameter: 46
#    body: 6
#    conditions: 7\n5. n in Naturals
#    core type: Operation
#    operator: 51
# ...
