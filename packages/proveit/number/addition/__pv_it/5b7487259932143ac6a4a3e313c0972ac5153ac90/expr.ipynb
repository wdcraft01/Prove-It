# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Forall, InSet
from proveit.number import Complexes, Mult

# %%
# build up the expression from sub-expressions
expr = Forall([b], InSet(Mult(a, b), Complexes), domain = Complexes, conditions = [])
# Out:
# expr: forall_{b in Complexes} ((a * b) in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b in Complexes} ((a * b) in Complexes)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. b -> ((a * b) in Complexes) | b in Complexes
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. (a * b) in Complexes
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a * b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 7, 12
# 6. b in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. a * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (a , b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
