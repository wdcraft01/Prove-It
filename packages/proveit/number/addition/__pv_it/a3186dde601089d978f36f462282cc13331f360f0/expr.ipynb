# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c, d, e, f
from proveit.logic import Forall, InSet
from proveit.number import Exp, six

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b, c, d, e, f], InSet([a, b, c, d, e, f], Exp(S, six)), domain = S, conditions = []), conditions = [InSet(a, S)])
# Out:
# expr: a -> [forall_{b, c, d, e, f in S} ((a , b , c , d , e , f) in S^{6})] | a in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b, c, d, e, f in S} ((a , b , c , d , e , f) in S^{6})] | a in S
#    core type: Lambda
#    parameter: 35
#    body: 1
#    conditions: 2\n1. forall_{b, c, d, e, f in S} ((a , b , c , d , e , f) in S^{6})
#    core type: Operation
#    operator: 23
#    operand: 3
# 2. (a in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{c, d, e, f in S} ((a , b , c , d , e , f) in S^{6})] | b in S
#    core type: Lambda
#    parameter: 36
#    body: 5
#    conditions: 6\n4. a in S
#    core type: Operation
#    operator: 33
#    operands: 7
# 5. forall_{c, d, e, f in S} ((a , b , c , d , e , f) in S^{6})
#    core type: Operation
#    operator: 23
#    operand: 8
# 6. (b in S)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (a , S)
#    core type: ExprTuple
#    sub-expressions: 35, 43
# 8. c -> [forall_{d, e, f in S} ((a , b , c , d , e , f) in S^{6})] | c in S
#    core type: Lambda
#    parameter: 37
#    body: 10
#    conditions: 11\n9. b in S
#    core type: Operation
#    operator: 33
#    operands: 12
# 10. forall_{d, e, f in S} ((a , b , c , d , e , f) in S^{6})
#     core type: Operation
#     operator: 23
#     operand: 13
# 11. (c in S)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (b , S)
#     core type: ExprTuple
#     sub-expressions: 36, 43
# 13. d -> [forall_{e, f in S} ((a , b , c , d , e , f) in S^{6})] | d in S
#     core type: Lambda
#     parameter: 38
#     body: 15
#     conditions: 16\n14. c in S
#     core type: Operation
#     operator: 33
#     operands: 17
# 15. forall_{e, f in S} ((a , b , c , d , e , f) in S^{6})
#     core type: Operation
#     operator: 23
#     operand: 18
# 16. (d in S)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (c , S)
#     core type: ExprTuple
#     sub-expressions: 37, 43
# 18. e -> [forall_{f in S} ((a , b , c , d , e , f) in S^{6})] | e in S
#     core type: Lambda
#     parameter: 39
#     body: 20
#     conditions: 21\n19. d in S
#     core type: Operation
#     operator: 33
#     operands: 22
# 20. forall_{f in S} ((a , b , c , d , e , f) in S^{6})
#     core type: Operation
#     operator: 23
#     operand: 24
# 21. (e in S)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. (d , S)
#     core type: ExprTuple
#     sub-expressions: 38, 43
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. f -> ((a , b , c , d , e , f) in S^{6}) | f in S
#     core type: Lambda
#     parameter: 42
#     body: 26
#     conditions: 27\n25. e in S
#     core type: Operation
#     operator: 33
#     operands: 28
# 26. (a , b , c , d , e , f) in S^{6}
#     core type: Operation
#     operator: 33
#     operands: 29
# 27. (f in S)
#     core type: ExprTuple
#     sub-expressions: 30
# 28. (e , S)
#     core type: ExprTuple
#     sub-expressions: 39, 43
# 29. ((a , b , c , d , e , f) , S^{6})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. f in S
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. (a , b , c , d , e , f)
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37, 38, 39, 42
# 32. S^{6}
#     core type: Operation
#     operator: 40
#     operands: 41
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (f , S)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. b
#     core type: Variable
#     sub-expressions:
# 37. c
#     core type: Variable
#     sub-expressions:
# 38. d
#     core type: Variable
#     sub-expressions:
# 39. e
#     core type: Variable
#     sub-expressions:
# 40. Exp
#     core type: Literal
#     sub-expressions:
# 41. (S , 6)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. f
#     core type: Variable
#     sub-expressions:
# 43. S
#     core type: Variable
#     sub-expressions:
# 44. 6
#     core type: Literal
#     sub-expressions:
