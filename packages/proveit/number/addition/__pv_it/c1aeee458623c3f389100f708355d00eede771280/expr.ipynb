# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e
from proveit.logic import Forall, InSet
from proveit.number import Exp, five

# %%
# build up the expression from sub-expressions
expr = Forall([b, c, d, e], InSet([a, b, c, d, e], Exp(S, five)), domain = S, conditions = [])
# Out:
# expr: forall_{b, c, d, e in S} ((a , b , c , d , e) in S^{5})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c, d, e in S} ((a , b , c , d , e) in S^{5})
#    core type: Operation
#    operator: 14
#    operand: 1
# 1. b -> [forall_{c, d, e in S} ((a , b , c , d , e) in S^{5})] | b in S
#    core type: Lambda
#    parameter: 27
#    body: 2
#    conditions: 3\n2. forall_{c, d, e in S} ((a , b , c , d , e) in S^{5})
#    core type: Operation
#    operator: 14
#    operand: 4
# 3. (b in S)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. c -> [forall_{d, e in S} ((a , b , c , d , e) in S^{5})] | c in S
#    core type: Lambda
#    parameter: 28
#    body: 6
#    conditions: 7\n5. b in S
#    core type: Operation
#    operator: 24
#    operands: 8
# 6. forall_{d, e in S} ((a , b , c , d , e) in S^{5})
#    core type: Operation
#    operator: 14
#    operand: 9
# 7. (c in S)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (b , S)
#    core type: ExprTuple
#    sub-expressions: 27, 33
# 9. d -> [forall_{e in S} ((a , b , c , d , e) in S^{5})] | d in S
#    core type: Lambda
#    parameter: 29
#    body: 11
#    conditions: 12\n10. c in S
#     core type: Operation
#     operator: 24
#     operands: 13
# 11. forall_{e in S} ((a , b , c , d , e) in S^{5})
#     core type: Operation
#     operator: 14
#     operand: 15
# 12. (d in S)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (c , S)
#     core type: ExprTuple
#     sub-expressions: 28, 33
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. e -> ((a , b , c , d , e) in S^{5}) | e in S
#     core type: Lambda
#     parameter: 32
#     body: 17
#     conditions: 18\n16. d in S
#     core type: Operation
#     operator: 24
#     operands: 19
# 17. (a , b , c , d , e) in S^{5}
#     core type: Operation
#     operator: 24
#     operands: 20
# 18. (e in S)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. (d , S)
#     core type: ExprTuple
#     sub-expressions: 29, 33
# 20. ((a , b , c , d , e) , S^{5})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. e in S
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (a , b , c , d , e)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28, 29, 32
# 23. S^{5}
#     core type: Operation
#     operator: 30
#     operands: 31
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (e , S)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. d
#     core type: Variable
#     sub-expressions:
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (S , 5)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. e
#     core type: Variable
#     sub-expressions:
# 33. S
#     core type: Variable
#     sub-expressions:
# 34. 5
#     core type: Literal
#     sub-expressions:
