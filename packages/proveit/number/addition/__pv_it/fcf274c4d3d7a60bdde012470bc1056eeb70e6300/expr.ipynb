# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import B, CC, n
from proveit.logic import Forall
from proveit.logic._common_ import iterA1m
from proveit.number import Add, Greater, Reals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([B], Greater(Add(iterA1m, B, Iter(subExpr1, Indexed(CC, subExpr1, base = 1), one, n)), B), domain = Reals, conditions = [])
# Out:
# expr: forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B) | B in Reals
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. (A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B in Reals)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. >
#    core type: Literal
#    sub-expressions:
# 6. (A_1 +  ...  + A_m + B + C_1 +  ...  + C_n , B)
#    core type: ExprTuple
#    sub-expressions: 8, 14
# 7. B in Reals
#    core type: Operation
#    operator: 27
#    operands: 9
# 8. A_1 +  ...  + A_m + B + C_1 +  ...  + C_n
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (B , Reals)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 10. +
#     core type: Literal
#     sub-expressions:
# ...
