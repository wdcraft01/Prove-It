# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, B, CC, m, n
from proveit.logic import Forall
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Add, Exp, Greater, Reals, RealsPos

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([AA, CC], Forall([B], Greater(Add(iterA1m, B, iterC1n), B), domain = Reals, conditions = subExpr1), domains = [Exp(RealsPos, m), Exp(RealsPos, n)], conditions = subExpr1)
# Out:
# expr: forall_{(A, C) in (RealsPos)^{m} * (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(A, C) in (RealsPos)^{m} * (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. A -> [forall_{C in (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]] | A in (RealsPos)^{m}
#    core type: Lambda
#    parameter: 38
#    body: 2
#    conditions: 3\n2. forall_{C in (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (A in (RealsPos)^{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. C -> [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)] | C in (RealsPos)^{n}
#    core type: Lambda
#    parameter: 40
#    body: 6
#    conditions: 7\n5. A in (RealsPos)^{m}
#    core type: Operation
#    operator: 43
#    operands: 8
# 6. forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)
# ...
