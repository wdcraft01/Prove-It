# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b
from proveit.logic import Equals
from proveit.number import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(Mult(two, b), Mult(three, b), b, Neg(b))
expr = Equals(subExpr1, subExpr1)
# Out:
# expr: ((2 * b) + (3 * b) + b - b) = ((2 * b) + (3 * b) + b - b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((2 * b) + (3 * b) + b - b) = ((2 * b) + (3 * b) + b - b)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * b) + (3 * b) + b - b , (2 * b) + (3 * b) + b - b)
#    core type: ExprTuple
#    sub-expressions: 3, 3
# 3. (2 * b) + (3 * b) + b - b
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2 * b , 3 * b , b , -b)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 15, 8
# 6. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. -b
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. (2 , b)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
