# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda, Variable
from proveit._common_ import aa, b, cc, dd, l, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Exp, Neg, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(aa, subExpr1, base = 1), one, l)
subExpr3 = Iter(subExpr1, Indexed(cc, subExpr1, base = 1), one, m)
subExpr4 = Iter(subExpr1, Indexed(dd, subExpr1, base = 1), one, n)
expr = Lambda(b, Forall([cc, dd], Equals(Add(subExpr2, b, subExpr3, Neg(b), subExpr4), Add(subExpr2, subExpr3, subExpr4)), domains = [Exp(Complexes, m), Exp(Complexes, n)], conditions = []), conditions = [InSet(b, Complexes)])
# Out:
# expr: b -> [forall_{(c, d) in Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))] | b in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{(c, d) in Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))] | b in Complexes
#    core type: Lambda
#    parameter: 33
#    body: 1
#    conditions: 2\n1. forall_{(c, d) in Complexes^{m} * Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. c -> [forall_{d in Complexes^{n}} ((a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n) = (a_1 +  ...  + a_l + c_1 +  ...  + c_m + d_1 +  ...  + d_n))] | c in Complexes^{m}
#    core type: Lambda
#    parameter: 46
#    body: 5
#    conditions: 6\n4. b in Complexes
#    core type: Operation
#    operator: 52
#    operands: 7
# ...
