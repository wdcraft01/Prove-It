# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import InSet
from proveit.number import Complexes, Exp, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = InSet([Mult(three, b), Mult(two, b), c], Exp(Complexes, three))
# Out:
# expr: (3 * b , 2 * b , c) in Complexes^{3}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (3 * b , 2 * b , c) in Complexes^{3}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((3 * b , 2 * b , c) , Complexes^{3})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (3 * b , 2 * b , c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 4. Complexes^{3}
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 6. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (Complexes , 3)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
