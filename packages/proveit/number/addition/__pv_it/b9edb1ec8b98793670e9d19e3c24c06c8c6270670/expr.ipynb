# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, four, nine, three, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(Add(two, three, four, a, a, c, zero, c, b, b), Add(Mult(two, a), Mult(two, c), Mult(two, b), nine))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b) = ((2 * a) + (2 * c) + (2 * b) + 9)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b) = ((2 * a) + (2 * c) + (2 * b) + 9)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + 3 + 4 + a + a + c + 0 + c + b + b , (2 * a) + (2 * c) + (2 * b) + 9)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * a) + (2 * c) + (2 * b) + 9
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2 , 3 , 4 , a , a , c , 0 , c , b , b)
#    core type: ExprTuple
#    sub-expressions: 21, 8, 9, 19, 19, 20, 10, 20, 22, 22
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2 * a , 2 * c , 2 * b , 9)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. 4
#    core type: Literal
#    sub-expressions:
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. 2 * a
#     core type: Operation
#     operator: 17
#     operands: 15
# 12. 2 * c
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. 2 * b
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. 9
#     core type: Literal
#     sub-expressions:
# 15. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 16. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
