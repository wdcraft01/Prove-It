# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b
from proveit.logic import InSet
from proveit.number import Complexes, Exp, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = InSet([two, Mult(three, b), Mult(two, b)], Exp(Complexes, three))
# Out:
# expr: (2 , 3 * b , 2 * b) in Complexes^{3}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 , 3 * b , 2 * b) in Complexes^{3}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((2 , 3 * b , 2 * b) , Complexes^{3})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 , 3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 14, 5, 6
# 4. Complexes^{3}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (Complexes , 3)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (3 , b)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
