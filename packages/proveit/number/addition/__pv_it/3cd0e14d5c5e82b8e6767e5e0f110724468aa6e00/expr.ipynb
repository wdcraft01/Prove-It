# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, c], Equals(Add(Neg(a), Neg(b)), Neg(c)), domain = Complexes, conditions = [Equals(Add(a, b), c)])
# Out:
# expr: forall_{a, b, c in Complexes | (a + b) = c} ((-a - b) = (-c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a, b, c in Complexes | (a + b) = c} ((-a - b) = (-c))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b, c in Complexes | (a + b) = c} ((-a - b) = (-c))] | a in Complexes
#    core type: Lambda
#    parameter: 33
#    body: 2
#    conditions: 3\n2. forall_{b, c in Complexes | (a + b) = c} ((-a - b) = (-c))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))] | b in Complexes
#    core type: Lambda
#    parameter: 34
#    body: 6
#    conditions: 7\n5. a in Complexes
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 33, 25
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. c -> ((-a - b) = (-c)) | c in Complexes , (a + b) = c
#     core type: Lambda
#     parameter: 27
#     body: 12
#     conditions: 13\n11. b in Complexes
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. (-a - b) = (-c)
#     core type: Operation
#     operator: 22
#     operands: 15
# 13. (c in Complexes , (a + b) = c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 34, 25
# 15. (-a - b , -c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. c in Complexes
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. (a + b) = c
#     core type: Operation
#     operator: 22
#     operands: 23
# 18. -a - b
#     core type: Operation
#     operator: 30
#     operands: 24
# 19. -c
#     core type: Operation
#     operator: 32
#     operand: 27
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. (-a , -b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. Complexes
#     core type: Literal
#     sub-expressions:
# 26. a + b
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. c
#     core type: Variable
#     sub-expressions:
# 28. -a
#     core type: Operation
#     operator: 32
#     operand: 33
# 29. -b
#     core type: Operation
#     operator: 32
#     operand: 34
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (a , b)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. a
#     core type: Variable
#     sub-expressions:
# 34. b
#     core type: Variable
#     sub-expressions:
