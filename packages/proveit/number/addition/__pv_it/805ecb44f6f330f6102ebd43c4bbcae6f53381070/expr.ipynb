# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(two, three, four, a, a, c, zero, c, b, b), Add(Mult(two, a), Mult(two, c), Add(b, b), Add(two, three, four)))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b , (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b , (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 14
#    operands: 3
# 2. (2 * a) + (2 * c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (2 , 3 , 4 , a , a , c , 0 , c , b , b)
#    core type: ExprTuple
#    sub-expressions: 19, 20, 21, 16, 16, 17, 5, 17, 18, 18
# 4. (2 * a , 2 * c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. 2 * a
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. 2 * c
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. b + b
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. 2 + 3 + 4
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. (2 , a)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 13. (b , b)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. 4
#     core type: Literal
#     sub-expressions:
