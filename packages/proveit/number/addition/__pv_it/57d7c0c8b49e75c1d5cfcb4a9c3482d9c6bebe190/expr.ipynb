# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g
from proveit.logic import Forall, InSet
from proveit.number import Exp, seven

# %%
# build up the expression from sub-expressions
expr = Forall([g], InSet([a, b, c, d, e, f, g], Exp(S, seven)), domain = S, conditions = [])
# Out:
# expr: forall_{g in S} ((a , b , c , d , e , f , g) in S^{7})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. g -> ((a , b , c , d , e , f , g) in S^{7}) | g in S
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. (a , b , c , d , e , f , g) in S^{7}
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (g in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. ((a , b , c , d , e , f , g) , S^{7})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. g in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (a , b , c , d , e , f , g)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14, 15, 16, 19
# 8. S^{7}
#    core type: Operation
#    operator: 17
#    operands: 18
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (g , S)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (S , 7)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. g
#     core type: Variable
#     sub-expressions:
# 20. S
#     core type: Variable
#     sub-expressions:
# 21. 7
#     core type: Literal
#     sub-expressions:
