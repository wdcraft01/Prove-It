# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, one, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(a, a)
subExpr2 = Add(c, c, c)
subExpr3 = Add(b, b)
expr = ExprTuple(Add(subExpr1, subExpr2, subExpr3, one, two, three), Add(subExpr1, subExpr2, subExpr3, Add(one, two, three)))
# Out:
# expr: ((a + a) + (c + c + c) + (b + b) + 1 + 2 + 3 , (a + a) + (c + c + c) + (b + b) + (1 + 2 + 3))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a + a) + (c + c + c) + (b + b) + 1 + 2 + 3 , (a + a) + (c + c + c) + (b + b) + (1 + 2 + 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a + a) + (c + c + c) + (b + b) + 1 + 2 + 3
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a + a) + (c + c + c) + (b + b) + (1 + 2 + 3)
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. (a + a , c + c + c , b + b , 1 , 2 , 3)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 17, 18, 19
# 4. (a + a , c + c + c , b + b , 1 + 2 + 3)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7, 8
# 5. a + a
#    core type: Operation
#    operator: 12
#    operands: 9
# 6. c + c + c
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. b + b
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. 1 + 2 + 3
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (a , a)
#    core type: ExprTuple
#    sub-expressions: 14, 14
# 10. (c , c , c)
#     core type: ExprTuple
#     sub-expressions: 15, 15, 15
# 11. (b , b)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (1 , 2 , 3)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. 3
#     core type: Literal
#     sub-expressions:
