# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c, d, e, f, g
from proveit.logic import InSet
from proveit.number import Exp, seven

# %%
# build up the expression from sub-expressions
expr = Lambda(g, InSet([a, b, c, d, e, f, g], Exp(S, seven)), conditions = [InSet(g, S)])
# Out:
# expr: g -> ((a , b , c , d , e , f , g) in S^{7}) | g in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. g -> ((a , b , c , d , e , f , g) in S^{7}) | g in S
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. (a , b , c , d , e , f , g) in S^{7}
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (g in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. ((a , b , c , d , e , f , g) , S^{7})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. g in S
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (a , b , c , d , e , f , g)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13, 14, 17
# 6. S^{7}
#    core type: Operation
#    operator: 15
#    operands: 16
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (g , S)
#    core type: ExprTuple
#    sub-expressions: 17, 18
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. d
#     core type: Variable
#     sub-expressions:
# 13. e
#     core type: Variable
#     sub-expressions:
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (S , 7)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. g
#     core type: Variable
#     sub-expressions:
# 18. S
#     core type: Variable
#     sub-expressions:
# 19. 7
#     core type: Literal
#     sub-expressions:
