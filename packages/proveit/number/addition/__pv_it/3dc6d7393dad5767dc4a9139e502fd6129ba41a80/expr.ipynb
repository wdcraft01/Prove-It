# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, b, c, a, b, a, c, b, a, c, a), Add(Add(a, a, a, a, a), Add(b, b, b), Add(c, c, c)))
# Out:
# expr: (a + b + c + a + b + a + c + b + a + c + a , (a + a + a + a + a) + (b + b + b) + (c + c + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + b + c + a + b + a + c + b + a + c + a , (a + a + a + a + a) + (b + b + b) + (c + c + c))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + b + c + a + b + a + c + b + a + c + a
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (a + a + a + a + a) + (b + b + b) + (c + c + c)
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (a , b , c , a , b , a , c , b , a , c , a)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 12, 13, 12, 14, 13, 12, 14, 12
# 4. (a + a + a + a + a , b + b + b , c + c + c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. a + a + a + a + a
#    core type: Operation
#    operator: 10
#    operands: 8
# 6. b + b + b
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. c + c + c
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (a , a , a , a , a)
#    core type: ExprTuple
#    sub-expressions: 12, 12, 12, 12, 12
# 9. (b , b , b)
#    core type: ExprTuple
#    sub-expressions: 13, 13, 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (c , c , c)
#     core type: ExprTuple
#     sub-expressions: 14, 14, 14
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
