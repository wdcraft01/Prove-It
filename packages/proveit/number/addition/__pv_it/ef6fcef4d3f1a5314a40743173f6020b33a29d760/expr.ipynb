# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Complexes, Exp, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple([Add(a, a), Add(c, c, c), Add(b, b)], Exp(Complexes, three))
# Out:
# expr: ((a + a , c + c + c , b + b) , Complexes^{3})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a + a , c + c + c , b + b) , Complexes^{3})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a + a , c + c + c , b + b)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 2. Complexes^{3}
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. a + a
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. c + c + c
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. b + b
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. Exp
#    core type: Literal
#    sub-expressions:
# 7. (Complexes , 3)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 8. (a , a)
#    core type: ExprTuple
#    sub-expressions: 14, 14
# 9. (c , c , c)
#    core type: ExprTuple
#    sub-expressions: 15, 15, 15
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (b , b)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
