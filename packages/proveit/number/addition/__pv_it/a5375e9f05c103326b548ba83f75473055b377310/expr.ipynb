# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import InSet
from proveit.number import Add, Complexes, Exp, two

# %%
# build up the expression from sub-expressions
expr = InSet([Add(a, a, a), Add(b, b)], Exp(Complexes, two))
# Out:
# expr: (a + a + a , b + b) in Complexes^{2}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + a + a , b + b) in Complexes^{2}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((a + a + a , b + b) , Complexes^{2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a + a + a , b + b)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. Complexes^{2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. a + a + a
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. b + b
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (Complexes , 2)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (a , a , a)
#    core type: ExprTuple
#    sub-expressions: 14, 14, 14
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (b , b)
#     core type: ExprTuple
#     sub-expressions: 15, 15
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
