# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(c, c)
subExpr2 = Mult(three, b)
subExpr3 = Mult(two, b)
expr = ExprTuple(Add(subExpr1, subExpr2, subExpr3, two), Add(subExpr1, Add(subExpr2, subExpr3), two))
# Out:
# expr: ((c + c) + (3 * b) + (2 * b) + 2 , (c + c) + ((3 * b) + (2 * b)) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((c + c) + (3 * b) + (2 * b) + 2 , (c + c) + ((3 * b) + (2 * b)) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (c + c) + (3 * b) + (2 * b) + 2
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (c + c) + ((3 * b) + (2 * b)) + 2
#    core type: Operation
#    operator: 8
#    operands: 4
# 3. (c + c , 3 * b , 2 * b , 2)
#    core type: ExprTuple
#    sub-expressions: 5, 11, 12, 17
# 4. (c + c , (3 * b) + (2 * b) , 2)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 17
# 5. c + c
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. (3 * b) + (2 * b)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (c , c)
#    core type: ExprTuple
#    sub-expressions: 10, 10
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (3 * b , 2 * b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. 3 * b
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. 2 * b
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
