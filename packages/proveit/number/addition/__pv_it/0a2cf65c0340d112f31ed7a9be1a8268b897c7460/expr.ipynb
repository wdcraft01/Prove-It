# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(two, b, c, subExpr1, subExpr2, Neg(b), c), Add(Mult(two, c), subExpr1, subExpr2, two))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) - b + c , (2 * c) + (3 * b) + (2 * b) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) - b + c , (2 * c) + (3 * b) + (2 * b) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + b + c + (3 * b) + (2 * b) - b + c
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (2 * c) + (3 * b) + (2 * b) + 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 , b , c , 3 * b , 2 * b , -b , c)
#    core type: ExprTuple
#    sub-expressions: 17, 18, 15, 8, 9, 6, 15
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2 * c , 3 * b , 2 * b , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 17
# 6. -b
#    core type: Operation
#    operator: 10
#    operand: 18
# 7. 2 * c
#    core type: Operation
#    operator: 13
#    operands: 11
# 8. 3 * b
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 2 * b
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
