# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#strictlyIncreasingAdditions">strictlyIncreasingAdditions</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.addition._theorems_ import strictlyIncreasingAdditions

# %%
# check that the built expression is the same as the stored expression
# %check_expr strictlyIncreasingAdditions
# Out:
# Passed sanity check: built 'strictlyIncreasingAdditions' is the same as the stored Expression.

# %%
# display the expression information
strictlyIncreasingAdditions.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{(A, C) in (RealsPos)^{m} * (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]]
#    core type: Operation
#    operator: 20
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{(A, C) in (RealsPos)^{m} * (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]]] | m in Naturals
#    core type: Lambda
#    parameter: 62
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{(A, C) in (RealsPos)^{m} * (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{(A, C) in (RealsPos)^{m} * (RealsPos)^{n}} [forall_{B in Reals} ((A_1 +  ...  + A_m + B + C_1 +  ...  + C_n) > B)]] | n in Naturals
#    core type: Lambda
#    parameter: 64
#    body: 6
#    conditions: 7\n5. m in Naturals
# ...
