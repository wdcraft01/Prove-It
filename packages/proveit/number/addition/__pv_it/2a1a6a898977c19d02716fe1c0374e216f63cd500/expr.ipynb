# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(a, b, c, a, b, a, c), Add(Mult(three, a), Mult(two, b), Add(c, c)))
# Out:
# expr: (a + b + c + a + b + a + c , (3 * a) + (2 * b) + (c + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + b + c + a + b + a + c , (3 * a) + (2 * b) + (c + c))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a + b + c + a + b + a + c
#    core type: Operation
#    operator: 11
#    operands: 3
# 2. (3 * a) + (2 * b) + (c + c)
#    core type: Operation
#    operator: 11
#    operands: 4
# 3. (a , b , c , a , b , a , c)
#    core type: ExprTuple
#    sub-expressions: 14, 16, 17, 14, 16, 14, 17
# 4. (3 * a , 2 * b , c + c)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. 3 * a
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. 2 * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. c + c
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (3 , a)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (c , c)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
