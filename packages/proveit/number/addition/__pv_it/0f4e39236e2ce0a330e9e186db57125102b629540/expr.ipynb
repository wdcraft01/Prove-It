# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Complexes, Exp, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple([b, Mult(three, b), Mult(two, b), c], Exp(Complexes, four))
# Out:
# expr: ((b , 3 * b , 2 * b , c) , Complexes^{4})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((b , 3 * b , 2 * b , c) , Complexes^{4})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (b , 3 * b , 2 * b , c)
#    core type: ExprTuple
#    sub-expressions: 15, 3, 4, 5
# 2. Complexes^{4}
#    core type: Operation
#    operator: 6
#    operands: 7
# 3. 3 * b
#    core type: Operation
#    operator: 9
#    operands: 8
# 4. 2 * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. c
#    core type: Variable
#    sub-expressions:
# 6. Exp
#    core type: Literal
#    sub-expressions:
# 7. (Complexes , 4)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (3 , b)
#    core type: ExprTuple
#    sub-expressions: 13, 15
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. 4
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
