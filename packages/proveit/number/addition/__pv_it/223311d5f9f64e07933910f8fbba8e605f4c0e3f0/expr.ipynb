# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Exp, four

# %%
# build up the expression from sub-expressions
subExpr1 = []
subExpr2 = [a, b, c, d]
expr = Forall([S], Forall(subExpr2, InSet(subExpr2, Exp(S, four)), domain = S, conditions = subExpr1), conditions = subExpr1)
# Out:
# expr: forall_{S} [forall_{a, b, c, d in S} ((a , b , c , d) in S^{4})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{S} [forall_{a, b, c, d in S} ((a , b , c , d) in S^{4})]
#    core type: Operation
#    operator: 16
#    operand: 1
# 1. S -> [forall_{a, b, c, d in S} ((a , b , c , d) in S^{4})]
#    core type: Lambda
#    parameter: 34
#    body: 2
# 2. forall_{a, b, c, d in S} ((a , b , c , d) in S^{4})
#    core type: Operation
#    operator: 16
#    operand: 3
# 3. a -> [forall_{b, c, d in S} ((a , b , c , d) in S^{4})] | a in S
#    core type: Lambda
#    parameter: 28
#    body: 4
#    conditions: 5\n4. forall_{b, c, d in S} ((a , b , c , d) in S^{4})
#    core type: Operation
#    operator: 16
#    operand: 6
# 5. (a in S)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. b -> [forall_{c, d in S} ((a , b , c , d) in S^{4})] | b in S
#    core type: Lambda
#    parameter: 29
#    body: 8
#    conditions: 9\n7. a in S
#    core type: Operation
#    operator: 26
#    operands: 10
# 8. forall_{c, d in S} ((a , b , c , d) in S^{4})
#    core type: Operation
#    operator: 16
#    operand: 11
# 9. (b in S)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (a , S)
#     core type: ExprTuple
#     sub-expressions: 28, 34
# 11. c -> [forall_{d in S} ((a , b , c , d) in S^{4})] | c in S
#     core type: Lambda
#     parameter: 30
#     body: 13
#     conditions: 14\n12. b in S
#     core type: Operation
#     operator: 26
#     operands: 15
# 13. forall_{d in S} ((a , b , c , d) in S^{4})
#     core type: Operation
#     operator: 16
#     operand: 17
# 14. (c in S)
#     core type: ExprTuple
#     sub-expressions: 18
# 15. (b , S)
#     core type: ExprTuple
#     sub-expressions: 29, 34
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. d -> ((a , b , c , d) in S^{4}) | d in S
#     core type: Lambda
#     parameter: 33
#     body: 19
#     conditions: 20\n18. c in S
#     core type: Operation
#     operator: 26
#     operands: 21
# 19. (a , b , c , d) in S^{4}
#     core type: Operation
#     operator: 26
#     operands: 22
# 20. (d in S)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. (c , S)
#     core type: ExprTuple
#     sub-expressions: 30, 34
# 22. ((a , b , c , d) , S^{4})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. d in S
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (a , b , c , d)
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 33
# 25. S^{4}
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (d , S)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. c
#     core type: Variable
#     sub-expressions:
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (S , 4)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. d
#     core type: Variable
#     sub-expressions:
# 34. S
#     core type: Variable
#     sub-expressions:
# 35. 4
#     core type: Literal
#     sub-expressions:
