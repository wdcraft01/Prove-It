# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(b, subExpr1, subExpr2, two, c, c), Add(b, subExpr1, subExpr2, c, two, c))
# Out:
# expr: (b + (3 * b) + (2 * b) + 2 + c + c , b + (3 * b) + (2 * b) + c + 2 + c)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (b + (3 * b) + (2 * b) + 2 + c + c , b + (3 * b) + (2 * b) + c + 2 + c)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. b + (3 * b) + (2 * b) + 2 + c + c
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. b + (3 * b) + (2 * b) + c + 2 + c
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (b , 3 * b , 2 * b , 2 , c , c)
#    core type: ExprTuple
#    sub-expressions: 14, 6, 7, 13, 8, 8
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (b , 3 * b , 2 * b , c , 2 , c)
#    core type: ExprTuple
#    sub-expressions: 14, 6, 7, 8, 13, 8
# 6. 3 * b
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. 2 * b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. (3 , b)
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
