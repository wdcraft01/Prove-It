# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import A, B, C, a, b
from proveit.logic import InSet
from proveit.number import Complexes

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Complexes), InSet(A, Complexes), InSet(b, Complexes), InSet(B, Complexes), InSet(C, Complexes))
# Out:
# expr: (a in Complexes , A in Complexes , b in Complexes , B in Complexes , C in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a in Complexes , A in Complexes , b in Complexes , B in Complexes , C in Complexes)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5
# 1. a in Complexes
#    core type: Operation
#    operator: 10
#    operands: 6
# 2. A in Complexes
#    core type: Operation
#    operator: 10
#    operands: 7
# 3. b in Complexes
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. B in Complexes
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. C in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 12, 17
# 7. (A , Complexes)
#    core type: ExprTuple
#    sub-expressions: 13, 17
# 8. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 17
# 9. (B , Complexes)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (C , Complexes)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. A
#     core type: Variable
#     sub-expressions:
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. B
#     core type: Variable
#     sub-expressions:
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. Complexes
#     core type: Literal
#     sub-expressions:
