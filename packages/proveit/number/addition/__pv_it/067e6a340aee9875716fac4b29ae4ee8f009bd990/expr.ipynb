# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, a, b, c, d, e, f, g
from proveit.logic import Forall, InSet
from proveit.number import Exp, seven

# %%
# build up the expression from sub-expressions
expr = Forall([f, g], InSet([a, b, c, d, e, f, g], Exp(S, seven)), domain = S, conditions = [])
# Out:
# expr: forall_{f, g in S} ((a , b , c , d , e , f , g) in S^{7})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. f -> [forall_{g in S} ((a , b , c , d , e , f , g) in S^{7})] | f in S
#    core type: Lambda
#    parameter: 21
#    body: 2
#    conditions: 3\n2. forall_{g in S} ((a , b , c , d , e , f , g) in S^{7})
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (f in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. g -> ((a , b , c , d , e , f , g) in S^{7}) | g in S
#    core type: Lambda
#    parameter: 24
#    body: 7
#    conditions: 8\n6. f in S
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (a , b , c , d , e , f , g) in S^{7}
#    core type: Operation
#    operator: 14
#    operands: 10
# 8. (g in S)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (f , S)
#    core type: ExprTuple
#    sub-expressions: 21, 25
# 10. ((a , b , c , d , e , f , g) , S^{7})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. g in S
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (a , b , c , d , e , f , g)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19, 20, 21, 24
# 13. S^{7}
#     core type: Operation
#     operator: 22
#     operands: 23
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (g , S)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. d
#     core type: Variable
#     sub-expressions:
# 20. e
#     core type: Variable
#     sub-expressions:
# 21. f
#     core type: Variable
#     sub-expressions:
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (S , 7)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. g
#     core type: Variable
#     sub-expressions:
# 25. S
#     core type: Variable
#     sub-expressions:
# 26. 7
#     core type: Literal
#     sub-expressions:
