# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import A, B, C, b, c
from proveit.logic import InSet
from proveit.number import Complexes, Exp, eight, one, three

# %%
# build up the expression from sub-expressions
expr = InSet([A, b, B, C, c, one, three, A], Exp(Complexes, eight))
# Out:
# expr: (A , b , B , C , c , 1 , 3 , A) in Complexes^{8}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A , b , B , C , c , 1 , 3 , A) in Complexes^{8}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((A , b , B , C , c , 1 , 3 , A) , Complexes^{8})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (A , b , B , C , c , 1 , 3 , A)
#    core type: ExprTuple
#    sub-expressions: 11, 5, 6, 7, 8, 9, 10, 11
# 4. Complexes^{8}
#    core type: Operation
#    operator: 12
#    operands: 13
# 5. b
#    core type: Variable
#    sub-expressions:
# 6. B
#    core type: Variable
#    sub-expressions:
# 7. C
#    core type: Variable
#    sub-expressions:
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. A
#     core type: Variable
#     sub-expressions:
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (Complexes , 8)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. 8
#     core type: Literal
#     sub-expressions:
