# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a], Equals(Add(Neg(a), a), zero), domain = Complexes, conditions = [])
# Out:
# expr: forall_{a in Complexes} ((-a + a) = 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{a in Complexes} ((-a + a) = 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> ((-a + a) = 0) | a in Complexes
#    core type: Lambda
#    parameter: 17
#    body: 3
#    conditions: 4\n3. (-a + a) = 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (-a + a , 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. -a + a
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (a , Complexes)
#     core type: ExprTuple
#     sub-expressions: 17, 14
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (-a , a)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. -a
#     core type: Operation
#     operator: 16
#     operand: 17
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
