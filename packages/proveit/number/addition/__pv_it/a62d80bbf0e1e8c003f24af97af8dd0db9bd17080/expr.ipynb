# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import Equals
from proveit.number import Add, Mult, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = Equals(Add(two, b, c, subExpr1, subExpr2, c), Add(Add(b, subExpr1, subExpr2), Mult(two, c), two))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) + c) = ((b + (3 * b) + (2 * b)) + (2 * c) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) + c) = ((b + (3 * b) + (2 * b)) + (2 * c) + 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 + b + c + (3 * b) + (2 * b) + c , (b + (3 * b) + (2 * b)) + (2 * c) + 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 + b + c + (3 * b) + (2 * b) + c
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (b + (3 * b) + (2 * b)) + (2 * c) + 2
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (2 , b , c , 3 * b , 2 * b , c)
#    core type: ExprTuple
#    sub-expressions: 19, 20, 14, 12, 13, 14
# 6. (b + (3 * b) + (2 * b) , 2 * c , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 19
# 7. b + (3 * b) + (2 * b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. 2 * c
#    core type: Operation
#    operator: 16
#    operands: 11
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (b , 3 * b , 2 * b)
#     core type: ExprTuple
#     sub-expressions: 20, 12, 13
# 11. (2 , c)
#     core type: ExprTuple
#     sub-expressions: 19, 14
# 12. 3 * b
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. 2 * b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
