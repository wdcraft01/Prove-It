# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import a, b, c
from proveit.number import Add, four, three, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(two, three, four, a, a, c, zero, c, b, b), Add(a, a, c, c, b, two, three, four, b))
# Out:
# expr: (2 + 3 + 4 + a + a + c + 0 + c + b + b , a + a + c + c + b + 2 + 3 + 4 + b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + 3 + 4 + a + a + c + 0 + c + b + b , a + a + c + c + b + 2 + 3 + 4 + b)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + 3 + 4 + a + a + c + 0 + c + b + b
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a + a + c + c + b + 2 + 3 + 4 + b
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 , 3 , 4 , a , a , c , 0 , c , b , b)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 7, 7, 8, 6, 8, 12, 12
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (a , a , c , c , b , 2 , 3 , 4 , b)
#    core type: ExprTuple
#    sub-expressions: 7, 7, 8, 8, 12, 9, 10, 11, 12
# 6. 0
#    core type: Literal
#    sub-expressions:
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 4
#     core type: Literal
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
