# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, c
from proveit.logic import InSet
from proveit.number import Complexes, Exp, Mult, four, three, two

# %%
# build up the expression from sub-expressions
expr = InSet([c, Mult(three, b), Mult(two, b), c], Exp(Complexes, four))
# Out:
# expr: (c , 3 * b , 2 * b , c) in Complexes^{4}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (c , 3 * b , 2 * b , c) in Complexes^{4}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. ((c , 3 * b , 2 * b , c) , Complexes^{4})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (c , 3 * b , 2 * b , c)
#    core type: ExprTuple
#    sub-expressions: 7, 5, 6, 7
# 4. Complexes^{4}
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. 3 * b
#    core type: Operation
#    operator: 11
#    operands: 10
# 6. 2 * b
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (Complexes , 4)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 17
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. 4
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
