# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, four, three, two

# %%
# build up the expression from sub-expressions
expr = Equals(Add(a, a, c, c, b, two, three, four, b), Add(a, a, c, c, b, b, two, three, four))
# Out:
# expr: (a + a + c + c + b + 2 + 3 + 4 + b) = (a + a + c + c + b + b + 2 + 3 + 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a + a + c + c + b + 2 + 3 + 4 + b) = (a + a + c + c + b + b + 2 + 3 + 4)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a + a + c + c + b + 2 + 3 + 4 + b , a + a + c + c + b + b + 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a + a + c + c + b + 2 + 3 + 4 + b
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a + a + c + c + b + b + 2 + 3 + 4
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a , a , c , c , b , 2 , 3 , 4 , b)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 9, 9, 10, 11, 12, 13, 10
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (a , a , c , c , b , b , 2 , 3 , 4)
#    core type: ExprTuple
#    sub-expressions: 8, 8, 9, 9, 10, 10, 11, 12, 13
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. 3
#     core type: Literal
#     sub-expressions:
# 13. 4
#     core type: Literal
#     sub-expressions:
