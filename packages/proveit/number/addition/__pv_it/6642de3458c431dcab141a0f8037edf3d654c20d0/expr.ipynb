# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals
from proveit.number import Add, four, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Add(a, a)
subExpr2 = Add(c, c)
subExpr3 = Add(b, b)
expr = Equals(Add(subExpr1, subExpr2, subExpr3, two, three, four), Add(subExpr1, subExpr2, subExpr3, Add(two, three, four)))
# Out:
# expr: ((a + a) + (c + c) + (b + b) + 2 + 3 + 4) = ((a + a) + (c + c) + (b + b) + (2 + 3 + 4))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((a + a) + (c + c) + (b + b) + 2 + 3 + 4) = ((a + a) + (c + c) + (b + b) + (2 + 3 + 4))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a + a) + (c + c) + (b + b) + 2 + 3 + 4 , (a + a) + (c + c) + (b + b) + (2 + 3 + 4))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a + a) + (c + c) + (b + b) + 2 + 3 + 4
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. (a + a) + (c + c) + (b + b) + (2 + 3 + 4)
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (a + a , c + c , b + b , 2 , 3 , 4)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 19, 20, 21
# 6. (a + a , c + c , b + b , 2 + 3 + 4)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 7. a + a
#    core type: Operation
#    operator: 14
#    operands: 11
# 8. c + c
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. b + b
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. 2 + 3 + 4
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (a , a)
#     core type: ExprTuple
#     sub-expressions: 16, 16
# 12. (c , c)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 13. (b , b)
#     core type: ExprTuple
#     sub-expressions: 18, 18
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2 , 3 , 4)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. 4
#     core type: Literal
#     sub-expressions:
