# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Forall, InSet
from proveit.number import Add, Integers

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], InSet(Add(a, b), Integers), domain = Integers, conditions = []), conditions = [InSet(a, Integers)])
# Out:
# expr: a -> [forall_{b in Integers} ((a + b) in Integers)] | a in Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b in Integers} ((a + b) in Integers)] | a in Integers
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. forall_{b in Integers} ((a + b) in Integers)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> ((a + b) in Integers) | b in Integers
#    core type: Lambda
#    parameter: 18
#    body: 6
#    conditions: 7\n5. a in Integers
#    core type: Operation
#    operator: 12
#    operands: 8
# 6. (a + b) in Integers
#    core type: Operation
#    operator: 12
#    operands: 9
# 7. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 17, 16
# 9. (a + b , Integers)
#    core type: ExprTuple
#    sub-expressions: 11, 16
# 10. b in Integers
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. a + b
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 18, 16
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (a , b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. Integers
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
