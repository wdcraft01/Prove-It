# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import b, c
from proveit.number import Add, Mult, Neg, three, two

# %%
# build up the expression from sub-expressions
subExpr1 = Mult(three, b)
subExpr2 = Mult(two, b)
expr = ExprTuple(Add(two, b, c, subExpr1, subExpr2, Neg(b), c), Add(c, c, subExpr1, subExpr2, two))
# Out:
# expr: (2 + b + c + (3 * b) + (2 * b) - b + c , c + c + (3 * b) + (2 * b) + 2)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (2 + b + c + (3 * b) + (2 * b) - b + c , c + c + (3 * b) + (2 * b) + 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 + b + c + (3 * b) + (2 * b) - b + c
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. c + c + (3 * b) + (2 * b) + 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2 , b , c , 3 * b , 2 * b , -b , c)
#    core type: ExprTuple
#    sub-expressions: 15, 16, 7, 8, 9, 6, 7
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (c , c , 3 * b , 2 * b , 2)
#    core type: ExprTuple
#    sub-expressions: 7, 7, 8, 9, 15
# 6. -b
#    core type: Operation
#    operator: 10
#    operand: 16
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. 3 * b
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. 2 * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. (3 , b)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2 , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. 3
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
