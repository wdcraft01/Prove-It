# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], Equals(Add(a, b, Neg(a)), b), domain = Complexes, conditions = []), conditions = [InSet(a, Complexes)])
# Out:
# expr: a -> [forall_{b in Complexes} ((a + b - a) = b)] | a in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b in Complexes} ((a + b - a) = b)] | a in Complexes
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. forall_{b in Complexes} ((a + b - a) = b)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> ((a + b - a) = b) | b in Complexes
#    core type: Lambda
#    parameter: 18
#    body: 6
#    conditions: 7\n5. a in Complexes
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. (a + b - a) = b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 21, 17
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (a + b - a , b)
#     core type: ExprTuple
#     sub-expressions: 12, 18
# 11. b in Complexes
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. a + b - a
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a , b , -a)
#     core type: ExprTuple
#     sub-expressions: 21, 18, 19
# 17. Complexes
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. -a
#     core type: Operation
#     operator: 20
#     operand: 21
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
