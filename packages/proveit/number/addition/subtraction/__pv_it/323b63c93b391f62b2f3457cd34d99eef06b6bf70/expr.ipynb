# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([c], Equals(Add(Neg(a), Neg(b)), Neg(c)), domain = Complexes, conditions = [Equals(Add(a, b), c)])
# Out:
# expr: forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. c -> ((-a - b) = (-c)) | c in Complexes , (a + b) = c
#    core type: Lambda
#    parameter: 17
#    body: 3
#    conditions: 4\n3. (-a - b) = (-c)
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (c in Complexes , (a + b) = c)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (-a - b , -c)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. c in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (a + b) = c
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. -a - b
#    core type: Operation
#    operator: 20
#    operands: 14
# 9. -c
#    core type: Operation
#    operator: 22
#    operand: 17
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. (-a , -b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. Complexes
#     core type: Literal
#     sub-expressions:
# 16. a + b
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. -a
#     core type: Operation
#     operator: 22
#     operand: 23
# 19. -b
#     core type: Operation
#     operator: 22
#     operand: 24
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (a , b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
