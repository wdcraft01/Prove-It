# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([b], Equals(Add(Neg(a), a, b), b), domain = Complexes, conditions = [])
# Out:
# expr: forall_{b in Complexes} ((-a + a + b) = b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b in Complexes} ((-a + a + b) = b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. b -> ((-a + a + b) = b) | b in Complexes
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. (-a + a + b) = b
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (-a + a + b , b)
#    core type: ExprTuple
#    sub-expressions: 8, 15
# 7. b in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. -a + a + b
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (b , Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (-a , a , b)
#     core type: ExprTuple
#     sub-expressions: 14, 17, 15
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. -a
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
