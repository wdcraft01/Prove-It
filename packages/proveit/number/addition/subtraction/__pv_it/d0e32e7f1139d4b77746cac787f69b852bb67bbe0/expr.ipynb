# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], Equals(Add(Neg(a), Neg(b)), Neg(c)), domain = Complexes, conditions = [Equals(Add(a, b), c)]), conditions = [InSet(b, Complexes)])
# Out:
# expr: b -> [forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))] | b in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))] | b in Complexes
#    core type: Lambda
#    parameter: 28
#    body: 1
#    conditions: 2\n1. forall_{c in Complexes | (a + b) = c} ((-a - b) = (-c))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> ((-a - b) = (-c)) | c in Complexes , (a + b) = c
#    core type: Lambda
#    parameter: 21
#    body: 6
#    conditions: 7\n5. b in Complexes
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. (-a - b) = (-c)
#    core type: Operation
#    operator: 16
#    operands: 9
# 7. (c in Complexes , (a + b) = c)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 28, 19
# 9. (-a - b , -c)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. c in Complexes
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (a + b) = c
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. -a - b
#     core type: Operation
#     operator: 24
#     operands: 18
# 13. -c
#     core type: Operation
#     operator: 26
#     operand: 21
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (-a , -b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. Complexes
#     core type: Literal
#     sub-expressions:
# 20. a + b
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. -a
#     core type: Operation
#     operator: 26
#     operand: 27
# 23. -b
#     core type: Operation
#     operator: 26
#     operand: 28
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (a , b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
