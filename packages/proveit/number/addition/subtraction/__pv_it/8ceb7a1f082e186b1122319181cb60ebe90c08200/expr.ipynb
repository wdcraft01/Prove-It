# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.number.Add.html">Add</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b
from proveit.number import Add, Neg
from proveit.number._common_ import iter_a1l, iter_c1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = Add(iter_a1l, b, iter_c1m, Neg(b), iter_d1n)
# Out:
# expr: a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a_1   ...  + a_l + b + c_1   ...  + c_m - b + d_1   ...  + d_n
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (a_1 ,  ...  , a_l , b , c_1 ,  ...  , c_m , -b , d_1 ,  ...  , d_n)
#    core type: ExprTuple
#    sub-expressions: 3, 10, 4, 5, 6
# 3. a_1,...,a_l
#    core type: Iter
#    lambda_map: 7
#    start_index: 38
#    end_index: 36
# 4. c_1,...,c_m
#    core type: Iter
#    lambda_map: 8
#    start_index: 38
#    end_index: 37
# 5. -b
#    core type: Operation
#    operator: 9
#    operand: 10
# 6. d_1,...,d_n
#    core type: Iter
#    lambda_map: 11
#    start_index: 38
#    end_index: 39
# 7. _x_ -> a__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 30
#    body: 12
#    conditions: 13\n8. _x_ -> c__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 30
#    body: 14
#    conditions: 15\n9. -
#    core type: Literal
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. _x_ -> d__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 30
#     body: 16
#     conditions: 17\n12. a__x_
#     core type: Indexed
#     var: 18
#     index: 30
#     base: "1"
# 13. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 19
# 14. c__x_
#     core type: Indexed
#     var: 20
#     index: 30
#     base: "1"
# 15. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. d__x_
#     core type: Indexed
#     var: 22
#     index: 30
#     base: "1"
# 17. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 23
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. _x_ in {1...l}
#     core type: Operation
#     operator: 26
#     operands: 24
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. _x_ in {1...m}
#     core type: Operation
#     operator: 26
#     operands: 25
# 22. d
#     core type: Variable
#     sub-expressions:
# 23. _x_ in {1...n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 25. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 30, 29
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. {1...l}
#     core type: Operation
#     operator: 34
#     operands: 32
# 29. {1...m}
#     core type: Operation
#     operator: 34
#     operands: 33
# 30. _x_
#     core type: Variable
#     sub-expressions:
# 31. {1...n}
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 38, 36
# 33. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 38, 37
# 34. Interval
#     core type: Literal
#     sub-expressions:
# 35. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. l
#     core type: Variable
#     sub-expressions:
# 37. m
#     core type: Variable
#     sub-expressions:
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. n
#     core type: Variable
#     sub-expressions:
