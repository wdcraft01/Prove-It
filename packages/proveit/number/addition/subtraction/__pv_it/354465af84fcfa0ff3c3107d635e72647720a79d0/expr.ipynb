# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([b, c], Equals(Add(c, b), a), domain = Complexes, conditions = [Equals(Add(a, Neg(b)), c)])
# Out:
# expr: forall_{b, c in Complexes | (a - b) = c} ((c + b) = a)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c in Complexes | (a - b) = c} ((c + b) = a)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. b -> [forall_{c in Complexes | (a - b) = c} ((c + b) = a)] | b in Complexes
#    core type: Lambda
#    parameter: 27
#    body: 2
#    conditions: 3\n2. forall_{c in Complexes | (a - b) = c} ((c + b) = a)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. c -> ((c + b) = a) | c in Complexes , (a - b) = c
#    core type: Lambda
#    parameter: 21
#    body: 7
#    conditions: 8\n6. b in Complexes
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (c + b) = a
#    core type: Operation
#    operator: 16
#    operands: 10
# 8. (c in Complexes , (a - b) = c)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 27, 19
# 10. (c + b , a)
#     core type: ExprTuple
#     sub-expressions: 13, 24
# 11. c in Complexes
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (a - b) = c
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. c + b
#     core type: Operation
#     operator: 22
#     operands: 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (c , Complexes)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (a - b , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (c , b)
#     core type: ExprTuple
#     sub-expressions: 21, 27
# 19. Complexes
#     core type: Literal
#     sub-expressions:
# 20. a - b
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (a , -b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. -b
#     core type: Operation
#     operator: 26
#     operand: 27
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
