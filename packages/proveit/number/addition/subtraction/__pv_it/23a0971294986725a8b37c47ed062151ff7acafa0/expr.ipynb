# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#addCancelTriple_31">addCancelTriple_31</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.addition.subtraction._theorems_ import addCancelTriple_31

# %%
# check that the built expression is the same as the stored expression
# %check_expr addCancelTriple_31
# Out:
# Passed sanity check: built 'addCancelTriple_31' is the same as the stored Expression.

# %%
# display the expression information
addCancelTriple_31.exprInfo()
# Out:
# 0. forall_{a, b in Complexes} ((-a + b + a) = b)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Complexes} ((-a + b + a) = b)] | a in Complexes
#    core type: Lambda
#    parameter: 22
#    body: 2
#    conditions: 3\n2. forall_{b in Complexes} ((-a + b + a) = b)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((-a + b + a) = b) | b in Complexes
#    core type: Lambda
#    parameter: 20
#    body: 7
#    conditions: 8\n6. a in Complexes
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (-a + b + a) = b
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 22, 18
# 10. =
#     core type: Literal
#     sub-expressions:
# ...
