# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(c, Equals(Add(b, Neg(c)), Neg(a)), conditions = [InSet(c, Complexes), Equals(Add(a, b), c)])
# Out:
# expr: c -> ((b - c) = (-a)) | c in Complexes , (a + b) = c

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> ((b - c) = (-a)) | c in Complexes , (a + b) = c
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. (b - c) = (-a)
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (c in Complexes , (a + b) = c)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. (b - c , -a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. c in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. (a + b) = c
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. b - c
#    core type: Operation
#    operator: 16
#    operands: 12
# 7. -a
#    core type: Operation
#    operator: 18
#    operand: 20
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (c , Complexes)
#    core type: ExprTuple
#    sub-expressions: 19, 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 14, 19
# 12. (b , -c)
#     core type: ExprTuple
#     sub-expressions: 21, 15
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. a + b
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. -c
#     core type: Operation
#     operator: 18
#     operand: 19
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (a , b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
