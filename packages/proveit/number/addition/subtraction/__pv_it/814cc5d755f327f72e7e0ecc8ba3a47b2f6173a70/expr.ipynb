# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.addition.subtraction</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Equals(Add(a, Neg(a), b), b), conditions = [InSet(b, Complexes)])
# Out:
# expr: b -> ((a - a + b) = b) | b in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> ((a - a + b) = b) | b in Complexes
#    core type: Lambda
#    parameter: 13
#    body: 1
#    conditions: 2\n1. (a - a + b) = b
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a - a + b , b)
#    core type: ExprTuple
#    sub-expressions: 6, 13
# 5. b in Complexes
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. a - a + b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (a , -a , b)
#     core type: ExprTuple
#     sub-expressions: 15, 12, 13
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. -a
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
