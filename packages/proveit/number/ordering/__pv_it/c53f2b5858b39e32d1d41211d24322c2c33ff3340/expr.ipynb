# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Forall
from proveit.number import Add, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Forall([c], GreaterEq(Add(a, c), b), domain = Reals, conditions = [GreaterEq(c, zero)])
# Out:
# expr: forall_{c in Reals | c >= 0} ((a + c) >= b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c in Reals | c >= 0} ((a + c) >= b)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. c -> ((a + c) >= b) | c in Reals , c >= 0
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. (a + c) >= b
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (c in Reals , c >= 0)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a + c , b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. c in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. c >= 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. a + c
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 12. >=
#     core type: Literal
#     sub-expressions:
# 13. (c , 0)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (a , c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. Reals
#     core type: Literal
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
