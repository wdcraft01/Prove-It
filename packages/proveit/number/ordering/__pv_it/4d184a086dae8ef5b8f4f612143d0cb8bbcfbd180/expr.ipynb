# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Add, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c, d], LessEq(Add(a, c), Add(b, d)), domain = Reals, conditions = [LessEq(c, d)]), conditions = [InSet(b, Reals), LessEq(a, b)])
# Out:
# expr: b -> [forall_{c, d in Reals | c <= d} ((a + c) <= (b + d))] | b in Reals , a <= b

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c, d in Reals | c <= d} ((a + c) <= (b + d))] | b in Reals , a <= b
#    core type: Lambda
#    parameter: 31
#    body: 1
#    conditions: 2\n1. forall_{c, d in Reals | c <= d} ((a + c) <= (b + d))
#    core type: Operation
#    operator: 10
#    operand: 3
# 2. (b in Reals , a <= b)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. c -> [forall_{d in Reals | c <= d} ((a + c) <= (b + d))] | c in Reals
#    core type: Lambda
#    parameter: 30
#    body: 6
#    conditions: 7\n4. b in Reals
#    core type: Operation
#    operator: 21
#    operands: 8
# 5. a <= b
#    core type: Operation
#    operator: 23
#    operands: 9
# 6. forall_{d in Reals | c <= d} ((a + c) <= (b + d))
#    core type: Operation
#    operator: 10
#    operand: 11
# 7. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. (b , Reals)
#    core type: ExprTuple
#    sub-expressions: 31, 28
# 9. (a , b)
#    core type: ExprTuple
#    sub-expressions: 29, 31
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. d -> ((a + c) <= (b + d)) | d in Reals , c <= d
#     core type: Lambda
#     parameter: 32
#     body: 13
#     conditions: 14\n12. c in Reals
#     core type: Operation
#     operator: 21
#     operands: 15
# 13. (a + c) <= (b + d)
#     core type: Operation
#     operator: 23
#     operands: 16
# 14. (d in Reals , c <= d)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 16. (a + c , b + d)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. d in Reals
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. c <= d
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. a + c
#     core type: Operation
#     operator: 26
#     operands: 25
# 20. b + d
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 32, 28
# 23. <=
#     core type: Literal
#     sub-expressions:
# 24. (c , d)
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 25. (a , c)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (b , d)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. Reals
#     core type: Literal
#     sub-expressions:
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. c
#     core type: Variable
#     sub-expressions:
# 31. b
#     core type: Variable
#     sub-expressions:
# 32. d
#     core type: Variable
#     sub-expressions:
