# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import AA, B, CC, m, n
from proveit.logic import Booleans, Forall, Or
from proveit.number import Exp, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([m, n], Forall([AA, B, CC], Or(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, m), B, Iter(subExpr1, Indexed(CC, subExpr1, base = 1), one, n)), domains = [Exp(Booleans, m), Booleans, Exp(Booleans, n)], conditions = [B]), domain = Naturals, conditions = [])
# Out:
# expr: forall_{m, n in Naturals} [forall_{(A, B, C) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n} | B} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{(A, B, C) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n} | B} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)]
#    core type: Operation
#    operator: 20
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{(A, B, C) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n} | B} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)]] | m in Naturals
#    core type: Lambda
#    parameter: 58
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{(A, B, C) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n} | B} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{(A, B, C) in BOOLEANS^{m} * BOOLEANS * BOOLEANS^{n} | B} (A_1 or  ...  or A_m or B or C_1 or  ...  or C_n)] | n in Naturals
#    core type: Lambda
#    parameter: 60
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
# ...
