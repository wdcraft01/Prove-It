# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import i, n, x
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Iter(i, Indexed(x, i, base = 1), one, n), Indexed(x, Add(n, one), base = 1))
# Out:
# expr: (x_1 ,  ...  , x_n , x_(n + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1 ,  ...  , x_n , x_(n + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x_1,...,x_n
#    core type: Iter
#    lambda_map: 3
#    start_index: 17
#    end_index: 18
# 2. x_(n + 1)
#    core type: Indexed
#    var: 9
#    index: 4
#    base: "1"
# 3. i -> x_i | i in {1...n}
#    core type: Lambda
#    parameter: 13
#    body: 5
#    conditions: 6\n4. n + 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. x_i
#    core type: Indexed
#    var: 9
#    index: 13
#    base: "1"
# 6. (i in {1...n})
#    core type: ExprTuple
#    sub-expressions: 10
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (n , 1)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. i in {1...n}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (i , {1...n})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. {1...n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
