# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#lessAddRight">lessAddRight</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._theorems_ import lessAddRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr lessAddRight
# Out:
# Passed sanity check: built 'lessAddRight' is the same as the stored Expression.

# %%
# display the expression information
lessAddRight.exprInfo()
# Out:
# 0. forall_{a, b, c in Reals | a < b , 0 <= c} (a < (b + c))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b, c in Reals | a < b , 0 <= c} (a < (b + c))] | a in Reals
#    core type: Lambda
#    parameter: 21
#    body: 2
#    conditions: 3\n2. forall_{b, c in Reals | a < b , 0 <= c} (a < (b + c))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{c in Reals | 0 <= c} (a < (b + c))] | b in Reals , a < b
#    core type: Lambda
#    parameter: 31
#    body: 6
#    conditions: 7\n5. a in Reals
#    core type: Operation
#    operator: 23
#    operands: 8
# 6. forall_{c in Reals | 0 <= c} (a < (b + c))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Reals , a < b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 21, 29
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. c -> (a < (b + c)) | c in Reals , 0 <= c
#     core type: Lambda
#     parameter: 32
#     body: 13
#     conditions: 14\n11. b in Reals
#     core type: Operation
#     operator: 23
#     operands: 15
# 12. a < b
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. a < (b + c)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (c in Reals , 0 <= c)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 16. (a , b)
#     core type: ExprTuple
#     sub-expressions: 21, 31
# 17. <
#     core type: Literal
#     sub-expressions:
# 18. (a , b + c)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. c in Reals
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. 0 <= c
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. b + c
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 32, 29
# 25. <=
#     core type: Literal
#     sub-expressions:
# 26. (0 , c)
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (b , c)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. Reals
#     core type: Literal
#     sub-expressions:
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. b
#     core type: Variable
#     sub-expressions:
# 32. c
#     core type: Variable
#     sub-expressions:
