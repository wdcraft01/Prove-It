# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Forall
from proveit.number import Add, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Forall([b, c], LessEq(Add(c, a), Add(c, b)), domain = Reals, conditions = [LessEq(a, b)])
# Out:
# expr: forall_{b, c in Reals | a <= b} ((c + a) <= (c + b))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c in Reals | a <= b} ((c + a) <= (c + b))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. b -> [forall_{c in Reals} ((c + a) <= (c + b))] | b in Reals , a <= b
#    core type: Lambda
#    parameter: 25
#    body: 2
#    conditions: 3\n2. forall_{c in Reals} ((c + a) <= (c + b))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (b in Reals , a <= b)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. c -> ((c + a) <= (c + b)) | c in Reals
#    core type: Lambda
#    parameter: 24
#    body: 8
#    conditions: 9\n6. b in Reals
#    core type: Operation
#    operator: 17
#    operands: 10
# 7. a <= b
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. (c + a) <= (c + b)
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 14
# 10. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 11. (a , b)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 12. <=
#     core type: Literal
#     sub-expressions:
# 13. (c + a , c + b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. c in Reals
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. c + a
#     core type: Operation
#     operator: 20
#     operands: 19
# 16. c + b
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 19. (c , a)
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (c , b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Reals
#     core type: Literal
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
