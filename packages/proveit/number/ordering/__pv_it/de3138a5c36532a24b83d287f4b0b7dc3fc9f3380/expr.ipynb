# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(c, Equals(Add(c, Neg(b)), a), conditions = [InSet(c, Complexes), Equals(Add(a, b), c)])
# Out:
# expr: c -> ((c - b) = a) | c in Complexes , (a + b) = c

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> ((c - b) = a) | c in Complexes , (a + b) = c
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. (c - b) = a
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (c in Complexes , (a + b) = c)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. (c - b , a)
#    core type: ExprTuple
#    sub-expressions: 6, 19
# 4. c in Complexes
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (a + b) = c
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. c - b
#    core type: Operation
#    operator: 16
#    operands: 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (c , Complexes)
#    core type: ExprTuple
#    sub-expressions: 14, 12
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (c , -b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. a + b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. -b
#     core type: Operation
#     operator: 18
#     operand: 20
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (a , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
