# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Forall
from proveit.number import Greater, GreaterEq

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Forall([z], Greater(x, z), conditions = [GreaterEq(y, z)]), conditions = [Greater(x, y)])
# Out:
# expr: y -> [forall_{z | y >= z} (x > z)] | x > y

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> [forall_{z | y >= z} (x > z)] | x > y
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. forall_{z | y >= z} (x > z)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x > y)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. z -> (x > z) | y >= z
#    core type: Lambda
#    parameter: 16
#    body: 6
#    conditions: 7\n5. x > y
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. x > z
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (y >= z)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (x , y)
#    core type: ExprTuple
#    sub-expressions: 12, 15
# 9. >
#    core type: Literal
#    sub-expressions:
# 10. (x , z)
#     core type: ExprTuple
#     sub-expressions: 12, 16
# 11. y >= z
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. >=
#     core type: Literal
#     sub-expressions:
# 14. (y , z)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. y
#     core type: Variable
#     sub-expressions:
# 16. z
#     core type: Variable
#     sub-expressions:
