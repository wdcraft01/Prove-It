# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#relaxGreater">relaxGreater</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._theorems_ import relaxGreater

# %%
# check that the built expression is the same as the stored expression
# %check_expr relaxGreater
# Out:
# Passed sanity check: built 'relaxGreater' is the same as the stored Expression.

# %%
# display the expression information
relaxGreater.exprInfo()
# Out:
# 0. forall_{x, y | x > y} (x >= y)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. x -> [forall_{y | x > y} (x >= y)]
#    core type: Lambda
#    parameter: 11
#    body: 2
# 2. forall_{y | x > y} (x >= y)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> (x >= y) | x > y
#    core type: Lambda
#    parameter: 12
#    body: 5
#    conditions: 6\n5. x >= y
#    core type: Operation
#    operator: 7
#    operands: 10
# 6. (x > y)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. >=
#    core type: Literal
#    sub-expressions:
# 8. x > y
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. >
#    core type: Literal
#    sub-expressions:
# 10. (x , y)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. y
#     core type: Variable
#     sub-expressions:
