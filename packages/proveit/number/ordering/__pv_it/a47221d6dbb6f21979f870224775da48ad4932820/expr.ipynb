# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import v, w, x, y, z
from proveit.logic import InSet
from proveit.number import Reals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(v, Reals), InSet(w, Reals), InSet(x, Reals), InSet(y, Reals), InSet(z, Reals))
# Out:
# expr: (v in Reals , w in Reals , x in Reals , y in Reals , z in Reals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (v in Reals , w in Reals , x in Reals , y in Reals , z in Reals)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5
# 1. v in Reals
#    core type: Operation
#    operator: 10
#    operands: 6
# 2. w in Reals
#    core type: Operation
#    operator: 10
#    operands: 7
# 3. x in Reals
#    core type: Operation
#    operator: 10
#    operands: 8
# 4. y in Reals
#    core type: Operation
#    operator: 10
#    operands: 9
# 5. z in Reals
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. (v , Reals)
#    core type: ExprTuple
#    sub-expressions: 12, 17
# 7. (w , Reals)
#    core type: ExprTuple
#    sub-expressions: 13, 17
# 8. (x , Reals)
#    core type: ExprTuple
#    sub-expressions: 14, 17
# 9. (y , Reals)
#    core type: ExprTuple
#    sub-expressions: 15, 17
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (z , Reals)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. v
#     core type: Variable
#     sub-expressions:
# 13. w
#     core type: Variable
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. y
#     core type: Variable
#     sub-expressions:
# 16. z
#     core type: Variable
#     sub-expressions:
# 17. Reals
#     core type: Literal
#     sub-expressions:
