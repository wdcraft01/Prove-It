# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import InSet
from proveit.number import Add, Less, LessEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(c, Less(a, Add(b, c)), conditions = [InSet(c, Reals), LessEq(zero, c)])
# Out:
# expr: c -> (a < (b + c)) | c in Reals , 0 <= c

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> (a < (b + c)) | c in Reals , 0 <= c
#    core type: Lambda
#    parameter: 18
#    body: 1
#    conditions: 2\n1. a < (b + c)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (c in Reals , 0 <= c)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. <
#    core type: Literal
#    sub-expressions:
# 4. (a , b + c)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. c in Reals
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. 0 <= c
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b + c
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 18, 15
# 11. <=
#     core type: Literal
#     sub-expressions:
# 12. (0 , c)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (b , c)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Reals
#     core type: Literal
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
