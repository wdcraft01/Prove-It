# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Forall
from proveit.number import Add, Less, LessEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Forall([b, c], Less(Add(a, c), b), domain = Reals, conditions = [Less(a, b), LessEq(c, zero)])
# Out:
# expr: forall_{b, c in Reals | a < b , c <= 0} ((a + c) < b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c in Reals | a < b , c <= 0} ((a + c) < b)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. b -> [forall_{c in Reals | c <= 0} ((a + c) < b)] | b in Reals , a < b
#    core type: Lambda
#    parameter: 17
#    body: 2
#    conditions: 3\n2. forall_{c in Reals | c <= 0} ((a + c) < b)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (b in Reals , a < b)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. c -> ((a + c) < b) | c in Reals , c <= 0
#    core type: Lambda
#    parameter: 27
#    body: 8
#    conditions: 9\n6. b in Reals
#    core type: Operation
#    operator: 18
#    operands: 10
# 7. a < b
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. (a + c) < b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (c in Reals , c <= 0)
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 17, 24
# 11. (a , b)
#     core type: ExprTuple
#     sub-expressions: 26, 17
# 12. <
#     core type: Literal
#     sub-expressions:
# 13. (a + c , b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. c in Reals
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. c <= 0
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. a + c
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 27, 24
# 20. <=
#     core type: Literal
#     sub-expressions:
# 21. (c , 0)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (a , c)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. Reals
#     core type: Literal
#     sub-expressions:
# 25. 0
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. c
#     core type: Variable
#     sub-expressions:
