# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Add, Greater, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c, d], Greater(Add(a, c), Add(b, d)), domain = Reals, conditions = [GreaterEq(c, d)]), conditions = [InSet(b, Reals), Greater(a, b)])
# Out:
# expr: b -> [forall_{c, d in Reals | c >= d} ((a + c) > (b + d))] | b in Reals , a > b

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c, d in Reals | c >= d} ((a + c) > (b + d))] | b in Reals , a > b
#    core type: Lambda
#    parameter: 32
#    body: 1
#    conditions: 2\n1. forall_{c, d in Reals | c >= d} ((a + c) > (b + d))
#    core type: Operation
#    operator: 10
#    operand: 3
# 2. (b in Reals , a > b)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. c -> [forall_{d in Reals | c >= d} ((a + c) > (b + d))] | c in Reals
#    core type: Lambda
#    parameter: 31
#    body: 6
#    conditions: 7\n4. b in Reals
#    core type: Operation
#    operator: 22
#    operands: 8
# 5. a > b
#    core type: Operation
#    operator: 16
#    operands: 9
# 6. forall_{d in Reals | c >= d} ((a + c) > (b + d))
#    core type: Operation
#    operator: 10
#    operand: 11
# 7. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. (b , Reals)
#    core type: ExprTuple
#    sub-expressions: 32, 29
# 9. (a , b)
#    core type: ExprTuple
#    sub-expressions: 30, 32
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. d -> ((a + c) > (b + d)) | d in Reals , c >= d
#     core type: Lambda
#     parameter: 33
#     body: 13
#     conditions: 14\n12. c in Reals
#     core type: Operation
#     operator: 22
#     operands: 15
# 13. (a + c) > (b + d)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. (d in Reals , c >= d)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 16. >
#     core type: Literal
#     sub-expressions:
# 17. (a + c , b + d)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. d in Reals
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. c >= d
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. a + c
#     core type: Operation
#     operator: 27
#     operands: 26
# 21. b + d
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 33, 29
# 24. >=
#     core type: Literal
#     sub-expressions:
# 25. (c , d)
#     core type: ExprTuple
#     sub-expressions: 31, 33
# 26. (a , c)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (b , d)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. Reals
#     core type: Literal
#     sub-expressions:
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. c
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. d
#     core type: Variable
#     sub-expressions:
