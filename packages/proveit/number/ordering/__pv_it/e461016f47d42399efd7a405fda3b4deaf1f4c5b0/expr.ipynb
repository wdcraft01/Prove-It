# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#greaterEqAddLeft">greaterEqAddLeft</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._theorems_ import greaterEqAddLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr greaterEqAddLeft
# Out:
# Passed sanity check: built 'greaterEqAddLeft' is the same as the stored Expression.

# %%
# display the expression information
greaterEqAddLeft.exprInfo()
# Out:
# 0. forall_{a, b, c in Reals | a >= b , c >= 0} ((a + c) >= b)
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b, c in Reals | a >= b , c >= 0} ((a + c) >= b)] | a in Reals
#    core type: Lambda
#    parameter: 30
#    body: 2
#    conditions: 3\n2. forall_{b, c in Reals | a >= b , c >= 0} ((a + c) >= b)
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{c in Reals | c >= 0} ((a + c) >= b)] | b in Reals , a >= b
#    core type: Lambda
#    parameter: 21
#    body: 6
#    conditions: 7\n5. a in Reals
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. forall_{c in Reals | c >= 0} ((a + c) >= b)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Reals , a >= b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 30, 28
# 9. forall
#    core type: Literal
# ...
