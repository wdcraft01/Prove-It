# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y, z
from proveit.logic import Forall
from proveit.number import Less, LessEq

# %%
# build up the expression from sub-expressions
expr = Forall([y, z], Less(x, z), conditions = [Less(x, y), LessEq(y, z)])
# Out:
# expr: forall_{y, z | x < y , y <= z} (x < z)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y, z | x < y , y <= z} (x < z)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. y -> [forall_{z | y <= z} (x < z)] | x < y
#    core type: Lambda
#    parameter: 16
#    body: 2
#    conditions: 3\n2. forall_{z | y <= z} (x < z)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x < y)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. z -> (x < z) | y <= z
#    core type: Lambda
#    parameter: 17
#    body: 7
#    conditions: 8\n6. x < y
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. x < z
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (y <= z)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (x , y)
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 10. <
#     core type: Literal
#     sub-expressions:
# 11. (x , z)
#     core type: ExprTuple
#     sub-expressions: 13, 17
# 12. y <= z
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. (y , z)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. z
#     core type: Variable
#     sub-expressions:
