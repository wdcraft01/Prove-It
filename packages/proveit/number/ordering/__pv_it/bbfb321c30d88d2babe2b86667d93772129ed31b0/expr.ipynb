# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Forall
from proveit.number import GreaterEq

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y, z], GreaterEq(x, z), conditions = [GreaterEq(x, y), GreaterEq(y, z)]))
# Out:
# expr: x -> [forall_{y, z | x >= y , y >= z} (x >= z)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y, z | x >= y , y >= z} (x >= z)]
#    core type: Lambda
#    parameter: 13
#    body: 1
# 1. forall_{y, z | x >= y , y >= z} (x >= z)
#    core type: Operation
#    operator: 5
#    operand: 2
# 2. y -> [forall_{z | y >= z} (x >= z)] | x >= y
#    core type: Lambda
#    parameter: 16
#    body: 3
#    conditions: 4\n3. forall_{z | y >= z} (x >= z)
#    core type: Operation
#    operator: 5
#    operand: 6
# 4. (x >= y)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. z -> (x >= z) | y >= z
#    core type: Lambda
#    parameter: 17
#    body: 8
#    conditions: 9\n7. x >= y
#    core type: Operation
#    operator: 14
#    operands: 10
# 8. x >= z
#    core type: Operation
#    operator: 14
#    operands: 11
# 9. (y >= z)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. (x , y)
#     core type: ExprTuple
#     sub-expressions: 13, 16
# 11. (x , z)
#     core type: ExprTuple
#     sub-expressions: 13, 17
# 12. y >= z
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. >=
#     core type: Literal
#     sub-expressions:
# 15. (y , z)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. y
#     core type: Variable
#     sub-expressions:
# 17. z
#     core type: Variable
#     sub-expressions:
