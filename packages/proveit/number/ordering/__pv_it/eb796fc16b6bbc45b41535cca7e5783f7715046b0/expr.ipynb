# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d
from proveit.logic import InSet
from proveit.number import Add, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(d, GreaterEq(Add(a, c), Add(b, d)), conditions = [InSet(d, Reals), GreaterEq(c, d)])
# Out:
# expr: d -> ((a + c) >= (b + d)) | d in Reals , c >= d

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. d -> ((a + c) >= (b + d)) | d in Reals , c >= d
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. (a + c) >= (b + d)
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (d in Reals , c >= d)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. (a + c , b + d)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. d in Reals
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. c >= d
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. a + c
#    core type: Operation
#    operator: 13
#    operands: 12
# 7. b + d
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (d , Reals)
#    core type: ExprTuple
#    sub-expressions: 19, 15
# 10. >=
#     core type: Literal
#     sub-expressions:
# 11. (c , d)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 12. (a , c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (b , d)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. Reals
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. d
#     core type: Variable
#     sub-expressions:
