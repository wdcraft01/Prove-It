# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Add, Less, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(c, Forall([d], Less(Add(a, c), Add(b, d)), domain = Reals, conditions = [LessEq(c, d)]), conditions = [InSet(c, Reals)])
# Out:
# expr: c -> [forall_{d in Reals | c <= d} ((a + c) < (b + d))] | c in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> [forall_{d in Reals | c <= d} ((a + c) < (b + d))] | c in Reals
#    core type: Lambda
#    parameter: 24
#    body: 1
#    conditions: 2\n1. forall_{d in Reals | c <= d} ((a + c) < (b + d))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. d -> ((a + c) < (b + d)) | d in Reals , c <= d
#    core type: Lambda
#    parameter: 26
#    body: 6
#    conditions: 7\n5. c in Reals
#    core type: Operation
#    operator: 15
#    operands: 8
# 6. (a + c) < (b + d)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (d in Reals , c <= d)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (c , Reals)
#    core type: ExprTuple
#    sub-expressions: 24, 22
# 9. <
#    core type: Literal
#    sub-expressions:
# 10. (a + c , b + d)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. d in Reals
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. c <= d
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. a + c
#     core type: Operation
#     operator: 20
#     operands: 19
# 14. b + d
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 22
# 17. <=
#     core type: Literal
#     sub-expressions:
# 18. (c , d)
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 19. (a , c)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (b , d)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. Reals
#     core type: Literal
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
# 26. d
#     core type: Variable
#     sub-expressions:
