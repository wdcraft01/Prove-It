# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Add, LessEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b, c, d], LessEq(Add(a, c), Add(b, d)), domain = Reals, conditions = [LessEq(a, b), LessEq(c, d)]), conditions = [InSet(a, Reals)])
# Out:
# expr: a -> [forall_{b, c, d in Reals | a <= b , c <= d} ((a + c) <= (b + d))] | a in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b, c, d in Reals | a <= b , c <= d} ((a + c) <= (b + d))] | a in Reals
#    core type: Lambda
#    parameter: 34
#    body: 1
#    conditions: 2\n1. forall_{b, c, d in Reals | a <= b , c <= d} ((a + c) <= (b + d))
#    core type: Operation
#    operator: 15
#    operand: 3
# 2. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{c, d in Reals | c <= d} ((a + c) <= (b + d))] | b in Reals , a <= b
#    core type: Lambda
#    parameter: 36
#    body: 5
#    conditions: 6\n4. a in Reals
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. forall_{c, d in Reals | c <= d} ((a + c) <= (b + d))
#    core type: Operation
#    operator: 15
#    operand: 8
# 6. (b in Reals , a <= b)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 34, 33
# 8. c -> [forall_{d in Reals | c <= d} ((a + c) <= (b + d))] | c in Reals
#    core type: Lambda
#    parameter: 35
#    body: 11
#    conditions: 12\n9. b in Reals
#    core type: Operation
#    operator: 26
#    operands: 13
# 10. a <= b
#     core type: Operation
#     operator: 28
#     operands: 14
# 11. forall_{d in Reals | c <= d} ((a + c) <= (b + d))
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. (c in Reals)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 36, 33
# 14. (a , b)
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. d -> ((a + c) <= (b + d)) | d in Reals , c <= d
#     core type: Lambda
#     parameter: 37
#     body: 18
#     conditions: 19\n17. c in Reals
#     core type: Operation
#     operator: 26
#     operands: 20
# 18. (a + c) <= (b + d)
#     core type: Operation
#     operator: 28
#     operands: 21
# 19. (d in Reals , c <= d)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 35, 33
# 21. (a + c , b + d)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. d in Reals
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. c <= d
#     core type: Operation
#     operator: 28
#     operands: 29
# 24. a + c
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. b + d
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 37, 33
# 28. <=
#     core type: Literal
#     sub-expressions:
# 29. (c , d)
#     core type: ExprTuple
#     sub-expressions: 35, 37
# 30. (a , c)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. +
#     core type: Literal
#     sub-expressions:
# 32. (b , d)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 33. Reals
#     core type: Literal
#     sub-expressions:
# 34. a
#     core type: Variable
#     sub-expressions:
# 35. c
#     core type: Variable
#     sub-expressions:
# 36. b
#     core type: Variable
#     sub-expressions:
# 37. d
#     core type: Variable
#     sub-expressions:
