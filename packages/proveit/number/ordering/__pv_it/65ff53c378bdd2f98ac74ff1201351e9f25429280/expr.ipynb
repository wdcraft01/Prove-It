# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Forall, InSet
from proveit.number import Add, Less, Reals, RealsPos

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], Less(a, Add(a, b)), domain = RealsPos, conditions = []), conditions = [InSet(a, Reals)])
# Out:
# expr: a -> [forall_{b in RealsPos} (a < (a + b))] | a in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b in RealsPos} (a < (a + b))] | a in Reals
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. forall_{b in RealsPos} (a < (a + b))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> (a < (a + b)) | b in RealsPos
#    core type: Lambda
#    parameter: 20
#    body: 6
#    conditions: 7\n5. a in Reals
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. a < (a + b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (b in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 9. <
#    core type: Literal
#    sub-expressions:
# 10. (a , a + b)
#     core type: ExprTuple
#     sub-expressions: 19, 13
# 11. b in RealsPos
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. Reals
#     core type: Literal
#     sub-expressions:
# 13. a + b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b , RealsPos)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (a , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. RealsPos
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
