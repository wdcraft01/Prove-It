# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, a, b, c, d, e
from proveit.logic import InSet
from proveit.number import Exp, five

# %%
# build up the expression from sub-expressions
expr = Lambda(e, InSet([a, b, c, d, e], Exp(S, five)), conditions = [InSet(e, S)])
# Out:
# expr: e -> ((a , b , c , d , e) in S^{5}) | e in S

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. e -> ((a , b , c , d , e) in S^{5}) | e in S
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. (a , b , c , d , e) in S^{5}
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (e in S)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. ((a , b , c , d , e) , S^{5})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. e in S
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. (a , b , c , d , e)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 15
# 6. S^{5}
#    core type: Operation
#    operator: 13
#    operands: 14
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (e , S)
#    core type: ExprTuple
#    sub-expressions: 15, 16
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. d
#     core type: Variable
#     sub-expressions:
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (S , 5)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. S
#     core type: Variable
#     sub-expressions:
# 17. 5
#     core type: Literal
#     sub-expressions:
