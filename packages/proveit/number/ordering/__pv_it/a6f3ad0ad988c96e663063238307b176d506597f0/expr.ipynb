# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Add, Greater, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], Greater(Add(a, c), b), domain = Reals, conditions = [GreaterEq(c, zero)]), conditions = [InSet(b, Reals), Greater(a, b)])
# Out:
# expr: b -> [forall_{c in Reals | c >= 0} ((a + c) > b)] | b in Reals , a > b

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c in Reals | c >= 0} ((a + c) > b)] | b in Reals , a > b
#    core type: Lambda
#    parameter: 16
#    body: 1
#    conditions: 2\n1. forall_{c in Reals | c >= 0} ((a + c) > b)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in Reals , a > b)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> ((a + c) > b) | c in Reals , c >= 0
#    core type: Lambda
#    parameter: 26
#    body: 7
#    conditions: 8\n5. b in Reals
#    core type: Operation
#    operator: 17
#    operands: 9
# 6. a > b
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. (a + c) > b
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (c in Reals , c >= 0)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 9. (b , Reals)
#    core type: ExprTuple
#    sub-expressions: 16, 23
# 10. (a , b)
#     core type: ExprTuple
#     sub-expressions: 25, 16
# 11. >
#     core type: Literal
#     sub-expressions:
# 12. (a + c , b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. c in Reals
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. c >= 0
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. a + c
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 26, 23
# 19. >=
#     core type: Literal
#     sub-expressions:
# 20. (c , 0)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (a , c)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Reals
#     core type: Literal
#     sub-expressions:
# 24. 0
#     core type: Literal
#     sub-expressions:
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. c
#     core type: Variable
#     sub-expressions:
