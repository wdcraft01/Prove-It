# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Add, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b, c], GreaterEq(a, Add(b, c)), domain = Reals, conditions = [GreaterEq(a, b), GreaterEq(zero, c)]), conditions = [InSet(a, Reals)])
# Out:
# expr: a -> [forall_{b, c in Reals | a >= b , 0 >= c} (a >= (b + c))] | a in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b, c in Reals | a >= b , 0 >= c} (a >= (b + c))] | a in Reals
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. forall_{b, c in Reals | a >= b , 0 >= c} (a >= (b + c))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{c in Reals | 0 >= c} (a >= (b + c))] | b in Reals , a >= b
#    core type: Lambda
#    parameter: 29
#    body: 5
#    conditions: 6\n4. a in Reals
#    core type: Operation
#    operator: 21
#    operands: 7
# 5. forall_{c in Reals | 0 >= c} (a >= (b + c))
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (b in Reals , a >= b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 19, 27
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. c -> (a >= (b + c)) | c in Reals , 0 >= c
#    core type: Lambda
#    parameter: 30
#    body: 12
#    conditions: 13\n10. b in Reals
#     core type: Operation
#     operator: 21
#     operands: 14
# 11. a >= b
#     core type: Operation
#     operator: 23
#     operands: 15
# 12. a >= (b + c)
#     core type: Operation
#     operator: 23
#     operands: 16
# 13. (c in Reals , 0 >= c)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 29, 27
# 15. (a , b)
#     core type: ExprTuple
#     sub-expressions: 19, 29
# 16. (a , b + c)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. c in Reals
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. 0 >= c
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b + c
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 30, 27
# 23. >=
#     core type: Literal
#     sub-expressions:
# 24. (0 , c)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (b , c)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. Reals
#     core type: Literal
#     sub-expressions:
# 28. 0
#     core type: Literal
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. c
#     core type: Variable
#     sub-expressions:
