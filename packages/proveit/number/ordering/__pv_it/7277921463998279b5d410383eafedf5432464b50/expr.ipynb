# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d
from proveit.logic import Forall
from proveit.number import Add, Greater, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Forall([d], Greater(Add(a, c), Add(b, d)), domain = Reals, conditions = [GreaterEq(c, d)])
# Out:
# expr: forall_{d in Reals | c >= d} ((a + c) > (b + d))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{d in Reals | c >= d} ((a + c) > (b + d))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. d -> ((a + c) > (b + d)) | d in Reals , c >= d
#    core type: Lambda
#    parameter: 22
#    body: 3
#    conditions: 4\n3. (a + c) > (b + d)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (d in Reals , c >= d)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. >
#    core type: Literal
#    sub-expressions:
# 6. (a + c , b + d)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. d in Reals
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. c >= d
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. a + c
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. b + d
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 22, 18
# 13. >=
#     core type: Literal
#     sub-expressions:
# 14. (c , d)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 15. (a , c)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (b , d)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. Reals
#     core type: Literal
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. d
#     core type: Variable
#     sub-expressions:
