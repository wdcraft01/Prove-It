# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, x
from proveit.logic import Equals, Forall, InSet
from proveit.number import Exp, Len, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([S], InSet(x, Exp(S, zero)), conditions = []), conditions = [Equals(Len(x), zero)])
# Out:
# expr: x -> [forall_{S} (x in S^{0})] | |x| = 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{S} (x in S^{0})] | |x| = 0
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. forall_{S} (x in S^{0})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (|x| = 0)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. S -> (x in S^{0})
#    core type: Lambda
#    parameter: 17
#    body: 6
# 5. |x| = 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in S^{0}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|x| , 0)
#    core type: ExprTuple
#    sub-expressions: 11, 18
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , S^{0})
#     core type: ExprTuple
#     sub-expressions: 14, 12
# 11. |x|
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. S^{0}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. length
#     core type: Literal
#     sub-expressions:
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (S , 0)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. S
#     core type: Variable
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
