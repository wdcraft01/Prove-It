# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P, Px, Py, x, y
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Forall([x, y], Px, conditions = [Py, Equals(x, y)]))
# Out:
# expr: P -> [forall_{x, y | P(y) , x = y} P(x)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> [forall_{x, y | P(y) , x = y} P(x)]
#    core type: Lambda
#    parameter: 10
#    body: 1
# 1. forall_{x, y | P(y) , x = y} P(x)
#    core type: Operation
#    operator: 4
#    operand: 2
# 2. x -> [forall_{y | P(y) , x = y} P(x)]
#    core type: Lambda
#    parameter: 13
#    body: 3
# 3. forall_{y | P(y) , x = y} P(x)
#    core type: Operation
#    operator: 4
#    operand: 5
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. y -> P(x) | P(y) , x = y
#    core type: Lambda
#    parameter: 14
#    body: 6
#    conditions: 7\n6. P(x)
#    core type: Operation
#    operator: 10
#    operand: 13
# 7. (P(y) , x = y)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. P(y)
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. x = y
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. y
#     core type: Variable
#     sub-expressions:
