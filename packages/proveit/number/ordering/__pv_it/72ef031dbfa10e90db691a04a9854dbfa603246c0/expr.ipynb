# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import l, x, yy
from proveit.logic import InSet, Set
from proveit.number import one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = InSet(x, Set(Iter(subExpr1, Indexed(yy, subExpr1, base = 1), one, l)))
# Out:
# expr: x in {y_1 ,  ...  , y_l}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x in {y_1 ,  ...  , y_l}
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. (x , {y_1 ,  ...  , y_l})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. x
#    core type: Variable
#    sub-expressions:
# 3. {y_1 ,  ...  , y_l}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. Set
#    core type: Literal
#    sub-expressions:
# 5. (y_1 ,  ...  , y_l)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. y_1,...,y_l
#    core type: Iter
#    lambda_map: 7
#    start_index: 18
#    end_index: 19
# 7. _x_ -> y__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 14
#    body: 8
#    conditions: 9\n8. y__x_
#    core type: Indexed
#    var: 10
#    index: 14
#    base: "1"
# 9. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. y
#     core type: Variable
#     sub-expressions:
# 11. _x_ in {1...l}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. _x_
#     core type: Variable
#     sub-expressions:
# 15. {1...l}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. l
#     core type: Variable
#     sub-expressions:
