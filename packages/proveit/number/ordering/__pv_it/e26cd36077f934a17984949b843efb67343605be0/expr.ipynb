# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#lessAddBoth">lessAddBoth</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._theorems_ import lessAddBoth

# %%
# check that the built expression is the same as the stored expression
# %check_expr lessAddBoth
# Out:
# Passed sanity check: built 'lessAddBoth' is the same as the stored Expression.

# %%
# display the expression information
lessAddBoth.exprInfo()
# Out:
# 0. forall_{a, b, c, d in Reals | a < b , c <= d} ((a + c) < (b + d))
#    core type: Operation
#    operator: 16
#    operand: 1
# 1. a -> [forall_{b, c, d in Reals | a < b , c <= d} ((a + c) < (b + d))] | a in Reals
#    core type: Lambda
#    parameter: 36
#    body: 2
#    conditions: 3\n2. forall_{b, c, d in Reals | a < b , c <= d} ((a + c) < (b + d))
#    core type: Operation
#    operator: 16
#    operand: 4
# 3. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{c, d in Reals | c <= d} ((a + c) < (b + d))] | b in Reals , a < b
#    core type: Lambda
#    parameter: 38
#    body: 6
#    conditions: 7\n5. a in Reals
#    core type: Operation
#    operator: 28
#    operands: 8
# 6. forall_{c, d in Reals | c <= d} ((a + c) < (b + d))
#    core type: Operation
#    operator: 16
#    operand: 9
# 7. (b in Reals , a < b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 36, 35
# ...
