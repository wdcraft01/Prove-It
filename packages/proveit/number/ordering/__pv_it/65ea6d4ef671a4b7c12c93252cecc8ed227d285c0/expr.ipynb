# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Forall
from proveit.number import Add, Greater, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Forall([c], Greater(a, Add(b, c)), domain = Reals, conditions = [GreaterEq(zero, c)])
# Out:
# expr: forall_{c in Reals | 0 >= c} (a > (b + c))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c in Reals | 0 >= c} (a > (b + c))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. c -> (a > (b + c)) | c in Reals , 0 >= c
#    core type: Lambda
#    parameter: 20
#    body: 3
#    conditions: 4\n3. a > (b + c)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (c in Reals , 0 >= c)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. >
#    core type: Literal
#    sub-expressions:
# 6. (a , b + c)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. c in Reals
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. 0 >= c
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b + c
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 13. >=
#     core type: Literal
#     sub-expressions:
# 14. (0 , c)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (b , c)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. Reals
#     core type: Literal
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
