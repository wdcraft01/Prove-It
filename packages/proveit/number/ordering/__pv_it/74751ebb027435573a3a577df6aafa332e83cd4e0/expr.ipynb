# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#transitivityLessLess">transitivityLessLess</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._axioms_ import transitivityLessLess

# %%
# check that the built expression is the same as the stored expression
# %check_expr transitivityLessLess
# Out:
# Passed sanity check: built 'transitivityLessLess' is the same as the stored Expression.

# %%
# display the expression information
transitivityLessLess.exprInfo()
# Out:
# 0. forall_{x, y, z | x < y , y < z} (x < z)
#    core type: Operation
#    operator: 6
#    operand: 1
# 1. x -> [forall_{y, z | x < y , y < z} (x < z)]
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. forall_{y, z | x < y , y < z} (x < z)
#    core type: Operation
#    operator: 6
#    operand: 3
# 3. y -> [forall_{z | y < z} (x < z)] | x < y
#    core type: Lambda
#    parameter: 17
#    body: 4
#    conditions: 5\n4. forall_{z | y < z} (x < z)
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. (x < y)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. z -> (x < z) | y < z
#    core type: Lambda
#    parameter: 18
#    body: 9
#    conditions: 10\n8. x < y
#    core type: Operation
#    operator: 15
#    operands: 11
# 9. x < z
#    core type: Operation
#    operator: 15
#    operands: 12
# 10. (y < z)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (x , y)
#     core type: ExprTuple
# ...
