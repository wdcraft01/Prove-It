# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, InSet, Or
from proveit.number import Greater, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Or(Greater(x, y), Equals(x, y)), domain = Reals, conditions = [GreaterEq(x, y)]), conditions = [InSet(x, Reals)])
# Out:
# expr: x -> [forall_{y in Reals | x >= y} ((x > y) or (x = y))] | x in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y in Reals | x >= y} ((x > y) or (x = y))] | x in Reals
#    core type: Lambda
#    parameter: 22
#    body: 1
#    conditions: 2\n1. forall_{y in Reals | x >= y} ((x > y) or (x = y))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((x > y) or (x = y)) | y in Reals , x >= y
#    core type: Lambda
#    parameter: 23
#    body: 6
#    conditions: 7\n5. x in Reals
#    core type: Operation
#    operator: 15
#    operands: 8
# 6. (x > y) or (x = y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (y in Reals , x >= y)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (x , Reals)
#    core type: ExprTuple
#    sub-expressions: 22, 21
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (x > y , x = y)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. y in Reals
# ...
