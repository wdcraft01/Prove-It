# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Add, Greater, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b, c], Greater(Add(c, a), Add(c, b)), domain = Reals, conditions = [Greater(a, b)]), conditions = [InSet(a, Reals)])
# Out:
# expr: a -> [forall_{b, c in Reals | a > b} ((c + a) > (c + b))] | a in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b, c in Reals | a > b} ((c + a) > (c + b))] | a in Reals
#    core type: Lambda
#    parameter: 27
#    body: 1
#    conditions: 2\n1. forall_{b, c in Reals | a > b} ((c + a) > (c + b))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{c in Reals} ((c + a) > (c + b))] | b in Reals , a > b
#    core type: Lambda
#    parameter: 29
#    body: 5
#    conditions: 6\n4. a in Reals
#    core type: Operation
#    operator: 21
#    operands: 7
# 5. forall_{c in Reals} ((c + a) > (c + b))
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (b in Reals , a > b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 27, 26
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. c -> ((c + a) > (c + b)) | c in Reals
#    core type: Lambda
#    parameter: 28
#    body: 12
#    conditions: 13\n10. b in Reals
#     core type: Operation
#     operator: 21
#     operands: 14
# 11. a > b
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. (c + a) > (c + b)
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (c in Reals)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 29, 26
# 15. (a , b)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 16. >
#     core type: Literal
#     sub-expressions:
# 17. (c + a , c + b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. c in Reals
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. c + a
#     core type: Operation
#     operator: 24
#     operands: 23
# 20. c + b
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 23. (c , a)
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (c , b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. Reals
#     core type: Literal
#     sub-expressions:
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
