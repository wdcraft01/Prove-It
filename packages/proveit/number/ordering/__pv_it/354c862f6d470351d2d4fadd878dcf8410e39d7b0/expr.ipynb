# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d
from proveit.logic import Forall, InSet
from proveit.number import Add, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(c, Forall([d], GreaterEq(Add(a, c), Add(b, d)), domain = Reals, conditions = [GreaterEq(c, d)]), conditions = [InSet(c, Reals)])
# Out:
# expr: c -> [forall_{d in Reals | c >= d} ((a + c) >= (b + d))] | c in Reals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. c -> [forall_{d in Reals | c >= d} ((a + c) >= (b + d))] | c in Reals
#    core type: Lambda
#    parameter: 23
#    body: 1
#    conditions: 2\n1. forall_{d in Reals | c >= d} ((a + c) >= (b + d))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. d -> ((a + c) >= (b + d)) | d in Reals , c >= d
#    core type: Lambda
#    parameter: 25
#    body: 6
#    conditions: 7\n5. c in Reals
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. (a + c) >= (b + d)
#    core type: Operation
#    operator: 16
#    operands: 9
# 7. (d in Reals , c >= d)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (c , Reals)
#    core type: ExprTuple
#    sub-expressions: 23, 21
# 9. (a + c , b + d)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. d in Reals
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. c >= d
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. a + c
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. b + d
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (d , Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 16. >=
#     core type: Literal
#     sub-expressions:
# 17. (c , d)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 18. (a , c)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (b , d)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. c
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. d
#     core type: Variable
#     sub-expressions:
