# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Operation
from proveit._common_ import i, n, rho, x
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Iter(i, Operation(Indexed(rho, i, base = 1), [Indexed(x, i, base = 1), Indexed(x, Add(i, one), base = 1)]), one, n))
# Out:
# expr: (x_1 rho_1 x_(1 + 1) ,  ...  , x_n rho_n x_(n + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1 rho_1 x_(1 + 1) ,  ...  , x_n rho_n x_(n + 1))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_1 rho_1 x_(1 + 1)),...,(x_n rho_n x_(n + 1))
#    core type: Iter
#    lambda_map: 2
#    start_index: 21
#    end_index: 22
# 2. i -> (x_i rho_i x_(i + 1)) | i in {1...n}
#    core type: Lambda
#    parameter: 20
#    body: 3
#    conditions: 4\n3. x_i rho_i x_(i + 1)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (i in {1...n})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. rho_i
#    core type: Indexed
#    var: 8
#    index: 20
#    base: "1"
# 6. (x_i , x_(i + 1))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. i in {1...n}
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. rho
#    core type: Variable
#    sub-expressions:
# 9. x_i
#    core type: Indexed
#    var: 13
#    index: 20
#    base: "1"
# 10. x_(i + 1)
#     core type: Indexed
#     var: 13
#     index: 14
#     base: "1"
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (i , {1...n})
#     core type: ExprTuple
#     sub-expressions: 20, 15
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. i + 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. {1...n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (i , 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. i
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
