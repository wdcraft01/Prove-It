# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#greaterSequenceDef">greaterSequenceDef</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._axioms_ import greaterSequenceDef

# %%
# check that the built expression is the same as the stored expression
# %check_expr greaterSequenceDef
# Out:
# Passed sanity check: built 'greaterSequenceDef' is the same as the stored Expression.

# %%
# display the expression information
greaterSequenceDef.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{(x, rho) in Reals^{n + 1} * {> , >= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. n -> [forall_{(x, rho) in Reals^{n + 1} * {> , >= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))] | n in NaturalsPos
#    core type: Lambda
#    parameter: 65
#    body: 2
#    conditions: 3\n2. forall_{(x, rho) in Reals^{n + 1} * {> , >= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (n in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. x -> [forall_{rho in {> , >= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))] | x in Reals^{n + 1}
#    core type: Lambda
#    parameter: 56
#    body: 6
#    conditions: 7\n5. n in NaturalsPos
#    core type: Operation
#    operator: 54
#    operands: 8
# 6. forall_{rho in {> , >= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (x in Reals^{n + 1})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (n , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 65, 12
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. rho -> ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1)))) | rho in {> , >= , =}^{n}
#     core type: Lambda
#     parameter: 51
#     body: 13
#     conditions: 14\n11. x in Reals^{n + 1}
#     core type: Operation
#     operator: 54
#     operands: 15
# 12. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 13. (x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1)))
#     core type: Operation
#     operator: 50
#     operands: 16
# 14. (rho in {> , >= , =}^{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (x , Reals^{n + 1})
#     core type: ExprTuple
#     sub-expressions: 56, 18
# 16. (x_1 rho_1  ...   x_n rho_n x_(n + 1) , (x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1)))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. rho in {> , >= , =}^{n}
#     core type: Operation
#     operator: 54
#     operands: 21
# 18. Reals^{n + 1}
#     core type: Operation
#     operator: 33
#     operands: 22
# 19. x_1 rho_1  ...   x_n rho_n x_(n + 1)
#     core type: Operation
#     operators: 23
#     operands: 24
# 20. (x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. (rho , {> , >= , =}^{n})
#     core type: ExprTuple
#     sub-expressions: 51, 27
# 22. (Reals , n + 1)
#     core type: ExprTuple
#     sub-expressions: 28, 37
# 23. (rho_1 ,  ...  , rho_n)
#     core type: ExprTuple
#     sub-expressions: 29
# 24. (x_1 ,  ...  , x_n , x_(n + 1))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. (x_1 rho_1 x_(1 + 1) ,  ...  , x_n rho_n x_(n + 1))
#     core type: ExprTuple
#     sub-expressions: 32
# 27. {> , >= , =}^{n}
#     core type: Operation
#     operator: 33
#     operands: 34
# 28. Reals
#     core type: Literal
#     sub-expressions:
# 29. rho_1,...,rho_n
#     core type: Iter
#     lambda_map: 35
#     start_index: 64
#     end_index: 65
# 30. x_1,...,x_n
#     core type: Iter
#     lambda_map: 36
#     start_index: 64
#     end_index: 65
# 31. x_(n + 1)
#     core type: Indexed
#     var: 56
#     index: 37
#     base: "1"
# 32. (x_1 rho_1 x_(1 + 1)),...,(x_n rho_n x_(n + 1))
#     core type: Iter
#     lambda_map: 38
#     start_index: 64
#     end_index: 65
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. ({> , >= , =} , n)
#     core type: ExprTuple
#     sub-expressions: 39, 65
# 35. i -> rho_i | i in {1...n}
#     core type: Lambda
#     parameter: 63
#     body: 45
#     conditions: 42\n36. i -> x_i | i in {1...n}
#     core type: Lambda
#     parameter: 63
#     body: 52
#     conditions: 42\n37. n + 1
#     core type: Operation
#     operator: 59
#     operands: 40
# 38. i -> (x_i rho_i x_(i + 1)) | i in {1...n}
#     core type: Lambda
#     parameter: 63
#     body: 41
#     conditions: 42\n39. {> , >= , =}
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (n , 1)
#     core type: ExprTuple
#     sub-expressions: 65, 64
# 41. x_i rho_i x_(i + 1)
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. (i in {1...n})
#     core type: ExprTuple
#     sub-expressions: 47
# 43. Set
#     core type: Literal
#     sub-expressions:
# 44. (> , >= , =)
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50
# 45. rho_i
#     core type: Indexed
#     var: 51
#     index: 63
#     base: "1"
# 46. (x_i , x_(i + 1))
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 47. i in {1...n}
#     core type: Operation
#     operator: 54
#     operands: 55
# 48. >
#     core type: Literal
#     sub-expressions:
# 49. >=
#     core type: Literal
#     sub-expressions:
# 50. =
#     core type: Literal
#     sub-expressions:
# 51. rho
#     core type: Variable
#     sub-expressions:
# 52. x_i
#     core type: Indexed
#     var: 56
#     index: 63
#     base: "1"
# 53. x_(i + 1)
#     core type: Indexed
#     var: 56
#     index: 57
#     base: "1"
# 54. in
#     core type: Literal
#     sub-expressions:
# 55. (i , {1...n})
#     core type: ExprTuple
#     sub-expressions: 63, 58
# 56. x
#     core type: Variable
#     sub-expressions:
# 57. i + 1
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. {1...n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 59. +
#     core type: Literal
#     sub-expressions:
# 60. (i , 1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. Interval
#     core type: Literal
#     sub-expressions:
# 62. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 63. i
#     core type: Variable
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. n
#     core type: Variable
#     sub-expressions:
