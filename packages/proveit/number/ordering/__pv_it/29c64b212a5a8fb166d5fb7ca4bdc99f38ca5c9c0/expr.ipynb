# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#lessShiftAddLeft">lessShiftAddLeft</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.ordering._theorems_ import lessShiftAddLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr lessShiftAddLeft
# Out:
# Passed sanity check: built 'lessShiftAddLeft' is the same as the stored Expression.

# %%
# display the expression information
lessShiftAddLeft.exprInfo()
# Out:
# 0. forall_{a, b, c in Reals | a < b} ((c + a) < (c + b))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b, c in Reals | a < b} ((c + a) < (c + b))] | a in Reals
#    core type: Lambda
#    parameter: 28
#    body: 2
#    conditions: 3\n2. forall_{b, c in Reals | a < b} ((c + a) < (c + b))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Reals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{c in Reals} ((c + a) < (c + b))] | b in Reals , a < b
#    core type: Lambda
#    parameter: 30
#    body: 6
#    conditions: 7\n5. a in Reals
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. forall_{c in Reals} ((c + a) < (c + b))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Reals , a < b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 8. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 28, 27
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. c -> ((c + a) < (c + b)) | c in Reals
#     core type: Lambda
#     parameter: 29
#     body: 13
#     conditions: 14\n11. b in Reals
#     core type: Operation
#     operator: 22
#     operands: 15
# 12. a < b
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. (c + a) < (c + b)
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (c in Reals)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. (b , Reals)
#     core type: ExprTuple
#     sub-expressions: 30, 27
# 16. (a , b)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 17. <
#     core type: Literal
#     sub-expressions:
# 18. (c + a , c + b)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. c in Reals
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. c + a
#     core type: Operation
#     operator: 25
#     operands: 24
# 21. c + b
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 29, 27
# 24. (c , a)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (c , b)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. Reals
#     core type: Literal
#     sub-expressions:
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. c
#     core type: Variable
#     sub-expressions:
# 30. b
#     core type: Variable
#     sub-expressions:
