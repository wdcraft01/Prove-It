# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Operation, OperationSequence
from proveit._common_ import i, n, rho, x
from proveit.logic import And
from proveit.number import Add, one

# %%
# build up the expression from sub-expressions
subExpr1 = Indexed(rho, i, base = 1)
subExpr2 = Indexed(x, i, base = 1)
expr = ExprTuple(OperationSequence([Iter(i, subExpr1, one, n)], [Iter(i, subExpr2, one, n), Indexed(x, Add(n, one), base = 1)]), And(Iter(i, Operation(subExpr1, [subExpr2, Indexed(x, Add(i, one), base = 1)]), one, n)))
# Out:
# expr: (x_1 rho_1  ...   x_n rho_n x_(n + 1) , (x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (x_1 rho_1  ...   x_n rho_n x_(n + 1) , (x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x_1 rho_1  ...   x_n rho_n x_(n + 1)
#    core type: Operation
#    operators: 3
#    operands: 4
# 2. (x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. (rho_1 ,  ...  , rho_n)
#    core type: ExprTuple
#    sub-expressions: 7
# 4. (x_1 ,  ...  , x_n , x_(n + 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x_1 rho_1 x_(1 + 1) ,  ...  , x_n rho_n x_(n + 1))
#    core type: ExprTuple
#    sub-expressions: 10
# 7. rho_1,...,rho_n
#    core type: Iter
#    lambda_map: 11
#    start_index: 34
#    end_index: 35
# 8. x_1,...,x_n
#    core type: Iter
#    lambda_map: 12
#    start_index: 34
#    end_index: 35
# 9. x_(n + 1)
#    core type: Indexed
#    var: 26
#    index: 13
#    base: "1"
# ...
