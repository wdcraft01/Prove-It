# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Add, GreaterEq, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], GreaterEq(a, Add(b, c)), domain = Reals, conditions = [GreaterEq(zero, c)]), conditions = [InSet(b, Reals), GreaterEq(a, b)])
# Out:
# expr: b -> [forall_{c in Reals | 0 >= c} (a >= (b + c))] | b in Reals , a >= b

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c in Reals | 0 >= c} (a >= (b + c))] | b in Reals , a >= b
#    core type: Lambda
#    parameter: 24
#    body: 1
#    conditions: 2\n1. forall_{c in Reals | 0 >= c} (a >= (b + c))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in Reals , a >= b)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> (a >= (b + c)) | c in Reals , 0 >= c
#    core type: Lambda
#    parameter: 25
#    body: 7
#    conditions: 8\n5. b in Reals
#    core type: Operation
#    operator: 16
#    operands: 9
# 6. a >= b
#    core type: Operation
#    operator: 18
#    operands: 10
# 7. a >= (b + c)
#    core type: Operation
#    operator: 18
#    operands: 11
# 8. (c in Reals , 0 >= c)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (b , Reals)
#    core type: ExprTuple
#    sub-expressions: 24, 22
# 10. (a , b)
#     core type: ExprTuple
#     sub-expressions: 14, 24
# 11. (a , b + c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. c in Reals
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. 0 >= c
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b + c
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 18. >=
#     core type: Literal
#     sub-expressions:
# 19. (0 , c)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (b , c)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. Reals
#     core type: Literal
#     sub-expressions:
# 23. 0
#     core type: Literal
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
