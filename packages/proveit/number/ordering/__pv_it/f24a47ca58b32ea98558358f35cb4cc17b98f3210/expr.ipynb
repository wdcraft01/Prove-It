# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, Or
from proveit.number import Greater, GreaterEq, Reals

# %%
# build up the expression from sub-expressions
expr = Forall([y], Or(Greater(x, y), Equals(x, y)), domain = Reals, conditions = [GreaterEq(x, y)])
# Out:
# expr: forall_{y in Reals | x >= y} ((x > y) or (x = y))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in Reals | x >= y} ((x > y) or (x = y))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> ((x > y) or (x = y)) | y in Reals , x >= y
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. (x > y) or (x = y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (y in Reals , x >= y)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x > y , x = y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. y in Reals
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. x >= y
#    core type: Operation
#    operator: 13
#    operands: 16
# 9. x > y
#    core type: Operation
#    operator: 14
#    operands: 16
# 10. x = y
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (y , Reals)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 13. >=
#     core type: Literal
#     sub-expressions:
# 14. >
#     core type: Literal
#     sub-expressions:
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (x , y)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Reals
#     core type: Literal
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
