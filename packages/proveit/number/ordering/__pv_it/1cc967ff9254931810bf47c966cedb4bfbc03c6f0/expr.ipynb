# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Forall
from proveit.number import Greater

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Forall([z], Greater(x, z), conditions = [Greater(y, z)]), conditions = [Greater(x, y)])
# Out:
# expr: y -> [forall_{z | y > z} (x > z)] | x > y

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> [forall_{z | y > z} (x > z)] | x > y
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. forall_{z | y > z} (x > z)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x > y)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. z -> (x > z) | y > z
#    core type: Lambda
#    parameter: 15
#    body: 6
#    conditions: 7\n5. x > y
#    core type: Operation
#    operator: 12
#    operands: 8
# 6. x > z
#    core type: Operation
#    operator: 12
#    operands: 9
# 7. (y > z)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (x , y)
#    core type: ExprTuple
#    sub-expressions: 11, 14
# 9. (x , z)
#    core type: ExprTuple
#    sub-expressions: 11, 15
# 10. y > z
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. >
#     core type: Literal
#     sub-expressions:
# 13. (y , z)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. y
#     core type: Variable
#     sub-expressions:
# 15. z
#     core type: Variable
#     sub-expressions:
