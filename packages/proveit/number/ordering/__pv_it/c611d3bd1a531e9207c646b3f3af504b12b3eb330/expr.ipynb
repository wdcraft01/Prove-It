# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Forall, InSet
from proveit.number import Add, Less, Reals

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], Less(Add(c, a), Add(c, b)), domain = Reals, conditions = []), conditions = [InSet(b, Reals), Less(a, b)])
# Out:
# expr: b -> [forall_{c in Reals} ((c + a) < (c + b))] | b in Reals , a < b

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c in Reals} ((c + a) < (c + b))] | b in Reals , a < b
#    core type: Lambda
#    parameter: 24
#    body: 1
#    conditions: 2\n1. forall_{c in Reals} ((c + a) < (c + b))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in Reals , a < b)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. c -> ((c + a) < (c + b)) | c in Reals
#    core type: Lambda
#    parameter: 23
#    body: 7
#    conditions: 8\n5. b in Reals
#    core type: Operation
#    operator: 16
#    operands: 9
# 6. a < b
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. (c + a) < (c + b)
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (c in Reals)
#    core type: ExprTuple
#    sub-expressions: 13
# 9. (b , Reals)
#    core type: ExprTuple
#    sub-expressions: 24, 21
# 10. (a , b)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 11. <
#     core type: Literal
#     sub-expressions:
# 12. (c + a , c + b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. c in Reals
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. c + a
#     core type: Operation
#     operator: 19
#     operands: 18
# 15. c + b
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (c , Reals)
#     core type: ExprTuple
#     sub-expressions: 23, 21
# 18. (c , a)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (c , b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. Reals
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. c
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
