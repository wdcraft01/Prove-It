# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Operation, OperationSequence
from proveit._common_ import i, n, rho, x
from proveit.logic import And, Equals, Forall, Set
from proveit.number import Add, Exp, Less, LessEq, Reals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Indexed(rho, i, base = 1)
subExpr2 = Indexed(x, i, base = 1)
subExpr3 = Add(n, one)
expr = Forall([x, rho], Equals(OperationSequence([Iter(i, subExpr1, one, n)], [Iter(i, subExpr2, one, n), Indexed(x, subExpr3, base = 1)]), And(Iter(i, Operation(subExpr1, [subExpr2, Indexed(x, Add(i, one), base = 1)]), one, n))), domains = [Exp(Reals, subExpr3), Exp(Set(Less._operator_, LessEq._operator_, Equals._operator_), n)], conditions = [])
# Out:
# expr: forall_{(x, rho) in Reals^{n + 1} * {< , <= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(x, rho) in Reals^{n + 1} * {< , <= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. x -> [forall_{rho in {< , <= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))] | x in Reals^{n + 1}
#    core type: Lambda
#    parameter: 50
#    body: 2
#    conditions: 3\n2. forall_{rho in {< , <= , =}^{n}} ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1))))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x in Reals^{n + 1})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. rho -> ((x_1 rho_1  ...   x_n rho_n x_(n + 1)) = ((x_1 rho_1 x_(1 + 1)) and  ...  and (x_n rho_n x_(n + 1)))) | rho in {< , <= , =}^{n}
#    core type: Lambda
#    parameter: 45
#    body: 7
# ...
