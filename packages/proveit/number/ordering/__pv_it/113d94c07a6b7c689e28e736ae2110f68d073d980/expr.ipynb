# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.ordering</a>

# %%
# import Expression classes needed to build the expression
from proveit import OperationSequence
from proveit._common_ import v, w, x, y, z
from proveit.logic import And, Equals
from proveit.number import Less, LessEq

# %%
# build up the expression from sub-expressions
expr = Equals(OperationSequence([Less._operator_, LessEq._operator_, Equals._operator_, Less._operator_], [v, w, x, y, z]), And(Less(v, w), LessEq(w, x), Equals(x, y), Less(y, z)))
# Out:
# expr: (v < w <= x = y < z) = ((v < w) and (w <= x) and (x = y) and (y < z))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (v < w <= x = y < z) = ((v < w) and (w <= x) and (x = y) and (y < z))
#    core type: Operation
#    operator: 15
#    operands: 1
# 1. (v < w <= x = y < z , (v < w) and (w <= x) and (x = y) and (y < z))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. v < w <= x = y < z
#    core type: Operation
#    operators: 4
#    operands: 5
# 3. (v < w) and (w <= x) and (x = y) and (y < z)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. (< , <= , = , <)
#    core type: ExprTuple
#    sub-expressions: 17, 13, 15, 17
# 5. (v , w , x , y , z)
#    core type: ExprTuple
#    sub-expressions: 19, 20, 21, 22, 23
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (v < w , w <= x , x = y , y < z)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. v < w
#    core type: Operation
#    operator: 17
#    operands: 12
# 9. w <= x
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. x = y
#     core type: Operation
#     operator: 15
# ...
