# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Less, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(n, Forall([m], Forall([AA], Equals(AA, subExpr1), conditions = subExpr1), domain = Naturals, conditions = [Less(n, m)]), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{m in Naturals | n < m} [forall_{A} (A = ())]] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{m in Naturals | n < m} [forall_{A} (A = ())]] | n in Naturals
#    core type: Lambda
#    parameter: 20
#    body: 1
#    conditions: 2\n1. forall_{m in Naturals | n < m} [forall_{A} (A = ())]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. m -> [forall_{A} (A = ())] | m in Naturals , n < m
#    core type: Lambda
#    parameter: 21
#    body: 5
#    conditions: 6\n4. n in Naturals
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. forall_{A} (A = ())
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (m in Naturals , n < m)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 7. (n , Naturals)
#    core type: ExprTuple
#    sub-expressions: 20, 19
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. A -> (A = ())
#    core type: Lambda
#    parameter: 22
#    body: 12
# 10. m in Naturals
#     core type: Operation
#     operator: 13
# ...
