# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Interval, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([b], Forall([n], InSet(n, Naturals), domain = Interval(a, b), conditions = subExpr1), domain = Naturals, conditions = subExpr1)
# Out:
# expr: forall_{b in Naturals} [forall_{n in {a...b}} (n in Naturals)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b in Naturals} [forall_{n in {a...b}} (n in Naturals)]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. b -> [forall_{n in {a...b}} (n in Naturals)] | b in Naturals
#    core type: Lambda
#    parameter: 20
#    body: 2
#    conditions: 3\n2. forall_{n in {a...b}} (n in Naturals)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (b in Naturals)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. n -> (n in Naturals) | n in {a...b}
#    core type: Lambda
#    parameter: 15
#    body: 7
#    conditions: 8\n6. b in Naturals
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. n in Naturals
#    core type: Operation
#    operator: 13
#    operands: 10
# 8. (n in {a...b})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (b , Naturals)
#    core type: ExprTuple
#    sub-expressions: 20, 12
# 10. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 15, 12
# 11. n in {a...b}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. Naturals
#     core type: Literal
#     sub-expressions:
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. {a...b}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (a , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
