# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import InSet
from proveit.number import Add, Integers, Less, NaturalsPos, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(b, InSet(Add(a, Neg(b)), NaturalsPos), conditions = [InSet(b, Integers), Less(b, a)])
# Out:
# expr: b -> ((a - b) in NaturalsPos) | b in Integers , b < a

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> ((a - b) in NaturalsPos) | b in Integers , b < a
#    core type: Lambda
#    parameter: 18
#    body: 1
#    conditions: 2\n1. (a - b) in NaturalsPos
#    core type: Operation
#    operator: 8
#    operands: 3
# 2. (b in Integers , b < a)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. (a - b , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. b in Integers
#    core type: Operation
#    operator: 8
#    operands: 9
# 5. b < a
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. a - b
#    core type: Operation
#    operator: 12
#    operands: 13
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (b , Integers)
#    core type: ExprTuple
#    sub-expressions: 18, 14
# 10. <
#     core type: Literal
#     sub-expressions:
# 11. (b , a)
#     core type: ExprTuple
#     sub-expressions: 18, 15
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (a , -b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Integers
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. -b
#     core type: Operation
#     operator: 17
#     operand: 18
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
