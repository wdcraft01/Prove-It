# %% [markdown]
# Axiom <a class="ProveItLink" href="../../_axioms_.ipynb#addByZero">addByZero</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._axioms_ import addByZero

# %%
# check that the built expression is the same as the stored expression
# %check_expr addByZero
# Out:
# Passed sanity check: built 'addByZero' is the same as the stored Expression.

# %%
# display the expression information
addByZero.exprInfo()
# Out:
# 0. forall_{x in Complexes} ((x + 0) = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x + 0) = x) | x in Complexes
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. (x + 0) = x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x + 0 , x)
#    core type: ExprTuple
#    sub-expressions: 8, 14
# 7. x in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. x + 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (x , 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Complexes
# ...
