# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Integers, Interval, LessEq

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(a, Forall([b], Forall([n], LessEq(a, n), domain = Interval(a, b), conditions = subExpr1), domain = Integers, conditions = subExpr1), conditions = [InSet(a, Integers)])
# Out:
# expr: a -> [forall_{b in Integers} [forall_{n in {a...b}} (a <= n)]] | a in Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b in Integers} [forall_{n in {a...b}} (a <= n)]] | a in Integers
#    core type: Lambda
#    parameter: 24
#    body: 1
#    conditions: 2\n1. forall_{b in Integers} [forall_{n in {a...b}} (a <= n)]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{n in {a...b}} (a <= n)] | b in Integers
#    core type: Lambda
#    parameter: 25
#    body: 5
#    conditions: 6\n4. a in Integers
#    core type: Operation
#    operator: 18
#    operands: 7
# 5. forall_{n in {a...b}} (a <= n)
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 24, 17
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. n -> (a <= n) | n in {a...b}
#    core type: Lambda
#    parameter: 20
#    body: 11
#    conditions: 12\n10. b in Integers
#     core type: Operation
#     operator: 18
#     operands: 13
# 11. a <= n
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (n in {a...b})
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 25, 17
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. (a , n)
#     core type: ExprTuple
#     sub-expressions: 24, 20
# 16. n in {a...b}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. Integers
#     core type: Literal
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. {a...b}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (a , b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
