# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import m
from proveit.logic import Forall
from proveit.number import Naturals
from proveit.number._common_ import P_mAddOne, Pm, Pone

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Pone, Forall([m], P_mAddOne, domain = Naturals, conditions = [Pm]))
# Out:
# expr: (P(1) , forall_{m in Naturals | P(m)} P(m + 1))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(1) , forall_{m in Naturals | P(m)} P(m + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(1)
#    core type: Operation
#    operator: 14
#    operand: 15
# 2. forall_{m in Naturals | P(m)} P(m + 1)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. m -> P(m + 1) | m in Naturals , P(m)
#    core type: Lambda
#    parameter: 16
#    body: 5
#    conditions: 6\n5. P(m + 1)
#    core type: Operation
#    operator: 14
#    operand: 7
# 6. (m in Naturals , P(m))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. m + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. m in Naturals
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. P(m)
#    core type: Operation
#    operator: 14
#    operand: 16
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (m , 1)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. P
#     core type: Variable
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. Naturals
#     core type: Literal
#     sub-expressions:
