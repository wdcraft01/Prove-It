# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#induction">induction</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import induction

# %%
# check that the built expression is the same as the stored expression
# %check_expr induction
# Out:
# Passed sanity check: built 'induction' is the same as the stored Expression.

# %%
# display the expression information
induction.exprInfo()
# Out:
# 0. forall_{P} ((P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in Naturals} P(n)])
#    core type: Operation
#    operator: 15
#    operand: 1
# 1. P -> ((P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in Naturals} P(n)])
#    core type: Lambda
#    parameter: 29
#    body: 2
# 2. (P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in Naturals} P(n)]
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (P(0) and [forall_{m in Naturals | P(m)} P(m + 1)] , forall_{n in Naturals} P(n))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. forall_{n in Naturals} P(n)
#    core type: Operation
#    operator: 15
#    operand: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (P(0) , forall_{m in Naturals | P(m)} P(m + 1))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. n -> P(n) | n in Naturals
#    core type: Lambda
#    parameter: 24
#    body: 12
#    conditions: 13\n10. P(0)
#     core type: Operation
#     operator: 29
#     operand: 14
# 11. forall_{m in Naturals | P(m)} P(m + 1)
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. P(n)
#     core type: Operation
#     operator: 29
#     operand: 24
# 13. (n in Naturals)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. 0
#     core type: Literal
#     sub-expressions:
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. m -> P(m + 1) | m in Naturals , P(m)
#     core type: Lambda
#     parameter: 31
#     body: 18
#     conditions: 19\n17. n in Naturals
#     core type: Operation
#     operator: 27
#     operands: 20
# 18. P(m + 1)
#     core type: Operation
#     operator: 29
#     operand: 21
# 19. (m in Naturals , P(m))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 24, 32
# 21. m + 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. m in Naturals
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. P(m)
#     core type: Operation
#     operator: 29
#     operand: 31
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (m , 1)
#     core type: ExprTuple
#     sub-expressions: 31, 30
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. P
#     core type: Variable
#     sub-expressions:
# 30. 1
#     core type: Literal
#     sub-expressions:
# 31. m
#     core type: Variable
#     sub-expressions:
# 32. Naturals
#     core type: Literal
#     sub-expressions:
