# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#natsPosInIntegers">natsPosInIntegers</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import natsPosInIntegers

# %%
# check that the built expression is the same as the stored expression
# %check_expr natsPosInIntegers
# Out:
# Passed sanity check: built 'natsPosInIntegers' is the same as the stored Expression.

# %%
# display the expression information
natsPosInIntegers.exprInfo()
# Out:
# 0. forall_{a in NaturalsPos} (a in Integers)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> (a in Integers) | a in NaturalsPos
#    core type: Lambda
#    parameter: 10
#    body: 3
#    conditions: 4\n3. a in Integers
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (a in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 10, 7
# 6. a in NaturalsPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. Integers
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. NaturalsPos
#     core type: Literal
#     sub-expressions:
