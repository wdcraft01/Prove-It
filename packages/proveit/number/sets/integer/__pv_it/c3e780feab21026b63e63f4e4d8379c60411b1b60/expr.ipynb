# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Integers, Interval, LessEq

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([n], LessEq(n, b), domain = Interval(a, b), conditions = []), conditions = [InSet(b, Integers)])
# Out:
# expr: b -> [forall_{n in {a...b}} (n <= b)] | b in Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{n in {a...b}} (n <= b)] | b in Integers
#    core type: Lambda
#    parameter: 20
#    body: 1
#    conditions: 2\n1. forall_{n in {a...b}} (n <= b)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. n -> (n <= b) | n in {a...b}
#    core type: Lambda
#    parameter: 15
#    body: 6
#    conditions: 7\n5. b in Integers
#    core type: Operation
#    operator: 13
#    operands: 8
# 6. n <= b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (n in {a...b})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (b , Integers)
#    core type: ExprTuple
#    sub-expressions: 20, 12
# 9. <=
#    core type: Literal
#    sub-expressions:
# 10. (n , b)
#     core type: ExprTuple
#     sub-expressions: 15, 20
# 11. n in {a...b}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. Integers
#     core type: Literal
#     sub-expressions:
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. {a...b}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (a , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
