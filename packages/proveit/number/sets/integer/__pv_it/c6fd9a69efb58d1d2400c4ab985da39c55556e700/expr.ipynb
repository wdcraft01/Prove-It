# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import P, m, n
from proveit.logic import And, Forall, Implies
from proveit.number import Naturals, NaturalsPos
from proveit.number._common_ import P_mAddOne, Pm, Pn, Pone

# %%
# build up the expression from sub-expressions
expr = Lambda(P, Implies(And(Pone, Forall([m], P_mAddOne, domain = Naturals, conditions = [Pm])), Forall([n], Pn, domain = NaturalsPos, conditions = [])))
# Out:
# expr: P -> ((P(1) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> ((P(1) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)])
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. (P(1) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in NaturalsPos} P(n)]
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. (P(1) and [forall_{m in Naturals | P(m)} P(m + 1)] , forall_{n in NaturalsPos} P(n))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. P(1) and [forall_{m in Naturals | P(m)} P(m + 1)]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. forall_{n in NaturalsPos} P(n)
#    core type: Operation
#    operator: 13
#    operand: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (P(1) , forall_{m in Naturals | P(m)} P(m + 1))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. n -> P(n) | n in NaturalsPos
#    core type: Lambda
#    parameter: 22
#    body: 11
#    conditions: 12\n9. P(1)
# ...
