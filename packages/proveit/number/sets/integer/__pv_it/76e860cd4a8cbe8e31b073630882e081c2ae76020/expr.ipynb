# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#differenceInNaturalsPos">differenceInNaturalsPos</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import differenceInNaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr differenceInNaturalsPos
# Out:
# Passed sanity check: built 'differenceInNaturalsPos' is the same as the stored Expression.

# %%
# display the expression information
differenceInNaturalsPos.exprInfo()
# Out:
# 0. forall_{a, b in Integers | b < a} ((a - b) in NaturalsPos)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Integers | b < a} ((a - b) in NaturalsPos)] | a in Integers
#    core type: Lambda
#    parameter: 22
#    body: 2
#    conditions: 3\n2. forall_{b in Integers | b < a} ((a - b) in NaturalsPos)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((a - b) in NaturalsPos) | b in Integers , b < a
#    core type: Lambda
#    parameter: 25
#    body: 7
#    conditions: 8\n6. a in Integers
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. (a - b) in NaturalsPos
#    core type: Operation
#    operator: 15
#    operands: 10
# 8. (b in Integers , b < a)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 22, 21
# 10. (a - b , NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. b in Integers
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. b < a
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. a - b
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 17. <
#     core type: Literal
#     sub-expressions:
# 18. (b , a)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (a , -b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. Integers
#     core type: Literal
#     sub-expressions:
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. -b
#     core type: Operation
#     operator: 24
#     operand: 25
# 24. -
#     core type: Literal
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
