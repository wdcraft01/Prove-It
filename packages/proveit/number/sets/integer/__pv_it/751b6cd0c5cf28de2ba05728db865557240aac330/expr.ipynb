# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import S, x
from proveit.logic import And, Forall, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S, conditions = [])))
# Out:
# expr: ((0 in S) and [forall_{x in S} ((x + 1) in S)])

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((0 in S) and [forall_{x in S} ((x + 1) in S)])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. and
#    core type: Literal
#    sub-expressions:
# 3. (0 in S , forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. 0 in S
#    core type: Operation
#    operator: 15
#    operands: 6
# 5. forall_{x in S} ((x + 1) in S)
#    core type: Operation
#    operator: 7
#    operand: 8
# 6. (0 , S)
#    core type: ExprTuple
#    sub-expressions: 9, 19
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. x -> ((x + 1) in S) | x in S
#    core type: Lambda
#    parameter: 20
#    body: 10
#    conditions: 11\n9. 0
#    core type: Literal
#    sub-expressions:
# 10. (x + 1) in S
#     core type: Operation
#     operator: 15
#     operands: 12
# 11. (x in S)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (x + 1 , S)
#     core type: ExprTuple
#     sub-expressions: 14, 19
# 13. x in S
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. x + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x , S)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (x , 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. S
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
