# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import m, n
from proveit.logic import And, Forall, Implies
from proveit.number import Naturals
from proveit.number._common_ import P_mAddOne, Pm, Pn, Pzero

# %%
# build up the expression from sub-expressions
expr = Implies(And(Pzero, Forall([m], P_mAddOne, domain = Naturals, conditions = [Pm])), Forall([n], Pn, domain = Naturals, conditions = []))
# Out:
# expr: (P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in Naturals} P(n)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]) => [forall_{n in Naturals} P(n)]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (P(0) and [forall_{m in Naturals | P(m)} P(m + 1)] , forall_{n in Naturals} P(n))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. P(0) and [forall_{m in Naturals | P(m)} P(m + 1)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. forall_{n in Naturals} P(n)
#    core type: Operation
#    operator: 13
#    operand: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (P(0) , forall_{m in Naturals | P(m)} P(m + 1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. n -> P(n) | n in Naturals
#    core type: Lambda
#    parameter: 22
#    body: 10
#    conditions: 11\n8. P(0)
#    core type: Operation
#    operator: 27
#    operand: 12
# 9. forall_{m in Naturals | P(m)} P(m + 1)
#    core type: Operation
#    operator: 13
#    operand: 14
# 10. P(n)
#     core type: Operation
#     operator: 27
#     operand: 22
# 11. (n in Naturals)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. 0
#     core type: Literal
#     sub-expressions:
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. m -> P(m + 1) | m in Naturals , P(m)
#     core type: Lambda
#     parameter: 29
#     body: 16
#     conditions: 17\n15. n in Naturals
#     core type: Operation
#     operator: 25
#     operands: 18
# 16. P(m + 1)
#     core type: Operation
#     operator: 27
#     operand: 19
# 17. (m in Naturals , P(m))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 22, 30
# 19. m + 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. m in Naturals
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. P(m)
#     core type: Operation
#     operator: 27
#     operand: 29
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (m , 1)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. P
#     core type: Variable
#     sub-expressions:
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. m
#     core type: Variable
#     sub-expressions:
# 30. Naturals
#     core type: Literal
#     sub-expressions:
