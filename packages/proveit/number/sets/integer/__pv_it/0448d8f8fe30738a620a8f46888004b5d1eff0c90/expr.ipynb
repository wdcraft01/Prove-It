# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, m, n
from proveit.logic import Equals, Forall
from proveit.number import Less, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([m], Forall([AA], Equals(AA, subExpr1), conditions = subExpr1), domain = Naturals, conditions = [Less(n, m)])
# Out:
# expr: forall_{m in Naturals | n < m} [forall_{A} (A = ())]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m in Naturals | n < m} [forall_{A} (A = ())]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. m -> [forall_{A} (A = ())] | m in Naturals , n < m
#    core type: Lambda
#    parameter: 17
#    body: 2
#    conditions: 3\n2. forall_{A} (A = ())
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (m in Naturals , n < m)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. A -> (A = ())
#    core type: Lambda
#    parameter: 18
#    body: 8
# 6. m in Naturals
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. n < m
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. A = ()
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 11. <
#     core type: Literal
#     sub-expressions:
# 12. (n , m)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (A , ())
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. Naturals
#     core type: Literal
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. A
#     core type: Variable
#     sub-expressions:
# 19. ()
#     core type: ExprTuple
#     sub-expressions:
