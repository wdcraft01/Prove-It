# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import S, n, x
from proveit.logic import And, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = Implies(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S, conditions = [])), InSet(n, S))
# Out:
# expr: ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((0 in S) and [forall_{x in S} ((x + 1) in S)] , n in S)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. n in S
#    core type: Operation
#    operator: 20
#    operands: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (0 in S , forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (n , S)
#    core type: ExprTuple
#    sub-expressions: 10, 24
# 8. 0 in S
#    core type: Operation
#    operator: 20
#    operands: 11
# 9. forall_{x in S} ((x + 1) in S)
#    core type: Operation
#    operator: 12
#    operand: 13
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. (0 , S)
#     core type: ExprTuple
#     sub-expressions: 14, 24
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. x -> ((x + 1) in S) | x in S
#     core type: Lambda
#     parameter: 25
#     body: 15
#     conditions: 16\n14. 0
#     core type: Literal
#     sub-expressions:
# 15. (x + 1) in S
#     core type: Operation
#     operator: 20
#     operands: 17
# 16. (x in S)
#     core type: ExprTuple
#     sub-expressions: 18
# 17. (x + 1 , S)
#     core type: ExprTuple
#     sub-expressions: 19, 24
# 18. x in S
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. x + 1
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (x , S)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (x , 1)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. S
#     core type: Variable
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. 1
#     core type: Literal
#     sub-expressions:
