# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Interval, NaturalsPos

# %%
# build up the expression from sub-expressions
expr = Forall([n], InSet(n, NaturalsPos), domain = Interval(a, b), conditions = [])
# Out:
# expr: forall_{n in {a...b}} (n in NaturalsPos)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in {a...b}} (n in NaturalsPos)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. n -> (n in NaturalsPos) | n in {a...b}
#    core type: Lambda
#    parameter: 10
#    body: 3
#    conditions: 4\n3. n in NaturalsPos
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (n in {a...b})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 10, 7
# 6. n in {a...b}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. NaturalsPos
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n , {a...b})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. {a...b}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (a , b)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
