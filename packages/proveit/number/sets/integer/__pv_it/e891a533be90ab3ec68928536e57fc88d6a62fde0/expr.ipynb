# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#intervalInNatsPos">intervalInNatsPos</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import intervalInNatsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr intervalInNatsPos
# Out:
# Passed sanity check: built 'intervalInNatsPos' is the same as the stored Expression.

# %%
# display the expression information
intervalInNatsPos.exprInfo()
# Out:
# 0. forall_{a, b in Integers | a > 0} [forall_{n in {a...b}} (n in NaturalsPos)]
#    core type: Operation
#    operator: 12
#    operand: 1
# 1. a -> [forall_{b in Integers} [forall_{n in {a...b}} (n in NaturalsPos)]] | a in Integers , a > 0
#    core type: Lambda
#    parameter: 29
#    body: 2
#    conditions: 3\n2. forall_{b in Integers} [forall_{n in {a...b}} (n in NaturalsPos)]
#    core type: Operation
#    operator: 12
#    operand: 4
# 3. (a in Integers , a > 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. b -> [forall_{n in {a...b}} (n in NaturalsPos)] | b in Integers
#    core type: Lambda
#    parameter: 30
#    body: 7
#    conditions: 8\n5. a in Integers
#    core type: Operation
#    operator: 23
#    operands: 9
# 6. a > 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. forall_{n in {a...b}} (n in NaturalsPos)
#    core type: Operation
#    operator: 12
#    operand: 13
# 8. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 14
# 9. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 29, 21
# 10. >
#     core type: Literal
#     sub-expressions:
# 11. (a , 0)
#     core type: ExprTuple
#     sub-expressions: 29, 15
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. n -> (n in NaturalsPos) | n in {a...b}
#     core type: Lambda
#     parameter: 25
#     body: 16
#     conditions: 17\n14. b in Integers
#     core type: Operation
#     operator: 23
#     operands: 18
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. n in NaturalsPos
#     core type: Operation
#     operator: 23
#     operands: 19
# 17. (n in {a...b})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 30, 21
# 19. (n , NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 20. n in {a...b}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. Integers
#     core type: Literal
#     sub-expressions:
# 22. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. {a...b}
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. Interval
#     core type: Literal
#     sub-expressions:
# 28. (a , b)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. b
#     core type: Variable
#     sub-expressions:
