# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#allInPositiveIntervalArePositive">allInPositiveIntervalArePositive</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import allInPositiveIntervalArePositive

# %%
# check that the built expression is the same as the stored expression
# %check_expr allInPositiveIntervalArePositive
# Out:
# Passed sanity check: built 'allInPositiveIntervalArePositive' is the same as the stored Expression.

# %%
# display the expression information
allInPositiveIntervalArePositive.exprInfo()
# Out:
# 0. forall_{a, b in Integers | a > 0} [forall_{n in {a...b}} (n > 0)]
#    core type: Operation
#    operator: 11
#    operand: 1
# 1. a -> [forall_{b in Integers} [forall_{n in {a...b}} (n > 0)]] | a in Integers , a > 0
#    core type: Lambda
#    parameter: 28
#    body: 2
#    conditions: 3\n2. forall_{b in Integers} [forall_{n in {a...b}} (n > 0)]
#    core type: Operation
#    operator: 11
#    operand: 4
# 3. (a in Integers , a > 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. b -> [forall_{n in {a...b}} (n > 0)] | b in Integers
#    core type: Lambda
#    parameter: 29
#    body: 7
#    conditions: 8\n5. a in Integers
#    core type: Operation
#    operator: 22
#    operands: 9
# 6. a > 0
#    core type: Operation
#    operator: 17
#    operands: 10
# 7. forall_{n in {a...b}} (n > 0)
#    core type: Operation
#    operator: 11
#    operand: 12
# 8. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 13
# 9. (a , Integers)
#    core type: ExprTuple
# ...
