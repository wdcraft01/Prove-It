# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import n
from proveit.logic import SetOfAll, Union
from proveit.number import Integers, Naturals, NaturalsPos, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Integers, Union(Naturals, SetOfAll([n], Neg(n), domain = NaturalsPos, conditions = [])))
# Out:
# expr: (Integers , Naturals union {(-n) s.t. ()}_{n in NaturalsPos})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Integers , Naturals union {(-n) s.t. ()}_{n in NaturalsPos})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Integers
#    core type: Literal
#    sub-expressions:
# 2. Naturals union {(-n) s.t. ()}_{n in NaturalsPos}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. union
#    core type: Literal
#    sub-expressions:
# 4. (Naturals , {(-n) s.t. ()}_{n in NaturalsPos})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. Naturals
#    core type: Literal
#    sub-expressions:
# 6. {(-n) s.t. ()}_{n in NaturalsPos}
#    core type: Operation
#    operator: 7
#    operand: 8
# 7. Set
#    core type: Literal
#    sub-expressions:
# 8. n -> (-n) | n in NaturalsPos
#    core type: Lambda
#    parameter: 15
#    body: 9
#    conditions: 10\n9. -n
#    core type: Operation
#    operator: 11
#    operand: 15
# 10. (n in NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. n in NaturalsPos
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (n , NaturalsPos)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. NaturalsPos
#     core type: Literal
#     sub-expressions:
