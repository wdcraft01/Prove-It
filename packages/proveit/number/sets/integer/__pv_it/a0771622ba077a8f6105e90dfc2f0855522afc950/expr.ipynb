# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import InSet
from proveit.number import Integers, Interval, LessEq, LesserSequence

# %%
# build up the expression from sub-expressions
expr = Lambda(n, InSet(n, Interval(a, b)), conditions = [InSet(n, Integers), LesserSequence([LessEq._operator_, LessEq._operator_], [a, n, b])])
# Out:
# expr: n -> (n in {a...b}) | n in Integers , a <= n <= b

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> (n in {a...b}) | n in Integers , a <= n <= b
#    core type: Lambda
#    parameter: 15
#    body: 1
#    conditions: 2\n1. n in {a...b}
#    core type: Operation
#    operator: 7
#    operands: 3
# 2. (n in Integers , a <= n <= b)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. (n , {a...b})
#    core type: ExprTuple
#    sub-expressions: 15, 6
# 4. n in Integers
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. a <= n <= b
#    core type: Operation
#    operators: 9
#    operands: 10
# 6. {a...b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (n , Integers)
#    core type: ExprTuple
#    sub-expressions: 15, 13
# 9. (<= , <=)
#    core type: ExprTuple
#    sub-expressions: 14, 14
# 10. (a , n , b)
#     core type: ExprTuple
#     sub-expressions: 16, 15, 17
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (a , b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. Integers
#     core type: Literal
#     sub-expressions:
# 14. <=
#     core type: Literal
#     sub-expressions:
# 15. n
#     core type: Variable
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
