# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#intervalInInts">intervalInInts</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import intervalInInts

# %%
# check that the built expression is the same as the stored expression
# %check_expr intervalInInts
# Out:
# Passed sanity check: built 'intervalInInts' is the same as the stored Expression.

# %%
# display the expression information
intervalInInts.exprInfo()
# Out:
# 0. forall_{a, b in Integers} [forall_{n in {a...b}} (n in Integers)]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b in Integers} [forall_{n in {a...b}} (n in Integers)]] | a in Integers
#    core type: Lambda
#    parameter: 24
#    body: 2
#    conditions: 3\n2. forall_{b in Integers} [forall_{n in {a...b}} (n in Integers)]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{n in {a...b}} (n in Integers)] | b in Integers
#    core type: Lambda
#    parameter: 25
#    body: 6
#    conditions: 7\n5. a in Integers
#    core type: Operation
#    operator: 18
#    operands: 8
# 6. forall_{n in {a...b}} (n in Integers)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 24, 17
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. n -> (n in Integers) | n in {a...b}
#     core type: Lambda
#     parameter: 20
#     body: 12
#     conditions: 13\n11. b in Integers
#     core type: Operation
#     operator: 18
#     operands: 14
# 12. n in Integers
#     core type: Operation
#     operator: 18
#     operands: 15
# 13. (n in {a...b})
#     core type: ExprTuple
#     sub-expressions: 16
# 14. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 25, 17
# 15. (n , Integers)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 16. n in {a...b}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. Integers
#     core type: Literal
#     sub-expressions:
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. n
#     core type: Variable
#     sub-expressions:
# 21. {a...b}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Interval
#     core type: Literal
#     sub-expressions:
# 23. (a , b)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
