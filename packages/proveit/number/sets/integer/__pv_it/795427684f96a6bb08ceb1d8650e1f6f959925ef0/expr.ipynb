# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import S, n, x
from proveit.logic import And, Forall, Implies, InSet
from proveit.number import Add, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(S, Implies(And(InSet(zero, S), Forall([x], InSet(Add(x, one), S), domain = S, conditions = [])), InSet(n, S)))
# Out:
# expr: S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. S -> (((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S))
#    core type: Lambda
#    parameter: 25
#    body: 1
# 1. ((0 in S) and [forall_{x in S} ((x + 1) in S)]) => (n in S)
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. ((0 in S) and [forall_{x in S} ((x + 1) in S)] , n in S)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (0 in S) and [forall_{x in S} ((x + 1) in S)]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. n in S
#    core type: Operation
#    operator: 21
#    operands: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (0 in S , forall_{x in S} ((x + 1) in S))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (n , S)
#    core type: ExprTuple
#    sub-expressions: 11, 25
# 9. 0 in S
#    core type: Operation
#    operator: 21
#    operands: 12
# 10. forall_{x in S} ((x + 1) in S)
#     core type: Operation
#     operator: 13
#     operand: 14
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. (0 , S)
#     core type: ExprTuple
#     sub-expressions: 15, 25
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. x -> ((x + 1) in S) | x in S
#     core type: Lambda
#     parameter: 26
#     body: 16
#     conditions: 17\n15. 0
#     core type: Literal
#     sub-expressions:
# 16. (x + 1) in S
#     core type: Operation
#     operator: 21
#     operands: 18
# 17. (x in S)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (x + 1 , S)
#     core type: ExprTuple
#     sub-expressions: 20, 25
# 19. x in S
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. x + 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (x , S)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (x , 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. S
#     core type: Variable
#     sub-expressions:
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. 1
#     core type: Literal
#     sub-expressions:
