# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Interval, Naturals

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(a, Forall([b], Forall([n], InSet(n, Naturals), domain = Interval(a, b), conditions = subExpr1), domain = Naturals, conditions = subExpr1), conditions = [InSet(a, Naturals)])
# Out:
# expr: a -> [forall_{b in Naturals} [forall_{n in {a...b}} (n in Naturals)]] | a in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b in Naturals} [forall_{n in {a...b}} (n in Naturals)]] | a in Naturals
#    core type: Lambda
#    parameter: 23
#    body: 1
#    conditions: 2\n1. forall_{b in Naturals} [forall_{n in {a...b}} (n in Naturals)]
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{n in {a...b}} (n in Naturals)] | b in Naturals
#    core type: Lambda
#    parameter: 24
#    body: 5
#    conditions: 6\n4. a in Naturals
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall_{n in {a...b}} (n in Naturals)
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (b in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (a , Naturals)
#    core type: ExprTuple
#    sub-expressions: 23, 16
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. n -> (n in Naturals) | n in {a...b}
#    core type: Lambda
#    parameter: 19
#    body: 11
#    conditions: 12\n10. b in Naturals
#     core type: Operation
#     operator: 17
#     operands: 13
# 11. n in Naturals
#     core type: Operation
#     operator: 17
#     operands: 14
# 12. (n in {a...b})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (b , Naturals)
#     core type: ExprTuple
#     sub-expressions: 24, 16
# 14. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 15. n in {a...b}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. Naturals
#     core type: Literal
#     sub-expressions:
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. {a...b}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (a , b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
