# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#natsPosInReals">natsPosInReals</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import natsPosInReals

# %%
# check that the built expression is the same as the stored expression
# %check_expr natsPosInReals
# Out:
# Passed sanity check: built 'natsPosInReals' is the same as the stored Expression.

# %%
# display the expression information
natsPosInReals.exprInfo()
# Out:
# 0. forall_{a in NaturalsPos} (a in Reals)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. a -> (a in Reals) | a in NaturalsPos
#    core type: Lambda
#    parameter: 10
#    body: 3
#    conditions: 4\n3. a in Reals
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. (a in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 10, 7
# 6. a in NaturalsPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. Reals
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. NaturalsPos
#     core type: Literal
#     sub-expressions:
