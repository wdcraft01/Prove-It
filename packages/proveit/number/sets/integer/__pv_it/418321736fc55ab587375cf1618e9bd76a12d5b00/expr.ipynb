# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Integers, Interval, LessEq, LesserSequence

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b, n], InSet(n, Interval(a, b)), domain = Integers, conditions = [LesserSequence([LessEq._operator_, LessEq._operator_], [a, n, b])]), conditions = [InSet(a, Integers)])
# Out:
# expr: a -> [forall_{b, n in Integers | a <= n <= b} (n in {a...b})] | a in Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b, n in Integers | a <= n <= b} (n in {a...b})] | a in Integers
#    core type: Lambda
#    parameter: 27
#    body: 1
#    conditions: 2\n1. forall_{b, n in Integers | a <= n <= b} (n in {a...b})
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. b -> [forall_{n in Integers | a <= n <= b} (n in {a...b})] | b in Integers
#    core type: Lambda
#    parameter: 28
#    body: 5
#    conditions: 6\n4. a in Integers
#    core type: Operation
#    operator: 18
#    operands: 7
# 5. forall_{n in Integers | a <= n <= b} (n in {a...b})
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 27, 24
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. n -> (n in {a...b}) | n in Integers , a <= n <= b
#    core type: Lambda
#    parameter: 26
# ...
