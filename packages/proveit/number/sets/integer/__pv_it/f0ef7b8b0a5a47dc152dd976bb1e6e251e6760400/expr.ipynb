# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import n
from proveit.logic import Equals, Forall
from proveit.logic._common_ import xIter1n
from proveit.number import Len

# %%
# build up the expression from sub-expressions
subExpr1 = [xIter1n]
expr = Forall(subExpr1, Equals(Len(subExpr1), n), conditions = [])
# Out:
# expr: forall_{x_1,...,x_n} (|(x_1 ,  ...  , x_n)| = n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x_1,...,x_n} (|(x_1 ,  ...  , x_n)| = n)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x_1,...,x_n) -> (|(x_1 ,  ...  , x_n)| = n)
#    core type: Lambda
#    parameter: 9
#    body: 3
# 3. |(x_1 ,  ...  , x_n)| = n
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (|(x_1 ,  ...  , x_n)| , n)
#    core type: ExprTuple
#    sub-expressions: 6, 22
# 6. |(x_1 ,  ...  , x_n)|
#    core type: Operation
#    operator: 7
#    operand: 8
# 7. length
#    core type: Literal
#    sub-expressions:
# 8. (x_1 ,  ...  , x_n)
#    core type: ExprTuple
#    sub-expressions: 9
# 9. x_1,...,x_n
#    core type: Iter
#    lambda_map: 10
#    start_index: 21
#    end_index: 22
# 10. _x_ -> x__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 17
#     body: 11
#     conditions: 12\n11. x__x_
#     core type: Indexed
#     var: 13
#     index: 17
#     base: "1"
# 12. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. _x_ in {1...n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. _x_
#     core type: Variable
#     sub-expressions:
# 18. {1...n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. Interval
#     core type: Literal
#     sub-expressions:
# 20. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
