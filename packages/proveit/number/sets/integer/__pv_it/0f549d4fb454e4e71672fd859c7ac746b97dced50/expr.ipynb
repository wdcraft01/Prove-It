# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Forall, InSet
from proveit.number import Integers, Interval

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([n], InSet(n, Integers), domain = Interval(a, b), conditions = []), conditions = [InSet(b, Integers)])
# Out:
# expr: b -> [forall_{n in {a...b}} (n in Integers)] | b in Integers

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{n in {a...b}} (n in Integers)] | b in Integers
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. forall_{n in {a...b}} (n in Integers)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. n -> (n in Integers) | n in {a...b}
#    core type: Lambda
#    parameter: 14
#    body: 6
#    conditions: 7\n5. b in Integers
#    core type: Operation
#    operator: 12
#    operands: 8
# 6. n in Integers
#    core type: Operation
#    operator: 12
#    operands: 9
# 7. (n in {a...b})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (b , Integers)
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 9. (n , Integers)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 10. n in {a...b}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Integers
#     core type: Literal
#     sub-expressions:
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. {a...b}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (a , b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
