# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#intervalUpperBound">intervalUpperBound</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.sets.integer</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.sets.integer._theorems_ import intervalUpperBound

# %%
# check that the built expression is the same as the stored expression
# %check_expr intervalUpperBound
# Out:
# Passed sanity check: built 'intervalUpperBound' is the same as the stored Expression.

# %%
# display the expression information
intervalUpperBound.exprInfo()
# Out:
# 0. forall_{a, b in Integers} [forall_{n in {a...b}} (n <= b)]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b in Integers} [forall_{n in {a...b}} (n <= b)]] | a in Integers
#    core type: Lambda
#    parameter: 25
#    body: 2
#    conditions: 3\n2. forall_{b in Integers} [forall_{n in {a...b}} (n <= b)]
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. b -> [forall_{n in {a...b}} (n <= b)] | b in Integers
#    core type: Lambda
#    parameter: 26
#    body: 6
#    conditions: 7\n5. a in Integers
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall_{n in {a...b}} (n <= b)
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 25, 18
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. n -> (n <= b) | n in {a...b}
#     core type: Lambda
#     parameter: 21
#     body: 12
#     conditions: 13\n11. b in Integers
#     core type: Operation
#     operator: 19
#     operands: 14
# 12. n <= b
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (n in {a...b})
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 26, 18
# 15. <=
#     core type: Literal
#     sub-expressions:
# 16. (n , b)
#     core type: ExprTuple
#     sub-expressions: 21, 26
# 17. n in {a...b}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. Integers
#     core type: Literal
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (n , {a...b})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. {a...b}
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (a , b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
