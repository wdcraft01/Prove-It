# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Forall([z], Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), domain = Complexes, conditions = []), conditions = [InSet(y, Complexes)])
# Out:
# expr: y -> [forall_{z in Complexes} (((x * y) / (x * z)) = (y / z))] | y in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> [forall_{z in Complexes} (((x * y) / (x * z)) = (y / z))] | y in Complexes
#    core type: Lambda
#    parameter: 25
#    body: 1
#    conditions: 2\n1. forall_{z in Complexes} (((x * y) / (x * z)) = (y / z))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. z -> (((x * y) / (x * z)) = (y / z)) | z in Complexes
#    core type: Lambda
#    parameter: 27
#    body: 6
#    conditions: 7\n5. y in Complexes
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. ((x * y) / (x * z)) = (y / z)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (y , Complexes)
#    core type: ExprTuple
#    sub-expressions: 25, 19
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. ((x * y) / (x * z) , y / z)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. z in Complexes
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (x * y) / (x * z)
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. y / z
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 27, 19
# 16. (x * y , x * z)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. /
#     core type: Literal
#     sub-expressions:
# 18. (y , z)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 19. Complexes
#     core type: Literal
#     sub-expressions:
# 20. x * y
#     core type: Operation
#     operator: 23
#     operands: 22
# 21. x * z
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (x , y)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (x , z)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. z
#     core type: Variable
#     sub-expressions:
