# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x
from proveit.logic import Equals, InSet, NotEquals
from proveit.number import Complexes, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Equals(frac(x, x), one), conditions = [InSet(x, Complexes), NotEquals(x, zero)])
# Out:
# expr: x -> ((x / x) = 1) | x in Complexes , x != 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> ((x / x) = 1) | x in Complexes , x != 0
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. (x / x) = 1
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complexes , x != 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (x / x , 1)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. x in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. x != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 7. x / x
#    core type: Operation
#    operator: 13
#    operands: 14
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 17, 15
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (x , 0)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 13. /
#     core type: Literal
#     sub-expressions:
# 14. (x , x)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 15. Complexes
#     core type: Literal
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. x
#     core type: Variable
#     sub-expressions:
