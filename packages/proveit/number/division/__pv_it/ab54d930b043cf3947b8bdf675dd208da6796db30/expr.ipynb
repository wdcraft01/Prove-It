# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Equals, InSet
from proveit.number import Complexes, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Lambda(z, Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), conditions = [InSet(z, Complexes)])
# Out:
# expr: z -> (((x * y) / (x * z)) = (y / z)) | z in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. z -> (((x * y) / (x * z)) = (y / z)) | z in Complexes
#    core type: Lambda
#    parameter: 21
#    body: 1
#    conditions: 2\n1. ((x * y) / (x * z)) = (y / z)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((x * y) / (x * z) , y / z)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. z in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (x * y) / (x * z)
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. y / z
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (z , Complexes)
#    core type: ExprTuple
#    sub-expressions: 21, 13
# 10. (x * y , x * z)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (y , z)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. x * y
#     core type: Operation
#     operator: 17
#     operands: 16
# 15. x * z
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x , y)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (x , z)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. z
#     core type: Variable
#     sub-expressions:
