# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.number import Exp, NaturalsPos, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([a, b], Equals(frac(Exp(a, n), Exp(b, n)), Exp(frac(a, b), n)), conditions = [NotEquals(b, zero)]), conditions = [InSet(n, NaturalsPos)])
# Out:
# expr: n -> [forall_{a, b | b != 0} ((a^{n} / b^{n}) = a / b^{n})] | n in NaturalsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{a, b | b != 0} ((a^{n} / b^{n}) = a / b^{n})] | n in NaturalsPos
#    core type: Lambda
#    parameter: 31
#    body: 1
#    conditions: 2\n1. forall_{a, b | b != 0} ((a^{n} / b^{n}) = a / b^{n})
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (n in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. a -> [forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})]
#    core type: Lambda
#    parameter: 32
#    body: 5
# 4. n in NaturalsPos
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (n , NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 31, 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. b -> ((a^{n} / b^{n}) = a / b^{n}) | b != 0
#    core type: Lambda
#    parameter: 33
#    body: 11
#    conditions: 12\n10. NaturalsPos
#     core type: Literal
#     sub-expressions:
# 11. (a^{n} / b^{n}) = a / b^{n}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (b != 0)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (a^{n} / b^{n} , a / b^{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. b != 0
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. a^{n} / b^{n}
#     core type: Operation
#     operator: 29
#     operands: 20
# 17. a / b^{n}
#     core type: Operation
#     operator: 27
#     operands: 21
# 18. !=
#     core type: Literal
#     sub-expressions:
# 19. (b , 0)
#     core type: ExprTuple
#     sub-expressions: 33, 22
# 20. (a^{n} , b^{n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (a / b , n)
#     core type: ExprTuple
#     sub-expressions: 25, 31
# 22. 0
#     core type: Literal
#     sub-expressions:
# 23. a^{n}
#     core type: Operation
#     operator: 27
#     operands: 26
# 24. b^{n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. a / b
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (a , n)
#     core type: ExprTuple
#     sub-expressions: 32, 31
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (b , n)
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (a , b)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. n
#     core type: Variable
#     sub-expressions:
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. b
#     core type: Variable
#     sub-expressions:
