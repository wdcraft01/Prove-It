# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import w, x, y, z
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg, frac

# %%
# build up the expression from sub-expressions
expr = Forall([y, z], Equals(frac(Add(w, Neg(x)), Add(y, Neg(z))), frac(Add(x, Neg(w)), Add(z, Neg(y)))), domain = Complexes, conditions = [])
# Out:
# expr: forall_{y, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. y -> [forall_{z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))] | y in Complexes
#    core type: Lambda
#    parameter: 38
#    body: 2
#    conditions: 3\n2. forall_{z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. z -> (((w - x) / (y - z)) = ((x - w) / (z - y))) | z in Complexes
#    core type: Lambda
#    parameter: 35
#    body: 7
#    conditions: 8\n6. y in Complexes
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. ((w - x) / (y - z)) = ((x - w) / (z - y))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (y , Complexes)
#    core type: ExprTuple
#    sub-expressions: 38, 20
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. ((w - x) / (y - z) , (x - w) / (z - y))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. z in Complexes
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (w - x) / (y - z)
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. (x - w) / (z - y)
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 35, 20
# 17. (w - x , y - z)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. /
#     core type: Literal
#     sub-expressions:
# 19. (x - w , z - y)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. Complexes
#     core type: Literal
#     sub-expressions:
# 21. w - x
#     core type: Operation
#     operator: 28
#     operands: 25
# 22. y - z
#     core type: Operation
#     operator: 28
#     operands: 26
# 23. x - w
#     core type: Operation
#     operator: 28
#     operands: 27
# 24. z - y
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (w , -x)
#     core type: ExprTuple
#     sub-expressions: 36, 30
# 26. (y , -z)
#     core type: ExprTuple
#     sub-expressions: 38, 31
# 27. (x , -w)
#     core type: ExprTuple
#     sub-expressions: 34, 32
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (z , -y)
#     core type: ExprTuple
#     sub-expressions: 35, 33
# 30. -x
#     core type: Operation
#     operator: 37
#     operand: 34
# 31. -z
#     core type: Operation
#     operator: 37
#     operand: 35
# 32. -w
#     core type: Operation
#     operator: 37
#     operand: 36
# 33. -y
#     core type: Operation
#     operator: 37
#     operand: 38
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. z
#     core type: Variable
#     sub-expressions:
# 36. w
#     core type: Variable
#     sub-expressions:
# 37. -
#     core type: Literal
#     sub-expressions:
# 38. y
#     core type: Variable
#     sub-expressions:
