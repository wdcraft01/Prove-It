# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fracCancelDenomLeft">fracCancelDenomLeft</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.division._theorems_ import fracCancelDenomLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr fracCancelDenomLeft
# Out:
# Passed sanity check: built 'fracCancelDenomLeft' is the same as the stored Expression.

# %%
# display the expression information
fracCancelDenomLeft.exprInfo()
# Out:
# 0. forall_{x, y in Complexes | x != 0} (((x * y) / x) = y)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. x -> [forall_{y in Complexes} (((x * y) / x) = y)] | x in Complexes , x != 0
#    core type: Lambda
#    parameter: 26
#    body: 2
#    conditions: 3\n2. forall_{y in Complexes} (((x * y) / x) = y)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x in Complexes , x != 0)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. y -> (((x * y) / x) = y) | y in Complexes
#    core type: Lambda
#    parameter: 27
#    body: 8
#    conditions: 9\n6. x in Complexes
#    core type: Operation
#    operator: 18
#    operands: 10
# 7. x != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. ((x * y) / x) = y
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 15
# 10. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 26, 22
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (x , 0)
#     core type: ExprTuple
#     sub-expressions: 26, 16
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. ((x * y) / x , y)
#     core type: ExprTuple
#     sub-expressions: 17, 27
# 15. y in Complexes
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. 0
#     core type: Literal
#     sub-expressions:
# 17. (x * y) / x
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 27, 22
# 20. /
#     core type: Literal
#     sub-expressions:
# 21. (x * y , x)
#     core type: ExprTuple
#     sub-expressions: 23, 26
# 22. Complexes
#     core type: Literal
#     sub-expressions:
# 23. x * y
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (x , y)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. y
#     core type: Variable
#     sub-expressions:
