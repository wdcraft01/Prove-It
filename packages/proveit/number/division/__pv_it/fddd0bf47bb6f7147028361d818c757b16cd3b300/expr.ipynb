# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#prodOfFracsRightNumerOne">prodOfFracsRightNumerOne</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.division._theorems_ import prodOfFracsRightNumerOne

# %%
# check that the built expression is the same as the stored expression
# %check_expr prodOfFracsRightNumerOne
# Out:
# Passed sanity check: built 'prodOfFracsRightNumerOne' is the same as the stored Expression.

# %%
# display the expression information
prodOfFracsRightNumerOne.exprInfo()
# Out:
# 0. forall_{x, y, z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. x -> [forall_{y, z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))] | x in Complexes
#    core type: Lambda
#    parameter: 33
#    body: 2
#    conditions: 3\n2. forall_{y, z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. y -> [forall_{z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))] | y in Complexes
#    core type: Lambda
#    parameter: 35
#    body: 6
#    conditions: 7\n5. x in Complexes
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall_{z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 33, 24
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. z -> (((x / y) * (1 / z)) = (x / (y * z))) | z in Complexes
#     core type: Lambda
#     parameter: 36
#     body: 12
#     conditions: 13\n11. y in Complexes
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. ((x / y) * (1 / z)) = (x / (y * z))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (z in Complexes)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 35, 24
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ((x / y) * (1 / z) , x / (y * z))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. z in Complexes
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (x / y) * (1 / z)
#     core type: Operation
#     operator: 31
#     operands: 22
# 19. x / (y * z)
#     core type: Operation
#     operator: 29
#     operands: 23
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 36, 24
# 22. (x / y , 1 / z)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. (x , y * z)
#     core type: ExprTuple
#     sub-expressions: 33, 27
# 24. Complexes
#     core type: Literal
#     sub-expressions:
# 25. x / y
#     core type: Operation
#     operator: 29
#     operands: 28
# 26. 1 / z
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. y * z
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. (x , y)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (1 , z)
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 31. *
#     core type: Literal
#     sub-expressions:
# 32. (y , z)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. x
#     core type: Variable
#     sub-expressions:
# 34. 1
#     core type: Literal
#     sub-expressions:
# 35. y
#     core type: Variable
#     sub-expressions:
# 36. z
#     core type: Variable
#     sub-expressions:
