# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import w, x, y, z
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Neg, frac

# %%
# build up the expression from sub-expressions
expr = Forall([x, y, z], Equals(frac(Add(w, Neg(x)), Add(y, Neg(z))), frac(Add(x, Neg(w)), Add(z, Neg(y)))), domain = Complexes, conditions = [])
# Out:
# expr: forall_{x, y, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{x, y, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. x -> [forall_{y, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))] | x in Complexes
#    core type: Lambda
#    parameter: 39
#    body: 2
#    conditions: 3\n2. forall_{y, z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. y -> [forall_{z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))] | y in Complexes
#    core type: Lambda
#    parameter: 43
#    body: 6
#    conditions: 7\n5. x in Complexes
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall_{z in Complexes} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 39, 25
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. z -> (((w - x) / (y - z)) = ((x - w) / (z - y))) | z in Complexes
#     core type: Lambda
#     parameter: 40
#     body: 12
#     conditions: 13\n11. y in Complexes
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. ((w - x) / (y - z)) = ((x - w) / (z - y))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (z in Complexes)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 43, 25
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ((w - x) / (y - z) , (x - w) / (z - y))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. z in Complexes
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (w - x) / (y - z)
#     core type: Operation
#     operator: 23
#     operands: 22
# 19. (x - w) / (z - y)
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 40, 25
# 22. (w - x , y - z)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (x - w , z - y)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. Complexes
#     core type: Literal
#     sub-expressions:
# 26. w - x
#     core type: Operation
#     operator: 33
#     operands: 30
# 27. y - z
#     core type: Operation
#     operator: 33
#     operands: 31
# 28. x - w
#     core type: Operation
#     operator: 33
#     operands: 32
# 29. z - y
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (w , -x)
#     core type: ExprTuple
#     sub-expressions: 41, 35
# 31. (y , -z)
#     core type: ExprTuple
#     sub-expressions: 43, 36
# 32. (x , -w)
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (z , -y)
#     core type: ExprTuple
#     sub-expressions: 40, 38
# 35. -x
#     core type: Operation
#     operator: 42
#     operand: 39
# 36. -z
#     core type: Operation
#     operator: 42
#     operand: 40
# 37. -w
#     core type: Operation
#     operator: 42
#     operand: 41
# 38. -y
#     core type: Operation
#     operator: 42
#     operand: 43
# 39. x
#     core type: Variable
#     sub-expressions:
# 40. z
#     core type: Variable
#     sub-expressions:
# 41. w
#     core type: Variable
#     sub-expressions:
# 42. -
#     core type: Literal
#     sub-expressions:
# 43. y
#     core type: Variable
#     sub-expressions:
