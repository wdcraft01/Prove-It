# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, NotEquals
from proveit.number import Exp, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], Equals(frac(Exp(a, n), Exp(b, n)), Exp(frac(a, b), n)), conditions = [NotEquals(b, zero)]))
# Out:
# expr: a -> [forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})]
#    core type: Lambda
#    parameter: 25
#    body: 1
# 1. forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. b -> ((a^{n} / b^{n}) = a / b^{n}) | b != 0
#    core type: Lambda
#    parameter: 26
#    body: 4
#    conditions: 5\n4. (a^{n} / b^{n}) = a / b^{n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (b != 0)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (a^{n} / b^{n} , a / b^{n})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. b != 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. a^{n} / b^{n}
#    core type: Operation
#    operator: 22
#    operands: 13
# 10. a / b^{n}
#     core type: Operation
#     operator: 20
#     operands: 14
# 11. !=
#     core type: Literal
#     sub-expressions:
# 12. (b , 0)
#     core type: ExprTuple
#     sub-expressions: 26, 15
# 13. (a^{n} , b^{n})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. (a / b , n)
#     core type: ExprTuple
#     sub-expressions: 18, 24
# 15. 0
#     core type: Literal
#     sub-expressions:
# 16. a^{n}
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. b^{n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. a / b
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (a , n)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (b , n)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. (a , b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. n
#     core type: Variable
#     sub-expressions:
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
