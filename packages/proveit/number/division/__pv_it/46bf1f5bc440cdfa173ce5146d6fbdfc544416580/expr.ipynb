# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multFracLeftCancel">multFracLeftCancel</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.division._theorems_ import multFracLeftCancel

# %%
# check that the built expression is the same as the stored expression
# %check_expr multFracLeftCancel
# Out:
# Passed sanity check: built 'multFracLeftCancel' is the same as the stored Expression.

# %%
# display the expression information
multFracLeftCancel.exprInfo()
# Out:
# 0. forall_{x, y in Complexes | y != 0} (((x / y) * y) = x)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. x -> [forall_{y in Complexes | y != 0} (((x / y) * y) = x)] | x in Complexes
#    core type: Lambda
#    parameter: 26
#    body: 2
#    conditions: 3\n2. forall_{y in Complexes | y != 0} (((x / y) * y) = x)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. y -> (((x / y) * y) = x) | y in Complexes , y != 0
#    core type: Lambda
#    parameter: 27
#    body: 7
#    conditions: 8\n6. x in Complexes
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. ((x / y) * y) = x
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (y in Complexes , y != 0)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 26, 21
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. ((x / y) * y , x)
#     core type: ExprTuple
#     sub-expressions: 14, 26
# 12. y in Complexes
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. y != 0
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (x / y) * y
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 17. !=
#     core type: Literal
#     sub-expressions:
# 18. (y , 0)
#     core type: ExprTuple
#     sub-expressions: 27, 22
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (x / y , y)
#     core type: ExprTuple
#     sub-expressions: 23, 27
# 21. Complexes
#     core type: Literal
#     sub-expressions:
# 22. 0
#     core type: Literal
#     sub-expressions:
# 23. x / y
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. /
#     core type: Literal
#     sub-expressions:
# 25. (x , y)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. y
#     core type: Variable
#     sub-expressions:
