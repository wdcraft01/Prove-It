# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, NotEquals
from proveit.number import Complexes, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Forall([y], Equals(Mult(frac(x, y), y), x), domain = Complexes, conditions = [NotEquals(y, zero)])
# Out:
# expr: forall_{y in Complexes | y != 0} (((x / y) * y) = x)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in Complexes | y != 0} (((x / y) * y) = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> (((x / y) * y) = x) | y in Complexes , y != 0
#    core type: Lambda
#    parameter: 22
#    body: 3
#    conditions: 4\n3. ((x / y) * y) = x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (y in Complexes , y != 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((x / y) * y , x)
#    core type: ExprTuple
#    sub-expressions: 9, 21
# 7. y in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. y != 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (x / y) * y
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 22, 16
# 12. !=
#     core type: Literal
#     sub-expressions:
# 13. (y , 0)
#     core type: ExprTuple
#     sub-expressions: 22, 17
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (x / y , y)
#     core type: ExprTuple
#     sub-expressions: 18, 22
# 16. Complexes
#     core type: Literal
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. x / y
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. /
#     core type: Literal
#     sub-expressions:
# 20. (x , y)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. y
#     core type: Variable
#     sub-expressions:
