# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.number import Complexes, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y, z], Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), domain = Complexes, conditions = []), conditions = [InSet(x, Complexes), NotEquals(x, zero)])
# Out:
# expr: x -> [forall_{y, z in Complexes} (((x * y) / (x * z)) = (y / z))] | x in Complexes , x != 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y, z in Complexes} (((x * y) / (x * z)) = (y / z))] | x in Complexes , x != 0
#    core type: Lambda
#    parameter: 35
#    body: 1
#    conditions: 2\n1. forall_{y, z in Complexes} (((x * y) / (x * z)) = (y / z))
#    core type: Operation
#    operator: 11
#    operand: 3
# 2. (x in Complexes , x != 0)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 3. y -> [forall_{z in Complexes} (((x * y) / (x * z)) = (y / z))] | y in Complexes
#    core type: Lambda
#    parameter: 34
#    body: 6
#    conditions: 7\n4. x in Complexes
#    core type: Operation
#    operator: 23
#    operands: 8
# 5. x != 0
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. forall_{z in Complexes} (((x * y) / (x * z)) = (y / z))
#    core type: Operation
#    operator: 11
#    operand: 12
# 7. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 13
# 8. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 35, 28
# 9. !=
#    core type: Literal
# ...
