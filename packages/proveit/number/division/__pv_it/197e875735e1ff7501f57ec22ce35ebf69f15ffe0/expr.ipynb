# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y, z
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Forall([z], Equals(Mult(frac(one, y), frac(x, z)), frac(x, Mult(y, z))), domain = Complexes, conditions = [])
# Out:
# expr: forall_{z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. z -> (((1 / y) * (x / z)) = (x / (y * z))) | z in Complexes
#    core type: Lambda
#    parameter: 26
#    body: 3
#    conditions: 4\n3. ((1 / y) * (x / z)) = (x / (y * z))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((1 / y) * (x / z) , x / (y * z))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. z in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (1 / y) * (x / z)
#    core type: Operation
#    operator: 21
#    operands: 12
# 9. x / (y * z)
#    core type: Operation
#    operator: 19
#    operands: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 26, 14
# 12. (1 / y , x / z)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. (x , y * z)
#     core type: ExprTuple
#     sub-expressions: 24, 17
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. 1 / y
#     core type: Operation
#     operator: 19
#     operands: 18
# 16. x / z
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. y * z
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. (1 , y)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 19. /
#     core type: Literal
#     sub-expressions:
# 20. (x , z)
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (y , z)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. 1
#     core type: Literal
#     sub-expressions:
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. z
#     core type: Variable
#     sub-expressions:
