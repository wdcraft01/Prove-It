# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fracIntExp">fracIntExp</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.division._theorems_ import fracIntExp

# %%
# check that the built expression is the same as the stored expression
# %check_expr fracIntExp
# Out:
# Passed sanity check: built 'fracIntExp' is the same as the stored Expression.

# %%
# display the expression information
fracIntExp.exprInfo()
# Out:
# 0. forall_{n in Integers} [forall_{a, b | a != 0 , b != 0} ((a^{n} / b^{n}) = a / b^{n})]
#    core type: Operation
#    operator: 10
#    operand: 1
# 1. n -> [forall_{a, b | a != 0 , b != 0} ((a^{n} / b^{n}) = a / b^{n})] | n in Integers
#    core type: Lambda
#    parameter: 35
#    body: 2
#    conditions: 3\n2. forall_{a, b | a != 0 , b != 0} ((a^{n} / b^{n}) = a / b^{n})
#    core type: Operation
#    operator: 10
#    operand: 4
# 3. (n in Integers)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. a -> [forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})] | a != 0
#    core type: Lambda
#    parameter: 36
#    body: 6
#    conditions: 7\n5. n in Integers
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})
#    core type: Operation
#    operator: 10
#    operand: 11
# 7. (a != 0)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (n , Integers)
#    core type: ExprTuple
#    sub-expressions: 35, 13
# 10. forall
#     core type: Literal
#     sub-expressions:
# 11. b -> ((a^{n} / b^{n}) = a / b^{n}) | b != 0
#     core type: Lambda
#     parameter: 37
#     body: 14
#     conditions: 15\n12. a != 0
#     core type: Operation
#     operator: 22
#     operands: 16
# 13. Integers
#     core type: Literal
#     sub-expressions:
# 14. (a^{n} / b^{n}) = a / b^{n}
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. (b != 0)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. (a , 0)
#     core type: ExprTuple
#     sub-expressions: 36, 26
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (a^{n} / b^{n} , a / b^{n})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. b != 0
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. a^{n} / b^{n}
#     core type: Operation
#     operator: 33
#     operands: 24
# 21. a / b^{n}
#     core type: Operation
#     operator: 31
#     operands: 25
# 22. !=
#     core type: Literal
#     sub-expressions:
# 23. (b , 0)
#     core type: ExprTuple
#     sub-expressions: 37, 26
# 24. (a^{n} , b^{n})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. (a / b , n)
#     core type: ExprTuple
#     sub-expressions: 29, 35
# 26. 0
#     core type: Literal
#     sub-expressions:
# 27. a^{n}
#     core type: Operation
#     operator: 31
#     operands: 30
# 28. b^{n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 29. a / b
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (a , n)
#     core type: ExprTuple
#     sub-expressions: 36, 35
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (b , n)
#     core type: ExprTuple
#     sub-expressions: 37, 35
# 33. /
#     core type: Literal
#     sub-expressions:
# 34. (a , b)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. a
#     core type: Variable
#     sub-expressions:
# 37. b
#     core type: Variable
#     sub-expressions:
