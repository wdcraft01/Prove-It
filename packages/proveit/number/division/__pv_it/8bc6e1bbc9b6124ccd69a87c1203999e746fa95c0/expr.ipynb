# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Forall([z], Equals(Mult(frac(x, y), frac(one, z)), frac(x, Mult(y, z))), domain = Complexes, conditions = []), conditions = [InSet(y, Complexes)])
# Out:
# expr: y -> [forall_{z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))] | y in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> [forall_{z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))] | y in Complexes
#    core type: Lambda
#    parameter: 29
#    body: 1
#    conditions: 2\n1. forall_{z in Complexes} (((x / y) * (1 / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. z -> (((x / y) * (1 / z)) = (x / (y * z))) | z in Complexes
#    core type: Lambda
#    parameter: 30
#    body: 6
#    conditions: 7\n5. y in Complexes
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. ((x / y) * (1 / z)) = (x / (y * z))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (z in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (y , Complexes)
#    core type: ExprTuple
#    sub-expressions: 29, 18
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. ((x / y) * (1 / z) , x / (y * z))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. z in Complexes
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (x / y) * (1 / z)
#     core type: Operation
#     operator: 25
#     operands: 16
# 13. x / (y * z)
#     core type: Operation
#     operator: 23
#     operands: 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 30, 18
# 16. (x / y , 1 / z)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. (x , y * z)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 18. Complexes
#     core type: Literal
#     sub-expressions:
# 19. x / y
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. 1 / z
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. y * z
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. (x , y)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (1 , z)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (y , z)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. y
#     core type: Variable
#     sub-expressions:
# 30. z
#     core type: Variable
#     sub-expressions:
