# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fracOneDenom">fracOneDenom</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.division._theorems_ import fracOneDenom

# %%
# check that the built expression is the same as the stored expression
# %check_expr fracOneDenom
# Out:
# Passed sanity check: built 'fracOneDenom' is the same as the stored Expression.

# %%
# display the expression information
fracOneDenom.exprInfo()
# Out:
# 0. forall_{x in Complexes} ((x / 1) = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x / 1) = x) | x in Complexes
#    core type: Lambda
#    parameter: 14
#    body: 3
#    conditions: 4\n3. (x / 1) = x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x / 1 , x)
#    core type: ExprTuple
#    sub-expressions: 8, 14
# 7. x in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. x / 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. /
#     core type: Literal
#     sub-expressions:
# 12. (x , 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Complexes
# ...
