# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, n
from proveit.logic import Equals, Forall, NotEquals
from proveit.number import Exp, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Forall([b], Equals(frac(Exp(a, n), Exp(b, n)), Exp(frac(a, b), n)), conditions = [NotEquals(b, zero)]), conditions = [NotEquals(a, zero)])
# Out:
# expr: a -> [forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})] | a != 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> [forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})] | a != 0
#    core type: Lambda
#    parameter: 28
#    body: 1
#    conditions: 2\n1. forall_{b | b != 0} ((a^{n} / b^{n}) = a / b^{n})
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (a != 0)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> ((a^{n} / b^{n}) = a / b^{n}) | b != 0
#    core type: Lambda
#    parameter: 29
#    body: 6
#    conditions: 7\n5. a != 0
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. (a^{n} / b^{n}) = a / b^{n}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (b != 0)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (a , 0)
#    core type: ExprTuple
#    sub-expressions: 28, 18
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (a^{n} / b^{n} , a / b^{n})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. b != 0
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. a^{n} / b^{n}
#     core type: Operation
#     operator: 25
#     operands: 16
# 13. a / b^{n}
#     core type: Operation
#     operator: 23
#     operands: 17
# 14. !=
#     core type: Literal
#     sub-expressions:
# 15. (b , 0)
#     core type: ExprTuple
#     sub-expressions: 29, 18
# 16. (a^{n} , b^{n})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. (a / b , n)
#     core type: ExprTuple
#     sub-expressions: 21, 27
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. a^{n}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. b^{n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. a / b
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. (a , n)
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 23. Exp
#     core type: Literal
#     sub-expressions:
# 24. (b , n)
#     core type: ExprTuple
#     sub-expressions: 29, 27
# 25. /
#     core type: Literal
#     sub-expressions:
# 26. (a , b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. a
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
