# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import w, x, y, z
from proveit.logic import Equals, InSet
from proveit.number import Complexes, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Lambda(w, Equals(Mult(frac(x, z), frac(y, w)), frac(Mult(x, y), Mult(z, w))), conditions = [InSet(w, Complexes)])
# Out:
# expr: w -> (((x / z) * (y / w)) = ((x * y) / (z * w))) | w in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. w -> (((x / z) * (y / w)) = ((x * y) / (z * w))) | w in Complexes
#    core type: Lambda
#    parameter: 26
#    body: 1
#    conditions: 2\n1. ((x / z) * (y / w)) = ((x * y) / (z * w))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (w in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((x / z) * (y / w) , (x * y) / (z * w))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. w in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (x / z) * (y / w)
#    core type: Operation
#    operator: 21
#    operands: 10
# 7. (x * y) / (z * w)
#    core type: Operation
#    operator: 18
#    operands: 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (w , Complexes)
#    core type: ExprTuple
#    sub-expressions: 26, 12
# 10. (x / z , y / w)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. (x * y , z * w)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. x / z
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. y / w
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. x * y
#     core type: Operation
#     operator: 21
#     operands: 20
# 16. z * w
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. (x , z)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 18. /
#     core type: Literal
#     sub-expressions:
# 19. (y , w)
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 20. (x , y)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (z , w)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. y
#     core type: Variable
#     sub-expressions:
# 25. z
#     core type: Variable
#     sub-expressions:
# 26. w
#     core type: Variable
#     sub-expressions:
