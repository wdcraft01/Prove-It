# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#fracNotEqZero">fracNotEqZero</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.division._theorems_ import fracNotEqZero

# %%
# check that the built expression is the same as the stored expression
# %check_expr fracNotEqZero
# Out:
# Passed sanity check: built 'fracNotEqZero' is the same as the stored Expression.

# %%
# display the expression information
fracNotEqZero.exprInfo()
# Out:
# 0. forall_{a, b in Complexes - {0}} ((a / b) != 0)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Complexes - {0}} ((a / b) != 0)] | a in (Complexes - {0})
#    core type: Lambda
#    parameter: 19
#    body: 2
#    conditions: 3\n2. forall_{b in Complexes - {0}} ((a / b) != 0)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in (Complexes - {0}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((a / b) != 0) | b in (Complexes - {0})
#    core type: Lambda
#    parameter: 20
#    body: 7
#    conditions: 8\n6. a in (Complexes - {0})
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (a / b) != 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (b in (Complexes - {0}))
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (a , Complexes - {0})
#    core type: ExprTuple
#    sub-expressions: 19, 18
# 10. !=
#     core type: Literal
#     sub-expressions:
# 11. (a / b , 0)
#     core type: ExprTuple
#     sub-expressions: 13, 27
# 12. b in (Complexes - {0})
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. a / b
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b , Complexes - {0})
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (a , b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. Complexes - {0}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (Complexes , {0})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. Complexes
#     core type: Literal
#     sub-expressions:
# 24. {0}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Set
#     core type: Literal
#     sub-expressions:
# 26. (0)
#     core type: ExprTuple
#     sub-expressions: 27
# 27. 0
#     core type: Literal
#     sub-expressions:
