# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, InSet, NotEquals
from proveit.number import Complexes, Mult, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(frac(x, Mult(x, y)), frac(one, y)), domain = Complexes, conditions = []), conditions = [InSet(x, Complexes), NotEquals(x, zero)])
# Out:
# expr: x -> [forall_{y in Complexes} ((x / (x * y)) = (1 / y))] | x in Complexes , x != 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y in Complexes} ((x / (x * y)) = (1 / y))] | x in Complexes , x != 0
#    core type: Lambda
#    parameter: 28
#    body: 1
#    conditions: 2\n1. forall_{y in Complexes} ((x / (x * y)) = (1 / y))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x in Complexes , x != 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((x / (x * y)) = (1 / y)) | y in Complexes
#    core type: Lambda
#    parameter: 29
#    body: 7
#    conditions: 8\n5. x in Complexes
#    core type: Operation
#    operator: 18
#    operands: 9
# 6. x != 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (x / (x * y)) = (1 / y)
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 14
# 9. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 28, 23
# 10. !=
#     core type: Literal
#     sub-expressions:
# ...
