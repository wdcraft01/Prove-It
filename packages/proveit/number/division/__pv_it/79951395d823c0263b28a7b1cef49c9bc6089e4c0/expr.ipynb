# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Forall([y], Equals(frac(x, Mult(x, y)), frac(one, y)), domain = Complexes, conditions = [])
# Out:
# expr: forall_{y in Complexes} ((x / (x * y)) = (1 / y))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in Complexes} ((x / (x * y)) = (1 / y))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> ((x / (x * y)) = (1 / y)) | y in Complexes
#    core type: Lambda
#    parameter: 21
#    body: 3
#    conditions: 4\n3. (x / (x * y)) = (1 / y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x / (x * y) , 1 / y)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. y in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x / (x * y)
#    core type: Operation
#    operator: 13
#    operands: 12
# 9. 1 / y
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 21, 15
# 12. (x , x * y)
#     core type: ExprTuple
#     sub-expressions: 20, 16
# 13. /
#     core type: Literal
#     sub-expressions:
# 14. (1 , y)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 15. Complexes
#     core type: Literal
#     sub-expressions:
# 16. x * y
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (x , y)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. y
#     core type: Variable
#     sub-expressions:
