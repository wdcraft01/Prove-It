# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y, z
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y, z], Equals(Mult(frac(one, y), frac(x, z)), frac(x, Mult(y, z))), domain = Complexes, conditions = []), conditions = [InSet(x, Complexes)])
# Out:
# expr: x -> [forall_{y, z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))] | x in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y, z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))] | x in Complexes
#    core type: Lambda
#    parameter: 33
#    body: 1
#    conditions: 2\n1. forall_{y, z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. y -> [forall_{z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))] | y in Complexes
#    core type: Lambda
#    parameter: 34
#    body: 5
#    conditions: 6\n4. x in Complexes
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. forall_{z in Complexes} (((1 / y) * (x / z)) = (x / (y * z)))
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 33, 23
# 8. forall
#    core type: Literal
#    sub-expressions:
# 9. z -> (((1 / y) * (x / z)) = (x / (y * z))) | z in Complexes
#    core type: Lambda
#    parameter: 35
#    body: 11
#    conditions: 12\n10. y in Complexes
#     core type: Operation
#     operator: 19
#     operands: 13
# 11. ((1 / y) * (x / z)) = (x / (y * z))
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (z in Complexes)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 34, 23
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. ((1 / y) * (x / z) , x / (y * z))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. z in Complexes
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (1 / y) * (x / z)
#     core type: Operation
#     operator: 30
#     operands: 21
# 18. x / (y * z)
#     core type: Operation
#     operator: 28
#     operands: 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (z , Complexes)
#     core type: ExprTuple
#     sub-expressions: 35, 23
# 21. (1 / y , x / z)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. (x , y * z)
#     core type: ExprTuple
#     sub-expressions: 33, 26
# 23. Complexes
#     core type: Literal
#     sub-expressions:
# 24. 1 / y
#     core type: Operation
#     operator: 28
#     operands: 27
# 25. x / z
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. y * z
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. (1 , y)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 28. /
#     core type: Literal
#     sub-expressions:
# 29. (x , z)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (y , z)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. x
#     core type: Variable
#     sub-expressions:
# 34. y
#     core type: Variable
#     sub-expressions:
# 35. z
#     core type: Variable
#     sub-expressions:
