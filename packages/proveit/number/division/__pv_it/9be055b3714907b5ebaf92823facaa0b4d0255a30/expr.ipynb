# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.division</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import w, x, y, z
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y, z, w], Equals(Mult(frac(x, z), frac(y, w)), frac(Mult(x, y), Mult(z, w))), domain = Complexes, conditions = []), conditions = [InSet(x, Complexes)])
# Out:
# expr: x -> [forall_{y, z, w in Complexes} (((x / z) * (y / w)) = ((x * y) / (z * w)))] | x in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y, z, w in Complexes} (((x / z) * (y / w)) = ((x * y) / (z * w)))] | x in Complexes
#    core type: Lambda
#    parameter: 39
#    body: 1
#    conditions: 2\n1. forall_{y, z, w in Complexes} (((x / z) * (y / w)) = ((x * y) / (z * w)))
#    core type: Operation
#    operator: 13
#    operand: 3
# 2. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. y -> [forall_{z, w in Complexes} (((x / z) * (y / w)) = ((x * y) / (z * w)))] | y in Complexes
#    core type: Lambda
#    parameter: 40
#    body: 5
#    conditions: 6\n4. x in Complexes
#    core type: Operation
#    operator: 24
#    operands: 7
# 5. forall_{z, w in Complexes} (((x / z) * (y / w)) = ((x * y) / (z * w)))
#    core type: Operation
#    operator: 13
#    operand: 8
# 6. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 39, 28
# ...
