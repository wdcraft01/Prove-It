# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.summation</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import m, x
from proveit.number import Add, Exp, Interval, Neg, Sum, frac, infinity, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Sum([m], Exp(x, m), domain = Interval(zero, infinity), conditions = []), frac(one, Add(one, Neg(x))))
# Out:
# expr: (Sum_{m=0}^{infinity} x^{m} , 1 / (1 - x))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (Sum_{m=0}^{infinity} x^{m} , 1 / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{m=0}^{infinity} x^{m}
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. 1 / (1 - x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. m -> x^{m} | m in {0...infinity}
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n5. /
#    core type: Literal
#    sub-expressions:
# 6. (1 , 1 - x)
#    core type: ExprTuple
#    sub-expressions: 17, 9
# 7. x^{m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (m in {0...infinity})
#    core type: ExprTuple
#    sub-expressions: 12
# 9. 1 - x
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (x , m)
#     core type: ExprTuple
#     sub-expressions: 22, 19
# 12. m in {0...infinity}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (1 , -x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (m , {0...infinity})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. -x
#     core type: Operation
#     operator: 21
#     operand: 22
# 19. m
#     core type: Variable
#     sub-expressions:
# 20. {0...infinity}
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (0 , infinity)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. 0
#     core type: Literal
#     sub-expressions:
# 26. infinity
#     core type: Literal
#     sub-expressions:
