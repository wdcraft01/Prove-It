# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, e, f
from proveit.logic import Equals, Forall
from proveit.number import Len, six

# %%
# build up the expression from sub-expressions
expr = Forall([b, c, d, e, f], Equals(Len([a, b, c, d, e, f]), six), conditions = [])
# Out:
# expr: forall_{b, c, d, e, f} (|(a , b , c , d , e , f)| = 6)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c, d, e, f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. b -> [forall_{c, d, e, f} (|(a , b , c , d , e , f)| = 6)]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{c, d, e, f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 9
#    operand: 3
# 3. c -> [forall_{d, e, f} (|(a , b , c , d , e , f)| = 6)]
#    core type: Lambda
#    parameter: 20
#    body: 4
# 4. forall_{d, e, f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 9
#    operand: 5
# 5. d -> [forall_{e, f} (|(a , b , c , d , e , f)| = 6)]
#    core type: Lambda
#    parameter: 21
#    body: 6
# 6. forall_{e, f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 9
#    operand: 7
# 7. e -> [forall_{f} (|(a , b , c , d , e , f)| = 6)]
#    core type: Lambda
#    parameter: 22
#    body: 8
# 8. forall_{f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. f -> (|(a , b , c , d , e , f)| = 6)
#     core type: Lambda
#     parameter: 23
#     body: 11
# 11. |(a , b , c , d , e , f)| = 6
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. =
#     core type: Literal
#     sub-expressions:
# 13. (|(a , b , c , d , e , f)| , 6)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. |(a , b , c , d , e , f)|
#     core type: Operation
#     operator: 16
#     operand: 17
# 15. 6
#     core type: Literal
#     sub-expressions:
# 16. length
#     core type: Literal
#     sub-expressions:
# 17. (a , b , c , d , e , f)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20, 21, 22, 23
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. d
#     core type: Variable
#     sub-expressions:
# 22. e
#     core type: Variable
#     sub-expressions:
# 23. f
#     core type: Variable
#     sub-expressions:
