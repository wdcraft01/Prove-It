# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d
from proveit.logic import Equals, Forall
from proveit.number import Len, four

# %%
# build up the expression from sub-expressions
expr = Forall([b, c, d], Equals(Len([a, b, c, d]), four), conditions = [])
# Out:
# expr: forall_{b, c, d} (|(a , b , c , d)| = 4)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c, d} (|(a , b , c , d)| = 4)
#    core type: Operation
#    operator: 5
#    operand: 1
# 1. b -> [forall_{c, d} (|(a , b , c , d)| = 4)]
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. forall_{c, d} (|(a , b , c , d)| = 4)
#    core type: Operation
#    operator: 5
#    operand: 3
# 3. c -> [forall_{d} (|(a , b , c , d)| = 4)]
#    core type: Lambda
#    parameter: 16
#    body: 4
# 4. forall_{d} (|(a , b , c , d)| = 4)
#    core type: Operation
#    operator: 5
#    operand: 6
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. d -> (|(a , b , c , d)| = 4)
#    core type: Lambda
#    parameter: 17
#    body: 7
# 7. |(a , b , c , d)| = 4
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (|(a , b , c , d)| , 4)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. |(a , b , c , d)|
#     core type: Operation
#     operator: 12
#     operand: 13
# 11. 4
#     core type: Literal
#     sub-expressions:
# 12. length
#     core type: Literal
#     sub-expressions:
# 13. (a , b , c , d)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. d
#     core type: Variable
#     sub-expressions:
