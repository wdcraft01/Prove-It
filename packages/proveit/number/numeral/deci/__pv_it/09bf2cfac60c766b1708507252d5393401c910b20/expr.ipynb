# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d, e, f, g, h, i
from proveit.logic import Equals, Forall
from proveit.number import Len, nine

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c, d, e, f, g, h, i], Equals(Len([a, b, c, d, e, f, g, h, i]), nine), conditions = []))
# Out:
# expr: b -> [forall_{c, d, e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c, d, e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 24
#    body: 1
# 1. forall_{c, d, e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 14
#    operand: 2
# 2. c -> [forall_{d, e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 25
#    body: 3
# 3. forall_{d, e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 14
#    operand: 4
# 4. d -> [forall_{e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 26
#    body: 5
# 5. forall_{e, f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 14
#    operand: 6
# 6. e -> [forall_{f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 27
#    body: 7
# 7. forall_{f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 14
#    operand: 8
# 8. f -> [forall_{g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 28
#    body: 9
# 9. forall_{g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 14
#    operand: 10
# 10. g -> [forall_{h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#     core type: Lambda
#     parameter: 29
#     body: 11
# 11. forall_{h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#     core type: Operation
#     operator: 14
#     operand: 12
# 12. h -> [forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#     core type: Lambda
#     parameter: 30
#     body: 13
# 13. forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#     core type: Operation
#     operator: 14
#     operand: 15
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. i -> (|(a , b , c , d , e , f , g , h , i)| = 9)
#     core type: Lambda
#     parameter: 31
#     body: 16
# 16. |(a , b , c , d , e , f , g , h , i)| = 9
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (|(a , b , c , d , e , f , g , h , i)| , 9)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. |(a , b , c , d , e , f , g , h , i)|
#     core type: Operation
#     operator: 21
#     operand: 22
# 20. 9
#     core type: Literal
#     sub-expressions:
# 21. length
#     core type: Literal
#     sub-expressions:
# 22. (a , b , c , d , e , f , g , h , i)
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25, 26, 27, 28, 29, 30, 31
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. d
#     core type: Variable
#     sub-expressions:
# 27. e
#     core type: Variable
#     sub-expressions:
# 28. f
#     core type: Variable
#     sub-expressions:
# 29. g
#     core type: Variable
#     sub-expressions:
# 30. h
#     core type: Variable
#     sub-expressions:
# 31. i
#     core type: Variable
#     sub-expressions:
