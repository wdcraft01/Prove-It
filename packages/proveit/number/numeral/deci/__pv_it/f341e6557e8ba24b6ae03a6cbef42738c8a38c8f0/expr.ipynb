# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#listLen5">listLen5</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.numeral.deci._theorems_ import listLen5

# %%
# check that the built expression is the same as the stored expression
# %check_expr listLen5
# Out:
# Passed sanity check: built 'listLen5' is the same as the stored Expression.

# %%
# display the expression information
listLen5.exprInfo()
# Out:
# 0. forall_{a, b, c, d, e} (|(a , b , c , d , e)| = 5)
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. a -> [forall_{b, c, d, e} (|(a , b , c , d , e)| = 5)]
#    core type: Lambda
#    parameter: 18
#    body: 2
# 2. forall_{b, c, d, e} (|(a , b , c , d , e)| = 5)
#    core type: Operation
#    operator: 9
#    operand: 3
# 3. b -> [forall_{c, d, e} (|(a , b , c , d , e)| = 5)]
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. forall_{c, d, e} (|(a , b , c , d , e)| = 5)
#    core type: Operation
#    operator: 9
#    operand: 5
# 5. c -> [forall_{d, e} (|(a , b , c , d , e)| = 5)]
#    core type: Lambda
#    parameter: 20
#    body: 6
# 6. forall_{d, e} (|(a , b , c , d , e)| = 5)
#    core type: Operation
#    operator: 9
#    operand: 7
# 7. d -> [forall_{e} (|(a , b , c , d , e)| = 5)]
#    core type: Lambda
#    parameter: 21
#    body: 8
# 8. forall_{e} (|(a , b , c , d , e)| = 5)
#    core type: Operation
#    operator: 9
#    operand: 10
# 9. forall
# ...
