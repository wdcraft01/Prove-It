# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, e, f, g, h
from proveit.logic import Equals, Forall
from proveit.number import Len, eight

# %%
# build up the expression from sub-expressions
expr = Forall([b, c, d, e, f, g, h], Equals(Len([a, b, c, d, e, f, g, h]), eight), conditions = [])
# Out:
# expr: forall_{b, c, d, e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c, d, e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)
#    core type: Operation
#    operator: 13
#    operand: 1
# 1. b -> [forall_{c, d, e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)]
#    core type: Lambda
#    parameter: 23
#    body: 2
# 2. forall_{c, d, e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)
#    core type: Operation
#    operator: 13
#    operand: 3
# 3. c -> [forall_{d, e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)]
#    core type: Lambda
#    parameter: 24
#    body: 4
# 4. forall_{d, e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)
#    core type: Operation
#    operator: 13
#    operand: 5
# 5. d -> [forall_{e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)]
#    core type: Lambda
#    parameter: 25
#    body: 6
# 6. forall_{e, f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)
#    core type: Operation
#    operator: 13
#    operand: 7
# 7. e -> [forall_{f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)]
#    core type: Lambda
#    parameter: 26
#    body: 8
# 8. forall_{f, g, h} (|(a , b , c , d , e , f , g , h)| = 8)
#    core type: Operation
#    operator: 13
#    operand: 9
# 9. f -> [forall_{g, h} (|(a , b , c , d , e , f , g , h)| = 8)]
#    core type: Lambda
#    parameter: 27
#    body: 10
# 10. forall_{g, h} (|(a , b , c , d , e , f , g , h)| = 8)
#     core type: Operation
#     operator: 13
#     operand: 11
# 11. g -> [forall_{h} (|(a , b , c , d , e , f , g , h)| = 8)]
#     core type: Lambda
#     parameter: 28
#     body: 12
# 12. forall_{h} (|(a , b , c , d , e , f , g , h)| = 8)
#     core type: Operation
#     operator: 13
#     operand: 14
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. h -> (|(a , b , c , d , e , f , g , h)| = 8)
#     core type: Lambda
#     parameter: 29
#     body: 15
# 15. |(a , b , c , d , e , f , g , h)| = 8
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (|(a , b , c , d , e , f , g , h)| , 8)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. |(a , b , c , d , e , f , g , h)|
#     core type: Operation
#     operator: 20
#     operand: 21
# 19. 8
#     core type: Literal
#     sub-expressions:
# 20. length
#     core type: Literal
#     sub-expressions:
# 21. (a , b , c , d , e , f , g , h)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24, 25, 26, 27, 28, 29
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
# 25. d
#     core type: Variable
#     sub-expressions:
# 26. e
#     core type: Variable
#     sub-expressions:
# 27. f
#     core type: Variable
#     sub-expressions:
# 28. g
#     core type: Variable
#     sub-expressions:
# 29. h
#     core type: Variable
#     sub-expressions:
