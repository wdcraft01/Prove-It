# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall
from proveit.number import Len, three

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Forall([c], Equals(Len([a, b, c]), three), conditions = []))
# Out:
# expr: b -> [forall_{c} (|(a , b , c)| = 3)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> [forall_{c} (|(a , b , c)| = 3)]
#    core type: Lambda
#    parameter: 12
#    body: 1
# 1. forall_{c} (|(a , b , c)| = 3)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. c -> (|(a , b , c)| = 3)
#    core type: Lambda
#    parameter: 13
#    body: 4
# 4. |(a , b , c)| = 3
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(a , b , c)| , 3)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. |(a , b , c)|
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. 3
#    core type: Literal
#    sub-expressions:
# 9. length
#    core type: Literal
#    sub-expressions:
# 10. (a , b , c)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
