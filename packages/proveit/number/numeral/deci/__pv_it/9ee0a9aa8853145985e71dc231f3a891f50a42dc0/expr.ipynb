# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d, e, f, g, h
from proveit.logic import Equals
from proveit.number import Len, eight

# %%
# build up the expression from sub-expressions
expr = Lambda(h, Equals(Len([a, b, c, d, e, f, g, h]), eight))
# Out:
# expr: h -> (|(a , b , c , d , e , f , g , h)| = 8)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. h -> (|(a , b , c , d , e , f , g , h)| = 8)
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. |(a , b , c , d , e , f , g , h)| = 8
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (|(a , b , c , d , e , f , g , h)| , 8)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. |(a , b , c , d , e , f , g , h)|
#    core type: Operation
#    operator: 6
#    operand: 7
# 5. 8
#    core type: Literal
#    sub-expressions:
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. (a , b , c , d , e , f , g , h)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11, 12, 13, 14, 15
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. d
#     core type: Variable
#     sub-expressions:
# 12. e
#     core type: Variable
#     sub-expressions:
# 13. f
#     core type: Variable
#     sub-expressions:
# 14. g
#     core type: Variable
#     sub-expressions:
# 15. h
#     core type: Variable
#     sub-expressions:
