# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d, e, f, g
from proveit.logic import Equals, Forall
from proveit.number import Len, seven

# %%
# build up the expression from sub-expressions
expr = Lambda(d, Forall([e, f, g], Equals(Len([a, b, c, d, e, f, g]), seven), conditions = []))
# Out:
# expr: d -> [forall_{e, f, g} (|(a , b , c , d , e , f , g)| = 7)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. d -> [forall_{e, f, g} (|(a , b , c , d , e , f , g)| = 7)]
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. forall_{e, f, g} (|(a , b , c , d , e , f , g)| = 7)
#    core type: Operation
#    operator: 6
#    operand: 2
# 2. e -> [forall_{f, g} (|(a , b , c , d , e , f , g)| = 7)]
#    core type: Lambda
#    parameter: 19
#    body: 3
# 3. forall_{f, g} (|(a , b , c , d , e , f , g)| = 7)
#    core type: Operation
#    operator: 6
#    operand: 4
# 4. f -> [forall_{g} (|(a , b , c , d , e , f , g)| = 7)]
#    core type: Lambda
#    parameter: 20
#    body: 5
# 5. forall_{g} (|(a , b , c , d , e , f , g)| = 7)
#    core type: Operation
#    operator: 6
#    operand: 7
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. g -> (|(a , b , c , d , e , f , g)| = 7)
#    core type: Lambda
#    parameter: 21
#    body: 8
# 8. |(a , b , c , d , e , f , g)| = 7
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (|(a , b , c , d , e , f , g)| , 7)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. |(a , b , c , d , e , f , g)|
#     core type: Operation
#     operator: 13
#     operand: 14
# 12. 7
#     core type: Literal
#     sub-expressions:
# 13. length
#     core type: Literal
#     sub-expressions:
# 14. (a , b , c , d , e , f , g)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18, 19, 20, 21
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. d
#     core type: Variable
#     sub-expressions:
# 19. e
#     core type: Variable
#     sub-expressions:
# 20. f
#     core type: Variable
#     sub-expressions:
# 21. g
#     core type: Variable
#     sub-expressions:
