# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, e, f, g, h, i
from proveit.logic import Equals, Forall
from proveit.number import Len, nine

# %%
# build up the expression from sub-expressions
expr = Forall([f, g, h, i], Equals(Len([a, b, c, d, e, f, g, h, i]), nine), conditions = [])
# Out:
# expr: forall_{f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{f, g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 7
#    operand: 1
# 1. f -> [forall_{g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. forall_{g, h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 7
#    operand: 3
# 3. g -> [forall_{h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 22
#    body: 4
# 4. forall_{h, i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 7
#    operand: 5
# 5. h -> [forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 23
#    body: 6
# 6. forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 7
#    operand: 8
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. i -> (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Lambda
#    parameter: 24
#    body: 9
# 9. |(a , b , c , d , e , f , g , h , i)| = 9
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (|(a , b , c , d , e , f , g , h , i)| , 9)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. |(a , b , c , d , e , f , g , h , i)|
#     core type: Operation
#     operator: 14
#     operand: 15
# 13. 9
#     core type: Literal
#     sub-expressions:
# 14. length
#     core type: Literal
#     sub-expressions:
# 15. (a , b , c , d , e , f , g , h , i)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19, 20, 21, 22, 23, 24
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. c
#     core type: Variable
#     sub-expressions:
# 19. d
#     core type: Variable
#     sub-expressions:
# 20. e
#     core type: Variable
#     sub-expressions:
# 21. f
#     core type: Variable
#     sub-expressions:
# 22. g
#     core type: Variable
#     sub-expressions:
# 23. h
#     core type: Variable
#     sub-expressions:
# 24. i
#     core type: Variable
#     sub-expressions:
