# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d, e, f, g, h, i
from proveit.logic import Equals, Forall
from proveit.number import Len, nine

# %%
# build up the expression from sub-expressions
expr = Lambda(h, Forall([i], Equals(Len([a, b, c, d, e, f, g, h, i]), nine), conditions = []))
# Out:
# expr: h -> [forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. h -> [forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)]
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. forall_{i} (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. i -> (|(a , b , c , d , e , f , g , h , i)| = 9)
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. |(a , b , c , d , e , f , g , h , i)| = 9
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(a , b , c , d , e , f , g , h , i)| , 9)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. |(a , b , c , d , e , f , g , h , i)|
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. 9
#    core type: Literal
#    sub-expressions:
# 9. length
#    core type: Literal
#    sub-expressions:
# 10. (a , b , c , d , e , f , g , h , i)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13, 14, 15, 16, 17, 18, 19
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. g
#     core type: Variable
#     sub-expressions:
# 18. h
#     core type: Variable
#     sub-expressions:
# 19. i
#     core type: Variable
#     sub-expressions:
