# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c, d, e, f
from proveit.logic import Equals, Forall
from proveit.number import Len, six

# %%
# build up the expression from sub-expressions
expr = Forall([e, f], Equals(Len([a, b, c, d, e, f]), six), conditions = [])
# Out:
# expr: forall_{e, f} (|(a , b , c , d , e , f)| = 6)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{e, f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. e -> [forall_{f} (|(a , b , c , d , e , f)| = 6)]
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. forall_{f} (|(a , b , c , d , e , f)| = 6)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. f -> (|(a , b , c , d , e , f)| = 6)
#    core type: Lambda
#    parameter: 17
#    body: 5
# 5. |(a , b , c , d , e , f)| = 6
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (|(a , b , c , d , e , f)| , 6)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. |(a , b , c , d , e , f)|
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. 6
#    core type: Literal
#    sub-expressions:
# 10. length
#     core type: Literal
#     sub-expressions:
# 11. (a , b , c , d , e , f)
#     core type: ExprTuple
#     sub-expressions: 12, 13, 14, 15, 16, 17
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. d
#     core type: Variable
#     sub-expressions:
# 16. e
#     core type: Variable
#     sub-expressions:
# 17. f
#     core type: Variable
#     sub-expressions:
