# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#listLen2">listLen2</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.numeral.deci._theorems_ import listLen2

# %%
# check that the built expression is the same as the stored expression
# %check_expr listLen2
# Out:
# Passed sanity check: built 'listLen2' is the same as the stored Expression.

# %%
# display the expression information
listLen2.exprInfo()
# Out:
# 0. forall_{a, b} (|(a , b)| = 2)
#    core type: Operation
#    operator: 3
#    operand: 1
# 1. a -> [forall_{b} (|(a , b)| = 2)]
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. forall_{b} (|(a , b)| = 2)
#    core type: Operation
#    operator: 3
#    operand: 4
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. b -> (|(a , b)| = 2)
#    core type: Lambda
#    parameter: 13
#    body: 5
# 5. |(a , b)| = 2
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (|(a , b)| , 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. |(a , b)|
#    core type: Operation
#    operator: 10
#    operand: 11
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. length
#     core type: Literal
#     sub-expressions:
# 11. (a , b)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
