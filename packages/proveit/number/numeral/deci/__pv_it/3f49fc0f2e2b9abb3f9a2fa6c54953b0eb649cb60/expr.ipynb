# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.numeral.deci</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b, c, d, e, f, g
from proveit.logic import Equals, Forall
from proveit.number import Len, seven

# %%
# build up the expression from sub-expressions
expr = Lambda(f, Forall([g], Equals(Len([a, b, c, d, e, f, g]), seven), conditions = []))
# Out:
# expr: f -> [forall_{g} (|(a , b , c , d , e , f , g)| = 7)]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. f -> [forall_{g} (|(a , b , c , d , e , f , g)| = 7)]
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. forall_{g} (|(a , b , c , d , e , f , g)| = 7)
#    core type: Operation
#    operator: 2
#    operand: 3
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. g -> (|(a , b , c , d , e , f , g)| = 7)
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. |(a , b , c , d , e , f , g)| = 7
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(a , b , c , d , e , f , g)| , 7)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. |(a , b , c , d , e , f , g)|
#    core type: Operation
#    operator: 9
#    operand: 10
# 8. 7
#    core type: Literal
#    sub-expressions:
# 9. length
#    core type: Literal
#    sub-expressions:
# 10. (a , b , c , d , e , f , g)
#     core type: ExprTuple
#     sub-expressions: 11, 12, 13, 14, 15, 16, 17
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. e
#     core type: Variable
#     sub-expressions:
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. g
#     core type: Variable
#     sub-expressions:
