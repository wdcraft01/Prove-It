# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import AA, m, x
from proveit.logic import Equals
from proveit.number import Add, Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Equals(Mult(m, x), Add(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, m)))
# Out:
# expr: (m * x) = (A_1 +  ...  + A_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (m * x) = (A_1 +  ...  + A_m)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (m * x , A_1 +  ...  + A_m)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. m * x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. A_1 +  ...  + A_m
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (m , x)
#    core type: ExprTuple
#    sub-expressions: 23, 9
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. A_1,...,A_m
#     core type: Iter
#     lambda_map: 11
#     start_index: 22
#     end_index: 23
# 11. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 18
#     body: 12
#     conditions: 13\n12. A__x_
#     core type: Indexed
#     var: 14
#     index: 18
#     base: "1"
# 13. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. _x_ in {1...m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. _x_
#     core type: Variable
#     sub-expressions:
# 19. {1...m}
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. m
#     core type: Variable
#     sub-expressions:
