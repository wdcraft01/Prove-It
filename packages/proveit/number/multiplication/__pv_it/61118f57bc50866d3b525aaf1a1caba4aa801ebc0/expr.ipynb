# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import aa, bb, cc, l, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Exp, Mult, Naturals
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Forall([aa, bb, cc], Equals(Mult(iter_a1l, iter_b1m, iter_c1n), Mult(iter_a1l, Mult(iter_b1m), iter_c1n)), domains = [Exp(Complexes, l), Exp(Complexes, m), Exp(Complexes, n)], conditions = []), conditions = [InSet(n, Naturals)])
# Out:
# expr: n -> [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))] | n in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. n -> [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))] | n in Naturals
#    core type: Lambda
#    parameter: 68
#    body: 1
#    conditions: 2\n1. forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))
#    core type: Operation
#    operator: 14
#    operand: 3
# 2. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. a -> [forall_{(b, c) in Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))] | a in Complexes^{l}
#    core type: Lambda
#    parameter: 48
#    body: 5
#    conditions: 6\n4. n in Naturals
#    core type: Operation
#    operator: 62
#    operands: 7
# ...
