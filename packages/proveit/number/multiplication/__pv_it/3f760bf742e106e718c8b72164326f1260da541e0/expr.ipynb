# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import c
from proveit.number import Mult
from proveit.number._common_ import iter_a1l, iter_b1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(iter_a1l, iter_b1m, c, iter_d1n), Mult(iter_a1l, c, iter_b1m, iter_d1n))
# Out:
# expr: (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n , a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n , a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_1 ,  ...  , a_l , b_1 ,  ...  , b_m , c , d_1 ,  ...  , d_n)
#    core type: ExprTuple
#    sub-expressions: 6, 8, 7, 9
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (a_1 ,  ...  , a_l , c , b_1 ,  ...  , b_m , d_1 ,  ...  , d_n)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 6. a_1,...,a_l
#    core type: Iter
#    lambda_map: 10
#    start_index: 39
#    end_index: 37
# 7. c
#    core type: Variable
#    sub-expressions:
# 8. b_1,...,b_m
#    core type: Iter
#    lambda_map: 11
#    start_index: 39
#    end_index: 38
# 9. d_1,...,d_n
#    core type: Iter
#    lambda_map: 12
#    start_index: 39
#    end_index: 40
# 10. _x_ -> a__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 31
#     body: 13
#     conditions: 14\n11. _x_ -> b__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 31
#     body: 15
#     conditions: 16\n12. _x_ -> d__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 31
#     body: 17
#     conditions: 18\n13. a__x_
#     core type: Indexed
#     var: 19
#     index: 31
#     base: "1"
# 14. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 20
# 15. b__x_
#     core type: Indexed
#     var: 21
#     index: 31
#     base: "1"
# 16. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 22
# 17. d__x_
#     core type: Indexed
#     var: 23
#     index: 31
#     base: "1"
# 18. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 24
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...l}
#     core type: Operation
#     operator: 27
#     operands: 25
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. _x_ in {1...m}
#     core type: Operation
#     operator: 27
#     operands: 26
# 23. d
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 26. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 31, 30
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. {1...l}
#     core type: Operation
#     operator: 35
#     operands: 33
# 30. {1...m}
#     core type: Operation
#     operator: 35
#     operands: 34
# 31. _x_
#     core type: Variable
#     sub-expressions:
# 32. {1...n}
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 34. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 37. l
#     core type: Variable
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
