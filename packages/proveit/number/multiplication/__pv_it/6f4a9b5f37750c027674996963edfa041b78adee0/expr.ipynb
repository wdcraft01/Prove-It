# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([y], Equals(Mult(x, Neg(y)), Neg(Mult(x, y))), domain = Complexes, conditions = [])
# Out:
# expr: forall_{y in Complexes} ((x * (-y)) = (-(x * y)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{y in Complexes} ((x * (-y)) = (-(x * y)))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. y -> ((x * (-y)) = (-(x * y))) | y in Complexes
#    core type: Lambda
#    parameter: 20
#    body: 3
#    conditions: 4\n3. (x * (-y)) = (-(x * y))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x * (-y) , -(x * y))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. y in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x * (-y)
#    core type: Operation
#    operator: 16
#    operands: 12
# 9. -(x * y)
#    core type: Operation
#    operator: 18
#    operand: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 20, 14
# 12. (x , -y)
#     core type: ExprTuple
#     sub-expressions: 19, 15
# 13. x * y
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. Complexes
#     core type: Literal
#     sub-expressions:
# 15. -y
#     core type: Operation
#     operator: 18
#     operand: 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (x , y)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. y
#     core type: Variable
#     sub-expressions:
