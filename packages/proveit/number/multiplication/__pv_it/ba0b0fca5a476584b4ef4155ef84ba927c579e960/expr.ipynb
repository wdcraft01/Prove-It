# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit.logic import InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Mult, RealsPos

# %%
# build up the expression from sub-expressions
expr = InSet(Mult(iterA1m), RealsPos)
# Out:
# expr: (A_1 *  ...  * A_m) in RealsPos

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 *  ...  * A_m) in RealsPos
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. (A_1 *  ...  * A_m , RealsPos)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. A_1 *  ...  * A_m
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. RealsPos
#    core type: Literal
#    sub-expressions:
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (A_1 ,  ...  , A_m)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. A_1,...,A_m
#    core type: Iter
#    lambda_map: 7
#    start_index: 18
#    end_index: 19
# 7. _x_ -> A__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 14
#    body: 8
#    conditions: 9\n8. A__x_
#    core type: Indexed
#    var: 10
#    index: 14
#    base: "1"
# 9. (_x_ in {1...m})
#    core type: ExprTuple
#    sub-expressions: 11
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. _x_ in {1...m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. _x_
#     core type: Variable
#     sub-expressions:
# 15. {1...m}
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. m
#     core type: Variable
#     sub-expressions:
