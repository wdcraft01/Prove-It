# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import AA, BB, CC, i, l, m, n
from proveit.logic import Equals, Forall
from proveit.logic._common_ import iterC1n
from proveit.number import Add, Complexes, Exp, Mult, Naturals, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = []
subExpr3 = Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l)
expr = Forall([m, n], Forall([AA, BB, CC], Equals(Mult(subExpr3, Add(Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)), iterC1n), Add(Iter(i, Mult(subExpr3, Indexed(BB, i, base = 1), iterC1n), one, m))), domains = [Exp(Complexes, l), Exp(Complexes, m), Exp(Complexes, n)], conditions = subExpr2), domain = Naturals, conditions = subExpr2)
# Out:
# expr: forall_{m, n in Naturals} [forall_{(A, B, C) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{(A, B, C) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))]
#    core type: Operation
#    operator: 20
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{(A, B, C) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))]] | m in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{(A, B, C) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{(A, B, C) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))] | n in Naturals
#    core type: Lambda
#    parameter: 88
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 77
#    operands: 8
# 6. forall_{(A, B, C) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))
#    core type: Operation
#    operator: 20
#    operand: 9
# 7. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 79, 16
# 9. A -> [forall_{(B, C) in Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))] | A in Complexes^{l}
#    core type: Lambda
#    parameter: 71
#    body: 11
#    conditions: 12\n10. n in Naturals
#     core type: Operation
#     operator: 77
#     operands: 13
# 11. forall_{(B, C) in Complexes^{m} * Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))
#     core type: Operation
#     operator: 20
#     operand: 14
# 12. (A in Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 88, 16
# 14. B -> [forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))] | B in Complexes^{m}
#     core type: Lambda
#     parameter: 62
#     body: 17
#     conditions: 18\n15. A in Complexes^{l}
#     core type: Operation
#     operator: 77
#     operands: 19
# 16. Naturals
#     core type: Literal
#     sub-expressions:
# 17. forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. (B in Complexes^{m})
#     core type: ExprTuple
#     sub-expressions: 22
# 19. (A , Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 71, 23
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. C -> ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n))) | C in Complexes^{n}
#     core type: Lambda
#     parameter: 73
#     body: 24
#     conditions: 25\n22. B in Complexes^{m}
#     core type: Operation
#     operator: 77
#     operands: 26
# 23. Complexes^{l}
#     core type: Operation
#     operator: 41
#     operands: 27
# 24. (A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n))
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. (C in Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. (B , Complexes^{m})
#     core type: ExprTuple
#     sub-expressions: 62, 31
# 27. (Complexes , l)
#     core type: ExprTuple
#     sub-expressions: 46, 86
# 28. =
#     core type: Literal
#     sub-expressions:
# 29. (A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n , (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n))
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. C in Complexes^{n}
#     core type: Operation
#     operator: 77
#     operands: 34
# 31. Complexes^{m}
#     core type: Operation
#     operator: 41
#     operands: 35
# 32. A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 51
#     operands: 36
# 33. (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)
#     core type: Operation
#     operator: 43
#     operands: 37
# 34. (C , Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 73, 38
# 35. (Complexes , m)
#     core type: ExprTuple
#     sub-expressions: 46, 79
# 36. (A_1 ,  ...  , A_l , B_1 +  ...  + B_m , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 56, 39, 58
# 37. (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n ,  ...  , A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. Complexes^{n}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. B_1 +  ...  + B_m
#     core type: Operation
#     operator: 43
#     operands: 44
# 40. (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n),...,(A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)
#     core type: Iter
#     lambda_map: 45
#     start_index: 87
#     end_index: 79
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (Complexes , n)
#     core type: ExprTuple
#     sub-expressions: 46, 88
# 43. +
#     core type: Literal
#     sub-expressions:
# 44. (B_1 ,  ...  , B_m)
#     core type: ExprTuple
#     sub-expressions: 47
# 45. i -> (A_1 *  ...  * A_l * B_i * C_1 *  ...  * C_n) | i in {1...m}
#     core type: Lambda
#     parameter: 64
#     body: 48
#     conditions: 49\n46. Complexes
#     core type: Literal
#     sub-expressions:
# 47. B_1,...,B_m
#     core type: Iter
#     lambda_map: 50
#     start_index: 87
#     end_index: 79
# 48. A_1 *  ...  * A_l * B_i * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 51
#     operands: 52
# 49. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 53
# 50. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 81
#     body: 54
#     conditions: 55\n51. *
#     core type: Literal
#     sub-expressions:
# 52. (A_1 ,  ...  , A_l , B_i , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58
# 53. i in {1...m}
#     core type: Operation
#     operator: 77
#     operands: 59
# 54. B__x_
#     core type: Indexed
#     var: 62
#     index: 81
#     base: "1"
# 55. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 60
# 56. A_1,...,A_l
#     core type: Iter
#     lambda_map: 61
#     start_index: 87
#     end_index: 86
# 57. B_i
#     core type: Indexed
#     var: 62
#     index: 64
#     base: "1"
# 58. C_1,...,C_n
#     core type: Iter
#     lambda_map: 63
#     start_index: 87
#     end_index: 88
# 59. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 64, 70
# 60. _x_ in {1...m}
#     core type: Operation
#     operator: 77
#     operands: 65
# 61. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 81
#     body: 66
#     conditions: 67\n62. B
#     core type: Variable
#     sub-expressions:
# 63. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 81
#     body: 68
#     conditions: 69\n64. i
#     core type: Variable
#     sub-expressions:
# 65. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 81, 70
# 66. A__x_
#     core type: Indexed
#     var: 71
#     index: 81
#     base: "1"
# 67. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 72
# 68. C__x_
#     core type: Indexed
#     var: 73
#     index: 81
#     base: "1"
# 69. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 74
# 70. {1...m}
#     core type: Operation
#     operator: 84
#     operands: 75
# 71. A
#     core type: Variable
#     sub-expressions:
# 72. _x_ in {1...l}
#     core type: Operation
#     operator: 77
#     operands: 76
# 73. C
#     core type: Variable
#     sub-expressions:
# 74. _x_ in {1...n}
#     core type: Operation
#     operator: 77
#     operands: 78
# 75. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 87, 79
# 76. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 81, 80
# 77. in
#     core type: Literal
#     sub-expressions:
# 78. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 81, 82
# 79. m
#     core type: Variable
#     sub-expressions:
# 80. {1...l}
#     core type: Operation
#     operator: 84
#     operands: 83
# 81. _x_
#     core type: Variable
#     sub-expressions:
# 82. {1...n}
#     core type: Operation
#     operator: 84
#     operands: 85
# 83. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 87, 86
# 84. Interval
#     core type: Literal
#     sub-expressions:
# 85. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 86. l
#     core type: Variable
#     sub-expressions:
# 87. 1
#     core type: Literal
#     sub-expressions:
# 88. n
#     core type: Variable
#     sub-expressions:
