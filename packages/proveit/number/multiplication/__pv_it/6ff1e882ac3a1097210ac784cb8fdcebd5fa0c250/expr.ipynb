# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import aa, bb, cc, l, m, n
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Exp, Mult, Naturals
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Forall([n], Forall([aa, bb, cc], Equals(Mult(iter_a1l, Mult(iter_b1m), iter_c1n), Mult(iter_a1l, iter_b1m, iter_c1n)), domains = [Exp(Complexes, l), Exp(Complexes, m), Exp(Complexes, n)], conditions = subExpr1), domain = Naturals, conditions = subExpr1)
# Out:
# expr: forall_{n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n))]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n))]
#    core type: Operation
#    operator: 15
#    operand: 1
# 1. n -> [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n))] | n in Naturals
#    core type: Lambda
#    parameter: 69
#    body: 2
#    conditions: 3\n2. forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n))
#    core type: Operation
#    operator: 15
#    operand: 4
# 3. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# ...
