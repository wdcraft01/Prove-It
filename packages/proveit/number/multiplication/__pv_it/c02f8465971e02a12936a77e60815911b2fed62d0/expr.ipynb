# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multNegAnyDouble">multNegAnyDouble</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import multNegAnyDouble

# %%
# check that the built expression is the same as the stored expression
# %check_expr multNegAnyDouble
# Out:
# Passed sanity check: built 'multNegAnyDouble' is the same as the stored Expression.

# %%
# display the expression information
multNegAnyDouble.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{A, B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))]
#    core type: Operation
#    operator: 20
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{A, B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))]] | m in Naturals
#    core type: Lambda
#    parameter: 61
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{A, B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))]
#    core type: Operation
#    operator: 20
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{A, B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))] | n in Naturals
#    core type: Lambda
#    parameter: 63
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 53
#    operands: 8
# 6. forall_{A, B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#    core type: Operation
#    operator: 20
#    operand: 9
# 7. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 61, 16
# 9. A -> [forall_{B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))] | A in Complexes
#    core type: Lambda
#    parameter: 48
#    body: 11
#    conditions: 12\n10. n in Naturals
#     core type: Operation
#     operator: 53
#     operands: 13
# 11. forall_{B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#     core type: Operation
#     operator: 20
#     operand: 14
# 12. (A in Complexes)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 63, 16
# 14. B -> [forall_{C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))] | B in Complexes
#     core type: Lambda
#     parameter: 42
#     body: 17
#     conditions: 18\n15. A in Complexes
#     core type: Operation
#     operator: 53
#     operands: 19
# 16. Naturals
#     core type: Literal
#     sub-expressions:
# 17. forall_{C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#     core type: Operation
#     operator: 20
#     operand: 21
# 18. (B in Complexes)
#     core type: ExprTuple
#     sub-expressions: 22
# 19. (A , Complexes)
#     core type: ExprTuple
#     sub-expressions: 48, 34
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. C -> ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)) | C in Complexes
#     core type: Lambda
#     parameter: 50
#     body: 23
#     conditions: 24\n22. B in Complexes
#     core type: Operation
#     operator: 53
#     operands: 25
# 23. (-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. (C in Complexes)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. (B , Complexes)
#     core type: ExprTuple
#     sub-expressions: 42, 34
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) , A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. C in Complexes
#     core type: Operation
#     operator: 53
#     operands: 31
# 29. -(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)
#     core type: Operation
#     operator: 41
#     operand: 32
# 30. A_1 *  ...  * A_m * B * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 35
#     operands: 33
# 31. (C , Complexes)
#     core type: ExprTuple
#     sub-expressions: 50, 34
# 32. A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (A_1 ,  ...  , A_m , B , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 37, 42, 39
# 34. Complexes
#     core type: Literal
#     sub-expressions:
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (A_1 ,  ...  , A_m , -B , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 37. A_1,...,A_m
#     core type: Iter
#     lambda_map: 40
#     start_index: 62
#     end_index: 61
# 38. -B
#     core type: Operation
#     operator: 41
#     operand: 42
# 39. C_1,...,C_n
#     core type: Iter
#     lambda_map: 43
#     start_index: 62
#     end_index: 63
# 40. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 56
#     body: 44
#     conditions: 45\n41. -
#     core type: Literal
#     sub-expressions:
# 42. B
#     core type: Variable
#     sub-expressions:
# 43. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 56
#     body: 46
#     conditions: 47\n44. A__x_
#     core type: Indexed
#     var: 48
#     index: 56
#     base: "1"
# 45. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 49
# 46. C__x_
#     core type: Indexed
#     var: 50
#     index: 56
#     base: "1"
# 47. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 51
# 48. A
#     core type: Variable
#     sub-expressions:
# 49. _x_ in {1...m}
#     core type: Operation
#     operator: 53
#     operands: 52
# 50. C
#     core type: Variable
#     sub-expressions:
# 51. _x_ in {1...n}
#     core type: Operation
#     operator: 53
#     operands: 54
# 52. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 56, 55
# 53. in
#     core type: Literal
#     sub-expressions:
# 54. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 55. {1...m}
#     core type: Operation
#     operator: 59
#     operands: 58
# 56. _x_
#     core type: Variable
#     sub-expressions:
# 57. {1...n}
#     core type: Operation
#     operator: 59
#     operands: 60
# 58. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 59. Interval
#     core type: Literal
#     sub-expressions:
# 60. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 61. m
#     core type: Variable
#     sub-expressions:
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
