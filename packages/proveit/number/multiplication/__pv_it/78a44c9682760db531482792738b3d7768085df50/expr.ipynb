# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#elimOneLeft">elimOneLeft</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import elimOneLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr elimOneLeft
# Out:
# Passed sanity check: built 'elimOneLeft' is the same as the stored Expression.

# %%
# display the expression information
elimOneLeft.exprInfo()
# Out:
# 0. forall_{x in Complexes} ((1 * x) = x)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((1 * x) = x) | x in Complexes
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. (1 * x) = x
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (1 * x , x)
#    core type: ExprTuple
#    sub-expressions: 8, 15
# 7. x in Complexes
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. 1 * x
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (1 , x)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Complexes
# ...
