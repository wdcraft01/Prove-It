# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import BB, n, x, y
from proveit.logic import Equals, Forall
from proveit.logic._common_ import iterA1m, iterB1n
from proveit.number import Add, Complexes, Exp, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([x, y, BB], Equals(Mult(iterA1m, Add(x, Neg(y)), iterB1n), Add(Mult(iterA1m, x, iterB1n), Neg(Mult(iterA1m, y, iterB1n)))), domains = [Complexes, Complexes, Exp(Complexes, n)], conditions = [])
# Out:
# expr: forall_{(x, y, B) in Complexes * Complexes * Complexes^{n}} ((A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n)))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(x, y, B) in Complexes * Complexes * Complexes^{n}} ((A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n)))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. x -> [forall_{(y, B) in Complexes * Complexes^{n}} ((A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n)))] | x in Complexes
#    core type: Lambda
#    parameter: 35
#    body: 2
#    conditions: 3\n2. forall_{(y, B) in Complexes * Complexes^{n}} ((A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n)))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# ...
