# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import AA, m
from proveit.logic import InSet
from proveit.number import Exp
from proveit.number._common_ import ComplexesSansZero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(AA, Exp(ComplexesSansZero, m)))
# Out:
# expr: (A in Complexes - {0}^{m})

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A in Complexes - {0}^{m})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. A in Complexes - {0}^{m}
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. in
#    core type: Literal
#    sub-expressions:
# 3. (A , Complexes - {0}^{m})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. A
#    core type: Variable
#    sub-expressions:
# 5. Complexes - {0}^{m}
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. Exp
#    core type: Literal
#    sub-expressions:
# 7. (Complexes - {0} , m)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. Complexes - {0}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. (Complexes , {0})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. {0}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. Set
#     core type: Literal
#     sub-expressions:
# 15. (0)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. 0
#     core type: Literal
#     sub-expressions:
