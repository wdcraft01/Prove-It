# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import AA, i, m, x
from proveit.logic import Equals, Forall
from proveit.number import Add, Complexes, Exp, Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([AA, x], Equals(Mult(m, x), Add(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, m))), domains = [Exp(Complexes, m), Complexes], conditions = [Iter(i, Equals(Indexed(AA, i, base = 1), x), one, m)])
# Out:
# expr: forall_{(A, x) in Complexes^{m} * Complexes | A_1 = x ,  ...  , A_m = x} ((m * x) = (A_1 +  ...  + A_m))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(A, x) in Complexes^{m} * Complexes | A_1 = x ,  ...  , A_m = x} ((m * x) = (A_1 +  ...  + A_m))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. A -> [forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((m * x) = (A_1 +  ...  + A_m))] | A in Complexes^{m}
#    core type: Lambda
#    parameter: 38
#    body: 2
#    conditions: 3\n2. forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((m * x) = (A_1 +  ...  + A_m))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (A in Complexes^{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> ((m * x) = (A_1 +  ...  + A_m)) | x in Complexes , A_1 = x ,  ...  , A_m = x
#    core type: Lambda
#    parameter: 33
#    body: 7
#    conditions: 8\n6. A in Complexes^{m}
#    core type: Operation
#    operator: 40
#    operands: 9
# 7. (m * x) = (A_1 +  ...  + A_m)
#    core type: Operation
#    operator: 28
#    operands: 10
# ...
