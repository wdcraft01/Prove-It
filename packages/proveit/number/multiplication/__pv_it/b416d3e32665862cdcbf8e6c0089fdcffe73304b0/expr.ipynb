# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multIntClosureBin">multIntClosureBin</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import multIntClosureBin

# %%
# check that the built expression is the same as the stored expression
# %check_expr multIntClosureBin
# Out:
# Passed sanity check: built 'multIntClosureBin' is the same as the stored Expression.

# %%
# display the expression information
multIntClosureBin.exprInfo()
# Out:
# 0. forall_{a, b in Integers} ((a * b) in Integers)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Integers} ((a * b) in Integers)] | a in Integers
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{b in Integers} ((a * b) in Integers)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Integers)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((a * b) in Integers) | b in Integers
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n6. a in Integers
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. (a * b) in Integers
#    core type: Operation
#    operator: 13
#    operands: 10
# 8. (b in Integers)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (a , Integers)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 10. (a * b , Integers)
#     core type: ExprTuple
#     sub-expressions: 12, 17
# 11. b in Integers
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. a * b
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (b , Integers)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (a , b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Integers
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
