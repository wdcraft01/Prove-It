# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, B, CC, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Complexes, Mult, Naturals, Neg

# %%
# build up the expression from sub-expressions
subExpr1 = []
expr = Lambda(m, Forall([n], Forall([AA, B, CC], Equals(Mult(iterA1m, Neg(B), iterC1n), Neg(Mult(iterA1m, B, iterC1n))), domain = Complexes, conditions = subExpr1), domain = Naturals, conditions = subExpr1), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{n in Naturals} [forall_{A, B, C in Complexes} ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)))]] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{n in Naturals} [forall_{A, B, C in Complexes} ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)))]] | m in Naturals
#    core type: Lambda
#    parameter: 60
#    body: 1
#    conditions: 2\n1. forall_{n in Naturals} [forall_{A, B, C in Complexes} ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)))]
#    core type: Operation
#    operator: 19
#    operand: 3
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. n -> [forall_{A, B, C in Complexes} ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)))] | n in Naturals
#    core type: Lambda
#    parameter: 62
#    body: 5
#    conditions: 6\n4. m in Naturals
#    core type: Operation
#    operator: 52
#    operands: 7
# 5. forall_{A, B, C in Complexes} ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)))
# ...
