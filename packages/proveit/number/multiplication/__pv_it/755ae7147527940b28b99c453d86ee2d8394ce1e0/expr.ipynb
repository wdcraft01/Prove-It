# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import b, cc, dd, m, n
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Exp, Mult
from proveit.number._common_ import iter_a1l, iter_c1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = Forall([b, cc, dd], Equals(Mult(iter_a1l, b, iter_c1m, iter_d1n), Mult(iter_a1l, iter_c1m, b, iter_d1n)), domains = [Complexes, Exp(Complexes, m), Exp(Complexes, n)], conditions = [])
# Out:
# expr: forall_{(b, c, d) in Complexes * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b * c_1 *  ...  * c_m * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c_1 *  ...  * c_m * b * d_1 *  ...  * d_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(b, c, d) in Complexes * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b * c_1 *  ...  * c_m * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c_1 *  ...  * c_m * b * d_1 *  ...  * d_n))
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. b -> [forall_{(c, d) in Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b * c_1 *  ...  * c_m * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c_1 *  ...  * c_m * b * d_1 *  ...  * d_n))] | b in Complexes
#    core type: Lambda
#    parameter: 29
#    body: 2
#    conditions: 3\n2. forall_{(c, d) in Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b * c_1 *  ...  * c_m * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c_1 *  ...  * c_m * b * d_1 *  ...  * d_n))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# ...
