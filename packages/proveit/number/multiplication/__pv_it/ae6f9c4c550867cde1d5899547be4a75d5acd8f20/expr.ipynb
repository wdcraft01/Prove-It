# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multRealPosClosureBin">multRealPosClosureBin</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import multRealPosClosureBin

# %%
# check that the built expression is the same as the stored expression
# %check_expr multRealPosClosureBin
# Out:
# Passed sanity check: built 'multRealPosClosureBin' is the same as the stored Expression.

# %%
# display the expression information
multRealPosClosureBin.exprInfo()
# Out:
# 0. forall_{a, b in RealsPos} ((a * b) in RealsPos)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in RealsPos} ((a * b) in RealsPos)] | a in RealsPos
#    core type: Lambda
#    parameter: 18
#    body: 2
#    conditions: 3\n2. forall_{b in RealsPos} ((a * b) in RealsPos)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((a * b) in RealsPos) | b in RealsPos
#    core type: Lambda
#    parameter: 19
#    body: 7
#    conditions: 8\n6. a in RealsPos
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. (a * b) in RealsPos
#    core type: Operation
#    operator: 13
#    operands: 10
# 8. (b in RealsPos)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (a , RealsPos)
#    core type: ExprTuple
#    sub-expressions: 18, 17
# 10. (a * b , RealsPos)
#     core type: ExprTuple
# ...
