# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import BB, n, x, y
from proveit.logic import Equals, InSet
from proveit.logic._common_ import iterA1m, iterB1n
from proveit.number import Add, Complexes, Exp, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(BB, Equals(Mult(iterA1m, Add(x, Neg(y)), iterB1n), Add(Mult(iterA1m, x, iterB1n), Neg(Mult(iterA1m, y, iterB1n)))), conditions = [InSet(BB, Exp(Complexes, n))])
# Out:
# expr: B -> ((A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n))) | B in Complexes^{n}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> ((A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n))) | B in Complexes^{n}
#    core type: Lambda
#    parameter: 38
#    body: 1
#    conditions: 2\n1. (A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n) = ((A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (B in Complexes^{n})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n , (A_1 *  ...  * A_m * x * B_1 *  ...  * B_n) - (A_1 *  ...  * A_m * y * B_1 *  ...  * B_n))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. B in Complexes^{n}
#    core type: Operation
#    operator: 41
#    operands: 8
# 6. A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n
#    core type: Operation
#    operator: 24
#    operands: 9
# ...
