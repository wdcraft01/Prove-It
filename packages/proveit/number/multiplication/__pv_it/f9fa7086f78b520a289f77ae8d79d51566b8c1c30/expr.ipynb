# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Mult.html">Mult</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Variable
from proveit._common_ import AA, BB, i, l
from proveit.logic._common_ import iterC1n
from proveit.number import Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Mult(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l), Indexed(BB, i, base = 1), iterC1n)
# Out:
# expr: A_1 *  ...  * A_l * B_i * C_1 *  ...  * C_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_1 *  ...  * A_l * B_i * C_1 *  ...  * C_n
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. (A_1 ,  ...  , A_l , B_i , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. A_1,...,A_l
#    core type: Iter
#    lambda_map: 6
#    start_index: 28
#    end_index: 27
# 4. B_i
#    core type: Indexed
#    var: 7
#    index: 8
#    base: "1"
# 5. C_1,...,C_n
#    core type: Iter
#    lambda_map: 9
#    start_index: 28
#    end_index: 29
# 6. _x_ -> A__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 22
#    body: 10
#    conditions: 11\n7. B
#    core type: Variable
#    sub-expressions:
# 8. i
#    core type: Variable
#    sub-expressions:
# 9. _x_ -> C__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 22
#    body: 12
#    conditions: 13\n10. A__x_
#     core type: Indexed
#     var: 14
#     index: 22
#     base: "1"
# 11. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 15
# 12. C__x_
#     core type: Indexed
#     var: 16
#     index: 22
#     base: "1"
# 13. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 17
# 14. A
#     core type: Variable
#     sub-expressions:
# 15. _x_ in {1...l}
#     core type: Operation
#     operator: 19
#     operands: 18
# 16. C
#     core type: Variable
#     sub-expressions:
# 17. _x_ in {1...n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. {1...l}
#     core type: Operation
#     operator: 25
#     operands: 24
# 22. _x_
#     core type: Variable
#     sub-expressions:
# 23. {1...n}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 28, 27
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 27. l
#     core type: Variable
#     sub-expressions:
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
