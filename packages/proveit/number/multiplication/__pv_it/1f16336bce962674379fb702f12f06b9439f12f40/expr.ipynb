# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multNegLeft">multNegLeft</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import multNegLeft

# %%
# check that the built expression is the same as the stored expression
# %check_expr multNegLeft
# Out:
# Passed sanity check: built 'multNegLeft' is the same as the stored Expression.

# %%
# display the expression information
multNegLeft.exprInfo()
# Out:
# 0. forall_{x, y in Complexes} (((-x) * y) = (-(x * y)))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. x -> [forall_{y in Complexes} (((-x) * y) = (-(x * y)))] | x in Complexes
#    core type: Lambda
#    parameter: 24
#    body: 2
#    conditions: 3\n2. forall_{y in Complexes} (((-x) * y) = (-(x * y)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. y -> (((-x) * y) = (-(x * y))) | y in Complexes
#    core type: Lambda
#    parameter: 25
#    body: 7
#    conditions: 8\n6. x in Complexes
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. ((-x) * y) = (-(x * y))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 24, 19
# 10. =
#     core type: Literal
# ...
