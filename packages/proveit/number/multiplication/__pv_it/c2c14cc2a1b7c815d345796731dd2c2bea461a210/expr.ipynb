# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit._common_ import y
from proveit.logic._common_ import iterA1m, iterB1n

# %%
# build up the expression from sub-expressions
expr = ExprTuple(iterA1m, y, iterB1n)
# Out:
# expr: (A_1 ,  ...  , A_m , y , B_1 ,  ...  , B_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 ,  ...  , A_m , y , B_1 ,  ...  , B_n)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. A_1,...,A_m
#    core type: Iter
#    lambda_map: 4
#    start_index: 24
#    end_index: 23
# 2. y
#    core type: Variable
#    sub-expressions:
# 3. B_1,...,B_n
#    core type: Iter
#    lambda_map: 5
#    start_index: 24
#    end_index: 25
# 4. _x_ -> A__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 18
#    body: 6
#    conditions: 7\n5. _x_ -> B__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 18
#    body: 8
#    conditions: 9\n6. A__x_
#    core type: Indexed
#    var: 10
#    index: 18
#    base: "1"
# 7. (_x_ in {1...m})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. B__x_
#    core type: Indexed
#    var: 12
#    index: 18
#    base: "1"
# 9. (_x_ in {1...n})
#    core type: ExprTuple
#    sub-expressions: 13
# 10. A
#     core type: Variable
#     sub-expressions:
# 11. _x_ in {1...m}
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. B
#     core type: Variable
#     sub-expressions:
# 13. _x_ in {1...n}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {1...m}
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. _x_
#     core type: Variable
#     sub-expressions:
# 19. {1...n}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. m
#     core type: Variable
#     sub-expressions:
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. n
#     core type: Variable
#     sub-expressions:
