# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import B, CC
from proveit.logic import Equals, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Complexes, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(CC, Equals(Mult(iterA1m, Neg(B), iterC1n), Neg(Mult(iterA1m, B, iterC1n))), conditions = [InSet(CC, Complexes)])
# Out:
# expr: C -> ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))) | C in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. C -> ((A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))) | C in Complexes
#    core type: Lambda
#    parameter: 27
#    body: 1
#    conditions: 2\n1. (A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n) = (-(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (C in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n , -(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. C in Complexes
#    core type: Operation
#    operator: 30
#    operands: 8
# 6. A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. -(A_1 *  ...  * A_m * B * C_1 *  ...  * C_n)
#    core type: Operation
#    operator: 15
#    operand: 10
# 8. (C , Complexes)
#    core type: ExprTuple
#    sub-expressions: 27, 11
# 9. (A_1 ,  ...  , A_m , -B , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 16, 12, 18
# 10. A_1 *  ...  * A_m * B * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. Complexes
#     core type: Literal
#     sub-expressions:
# 12. -B
#     core type: Operation
#     operator: 15
#     operand: 17
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (A_1 ,  ...  , A_m , B , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. A_1,...,A_m
#     core type: Iter
#     lambda_map: 19
#     start_index: 39
#     end_index: 38
# 17. B
#     core type: Variable
#     sub-expressions:
# 18. C_1,...,C_n
#     core type: Iter
#     lambda_map: 20
#     start_index: 39
#     end_index: 40
# 19. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 33
#     body: 21
#     conditions: 22\n20. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 33
#     body: 23
#     conditions: 24\n21. A__x_
#     core type: Indexed
#     var: 25
#     index: 33
#     base: "1"
# 22. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 26
# 23. C__x_
#     core type: Indexed
#     var: 27
#     index: 33
#     base: "1"
# 24. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 28
# 25. A
#     core type: Variable
#     sub-expressions:
# 26. _x_ in {1...m}
#     core type: Operation
#     operator: 30
#     operands: 29
# 27. C
#     core type: Variable
#     sub-expressions:
# 28. _x_ in {1...n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 33, 32
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. {1...m}
#     core type: Operation
#     operator: 36
#     operands: 35
# 33. _x_
#     core type: Variable
#     sub-expressions:
# 34. {1...n}
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 39, 38
# 36. Interval
#     core type: Literal
#     sub-expressions:
# 37. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 38. m
#     core type: Variable
#     sub-expressions:
# 39. 1
#     core type: Literal
#     sub-expressions:
# 40. n
#     core type: Variable
#     sub-expressions:
