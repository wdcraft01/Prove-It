# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Mult.html">Mult</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit.number import Mult
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
expr = Mult(iter_a1l, Mult(iter_b1m), iter_c1n)
# Out:
# expr: a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n
#    core type: Operation
#    operator: 6
#    operands: 1
# 1. (a_1 ,  ...  , a_l , b_1 *  ...  * b_m , c_1 ,  ...  , c_n)
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. a_1,...,a_l
#    core type: Iter
#    lambda_map: 5
#    start_index: 37
#    end_index: 31
# 3. b_1 *  ...  * b_m
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. c_1,...,c_n
#    core type: Iter
#    lambda_map: 8
#    start_index: 37
#    end_index: 34
# 5. _x_ -> a__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 32
#    body: 9
#    conditions: 10\n6. *
#    core type: Literal
#    sub-expressions:
# 7. (b_1 ,  ...  , b_m)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. _x_ -> c__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 32
#    body: 12
#    conditions: 13\n9. a__x_
#    core type: Indexed
#    var: 14
#    index: 32
#    base: "1"
# 10. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 15
# 11. b_1,...,b_m
#     core type: Iter
#     lambda_map: 16
#     start_index: 37
#     end_index: 38
# 12. c__x_
#     core type: Indexed
#     var: 17
#     index: 32
#     base: "1"
# 13. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. _x_ in {1...l}
#     core type: Operation
#     operator: 28
#     operands: 19
# 16. _x_ -> b__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 32
#     body: 20
#     conditions: 21\n17. c
#     core type: Variable
#     sub-expressions:
# 18. _x_ in {1...n}
#     core type: Operation
#     operator: 28
#     operands: 22
# 19. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 32, 23
# 20. b__x_
#     core type: Indexed
#     var: 24
#     index: 32
#     base: "1"
# 21. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 32, 26
# 23. {1...l}
#     core type: Operation
#     operator: 35
#     operands: 27
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. _x_ in {1...m}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. {1...n}
#     core type: Operation
#     operator: 35
#     operands: 30
# 27. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 37, 31
# 28. in
#     core type: Literal
#     sub-expressions:
# 29. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 37, 34
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. _x_
#     core type: Variable
#     sub-expressions:
# 33. {1...m}
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. Interval
#     core type: Literal
#     sub-expressions:
# 36. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. 1
#     core type: Literal
#     sub-expressions:
# 38. m
#     core type: Variable
#     sub-expressions:
