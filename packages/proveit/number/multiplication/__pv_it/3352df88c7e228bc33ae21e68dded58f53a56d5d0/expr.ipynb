# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import BB
from proveit.logic import Equals, InSet
from proveit.logic._common_ import iterA1m, iterB1n
from proveit.number import Complexes, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda(BB, Equals(Mult(iterA1m, one, iterB1n), Mult(iterA1m, iterB1n)), conditions = [InSet(BB, Complexes)])
# Out:
# expr: B -> ((A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n)) | B in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> ((A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n)) | B in Complexes
#    core type: Lambda
#    parameter: 23
#    body: 1
#    conditions: 2\n1. (A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (B in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n , A_1 *  ...  * A_m * B_1 *  ...  * B_n)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. B in Complexes
#    core type: Operation
#    operator: 26
#    operands: 8
# 6. A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. A_1 *  ...  * A_m * B_1 *  ...  * B_n
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (B , Complexes)
#    core type: ExprTuple
#    sub-expressions: 23, 12
# ...
