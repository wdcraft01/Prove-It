# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multDefRev">multDefRev</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import multDefRev

# %%
# check that the built expression is the same as the stored expression
# %check_expr multDefRev
# Out:
# Passed sanity check: built 'multDefRev' is the same as the stored Expression.

# %%
# display the expression information
multDefRev.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{(A, x) in Complexes^{m} * Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))]
#    core type: Operation
#    operator: 9
#    operand: 1
# 1. m -> [forall_{(A, x) in Complexes^{m} * Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))] | m in Naturals
#    core type: Lambda
#    parameter: 53
#    body: 2
#    conditions: 3\n2. forall_{(A, x) in Complexes^{m} * Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))
#    core type: Operation
#    operator: 9
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. A -> [forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))] | A in Complexes^{m}
#    core type: Lambda
#    parameter: 44
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 46
#    operands: 8
# 6. forall_{x in Complexes | A_1 = x ,  ...  , A_m = x} ((A_1 +  ...  + A_m) = (m * x))
#    core type: Operation
#    operator: 9
#    operand: 10
# 7. (A in Complexes^{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 53, 12
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. x -> ((A_1 +  ...  + A_m) = (m * x)) | x in Complexes , A_1 = x ,  ...  , A_m = x
#     core type: Lambda
#     parameter: 39
#     body: 13
#     conditions: 14\n11. A in Complexes^{m}
#     core type: Operation
#     operator: 46
#     operands: 15
# 12. Naturals
#     core type: Literal
#     sub-expressions:
# 13. (A_1 +  ...  + A_m) = (m * x)
#     core type: Operation
#     operator: 34
#     operands: 16
# 14. (x in Complexes , A_1 = x ,  ...  , A_m = x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. (A , Complexes^{m})
#     core type: ExprTuple
#     sub-expressions: 44, 19
# 16. (A_1 +  ...  + A_m , m * x)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. x in Complexes
#     core type: Operation
#     operator: 46
#     operands: 22
# 18. (A_1 = x),...,(A_m = x)
#     core type: Iter
#     lambda_map: 23
#     start_index: 52
#     end_index: 53
# 19. Complexes^{m}
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. A_1 +  ...  + A_m
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. m * x
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 39, 32
# 23. i -> (A_i = x) | i in {1...m}
#     core type: Lambda
#     parameter: 43
#     body: 30
#     conditions: 31\n24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (Complexes , m)
#     core type: ExprTuple
#     sub-expressions: 32, 53
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 33
# 28. *
#     core type: Literal
#     sub-expressions:
# 29. (m , x)
#     core type: ExprTuple
#     sub-expressions: 53, 39
# 30. A_i = x
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (i in {1...m})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. Complexes
#     core type: Literal
#     sub-expressions:
# 33. A_1,...,A_m
#     core type: Iter
#     lambda_map: 37
#     start_index: 52
#     end_index: 53
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (A_i , x)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. i in {1...m}
#     core type: Operation
#     operator: 46
#     operands: 40
# 37. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 48
#     body: 41
#     conditions: 42\n38. A_i
#     core type: Indexed
#     var: 44
#     index: 43
#     base: "1"
# 39. x
#     core type: Variable
#     sub-expressions:
# 40. (i , {1...m})
#     core type: ExprTuple
#     sub-expressions: 43, 49
# 41. A__x_
#     core type: Indexed
#     var: 44
#     index: 48
#     base: "1"
# 42. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 45
# 43. i
#     core type: Variable
#     sub-expressions:
# 44. A
#     core type: Variable
#     sub-expressions:
# 45. _x_ in {1...m}
#     core type: Operation
#     operator: 46
#     operands: 47
# 46. in
#     core type: Literal
#     sub-expressions:
# 47. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 48. _x_
#     core type: Variable
#     sub-expressions:
# 49. {1...m}
#     core type: Operation
#     operator: 50
#     operands: 51
# 50. Interval
#     core type: Literal
#     sub-expressions:
# 51. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 52. 1
#     core type: Literal
#     sub-expressions:
# 53. m
#     core type: Variable
#     sub-expressions:
