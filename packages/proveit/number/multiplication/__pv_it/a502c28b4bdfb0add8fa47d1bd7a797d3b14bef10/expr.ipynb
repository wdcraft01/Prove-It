# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, m
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Exp, Mult, Naturals

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Forall([AA], InSet(Mult(iterA1m), Naturals), domain = Exp(Naturals, m), conditions = []), conditions = [InSet(m, Naturals)])
# Out:
# expr: m -> [forall_{A in Naturals^{m}} ((A_1 *  ...  * A_m) in Naturals)] | m in Naturals

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. m -> [forall_{A in Naturals^{m}} ((A_1 *  ...  * A_m) in Naturals)] | m in Naturals
#    core type: Lambda
#    parameter: 32
#    body: 1
#    conditions: 2\n1. forall_{A in Naturals^{m}} ((A_1 *  ...  * A_m) in Naturals)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. A -> ((A_1 *  ...  * A_m) in Naturals) | A in Naturals^{m}
#    core type: Lambda
#    parameter: 23
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 25
#    operands: 8
# 6. (A_1 *  ...  * A_m) in Naturals
#    core type: Operation
#    operator: 25
#    operands: 9
# 7. (A in Naturals^{m})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 32, 20
# 9. (A_1 *  ...  * A_m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 11, 20
# 10. A in Naturals^{m}
#     core type: Operation
#     operator: 25
#     operands: 12
# 11. A_1 *  ...  * A_m
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (A , Naturals^{m})
#     core type: ExprTuple
#     sub-expressions: 23, 15
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. Naturals^{m}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. A_1,...,A_m
#     core type: Iter
#     lambda_map: 19
#     start_index: 31
#     end_index: 32
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (Naturals , m)
#     core type: ExprTuple
#     sub-expressions: 20, 32
# 19. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 27
#     body: 21
#     conditions: 22\n20. Naturals
#     core type: Literal
#     sub-expressions:
# 21. A__x_
#     core type: Indexed
#     var: 23
#     index: 27
#     base: "1"
# 22. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. A
#     core type: Variable
#     sub-expressions:
# 24. _x_ in {1...m}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. in
#     core type: Literal
#     sub-expressions:
# 26. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. _x_
#     core type: Variable
#     sub-expressions:
# 28. {1...m}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. m
#     core type: Variable
#     sub-expressions:
