# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multIntClosure">multIntClosure</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import multIntClosure

# %%
# check that the built expression is the same as the stored expression
# %check_expr multIntClosure
# Out:
# Passed sanity check: built 'multIntClosure' is the same as the stored Expression.

# %%
# display the expression information
multIntClosure.exprInfo()
# Out:
# 0. forall_{m in Naturals} [forall_{A in Integers^{m}} ((A_1 *  ...  * A_m) in Integers)]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. m -> [forall_{A in Integers^{m}} ((A_1 *  ...  * A_m) in Integers)] | m in Naturals
#    core type: Lambda
#    parameter: 34
#    body: 2
#    conditions: 3\n2. forall_{A in Integers^{m}} ((A_1 *  ...  * A_m) in Integers)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. A -> ((A_1 *  ...  * A_m) in Integers) | A in Integers^{m}
#    core type: Lambda
#    parameter: 25
#    body: 7
#    conditions: 8\n6. m in Naturals
#    core type: Operation
#    operator: 27
#    operands: 9
# 7. (A_1 *  ...  * A_m) in Integers
#    core type: Operation
#    operator: 27
#    operands: 10
# 8. (A in Integers^{m})
#    core type: ExprTuple
#    sub-expressions: 11
# 9. (m , Naturals)
# ...
