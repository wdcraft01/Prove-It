# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter, Variable
from proveit._common_ import AA, BB, i, l, m
from proveit.logic._common_ import iterC1n
from proveit.number import Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = ExprTuple(Iter(i, Mult(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l), Indexed(BB, i, base = 1), iterC1n), one, m))
# Out:
# expr: (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n ,  ...  , A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n ,  ...  , A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n),...,(A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)
#    core type: Iter
#    lambda_map: 2
#    start_index: 37
#    end_index: 26
# 2. i -> (A_1 *  ...  * A_l * B_i * C_1 *  ...  * C_n) | i in {1...m}
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. A_1 *  ...  * A_l * B_i * C_1 *  ...  * C_n
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (i in {1...m})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (A_1 ,  ...  , A_l , B_i , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. i in {1...m}
#    core type: Operation
#    operator: 28
#    operands: 11
# 8. A_1,...,A_l
#    core type: Iter
#    lambda_map: 12
#    start_index: 37
#    end_index: 36
# ...
