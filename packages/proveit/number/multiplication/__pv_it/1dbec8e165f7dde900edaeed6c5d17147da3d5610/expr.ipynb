# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, m
from proveit.logic import Forall, NotEquals
from proveit.logic._common_ import iterA1m
from proveit.number import Exp, Mult, zero
from proveit.number._common_ import ComplexesSansZero

# %%
# build up the expression from sub-expressions
expr = Forall([AA], NotEquals(Mult(iterA1m), zero), domain = Exp(ComplexesSansZero, m), conditions = [])
# Out:
# expr: forall_{A in Complexes - {0}^{m}} ((A_1 *  ...  * A_m) != 0)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A in Complexes - {0}^{m}} ((A_1 *  ...  * A_m) != 0)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ((A_1 *  ...  * A_m) != 0) | A in Complexes - {0}^{m}
#    core type: Lambda
#    parameter: 22
#    body: 3
#    conditions: 4\n3. (A_1 *  ...  * A_m) != 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (A in Complexes - {0}^{m})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. !=
#    core type: Literal
#    sub-expressions:
# 6. (A_1 *  ...  * A_m , 0)
#    core type: ExprTuple
#    sub-expressions: 8, 32
# 7. A in Complexes - {0}^{m}
#    core type: Operation
#    operator: 26
#    operands: 9
# 8. A_1 *  ...  * A_m
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (A , Complexes - {0}^{m})
#    core type: ExprTuple
#    sub-expressions: 22, 12
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
# ...
