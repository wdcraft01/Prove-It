# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, Indexed, Iter, Variable
from proveit._common_ import BB, P, m
from proveit.number import Complexes, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = ExprTuple(Function(P, Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)), Complexes)
# Out:
# expr: (P(B_1,...,B_m) , Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (P(B_1,...,B_m) , Complexes)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. P(B_1,...,B_m)
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. Complexes
#    core type: Literal
#    sub-expressions:
# 3. P
#    core type: Variable
#    sub-expressions:
# 4. B_1,...,B_m
#    core type: Iter
#    lambda_map: 5
#    start_index: 16
#    end_index: 17
# 5. _x_ -> B__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 12
#    body: 6
#    conditions: 7\n6. B__x_
#    core type: Indexed
#    var: 8
#    index: 12
#    base: "1"
# 7. (_x_ in {1...m})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. B
#    core type: Variable
#    sub-expressions:
# 9. _x_ in {1...m}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. _x_
#     core type: Variable
#     sub-expressions:
# 13. {1...m}
# ...
