# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Lambda, Variable
from proveit._common_ import AA, BB, CC, P, S, l, m, n
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.logic._common_ import iterC1n
from proveit.number import Complexes, Exp, Mult, Sum, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = []
subExpr3 = Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)
subExpr4 = Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l)
subExpr5 = Function(P, subExpr3)
subExpr6 = [subExpr3]
expr = Lambda(P, Forall([S], Implies(Forall([BB], InSet(subExpr5, Complexes), domain = Exp(S, m), conditions = subExpr2), Forall([AA, CC], Equals(Mult(subExpr4, Sum(subExpr6, subExpr5, domain = S, conditions = subExpr2), iterC1n), Sum(subExpr6, Mult(subExpr4, subExpr5, iterC1n), domain = S, conditions = subExpr2)), domains = [Exp(Complexes, l), Exp(Complexes, n)], conditions = subExpr2)), conditions = subExpr2))
# Out:
# expr: P -> [forall_{S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. P -> [forall_{S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]
#    core type: Lambda
#    parameter: 51
#    body: 1
# 1. forall_{S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])
#    core type: Operation
#    operator: 16
#    operand: 2
# 2. S -> ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])
#    core type: Lambda
#    parameter: 59
#    body: 3
# 3. [forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])]
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes) , forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)]))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)
#    core type: Operation
#    operator: 16
#    operand: 8
# 7. forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])
#    core type: Operation
#    operator: 16
#    operand: 9
# 8. B -> (P(B_1,...,B_m) in Complexes) | B in S^{m}
#    core type: Lambda
#    parameter: 71
#    body: 10
#    conditions: 11\n9. A -> [forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])] | A in Complexes^{l}
#    core type: Lambda
#    parameter: 60
#    body: 12
#    conditions: 13\n10. P(B_1,...,B_m) in Complexes
#     core type: Operation
#     operator: 75
#     operands: 14
# 11. (B in S^{m})
#     core type: ExprTuple
#     sub-expressions: 15
# 12. forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])
#     core type: Operation
#     operator: 16
#     operand: 17
# 13. (A in Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (P(B_1,...,B_m) , Complexes)
#     core type: ExprTuple
#     sub-expressions: 47, 44
# 15. B in S^{m}
#     core type: Operation
#     operator: 75
#     operands: 19
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. C -> ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)]) | C in Complexes^{n}
#     core type: Lambda
#     parameter: 62
#     body: 20
#     conditions: 21\n18. A in Complexes^{l}
#     core type: Operation
#     operator: 75
#     operands: 22
# 19. (B , S^{m})
#     core type: ExprTuple
#     sub-expressions: 71, 23
# 20. (A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)]
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (C in Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 22. (A , Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 60, 27
# 23. S^{m}
#     core type: Operation
#     operator: 38
#     operands: 28
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n , Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. C in Complexes^{n}
#     core type: Operation
#     operator: 75
#     operands: 31
# 27. Complexes^{l}
#     core type: Operation
#     operator: 38
#     operands: 32
# 28. (S , m)
#     core type: ExprTuple
#     sub-expressions: 59, 84
# 29. A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 42
#     operands: 33
# 30. Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)
#     core type: Operation
#     operator: 40
#     operand: 34
# 31. (C , Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 62, 35
# 32. (Complexes , l)
#     core type: ExprTuple
#     sub-expressions: 44, 77
# 33. (A_1 ,  ...  , A_l , Sum_{B_1,...,B_m in S} P(B_1,...,B_m) , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 46, 36, 48
# 34. (B_1,...,B_m) -> (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n) | B_1 in  ...  in B_m in S
#     core type: Lambda
#     parameter: 58
#     body: 37
#     conditions: 45\n35. Complexes^{n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 36. Sum_{B_1,...,B_m in S} P(B_1,...,B_m)
#     core type: Operation
#     operator: 40
#     operand: 41
# 37. A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (Complexes , n)
#     core type: ExprTuple
#     sub-expressions: 44, 78
# 40. Sum
#     core type: Literal
#     sub-expressions:
# 41. (B_1,...,B_m) -> P(B_1,...,B_m) | B_1 in  ...  in B_m in S
#     core type: Lambda
#     parameter: 58
#     body: 47
#     conditions: 45\n42. *
#     core type: Literal
#     sub-expressions:
# 43. (A_1 ,  ...  , A_l , P(B_1,...,B_m) , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 46, 47, 48
# 44. Complexes
#     core type: Literal
#     sub-expressions:
# 45. (B_1 in  ...  in B_m in S)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. A_1,...,A_l
#     core type: Iter
#     lambda_map: 50
#     start_index: 83
#     end_index: 77
# 47. P(B_1,...,B_m)
#     core type: Operation
#     operator: 51
#     operand: 58
# 48. C_1,...,C_n
#     core type: Iter
#     lambda_map: 52
#     start_index: 83
#     end_index: 78
# 49. B_1 in  ...  in B_m in S
#     core type: Operation
#     operator: 75
#     operands: 53
# 50. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 79
#     body: 54
#     conditions: 55\n51. P
#     core type: Variable
#     sub-expressions:
# 52. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 79
#     body: 56
#     conditions: 57\n53. (B_1 ,  ...  , B_m , S)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 54. A__x_
#     core type: Indexed
#     var: 60
#     index: 79
#     base: "1"
# 55. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 61
# 56. C__x_
#     core type: Indexed
#     var: 62
#     index: 79
#     base: "1"
# 57. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 63
# 58. B_1,...,B_m
#     core type: Iter
#     lambda_map: 64
#     start_index: 83
#     end_index: 84
# 59. S
#     core type: Variable
#     sub-expressions:
# 60. A
#     core type: Variable
#     sub-expressions:
# 61. _x_ in {1...l}
#     core type: Operation
#     operator: 75
#     operands: 65
# 62. C
#     core type: Variable
#     sub-expressions:
# 63. _x_ in {1...n}
#     core type: Operation
#     operator: 75
#     operands: 66
# 64. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 79
#     body: 67
#     conditions: 68\n65. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 79, 69
# 66. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 79, 70
# 67. B__x_
#     core type: Indexed
#     var: 71
#     index: 79
#     base: "1"
# 68. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 72
# 69. {1...l}
#     core type: Operation
#     operator: 81
#     operands: 73
# 70. {1...n}
#     core type: Operation
#     operator: 81
#     operands: 74
# 71. B
#     core type: Variable
#     sub-expressions:
# 72. _x_ in {1...m}
#     core type: Operation
#     operator: 75
#     operands: 76
# 73. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 83, 77
# 74. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 83, 78
# 75. in
#     core type: Literal
#     sub-expressions:
# 76. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. l
#     core type: Variable
#     sub-expressions:
# 78. n
#     core type: Variable
#     sub-expressions:
# 79. _x_
#     core type: Variable
#     sub-expressions:
# 80. {1...m}
#     core type: Operation
#     operator: 81
#     operands: 82
# 81. Interval
#     core type: Literal
#     sub-expressions:
# 82. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 83. 1
#     core type: Literal
#     sub-expressions:
# 84. m
#     core type: Variable
#     sub-expressions:
