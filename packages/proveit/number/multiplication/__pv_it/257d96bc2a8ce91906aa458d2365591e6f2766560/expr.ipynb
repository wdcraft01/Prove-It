# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, B, CC
from proveit.logic import Equals, Forall, InSet
from proveit.logic._common_ import iterA1m, iterC1n
from proveit.number import Complexes, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, Forall([B, CC], Equals(Neg(Mult(iterA1m, Neg(B), iterC1n)), Mult(iterA1m, B, iterC1n)), domain = Complexes, conditions = []), conditions = [InSet(AA, Complexes)])
# Out:
# expr: A -> [forall_{B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))] | A in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))] | A in Complexes
#    core type: Lambda
#    parameter: 36
#    body: 1
#    conditions: 2\n1. forall_{B, C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#    core type: Operation
#    operator: 8
#    operand: 3
# 2. (A in Complexes)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. B -> [forall_{C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))] | B in Complexes
#    core type: Lambda
#    parameter: 30
#    body: 5
#    conditions: 6\n4. A in Complexes
#    core type: Operation
#    operator: 41
#    operands: 7
# 5. forall_{C in Complexes} ((-(A_1 *  ...  * A_m * (-B) * C_1 *  ...  * C_n)) = (A_1 *  ...  * A_m * B * C_1 *  ...  * C_n))
#    core type: Operation
#    operator: 8
#    operand: 9
# ...
