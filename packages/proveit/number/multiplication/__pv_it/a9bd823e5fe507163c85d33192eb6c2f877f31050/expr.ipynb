# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, Forall, InSet
from proveit.number import Complexes, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Forall([y], Equals(Neg(Mult(Neg(x), y)), Mult(x, y)), domain = Complexes, conditions = []), conditions = [InSet(x, Complexes)])
# Out:
# expr: x -> [forall_{y in Complexes} ((-((-x) * y)) = (x * y))] | x in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. x -> [forall_{y in Complexes} ((-((-x) * y)) = (x * y))] | x in Complexes
#    core type: Lambda
#    parameter: 24
#    body: 1
#    conditions: 2\n1. forall_{y in Complexes} ((-((-x) * y)) = (x * y))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. y -> ((-((-x) * y)) = (x * y)) | y in Complexes
#    core type: Lambda
#    parameter: 22
#    body: 6
#    conditions: 7\n5. x in Complexes
#    core type: Operation
#    operator: 14
#    operands: 8
# 6. (-((-x) * y)) = (x * y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. (x , Complexes)
#    core type: ExprTuple
#    sub-expressions: 24, 18
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (-((-x) * y) , x * y)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. y in Complexes
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. -((-x) * y)
#     core type: Operation
#     operator: 23
#     operand: 16
# 13. x * y
#     core type: Operation
#     operator: 19
#     operands: 17
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (y , Complexes)
#     core type: ExprTuple
#     sub-expressions: 22, 18
# 16. (-x) * y
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. (x , y)
#     core type: ExprTuple
#     sub-expressions: 24, 22
# 18. Complexes
#     core type: Literal
#     sub-expressions:
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (-x , y)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. -x
#     core type: Operation
#     operator: 23
#     operand: 24
# 22. y
#     core type: Variable
#     sub-expressions:
# 23. -
#     core type: Literal
#     sub-expressions:
# 24. x
#     core type: Variable
#     sub-expressions:
