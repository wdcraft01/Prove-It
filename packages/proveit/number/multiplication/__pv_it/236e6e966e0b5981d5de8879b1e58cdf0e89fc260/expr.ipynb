# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Sum.html">Sum</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Variable
from proveit._common_ import AA, BB, P, S, l, m
from proveit.logic._common_ import iterC1n
from proveit.number import Mult, Sum, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)
expr = Sum([subExpr2], Mult(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l), Function(P, subExpr2), iterC1n), domain = S, conditions = [])
# Out:
# expr: Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (B_1,...,B_m) -> (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n) | B_1 in  ...  in B_m in S
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (B_1 in  ...  in B_m in S)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (A_1 ,  ...  , A_l , P(B_1,...,B_m) , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. B_1 in  ...  in B_m in S
#    core type: Operation
#    operator: 34
#    operands: 11
# 8. A_1,...,A_l
#    core type: Iter
#    lambda_map: 12
#    start_index: 44
#    end_index: 40
# 9. P(B_1,...,B_m)
#    core type: Operation
# ...
