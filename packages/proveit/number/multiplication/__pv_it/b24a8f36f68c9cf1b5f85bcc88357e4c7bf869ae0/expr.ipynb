# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import AA, m
from proveit.logic import Forall, InSet
from proveit.logic._common_ import iterA1m
from proveit.number import Exp, Mult, Naturals

# %%
# build up the expression from sub-expressions
expr = Forall([AA], InSet(Mult(iterA1m), Naturals), domain = Exp(Naturals, m), conditions = [])
# Out:
# expr: forall_{A in Naturals^{m}} ((A_1 *  ...  * A_m) in Naturals)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{A in Naturals^{m}} ((A_1 *  ...  * A_m) in Naturals)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. A -> ((A_1 *  ...  * A_m) in Naturals) | A in Naturals^{m}
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. (A_1 *  ...  * A_m) in Naturals
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (A in Naturals^{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (A_1 *  ...  * A_m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 7, 16
# 6. A in Naturals^{m}
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. A_1 *  ...  * A_m
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (A , Naturals^{m})
#    core type: ExprTuple
#    sub-expressions: 19, 11
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (A_1 ,  ...  , A_m)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. Naturals^{m}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. A_1,...,A_m
#     core type: Iter
#     lambda_map: 15
#     start_index: 27
#     end_index: 28
# 13. Exp
#     core type: Literal
#     sub-expressions:
# 14. (Naturals , m)
#     core type: ExprTuple
#     sub-expressions: 16, 28
# 15. _x_ -> A__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 23
#     body: 17
#     conditions: 18\n16. Naturals
#     core type: Literal
#     sub-expressions:
# 17. A__x_
#     core type: Indexed
#     var: 19
#     index: 23
#     base: "1"
# 18. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 20
# 19. A
#     core type: Variable
#     sub-expressions:
# 20. _x_ in {1...m}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. _x_
#     core type: Variable
#     sub-expressions:
# 24. {1...m}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. m
#     core type: Variable
#     sub-expressions:
