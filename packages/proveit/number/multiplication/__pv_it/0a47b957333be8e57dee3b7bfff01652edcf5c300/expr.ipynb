# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Variable
from proveit._common_ import AA, BB, CC, P, S, l, m, n
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.logic._common_ import iterC1n
from proveit.number import Complexes, Exp, Mult, Naturals, Sum, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = []
subExpr3 = Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)
subExpr4 = Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l)
subExpr5 = Function(P, subExpr3)
subExpr6 = [subExpr3]
expr = Forall([m, n], Forall([P, S], Implies(Forall([BB], InSet(subExpr5, Complexes), domain = Exp(S, m), conditions = subExpr2), Forall([AA, CC], Equals(Mult(subExpr4, Sum(subExpr6, subExpr5, domain = S, conditions = subExpr2), iterC1n), Sum(subExpr6, Mult(subExpr4, subExpr5, iterC1n), domain = S, conditions = subExpr2)), domains = [Exp(Complexes, l), Exp(Complexes, n)], conditions = subExpr2)), conditions = subExpr2), domain = Naturals, conditions = subExpr2)
# Out:
# expr: forall_{m, n in Naturals} [forall_{P, S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{m, n in Naturals} [forall_{P, S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]
#    core type: Operation
#    operator: 28
#    operand: 1
# 1. m -> [forall_{n in Naturals} [forall_{P, S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]] | m in Naturals
#    core type: Lambda
#    parameter: 96
#    body: 2
#    conditions: 3\n2. forall_{n in Naturals} [forall_{P, S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]
#    core type: Operation
#    operator: 28
#    operand: 4
# 3. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. n -> [forall_{P, S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])] | n in Naturals
#    core type: Lambda
#    parameter: 90
#    body: 6
#    conditions: 7\n5. m in Naturals
#    core type: Operation
#    operator: 87
#    operands: 8
# 6. forall_{P, S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])
#    core type: Operation
#    operator: 28
#    operand: 9
# 7. (n in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (m , Naturals)
#    core type: ExprTuple
#    sub-expressions: 96, 14
# 9. P -> [forall_{S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])]
#    core type: Lambda
#    parameter: 63
#    body: 11
# 10. n in Naturals
#     core type: Operation
#     operator: 87
#     operands: 12
# 11. forall_{S} ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])
#     core type: Operation
#     operator: 28
#     operand: 13
# 12. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 90, 14
# 13. S -> ([forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])])
#     core type: Lambda
#     parameter: 71
#     body: 15
# 14. Naturals
#     core type: Literal
#     sub-expressions:
# 15. [forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)] => [forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])]
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. =>
#     core type: Literal
#     sub-expressions:
# 17. (forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes) , forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)]))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)
#     core type: Operation
#     operator: 28
#     operand: 20
# 19. forall_{(A, C) in Complexes^{l} * Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])
#     core type: Operation
#     operator: 28
#     operand: 21
# 20. B -> (P(B_1,...,B_m) in Complexes) | B in S^{m}
#     core type: Lambda
#     parameter: 83
#     body: 22
#     conditions: 23\n21. A -> [forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])] | A in Complexes^{l}
#     core type: Lambda
#     parameter: 72
#     body: 24
#     conditions: 25\n22. P(B_1,...,B_m) in Complexes
#     core type: Operation
#     operator: 87
#     operands: 26
# 23. (B in S^{m})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)])
#     core type: Operation
#     operator: 28
#     operand: 29
# 25. (A in Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 30
# 26. (P(B_1,...,B_m) , Complexes)
#     core type: ExprTuple
#     sub-expressions: 59, 56
# 27. B in S^{m}
#     core type: Operation
#     operator: 87
#     operands: 31
# 28. forall
#     core type: Literal
#     sub-expressions:
# 29. C -> ((A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)]) | C in Complexes^{n}
#     core type: Lambda
#     parameter: 74
#     body: 32
#     conditions: 33\n30. A in Complexes^{l}
#     core type: Operation
#     operator: 87
#     operands: 34
# 31. (B , S^{m})
#     core type: ExprTuple
#     sub-expressions: 83, 35
# 32. (A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n) = [Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)]
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. (C in Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 38
# 34. (A , Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 72, 39
# 35. S^{m}
#     core type: Operation
#     operator: 50
#     operands: 40
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n , Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 38. C in Complexes^{n}
#     core type: Operation
#     operator: 87
#     operands: 43
# 39. Complexes^{l}
#     core type: Operation
#     operator: 50
#     operands: 44
# 40. (S , m)
#     core type: ExprTuple
#     sub-expressions: 71, 96
# 41. A_1 *  ...  * A_l * [Sum_{B_1,...,B_m in S} P(B_1,...,B_m)] * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 54
#     operands: 45
# 42. Sum_{B_1,...,B_m in S} (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n)
#     core type: Operation
#     operator: 52
#     operand: 46
# 43. (C , Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 74, 47
# 44. (Complexes , l)
#     core type: ExprTuple
#     sub-expressions: 56, 89
# 45. (A_1 ,  ...  , A_l , Sum_{B_1,...,B_m in S} P(B_1,...,B_m) , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 58, 48, 60
# 46. (B_1,...,B_m) -> (A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n) | B_1 in  ...  in B_m in S
#     core type: Lambda
#     parameter: 70
#     body: 49
#     conditions: 57\n47. Complexes^{n}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. Sum_{B_1,...,B_m in S} P(B_1,...,B_m)
#     core type: Operation
#     operator: 52
#     operand: 53
# 49. A_1 *  ...  * A_l * P(B_1,...,B_m) * C_1 *  ...  * C_n
#     core type: Operation
#     operator: 54
#     operands: 55
# 50. Exp
#     core type: Literal
#     sub-expressions:
# 51. (Complexes , n)
#     core type: ExprTuple
#     sub-expressions: 56, 90
# 52. Sum
#     core type: Literal
#     sub-expressions:
# 53. (B_1,...,B_m) -> P(B_1,...,B_m) | B_1 in  ...  in B_m in S
#     core type: Lambda
#     parameter: 70
#     body: 59
#     conditions: 57\n54. *
#     core type: Literal
#     sub-expressions:
# 55. (A_1 ,  ...  , A_l , P(B_1,...,B_m) , C_1 ,  ...  , C_n)
#     core type: ExprTuple
#     sub-expressions: 58, 59, 60
# 56. Complexes
#     core type: Literal
#     sub-expressions:
# 57. (B_1 in  ...  in B_m in S)
#     core type: ExprTuple
#     sub-expressions: 61
# 58. A_1,...,A_l
#     core type: Iter
#     lambda_map: 62
#     start_index: 95
#     end_index: 89
# 59. P(B_1,...,B_m)
#     core type: Operation
#     operator: 63
#     operand: 70
# 60. C_1,...,C_n
#     core type: Iter
#     lambda_map: 64
#     start_index: 95
#     end_index: 90
# 61. B_1 in  ...  in B_m in S
#     core type: Operation
#     operator: 87
#     operands: 65
# 62. _x_ -> A__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 91
#     body: 66
#     conditions: 67\n63. P
#     core type: Variable
#     sub-expressions:
# 64. _x_ -> C__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 91
#     body: 68
#     conditions: 69\n65. (B_1 ,  ...  , B_m , S)
#     core type: ExprTuple
#     sub-expressions: 70, 71
# 66. A__x_
#     core type: Indexed
#     var: 72
#     index: 91
#     base: "1"
# 67. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 73
# 68. C__x_
#     core type: Indexed
#     var: 74
#     index: 91
#     base: "1"
# 69. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 75
# 70. B_1,...,B_m
#     core type: Iter
#     lambda_map: 76
#     start_index: 95
#     end_index: 96
# 71. S
#     core type: Variable
#     sub-expressions:
# 72. A
#     core type: Variable
#     sub-expressions:
# 73. _x_ in {1...l}
#     core type: Operation
#     operator: 87
#     operands: 77
# 74. C
#     core type: Variable
#     sub-expressions:
# 75. _x_ in {1...n}
#     core type: Operation
#     operator: 87
#     operands: 78
# 76. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 91
#     body: 79
#     conditions: 80\n77. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 91, 81
# 78. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 91, 82
# 79. B__x_
#     core type: Indexed
#     var: 83
#     index: 91
#     base: "1"
# 80. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 84
# 81. {1...l}
#     core type: Operation
#     operator: 93
#     operands: 85
# 82. {1...n}
#     core type: Operation
#     operator: 93
#     operands: 86
# 83. B
#     core type: Variable
#     sub-expressions:
# 84. _x_ in {1...m}
#     core type: Operation
#     operator: 87
#     operands: 88
# 85. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 95, 89
# 86. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 95, 90
# 87. in
#     core type: Literal
#     sub-expressions:
# 88. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 89. l
#     core type: Variable
#     sub-expressions:
# 90. n
#     core type: Variable
#     sub-expressions:
# 91. _x_
#     core type: Variable
#     sub-expressions:
# 92. {1...m}
#     core type: Operation
#     operator: 93
#     operands: 94
# 93. Interval
#     core type: Literal
#     sub-expressions:
# 94. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 95. 1
#     core type: Literal
#     sub-expressions:
# 96. m
#     core type: Variable
#     sub-expressions:
