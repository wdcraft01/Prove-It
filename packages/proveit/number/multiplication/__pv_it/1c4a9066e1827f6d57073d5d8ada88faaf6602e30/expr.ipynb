# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import cc, n
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Exp, Mult
from proveit.number._common_ import iter_a1l, iter_b1m, iter_c1n

# %%
# build up the expression from sub-expressions
expr = Forall([cc], Equals(Mult(iter_a1l, iter_b1m, iter_c1n), Mult(iter_a1l, Mult(iter_b1m), iter_c1n)), domain = Exp(Complexes, n), conditions = [])
# Out:
# expr: forall_{c in Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{c in Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. c -> ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n)) | c in Complexes^{n}
#    core type: Lambda
#    parameter: 32
#    body: 3
#    conditions: 4\n3. (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (c in Complexes^{n})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n , a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n)
#    core type: ExprTuple
# ...
