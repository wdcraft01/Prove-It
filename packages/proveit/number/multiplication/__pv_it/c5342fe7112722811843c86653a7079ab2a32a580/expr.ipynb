# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Lambda, Variable
from proveit._common_ import BB, P, S, m
from proveit.logic import InSet
from proveit.number import Complexes, Exp, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Lambda(BB, InSet(Function(P, Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)), Complexes), conditions = [InSet(BB, Exp(S, m))])
# Out:
# expr: B -> (P(B_1,...,B_m) in Complexes) | B in S^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> (P(B_1,...,B_m) in Complexes) | B in S^{m}
#    core type: Lambda
#    parameter: 17
#    body: 1
#    conditions: 2\n1. P(B_1,...,B_m) in Complexes
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. (B in S^{m})
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (P(B_1,...,B_m) , Complexes)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. B in S^{m}
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. P(B_1,...,B_m)
#    core type: Operation
#    operator: 8
#    operand: 9
# 6. Complexes
#    core type: Literal
#    sub-expressions:
# 7. (B , S^{m})
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 8. P
#    core type: Variable
#    sub-expressions:
# 9. B_1,...,B_m
#    core type: Iter
#    lambda_map: 11
#    start_index: 25
#    end_index: 26
# 10. S^{m}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 21
#     body: 14
# ...
