# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Mult.html">Mult</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import x, y
from proveit.logic._common_ import iterA1m, iterB1n
from proveit.number import Add, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Mult(iterA1m, Add(x, Neg(y)), iterB1n)
# Out:
# expr: A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A_1 *  ...  * A_m * (x - y) * B_1 *  ...  * B_n
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. (A_1 ,  ...  , A_m , x - y , B_1 ,  ...  , B_n)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. A_1,...,A_m
#    core type: Iter
#    lambda_map: 6
#    start_index: 32
#    end_index: 31
# 4. x - y
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. B_1,...,B_n
#    core type: Iter
#    lambda_map: 9
#    start_index: 32
#    end_index: 33
# 6. _x_ -> A__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 26
#    body: 10
#    conditions: 11\n7. +
#    core type: Literal
#    sub-expressions:
# 8. (x , -y)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. _x_ -> B__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 26
#    body: 14
#    conditions: 15\n10. A__x_
#     core type: Indexed
#     var: 16
#     index: 26
#     base: "1"
# 11. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 17
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. -y
#     core type: Operation
#     operator: 18
#     operand: 19
# 14. B__x_
#     core type: Indexed
#     var: 20
#     index: 26
#     base: "1"
# 15. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 21
# 16. A
#     core type: Variable
#     sub-expressions:
# 17. _x_ in {1...m}
#     core type: Operation
#     operator: 23
#     operands: 22
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. B
#     core type: Variable
#     sub-expressions:
# 21. _x_ in {1...n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. {1...m}
#     core type: Operation
#     operator: 29
#     operands: 28
# 26. _x_
#     core type: Variable
#     sub-expressions:
# 27. {1...n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 32, 31
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. m
#     core type: Variable
#     sub-expressions:
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. n
#     core type: Variable
#     sub-expressions:
