# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Variable
from proveit._common_ import BB, P, S, m
from proveit.logic import Forall, InSet
from proveit.number import Complexes, Exp, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
expr = Forall([BB], InSet(Function(P, Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)), Complexes), domain = Exp(S, m), conditions = [])
# Out:
# expr: forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{B in S^{m}} (P(B_1,...,B_m) in Complexes)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. B -> (P(B_1,...,B_m) in Complexes) | B in S^{m}
#    core type: Lambda
#    parameter: 19
#    body: 3
#    conditions: 4\n3. P(B_1,...,B_m) in Complexes
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. (B in S^{m})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (P(B_1,...,B_m) , Complexes)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. B in S^{m}
#    core type: Operation
#    operator: 21
#    operands: 9
# 7. P(B_1,...,B_m)
#    core type: Operation
#    operator: 10
#    operand: 11
# 8. Complexes
#    core type: Literal
#    sub-expressions:
# 9. (B , S^{m})
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 10. P
#     core type: Variable
#     sub-expressions:
# 11. B_1,...,B_m
#     core type: Iter
#     lambda_map: 13
#     start_index: 27
#     end_index: 28
# ...
