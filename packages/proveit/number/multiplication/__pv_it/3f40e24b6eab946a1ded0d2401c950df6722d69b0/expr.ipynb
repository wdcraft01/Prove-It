# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Function, Indexed, Iter, Variable
from proveit._common_ import AA, BB, P, S, l, m
from proveit.logic._common_ import iterC1n
from proveit.number import Sum, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)
expr = ExprTuple(Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l), Sum([subExpr2], Function(P, subExpr2), domain = S, conditions = []), iterC1n)
# Out:
# expr: (A_1 ,  ...  , A_l , Sum_{B_1,...,B_m in S} P(B_1,...,B_m) , C_1 ,  ...  , C_n)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (A_1 ,  ...  , A_l , Sum_{B_1,...,B_m in S} P(B_1,...,B_m) , C_1 ,  ...  , C_n)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. A_1,...,A_l
#    core type: Iter
#    lambda_map: 4
#    start_index: 42
#    end_index: 30
# 2. Sum_{B_1,...,B_m in S} P(B_1,...,B_m)
#    core type: Operation
#    operator: 5
#    operand: 6
# 3. C_1,...,C_n
#    core type: Iter
#    lambda_map: 7
#    start_index: 42
#    end_index: 33
# 4. _x_ -> A__x_ | _x_ in {1...l}
#    core type: Lambda
#    parameter: 38
#    body: 8
#    conditions: 9\n5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (B_1,...,B_m) -> P(B_1,...,B_m) | B_1 in  ...  in B_m in S
#    core type: Lambda
#    parameter: 24
#    body: 10
#    conditions: 11\n7. _x_ -> C__x_ | _x_ in {1...n}
#    core type: Lambda
#    parameter: 38
#    body: 12
#    conditions: 13\n8. A__x_
#    core type: Indexed
#    var: 14
#    index: 38
#    base: "1"
# 9. (_x_ in {1...l})
#    core type: ExprTuple
#    sub-expressions: 15
# ...
