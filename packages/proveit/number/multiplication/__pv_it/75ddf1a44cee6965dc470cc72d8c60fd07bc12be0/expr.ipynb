# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import AA, BB
from proveit.logic import Equals, Forall, InSet
from proveit.logic._common_ import iterA1m, iterB1n
from proveit.number import Complexes, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda(AA, Forall([BB], Equals(Mult(iterA1m, one, iterB1n), Mult(iterA1m, iterB1n)), domain = Complexes, conditions = []), conditions = [InSet(AA, Complexes)])
# Out:
# expr: A -> [forall_{B in Complexes} ((A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n))] | A in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. A -> [forall_{B in Complexes} ((A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n))] | A in Complexes
#    core type: Lambda
#    parameter: 27
#    body: 1
#    conditions: 2\n1. forall_{B in Complexes} ((A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (A in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. B -> ((A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n)) | B in Complexes
#    core type: Lambda
#    parameter: 29
#    body: 6
#    conditions: 7\n5. A in Complexes
#    core type: Operation
#    operator: 32
#    operands: 8
# 6. (A_1 *  ...  * A_m * 1 * B_1 *  ...  * B_n) = (A_1 *  ...  * A_m * B_1 *  ...  * B_n)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. (B in Complexes)
#    core type: ExprTuple
# ...
