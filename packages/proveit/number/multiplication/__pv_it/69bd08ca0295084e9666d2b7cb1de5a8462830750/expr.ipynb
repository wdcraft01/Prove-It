# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.number.Sum.html">Sum</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Function, Indexed, Iter, Variable
from proveit._common_ import BB, P, S, m
from proveit.number import Sum, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)
expr = Sum([subExpr2], Function(P, subExpr2), domain = S, conditions = [])
# Out:
# expr: Sum_{B_1,...,B_m in S} P(B_1,...,B_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. Sum_{B_1,...,B_m in S} P(B_1,...,B_m)
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (B_1,...,B_m) -> P(B_1,...,B_m) | B_1 in  ...  in B_m in S
#    core type: Lambda
#    parameter: 8
#    body: 3
#    conditions: 4\n3. P(B_1,...,B_m)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (B_1 in  ...  in B_m in S)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. P
#    core type: Variable
#    sub-expressions:
# 6. B_1 in  ...  in B_m in S
#    core type: Operation
#    operator: 15
#    operands: 7
# 7. (B_1 ,  ...  , B_m , S)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. B_1,...,B_m
#    core type: Iter
#    lambda_map: 10
#    start_index: 21
#    end_index: 22
# 9. S
#    core type: Variable
#    sub-expressions:
# 10. _x_ -> B__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 17
#     body: 11
#     conditions: 12\n11. B__x_
#     core type: Indexed
#     var: 13
#     index: 17
#     base: "1"
# 12. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. B
#     core type: Variable
#     sub-expressions:
# 14. _x_ in {1...m}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. _x_
#     core type: Variable
#     sub-expressions:
# 18. {1...m}
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. Interval
#     core type: Literal
#     sub-expressions:
# 20. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. m
#     core type: Variable
#     sub-expressions:
