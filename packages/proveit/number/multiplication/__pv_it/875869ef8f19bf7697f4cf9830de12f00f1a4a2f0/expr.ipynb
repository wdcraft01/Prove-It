# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import c, dd, n
from proveit.logic import Equals, Forall
from proveit.number import Complexes, Exp, Mult
from proveit.number._common_ import iter_a1l, iter_b1m, iter_d1n

# %%
# build up the expression from sub-expressions
expr = Forall([c, dd], Equals(Mult(iter_a1l, iter_b1m, c, iter_d1n), Mult(iter_a1l, c, iter_b1m, iter_d1n)), domains = [Complexes, Exp(Complexes, n)], conditions = [])
# Out:
# expr: forall_{(c, d) in Complexes * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{(c, d) in Complexes * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. c -> [forall_{d in Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n))] | c in Complexes
#    core type: Lambda
#    parameter: 21
#    body: 2
#    conditions: 3\n2. forall_{d in Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c * d_1 *  ...  * d_n) = (a_1 *  ...  * a_l * c * b_1 *  ...  * b_m * d_1 *  ...  * d_n))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (c in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# ...
