# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#association">association</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.multiplication._theorems_ import association

# %%
# check that the built expression is the same as the stored expression
# %check_expr association
# Out:
# Passed sanity check: built 'association' is the same as the stored Expression.

# %%
# display the expression information
association.exprInfo()
# Out:
# 0. forall_{l, m, n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))]
#    core type: Operation
#    operator: 25
#    operand: 1
# 1. l -> [forall_{m, n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))]] | l in Naturals
#    core type: Lambda
#    parameter: 76
#    body: 2
#    conditions: 3\n2. forall_{m, n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))]
#    core type: Operation
#    operator: 25
#    operand: 4
# 3. (l in Naturals)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. m -> [forall_{n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))]] | m in Naturals
#    core type: Lambda
#    parameter: 83
#    body: 6
#    conditions: 7\n5. l in Naturals
#    core type: Operation
#    operator: 73
#    operands: 8
# 6. forall_{n in Naturals} [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))]
#    core type: Operation
#    operator: 25
#    operand: 9
# 7. (m in Naturals)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. (l , Naturals)
#    core type: ExprTuple
#    sub-expressions: 76, 21
# 9. n -> [forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))] | n in Naturals
#    core type: Lambda
#    parameter: 79
#    body: 11
#    conditions: 12\n10. m in Naturals
#     core type: Operation
#     operator: 73
#     operands: 13
# 11. forall_{(a, b, c) in Complexes^{l} * Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))
#     core type: Operation
#     operator: 25
#     operand: 14
# 12. (n in Naturals)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. (m , Naturals)
#     core type: ExprTuple
#     sub-expressions: 83, 21
# 14. a -> [forall_{(b, c) in Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))] | a in Complexes^{l}
#     core type: Lambda
#     parameter: 59
#     body: 16
#     conditions: 17\n15. n in Naturals
#     core type: Operation
#     operator: 73
#     operands: 18
# 16. forall_{(b, c) in Complexes^{m} * Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))
#     core type: Operation
#     operator: 25
#     operand: 19
# 17. (a in Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (n , Naturals)
#     core type: ExprTuple
#     sub-expressions: 79, 21
# 19. b -> [forall_{c in Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))] | b in Complexes^{m}
#     core type: Lambda
#     parameter: 69
#     body: 22
#     conditions: 23\n20. a in Complexes^{l}
#     core type: Operation
#     operator: 73
#     operands: 24
# 21. Naturals
#     core type: Literal
#     sub-expressions:
# 22. forall_{c in Complexes^{n}} ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n))
#     core type: Operation
#     operator: 25
#     operand: 26
# 23. (b in Complexes^{m})
#     core type: ExprTuple
#     sub-expressions: 27
# 24. (a , Complexes^{l})
#     core type: ExprTuple
#     sub-expressions: 59, 28
# 25. forall
#     core type: Literal
#     sub-expressions:
# 26. c -> ((a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n)) | c in Complexes^{n}
#     core type: Lambda
#     parameter: 62
#     body: 29
#     conditions: 30\n27. b in Complexes^{m}
#     core type: Operation
#     operator: 73
#     operands: 31
# 28. Complexes^{l}
#     core type: Operation
#     operator: 47
#     operands: 32
# 29. (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n) = (a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n)
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. (c in Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 35
# 31. (b , Complexes^{m})
#     core type: ExprTuple
#     sub-expressions: 69, 36
# 32. (Complexes , l)
#     core type: ExprTuple
#     sub-expressions: 53, 76
# 33. =
#     core type: Literal
#     sub-expressions:
# 34. (a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n , a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. c in Complexes^{n}
#     core type: Operation
#     operator: 73
#     operands: 39
# 36. Complexes^{m}
#     core type: Operation
#     operator: 47
#     operands: 40
# 37. a_1 *  ...  * a_l * b_1 *  ...  * b_m * c_1 *  ...  * c_n
#     core type: Operation
#     operator: 50
#     operands: 41
# 38. a_1 *  ...  * a_l * (b_1 *  ...  * b_m) * c_1 *  ...  * c_n
#     core type: Operation
#     operator: 50
#     operands: 42
# 39. (c , Complexes^{n})
#     core type: ExprTuple
#     sub-expressions: 62, 43
# 40. (Complexes , m)
#     core type: ExprTuple
#     sub-expressions: 53, 83
# 41. (a_1 ,  ...  , a_l , b_1 ,  ...  , b_m , c_1 ,  ...  , c_n)
#     core type: ExprTuple
#     sub-expressions: 44, 56, 46
# 42. (a_1 ,  ...  , a_l , b_1 *  ...  * b_m , c_1 ,  ...  , c_n)
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46
# 43. Complexes^{n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. a_1,...,a_l
#     core type: Iter
#     lambda_map: 49
#     start_index: 82
#     end_index: 76
# 45. b_1 *  ...  * b_m
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. c_1,...,c_n
#     core type: Iter
#     lambda_map: 52
#     start_index: 82
#     end_index: 79
# 47. Exp
#     core type: Literal
#     sub-expressions:
# 48. (Complexes , n)
#     core type: ExprTuple
#     sub-expressions: 53, 79
# 49. _x_ -> a__x_ | _x_ in {1...l}
#     core type: Lambda
#     parameter: 77
#     body: 54
#     conditions: 55\n50. *
#     core type: Literal
#     sub-expressions:
# 51. (b_1 ,  ...  , b_m)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. _x_ -> c__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 77
#     body: 57
#     conditions: 58\n53. Complexes
#     core type: Literal
#     sub-expressions:
# 54. a__x_
#     core type: Indexed
#     var: 59
#     index: 77
#     base: "1"
# 55. (_x_ in {1...l})
#     core type: ExprTuple
#     sub-expressions: 60
# 56. b_1,...,b_m
#     core type: Iter
#     lambda_map: 61
#     start_index: 82
#     end_index: 83
# 57. c__x_
#     core type: Indexed
#     var: 62
#     index: 77
#     base: "1"
# 58. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 63
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. _x_ in {1...l}
#     core type: Operation
#     operator: 73
#     operands: 64
# 61. _x_ -> b__x_ | _x_ in {1...m}
#     core type: Lambda
#     parameter: 77
#     body: 65
#     conditions: 66\n62. c
#     core type: Variable
#     sub-expressions:
# 63. _x_ in {1...n}
#     core type: Operation
#     operator: 73
#     operands: 67
# 64. (_x_ , {1...l})
#     core type: ExprTuple
#     sub-expressions: 77, 68
# 65. b__x_
#     core type: Indexed
#     var: 69
#     index: 77
#     base: "1"
# 66. (_x_ in {1...m})
#     core type: ExprTuple
#     sub-expressions: 70
# 67. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 77, 71
# 68. {1...l}
#     core type: Operation
#     operator: 80
#     operands: 72
# 69. b
#     core type: Variable
#     sub-expressions:
# 70. _x_ in {1...m}
#     core type: Operation
#     operator: 73
#     operands: 74
# 71. {1...n}
#     core type: Operation
#     operator: 80
#     operands: 75
# 72. (1 , l)
#     core type: ExprTuple
#     sub-expressions: 82, 76
# 73. in
#     core type: Literal
#     sub-expressions:
# 74. (_x_ , {1...m})
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 82, 79
# 76. l
#     core type: Variable
#     sub-expressions:
# 77. _x_
#     core type: Variable
#     sub-expressions:
# 78. {1...m}
#     core type: Operation
#     operator: 80
#     operands: 81
# 79. n
#     core type: Variable
#     sub-expressions:
# 80. Interval
#     core type: Literal
#     sub-expressions:
# 81. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 82. 1
#     core type: Literal
#     sub-expressions:
# 83. m
#     core type: Variable
#     sub-expressions:
