# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.number._common_ import iter_b1m

# %%
# build up the expression from sub-expressions
expr = ExprTuple(iter_b1m)
# Out:
# expr: (b_1 ,  ...  , b_m)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (b_1 ,  ...  , b_m)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. b_1,...,b_m
#    core type: Iter
#    lambda_map: 2
#    start_index: 13
#    end_index: 14
# 2. _x_ -> b__x_ | _x_ in {1...m}
#    core type: Lambda
#    parameter: 9
#    body: 3
#    conditions: 4\n3. b__x_
#    core type: Indexed
#    var: 5
#    index: 9
#    base: "1"
# 4. (_x_ in {1...m})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. b
#    core type: Variable
#    sub-expressions:
# 6. _x_ in {1...m}
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (_x_ , {1...m})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. _x_
#    core type: Variable
#    sub-expressions:
# 10. {1...m}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (1 , m)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. m
#     core type: Variable
#     sub-expressions:
