# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.multiplication</a>

# %%
# import Expression classes needed to build the expression
from proveit import Indexed, Iter, Lambda, Variable
from proveit._common_ import AA, BB, CC, i, l, m, n
from proveit.logic import Equals, Forall, InSet
from proveit.logic._common_ import iterC1n
from proveit.number import Add, Complexes, Exp, Mult, one

# %%
# build up the expression from sub-expressions
subExpr1 = Variable("_x_", latexFormat = r"{_{-}x_{-}}")
subExpr2 = Iter(subExpr1, Indexed(AA, subExpr1, base = 1), one, l)
expr = Lambda(BB, Forall([CC], Equals(Mult(subExpr2, Add(Iter(subExpr1, Indexed(BB, subExpr1, base = 1), one, m)), iterC1n), Add(Iter(i, Mult(subExpr2, Indexed(BB, i, base = 1), iterC1n), one, m))), domain = Exp(Complexes, n), conditions = []), conditions = [InSet(BB, Exp(Complexes, m))])
# Out:
# expr: B -> [forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))] | B in Complexes^{m}

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. B -> [forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))] | B in Complexes^{m}
#    core type: Lambda
#    parameter: 43
#    body: 1
#    conditions: 2\n1. forall_{C in Complexes^{n}} ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n)))
#    core type: Operation
#    operator: 3
#    operand: 4
# 2. (B in Complexes^{m})
#    core type: ExprTuple
#    sub-expressions: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. C -> ((A_1 *  ...  * A_l * (B_1 +  ...  + B_m) * C_1 *  ...  * C_n) = ((A_1 *  ...  * A_l * B_1 * C_1 *  ...  * C_n) +  ...  + (A_1 *  ...  * A_l * B_m * C_1 *  ...  * C_n))) | C in Complexes^{n}
#    core type: Lambda
#    parameter: 54
#    body: 6
#    conditions: 7\n5. B in Complexes^{m}
# ...
