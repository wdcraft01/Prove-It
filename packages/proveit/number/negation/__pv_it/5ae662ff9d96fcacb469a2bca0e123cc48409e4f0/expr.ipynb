# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#multNegOneRight">multNegOneRight</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.negation._theorems_ import multNegOneRight

# %%
# check that the built expression is the same as the stored expression
# %check_expr multNegOneRight
# Out:
# Passed sanity check: built 'multNegOneRight' is the same as the stored Expression.

# %%
# display the expression information
multNegOneRight.exprInfo()
# Out:
# 0. forall_{x in Complexes} ((x * (-1)) = (-x))
#    core type: Operation
#    operator: 1
#    operand: 2
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. x -> ((x * (-1)) = (-x)) | x in Complexes
#    core type: Lambda
#    parameter: 15
#    body: 3
#    conditions: 4\n3. (x * (-1)) = (-x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complexes)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x * (-1) , -x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. x in Complexes
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x * (-1)
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. -x
#    core type: Operation
#    operator: 17
#    operand: 15
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x , Complexes)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. *
#     core type: Literal
#     sub-expressions:
# ...
