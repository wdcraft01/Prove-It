# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#distributeNegThroughSum">distributeNegThroughSum</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.negation._theorems_ import distributeNegThroughSum

# %%
# check that the built expression is the same as the stored expression
# %check_expr distributeNegThroughSum
# Out:
# Passed sanity check: built 'distributeNegThroughSum' is the same as the stored Expression.

# %%
# display the expression information
distributeNegThroughSum.exprInfo()
# Out:
# 0. forall_{n in NaturalsPos} [forall_{x in Complexes^{n}} ((-(x_1 +  ...  + x_n)) = ((-x_1) +  ...  + (-x_n)))]
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. n -> [forall_{x in Complexes^{n}} ((-(x_1 +  ...  + x_n)) = ((-x_1) +  ...  + (-x_n)))] | n in NaturalsPos
#    core type: Lambda
#    parameter: 47
#    body: 2
#    conditions: 3\n2. forall_{x in Complexes^{n}} ((-(x_1 +  ...  + x_n)) = ((-x_1) +  ...  + (-x_n)))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (n in NaturalsPos)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. x -> ((-(x_1 +  ...  + x_n)) = ((-x_1) +  ...  + (-x_n))) | x in Complexes^{n}
#    core type: Lambda
#    parameter: 37
#    body: 7
#    conditions: 8\n6. n in NaturalsPos
#    core type: Operation
#    operator: 39
#    operands: 9
# 7. (-(x_1 +  ...  + x_n)) = ((-x_1) +  ...  + (-x_n))
#    core type: Operation
#    operator: 10
#    operands: 11
# ...
