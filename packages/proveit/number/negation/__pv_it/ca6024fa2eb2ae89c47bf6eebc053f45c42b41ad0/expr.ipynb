# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>

# %%
# import Expression classes needed to build the expression
from proveit import ExprTuple, Indexed, Iter
from proveit._common_ import k, n, xx
from proveit.logic._common_ import xIter1n
from proveit.number import Add, Neg, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Neg(Add(xIter1n)), Add(Iter(k, Neg(Indexed(xx, k, base = 1)), one, n)))
# Out:
# expr: (-(x_1 +  ...  + x_n) , (-x_1) +  ...  + (-x_n))

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. (-(x_1 +  ...  + x_n) , (-x_1) +  ...  + (-x_n))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. -(x_1 +  ...  + x_n)
#    core type: Operation
#    operator: 15
#    operand: 3
# 2. (-x_1) +  ...  + (-x_n)
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. x_1 +  ...  + x_n
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (-x_1 ,  ...  , -x_n)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (x_1 ,  ...  , x_n)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (-x_1),...,(-x_n)
#    core type: Iter
#    lambda_map: 9
#    start_index: 28
#    end_index: 29
# 8. x_1,...,x_n
#    core type: Iter
#    lambda_map: 10
#    start_index: 28
#    end_index: 29
# 9. k -> (-x_k) | k in {1...n}
#    core type: Lambda
#    parameter: 23
#    body: 11
#    conditions: 12\n10. _x_ -> x__x_ | _x_ in {1...n}
#     core type: Lambda
#     parameter: 24
#     body: 13
#     conditions: 14\n11. -x_k
#     core type: Operation
#     operator: 15
#     operand: 16
# 12. (k in {1...n})
#     core type: ExprTuple
#     sub-expressions: 17
# 13. x__x_
#     core type: Indexed
#     var: 19
#     index: 24
#     base: "1"
# 14. (_x_ in {1...n})
#     core type: ExprTuple
#     sub-expressions: 18
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. x_k
#     core type: Indexed
#     var: 19
#     index: 23
#     base: "1"
# 17. k in {1...n}
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. _x_ in {1...n}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. (k , {1...n})
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (_x_ , {1...n})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. k
#     core type: Variable
#     sub-expressions:
# 24. _x_
#     core type: Variable
#     sub-expressions:
# 25. {1...n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (1 , n)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 1
#     core type: Literal
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
