# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import x, y
from proveit.logic import Equals, InSet
from proveit.number import Complexes, Mult, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Equals(Mult(Neg(x), Neg(y)), Mult(x, y)), conditions = [InSet(y, Complexes)])
# Out:
# expr: y -> (((-x) * (-y)) = (x * y)) | y in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. y -> (((-x) * (-y)) = (x * y)) | y in Complexes
#    core type: Lambda
#    parameter: 18
#    body: 1
#    conditions: 2\n1. ((-x) * (-y)) = (x * y)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (y in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((-x) * (-y) , x * y)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. y in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. (-x) * (-y)
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. x * y
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (y , Complexes)
#    core type: ExprTuple
#    sub-expressions: 18, 13
# 10. (-x , -y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (x , y)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 13. Complexes
#     core type: Literal
#     sub-expressions:
# 14. -x
#     core type: Operation
#     operator: 17
#     operand: 16
# 15. -y
#     core type: Operation
#     operator: 17
#     operand: 18
# 16. x
#     core type: Variable
#     sub-expressions:
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. y
#     core type: Variable
#     sub-expressions:
