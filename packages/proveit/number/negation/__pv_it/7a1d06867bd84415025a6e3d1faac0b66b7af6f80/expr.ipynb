# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a
from proveit.logic import InSet
from proveit.number import Greater, Less, Neg, Reals, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Less(Neg(a), zero), conditions = [InSet(a, Reals), Greater(a, zero)])
# Out:
# expr: a -> ((-a) < 0) | a in Reals , a > 0

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. a -> ((-a) < 0) | a in Reals , a > 0
#    core type: Lambda
#    parameter: 14
#    body: 1
#    conditions: 2\n1. (-a) < 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Reals , a > 0)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 3. <
#    core type: Literal
#    sub-expressions:
# 4. (-a , 0)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 5. a in Reals
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. a > 0
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. -a
#    core type: Operation
#    operator: 12
#    operand: 14
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a , Reals)
#    core type: ExprTuple
#    sub-expressions: 14, 13
# 10. >
#     core type: Literal
#     sub-expressions:
# 11. (a , 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. Reals
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
