# %% [markdown]
# Theorem <a class="ProveItLink" href="../../_theorems_.ipynb#distributeNegThroughBinarySum">distributeNegThroughBinarySum</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
# import the special expression
from proveit.number.negation._theorems_ import distributeNegThroughBinarySum

# %%
# check that the built expression is the same as the stored expression
# %check_expr distributeNegThroughBinarySum
# Out:
# Passed sanity check: built 'distributeNegThroughBinarySum' is the same as the stored Expression.

# %%
# display the expression information
distributeNegThroughBinarySum.exprInfo()
# Out:
# 0. forall_{a, b in Complexes} ((-(a + b)) = (-a - b))
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. a -> [forall_{b in Complexes} ((-(a + b)) = (-a - b))] | a in Complexes
#    core type: Lambda
#    parameter: 24
#    body: 2
#    conditions: 3\n2. forall_{b in Complexes} ((-(a + b)) = (-a - b))
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (a in Complexes)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. b -> ((-(a + b)) = (-a - b)) | b in Complexes
#    core type: Lambda
#    parameter: 26
#    body: 7
#    conditions: 8\n6. a in Complexes
#    core type: Operation
#    operator: 15
#    operands: 9
# 7. (-(a + b)) = (-a - b)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. (a , Complexes)
#    core type: ExprTuple
#    sub-expressions: 24, 19
# 10. =
#     core type: Literal
# ...
