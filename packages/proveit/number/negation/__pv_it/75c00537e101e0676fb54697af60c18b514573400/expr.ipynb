# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>

# %%
# import Expression classes needed to build the expression
from proveit._common_ import a, b, c
from proveit.logic import Equals, Forall
from proveit.number import Add, Naturals, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([b, c], Equals(Add(c, Neg(a)).withSubtractionAt(), b), domain = Naturals, conditions = [Equals(Add(a, b), c)])
# Out:
# expr: forall_{b, c in Naturals | (a + b) = c} ((c + (-a)) = b)

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. forall_{b, c in Naturals | (a + b) = c} ((c + (-a)) = b)
#    core type: Operation
#    operator: 4
#    operand: 1
# 1. b -> [forall_{c in Naturals | (a + b) = c} ((c + (-a)) = b)] | b in Naturals
#    core type: Lambda
#    parameter: 27
#    body: 2
#    conditions: 3\n2. forall_{c in Naturals | (a + b) = c} ((c + (-a)) = b)
#    core type: Operation
#    operator: 4
#    operand: 5
# 3. (b in Naturals)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. c -> ((c + (-a)) = b) | c in Naturals , (a + b) = c
#    core type: Lambda
#    parameter: 21
#    body: 7
#    conditions: 8\n6. b in Naturals
#    core type: Operation
#    operator: 14
#    operands: 9
# 7. (c + (-a)) = b
#    core type: Operation
#    operator: 16
#    operands: 10
# 8. (c in Naturals , (a + b) = c)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (b , Naturals)
#    core type: ExprTuple
#    sub-expressions: 27, 19
# 10. (c + (-a) , b)
#     core type: ExprTuple
#     sub-expressions: 13, 27
# 11. c in Naturals
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (a + b) = c
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. c + (-a)
#     core type: Operation
#     operator: 23
#     operands: 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (c , Naturals)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (a + b , c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (c , -a)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. Naturals
#     core type: Literal
#     sub-expressions:
# 20. a + b
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. -a
#     core type: Operation
#     operator: 25
#     operand: 26
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (a , b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
