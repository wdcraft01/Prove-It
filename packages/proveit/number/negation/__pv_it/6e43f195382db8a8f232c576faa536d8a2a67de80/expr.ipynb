# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from context <a class="ProveItLink" href="../../_context_.ipynb">proveit.number.negation</a>

# %%
# import Expression classes needed to build the expression
from proveit import Lambda
from proveit._common_ import a, b
from proveit.logic import Equals, InSet
from proveit.number import Add, Complexes, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Equals(Neg(Add(a, Neg(b))), Add(Neg(a), b)), conditions = [InSet(b, Complexes)])
# Out:
# expr: b -> ((-(a - b)) = (-a + b)) | b in Complexes

# %%
# check that the built expression is the same as the stored expression
# %check_expr
# Out:
# Passed sanity check: built 'expr' is the same as the stored Expression.

# %%
# display the expression information
expr.exprInfo()
# Out:
# 0. b -> ((-(a - b)) = (-a + b)) | b in Complexes
#    core type: Lambda
#    parameter: 19
#    body: 1
#    conditions: 2\n1. (-(a - b)) = (-a + b)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (b in Complexes)
#    core type: ExprTuple
#    sub-expressions: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (-(a - b) , -a + b)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. b in Complexes
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. -(a - b)
#    core type: Operation
#    operator: 18
#    operand: 10
# 7. -a + b
#    core type: Operation
#    operator: 13
#    operands: 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (b , Complexes)
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 10. a - b
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. (-a , b)
#     core type: ExprTuple
#     sub-expressions: 15, 19
# 12. Complexes
#     core type: Literal
#     sub-expressions:
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (a , -b)
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 15. -a
#     core type: Operation
#     operator: 18
#     operand: 17
# 16. -b
#     core type: Operation
#     operator: 18
#     operand: 19
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
