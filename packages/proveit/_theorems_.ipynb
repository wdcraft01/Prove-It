# %% [markdown]
# Theorems for context <a href="_context_.ipynb" class="ProveItLink">proveit</a>
# ========

# %%
import proveit
from proveit import Indexed, Iter, Function
from proveit._common_ import i, j, k, l, P, iterPil, iterPjk
from proveit.logic import Forall, InSet
from proveit.number import Subtract, Naturals
# %begin theorems
# Out:
# Defining theorems for context 'proveit'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %%
iterInstance = Forall((i, j, l), Forall(P, Function(P, j), \
                                     conditions=[iterPil, \
                                                 InSet(Subtract(j, i), Naturals), \
                                                 InSet(Subtract(l, j), Naturals)]))
# Out:
# iterInstance: forall_{i, j, l} [forall_{P | P(i) ,  ...  , P(l) , (j - i) in Naturals , (l - j) in Naturals} P(j)]

# %%
iterInterval = Forall((i, j, k, l), Forall(P, iterPjk, \
                                     conditions=[iterPil, \
                                                 InSet(Subtract(j, i), Naturals), \
                                                 InSet(Subtract(l, k), Naturals)]))
# Out:
# iterInterval: forall_{i, j, k, l} [forall_{P | P(i) ,  ...  , P(l) , (j - i) in Naturals , (l - k) in Naturals} (P(j),...,P(k))]

# %%
# %end theorems
# Out:
# Modifying theorem iterInstance in proveit context
# Modifying theorem iterInterval in proveit context
# iterInstance expression notebook is being updated
# iterInterval expression notebook is being updated
# Theorems may be imported from autogenerated _theorems_.py
